# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/Do_an_tot_nghiep/blob/main/GIN_Adam_C2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Oct 25 11:08:52 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    52W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric==1.4.3
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5
# !pip install torch-optimizer

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter_
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset
import torch_optimizer as optimization


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric==1.4.3 in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.18.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.12.1+cu113)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (6.2.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.56.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.3.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.23.0)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.7.4)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.21.6)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.6.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->torch-geometric==1.4.3) (1.5.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (4.13.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (57.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (0.39.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (4.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2022.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.4.3) (1.15.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (0.6.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (1.24.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (1.3.0)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (3.2.2)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2021.11.2)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (7.1.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2.9.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (1.4.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-optimizer in /usr/local/lib/python3.7/dist-packages (0.3.0)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (1.12.1+cu113)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (0.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->torch-optimizer) (4.1.1)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
            self.num_graphs = 768
        elif split == 'val':
            self.path = self.processed_paths[1]
            self.num_graphs = 96
        elif split == 'test':
            self.path = self.processed_paths[2]
            self.num_graphs = 96

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GINConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_input_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU())))
          else:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU()))) 

        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                add_xr_at = n
            if n == add_xr_at:
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/C2'
data_name = 'c2' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=True, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=True, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=True, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 4
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# !rm -rf /content/saved_models

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.0
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}_{result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    # class_weight = torch.Tensor([0.54, 7.15])
    # class_weight = class_weight.cuda(device=0)
    # criterion = torch.nn.CrossEntropyLoss(weight=class_weight)
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    # print(class_weight)
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-825b14a1-41a3-404a-8e6f-1dacdbcdd0e9.json
# ------------------------------
# ------------------------------
# Tue Oct 25 11:10:56 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GINConv(nn=Sequential(
#       (0): Linear(in_features=1, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (1): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (2): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (3): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (4): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (5): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (6): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (7): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (8): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (9): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (10): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (11): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 4
# epoch: 1, passed number of graphs: 96, train running loss: 0.04856 (passed time: 7s)
#           acc: 0.97694, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 192, train running loss: 0.03783 (passed time: 11s)
#           acc: 0.97707, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 288, train running loss: 0.03387 (passed time: 15s)
#           acc: 0.97868, fpr: 0.00001, fnr: 1.00000, rec: 0.00000, prc: 0.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 384, train running loss: 0.03137 (passed time: 20s)
#           acc: 0.97799, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 480, train running loss: 0.02905 (passed time: 24s)
#           acc: 0.97666, fpr: 0.00001, fnr: 0.99554, rec: 0.00446, prc: 0.90769, f1: 0.00887, f1_macro: 0.49853
# epoch: 1, passed number of graphs: 576, train running loss: 0.02666 (passed time: 28s)
#           acc: 0.98017, fpr: 0.00026, fnr: 0.90794, rec: 0.09206, prc: 0.88536, f1: 0.16678, f1_macro: 0.57837
# epoch: 1, passed number of graphs: 672, train running loss: 0.02435 (passed time: 32s)
#           acc: 0.98034, fpr: 0.00485, fnr: 0.62959, rec: 0.37041, prc: 0.64989, f1: 0.47187, f1_macro: 0.73092
# epoch: 1, passed number of graphs: 768, train running loss: 0.02238 (passed time: 37s)
#           acc: 0.98989, fpr: 0.00288, fnr: 0.32941, rec: 0.67059, prc: 0.84071, f1: 0.74608, f1_macro: 0.87046
# Validation --- epoch: 1, loss: 0.07389
#           fpr: 0.02762, prc: 0.56464, f1: 0.62642, rec: 0.87064, fnr: 0.12936, f1_macro: 0.80545, acc: 0.97030
# Better model saved at ./saved_models/GIN_0_0.62641673183252.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.00779 (passed time: 44s)
#           acc: 0.99866, fpr: 0.00005, fnr: 0.05597, rec: 0.94403, prc: 0.99778, f1: 0.97016, f1_macro: 0.98474
# epoch: 2, passed number of graphs: 192, train running loss: 0.00456 (passed time: 49s)
#           acc: 0.99901, fpr: 0.00005, fnr: 0.04095, rec: 0.95905, prc: 0.99756, f1: 0.97793, f1_macro: 0.98871
# epoch: 2, passed number of graphs: 288, train running loss: 0.00336 (passed time: 53s)
#           acc: 0.99939, fpr: 0.00034, fnr: 0.01301, rec: 0.98699, prc: 0.98465, f1: 0.98582, f1_macro: 0.99276
# epoch: 2, passed number of graphs: 384, train running loss: 0.00265 (passed time: 57s)
#           acc: 0.99983, fpr: 0.00008, fnr: 0.00397, rec: 0.99603, prc: 0.99627, f1: 0.99615, f1_macro: 0.99803
# epoch: 2, passed number of graphs: 480, train running loss: 0.00761 (passed time: 1m 2s)
#           acc: 0.97656, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 576, train running loss: 0.01076 (passed time: 1m 6s)
#           acc: 0.97844, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 672, train running loss: 0.01281 (passed time: 1m 10s)
#           acc: 0.97629, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 768, train running loss: 0.01407 (passed time: 1m 14s)
#           acc: 0.97784, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# Validation --- epoch: 2, loss: 0.09327
#           fpr: 0.00000, prc: -1.00000, f1: 0.00000, rec: 0.00000, fnr: 1.00000, f1_macro: nan, acc: 0.97750
# epoch: 3, passed number of graphs: 96, train running loss: 0.01883 (passed time: 1m 22s)
#           acc: 0.97790, fpr: 0.00000, fnr: 0.95831, rec: 0.04169, prc: 1.00000, f1: 0.08005, f1_macro: 0.53443
# epoch: 3, passed number of graphs: 192, train running loss: 0.01616 (passed time: 1m 26s)
#           acc: 0.97709, fpr: 0.00004, fnr: 0.99713, rec: 0.00287, prc: 0.62295, f1: 0.00572, f1_macro: 0.49707
# epoch: 3, passed number of graphs: 288, train running loss: 0.01531 (passed time: 1m 30s)
#           acc: 0.97936, fpr: 0.02047, fnr: 0.02815, rec: 0.97185, prc: 0.50830, f1: 0.66749, f1_macro: 0.82842
# epoch: 3, passed number of graphs: 384, train running loss: 0.01513 (passed time: 1m 35s)
#           acc: 0.98646, fpr: 0.00011, fnr: 0.61036, rec: 0.38964, prc: 0.98812, f1: 0.55890, f1_macro: 0.77601
# epoch: 3, passed number of graphs: 480, train running loss: 0.01293 (passed time: 1m 39s)
#           acc: 0.99795, fpr: 0.00109, fnr: 0.04230, rec: 0.95770, prc: 0.95488, f1: 0.95629, f1_macro: 0.97762
# epoch: 3, passed number of graphs: 576, train running loss: 0.01172 (passed time: 1m 43s)
#           acc: 0.99650, fpr: 0.00091, fnr: 0.12097, rec: 0.87903, prc: 0.95511, f1: 0.91549, f1_macro: 0.95685
# epoch: 3, passed number of graphs: 672, train running loss: 0.01039 (passed time: 1m 48s)
#           acc: 0.99762, fpr: 0.00089, fnr: 0.06371, rec: 0.93629, prc: 0.96215, f1: 0.94905, f1_macro: 0.97391
# epoch: 3, passed number of graphs: 768, train running loss: 0.00932 (passed time: 1m 52s)
#           acc: 0.99756, fpr: 0.00125, fnr: 0.05480, rec: 0.94520, prc: 0.94491, f1: 0.94505, f1_macro: 0.97190
# Validation --- epoch: 3, loss: 0.01263
#           fpr: 0.00415, prc: 0.87260, f1: 0.91218, rec: 0.97211, fnr: 0.02789, f1_macro: 0.95490, acc: 0.99537
# Better model saved at ./saved_models/GIN_2_0.9121772975352765.pt.
# epoch: 4, passed number of graphs: 96, train running loss: 0.00092 (passed time: 2m 0s)
#           acc: 0.99866, fpr: 0.00111, fnr: 0.01104, rec: 0.98896, prc: 0.95447, f1: 0.97141, f1_macro: 0.98536
# epoch: 4, passed number of graphs: 192, train running loss: 0.00076 (passed time: 2m 4s)
#           acc: 0.99933, fpr: 0.00007, fnr: 0.02584, rec: 0.97416, prc: 0.99675, f1: 0.98533, f1_macro: 0.99249
# epoch: 4, passed number of graphs: 288, train running loss: 0.00078 (passed time: 2m 8s)
#           acc: 0.99848, fpr: 0.00134, fnr: 0.00990, rec: 0.99010, prc: 0.94141, f1: 0.96514, f1_macro: 0.98218
# epoch: 4, passed number of graphs: 384, train running loss: 0.00302 (passed time: 2m 12s)
#           acc: 0.98564, fpr: 0.00231, fnr: 0.54960, rec: 0.45040, prc: 0.81421, f1: 0.57998, f1_macro: 0.78634
# epoch: 4, passed number of graphs: 480, train running loss: 0.00352 (passed time: 2m 17s)
#           acc: 0.99761, fpr: 0.00098, fnr: 0.06119, rec: 0.93881, prc: 0.95851, f1: 0.94856, f1_macro: 0.97367
# epoch: 4, passed number of graphs: 576, train running loss: 0.00324 (passed time: 2m 21s)
#           acc: 0.99760, fpr: 0.00127, fnr: 0.05372, rec: 0.94628, prc: 0.94256, f1: 0.94442, f1_macro: 0.97159
# epoch: 4, passed number of graphs: 672, train running loss: 0.00293 (passed time: 2m 25s)
#           acc: 0.99847, fpr: 0.00011, fnr: 0.06037, rec: 0.93963, prc: 0.99538, f1: 0.96671, f1_macro: 0.98296
# epoch: 4, passed number of graphs: 768, train running loss: 0.00277 (passed time: 2m 29s)
#           acc: 0.99810, fpr: 0.00060, fnr: 0.05908, rec: 0.94092, prc: 0.97253, f1: 0.95646, f1_macro: 0.97774
# Validation --- epoch: 4, loss: 0.02325
#           fpr: 0.01120, prc: 0.67462, f1: 0.79901, rec: 0.98565, fnr: 0.01435, f1_macro: 0.89661, acc: 0.98877
# epoch: 5, passed number of graphs: 96, train running loss: 0.00089 (passed time: 2m 37s)
#           acc: 0.99964, fpr: 0.00003, fnr: 0.01427, rec: 0.98573, prc: 0.99863, f1: 0.99214, f1_macro: 0.99598
# epoch: 5, passed number of graphs: 192, train running loss: 0.00088 (passed time: 2m 41s)
#           acc: 0.99933, fpr: 0.00006, fnr: 0.02690, rec: 0.97310, prc: 0.99752, f1: 0.98516, f1_macro: 0.99241
# epoch: 5, passed number of graphs: 288, train running loss: 0.00091 (passed time: 2m 46s)
#           acc: 0.99946, fpr: 0.00010, fnr: 0.02087, rec: 0.97913, prc: 0.99551, f1: 0.98725, f1_macro: 0.99349
# epoch: 5, passed number of graphs: 384, train running loss: 0.00086 (passed time: 2m 50s)
#           acc: 0.99982, fpr: 0.00008, fnr: 0.00453, rec: 0.99547, prc: 0.99634, f1: 0.99591, f1_macro: 0.99791
# epoch: 5, passed number of graphs: 480, train running loss: 0.00090 (passed time: 2m 54s)
#           acc: 0.99927, fpr: 0.00023, fnr: 0.02138, rec: 0.97862, prc: 0.99014, f1: 0.98435, f1_macro: 0.99199
# epoch: 5, passed number of graphs: 576, train running loss: 0.00087 (passed time: 2m 58s)
#           acc: 0.99936, fpr: 0.00012, fnr: 0.02416, rec: 0.97584, prc: 0.99426, f1: 0.98496, f1_macro: 0.99232
# epoch: 5, passed number of graphs: 672, train running loss: 0.00084 (passed time: 3m 3s)
#           acc: 0.99860, fpr: 0.00036, fnr: 0.04446, rec: 0.95554, prc: 0.98480, f1: 0.96995, f1_macro: 0.98462
# epoch: 5, passed number of graphs: 768, train running loss: 0.00082 (passed time: 3m 7s)
#           acc: 0.99919, fpr: 0.00005, fnr: 0.03430, rec: 0.96570, prc: 0.99758, f1: 0.98138, f1_macro: 0.99048
# Validation --- epoch: 5, loss: 0.00428
#           fpr: 0.00099, prc: 0.96119, f1: 0.97301, rec: 0.98714, fnr: 0.01286, f1_macro: 0.98620, acc: 0.99879
# Better model saved at ./saved_models/GIN_4_0.9730134898434359.pt.
# epoch: 6, passed number of graphs: 96, train running loss: 0.00560 (passed time: 3m 15s)
#           acc: 0.98102, fpr: 0.00000, fnr: 0.82278, rec: 0.17722, prc: 0.99958, f1: 0.30107, f1_macro: 0.64572
# epoch: 6, passed number of graphs: 192, train running loss: 0.01023 (passed time: 3m 19s)
#           acc: 0.97921, fpr: 0.00000, fnr: 0.90684, rec: 0.09316, prc: 1.00000, f1: 0.17045, f1_macro: 0.57996
# epoch: 6, passed number of graphs: 288, train running loss: 0.00907 (passed time: 3m 23s)
#           acc: 0.99537, fpr: 0.00290, fnr: 0.08387, rec: 0.91613, prc: 0.87291, f1: 0.89400, f1_macro: 0.94582
# epoch: 6, passed number of graphs: 384, train running loss: 0.00753 (passed time: 3m 27s)
#           acc: 0.99854, fpr: 0.00012, fnr: 0.06108, rec: 0.93892, prc: 0.99436, f1: 0.96585, f1_macro: 0.98255
# epoch: 6, passed number of graphs: 480, train running loss: 0.00633 (passed time: 3m 32s)
#           acc: 0.99815, fpr: 0.00109, fnr: 0.03354, rec: 0.96646, prc: 0.95499, f1: 0.96069, f1_macro: 0.97987
# epoch: 6, passed number of graphs: 576, train running loss: 0.00543 (passed time: 3m 36s)
#           acc: 0.99726, fpr: 0.00261, fnr: 0.00886, rec: 0.99114, prc: 0.89342, f1: 0.93975, f1_macro: 0.96917
# epoch: 6, passed number of graphs: 672, train running loss: 0.00526 (passed time: 3m 40s)
#           acc: 0.99498, fpr: 0.00002, fnr: 0.21095, rec: 0.78905, prc: 0.99917, f1: 0.88176, f1_macro: 0.93960
# epoch: 6, passed number of graphs: 768, train running loss: 0.00508 (passed time: 3m 45s)
#           acc: 0.99843, fpr: 0.00025, fnr: 0.05986, rec: 0.94014, prc: 0.98836, f1: 0.96365, f1_macro: 0.98142
# Validation --- epoch: 6, loss: 0.00766
#           fpr: 0.00080, prc: 0.96840, f1: 0.96587, rec: 0.96558, fnr: 0.03442, f1_macro: 0.98255, acc: 0.99849
# epoch: 7, passed number of graphs: 96, train running loss: 0.00139 (passed time: 3m 52s)
#           acc: 0.99948, fpr: 0.00008, fnr: 0.01938, rec: 0.98062, prc: 0.99656, f1: 0.98853, f1_macro: 0.99413
# epoch: 7, passed number of graphs: 192, train running loss: 0.00115 (passed time: 3m 56s)
#           acc: 0.99933, fpr: 0.00003, fnr: 0.02788, rec: 0.97212, prc: 0.99884, f1: 0.98530, f1_macro: 0.99248
# epoch: 7, passed number of graphs: 288, train running loss: 0.00317 (passed time: 4m 1s)
#           acc: 0.99654, fpr: 0.00157, fnr: 0.09025, rec: 0.90975, prc: 0.92642, f1: 0.91801, f1_macro: 0.95812
# epoch: 7, passed number of graphs: 384, train running loss: 0.00288 (passed time: 4m 5s)
#           acc: 0.99970, fpr: 0.00016, fnr: 0.00675, rec: 0.99325, prc: 0.99309, f1: 0.99317, f1_macro: 0.99651
# epoch: 7, passed number of graphs: 480, train running loss: 0.00249 (passed time: 4m 9s)
#           acc: 0.99820, fpr: 0.00129, fnr: 0.02296, rec: 0.97704, prc: 0.94796, f1: 0.96228, f1_macro: 0.98068
# epoch: 7, passed number of graphs: 576, train running loss: 0.00218 (passed time: 4m 14s)
#           acc: 0.99945, fpr: 0.00049, fnr: 0.00298, rec: 0.99702, prc: 0.97811, f1: 0.98748, f1_macro: 0.99360
# epoch: 7, passed number of graphs: 672, train running loss: 0.00195 (passed time: 4m 18s)
#           acc: 0.99870, fpr: 0.00044, fnr: 0.03676, rec: 0.96324, prc: 0.98150, f1: 0.97228, f1_macro: 0.98581
# epoch: 7, passed number of graphs: 768, train running loss: 0.00182 (passed time: 4m 22s)
#           acc: 0.99915, fpr: 0.00006, fnr: 0.03593, rec: 0.96407, prc: 0.99742, f1: 0.98046, f1_macro: 0.99001
# Validation --- epoch: 7, loss: 0.00365
#           fpr: 0.00071, prc: 0.97184, f1: 0.97724, rec: 0.98430, fnr: 0.01570, f1_macro: 0.98836, acc: 0.99900
# Better model saved at ./saved_models/GIN_6_0.977240765451289.pt.
# epoch: 8, passed number of graphs: 96, train running loss: 0.00054 (passed time: 4m 30s)
#           acc: 0.99963, fpr: 0.00004, fnr: 0.01465, rec: 0.98535, prc: 0.99848, f1: 0.99187, f1_macro: 0.99584
# epoch: 8, passed number of graphs: 192, train running loss: 0.00055 (passed time: 4m 34s)
#           acc: 0.99915, fpr: 0.00005, fnr: 0.03491, rec: 0.96509, prc: 0.99758, f1: 0.98107, f1_macro: 0.99031
# epoch: 8, passed number of graphs: 288, train running loss: 0.00061 (passed time: 4m 38s)
#           acc: 0.99857, fpr: 0.00110, fnr: 0.01645, rec: 0.98355, prc: 0.95102, f1: 0.96702, f1_macro: 0.98314
# epoch: 8, passed number of graphs: 384, train running loss: 0.00058 (passed time: 4m 43s)
#           acc: 0.99983, fpr: 0.00009, fnr: 0.00373, rec: 0.99627, prc: 0.99619, f1: 0.99623, f1_macro: 0.99807
# epoch: 8, passed number of graphs: 480, train running loss: 0.00056 (passed time: 4m 47s)
#           acc: 0.99962, fpr: 0.00027, fnr: 0.00506, rec: 0.99494, prc: 0.98889, f1: 0.99190, f1_macro: 0.99585
# epoch: 8, passed number of graphs: 576, train running loss: 0.00057 (passed time: 4m 51s)
#           acc: 0.99917, fpr: 0.00081, fnr: 0.00161, rec: 0.99839, prc: 0.96437, f1: 0.98108, f1_macro: 0.99033
# epoch: 8, passed number of graphs: 672, train running loss: 0.00055 (passed time: 4m 55s)
#           acc: 0.99871, fpr: 0.00046, fnr: 0.03538, rec: 0.96462, prc: 0.98058, f1: 0.97254, f1_macro: 0.98594
# epoch: 8, passed number of graphs: 768, train running loss: 0.00058 (passed time: 5m 0s)
#           acc: 0.99915, fpr: 0.00013, fnr: 0.03282, rec: 0.96718, prc: 0.99431, f1: 0.98056, f1_macro: 0.99006
# Validation --- epoch: 8, loss: 0.09568
#           fpr: 0.02312, prc: 0.76276, f1: 0.81801, rec: 0.98796, fnr: 0.01204, f1_macro: 0.90277, acc: 0.97719
# epoch: 9, passed number of graphs: 96, train running loss: 0.00046 (passed time: 5m 7s)
#           acc: 0.99974, fpr: 0.00004, fnr: 0.00939, rec: 0.99061, prc: 0.99818, f1: 0.99438, f1_macro: 0.99712
# epoch: 9, passed number of graphs: 192, train running loss: 0.00044 (passed time: 5m 12s)
#           acc: 0.99929, fpr: 0.00008, fnr: 0.02781, rec: 0.97219, prc: 0.99659, f1: 0.98424, f1_macro: 0.99194
# epoch: 9, passed number of graphs: 288, train running loss: 0.00052 (passed time: 5m 16s)
#           acc: 0.99963, fpr: 0.00010, fnr: 0.01293, rec: 0.98707, prc: 0.99554, f1: 0.99129, f1_macro: 0.99555
# epoch: 9, passed number of graphs: 384, train running loss: 0.00049 (passed time: 5m 20s)
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00349, rec: 0.99651, prc: 0.99651, f1: 0.99651, f1_macro: 0.99821
# epoch: 9, passed number of graphs: 480, train running loss: 0.00046 (passed time: 5m 24s)
#           acc: 0.99948, fpr: 0.00041, fnr: 0.00521, rec: 0.99479, prc: 0.98305, f1: 0.98889, f1_macro: 0.99431
# epoch: 9, passed number of graphs: 576, train running loss: 0.00046 (passed time: 5m 29s)
#           acc: 0.99965, fpr: 0.00029, fnr: 0.00314, rec: 0.99686, prc: 0.98716, f1: 0.99199, f1_macro: 0.99590
# epoch: 9, passed number of graphs: 672, train running loss: 0.00044 (passed time: 5m 33s)
#           acc: 0.99949, fpr: 0.00043, fnr: 0.00385, rec: 0.99615, prc: 0.98273, f1: 0.98939, f1_macro: 0.99457
# epoch: 9, passed number of graphs: 768, train running loss: 0.00048 (passed time: 5m 37s)
#           acc: 0.99916, fpr: 0.00009, fnr: 0.03391, rec: 0.96609, prc: 0.99606, f1: 0.98085, f1_macro: 0.99021
# Validation --- epoch: 9, loss: 2.64477
#           fpr: 0.50181, prc: 0.11080, f1: 0.15431, rec: 0.99940, fnr: 0.00060, f1_macro: 0.39412, acc: 0.50951
# epoch: 10, passed number of graphs: 96, train running loss: 0.00046 (passed time: 5m 45s)
#           acc: 0.99974, fpr: 0.00004, fnr: 0.00984, rec: 0.99016, prc: 0.99841, f1: 0.99427, f1_macro: 0.99707
# epoch: 10, passed number of graphs: 192, train running loss: 0.00041 (passed time: 5m 50s)
#           acc: 0.99955, fpr: 0.00008, fnr: 0.01587, rec: 0.98413, prc: 0.99640, f1: 0.99023, f1_macro: 0.99500
# epoch: 10, passed number of graphs: 288, train running loss: 0.00045 (passed time: 5m 54s)
#           acc: 0.99961, fpr: 0.00010, fnr: 0.01383, rec: 0.98617, prc: 0.99554, f1: 0.99083, f1_macro: 0.99532
# epoch: 10, passed number of graphs: 384, train running loss: 0.00043 (passed time: 5m 58s)
#           acc: 0.99986, fpr: 0.00008, fnr: 0.00310, rec: 0.99690, prc: 0.99659, f1: 0.99674, f1_macro: 0.99834
# epoch: 10, passed number of graphs: 480, train running loss: 0.00041 (passed time: 6m 2s)
#           acc: 0.99958, fpr: 0.00030, fnr: 0.00567, rec: 0.99433, prc: 0.98769, f1: 0.99100, f1_macro: 0.99539
# epoch: 10, passed number of graphs: 576, train running loss: 0.00040 (passed time: 6m 7s)
#           acc: 0.99967, fpr: 0.00028, fnr: 0.00250, rec: 0.99750, prc: 0.98748, f1: 0.99247, f1_macro: 0.99615
# epoch: 10, passed number of graphs: 672, train running loss: 0.00039 (passed time: 6m 11s)
#           acc: 0.99925, fpr: 0.00050, fnr: 0.01140, rec: 0.98860, prc: 0.97977, f1: 0.98416, f1_macro: 0.99189
# epoch: 10, passed number of graphs: 768, train running loss: 0.00041 (passed time: 6m 15s)
#           acc: 0.99920, fpr: 0.00006, fnr: 0.03352, rec: 0.96648, prc: 0.99735, f1: 0.98167, f1_macro: 0.99063
# Validation --- epoch: 10, loss: 0.00488
#           fpr: 0.00145, prc: 0.94652, f1: 0.96798, rec: 0.99310, fnr: 0.00690, f1_macro: 0.98359, acc: 0.99844
# epoch: 11, passed number of graphs: 96, train running loss: 0.00036 (passed time: 6m 23s)
#           acc: 0.99976, fpr: 0.00005, fnr: 0.00811, rec: 0.99189, prc: 0.99788, f1: 0.99488, f1_macro: 0.99738
# epoch: 11, passed number of graphs: 192, train running loss: 0.00033 (passed time: 6m 27s)
#           acc: 0.99956, fpr: 0.00007, fnr: 0.01624, rec: 0.98376, prc: 0.99717, f1: 0.99042, f1_macro: 0.99510
# epoch: 11, passed number of graphs: 288, train running loss: 0.00038 (passed time: 6m 31s)
#           acc: 0.99972, fpr: 0.00006, fnr: 0.01023, rec: 0.98977, prc: 0.99711, f1: 0.99343, f1_macro: 0.99664
# epoch: 11, passed number of graphs: 384, train running loss: 0.00038 (passed time: 6m 36s)
#           acc: 0.99986, fpr: 0.00005, fnr: 0.00397, rec: 0.99603, prc: 0.99761, f1: 0.99682, f1_macro: 0.99837
# epoch: 11, passed number of graphs: 480, train running loss: 0.00037 (passed time: 6m 40s)
#           acc: 0.99954, fpr: 0.00034, fnr: 0.00536, rec: 0.99464, prc: 0.98607, f1: 0.99034, f1_macro: 0.99505
# epoch: 11, passed number of graphs: 576, train running loss: 0.00037 (passed time: 6m 44s)
#           acc: 0.99968, fpr: 0.00026, fnr: 0.00306, rec: 0.99694, prc: 0.98842, f1: 0.99266, f1_macro: 0.99625
# epoch: 11, passed number of graphs: 672, train running loss: 0.00036 (passed time: 6m 48s)
#           acc: 0.99930, fpr: 0.00045, fnr: 0.01126, rec: 0.98874, prc: 0.98168, f1: 0.98520, f1_macro: 0.99242
# epoch: 11, passed number of graphs: 768, train running loss: 0.00038 (passed time: 6m 53s)
#           acc: 0.99921, fpr: 0.00005, fnr: 0.03321, rec: 0.96679, prc: 0.99767, f1: 0.98199, f1_macro: 0.99079
# Validation --- epoch: 11, loss: 0.00286
#           fpr: 0.00073, prc: 0.97241, f1: 0.98195, rec: 0.99294, fnr: 0.00706, f1_macro: 0.99075, acc: 0.99915
# Better model saved at ./saved_models/GIN_10_0.9819453740255568.pt.
# epoch: 12, passed number of graphs: 96, train running loss: 0.00035 (passed time: 7m 0s)
#           acc: 0.99977, fpr: 0.00004, fnr: 0.00826, rec: 0.99174, prc: 0.99834, f1: 0.99503, f1_macro: 0.99745
# epoch: 12, passed number of graphs: 192, train running loss: 0.00032 (passed time: 7m 5s)
#           acc: 0.99955, fpr: 0.00010, fnr: 0.01534, rec: 0.98466, prc: 0.99572, f1: 0.99016, f1_macro: 0.99497
# epoch: 12, passed number of graphs: 288, train running loss: 0.00039 (passed time: 7m 9s)
#           acc: 0.99788, fpr: 0.00186, fnr: 0.01407, rec: 0.98593, prc: 0.92033, f1: 0.95200, f1_macro: 0.97546
# epoch: 12, passed number of graphs: 384, train running loss: 0.00293 (passed time: 7m 13s)
#           acc: 0.99248, fpr: 0.00001, fnr: 0.34128, rec: 0.65872, prc: 0.99952, f1: 0.79410, f1_macro: 0.89514
# epoch: 12, passed number of graphs: 480, train running loss: 0.00319 (passed time: 7m 17s)
#           acc: 0.99787, fpr: 0.00013, fnr: 0.08544, rec: 0.91456, prc: 0.99409, f1: 0.95267, f1_macro: 0.97579
# epoch: 12, passed number of graphs: 576, train running loss: 0.00300 (passed time: 7m 22s)
#           acc: 0.99868, fpr: 0.00022, fnr: 0.05155, rec: 0.94845, prc: 0.98966, f1: 0.96862, f1_macro: 0.98397
# epoch: 12, passed number of graphs: 672, train running loss: 0.00274 (passed time: 7m 26s)
#           acc: 0.99787, fpr: 0.00038, fnr: 0.07453, rec: 0.92547, prc: 0.98356, f1: 0.95363, f1_macro: 0.97627
# epoch: 12, passed number of graphs: 768, train running loss: 0.00255 (passed time: 7m 30s)
#           acc: 0.99888, fpr: 0.00031, fnr: 0.03671, rec: 0.96329, prc: 0.98588, f1: 0.97445, f1_macro: 0.98694
# Validation --- epoch: 12, loss: 0.00287
#           fpr: 0.00011, prc: 0.99560, f1: 0.98764, rec: 0.98082, fnr: 0.01918, f1_macro: 0.99369, acc: 0.99951
# Better model saved at ./saved_models/GIN_11_0.9876361698105359.pt.
# epoch: 13, passed number of graphs: 96, train running loss: 0.00073 (passed time: 7m 38s)
#           acc: 0.99961, fpr: 0.00001, fnr: 0.01638, rec: 0.98362, prc: 0.99954, f1: 0.99152, f1_macro: 0.99566
# epoch: 13, passed number of graphs: 192, train running loss: 0.00064 (passed time: 7m 42s)
#           acc: 0.99946, fpr: 0.00005, fnr: 0.02146, rec: 0.97854, prc: 0.99784, f1: 0.98810, f1_macro: 0.99391
# epoch: 13, passed number of graphs: 288, train running loss: 0.00065 (passed time: 7m 46s)
#           acc: 0.99867, fpr: 0.00098, fnr: 0.01767, rec: 0.98233, prc: 0.95635, f1: 0.96916, f1_macro: 0.98424
# epoch: 13, passed number of graphs: 384, train running loss: 0.00060 (passed time: 7m 51s)
#           acc: 0.99985, fpr: 0.00007, fnr: 0.00349, rec: 0.99651, prc: 0.99674, f1: 0.99662, f1_macro: 0.99827
# epoch: 13, passed number of graphs: 480, train running loss: 0.00057 (passed time: 7m 55s)
#           acc: 0.99942, fpr: 0.00002, fnr: 0.02364, rec: 0.97636, prc: 0.99907, f1: 0.98758, f1_macro: 0.99364
# epoch: 13, passed number of graphs: 576, train running loss: 0.00055 (passed time: 7m 59s)
#           acc: 0.99968, fpr: 0.00026, fnr: 0.00306, rec: 0.99694, prc: 0.98842, f1: 0.99266, f1_macro: 0.99625
# epoch: 13, passed number of graphs: 672, train running loss: 0.00053 (passed time: 8m 4s)
#           acc: 0.99911, fpr: 0.00046, fnr: 0.01860, rec: 0.98140, prc: 0.98112, f1: 0.98126, f1_macro: 0.99040
# epoch: 13, passed number of graphs: 768, train running loss: 0.00056 (passed time: 8m 8s)
#           acc: 0.99912, fpr: 0.00012, fnr: 0.03422, rec: 0.96578, prc: 0.99454, f1: 0.97995, f1_macro: 0.98975
# Validation --- epoch: 13, loss: 0.00176
#           fpr: 0.00008, prc: 0.99673, f1: 0.98981, rec: 0.98370, fnr: 0.01630, f1_macro: 0.99480, acc: 0.99960
# Better model saved at ./saved_models/GIN_12_0.9898103460192793.pt.
# epoch: 14, passed number of graphs: 96, train running loss: 0.00046 (passed time: 8m 15s)
#           acc: 0.99966, fpr: 0.00003, fnr: 0.01330, rec: 0.98670, prc: 0.99871, f1: 0.99267, f1_macro: 0.99625
# epoch: 14, passed number of graphs: 192, train running loss: 0.00044 (passed time: 8m 20s)
#           acc: 0.99955, fpr: 0.00008, fnr: 0.01640, rec: 0.98360, prc: 0.99656, f1: 0.99004, f1_macro: 0.99490
# epoch: 14, passed number of graphs: 288, train running loss: 0.00048 (passed time: 8m 24s)
#           acc: 0.99962, fpr: 0.00007, fnr: 0.01448, rec: 0.98552, prc: 0.99652, f1: 0.99099, f1_macro: 0.99540
# epoch: 14, passed number of graphs: 384, train running loss: 0.00045 (passed time: 8m 28s)
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00318, rec: 0.99682, prc: 0.99635, f1: 0.99659, f1_macro: 0.99825
# epoch: 14, passed number of graphs: 480, train running loss: 0.00043 (passed time: 8m 33s)
#           acc: 0.99941, fpr: 0.00001, fnr: 0.02478, rec: 0.97522, prc: 0.99969, f1: 0.98730, f1_macro: 0.99350
# epoch: 14, passed number of graphs: 576, train running loss: 0.00043 (passed time: 8m 37s)
#           acc: 0.99968, fpr: 0.00025, fnr: 0.00338, rec: 0.99662, prc: 0.98881, f1: 0.99270, f1_macro: 0.99627
# epoch: 14, passed number of graphs: 672, train running loss: 0.00042 (passed time: 8m 41s)
#           acc: 0.99911, fpr: 0.00050, fnr: 0.01693, rec: 0.98307, prc: 0.97966, f1: 0.98136, f1_macro: 0.99045
# epoch: 14, passed number of graphs: 768, train running loss: 0.00044 (passed time: 8m 45s)
#           acc: 0.99920, fpr: 0.00007, fnr: 0.03336, rec: 0.96664, prc: 0.99703, f1: 0.98160, f1_macro: 0.99059
# Validation --- epoch: 14, loss: 0.00238
#           fpr: 0.00053, prc: 0.98025, f1: 0.98267, rec: 0.98650, fnr: 0.01350, f1_macro: 0.99113, acc: 0.99922
# epoch: 15, passed number of graphs: 96, train running loss: 0.00042 (passed time: 8m 53s)
#           acc: 0.99966, fpr: 0.00004, fnr: 0.01322, rec: 0.98678, prc: 0.99825, f1: 0.99248, f1_macro: 0.99615
# epoch: 15, passed number of graphs: 192, train running loss: 0.00042 (passed time: 8m 57s)
#           acc: 0.99955, fpr: 0.00008, fnr: 0.01624, rec: 0.98376, prc: 0.99671, f1: 0.99019, f1_macro: 0.99498
# epoch: 15, passed number of graphs: 288, train running loss: 0.00045 (passed time: 9m 2s)
#           acc: 0.99972, fpr: 0.00006, fnr: 0.01039, rec: 0.98961, prc: 0.99728, f1: 0.99343, f1_macro: 0.99664
# epoch: 15, passed number of graphs: 384, train running loss: 0.00042 (passed time: 9m 6s)
#           acc: 0.99985, fpr: 0.00007, fnr: 0.00342, rec: 0.99658, prc: 0.99674, f1: 0.99666, f1_macro: 0.99829
# epoch: 15, passed number of graphs: 480, train running loss: 0.00041 (passed time: 9m 10s)
#           acc: 0.99941, fpr: 0.00001, fnr: 0.02470, rec: 0.97530, prc: 0.99961, f1: 0.98731, f1_macro: 0.99350
# epoch: 15, passed number of graphs: 576, train running loss: 0.00040 (passed time: 9m 14s)
#           acc: 0.99967, fpr: 0.00028, fnr: 0.00290, rec: 0.99710, prc: 0.98756, f1: 0.99231, f1_macro: 0.99607
# epoch: 15, passed number of graphs: 672, train running loss: 0.00039 (passed time: 9m 19s)
#           acc: 0.99943, fpr: 0.00044, fnr: 0.00581, rec: 0.99419, prc: 0.98199, f1: 0.98805, f1_macro: 0.99388
# epoch: 15, passed number of graphs: 768, train running loss: 0.00041 (passed time: 9m 23s)
#           acc: 0.99918, fpr: 0.00007, fnr: 0.03383, rec: 0.96617, prc: 0.99686, f1: 0.98128, f1_macro: 0.99043
# Validation --- epoch: 15, loss: 0.00211
#           fpr: 0.00010, prc: 0.99592, f1: 0.99084, rec: 0.98640, fnr: 0.01360, f1_macro: 0.99533, acc: 0.99964
# Better model saved at ./saved_models/GIN_14_0.9908437751329155.pt.
# epoch: 16, passed number of graphs: 96, train running loss: 0.00038 (passed time: 9m 31s)
#           acc: 0.99976, fpr: 0.00006, fnr: 0.00781, rec: 0.99219, prc: 0.99743, f1: 0.99480, f1_macro: 0.99734
# epoch: 16, passed number of graphs: 192, train running loss: 0.00034 (passed time: 9m 35s)
#           acc: 0.99957, fpr: 0.00008, fnr: 0.01526, rec: 0.98474, prc: 0.99656, f1: 0.99061, f1_macro: 0.99520
# epoch: 16, passed number of graphs: 288, train running loss: 0.00039 (passed time: 9m 39s)
#           acc: 0.99973, fpr: 0.00004, fnr: 0.01047, rec: 0.98953, prc: 0.99794, f1: 0.99371, f1_macro: 0.99679
# epoch: 16, passed number of graphs: 384, train running loss: 0.00037 (passed time: 9m 43s)
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00334, rec: 0.99666, prc: 0.99643, f1: 0.99655, f1_macro: 0.99823
# epoch: 16, passed number of graphs: 480, train running loss: 0.00036 (passed time: 9m 48s)
#           acc: 0.99954, fpr: 0.00013, fnr: 0.01413, rec: 0.98587, prc: 0.99459, f1: 0.99021, f1_macro: 0.99499
# epoch: 16, passed number of graphs: 576, train running loss: 0.00036 (passed time: 9m 52s)
#           acc: 0.99967, fpr: 0.00028, fnr: 0.00274, rec: 0.99726, prc: 0.98748, f1: 0.99235, f1_macro: 0.99609
# epoch: 16, passed number of graphs: 672, train running loss: 0.00035 (passed time: 9m 56s)
#           acc: 0.99945, fpr: 0.00045, fnr: 0.00458, rec: 0.99542, prc: 0.98173, f1: 0.98853, f1_macro: 0.99412
# epoch: 16, passed number of graphs: 768, train running loss: 0.00037 (passed time: 10m 0s)
#           acc: 0.99921, fpr: 0.00005, fnr: 0.03352, rec: 0.96648, prc: 0.99767, f1: 0.98183, f1_macro: 0.99071
# Validation --- epoch: 16, loss: 0.00157
#           fpr: 0.00008, prc: 0.99673, f1: 0.99165, rec: 0.98717, fnr: 0.01283, f1_macro: 0.99574, acc: 0.99967
# Better model saved at ./saved_models/GIN_15_0.991647642366987.pt.
# epoch: 17, passed number of graphs: 96, train running loss: 0.00034 (passed time: 10m 8s)
#           acc: 0.99975, fpr: 0.00005, fnr: 0.00849, rec: 0.99151, prc: 0.99781, f1: 0.99465, f1_macro: 0.99726
# epoch: 17, passed number of graphs: 192, train running loss: 0.00031 (passed time: 10m 12s)
#           acc: 0.99958, fpr: 0.00007, fnr: 0.01534, rec: 0.98466, prc: 0.99686, f1: 0.99073, f1_macro: 0.99525
# epoch: 17, passed number of graphs: 288, train running loss: 0.00036 (passed time: 10m 17s)
#           acc: 0.99974, fpr: 0.00004, fnr: 0.01006, rec: 0.98994, prc: 0.99802, f1: 0.99396, f1_macro: 0.99692
# epoch: 17, passed number of graphs: 384, train running loss: 0.00035 (passed time: 10m 21s)
#           acc: 0.99985, fpr: 0.00009, fnr: 0.00294, rec: 0.99706, prc: 0.99603, f1: 0.99655, f1_macro: 0.99823
# epoch: 17, passed number of graphs: 480, train running loss: 0.00034 (passed time: 10m 25s)
#           acc: 0.99950, fpr: 0.00005, fnr: 0.01941, rec: 0.98059, prc: 0.99785, f1: 0.98914, f1_macro: 0.99444
# epoch: 17, passed number of graphs: 576, train running loss: 0.00034 (passed time: 10m 30s)
#           acc: 0.99967, fpr: 0.00027, fnr: 0.00274, rec: 0.99726, prc: 0.98772, f1: 0.99247, f1_macro: 0.99615
# epoch: 17, passed number of graphs: 672, train running loss: 0.00034 (passed time: 10m 34s)
#           acc: 0.99944, fpr: 0.00048, fnr: 0.00400, rec: 0.99600, prc: 0.98062, f1: 0.98825, f1_macro: 0.99398
# epoch: 17, passed number of graphs: 768, train running loss: 0.00036 (passed time: 10m 38s)
#           acc: 0.99921, fpr: 0.00005, fnr: 0.03336, rec: 0.96664, prc: 0.99767, f1: 0.98191, f1_macro: 0.99075
# Validation --- epoch: 17, loss: 0.00160
#           fpr: 0.00010, prc: 0.99568, f1: 0.99148, rec: 0.98788, fnr: 0.01212, f1_macro: 0.99565, acc: 0.99966
# epoch: 18, passed number of graphs: 96, train running loss: 0.00034 (passed time: 10m 46s)
#           acc: 0.99975, fpr: 0.00005, fnr: 0.00864, rec: 0.99136, prc: 0.99773, f1: 0.99454, f1_macro: 0.99720
# epoch: 18, passed number of graphs: 192, train running loss: 0.00031 (passed time: 10m 50s)
#           acc: 0.99958, fpr: 0.00007, fnr: 0.01541, rec: 0.98459, prc: 0.99702, f1: 0.99076, f1_macro: 0.99527
# epoch: 18, passed number of graphs: 288, train running loss: 0.00036 (passed time: 10m 54s)
#           acc: 0.99974, fpr: 0.00005, fnr: 0.00990, rec: 0.99010, prc: 0.99777, f1: 0.99392, f1_macro: 0.99689
# epoch: 18, passed number of graphs: 384, train running loss: 0.00035 (passed time: 10m 59s)
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00302, rec: 0.99698, prc: 0.99627, f1: 0.99663, f1_macro: 0.99827
# epoch: 18, passed number of graphs: 480, train running loss: 0.00034 (passed time: 11m 3s)
#           acc: 0.99951, fpr: 0.00005, fnr: 0.01866, rec: 0.98134, prc: 0.99793, f1: 0.98956, f1_macro: 0.99466
# epoch: 18, passed number of graphs: 576, train running loss: 0.00034 (passed time: 11m 7s)
#           acc: 0.99967, fpr: 0.00028, fnr: 0.00250, rec: 0.99750, prc: 0.98740, f1: 0.99243, f1_macro: 0.99613
# epoch: 18, passed number of graphs: 672, train running loss: 0.00034 (passed time: 11m 11s)
#           acc: 0.99945, fpr: 0.00048, fnr: 0.00363, rec: 0.99637, prc: 0.98055, f1: 0.98840, f1_macro: 0.99406
# epoch: 18, passed number of graphs: 768, train running loss: 0.00036 (passed time: 11m 16s)
#           acc: 0.99920, fpr: 0.00006, fnr: 0.03336, rec: 0.96664, prc: 0.99735, f1: 0.98175, f1_macro: 0.99067
# Validation --- epoch: 18, loss: 0.00159
#           fpr: 0.00012, prc: 0.99508, f1: 0.99139, rec: 0.98830, fnr: 0.01170, f1_macro: 0.99561, acc: 0.99965
# epoch: 19, passed number of graphs: 96, train running loss: 0.00033 (passed time: 11m 23s)
#           acc: 0.99976, fpr: 0.00006, fnr: 0.00789, rec: 0.99211, prc: 0.99751, f1: 0.99480, f1_macro: 0.99734
# epoch: 19, passed number of graphs: 192, train running loss: 0.00030 (passed time: 11m 28s)
#           acc: 0.99957, fpr: 0.00009, fnr: 0.01511, rec: 0.98489, prc: 0.99618, f1: 0.99050, f1_macro: 0.99514
# epoch: 19, passed number of graphs: 288, train running loss: 0.00035 (passed time: 11m 32s)
#           acc: 0.99974, fpr: 0.00005, fnr: 0.01006, rec: 0.98994, prc: 0.99777, f1: 0.99384, f1_macro: 0.99685
# epoch: 19, passed number of graphs: 384, train running loss: 0.00034 (passed time: 11m 36s)
#           acc: 0.99984, fpr: 0.00008, fnr: 0.00349, rec: 0.99651, prc: 0.99643, f1: 0.99647, f1_macro: 0.99819
# epoch: 19, passed number of graphs: 480, train running loss: 0.00033 (passed time: 11m 40s)
#           acc: 0.99961, fpr: 0.00018, fnr: 0.00884, rec: 0.99116, prc: 0.99236, f1: 0.99176, f1_macro: 0.99578
# epoch: 19, passed number of graphs: 576, train running loss: 0.00033 (passed time: 11m 45s)
#           acc: 0.99969, fpr: 0.00026, fnr: 0.00274, rec: 0.99726, prc: 0.98843, f1: 0.99282, f1_macro: 0.99633
# epoch: 19, passed number of graphs: 672, train running loss: 0.00033 (passed time: 11m 49s)
#           acc: 0.99947, fpr: 0.00044, fnr: 0.00392, rec: 0.99608, prc: 0.98195, f1: 0.98897, f1_macro: 0.99435
# epoch: 19, passed number of graphs: 768, train running loss: 0.00035 (passed time: 11m 53s)
#           acc: 0.99921, fpr: 0.00005, fnr: 0.03344, rec: 0.96656, prc: 0.99767, f1: 0.98187, f1_macro: 0.99073
# Validation --- epoch: 19, loss: 0.00153
#           fpr: 0.00008, prc: 0.99670, f1: 0.99188, rec: 0.98767, fnr: 0.01233, f1_macro: 0.99586, acc: 0.99968
# Better model saved at ./saved_models/GIN_18_0.9918849560196161.pt.
# epoch: 20, passed number of graphs: 96, train running loss: 0.00032 (passed time: 12m 1s)
#           acc: 0.99976, fpr: 0.00005, fnr: 0.00796, rec: 0.99204, prc: 0.99766, f1: 0.99484, f1_macro: 0.99736
# epoch: 20, passed number of graphs: 192, train running loss: 0.00030 (passed time: 12m 5s)
#           acc: 0.99957, fpr: 0.00009, fnr: 0.01496, rec: 0.98504, prc: 0.99610, f1: 0.99054, f1_macro: 0.99516
# epoch: 20, passed number of graphs: 288, train running loss: 0.00034 (passed time: 12m 9s)
#           acc: 0.99974, fpr: 0.00005, fnr: 0.01006, rec: 0.98994, prc: 0.99777, f1: 0.99384, f1_macro: 0.99685
# epoch: 20, passed number of graphs: 384, train running loss: 0.00033 (passed time: 12m 14s)
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00318, rec: 0.99682, prc: 0.99627, f1: 0.99655, f1_macro: 0.99823
# epoch: 20, passed number of graphs: 480, train running loss: 0.00033 (passed time: 12m 18s)
#           acc: 0.99954, fpr: 0.00009, fnr: 0.01586, rec: 0.98414, prc: 0.99633, f1: 0.99020, f1_macro: 0.99498
# epoch: 20, passed number of graphs: 576, train running loss: 0.00033 (passed time: 12m 22s)
#           acc: 0.99969, fpr: 0.00026, fnr: 0.00258, rec: 0.99742, prc: 0.98843, f1: 0.99290, f1_macro: 0.99637
# epoch: 20, passed number of graphs: 672, train running loss: 0.00033 (passed time: 12m 26s)
#           acc: 0.99947, fpr: 0.00045, fnr: 0.00385, rec: 0.99615, prc: 0.98181, f1: 0.98893, f1_macro: 0.99433
# epoch: 20, passed number of graphs: 768, train running loss: 0.00034 (passed time: 12m 31s)
#           acc: 0.99921, fpr: 0.00005, fnr: 0.03336, rec: 0.96664, prc: 0.99767, f1: 0.98191, f1_macro: 0.99075
# Validation --- epoch: 20, loss: 0.00152
#           fpr: 0.00008, prc: 0.99664, f1: 0.99190, rec: 0.98776, fnr: 0.01224, f1_macro: 0.99587, acc: 0.99968
# Better model saved at ./saved_models/GIN_19_0.9919013818614729.pt.
# epoch: 21, passed number of graphs: 96, train running loss: 0.00032 (passed time: 12m 38s)
#           acc: 0.99976, fpr: 0.00006, fnr: 0.00796, rec: 0.99204, prc: 0.99758, f1: 0.99480, f1_macro: 0.99734
# epoch: 21, passed number of graphs: 192, train running loss: 0.00030 (passed time: 12m 43s)
#           acc: 0.99957, fpr: 0.00009, fnr: 0.01496, rec: 0.98504, prc: 0.99610, f1: 0.99054, f1_macro: 0.99516
# epoch: 21, passed number of graphs: 288, train running loss: 0.00034 (passed time: 12m 47s)
#           acc: 0.99974, fpr: 0.00005, fnr: 0.00998, rec: 0.99002, prc: 0.99777, f1: 0.99388, f1_macro: 0.99687
# epoch: 21, passed number of graphs: 384, train running loss: 0.00033 (passed time: 12m 51s)
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00326, rec: 0.99674, prc: 0.99635, f1: 0.99655, f1_macro: 0.99823
# epoch: 21, passed number of graphs: 480, train running loss: 0.00033 (passed time: 12m 55s)
#           acc: 0.99965, fpr: 0.00020, fnr: 0.00627, rec: 0.99373, prc: 0.99156, f1: 0.99264, f1_macro: 0.99623
# epoch: 21, passed number of graphs: 576, train running loss: 0.00033 (passed time: 13m 0s)
#           acc: 0.99969, fpr: 0.00026, fnr: 0.00266, rec: 0.99734, prc: 0.98827, f1: 0.99278, f1_macro: 0.99631
# epoch: 21, passed number of graphs: 672, train running loss: 0.00033 (passed time: 13m 4s)
#           acc: 0.99947, fpr: 0.00045, fnr: 0.00370, rec: 0.99630, prc: 0.98175, f1: 0.98897, f1_macro: 0.99435
# epoch: 21, passed number of graphs: 768, train running loss: 0.00034 (passed time: 13m 8s)
#           acc: 0.99921, fpr: 0.00005, fnr: 0.03336, rec: 0.96664, prc: 0.99767, f1: 0.98191, f1_macro: 0.99075
# Validation --- epoch: 21, loss: 0.00152
#           fpr: 0.00008, prc: 0.99658, f1: 0.99189, rec: 0.98780, fnr: 0.01220, f1_macro: 0.99587, acc: 0.99968
# epoch: 22, passed number of graphs: 96, train running loss: 0.00032 (passed time: 13m 16s)
#           acc: 0.99976, fpr: 0.00005, fnr: 0.00796, rec: 0.99204, prc: 0.99766, f1: 0.99484, f1_macro: 0.99736
# epoch: 22, passed number of graphs: 192, train running loss: 0.00030 (passed time: 13m 20s)
#           acc: 0.99957, fpr: 0.00009, fnr: 0.01504, rec: 0.98496, prc: 0.99633, f1: 0.99062, f1_macro: 0.99520
# epoch: 22, passed number of graphs: 288, train running loss: 0.00034 (passed time: 13m 24s)
#           acc: 0.99974, fpr: 0.00005, fnr: 0.01006, rec: 0.98994, prc: 0.99777, f1: 0.99384, f1_macro: 0.99685
# epoch: 22, passed number of graphs: 384, train running loss: 0.00033 (passed time: 13m 29s)
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00318, rec: 0.99682, prc: 0.99627, f1: 0.99655, f1_macro: 0.99823
# epoch: 22, passed number of graphs: 480, train running loss: 0.00033 (passed time: 13m 33s)
#           acc: 0.99965, fpr: 0.00023, fnr: 0.00567, rec: 0.99433, prc: 0.99059, f1: 0.99246, f1_macro: 0.99614
# epoch: 22, passed number of graphs: 576, train running loss: 0.00033 (passed time: 13m 37s)
#           acc: 0.99969, fpr: 0.00026, fnr: 0.00266, rec: 0.99734, prc: 0.98827, f1: 0.99278, f1_macro: 0.99631
# epoch: 22, passed number of graphs: 672, train running loss: 0.00032 (passed time: 13m 41s)
#           acc: 0.99947, fpr: 0.00045, fnr: 0.00363, rec: 0.99637, prc: 0.98175, f1: 0.98900, f1_macro: 0.99437
# epoch: 22, passed number of graphs: 768, train running loss: 0.00034 (passed time: 13m 46s)
#           acc: 0.99921, fpr: 0.00005, fnr: 0.03321, rec: 0.96679, prc: 0.99767, f1: 0.98199, f1_macro: 0.99079
# Validation --- epoch: 22, loss: 0.00153
#           fpr: 0.00008, prc: 0.99653, f1: 0.99192, rec: 0.98790, fnr: 0.01210, f1_macro: 0.99588, acc: 0.99968
# Better model saved at ./saved_models/GIN_21_0.9919220122330682.pt.
# epoch: 23, passed number of graphs: 96, train running loss: 0.00032 (passed time: 13m 53s)
#           acc: 0.99976, fpr: 0.00006, fnr: 0.00781, rec: 0.99219, prc: 0.99751, f1: 0.99484, f1_macro: 0.99736
# epoch: 23, passed number of graphs: 192, train running loss: 0.00030 (passed time: 13m 58s)
#           acc: 0.99957, fpr: 0.00007, fnr: 0.01541, rec: 0.98459, prc: 0.99679, f1: 0.99065, f1_macro: 0.99522
# epoch: 23, passed number of graphs: 288, train running loss: 0.00034 (passed time: 14m 2s)
#           acc: 0.99974, fpr: 0.00005, fnr: 0.00974, rec: 0.99026, prc: 0.99761, f1: 0.99392, f1_macro: 0.99690
# epoch: 23, passed number of graphs: 384, train running loss: 0.00033 (passed time: 14m 6s)
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00349, rec: 0.99651, prc: 0.99651, f1: 0.99651, f1_macro: 0.99821
# epoch: 23, passed number of graphs: 480, train running loss: 0.00032 (passed time: 14m 11s)
#           acc: 0.99962, fpr: 0.00026, fnr: 0.00529, rec: 0.99471, prc: 0.98918, f1: 0.99194, f1_macro: 0.99587
# epoch: 23, passed number of graphs: 576, train running loss: 0.00033 (passed time: 14m 15s)
#           acc: 0.99970, fpr: 0.00024, fnr: 0.00306, rec: 0.99694, prc: 0.98913, f1: 0.99302, f1_macro: 0.99643
# epoch: 23, passed number of graphs: 672, train running loss: 0.00032 (passed time: 14m 19s)
#           acc: 0.99948, fpr: 0.00044, fnr: 0.00370, rec: 0.99630, prc: 0.98196, f1: 0.98907, f1_macro: 0.99440
# epoch: 23, passed number of graphs: 768, train running loss: 0.00034 (passed time: 14m 23s)
#           acc: 0.99921, fpr: 0.00005, fnr: 0.03336, rec: 0.96664, prc: 0.99775, f1: 0.98195, f1_macro: 0.99077
# Validation --- epoch: 23, loss: 0.00151
#           fpr: 0.00008, prc: 0.99663, f1: 0.99198, rec: 0.98791, fnr: 0.01209, f1_macro: 0.99591, acc: 0.99968
# Better model saved at ./saved_models/GIN_22_0.9919796693662656.pt.
# epoch: 24, passed number of graphs: 96, train running loss: 0.00032 (passed time: 14m 31s)
#           acc: 0.99976, fpr: 0.00006, fnr: 0.00781, rec: 0.99219, prc: 0.99751, f1: 0.99484, f1_macro: 0.99736
# epoch: 24, passed number of graphs: 192, train running loss: 0.00030 (passed time: 14m 35s)
#           acc: 0.99958, fpr: 0.00008, fnr: 0.01526, rec: 0.98474, prc: 0.99671, f1: 0.99069, f1_macro: 0.99524
# epoch: 24, passed number of graphs: 288, train running loss: 0.00034 (passed time: 14m 40s)
#           acc: 0.99974, fpr: 0.00005, fnr: 0.00974, rec: 0.99026, prc: 0.99761, f1: 0.99392, f1_macro: 0.99690
# epoch: 24, passed number of graphs: 384, train running loss: 0.00033 (passed time: 14m 44s)
#           acc: 0.99984, fpr: 0.00008, fnr: 0.00349, rec: 0.99651, prc: 0.99643, f1: 0.99647, f1_macro: 0.99819
# epoch: 24, passed number of graphs: 480, train running loss: 0.00032 (passed time: 14m 48s)
#           acc: 0.99962, fpr: 0.00026, fnr: 0.00529, rec: 0.99471, prc: 0.98911, f1: 0.99190, f1_macro: 0.99585
# epoch: 24, passed number of graphs: 576, train running loss: 0.00033 (passed time: 14m 52s)
#           acc: 0.99970, fpr: 0.00024, fnr: 0.00298, rec: 0.99702, prc: 0.98905, f1: 0.99302, f1_macro: 0.99643
# epoch: 24, passed number of graphs: 672, train running loss: 0.00032 (passed time: 14m 57s)
#           acc: 0.99948, fpr: 0.00044, fnr: 0.00363, rec: 0.99637, prc: 0.98203, f1: 0.98915, f1_macro: 0.99444
# epoch: 24, passed number of graphs: 768, train running loss: 0.00034 (passed time: 15m 1s)
#           acc: 0.99921, fpr: 0.00005, fnr: 0.03336, rec: 0.96664, prc: 0.99775, f1: 0.98195, f1_macro: 0.99077
# Validation --- epoch: 24, loss: 0.00151
#           fpr: 0.00008, prc: 0.99664, f1: 0.99198, rec: 0.98791, fnr: 0.01209, f1_macro: 0.99591, acc: 0.99968
# Better model saved at ./saved_models/GIN_23_0.9919833378689885.pt.
# epoch: 25, passed number of graphs: 96, train running loss: 0.00032 (passed time: 15m 9s)
#           acc: 0.99976, fpr: 0.00006, fnr: 0.00781, rec: 0.99219, prc: 0.99751, f1: 0.99484, f1_macro: 0.99736
# epoch: 25, passed number of graphs: 192, train running loss: 0.00029 (passed time: 15m 13s)
#           acc: 0.99958, fpr: 0.00008, fnr: 0.01526, rec: 0.98474, prc: 0.99671, f1: 0.99069, f1_macro: 0.99524
# epoch: 25, passed number of graphs: 288, train running loss: 0.00034 (passed time: 15m 17s)
# ...
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00318, rec: 0.99682, prc: 0.99643, f1: 0.99663, f1_macro: 0.99827
# epoch: 42, passed number of graphs: 480, train running loss: 0.00032 (passed time: 26m 4s)
#           acc: 0.99960, fpr: 0.00030, fnr: 0.00468, rec: 0.99532, prc: 0.98771, f1: 0.99150, f1_macro: 0.99565
# epoch: 42, passed number of graphs: 576, train running loss: 0.00032 (passed time: 26m 8s)
#           acc: 0.99970, fpr: 0.00023, fnr: 0.00322, rec: 0.99678, prc: 0.98953, f1: 0.99314, f1_macro: 0.99649
# epoch: 42, passed number of graphs: 672, train running loss: 0.00032 (passed time: 26m 13s)
#           acc: 0.99948, fpr: 0.00044, fnr: 0.00363, rec: 0.99637, prc: 0.98210, f1: 0.98918, f1_macro: 0.99446
# epoch: 42, passed number of graphs: 768, train running loss: 0.00033 (passed time: 26m 17s)
#           acc: 0.99922, fpr: 0.00005, fnr: 0.03313, rec: 0.96687, prc: 0.99775, f1: 0.98207, f1_macro: 0.99083
# Validation --- epoch: 42, loss: 0.00150
#           fpr: 0.00008, prc: 0.99655, f1: 0.99207, rec: 0.98815, fnr: 0.01185, f1_macro: 0.99595, acc: 0.99969
# epoch: 43, passed number of graphs: 96, train running loss: 0.00031 (passed time: 26m 24s)
#           acc: 0.99976, fpr: 0.00006, fnr: 0.00774, rec: 0.99226, prc: 0.99751, f1: 0.99488, f1_macro: 0.99738
# epoch: 43, passed number of graphs: 192, train running loss: 0.00029 (passed time: 26m 29s)
#           acc: 0.99957, fpr: 0.00008, fnr: 0.01534, rec: 0.98466, prc: 0.99671, f1: 0.99065, f1_macro: 0.99522
# epoch: 43, passed number of graphs: 288, train running loss: 0.00033 (passed time: 26m 33s)
#           acc: 0.99974, fpr: 0.00005, fnr: 0.00966, rec: 0.99034, prc: 0.99761, f1: 0.99396, f1_macro: 0.99692
# epoch: 43, passed number of graphs: 384, train running loss: 0.00032 (passed time: 26m 37s)
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00318, rec: 0.99682, prc: 0.99643, f1: 0.99663, f1_macro: 0.99827
# epoch: 43, passed number of graphs: 480, train running loss: 0.00032 (passed time: 26m 42s)
#           acc: 0.99960, fpr: 0.00030, fnr: 0.00468, rec: 0.99532, prc: 0.98756, f1: 0.99142, f1_macro: 0.99561
# epoch: 43, passed number of graphs: 576, train running loss: 0.00032 (passed time: 26m 46s)
#           acc: 0.99970, fpr: 0.00023, fnr: 0.00314, rec: 0.99686, prc: 0.98953, f1: 0.99318, f1_macro: 0.99651
# epoch: 43, passed number of graphs: 672, train running loss: 0.00032 (passed time: 26m 50s)
#           acc: 0.99948, fpr: 0.00044, fnr: 0.00363, rec: 0.99637, prc: 0.98210, f1: 0.98918, f1_macro: 0.99446
# epoch: 43, passed number of graphs: 768, train running loss: 0.00033 (passed time: 26m 54s)
#           acc: 0.99922, fpr: 0.00005, fnr: 0.03313, rec: 0.96687, prc: 0.99775, f1: 0.98207, f1_macro: 0.99083
# Validation --- epoch: 43, loss: 0.00149
#           fpr: 0.00008, prc: 0.99655, f1: 0.99208, rec: 0.98817, fnr: 0.01183, f1_macro: 0.99596, acc: 0.99969
# Better model saved at ./saved_models/GIN_42_0.9920751829651352.pt.
# epoch: 44, passed number of graphs: 96, train running loss: 0.00031 (passed time: 27m 2s)
#           acc: 0.99976, fpr: 0.00006, fnr: 0.00774, rec: 0.99226, prc: 0.99751, f1: 0.99488, f1_macro: 0.99738
# epoch: 44, passed number of graphs: 192, train running loss: 0.00029 (passed time: 27m 6s)
#           acc: 0.99958, fpr: 0.00007, fnr: 0.01534, rec: 0.98466, prc: 0.99679, f1: 0.99069, f1_macro: 0.99524
# epoch: 44, passed number of graphs: 288, train running loss: 0.00033 (passed time: 27m 11s)
#           acc: 0.99974, fpr: 0.00005, fnr: 0.00966, rec: 0.99034, prc: 0.99761, f1: 0.99396, f1_macro: 0.99692
# epoch: 44, passed number of graphs: 384, train running loss: 0.00032 (passed time: 27m 15s)
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00318, rec: 0.99682, prc: 0.99643, f1: 0.99663, f1_macro: 0.99827
# epoch: 44, passed number of graphs: 480, train running loss: 0.00032 (passed time: 27m 19s)
#           acc: 0.99960, fpr: 0.00030, fnr: 0.00468, rec: 0.99532, prc: 0.98756, f1: 0.99142, f1_macro: 0.99561
# epoch: 44, passed number of graphs: 576, train running loss: 0.00032 (passed time: 27m 23s)
#           acc: 0.99970, fpr: 0.00023, fnr: 0.00314, rec: 0.99686, prc: 0.98945, f1: 0.99314, f1_macro: 0.99649
# epoch: 44, passed number of graphs: 672, train running loss: 0.00032 (passed time: 27m 28s)
#           acc: 0.99948, fpr: 0.00044, fnr: 0.00356, rec: 0.99644, prc: 0.98210, f1: 0.98922, f1_macro: 0.99448
# epoch: 44, passed number of graphs: 768, train running loss: 0.00033 (passed time: 27m 32s)
#           acc: 0.99922, fpr: 0.00005, fnr: 0.03313, rec: 0.96687, prc: 0.99783, f1: 0.98211, f1_macro: 0.99085
# Validation --- epoch: 44, loss: 0.00149
#           fpr: 0.00008, prc: 0.99654, f1: 0.99207, rec: 0.98818, fnr: 0.01182, f1_macro: 0.99596, acc: 0.99969
# epoch: 45, passed number of graphs: 96, train running loss: 0.00031 (passed time: 27m 40s)
#           acc: 0.99976, fpr: 0.00006, fnr: 0.00774, rec: 0.99226, prc: 0.99751, f1: 0.99488, f1_macro: 0.99738
# epoch: 45, passed number of graphs: 192, train running loss: 0.00029 (passed time: 27m 44s)
#           acc: 0.99957, fpr: 0.00008, fnr: 0.01534, rec: 0.98466, prc: 0.99671, f1: 0.99065, f1_macro: 0.99522
# epoch: 45, passed number of graphs: 288, train running loss: 0.00033 (passed time: 27m 48s)
#           acc: 0.99974, fpr: 0.00005, fnr: 0.00966, rec: 0.99034, prc: 0.99761, f1: 0.99396, f1_macro: 0.99692
# epoch: 45, passed number of graphs: 384, train running loss: 0.00032 (passed time: 27m 52s)
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00318, rec: 0.99682, prc: 0.99643, f1: 0.99663, f1_macro: 0.99827
# epoch: 45, passed number of graphs: 480, train running loss: 0.00032 (passed time: 27m 57s)
#           acc: 0.99960, fpr: 0.00030, fnr: 0.00461, rec: 0.99539, prc: 0.98756, f1: 0.99146, f1_macro: 0.99563
# epoch: 45, passed number of graphs: 576, train running loss: 0.00032 (passed time: 28m 1s)
#           acc: 0.99970, fpr: 0.00023, fnr: 0.00314, rec: 0.99686, prc: 0.98945, f1: 0.99314, f1_macro: 0.99649
# epoch: 45, passed number of graphs: 672, train running loss: 0.00032 (passed time: 28m 5s)
#           acc: 0.99949, fpr: 0.00044, fnr: 0.00356, rec: 0.99644, prc: 0.98224, f1: 0.98929, f1_macro: 0.99451
# epoch: 45, passed number of graphs: 768, train running loss: 0.00033 (passed time: 28m 10s)
#           acc: 0.99922, fpr: 0.00005, fnr: 0.03313, rec: 0.96687, prc: 0.99783, f1: 0.98211, f1_macro: 0.99085
# Validation --- epoch: 45, loss: 0.00149
#           fpr: 0.00008, prc: 0.99654, f1: 0.99208, rec: 0.98818, fnr: 0.01182, f1_macro: 0.99596, acc: 0.99969
# Better model saved at ./saved_models/GIN_44_0.9920760755796972.pt.
# epoch: 46, passed number of graphs: 96, train running loss: 0.00031 (passed time: 28m 17s)
#           acc: 0.99976, fpr: 0.00006, fnr: 0.00774, rec: 0.99226, prc: 0.99751, f1: 0.99488, f1_macro: 0.99738
# epoch: 46, passed number of graphs: 192, train running loss: 0.00029 (passed time: 28m 21s)
#           acc: 0.99957, fpr: 0.00008, fnr: 0.01534, rec: 0.98466, prc: 0.99671, f1: 0.99065, f1_macro: 0.99522
# epoch: 46, passed number of graphs: 288, train running loss: 0.00033 (passed time: 28m 26s)
#           acc: 0.99974, fpr: 0.00005, fnr: 0.00966, rec: 0.99034, prc: 0.99761, f1: 0.99396, f1_macro: 0.99692
# epoch: 46, passed number of graphs: 384, train running loss: 0.00032 (passed time: 28m 30s)
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00318, rec: 0.99682, prc: 0.99643, f1: 0.99663, f1_macro: 0.99827
# epoch: 46, passed number of graphs: 480, train running loss: 0.00032 (passed time: 28m 34s)
#           acc: 0.99960, fpr: 0.00030, fnr: 0.00453, rec: 0.99547, prc: 0.98749, f1: 0.99146, f1_macro: 0.99563
# epoch: 46, passed number of graphs: 576, train running loss: 0.00032 (passed time: 28m 39s)
#           acc: 0.99970, fpr: 0.00023, fnr: 0.00314, rec: 0.99686, prc: 0.98945, f1: 0.99314, f1_macro: 0.99649
# epoch: 46, passed number of graphs: 672, train running loss: 0.00032 (passed time: 28m 43s)
#           acc: 0.99949, fpr: 0.00044, fnr: 0.00356, rec: 0.99644, prc: 0.98224, f1: 0.98929, f1_macro: 0.99451
# epoch: 46, passed number of graphs: 768, train running loss: 0.00033 (passed time: 28m 47s)
#           acc: 0.99922, fpr: 0.00005, fnr: 0.03313, rec: 0.96687, prc: 0.99783, f1: 0.98211, f1_macro: 0.99085
# Validation --- epoch: 46, loss: 0.00149
#           fpr: 0.00008, prc: 0.99654, f1: 0.99208, rec: 0.98819, fnr: 0.01181, f1_macro: 0.99596, acc: 0.99969
# Better model saved at ./saved_models/GIN_45_0.9920844819521754.pt.
# epoch: 47, passed number of graphs: 96, train running loss: 0.00031 (passed time: 28m 55s)
#           acc: 0.99976, fpr: 0.00006, fnr: 0.00774, rec: 0.99226, prc: 0.99751, f1: 0.99488, f1_macro: 0.99738
# epoch: 47, passed number of graphs: 192, train running loss: 0.00029 (passed time: 28m 59s)
#           acc: 0.99957, fpr: 0.00008, fnr: 0.01534, rec: 0.98466, prc: 0.99671, f1: 0.99065, f1_macro: 0.99522
# epoch: 47, passed number of graphs: 288, train running loss: 0.00033 (passed time: 29m 3s)
#           acc: 0.99974, fpr: 0.00005, fnr: 0.00966, rec: 0.99034, prc: 0.99761, f1: 0.99396, f1_macro: 0.99692
# epoch: 47, passed number of graphs: 384, train running loss: 0.00032 (passed time: 29m 8s)
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00318, rec: 0.99682, prc: 0.99643, f1: 0.99663, f1_macro: 0.99827
# epoch: 47, passed number of graphs: 480, train running loss: 0.00032 (passed time: 29m 12s)
#           acc: 0.99960, fpr: 0.00030, fnr: 0.00453, rec: 0.99547, prc: 0.98749, f1: 0.99146, f1_macro: 0.99563
# epoch: 47, passed number of graphs: 576, train running loss: 0.00032 (passed time: 29m 16s)
#           acc: 0.99970, fpr: 0.00023, fnr: 0.00314, rec: 0.99686, prc: 0.98945, f1: 0.99314, f1_macro: 0.99649
# epoch: 47, passed number of graphs: 672, train running loss: 0.00032 (passed time: 29m 20s)
#           acc: 0.99949, fpr: 0.00044, fnr: 0.00356, rec: 0.99644, prc: 0.98224, f1: 0.98929, f1_macro: 0.99451
# epoch: 47, passed number of graphs: 768, train running loss: 0.00033 (passed time: 29m 25s)
#           acc: 0.99922, fpr: 0.00005, fnr: 0.03313, rec: 0.96687, prc: 0.99783, f1: 0.98211, f1_macro: 0.99085
# Validation --- epoch: 47, loss: 0.00149
#           fpr: 0.00008, prc: 0.99654, f1: 0.99209, rec: 0.98820, fnr: 0.01180, f1_macro: 0.99597, acc: 0.99969
# Better model saved at ./saved_models/GIN_46_0.9920893183298999.pt.
# epoch: 48, passed number of graphs: 96, train running loss: 0.00031 (passed time: 29m 32s)
#           acc: 0.99977, fpr: 0.00006, fnr: 0.00766, rec: 0.99234, prc: 0.99751, f1: 0.99492, f1_macro: 0.99740
# epoch: 48, passed number of graphs: 192, train running loss: 0.00029 (passed time: 29m 37s)
#           acc: 0.99957, fpr: 0.00008, fnr: 0.01534, rec: 0.98466, prc: 0.99671, f1: 0.99065, f1_macro: 0.99522
# epoch: 48, passed number of graphs: 288, train running loss: 0.00033 (passed time: 29m 41s)
#           acc: 0.99974, fpr: 0.00005, fnr: 0.00966, rec: 0.99034, prc: 0.99761, f1: 0.99396, f1_macro: 0.99692
# epoch: 48, passed number of graphs: 384, train running loss: 0.00032 (passed time: 29m 45s)
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00318, rec: 0.99682, prc: 0.99643, f1: 0.99663, f1_macro: 0.99827
# epoch: 48, passed number of graphs: 480, train running loss: 0.00032 (passed time: 29m 49s)
#           acc: 0.99960, fpr: 0.00030, fnr: 0.00453, rec: 0.99547, prc: 0.98741, f1: 0.99142, f1_macro: 0.99561
# epoch: 48, passed number of graphs: 576, train running loss: 0.00032 (passed time: 29m 54s)
#           acc: 0.99970, fpr: 0.00023, fnr: 0.00314, rec: 0.99686, prc: 0.98945, f1: 0.99314, f1_macro: 0.99649
# epoch: 48, passed number of graphs: 672, train running loss: 0.00032 (passed time: 29m 58s)
#           acc: 0.99949, fpr: 0.00044, fnr: 0.00356, rec: 0.99644, prc: 0.98224, f1: 0.98929, f1_macro: 0.99451
# epoch: 48, passed number of graphs: 768, train running loss: 0.00033 (passed time: 30m 2s)
#           acc: 0.99922, fpr: 0.00005, fnr: 0.03313, rec: 0.96687, prc: 0.99783, f1: 0.98211, f1_macro: 0.99085
# Validation --- epoch: 48, loss: 0.00149
#           fpr: 0.00008, prc: 0.99654, f1: 0.99210, rec: 0.98822, fnr: 0.01178, f1_macro: 0.99597, acc: 0.99969
# Better model saved at ./saved_models/GIN_47_0.9920983535202027.pt.
# epoch: 49, passed number of graphs: 96, train running loss: 0.00031 (passed time: 30m 10s)
#           acc: 0.99977, fpr: 0.00006, fnr: 0.00766, rec: 0.99234, prc: 0.99751, f1: 0.99492, f1_macro: 0.99740
# epoch: 49, passed number of graphs: 192, train running loss: 0.00029 (passed time: 30m 14s)
#           acc: 0.99957, fpr: 0.00008, fnr: 0.01534, rec: 0.98466, prc: 0.99671, f1: 0.99065, f1_macro: 0.99522
# epoch: 49, passed number of graphs: 288, train running loss: 0.00033 (passed time: 30m 19s)
#           acc: 0.99974, fpr: 0.00005, fnr: 0.00966, rec: 0.99034, prc: 0.99761, f1: 0.99396, f1_macro: 0.99692
# epoch: 49, passed number of graphs: 384, train running loss: 0.00032 (passed time: 30m 23s)
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00318, rec: 0.99682, prc: 0.99643, f1: 0.99663, f1_macro: 0.99827
# epoch: 49, passed number of graphs: 480, train running loss: 0.00032 (passed time: 30m 27s)
#           acc: 0.99959, fpr: 0.00031, fnr: 0.00453, rec: 0.99547, prc: 0.98734, f1: 0.99139, f1_macro: 0.99559
# epoch: 49, passed number of graphs: 576, train running loss: 0.00032 (passed time: 30m 31s)
#           acc: 0.99971, fpr: 0.00023, fnr: 0.00306, rec: 0.99694, prc: 0.98953, f1: 0.99322, f1_macro: 0.99653
# epoch: 49, passed number of graphs: 672, train running loss: 0.00032 (passed time: 30m 36s)
#           acc: 0.99949, fpr: 0.00044, fnr: 0.00356, rec: 0.99644, prc: 0.98224, f1: 0.98929, f1_macro: 0.99451
# epoch: 49, passed number of graphs: 768, train running loss: 0.00033 (passed time: 30m 40s)
#           acc: 0.99922, fpr: 0.00005, fnr: 0.03313, rec: 0.96687, prc: 0.99783, f1: 0.98211, f1_macro: 0.99085
# Validation --- epoch: 49, loss: 0.00148
#           fpr: 0.00008, prc: 0.99654, f1: 0.99210, rec: 0.98822, fnr: 0.01178, f1_macro: 0.99597, acc: 0.99969
# Better model saved at ./saved_models/GIN_48_0.9920987160143854.pt.
# epoch: 50, passed number of graphs: 96, train running loss: 0.00031 (passed time: 30m 48s)
#           acc: 0.99977, fpr: 0.00006, fnr: 0.00766, rec: 0.99234, prc: 0.99758, f1: 0.99495, f1_macro: 0.99742
# epoch: 50, passed number of graphs: 192, train running loss: 0.00029 (passed time: 30m 52s)
#           acc: 0.99957, fpr: 0.00008, fnr: 0.01534, rec: 0.98466, prc: 0.99671, f1: 0.99065, f1_macro: 0.99522
# epoch: 50, passed number of graphs: 288, train running loss: 0.00033 (passed time: 30m 56s)
#           acc: 0.99974, fpr: 0.00005, fnr: 0.00966, rec: 0.99034, prc: 0.99761, f1: 0.99396, f1_macro: 0.99692
# epoch: 50, passed number of graphs: 384, train running loss: 0.00032 (passed time: 31m 0s)
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00318, rec: 0.99682, prc: 0.99643, f1: 0.99663, f1_macro: 0.99827
# epoch: 50, passed number of graphs: 480, train running loss: 0.00032 (passed time: 31m 5s)
#           acc: 0.99959, fpr: 0.00031, fnr: 0.00453, rec: 0.99547, prc: 0.98719, f1: 0.99131, f1_macro: 0.99555
# epoch: 50, passed number of graphs: 576, train running loss: 0.00032 (passed time: 31m 9s)
#           acc: 0.99971, fpr: 0.00023, fnr: 0.00306, rec: 0.99694, prc: 0.98953, f1: 0.99322, f1_macro: 0.99653
# epoch: 50, passed number of graphs: 672, train running loss: 0.00032 (passed time: 31m 13s)
#           acc: 0.99949, fpr: 0.00044, fnr: 0.00356, rec: 0.99644, prc: 0.98224, f1: 0.98929, f1_macro: 0.99451
# epoch: 50, passed number of graphs: 768, train running loss: 0.00033 (passed time: 31m 17s)
#           acc: 0.99922, fpr: 0.00005, fnr: 0.03313, rec: 0.96687, prc: 0.99791, f1: 0.98214, f1_macro: 0.99087
# Validation --- epoch: 50, loss: 0.00148
#           fpr: 0.00008, prc: 0.99653, f1: 0.99211, rec: 0.98826, fnr: 0.01174, f1_macro: 0.99598, acc: 0.99969
# Better model saved at ./saved_models/GIN_49_0.9921149020230908.pt.
# ************ best model obtained after epoch 50, saved at ./saved_models/GIN_49_0.9921149020230908.pt ************
# Testing --- loss: 0.00165
#           fpr: 0.00016, prc: 0.99416, f1: 0.99056, rec: 0.98752, fnr: 0.01248, f1_macro: 0.99518, acc: 0.99960

# %%
# !zip -r /content/GIN_Adam_C2.zip /content/saved_models
# Out:
#   adding: content/saved_models/ (stored 0%)
#   adding: content/saved_models/GIN_24_0.9920174942226924.pt (deflated 29%)
#   adding: content/saved_models/GIN_19_0.9919013818614729.pt (deflated 29%)
#   adding: content/saved_models/GIN_40_0.9920700506789567.pt (deflated 29%)
#   adding: content/saved_models/GIN_0_0.62641673183252.pt (deflated 30%)
#   adding: content/saved_models/GIN_23_0.9919833378689885.pt (deflated 29%)
#   adding: content/saved_models/GIN_49_0.9921149020230908.pt (deflated 29%)
#   adding: content/saved_models/GIN_44_0.9920760755796972.pt (deflated 29%)
#   adding: content/saved_models/GIN_46_0.9920893183298999.pt (deflated 29%)
#   adding: content/saved_models/GIN_4_0.9730134898434359.pt (deflated 29%)
#   adding: content/saved_models/GIN_12_0.9898103460192793.pt (deflated 28%)
#   adding: content/saved_models/GIN_22_0.9919796693662656.pt (deflated 29%)
#   adding: content/saved_models/GIN_45_0.9920844819521754.pt (deflated 29%)
#   adding: content/saved_models/GIN_15_0.991647642366987.pt (deflated 29%)
#   adding: content/saved_models/GIN_25_0.9920376155452799.pt (deflated 29%)
#   adding: content/saved_models/GIN_21_0.9919220122330682.pt (deflated 29%)
#   adding: content/saved_models/GIN_18_0.9918849560196161.pt (deflated 29%)
#   adding: content/saved_models/GIN_47_0.9920983535202027.pt (deflated 29%)
#   adding: content/saved_models/GIN_48_0.9920987160143854.pt (deflated 29%)
#   adding: content/saved_models/GIN_42_0.9920751829651352.pt (deflated 29%)
#   adding: content/saved_models/GIN_27_0.9920584782875004.pt (deflated 29%)
#   adding: content/saved_models/GIN_39_0.9920683524617581.pt (deflated 29%)
#   adding: content/saved_models/GIN_6_0.977240765451289.pt (deflated 28%)
#   adding: content/saved_models/GIN_26_0.9920444055624777.pt (deflated 29%)
#   adding: content/saved_models/GIN_28_0.992063458095792.pt (deflated 29%)
#   adding: content/saved_models/GIN_10_0.9819453740255568.pt (deflated 28%)
#   adding: content/saved_models/GIN_11_0.9876361698105359.pt (deflated 28%)
#   adding: content/saved_models/GIN_14_0.9908437751329155.pt (deflated 29%)
#   adding: content/saved_models/GIN_2_0.9121772975352765.pt (deflated 30%)

# %%
from google.colab import files
files.download("/content/GIN_Adam_C2.zip")
