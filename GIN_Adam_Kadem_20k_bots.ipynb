# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/Do_an_tot_nghiep/blob/main/GIN_Adam_Kadem_20k_bots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Wed Oct 26 05:17:10 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric==1.4.3
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5
# !pip install torch-optimizer

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter_
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset
import torch_optimizer as optimization


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric==1.4.3 in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (6.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.21.6)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.6.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.3.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.0.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.56.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.7.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.12.1+cu113)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.4)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.7.4)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.18.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.23.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->torch-geometric==1.4.3) (1.5.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (4.1.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.4.3) (1.15.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (3.0.9)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (0.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (3.0.4)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (1.3.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (7.1.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2021.11.2)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (3.2.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (0.11.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-optimizer in /usr/local/lib/python3.7/dist-packages (0.3.0)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (0.1.1)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->torch-optimizer) (4.1.1)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
            self.num_graphs = 768
        elif split == 'val':
            self.path = self.processed_paths[1]
            self.num_graphs = 96
        elif split == 'test':
            self.path = self.processed_paths[2]
            self.num_graphs = 96

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GINConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_input_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU())))
          else:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU()))) 

        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                add_xr_at = n
            if n == add_xr_at:
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/kadem_20k_botnode'
data_name = 'kadem' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=True, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 2
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# !rm -rf /content/saved_models

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.0
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}_{result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-1fcb09ba-1026-476f-865f-8a20ad136784.json
# ------------------------------
# ------------------------------
# Wed Oct 26 05:19:22 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GINConv(nn=Sequential(
#       (0): Linear(in_features=1, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (1): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (2): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (3): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (4): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (5): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (6): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (7): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (8): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (9): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (10): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (11): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 2
# epoch: 1, passed number of graphs: 96, train running loss: 0.20163 (passed time: 16s)
#           acc: 0.86156, fpr: 0.00004, fnr: 0.99997, rec: 0.00003, prc: 0.10000, f1: 0.00005, f1_macro: 0.46284
# epoch: 1, passed number of graphs: 192, train running loss: 0.15579 (passed time: 30s)
#           acc: 0.97168, fpr: 0.00219, fnr: 0.18937, rec: 0.81063, prc: 0.98365, f1: 0.88879, f1_macro: 0.93629
# epoch: 1, passed number of graphs: 288, train running loss: 0.11402 (passed time: 43s)
#           acc: 0.98818, fpr: 0.00411, fnr: 0.05978, rec: 0.94022, prc: 0.97352, f1: 0.95658, f1_macro: 0.97487
# epoch: 1, passed number of graphs: 384, train running loss: 0.11992 (passed time: 57s)
#           acc: 0.96168, fpr: 0.00154, fnr: 0.26075, rec: 0.73925, prc: 0.98758, f1: 0.84556, f1_macro: 0.91184
# epoch: 1, passed number of graphs: 480, train running loss: 0.10276 (passed time: 1m 11s)
#           acc: 0.98678, fpr: 0.00267, fnr: 0.07735, rec: 0.92265, prc: 0.98274, f1: 0.95175, f1_macro: 0.97204
# epoch: 1, passed number of graphs: 576, train running loss: 0.08871 (passed time: 1m 25s)
#           acc: 0.99184, fpr: 0.00219, fnr: 0.04535, rec: 0.95465, prc: 0.98588, f1: 0.97001, f1_macro: 0.98264
# epoch: 1, passed number of graphs: 672, train running loss: 0.07784 (passed time: 1m 40s)
#           acc: 0.99323, fpr: 0.00181, fnr: 0.03762, rec: 0.96237, prc: 0.98842, f1: 0.97522, f1_macro: 0.98565
# epoch: 1, passed number of graphs: 768, train running loss: 0.06972 (passed time: 1m 54s)
#           acc: 0.99263, fpr: 0.00179, fnr: 0.04202, rec: 0.95798, prc: 0.98849, f1: 0.97300, f1_macro: 0.98436
# Validation --- epoch: 1, loss: 0.03475
#           rec: 0.94964, fpr: 0.00297, prc: 0.96840, acc: 0.99374, f1: 0.95766, fnr: 0.05036, f1_macro: 0.97713
# Better model saved at ./saved_models/GIN_0_0.9576587290230897.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.01163 (passed time: 2m 29s)
#           acc: 0.99432, fpr: 0.00180, fnr: 0.02977, rec: 0.97023, prc: 0.98856, f1: 0.97931, f1_macro: 0.98801
# epoch: 2, passed number of graphs: 192, train running loss: 0.01196 (passed time: 2m 43s)
#           acc: 0.99438, fpr: 0.00137, fnr: 0.03175, rec: 0.96825, prc: 0.99132, f1: 0.97965, f1_macro: 0.98820
# epoch: 2, passed number of graphs: 288, train running loss: 0.01123 (passed time: 2m 57s)
#           acc: 0.99358, fpr: 0.00065, fnr: 0.04230, rec: 0.95770, prc: 0.99579, f1: 0.97637, f1_macro: 0.98633
# epoch: 2, passed number of graphs: 384, train running loss: 0.01054 (passed time: 3m 11s)
#           acc: 0.99515, fpr: 0.00158, fnr: 0.02460, rec: 0.97540, prc: 0.99028, f1: 0.98278, f1_macro: 0.98998
# epoch: 2, passed number of graphs: 480, train running loss: 0.01161 (passed time: 3m 25s)
#           acc: 0.99388, fpr: 0.00148, fnr: 0.03435, rec: 0.96565, prc: 0.99079, f1: 0.97806, f1_macro: 0.98725
# epoch: 2, passed number of graphs: 576, train running loss: 0.01165 (passed time: 3m 39s)
#           acc: 0.99466, fpr: 0.00153, fnr: 0.02905, rec: 0.97095, prc: 0.99026, f1: 0.98051, f1_macro: 0.98871
# epoch: 2, passed number of graphs: 672, train running loss: 0.01150 (passed time: 3m 53s)
#           acc: 0.99440, fpr: 0.00138, fnr: 0.03193, rec: 0.96808, prc: 0.99122, f1: 0.97951, f1_macro: 0.98813
# epoch: 2, passed number of graphs: 768, train running loss: 0.01135 (passed time: 4m 7s)
#           acc: 0.99529, fpr: 0.00118, fnr: 0.02662, rec: 0.97337, prc: 0.99251, f1: 0.98285, f1_macro: 0.99006
# Validation --- epoch: 2, loss: 0.02768
#           rec: 0.94109, fpr: 0.00016, prc: 0.99769, acc: 0.99575, f1: 0.96856, fnr: 0.05891, f1_macro: 0.98314
# Better model saved at ./saved_models/GIN_1_0.9685641547471825.pt.
# epoch: 3, passed number of graphs: 96, train running loss: 0.01277 (passed time: 4m 42s)
#           acc: 0.99501, fpr: 0.00106, fnr: 0.02942, rec: 0.97057, prc: 0.99322, f1: 0.98177, f1_macro: 0.98944
# epoch: 3, passed number of graphs: 192, train running loss: 0.01128 (passed time: 4m 56s)
#           acc: 0.98940, fpr: 0.00097, fnr: 0.06995, rec: 0.93005, prc: 0.99359, f1: 0.96077, f1_macro: 0.97732
# epoch: 3, passed number of graphs: 288, train running loss: 0.01182 (passed time: 5m 10s)
#           acc: 0.84872, fpr: 0.15782, fnr: 0.11058, rec: 0.88943, prc: 0.47537, f1: 0.61959, f1_macro: 0.76259
# epoch: 3, passed number of graphs: 384, train running loss: 0.01525 (passed time: 5m 24s)
#           acc: 0.99067, fpr: 0.00573, fnr: 0.03107, rec: 0.96893, prc: 0.96545, f1: 0.96718, f1_macro: 0.98087
# epoch: 3, passed number of graphs: 480, train running loss: 0.01489 (passed time: 5m 38s)
#           acc: 0.99448, fpr: 0.00168, fnr: 0.02885, rec: 0.97115, prc: 0.98958, f1: 0.98028, f1_macro: 0.98853
# epoch: 3, passed number of graphs: 576, train running loss: 0.01371 (passed time: 5m 53s)
#           acc: 0.99516, fpr: 0.00200, fnr: 0.02250, rec: 0.97750, prc: 0.98740, f1: 0.98242, f1_macro: 0.98981
# epoch: 3, passed number of graphs: 672, train running loss: 0.01278 (passed time: 6m 7s)
#           acc: 0.99608, fpr: 0.00119, fnr: 0.02088, rec: 0.97913, prc: 0.99247, f1: 0.98575, f1_macro: 0.99174
# epoch: 3, passed number of graphs: 768, train running loss: 0.01264 (passed time: 6m 21s)
#           acc: 0.99471, fpr: 0.00161, fnr: 0.02810, rec: 0.97190, prc: 0.98979, f1: 0.98076, f1_macro: 0.98885
# Validation --- epoch: 3, loss: 0.01489
#           rec: 0.97118, fpr: 0.00105, prc: 0.98578, acc: 0.99702, f1: 0.97842, fnr: 0.02882, f1_macro: 0.98841
# Better model saved at ./saved_models/GIN_2_0.9784236236482885.pt.
# epoch: 4, passed number of graphs: 96, train running loss: 0.02828 (passed time: 6m 55s)
#           acc: 0.97567, fpr: 0.00369, fnr: 0.15282, rec: 0.84718, prc: 0.97360, f1: 0.90600, f1_macro: 0.94601
# epoch: 4, passed number of graphs: 192, train running loss: 0.02319 (passed time: 7m 10s)
#           acc: 0.99358, fpr: 0.00147, fnr: 0.03692, rec: 0.96308, prc: 0.99067, f1: 0.97668, f1_macro: 0.98648
# epoch: 4, passed number of graphs: 288, train running loss: 0.02817 (passed time: 7m 24s)
#           acc: 0.98755, fpr: 0.00320, fnr: 0.06997, rec: 0.93002, prc: 0.97908, f1: 0.95392, f1_macro: 0.97336
# epoch: 4, passed number of graphs: 384, train running loss: 0.02426 (passed time: 7m 38s)
#           acc: 0.99319, fpr: 0.00298, fnr: 0.02995, rec: 0.97005, prc: 0.98173, f1: 0.97586, f1_macro: 0.98595
# epoch: 4, passed number of graphs: 480, train running loss: 0.02120 (passed time: 7m 52s)
#           acc: 0.99527, fpr: 0.00194, fnr: 0.02167, rec: 0.97833, prc: 0.98811, f1: 0.98319, f1_macro: 0.99022
# epoch: 4, passed number of graphs: 576, train running loss: 0.01928 (passed time: 8m 6s)
#           acc: 0.99307, fpr: 0.00218, fnr: 0.03653, rec: 0.96347, prc: 0.98608, f1: 0.97465, f1_macro: 0.98532
# epoch: 4, passed number of graphs: 672, train running loss: 0.01800 (passed time: 8m 20s)
#           acc: 0.99470, fpr: 0.00237, fnr: 0.02350, rec: 0.97650, prc: 0.98509, f1: 0.98078, f1_macro: 0.98885
# epoch: 4, passed number of graphs: 768, train running loss: 0.01744 (passed time: 8m 34s)
#           acc: 0.97671, fpr: 0.00256, fnr: 0.15207, rec: 0.84793, prc: 0.98159, f1: 0.90988, f1_macro: 0.94825
# Validation --- epoch: 4, loss: 0.04970
#           rec: 0.86750, fpr: 0.00274, prc: 0.95948, acc: 0.98823, f1: 0.91116, fnr: 0.13250, f1_macro: 0.95243
# epoch: 5, passed number of graphs: 96, train running loss: 0.01704 (passed time: 9m 8s)
#           acc: 0.99252, fpr: 0.00330, fnr: 0.03347, rec: 0.96652, prc: 0.97918, f1: 0.97281, f1_macro: 0.98424
# epoch: 5, passed number of graphs: 192, train running loss: 0.01494 (passed time: 9m 23s)
#           acc: 0.99292, fpr: 0.00247, fnr: 0.03547, rec: 0.96452, prc: 0.98446, f1: 0.97439, f1_macro: 0.98514
# epoch: 5, passed number of graphs: 288, train running loss: 0.01323 (passed time: 9m 37s)
#           acc: 0.99489, fpr: 0.00251, fnr: 0.02130, rec: 0.97870, prc: 0.98431, f1: 0.98150, f1_macro: 0.98927
# epoch: 5, passed number of graphs: 384, train running loss: 0.01200 (passed time: 9m 51s)
#           acc: 0.99469, fpr: 0.00244, fnr: 0.02265, rec: 0.97735, prc: 0.98513, f1: 0.98123, f1_macro: 0.98907
# epoch: 5, passed number of graphs: 480, train running loss: 0.01158 (passed time: 10m 5s)
#           acc: 0.99412, fpr: 0.00123, fnr: 0.03413, rec: 0.96588, prc: 0.99232, f1: 0.97892, f1_macro: 0.98775
# epoch: 5, passed number of graphs: 576, train running loss: 0.01111 (passed time: 10m 19s)
#           acc: 0.99520, fpr: 0.00122, fnr: 0.02718, rec: 0.97283, prc: 0.99227, f1: 0.98245, f1_macro: 0.98983
# epoch: 5, passed number of graphs: 672, train running loss: 0.01110 (passed time: 10m 33s)
#           acc: 0.99480, fpr: 0.00199, fnr: 0.02520, rec: 0.97480, prc: 0.98746, f1: 0.98109, f1_macro: 0.98904
# epoch: 5, passed number of graphs: 768, train running loss: 0.01068 (passed time: 10m 47s)
#           acc: 0.99538, fpr: 0.00196, fnr: 0.02117, rec: 0.97882, prc: 0.98771, f1: 0.98325, f1_macro: 0.99028
# Validation --- epoch: 5, loss: 0.01015
#           rec: 0.97428, fpr: 0.00086, prc: 0.98831, acc: 0.99741, f1: 0.98124, fnr: 0.02572, f1_macro: 0.98992
# Better model saved at ./saved_models/GIN_4_0.9812359281220716.pt.
# epoch: 6, passed number of graphs: 96, train running loss: 0.01043 (passed time: 11m 21s)
#           acc: 0.99317, fpr: 0.00215, fnr: 0.03598, rec: 0.96403, prc: 0.98632, f1: 0.97504, f1_macro: 0.98554
# epoch: 6, passed number of graphs: 192, train running loss: 0.00998 (passed time: 11m 36s)
#           acc: 0.99422, fpr: 0.00129, fnr: 0.03340, rec: 0.96660, prc: 0.99182, f1: 0.97905, f1_macro: 0.98785
# epoch: 6, passed number of graphs: 288, train running loss: 0.00947 (passed time: 11m 50s)
#           acc: 0.99564, fpr: 0.00199, fnr: 0.01910, rec: 0.98090, prc: 0.98757, f1: 0.98422, f1_macro: 0.99085
# epoch: 6, passed number of graphs: 384, train running loss: 0.00929 (passed time: 12m 4s)
#           acc: 0.99305, fpr: 0.00240, fnr: 0.03450, rec: 0.96550, prc: 0.98520, f1: 0.97525, f1_macro: 0.98560
# epoch: 6, passed number of graphs: 480, train running loss: 0.00916 (passed time: 12m 18s)
#           acc: 0.99570, fpr: 0.00171, fnr: 0.02003, rec: 0.97998, prc: 0.98950, f1: 0.98471, f1_macro: 0.99111
# epoch: 6, passed number of graphs: 576, train running loss: 0.00985 (passed time: 12m 32s)
#           acc: 0.98696, fpr: 0.00549, fnr: 0.06008, rec: 0.93993, prc: 0.96484, f1: 0.95222, f1_macro: 0.97233
# epoch: 6, passed number of graphs: 672, train running loss: 0.01026 (passed time: 12m 46s)
#           acc: 0.99481, fpr: 0.00174, fnr: 0.02662, rec: 0.97337, prc: 0.98898, f1: 0.98111, f1_macro: 0.98905
# epoch: 6, passed number of graphs: 768, train running loss: 0.01016 (passed time: 13m 0s)
#           acc: 0.99512, fpr: 0.00187, fnr: 0.02363, rec: 0.97637, prc: 0.98826, f1: 0.98228, f1_macro: 0.98972
# Validation --- epoch: 6, loss: 0.01061
#           rec: 0.97517, fpr: 0.00086, prc: 0.98830, acc: 0.99747, f1: 0.98169, fnr: 0.02483, f1_macro: 0.99017
# Better model saved at ./saved_models/GIN_5_0.9816899525132851.pt.
# epoch: 7, passed number of graphs: 96, train running loss: 0.00934 (passed time: 13m 35s)
#           acc: 0.99467, fpr: 0.00139, fnr: 0.02987, rec: 0.97013, prc: 0.99119, f1: 0.98054, f1_macro: 0.98873
# epoch: 7, passed number of graphs: 192, train running loss: 0.00911 (passed time: 13m 49s)
#           acc: 0.99536, fpr: 0.00135, fnr: 0.02488, rec: 0.97513, prc: 0.99151, f1: 0.98325, f1_macro: 0.99028
# epoch: 7, passed number of graphs: 288, train running loss: 0.01164 (passed time: 14m 3s)
#           acc: 0.98115, fpr: 0.00084, fnr: 0.13085, rec: 0.86915, prc: 0.99400, f1: 0.92739, f1_macro: 0.95828
# epoch: 7, passed number of graphs: 384, train running loss: 0.01323 (passed time: 14m 17s)
#           acc: 0.99338, fpr: 0.00266, fnr: 0.03058, rec: 0.96942, prc: 0.98366, f1: 0.97649, f1_macro: 0.98632
# epoch: 7, passed number of graphs: 480, train running loss: 0.01362 (passed time: 14m 31s)
#           acc: 0.99275, fpr: 0.00289, fnr: 0.03372, rec: 0.96627, prc: 0.98216, f1: 0.97415, f1_macro: 0.98497
# epoch: 7, passed number of graphs: 576, train running loss: 0.01297 (passed time: 14m 45s)
#           acc: 0.99430, fpr: 0.00186, fnr: 0.02965, rec: 0.97035, prc: 0.98821, f1: 0.97920, f1_macro: 0.98795
# epoch: 7, passed number of graphs: 672, train running loss: 0.01259 (passed time: 14m 59s)
#           acc: 0.99554, fpr: 0.00139, fnr: 0.02357, rec: 0.97642, prc: 0.99124, f1: 0.98378, f1_macro: 0.99060
# epoch: 7, passed number of graphs: 768, train running loss: 0.01200 (passed time: 15m 13s)
#           acc: 0.99561, fpr: 0.00158, fnr: 0.02185, rec: 0.97815, prc: 0.99008, f1: 0.98408, f1_macro: 0.99077
# Validation --- epoch: 7, loss: 0.01283
#           rec: 0.95787, fpr: 0.00026, prc: 0.99645, acc: 0.99683, f1: 0.97678, fnr: 0.04213, f1_macro: 0.98754
# epoch: 8, passed number of graphs: 96, train running loss: 0.00701 (passed time: 15m 48s)
#           acc: 0.99655, fpr: 0.00109, fnr: 0.01812, rec: 0.98188, prc: 0.99312, f1: 0.98747, f1_macro: 0.99273
# epoch: 8, passed number of graphs: 192, train running loss: 0.00681 (passed time: 16m 2s)
#           acc: 0.99626, fpr: 0.00109, fnr: 0.02013, rec: 0.97988, prc: 0.99321, f1: 0.98650, f1_macro: 0.99216
# epoch: 8, passed number of graphs: 288, train running loss: 0.00664 (passed time: 16m 16s)
#           acc: 0.99687, fpr: 0.00090, fnr: 0.01698, rec: 0.98303, prc: 0.99431, f1: 0.98864, f1_macro: 0.99341
# epoch: 8, passed number of graphs: 384, train running loss: 0.00649 (passed time: 16m 30s)
#           acc: 0.99640, fpr: 0.00140, fnr: 0.01692, rec: 0.98308, prc: 0.99145, f1: 0.98725, f1_macro: 0.99257
# epoch: 8, passed number of graphs: 480, train running loss: 0.00668 (passed time: 16m 44s)
#           acc: 0.99321, fpr: 0.00091, fnr: 0.04255, rec: 0.95745, prc: 0.99426, f1: 0.97551, f1_macro: 0.98578
# epoch: 8, passed number of graphs: 576, train running loss: 0.00696 (passed time: 16m 58s)
#           acc: 0.99560, fpr: 0.00148, fnr: 0.02258, rec: 0.97742, prc: 0.99065, f1: 0.98399, f1_macro: 0.99072
# epoch: 8, passed number of graphs: 672, train running loss: 0.00697 (passed time: 17m 12s)
#           acc: 0.99619, fpr: 0.00103, fnr: 0.02110, rec: 0.97890, prc: 0.99348, f1: 0.98614, f1_macro: 0.99196
# epoch: 8, passed number of graphs: 768, train running loss: 0.00694 (passed time: 17m 26s)
#           acc: 0.99635, fpr: 0.00137, fnr: 0.01780, rec: 0.98220, prc: 0.99140, f1: 0.98678, f1_macro: 0.99233
# Validation --- epoch: 8, loss: 0.00855
#           rec: 0.97972, fpr: 0.00066, prc: 0.99113, acc: 0.99798, f1: 0.98538, fnr: 0.02028, f1_macro: 0.99215
# Better model saved at ./saved_models/GIN_7_0.9853849018986337.pt.
# epoch: 9, passed number of graphs: 96, train running loss: 0.00653 (passed time: 18m 1s)
#           acc: 0.99667, fpr: 0.00098, fnr: 0.01798, rec: 0.98203, prc: 0.99385, f1: 0.98790, f1_macro: 0.99299
# epoch: 9, passed number of graphs: 192, train running loss: 0.00644 (passed time: 18m 15s)
#           acc: 0.99662, fpr: 0.00094, fnr: 0.01843, rec: 0.98157, prc: 0.99415, f1: 0.98782, f1_macro: 0.99293
# epoch: 9, passed number of graphs: 288, train running loss: 0.00628 (passed time: 18m 29s)
#           acc: 0.99704, fpr: 0.00081, fnr: 0.01630, rec: 0.98370, prc: 0.99489, f1: 0.98926, f1_macro: 0.99377
# epoch: 9, passed number of graphs: 384, train running loss: 0.00642 (passed time: 18m 43s)
#           acc: 0.99568, fpr: 0.00142, fnr: 0.02187, rec: 0.97813, prc: 0.99131, f1: 0.98467, f1_macro: 0.99108
# epoch: 9, passed number of graphs: 480, train running loss: 0.00751 (passed time: 18m 57s)
#           acc: 0.99500, fpr: 0.00053, fnr: 0.03220, rec: 0.96780, prc: 0.99670, f1: 0.98204, f1_macro: 0.98957
# epoch: 9, passed number of graphs: 576, train running loss: 0.00764 (passed time: 19m 11s)
#           acc: 0.99538, fpr: 0.00116, fnr: 0.02620, rec: 0.97380, prc: 0.99266, f1: 0.98314, f1_macro: 0.99023
# epoch: 9, passed number of graphs: 672, train running loss: 0.00763 (passed time: 19m 25s)
#           acc: 0.99653, fpr: 0.00097, fnr: 0.01905, rec: 0.98095, prc: 0.99390, f1: 0.98738, f1_macro: 0.99268
# epoch: 9, passed number of graphs: 768, train running loss: 0.00746 (passed time: 19m 39s)
#           acc: 0.99659, fpr: 0.00109, fnr: 0.01777, rec: 0.98223, prc: 0.99312, f1: 0.98764, f1_macro: 0.99283
# Validation --- epoch: 9, loss: 0.00787
#           rec: 0.97947, fpr: 0.00047, prc: 0.99366, acc: 0.99814, f1: 0.98651, fnr: 0.02053, f1_macro: 0.99275
# Better model saved at ./saved_models/GIN_8_0.9865107936595079.pt.
# epoch: 10, passed number of graphs: 96, train running loss: 0.00615 (passed time: 20m 14s)
#           acc: 0.99679, fpr: 0.00093, fnr: 0.01740, rec: 0.98260, prc: 0.99416, f1: 0.98834, f1_macro: 0.99324
# epoch: 10, passed number of graphs: 192, train running loss: 0.00648 (passed time: 20m 28s)
#           acc: 0.99593, fpr: 0.00079, fnr: 0.02428, rec: 0.97572, prc: 0.99500, f1: 0.98527, f1_macro: 0.99145
# epoch: 10, passed number of graphs: 288, train running loss: 0.00638 (passed time: 20m 42s)
#           acc: 0.99706, fpr: 0.00092, fnr: 0.01550, rec: 0.98450, prc: 0.99419, f1: 0.98932, f1_macro: 0.99381
# epoch: 10, passed number of graphs: 384, train running loss: 0.00623 (passed time: 20m 56s)
#           acc: 0.99656, fpr: 0.00087, fnr: 0.01897, rec: 0.98103, prc: 0.99465, f1: 0.98779, f1_macro: 0.99289
# epoch: 10, passed number of graphs: 480, train running loss: 0.00611 (passed time: 21m 10s)
#           acc: 0.99699, fpr: 0.00071, fnr: 0.01700, rec: 0.98300, prc: 0.99564, f1: 0.98928, f1_macro: 0.99377
# epoch: 10, passed number of graphs: 576, train running loss: 0.00617 (passed time: 21m 24s)
#           acc: 0.99663, fpr: 0.00083, fnr: 0.01915, rec: 0.98085, prc: 0.99473, f1: 0.98774, f1_macro: 0.99289
# epoch: 10, passed number of graphs: 672, train running loss: 0.00611 (passed time: 21m 38s)
#           acc: 0.99711, fpr: 0.00075, fnr: 0.01617, rec: 0.98382, prc: 0.99525, f1: 0.98950, f1_macro: 0.99391
# epoch: 10, passed number of graphs: 768, train running loss: 0.00605 (passed time: 21m 52s)
#           acc: 0.99708, fpr: 0.00090, fnr: 0.01547, rec: 0.98452, prc: 0.99434, f1: 0.98941, f1_macro: 0.99386
# Validation --- epoch: 10, loss: 0.00688
#           rec: 0.98245, fpr: 0.00034, prc: 0.99533, acc: 0.99846, f1: 0.98885, fnr: 0.01755, f1_macro: 0.99401
# Better model saved at ./saved_models/GIN_9_0.9888489251910592.pt.
# epoch: 11, passed number of graphs: 96, train running loss: 0.00560 (passed time: 22m 26s)
#           acc: 0.99678, fpr: 0.00077, fnr: 0.01850, rec: 0.98150, prc: 0.99516, f1: 0.98828, f1_macro: 0.99321
# epoch: 11, passed number of graphs: 192, train running loss: 0.00556 (passed time: 22m 40s)
#           acc: 0.99706, fpr: 0.00073, fnr: 0.01655, rec: 0.98345, prc: 0.99542, f1: 0.98940, f1_macro: 0.99385
# epoch: 11, passed number of graphs: 288, train running loss: 0.00545 (passed time: 22m 54s)
#           acc: 0.99734, fpr: 0.00075, fnr: 0.01452, rec: 0.98547, prc: 0.99528, f1: 0.99035, f1_macro: 0.99441
# epoch: 11, passed number of graphs: 384, train running loss: 0.00544 (passed time: 23m 8s)
#           acc: 0.99706, fpr: 0.00090, fnr: 0.01525, rec: 0.98475, prc: 0.99450, f1: 0.98960, f1_macro: 0.99394
# epoch: 11, passed number of graphs: 480, train running loss: 0.00540 (passed time: 23m 22s)
#           acc: 0.99743, fpr: 0.00039, fnr: 0.01580, rec: 0.98420, prc: 0.99759, f1: 0.99085, f1_macro: 0.99468
# epoch: 11, passed number of graphs: 576, train running loss: 0.00537 (passed time: 23m 36s)
#           acc: 0.99669, fpr: 0.00065, fnr: 0.01992, rec: 0.98008, prc: 0.99588, f1: 0.98792, f1_macro: 0.99300
# epoch: 11, passed number of graphs: 672, train running loss: 0.00540 (passed time: 23m 50s)
#           acc: 0.99728, fpr: 0.00076, fnr: 0.01487, rec: 0.98513, prc: 0.99520, f1: 0.99014, f1_macro: 0.99428
# epoch: 11, passed number of graphs: 768, train running loss: 0.00536 (passed time: 24m 4s)
#           acc: 0.99738, fpr: 0.00079, fnr: 0.01395, rec: 0.98605, prc: 0.99503, f1: 0.99052, f1_macro: 0.99450
# Validation --- epoch: 11, loss: 0.00684
#           rec: 0.98428, fpr: 0.00057, prc: 0.99227, acc: 0.99837, f1: 0.98825, fnr: 0.01572, f1_macro: 0.99369
# epoch: 12, passed number of graphs: 96, train running loss: 0.00548 (passed time: 24m 38s)
#           acc: 0.99656, fpr: 0.00145, fnr: 0.01578, rec: 0.98423, prc: 0.99089, f1: 0.98755, f1_macro: 0.99278
# epoch: 12, passed number of graphs: 192, train running loss: 0.00541 (passed time: 24m 52s)
#           acc: 0.99714, fpr: 0.00080, fnr: 0.01555, rec: 0.98445, prc: 0.99502, f1: 0.98971, f1_macro: 0.99402
# epoch: 12, passed number of graphs: 288, train running loss: 0.00524 (passed time: 25m 6s)
#           acc: 0.99739, fpr: 0.00086, fnr: 0.01353, rec: 0.98647, prc: 0.99463, f1: 0.99054, f1_macro: 0.99451
# epoch: 12, passed number of graphs: 384, train running loss: 0.00524 (passed time: 25m 20s)
#           acc: 0.99687, fpr: 0.00078, fnr: 0.01735, rec: 0.98265, prc: 0.99524, f1: 0.98890, f1_macro: 0.99354
# epoch: 12, passed number of graphs: 480, train running loss: 0.00522 (passed time: 25m 34s)
#           acc: 0.99752, fpr: 0.00053, fnr: 0.01430, rec: 0.98570, prc: 0.99671, f1: 0.99118, f1_macro: 0.99487
# epoch: 12, passed number of graphs: 576, train running loss: 0.00517 (passed time: 25m 48s)
#           acc: 0.99724, fpr: 0.00064, fnr: 0.01600, rec: 0.98400, prc: 0.99598, f1: 0.98995, f1_macro: 0.99418
# epoch: 12, passed number of graphs: 672, train running loss: 0.00515 (passed time: 26m 2s)
#           acc: 0.99743, fpr: 0.00072, fnr: 0.01410, rec: 0.98590, prc: 0.99548, f1: 0.99067, f1_macro: 0.99459
# epoch: 12, passed number of graphs: 768, train running loss: 0.00517 (passed time: 26m 16s)
#           acc: 0.99728, fpr: 0.00063, fnr: 0.01570, rec: 0.98430, prc: 0.99605, f1: 0.99014, f1_macro: 0.99428
# Validation --- epoch: 12, loss: 0.00659
#           rec: 0.98273, fpr: 0.00036, prc: 0.99514, acc: 0.99846, f1: 0.98889, fnr: 0.01727, f1_macro: 0.99403
# Better model saved at ./saved_models/GIN_11_0.9888924952526991.pt.
# epoch: 13, passed number of graphs: 96, train running loss: 0.00577 (passed time: 26m 50s)
#           acc: 0.99629, fpr: 0.00180, fnr: 0.01560, rec: 0.98440, prc: 0.98878, f1: 0.98658, f1_macro: 0.99222
# epoch: 13, passed number of graphs: 192, train running loss: 0.00548 (passed time: 27m 4s)
#           acc: 0.99719, fpr: 0.00072, fnr: 0.01572, rec: 0.98428, prc: 0.99552, f1: 0.98987, f1_macro: 0.99412
# epoch: 13, passed number of graphs: 288, train running loss: 0.00525 (passed time: 27m 18s)
#           acc: 0.99735, fpr: 0.00100, fnr: 0.01293, rec: 0.98708, prc: 0.99373, f1: 0.99039, f1_macro: 0.99443
# epoch: 13, passed number of graphs: 384, train running loss: 0.00521 (passed time: 27m 32s)
#           acc: 0.99681, fpr: 0.00081, fnr: 0.01752, rec: 0.98247, prc: 0.99501, f1: 0.98870, f1_macro: 0.99342
# epoch: 13, passed number of graphs: 480, train running loss: 0.00515 (passed time: 27m 46s)
#           acc: 0.99755, fpr: 0.00072, fnr: 0.01298, rec: 0.98703, prc: 0.99559, f1: 0.99129, f1_macro: 0.99493
# epoch: 13, passed number of graphs: 576, train running loss: 0.00513 (passed time: 28m 0s)
#           acc: 0.99694, fpr: 0.00055, fnr: 0.01870, rec: 0.98130, prc: 0.99652, f1: 0.98885, f1_macro: 0.99354
# epoch: 13, passed number of graphs: 672, train running loss: 0.00515 (passed time: 28m 14s)
#           acc: 0.99732, fpr: 0.00085, fnr: 0.01410, rec: 0.98590, prc: 0.99465, f1: 0.99026, f1_macro: 0.99435
# epoch: 13, passed number of graphs: 768, train running loss: 0.00511 (passed time: 28m 28s)
#           acc: 0.99748, fpr: 0.00070, fnr: 0.01383, rec: 0.98618, prc: 0.99561, f1: 0.99087, f1_macro: 0.99470
# Validation --- epoch: 13, loss: 0.00624
#           rec: 0.98441, fpr: 0.00033, prc: 0.99547, acc: 0.99860, f1: 0.98991, fnr: 0.01559, f1_macro: 0.99458
# Better model saved at ./saved_models/GIN_12_0.9899076448823384.pt.
# epoch: 14, passed number of graphs: 96, train running loss: 0.02304 (passed time: 29m 3s)
#           acc: 0.91289, fpr: 0.02261, fnr: 0.48860, rec: 0.51140, prc: 0.78418, f1: 0.61907, f1_macro: 0.78495
# epoch: 14, passed number of graphs: 192, train running loss: 0.02843 (passed time: 29m 17s)
#           acc: 0.99222, fpr: 0.00231, fnr: 0.04152, rec: 0.95847, prc: 0.98538, f1: 0.97174, f1_macro: 0.98361
# epoch: 14, passed number of graphs: 288, train running loss: 0.02263 (passed time: 29m 31s)
#           acc: 0.99433, fpr: 0.00207, fnr: 0.02805, rec: 0.97195, prc: 0.98690, f1: 0.97937, f1_macro: 0.98804
# epoch: 14, passed number of graphs: 384, train running loss: 0.01937 (passed time: 29m 45s)
#           acc: 0.99381, fpr: 0.00229, fnr: 0.02977, rec: 0.97023, prc: 0.98593, f1: 0.97801, f1_macro: 0.98721
# epoch: 14, passed number of graphs: 480, train running loss: 0.01722 (passed time: 29m 59s)
#           acc: 0.99549, fpr: 0.00146, fnr: 0.02297, rec: 0.97703, prc: 0.99097, f1: 0.98395, f1_macro: 0.99066
# epoch: 14, passed number of graphs: 576, train running loss: 0.01573 (passed time: 30m 13s)
#           acc: 0.99448, fpr: 0.00197, fnr: 0.02765, rec: 0.97235, prc: 0.98756, f1: 0.97990, f1_macro: 0.98835
# epoch: 14, passed number of graphs: 672, train running loss: 0.01471 (passed time: 30m 27s)
#           acc: 0.99537, fpr: 0.00157, fnr: 0.02363, rec: 0.97637, prc: 0.99006, f1: 0.98317, f1_macro: 0.99025
# epoch: 14, passed number of graphs: 768, train running loss: 0.01383 (passed time: 30m 41s)
#           acc: 0.99561, fpr: 0.00158, fnr: 0.02183, rec: 0.97818, prc: 0.99006, f1: 0.98408, f1_macro: 0.99077
# Validation --- epoch: 14, loss: 0.00947
#           rec: 0.97713, fpr: 0.00092, prc: 0.98761, acc: 0.99756, f1: 0.98234, fnr: 0.02287, f1_macro: 0.99051
# epoch: 15, passed number of graphs: 96, train running loss: 0.00759 (passed time: 31m 16s)
#           acc: 0.99541, fpr: 0.00143, fnr: 0.02428, rec: 0.97572, prc: 0.99096, f1: 0.98328, f1_macro: 0.99031
# epoch: 15, passed number of graphs: 192, train running loss: 0.00747 (passed time: 31m 31s)
#           acc: 0.99556, fpr: 0.00136, fnr: 0.02340, rec: 0.97660, prc: 0.99147, f1: 0.98398, f1_macro: 0.99070
# epoch: 15, passed number of graphs: 288, train running loss: 0.00722 (passed time: 31m 45s)
#           acc: 0.99594, fpr: 0.00115, fnr: 0.02215, rec: 0.97785, prc: 0.99272, f1: 0.98523, f1_macro: 0.99144
# epoch: 15, passed number of graphs: 384, train running loss: 0.00713 (passed time: 31m 59s)
#           acc: 0.99551, fpr: 0.00165, fnr: 0.02167, rec: 0.97833, prc: 0.98991, f1: 0.98408, f1_macro: 0.99073
# epoch: 15, passed number of graphs: 480, train running loss: 0.00698 (passed time: 32m 13s)
#           acc: 0.99679, fpr: 0.00100, fnr: 0.01665, rec: 0.98335, prc: 0.99386, f1: 0.98858, f1_macro: 0.99335
# epoch: 15, passed number of graphs: 576, train running loss: 0.00697 (passed time: 32m 27s)
#           acc: 0.99617, fpr: 0.00123, fnr: 0.02007, rec: 0.97993, prc: 0.99225, f1: 0.98605, f1_macro: 0.99191
# epoch: 15, passed number of graphs: 672, train running loss: 0.00691 (passed time: 32m 41s)
#           acc: 0.99665, fpr: 0.00123, fnr: 0.01655, rec: 0.98345, prc: 0.99228, f1: 0.98785, f1_macro: 0.99295
# epoch: 15, passed number of graphs: 768, train running loss: 0.00689 (passed time: 32m 55s)
#           acc: 0.99667, fpr: 0.00112, fnr: 0.01707, rec: 0.98293, prc: 0.99295, f1: 0.98791, f1_macro: 0.99299
# Validation --- epoch: 15, loss: 0.09124
#           rec: 0.98666, fpr: 0.03080, prc: 0.70574, acc: 0.97042, f1: 0.82284, fnr: 0.01334, f1_macro: 0.90335
# epoch: 16, passed number of graphs: 96, train running loss: 0.00586 (passed time: 33m 31s)
#           acc: 0.99692, fpr: 0.00108, fnr: 0.01550, rec: 0.98450, prc: 0.99319, f1: 0.98883, f1_macro: 0.99352
# epoch: 16, passed number of graphs: 192, train running loss: 0.00580 (passed time: 33m 45s)
#           acc: 0.99666, fpr: 0.00107, fnr: 0.01727, rec: 0.98272, prc: 0.99330, f1: 0.98799, f1_macro: 0.99302
# epoch: 16, passed number of graphs: 288, train running loss: 0.00575 (passed time: 33m 59s)
#           acc: 0.99686, fpr: 0.00107, fnr: 0.01597, rec: 0.98403, prc: 0.99326, f1: 0.98862, f1_macro: 0.99340
# epoch: 16, passed number of graphs: 384, train running loss: 0.00574 (passed time: 34m 13s)
#           acc: 0.99646, fpr: 0.00131, fnr: 0.01705, rec: 0.98295, prc: 0.99203, f1: 0.98747, f1_macro: 0.99270
# epoch: 16, passed number of graphs: 480, train running loss: 0.00571 (passed time: 34m 27s)
#           acc: 0.99712, fpr: 0.00082, fnr: 0.01537, rec: 0.98462, prc: 0.99497, f1: 0.98977, f1_macro: 0.99405
# epoch: 16, passed number of graphs: 576, train running loss: 0.00568 (passed time: 34m 41s)
#           acc: 0.99667, fpr: 0.00115, fnr: 0.01692, rec: 0.98308, prc: 0.99278, f1: 0.98790, f1_macro: 0.99299
# epoch: 16, passed number of graphs: 672, train running loss: 0.00567 (passed time: 34m 55s)
#           acc: 0.99693, fpr: 0.00107, fnr: 0.01555, rec: 0.98445, prc: 0.99329, f1: 0.98885, f1_macro: 0.99353
# epoch: 16, passed number of graphs: 768, train running loss: 0.00565 (passed time: 35m 9s)
#           acc: 0.99687, fpr: 0.00116, fnr: 0.01533, rec: 0.98467, prc: 0.99272, f1: 0.98868, f1_macro: 0.99343
# Validation --- epoch: 16, loss: 0.00712
#           rec: 0.98358, fpr: 0.00064, prc: 0.99143, acc: 0.99827, f1: 0.98749, fnr: 0.01642, f1_macro: 0.99328
# epoch: 17, passed number of graphs: 96, train running loss: 0.00547 (passed time: 35m 43s)
#           acc: 0.99705, fpr: 0.00111, fnr: 0.01443, rec: 0.98557, prc: 0.99305, f1: 0.98930, f1_macro: 0.99379
# epoch: 17, passed number of graphs: 192, train running loss: 0.00548 (passed time: 35m 57s)
#           acc: 0.99678, fpr: 0.00105, fnr: 0.01660, rec: 0.98340, prc: 0.99348, f1: 0.98842, f1_macro: 0.99327
# epoch: 17, passed number of graphs: 288, train running loss: 0.00548 (passed time: 36m 12s)
#           acc: 0.99704, fpr: 0.00104, fnr: 0.01490, rec: 0.98510, prc: 0.99350, f1: 0.98928, f1_macro: 0.99378
# epoch: 17, passed number of graphs: 384, train running loss: 0.00546 (passed time: 36m 26s)
#           acc: 0.99647, fpr: 0.00138, fnr: 0.01650, rec: 0.98350, prc: 0.99156, f1: 0.98751, f1_macro: 0.99273
# epoch: 17, passed number of graphs: 480, train running loss: 0.00543 (passed time: 36m 40s)
#           acc: 0.99721, fpr: 0.00076, fnr: 0.01512, rec: 0.98487, prc: 0.99535, f1: 0.99009, f1_macro: 0.99423
# epoch: 17, passed number of graphs: 576, train running loss: 0.00542 (passed time: 36m 54s)
#           acc: 0.99652, fpr: 0.00129, fnr: 0.01713, rec: 0.98288, prc: 0.99190, f1: 0.98737, f1_macro: 0.99268
# epoch: 17, passed number of graphs: 672, train running loss: 0.00546 (passed time: 37m 8s)
#           acc: 0.99708, fpr: 0.00089, fnr: 0.01558, rec: 0.98442, prc: 0.99439, f1: 0.98938, f1_macro: 0.99384
# epoch: 17, passed number of graphs: 768, train running loss: 0.00545 (passed time: 37m 22s)
#           acc: 0.99686, fpr: 0.00108, fnr: 0.01593, rec: 0.98408, prc: 0.99321, f1: 0.98862, f1_macro: 0.99340
# Validation --- epoch: 17, loss: 0.00698
#           rec: 0.98301, fpr: 0.00058, prc: 0.99219, acc: 0.99828, f1: 0.98758, fnr: 0.01699, f1_macro: 0.99333
# epoch: 18, passed number of graphs: 96, train running loss: 0.00525 (passed time: 37m 56s)
#           acc: 0.99713, fpr: 0.00102, fnr: 0.01438, rec: 0.98562, prc: 0.99360, f1: 0.98960, f1_macro: 0.99397
# epoch: 18, passed number of graphs: 192, train running loss: 0.00523 (passed time: 38m 10s)
#           acc: 0.99687, fpr: 0.00109, fnr: 0.01570, rec: 0.98430, prc: 0.99321, f1: 0.98874, f1_macro: 0.99346
# epoch: 18, passed number of graphs: 288, train running loss: 0.00519 (passed time: 38m 24s)
#           acc: 0.99712, fpr: 0.00094, fnr: 0.01498, rec: 0.98503, prc: 0.99412, f1: 0.98955, f1_macro: 0.99394
# epoch: 18, passed number of graphs: 384, train running loss: 0.00519 (passed time: 38m 38s)
#           acc: 0.99665, fpr: 0.00138, fnr: 0.01525, rec: 0.98475, prc: 0.99162, f1: 0.98817, f1_macro: 0.99311
# epoch: 18, passed number of graphs: 480, train running loss: 0.00518 (passed time: 38m 52s)
#           acc: 0.99730, fpr: 0.00074, fnr: 0.01457, rec: 0.98542, prc: 0.99545, f1: 0.99041, f1_macro: 0.99442
# epoch: 18, passed number of graphs: 576, train running loss: 0.00516 (passed time: 39m 6s)
#           acc: 0.99688, fpr: 0.00108, fnr: 0.01582, rec: 0.98418, prc: 0.99321, f1: 0.98867, f1_macro: 0.99343
# epoch: 18, passed number of graphs: 672, train running loss: 0.00515 (passed time: 39m 20s)
#           acc: 0.99708, fpr: 0.00105, fnr: 0.01452, rec: 0.98547, prc: 0.99340, f1: 0.98942, f1_macro: 0.99386
# epoch: 18, passed number of graphs: 768, train running loss: 0.00515 (passed time: 39m 35s)
#           acc: 0.99703, fpr: 0.00113, fnr: 0.01438, rec: 0.98562, prc: 0.99292, f1: 0.98926, f1_macro: 0.99377
# Validation --- epoch: 18, loss: 0.00669
#           rec: 0.98423, fpr: 0.00060, prc: 0.99197, acc: 0.99835, f1: 0.98808, fnr: 0.01577, f1_macro: 0.99360
# epoch: 19, passed number of graphs: 96, train running loss: 0.00509 (passed time: 40m 9s)
#           acc: 0.99715, fpr: 0.00101, fnr: 0.01427, rec: 0.98572, prc: 0.99365, f1: 0.98967, f1_macro: 0.99401
# epoch: 19, passed number of graphs: 192, train running loss: 0.00510 (passed time: 40m 23s)
#           acc: 0.99690, fpr: 0.00110, fnr: 0.01540, rec: 0.98460, prc: 0.99314, f1: 0.98885, f1_macro: 0.99353
# epoch: 19, passed number of graphs: 288, train running loss: 0.00507 (passed time: 40m 37s)
#           acc: 0.99713, fpr: 0.00091, fnr: 0.01510, rec: 0.98490, prc: 0.99430, f1: 0.98958, f1_macro: 0.99395
# epoch: 19, passed number of graphs: 384, train running loss: 0.00507 (passed time: 40m 51s)
#           acc: 0.99671, fpr: 0.00129, fnr: 0.01540, rec: 0.98460, prc: 0.99214, f1: 0.98836, f1_macro: 0.99322
# epoch: 19, passed number of graphs: 480, train running loss: 0.00506 (passed time: 41m 5s)
#           acc: 0.99733, fpr: 0.00074, fnr: 0.01443, rec: 0.98557, prc: 0.99548, f1: 0.99050, f1_macro: 0.99447
# epoch: 19, passed number of graphs: 576, train running loss: 0.00505 (passed time: 41m 19s)
#           acc: 0.99692, fpr: 0.00100, fnr: 0.01600, rec: 0.98400, prc: 0.99369, f1: 0.98882, f1_macro: 0.99352
# epoch: 19, passed number of graphs: 672, train running loss: 0.00504 (passed time: 41m 33s)
#           acc: 0.99715, fpr: 0.00097, fnr: 0.01452, rec: 0.98547, prc: 0.99390, f1: 0.98967, f1_macro: 0.99401
# epoch: 19, passed number of graphs: 768, train running loss: 0.00504 (passed time: 41m 48s)
#           acc: 0.99707, fpr: 0.00107, fnr: 0.01443, rec: 0.98557, prc: 0.99327, f1: 0.98941, f1_macro: 0.99386
# Validation --- epoch: 19, loss: 0.00654
#           rec: 0.98404, fpr: 0.00056, prc: 0.99247, acc: 0.99837, f1: 0.98823, fnr: 0.01596, f1_macro: 0.99368
# epoch: 20, passed number of graphs: 96, train running loss: 0.00496 (passed time: 42m 22s)
#           acc: 0.99726, fpr: 0.00097, fnr: 0.01378, rec: 0.98623, prc: 0.99390, f1: 0.99005, f1_macro: 0.99423
# epoch: 20, passed number of graphs: 192, train running loss: 0.00496 (passed time: 42m 36s)
#           acc: 0.99695, fpr: 0.00107, fnr: 0.01523, rec: 0.98477, prc: 0.99334, f1: 0.98904, f1_macro: 0.99364
# epoch: 20, passed number of graphs: 288, train running loss: 0.00495 (passed time: 42m 50s)
#           acc: 0.99716, fpr: 0.00090, fnr: 0.01490, rec: 0.98510, prc: 0.99435, f1: 0.98970, f1_macro: 0.99403
# epoch: 20, passed number of graphs: 384, train running loss: 0.00496 (passed time: 43m 4s)
#           acc: 0.99678, fpr: 0.00123, fnr: 0.01528, rec: 0.98472, prc: 0.99252, f1: 0.98861, f1_macro: 0.99336
# epoch: 20, passed number of graphs: 480, train running loss: 0.00495 (passed time: 43m 18s)
#           acc: 0.99735, fpr: 0.00071, fnr: 0.01443, rec: 0.98557, prc: 0.99566, f1: 0.99059, f1_macro: 0.99453
# epoch: 20, passed number of graphs: 576, train running loss: 0.00494 (passed time: 43m 32s)
#           acc: 0.99697, fpr: 0.00103, fnr: 0.01555, rec: 0.98445, prc: 0.99354, f1: 0.98897, f1_macro: 0.99361
# epoch: 20, passed number of graphs: 672, train running loss: 0.00494 (passed time: 43m 46s)
#           acc: 0.99711, fpr: 0.00104, fnr: 0.01438, rec: 0.98562, prc: 0.99347, f1: 0.98953, f1_macro: 0.99393
# epoch: 20, passed number of graphs: 768, train running loss: 0.00494 (passed time: 44m 0s)
#           acc: 0.99709, fpr: 0.00108, fnr: 0.01430, rec: 0.98570, prc: 0.99325, f1: 0.98946, f1_macro: 0.99389
# Validation --- epoch: 20, loss: 0.00648
#           rec: 0.98413, fpr: 0.00056, prc: 0.99251, acc: 0.99838, f1: 0.98830, fnr: 0.01587, f1_macro: 0.99371
# epoch: 21, passed number of graphs: 96, train running loss: 0.00492 (passed time: 44m 35s)
#           acc: 0.99728, fpr: 0.00095, fnr: 0.01372, rec: 0.98628, prc: 0.99405, f1: 0.99015, f1_macro: 0.99429
# epoch: 21, passed number of graphs: 192, train running loss: 0.00492 (passed time: 44m 49s)
#           acc: 0.99696, fpr: 0.00107, fnr: 0.01517, rec: 0.98482, prc: 0.99337, f1: 0.98908, f1_macro: 0.99366
# epoch: 21, passed number of graphs: 288, train running loss: 0.00491 (passed time: 45m 3s)
#           acc: 0.99720, fpr: 0.00088, fnr: 0.01477, rec: 0.98523, prc: 0.99447, f1: 0.98983, f1_macro: 0.99410
# epoch: 21, passed number of graphs: 384, train running loss: 0.00493 (passed time: 45m 17s)
#           acc: 0.99679, fpr: 0.00121, fnr: 0.01530, rec: 0.98470, prc: 0.99264, f1: 0.98865, f1_macro: 0.99339
# epoch: 21, passed number of graphs: 480, train running loss: 0.00492 (passed time: 45m 31s)
#           acc: 0.99736, fpr: 0.00071, fnr: 0.01435, rec: 0.98565, prc: 0.99566, f1: 0.99063, f1_macro: 0.99455
# epoch: 21, passed number of graphs: 576, train running loss: 0.00491 (passed time: 45m 45s)
#           acc: 0.99697, fpr: 0.00101, fnr: 0.01558, rec: 0.98442, prc: 0.99362, f1: 0.98900, f1_macro: 0.99362
# epoch: 21, passed number of graphs: 672, train running loss: 0.00491 (passed time: 45m 59s)
#           acc: 0.99716, fpr: 0.00100, fnr: 0.01427, rec: 0.98572, prc: 0.99370, f1: 0.98970, f1_macro: 0.99402
# epoch: 21, passed number of graphs: 768, train running loss: 0.00491 (passed time: 46m 13s)
#           acc: 0.99710, fpr: 0.00107, fnr: 0.01422, rec: 0.98577, prc: 0.99327, f1: 0.98951, f1_macro: 0.99391
# Validation --- epoch: 21, loss: 0.00643
#           rec: 0.98410, fpr: 0.00054, prc: 0.99268, acc: 0.99839, f1: 0.98837, fnr: 0.01590, f1_macro: 0.99375
# epoch: 22, passed number of graphs: 96, train running loss: 0.00488 (passed time: 46m 48s)
#           acc: 0.99729, fpr: 0.00096, fnr: 0.01362, rec: 0.98638, prc: 0.99398, f1: 0.99016, f1_macro: 0.99429
# epoch: 22, passed number of graphs: 192, train running loss: 0.00489 (passed time: 47m 2s)
#           acc: 0.99699, fpr: 0.00105, fnr: 0.01510, rec: 0.98490, prc: 0.99347, f1: 0.98917, f1_macro: 0.99371
# epoch: 22, passed number of graphs: 288, train running loss: 0.00488 (passed time: 47m 16s)
#           acc: 0.99722, fpr: 0.00087, fnr: 0.01468, rec: 0.98533, prc: 0.99455, f1: 0.98992, f1_macro: 0.99415
# epoch: 22, passed number of graphs: 384, train running loss: 0.00489 (passed time: 47m 30s)
#           acc: 0.99679, fpr: 0.00122, fnr: 0.01525, rec: 0.98475, prc: 0.99257, f1: 0.98864, f1_macro: 0.99339
# epoch: 22, passed number of graphs: 480, train running loss: 0.00488 (passed time: 47m 44s)
#           acc: 0.99735, fpr: 0.00074, fnr: 0.01430, rec: 0.98570, prc: 0.99548, f1: 0.99057, f1_macro: 0.99451
# epoch: 22, passed number of graphs: 576, train running loss: 0.00488 (passed time: 47m 58s)
#           acc: 0.99698, fpr: 0.00102, fnr: 0.01547, rec: 0.98452, prc: 0.99357, f1: 0.98903, f1_macro: 0.99364
# epoch: 22, passed number of graphs: 672, train running loss: 0.00487 (passed time: 48m 12s)
#           acc: 0.99718, fpr: 0.00095, fnr: 0.01445, rec: 0.98555, prc: 0.99405, f1: 0.98978, f1_macro: 0.99407
# epoch: 22, passed number of graphs: 768, train running loss: 0.00487 (passed time: 48m 26s)
#           acc: 0.99711, fpr: 0.00107, fnr: 0.01422, rec: 0.98577, prc: 0.99332, f1: 0.98954, f1_macro: 0.99393
# Validation --- epoch: 22, loss: 0.00643
#           rec: 0.98411, fpr: 0.00054, prc: 0.99265, acc: 0.99839, f1: 0.98836, fnr: 0.01589, f1_macro: 0.99375
# epoch: 23, passed number of graphs: 96, train running loss: 0.00487 (passed time: 49m 2s)
#           acc: 0.99727, fpr: 0.00098, fnr: 0.01365, rec: 0.98635, prc: 0.99388, f1: 0.99010, f1_macro: 0.99426
# epoch: 23, passed number of graphs: 192, train running loss: 0.00488 (passed time: 49m 16s)
#           acc: 0.99697, fpr: 0.00107, fnr: 0.01510, rec: 0.98490, prc: 0.99337, f1: 0.98912, f1_macro: 0.99368
# epoch: 23, passed number of graphs: 288, train running loss: 0.00487 (passed time: 49m 31s)
#           acc: 0.99724, fpr: 0.00086, fnr: 0.01463, rec: 0.98538, prc: 0.99463, f1: 0.98998, f1_macro: 0.99419
# epoch: 23, passed number of graphs: 384, train running loss: 0.00488 (passed time: 49m 45s)
#           acc: 0.99679, fpr: 0.00122, fnr: 0.01528, rec: 0.98472, prc: 0.99259, f1: 0.98864, f1_macro: 0.99339
# epoch: 23, passed number of graphs: 480, train running loss: 0.00487 (passed time: 49m 59s)
#           acc: 0.99734, fpr: 0.00074, fnr: 0.01430, rec: 0.98570, prc: 0.99546, f1: 0.99055, f1_macro: 0.99450
# epoch: 23, passed number of graphs: 576, train running loss: 0.00487 (passed time: 50m 13s)
#           acc: 0.99699, fpr: 0.00101, fnr: 0.01545, rec: 0.98455, prc: 0.99362, f1: 0.98906, f1_macro: 0.99366
# epoch: 23, passed number of graphs: 672, train running loss: 0.00487 (passed time: 50m 27s)
#           acc: 0.99719, fpr: 0.00094, fnr: 0.01445, rec: 0.98555, prc: 0.99410, f1: 0.98981, f1_macro: 0.99409
# epoch: 23, passed number of graphs: 768, train running loss: 0.00487 (passed time: 50m 41s)
#           acc: 0.99711, fpr: 0.00106, fnr: 0.01422, rec: 0.98577, prc: 0.99335, f1: 0.98955, f1_macro: 0.99394
# Validation --- epoch: 23, loss: 0.00643
#           rec: 0.98413, fpr: 0.00054, prc: 0.99266, acc: 0.99839, f1: 0.98837, fnr: 0.01587, f1_macro: 0.99375
# epoch: 24, passed number of graphs: 96, train running loss: 0.00486 (passed time: 51m 14s)
#           acc: 0.99727, fpr: 0.00097, fnr: 0.01370, rec: 0.98630, prc: 0.99393, f1: 0.99010, f1_macro: 0.99426
# epoch: 24, passed number of graphs: 192, train running loss: 0.00487 (passed time: 51m 28s)
#           acc: 0.99699, fpr: 0.00105, fnr: 0.01510, rec: 0.98490, prc: 0.99347, f1: 0.98917, f1_macro: 0.99371
# epoch: 24, passed number of graphs: 288, train running loss: 0.00486 (passed time: 51m 42s)
#           acc: 0.99723, fpr: 0.00086, fnr: 0.01465, rec: 0.98535, prc: 0.99457, f1: 0.98994, f1_macro: 0.99417
# epoch: 24, passed number of graphs: 384, train running loss: 0.00487 (passed time: 51m 57s)
#           acc: 0.99680, fpr: 0.00120, fnr: 0.01530, rec: 0.98470, prc: 0.99267, f1: 0.98867, f1_macro: 0.99340
# epoch: 24, passed number of graphs: 480, train running loss: 0.00486 (passed time: 52m 11s)
#           acc: 0.99735, fpr: 0.00074, fnr: 0.01427, rec: 0.98572, prc: 0.99546, f1: 0.99057, f1_macro: 0.99451
# epoch: 24, passed number of graphs: 576, train running loss: 0.00486 (passed time: 52m 25s)
#           acc: 0.99699, fpr: 0.00101, fnr: 0.01547, rec: 0.98452, prc: 0.99367, f1: 0.98907, f1_macro: 0.99367
# epoch: 24, passed number of graphs: 672, train running loss: 0.00486 (passed time: 52m 39s)
#           acc: 0.99718, fpr: 0.00096, fnr: 0.01443, rec: 0.98557, prc: 0.99397, f1: 0.98976, f1_macro: 0.99406
# epoch: 24, passed number of graphs: 768, train running loss: 0.00486 (passed time: 52m 53s)
#           acc: 0.99711, fpr: 0.00106, fnr: 0.01425, rec: 0.98575, prc: 0.99335, f1: 0.98953, f1_macro: 0.99393
# Validation --- epoch: 24, loss: 0.00642
#           rec: 0.98414, fpr: 0.00054, prc: 0.99267, acc: 0.99839, f1: 0.98839, fnr: 0.01586, f1_macro: 0.99376
# epoch: 25, passed number of graphs: 96, train running loss: 0.00486 (passed time: 53m 26s)
#           acc: 0.99728, fpr: 0.00096, fnr: 0.01370, rec: 0.98630, prc: 0.99400, f1: 0.99014, f1_macro: 0.99428
# epoch: 25, passed number of graphs: 192, train running loss: 0.00486 (passed time: 53m 40s)
#           acc: 0.99699, fpr: 0.00105, fnr: 0.01512, rec: 0.98487, prc: 0.99349, f1: 0.98917, f1_macro: 0.99371
# epoch: 25, passed number of graphs: 288, train running loss: 0.00486 (passed time: 53m 55s)
#           acc: 0.99723, fpr: 0.00086, fnr: 0.01463, rec: 0.98538, prc: 0.99460, f1: 0.98997, f1_macro: 0.99418
# ...
#           acc: 0.99723, fpr: 0.00086, fnr: 0.01463, rec: 0.98538, prc: 0.99460, f1: 0.98997, f1_macro: 0.99418
# epoch: 42, passed number of graphs: 384, train running loss: 0.00487 (passed time: 1h 31m 44s)
#           acc: 0.99680, fpr: 0.00120, fnr: 0.01533, rec: 0.98467, prc: 0.99269, f1: 0.98867, f1_macro: 0.99340
# epoch: 42, passed number of graphs: 480, train running loss: 0.00486 (passed time: 1h 31m 58s)
#           acc: 0.99735, fpr: 0.00074, fnr: 0.01427, rec: 0.98572, prc: 0.99548, f1: 0.99058, f1_macro: 0.99452
# epoch: 42, passed number of graphs: 576, train running loss: 0.00485 (passed time: 1h 32m 12s)
#           acc: 0.99700, fpr: 0.00100, fnr: 0.01545, rec: 0.98455, prc: 0.99372, f1: 0.98911, f1_macro: 0.99369
# epoch: 42, passed number of graphs: 672, train running loss: 0.00485 (passed time: 1h 32m 26s)
#           acc: 0.99717, fpr: 0.00097, fnr: 0.01438, rec: 0.98562, prc: 0.99390, f1: 0.98974, f1_macro: 0.99405
# epoch: 42, passed number of graphs: 768, train running loss: 0.00485 (passed time: 1h 32m 40s)
#           acc: 0.99711, fpr: 0.00106, fnr: 0.01422, rec: 0.98577, prc: 0.99335, f1: 0.98955, f1_macro: 0.99394
# Validation --- epoch: 42, loss: 0.00642
#           rec: 0.98414, fpr: 0.00054, prc: 0.99267, acc: 0.99839, f1: 0.98839, fnr: 0.01586, f1_macro: 0.99376
# epoch: 43, passed number of graphs: 96, train running loss: 0.00485 (passed time: 1h 33m 14s)
#           acc: 0.99729, fpr: 0.00096, fnr: 0.01362, rec: 0.98638, prc: 0.99400, f1: 0.99017, f1_macro: 0.99430
# epoch: 43, passed number of graphs: 192, train running loss: 0.00486 (passed time: 1h 33m 28s)
#           acc: 0.99701, fpr: 0.00102, fnr: 0.01517, rec: 0.98482, prc: 0.99367, f1: 0.98923, f1_macro: 0.99374
# epoch: 43, passed number of graphs: 288, train running loss: 0.00485 (passed time: 1h 33m 42s)
#           acc: 0.99723, fpr: 0.00086, fnr: 0.01463, rec: 0.98538, prc: 0.99460, f1: 0.98997, f1_macro: 0.99418
# epoch: 43, passed number of graphs: 384, train running loss: 0.00487 (passed time: 1h 33m 56s)
#           acc: 0.99680, fpr: 0.00120, fnr: 0.01533, rec: 0.98467, prc: 0.99269, f1: 0.98867, f1_macro: 0.99340
# epoch: 43, passed number of graphs: 480, train running loss: 0.00486 (passed time: 1h 34m 10s)
#           acc: 0.99735, fpr: 0.00074, fnr: 0.01427, rec: 0.98572, prc: 0.99548, f1: 0.99058, f1_macro: 0.99452
# epoch: 43, passed number of graphs: 576, train running loss: 0.00485 (passed time: 1h 34m 24s)
#           acc: 0.99700, fpr: 0.00100, fnr: 0.01545, rec: 0.98455, prc: 0.99372, f1: 0.98911, f1_macro: 0.99369
# epoch: 43, passed number of graphs: 672, train running loss: 0.00485 (passed time: 1h 34m 38s)
#           acc: 0.99717, fpr: 0.00097, fnr: 0.01438, rec: 0.98562, prc: 0.99390, f1: 0.98974, f1_macro: 0.99405
# epoch: 43, passed number of graphs: 768, train running loss: 0.00485 (passed time: 1h 34m 53s)
#           acc: 0.99711, fpr: 0.00106, fnr: 0.01422, rec: 0.98577, prc: 0.99335, f1: 0.98955, f1_macro: 0.99394
# Validation --- epoch: 43, loss: 0.00642
#           rec: 0.98414, fpr: 0.00054, prc: 0.99267, acc: 0.99839, f1: 0.98839, fnr: 0.01586, f1_macro: 0.99376
# epoch: 44, passed number of graphs: 96, train running loss: 0.00485 (passed time: 1h 35m 27s)
#           acc: 0.99729, fpr: 0.00096, fnr: 0.01362, rec: 0.98638, prc: 0.99400, f1: 0.99017, f1_macro: 0.99430
# epoch: 44, passed number of graphs: 192, train running loss: 0.00486 (passed time: 1h 35m 41s)
#           acc: 0.99701, fpr: 0.00102, fnr: 0.01517, rec: 0.98482, prc: 0.99367, f1: 0.98923, f1_macro: 0.99374
# epoch: 44, passed number of graphs: 288, train running loss: 0.00485 (passed time: 1h 35m 55s)
#           acc: 0.99723, fpr: 0.00086, fnr: 0.01463, rec: 0.98538, prc: 0.99460, f1: 0.98997, f1_macro: 0.99418
# epoch: 44, passed number of graphs: 384, train running loss: 0.00487 (passed time: 1h 36m 9s)
#           acc: 0.99680, fpr: 0.00120, fnr: 0.01533, rec: 0.98467, prc: 0.99269, f1: 0.98867, f1_macro: 0.99340
# epoch: 44, passed number of graphs: 480, train running loss: 0.00486 (passed time: 1h 36m 23s)
#           acc: 0.99735, fpr: 0.00074, fnr: 0.01427, rec: 0.98572, prc: 0.99548, f1: 0.99058, f1_macro: 0.99452
# epoch: 44, passed number of graphs: 576, train running loss: 0.00485 (passed time: 1h 36m 37s)
#           acc: 0.99700, fpr: 0.00100, fnr: 0.01545, rec: 0.98455, prc: 0.99372, f1: 0.98911, f1_macro: 0.99369
# epoch: 44, passed number of graphs: 672, train running loss: 0.00485 (passed time: 1h 36m 51s)
#           acc: 0.99717, fpr: 0.00097, fnr: 0.01438, rec: 0.98562, prc: 0.99390, f1: 0.98974, f1_macro: 0.99405
# epoch: 44, passed number of graphs: 768, train running loss: 0.00485 (passed time: 1h 37m 5s)
#           acc: 0.99711, fpr: 0.00106, fnr: 0.01422, rec: 0.98577, prc: 0.99335, f1: 0.98955, f1_macro: 0.99394
# Validation --- epoch: 44, loss: 0.00642
#           rec: 0.98414, fpr: 0.00054, prc: 0.99267, acc: 0.99839, f1: 0.98839, fnr: 0.01586, f1_macro: 0.99376
# epoch: 45, passed number of graphs: 96, train running loss: 0.00485 (passed time: 1h 37m 39s)
#           acc: 0.99729, fpr: 0.00096, fnr: 0.01362, rec: 0.98638, prc: 0.99400, f1: 0.99017, f1_macro: 0.99430
# epoch: 45, passed number of graphs: 192, train running loss: 0.00486 (passed time: 1h 37m 53s)
#           acc: 0.99701, fpr: 0.00102, fnr: 0.01517, rec: 0.98482, prc: 0.99367, f1: 0.98923, f1_macro: 0.99374
# epoch: 45, passed number of graphs: 288, train running loss: 0.00485 (passed time: 1h 38m 7s)
#           acc: 0.99723, fpr: 0.00086, fnr: 0.01463, rec: 0.98538, prc: 0.99460, f1: 0.98997, f1_macro: 0.99418
# epoch: 45, passed number of graphs: 384, train running loss: 0.00487 (passed time: 1h 38m 21s)
#           acc: 0.99680, fpr: 0.00120, fnr: 0.01533, rec: 0.98467, prc: 0.99269, f1: 0.98867, f1_macro: 0.99340
# epoch: 45, passed number of graphs: 480, train running loss: 0.00486 (passed time: 1h 38m 35s)
#           acc: 0.99735, fpr: 0.00074, fnr: 0.01427, rec: 0.98572, prc: 0.99548, f1: 0.99058, f1_macro: 0.99452
# epoch: 45, passed number of graphs: 576, train running loss: 0.00485 (passed time: 1h 38m 49s)
#           acc: 0.99700, fpr: 0.00100, fnr: 0.01545, rec: 0.98455, prc: 0.99372, f1: 0.98911, f1_macro: 0.99369
# epoch: 45, passed number of graphs: 672, train running loss: 0.00485 (passed time: 1h 39m 3s)
#           acc: 0.99717, fpr: 0.00097, fnr: 0.01438, rec: 0.98562, prc: 0.99390, f1: 0.98974, f1_macro: 0.99405
# epoch: 45, passed number of graphs: 768, train running loss: 0.00485 (passed time: 1h 39m 17s)
#           acc: 0.99711, fpr: 0.00106, fnr: 0.01422, rec: 0.98577, prc: 0.99335, f1: 0.98955, f1_macro: 0.99394
# Validation --- epoch: 45, loss: 0.00642
#           rec: 0.98414, fpr: 0.00054, prc: 0.99267, acc: 0.99839, f1: 0.98839, fnr: 0.01586, f1_macro: 0.99376
# epoch: 46, passed number of graphs: 96, train running loss: 0.00485 (passed time: 1h 39m 51s)
#           acc: 0.99729, fpr: 0.00096, fnr: 0.01362, rec: 0.98638, prc: 0.99400, f1: 0.99017, f1_macro: 0.99430
# epoch: 46, passed number of graphs: 192, train running loss: 0.00486 (passed time: 1h 40m 5s)
#           acc: 0.99701, fpr: 0.00102, fnr: 0.01517, rec: 0.98482, prc: 0.99367, f1: 0.98923, f1_macro: 0.99374
# epoch: 46, passed number of graphs: 288, train running loss: 0.00485 (passed time: 1h 40m 19s)
#           acc: 0.99723, fpr: 0.00086, fnr: 0.01463, rec: 0.98538, prc: 0.99460, f1: 0.98997, f1_macro: 0.99418
# epoch: 46, passed number of graphs: 384, train running loss: 0.00487 (passed time: 1h 40m 33s)
#           acc: 0.99680, fpr: 0.00120, fnr: 0.01533, rec: 0.98467, prc: 0.99269, f1: 0.98867, f1_macro: 0.99340
# epoch: 46, passed number of graphs: 480, train running loss: 0.00486 (passed time: 1h 40m 47s)
#           acc: 0.99735, fpr: 0.00074, fnr: 0.01427, rec: 0.98572, prc: 0.99548, f1: 0.99058, f1_macro: 0.99452
# epoch: 46, passed number of graphs: 576, train running loss: 0.00485 (passed time: 1h 41m 1s)
#           acc: 0.99700, fpr: 0.00100, fnr: 0.01545, rec: 0.98455, prc: 0.99372, f1: 0.98911, f1_macro: 0.99369
# epoch: 46, passed number of graphs: 672, train running loss: 0.00485 (passed time: 1h 41m 15s)
#           acc: 0.99717, fpr: 0.00097, fnr: 0.01438, rec: 0.98562, prc: 0.99390, f1: 0.98974, f1_macro: 0.99405
# epoch: 46, passed number of graphs: 768, train running loss: 0.00485 (passed time: 1h 41m 29s)
#           acc: 0.99711, fpr: 0.00106, fnr: 0.01422, rec: 0.98577, prc: 0.99335, f1: 0.98955, f1_macro: 0.99394
# Validation --- epoch: 46, loss: 0.00642
#           rec: 0.98414, fpr: 0.00054, prc: 0.99267, acc: 0.99839, f1: 0.98839, fnr: 0.01586, f1_macro: 0.99376
# epoch: 47, passed number of graphs: 96, train running loss: 0.00485 (passed time: 1h 42m 3s)
#           acc: 0.99729, fpr: 0.00096, fnr: 0.01362, rec: 0.98638, prc: 0.99400, f1: 0.99017, f1_macro: 0.99430
# epoch: 47, passed number of graphs: 192, train running loss: 0.00486 (passed time: 1h 42m 17s)
#           acc: 0.99701, fpr: 0.00102, fnr: 0.01517, rec: 0.98482, prc: 0.99367, f1: 0.98923, f1_macro: 0.99374
# epoch: 47, passed number of graphs: 288, train running loss: 0.00485 (passed time: 1h 42m 32s)
#           acc: 0.99723, fpr: 0.00086, fnr: 0.01463, rec: 0.98538, prc: 0.99460, f1: 0.98997, f1_macro: 0.99418
# epoch: 47, passed number of graphs: 384, train running loss: 0.00486 (passed time: 1h 42m 46s)
#           acc: 0.99680, fpr: 0.00120, fnr: 0.01533, rec: 0.98467, prc: 0.99269, f1: 0.98867, f1_macro: 0.99340
# epoch: 47, passed number of graphs: 480, train running loss: 0.00486 (passed time: 1h 43m 0s)
#           acc: 0.99735, fpr: 0.00074, fnr: 0.01427, rec: 0.98572, prc: 0.99548, f1: 0.99058, f1_macro: 0.99452
# epoch: 47, passed number of graphs: 576, train running loss: 0.00485 (passed time: 1h 43m 14s)
#           acc: 0.99700, fpr: 0.00100, fnr: 0.01545, rec: 0.98455, prc: 0.99372, f1: 0.98911, f1_macro: 0.99369
# epoch: 47, passed number of graphs: 672, train running loss: 0.00485 (passed time: 1h 43m 28s)
#           acc: 0.99717, fpr: 0.00097, fnr: 0.01438, rec: 0.98562, prc: 0.99390, f1: 0.98974, f1_macro: 0.99405
# epoch: 47, passed number of graphs: 768, train running loss: 0.00485 (passed time: 1h 43m 42s)
#           acc: 0.99711, fpr: 0.00106, fnr: 0.01422, rec: 0.98577, prc: 0.99335, f1: 0.98955, f1_macro: 0.99394
# Validation --- epoch: 47, loss: 0.00642
#           rec: 0.98414, fpr: 0.00054, prc: 0.99267, acc: 0.99839, f1: 0.98839, fnr: 0.01586, f1_macro: 0.99376
# epoch: 48, passed number of graphs: 96, train running loss: 0.00485 (passed time: 1h 44m 15s)
#           acc: 0.99729, fpr: 0.00096, fnr: 0.01362, rec: 0.98638, prc: 0.99400, f1: 0.99017, f1_macro: 0.99430
# epoch: 48, passed number of graphs: 192, train running loss: 0.00486 (passed time: 1h 44m 30s)
#           acc: 0.99701, fpr: 0.00102, fnr: 0.01517, rec: 0.98482, prc: 0.99367, f1: 0.98923, f1_macro: 0.99374
# epoch: 48, passed number of graphs: 288, train running loss: 0.00485 (passed time: 1h 44m 44s)
#           acc: 0.99723, fpr: 0.00086, fnr: 0.01463, rec: 0.98538, prc: 0.99460, f1: 0.98997, f1_macro: 0.99418
# epoch: 48, passed number of graphs: 384, train running loss: 0.00486 (passed time: 1h 44m 58s)
#           acc: 0.99680, fpr: 0.00120, fnr: 0.01533, rec: 0.98467, prc: 0.99269, f1: 0.98867, f1_macro: 0.99340
# epoch: 48, passed number of graphs: 480, train running loss: 0.00486 (passed time: 1h 45m 12s)
#           acc: 0.99735, fpr: 0.00074, fnr: 0.01427, rec: 0.98572, prc: 0.99548, f1: 0.99058, f1_macro: 0.99452
# epoch: 48, passed number of graphs: 576, train running loss: 0.00485 (passed time: 1h 45m 26s)
#           acc: 0.99700, fpr: 0.00100, fnr: 0.01545, rec: 0.98455, prc: 0.99372, f1: 0.98911, f1_macro: 0.99369
# epoch: 48, passed number of graphs: 672, train running loss: 0.00485 (passed time: 1h 45m 40s)
#           acc: 0.99717, fpr: 0.00097, fnr: 0.01438, rec: 0.98562, prc: 0.99390, f1: 0.98974, f1_macro: 0.99405
# epoch: 48, passed number of graphs: 768, train running loss: 0.00485 (passed time: 1h 45m 54s)
#           acc: 0.99711, fpr: 0.00106, fnr: 0.01422, rec: 0.98577, prc: 0.99335, f1: 0.98955, f1_macro: 0.99394
# Validation --- epoch: 48, loss: 0.00642
#           rec: 0.98414, fpr: 0.00054, prc: 0.99267, acc: 0.99839, f1: 0.98839, fnr: 0.01586, f1_macro: 0.99376
# epoch: 49, passed number of graphs: 96, train running loss: 0.00485 (passed time: 1h 46m 28s)
#           acc: 0.99729, fpr: 0.00096, fnr: 0.01362, rec: 0.98638, prc: 0.99400, f1: 0.99017, f1_macro: 0.99430
# epoch: 49, passed number of graphs: 192, train running loss: 0.00486 (passed time: 1h 46m 42s)
#           acc: 0.99701, fpr: 0.00102, fnr: 0.01517, rec: 0.98482, prc: 0.99367, f1: 0.98923, f1_macro: 0.99374
# epoch: 49, passed number of graphs: 288, train running loss: 0.00485 (passed time: 1h 46m 56s)
#           acc: 0.99723, fpr: 0.00086, fnr: 0.01463, rec: 0.98538, prc: 0.99460, f1: 0.98997, f1_macro: 0.99418
# epoch: 49, passed number of graphs: 384, train running loss: 0.00486 (passed time: 1h 47m 10s)
#           acc: 0.99680, fpr: 0.00120, fnr: 0.01533, rec: 0.98467, prc: 0.99269, f1: 0.98867, f1_macro: 0.99340
# epoch: 49, passed number of graphs: 480, train running loss: 0.00486 (passed time: 1h 47m 24s)
#           acc: 0.99735, fpr: 0.00074, fnr: 0.01427, rec: 0.98572, prc: 0.99548, f1: 0.99058, f1_macro: 0.99452
# epoch: 49, passed number of graphs: 576, train running loss: 0.00485 (passed time: 1h 47m 38s)
#           acc: 0.99700, fpr: 0.00100, fnr: 0.01545, rec: 0.98455, prc: 0.99372, f1: 0.98911, f1_macro: 0.99369
# epoch: 49, passed number of graphs: 672, train running loss: 0.00485 (passed time: 1h 47m 52s)
#           acc: 0.99717, fpr: 0.00097, fnr: 0.01438, rec: 0.98562, prc: 0.99390, f1: 0.98974, f1_macro: 0.99405
# epoch: 49, passed number of graphs: 768, train running loss: 0.00485 (passed time: 1h 48m 6s)
#           acc: 0.99711, fpr: 0.00106, fnr: 0.01422, rec: 0.98577, prc: 0.99335, f1: 0.98955, f1_macro: 0.99394
# Validation --- epoch: 49, loss: 0.00642
#           rec: 0.98414, fpr: 0.00054, prc: 0.99267, acc: 0.99839, f1: 0.98839, fnr: 0.01586, f1_macro: 0.99376
# epoch: 50, passed number of graphs: 96, train running loss: 0.00485 (passed time: 1h 48m 40s)
#           acc: 0.99729, fpr: 0.00096, fnr: 0.01362, rec: 0.98638, prc: 0.99400, f1: 0.99017, f1_macro: 0.99430
# epoch: 50, passed number of graphs: 192, train running loss: 0.00486 (passed time: 1h 48m 54s)
#           acc: 0.99701, fpr: 0.00102, fnr: 0.01517, rec: 0.98482, prc: 0.99367, f1: 0.98923, f1_macro: 0.99374
# epoch: 50, passed number of graphs: 288, train running loss: 0.00485 (passed time: 1h 49m 8s)
#           acc: 0.99723, fpr: 0.00086, fnr: 0.01463, rec: 0.98538, prc: 0.99460, f1: 0.98997, f1_macro: 0.99418
# epoch: 50, passed number of graphs: 384, train running loss: 0.00486 (passed time: 1h 49m 22s)
#           acc: 0.99680, fpr: 0.00120, fnr: 0.01533, rec: 0.98467, prc: 0.99269, f1: 0.98867, f1_macro: 0.99340
# epoch: 50, passed number of graphs: 480, train running loss: 0.00486 (passed time: 1h 49m 36s)
#           acc: 0.99735, fpr: 0.00074, fnr: 0.01427, rec: 0.98572, prc: 0.99548, f1: 0.99058, f1_macro: 0.99452
# epoch: 50, passed number of graphs: 576, train running loss: 0.00485 (passed time: 1h 49m 50s)
#           acc: 0.99700, fpr: 0.00100, fnr: 0.01545, rec: 0.98455, prc: 0.99372, f1: 0.98911, f1_macro: 0.99369
# epoch: 50, passed number of graphs: 672, train running loss: 0.00485 (passed time: 1h 50m 4s)
#           acc: 0.99717, fpr: 0.00097, fnr: 0.01438, rec: 0.98562, prc: 0.99390, f1: 0.98974, f1_macro: 0.99405
# epoch: 50, passed number of graphs: 768, train running loss: 0.00485 (passed time: 1h 50m 18s)
#           acc: 0.99711, fpr: 0.00106, fnr: 0.01422, rec: 0.98577, prc: 0.99335, f1: 0.98955, f1_macro: 0.99394
# Validation --- epoch: 50, loss: 0.00642
#           rec: 0.98414, fpr: 0.00054, prc: 0.99267, acc: 0.99839, f1: 0.98839, fnr: 0.01586, f1_macro: 0.99376
# ************ best model obtained after epoch 13, saved at ./saved_models/GIN_12_0.9899076448823384.pt ************
# Testing --- loss: 0.00619
#           rec: 0.98458, fpr: 0.00034, prc: 0.99543, acc: 0.99862, f1: 0.98998, fnr: 0.01542, f1_macro: 0.99462

# %%
# !zip -r /content/GIN_Adam_Kadem_20k_bots.zip /content/saved_models
# Out:
#   adding: content/saved_models/ (stored 0%)
#   adding: content/saved_models/GIN_8_0.9865107936595079.pt (deflated 29%)
#   adding: content/saved_models/GIN_4_0.9812359281220716.pt (deflated 28%)
#   adding: content/saved_models/GIN_1_0.9685641547471825.pt (deflated 30%)
#   adding: content/saved_models/GIN_2_0.9784236236482885.pt (deflated 29%)
#   adding: content/saved_models/GIN_9_0.9888489251910592.pt (deflated 29%)
#   adding: content/saved_models/GIN_0_0.9576587290230897.pt (deflated 30%)
#   adding: content/saved_models/GIN_5_0.9816899525132851.pt (deflated 28%)
#   adding: content/saved_models/GIN_11_0.9888924952526991.pt (deflated 30%)
#   adding: content/saved_models/GIN_12_0.9899076448823384.pt (deflated 30%)
#   adding: content/saved_models/GIN_7_0.9853849018986337.pt (deflated 29%)

# %%
from google.colab import files
files.download("/content/GIN_Adam_Kadem_20k_bots.zip")
