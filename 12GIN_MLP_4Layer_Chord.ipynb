# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/Do_an_tot_nghiep/blob/main/12GIN_MLP_4Layer_Chord.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric==1.4.3
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter_
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric==1.4.3 in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (6.2.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.6.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.23.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.18.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.7.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.12.1+cu113)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.56.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.7.3)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.21.6)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->torch-geometric==1.4.3) (1.5.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (4.13.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (0.39.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (4.1.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.4.3) (1.15.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (0.6.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2.10)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (3.2.2)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2021.11.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2.9.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (1.3.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (7.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (0.11.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
        elif split == 'val':
            self.path = self.processed_paths[1]
        elif split == 'test':
            self.path = self.processed_paths[2]

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
            self.num_graphs = self.data['num_graphs']
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            with h5py.File(self.path, 'r') as f:
                self.num_graphs = f.attrs['num_graphs']
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GINConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_input_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), 
                             BatchNorm1d(self.dim_hidden_feature), ReLU())))
          else:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), 
                             BatchNorm1d(self.dim_hidden_feature), ReLU()))) 

        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                add_xr_at = n
            if n == add_xr_at:
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/Chord'
data_name = 'chord' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=True, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 2
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.2
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-e24d5b24-1d69-4ee7-9cdb-e232662dd57d.json
# ------------------------------
# ------------------------------
# Mon Nov  7 14:34:58 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GINConv(nn=Sequential(
#       (0): Linear(in_features=1, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (1): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (2): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (3): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (4): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (5): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (6): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (7): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (8): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (9): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (10): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (11): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 2
# epoch: 1, passed number of graphs: 96, train running loss: 0.13076 (passed time: 21s)
#           acc: 0.93811, fpr: 0.00208, fnr: 0.86620, rec: 0.13380, prc: 0.82695, f1: 0.23033, f1_macro: 0.59905
# epoch: 1, passed number of graphs: 192, train running loss: 0.09709 (passed time: 42s)
#           acc: 0.97471, fpr: 0.00345, fnr: 0.31640, rec: 0.68360, prc: 0.93695, f1: 0.79047, f1_macro: 0.88851
# epoch: 1, passed number of graphs: 288, train running loss: 0.07602 (passed time: 1m 3s)
#           acc: 0.98601, fpr: 0.00209, fnr: 0.17390, rec: 0.82610, prc: 0.96710, f1: 0.89106, f1_macro: 0.94179
# epoch: 1, passed number of graphs: 384, train running loss: 0.06260 (passed time: 1m 24s)
#           acc: 0.98905, fpr: 0.00291, fnr: 0.11620, rec: 0.88380, prc: 0.95867, f1: 0.91971, f1_macro: 0.95692
# epoch: 1, passed number of graphs: 480, train running loss: 0.05287 (passed time: 1m 45s)
#           acc: 0.99260, fpr: 0.00370, fnr: 0.05600, rec: 0.94400, prc: 0.95099, f1: 0.94748, f1_macro: 0.97175
# epoch: 1, passed number of graphs: 576, train running loss: 0.04562 (passed time: 2m 6s)
#           acc: 0.99671, fpr: 0.00159, fnr: 0.02630, rec: 0.97370, prc: 0.97854, f1: 0.97612, f1_macro: 0.98717
# epoch: 1, passed number of graphs: 672, train running loss: 0.03998 (passed time: 2m 27s)
#           acc: 0.99468, fpr: 0.00337, fnr: 0.03155, rec: 0.96845, prc: 0.95531, f1: 0.96184, f1_macro: 0.97949
# epoch: 1, passed number of graphs: 768, train running loss: 0.03865 (passed time: 2m 48s)
#           acc: 0.99355, fpr: 0.00258, fnr: 0.05845, rec: 0.94155, prc: 0.96455, f1: 0.95291, f1_macro: 0.97473
# Validation --- epoch: 1, loss: 0.07183
#           f1_macro: 0.92800, f1: 0.86694, fnr: 0.05582, rec: 0.94418, prc: 0.80210, acc: 0.97978, fpr: 0.01755
# Better model saved at ./saved_models/GIN_0: 0.8669372092927038.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.00874 (passed time: 3m 29s)
#           acc: 0.99484, fpr: 0.00218, fnr: 0.04525, rec: 0.95475, prc: 0.97018, f1: 0.96240, f1_macro: 0.97981
# epoch: 2, passed number of graphs: 192, train running loss: 0.00760 (passed time: 3m 50s)
#           acc: 0.99769, fpr: 0.00077, fnr: 0.02290, rec: 0.97710, prc: 0.98962, f1: 0.98332, f1_macro: 0.99104
# epoch: 2, passed number of graphs: 288, train running loss: 0.01404 (passed time: 4m 11s)
#           acc: 0.98623, fpr: 0.00612, fnr: 0.11670, rec: 0.88330, prc: 0.91486, f1: 0.89880, f1_macro: 0.94571
# epoch: 2, passed number of graphs: 384, train running loss: 0.01339 (passed time: 4m 32s)
#           acc: 0.99569, fpr: 0.00168, fnr: 0.03870, rec: 0.96130, prc: 0.97758, f1: 0.96937, f1_macro: 0.98353
# epoch: 2, passed number of graphs: 480, train running loss: 0.01177 (passed time: 4m 53s)
#           acc: 0.99797, fpr: 0.00052, fnr: 0.02195, rec: 0.97805, prc: 0.99310, f1: 0.98552, f1_macro: 0.99221
# epoch: 2, passed number of graphs: 576, train running loss: 0.01061 (passed time: 5m 14s)
#           acc: 0.99789, fpr: 0.00081, fnr: 0.01970, rec: 0.98030, prc: 0.98905, f1: 0.98466, f1_macro: 0.99176
# epoch: 2, passed number of graphs: 672, train running loss: 0.00963 (passed time: 5m 35s)
#           acc: 0.99820, fpr: 0.00064, fnr: 0.01740, rec: 0.98260, prc: 0.99127, f1: 0.98692, f1_macro: 0.99297
# epoch: 2, passed number of graphs: 768, train running loss: 0.00883 (passed time: 5m 56s)
#           acc: 0.99847, fpr: 0.00057, fnr: 0.01435, rec: 0.98565, prc: 0.99225, f1: 0.98894, f1_macro: 0.99406
# Validation --- epoch: 2, loss: 0.00691
#           f1_macro: 0.99375, f1: 0.98837, fnr: 0.01921, rec: 0.98079, prc: 0.99607, acc: 0.99839, fpr: 0.00029
# Better model saved at ./saved_models/GIN_1: 0.988369938296234.pt.
# epoch: 3, passed number of graphs: 96, train running loss: 0.00401 (passed time: 6m 37s)
#           acc: 0.99455, fpr: 0.00102, fnr: 0.06505, rec: 0.93495, prc: 0.98556, f1: 0.95959, f1_macro: 0.97833
# epoch: 3, passed number of graphs: 192, train running loss: 0.00561 (passed time: 6m 58s)
#           acc: 0.99579, fpr: 0.00097, fnr: 0.04745, rec: 0.95255, prc: 0.98664, f1: 0.96929, f1_macro: 0.98352
# epoch: 3, passed number of graphs: 288, train running loss: 0.00785 (passed time: 7m 19s)
#           acc: 0.99520, fpr: 0.00155, fnr: 0.04845, rec: 0.95155, prc: 0.97856, f1: 0.96487, f1_macro: 0.98114
# epoch: 3, passed number of graphs: 384, train running loss: 0.00702 (passed time: 7m 40s)
#           acc: 0.99824, fpr: 0.00058, fnr: 0.01725, rec: 0.98275, prc: 0.99233, f1: 0.98751, f1_macro: 0.99328
# epoch: 3, passed number of graphs: 480, train running loss: 0.00613 (passed time: 8m 1s)
#           acc: 0.99889, fpr: 0.00019, fnr: 0.01320, rec: 0.98680, prc: 0.99747, f1: 0.99211, f1_macro: 0.99576
# epoch: 3, passed number of graphs: 576, train running loss: 0.00553 (passed time: 8m 22s)
#           acc: 0.99889, fpr: 0.00025, fnr: 0.01270, rec: 0.98730, prc: 0.99662, f1: 0.99194, f1_macro: 0.99567
# epoch: 3, passed number of graphs: 672, train running loss: 0.00506 (passed time: 8m 43s)
#           acc: 0.99884, fpr: 0.00028, fnr: 0.01290, rec: 0.98710, prc: 0.99617, f1: 0.99161, f1_macro: 0.99550
# epoch: 3, passed number of graphs: 768, train running loss: 0.00493 (passed time: 9m 4s)
#           acc: 0.97580, fpr: 0.02368, fnr: 0.03125, rec: 0.96875, prc: 0.75292, f1: 0.84731, f1_macro: 0.91708
# Validation --- epoch: 3, loss: 0.43373
#           f1_macro: nan, f1: 0.00045, fnr: 0.99977, rec: 0.00023, prc: 0.06687, acc: 0.93021, fpr: 0.00025
# epoch: 4, passed number of graphs: 96, train running loss: 0.01766 (passed time: 9m 44s)
#           acc: 0.99677, fpr: 0.00120, fnr: 0.03045, rec: 0.96955, prc: 0.98357, f1: 0.97651, f1_macro: 0.98739
# epoch: 4, passed number of graphs: 192, train running loss: 0.01168 (passed time: 10m 5s)
#           acc: 0.99704, fpr: 0.00059, fnr: 0.03445, rec: 0.96555, prc: 0.99188, f1: 0.97854, f1_macro: 0.98848
# epoch: 4, passed number of graphs: 288, train running loss: 0.01042 (passed time: 10m 26s)
#           acc: 0.99813, fpr: 0.00054, fnr: 0.01980, rec: 0.98020, prc: 0.99266, f1: 0.98639, f1_macro: 0.99269
# epoch: 4, passed number of graphs: 384, train running loss: 0.01183 (passed time: 10m 47s)
#           acc: 0.99200, fpr: 0.00391, fnr: 0.06155, rec: 0.93845, prc: 0.94831, f1: 0.94336, f1_macro: 0.96953
# epoch: 4, passed number of graphs: 480, train running loss: 0.01087 (passed time: 11m 8s)
#           acc: 0.99755, fpr: 0.00043, fnr: 0.02900, rec: 0.97100, prc: 0.99427, f1: 0.98250, f1_macro: 0.99059
# epoch: 4, passed number of graphs: 576, train running loss: 0.00973 (passed time: 11m 29s)
#           acc: 0.99813, fpr: 0.00084, fnr: 0.01580, rec: 0.98420, prc: 0.98865, f1: 0.98642, f1_macro: 0.99271
# epoch: 4, passed number of graphs: 672, train running loss: 0.00888 (passed time: 11m 50s)
#           acc: 0.99834, fpr: 0.00068, fnr: 0.01480, rec: 0.98520, prc: 0.99075, f1: 0.98797, f1_macro: 0.99354
# epoch: 4, passed number of graphs: 768, train running loss: 0.00814 (passed time: 12m 11s)
#           acc: 0.99858, fpr: 0.00043, fnr: 0.01470, rec: 0.98530, prc: 0.99420, f1: 0.98973, f1_macro: 0.99448
# Validation --- epoch: 4, loss: 0.00617
#           f1_macro: 0.99507, f1: 0.99082, fnr: 0.01365, rec: 0.98635, prc: 0.99536, acc: 0.99873, fpr: 0.00035
# Better model saved at ./saved_models/GIN_3: 0.9908242461648777.pt.
# epoch: 5, passed number of graphs: 96, train running loss: 0.00365 (passed time: 12m 51s)
#           acc: 0.99686, fpr: 0.00128, fnr: 0.02815, rec: 0.97185, prc: 0.98256, f1: 0.97718, f1_macro: 0.98774
# epoch: 5, passed number of graphs: 192, train running loss: 0.00404 (passed time: 13m 13s)
#           acc: 0.99829, fpr: 0.00028, fnr: 0.02070, rec: 0.97930, prc: 0.99619, f1: 0.98767, f1_macro: 0.99338
# epoch: 5, passed number of graphs: 288, train running loss: 0.00385 (passed time: 13m 33s)
#           acc: 0.99829, fpr: 0.00062, fnr: 0.01630, rec: 0.98370, prc: 0.99158, f1: 0.98763, f1_macro: 0.99335
# epoch: 5, passed number of graphs: 384, train running loss: 0.00373 (passed time: 13m 54s)
#           acc: 0.99831, fpr: 0.00054, fnr: 0.01670, rec: 0.98330, prc: 0.99283, f1: 0.98804, f1_macro: 0.99357
# epoch: 5, passed number of graphs: 480, train running loss: 0.00350 (passed time: 14m 15s)
#           acc: 0.99884, fpr: 0.00024, fnr: 0.01320, rec: 0.98680, prc: 0.99682, f1: 0.99178, f1_macro: 0.99558
# epoch: 5, passed number of graphs: 576, train running loss: 0.00355 (passed time: 14m 36s)
#           acc: 0.99628, fpr: 0.00228, fnr: 0.02305, rec: 0.97695, prc: 0.96948, f1: 0.97320, f1_macro: 0.98560
# epoch: 5, passed number of graphs: 672, train running loss: 0.00354 (passed time: 14m 57s)
#           acc: 0.99838, fpr: 0.00070, fnr: 0.01400, rec: 0.98600, prc: 0.99056, f1: 0.98827, f1_macro: 0.99370
# epoch: 5, passed number of graphs: 768, train running loss: 0.00342 (passed time: 15m 18s)
#           acc: 0.99870, fpr: 0.00039, fnr: 0.01350, rec: 0.98650, prc: 0.99476, f1: 0.99061, f1_macro: 0.99496
# Validation --- epoch: 5, loss: 0.00686
#           f1_macro: 0.99482, f1: 0.99036, fnr: 0.01765, rec: 0.98235, prc: 0.99851, acc: 0.99867, fpr: 0.00011
# epoch: 6, passed number of graphs: 96, train running loss: 0.00342 (passed time: 15m 59s)
#           acc: 0.99708, fpr: 0.00054, fnr: 0.03495, rec: 0.96505, prc: 0.99249, f1: 0.97858, f1_macro: 0.98850
# epoch: 6, passed number of graphs: 192, train running loss: 0.00331 (passed time: 16m 20s)
#           acc: 0.99852, fpr: 0.00022, fnr: 0.01830, rec: 0.98170, prc: 0.99700, f1: 0.98929, f1_macro: 0.99425
# epoch: 6, passed number of graphs: 288, train running loss: 0.00299 (passed time: 16m 41s)
#           acc: 0.99884, fpr: 0.00030, fnr: 0.01275, rec: 0.98725, prc: 0.99596, f1: 0.99159, f1_macro: 0.99548
# epoch: 6, passed number of graphs: 384, train running loss: 0.00280 (passed time: 17m 2s)
#           acc: 0.99882, fpr: 0.00025, fnr: 0.01340, rec: 0.98660, prc: 0.99667, f1: 0.99161, f1_macro: 0.99549
# epoch: 6, passed number of graphs: 480, train running loss: 0.00269 (passed time: 17m 23s)
#           acc: 0.99905, fpr: 0.00011, fnr: 0.01205, rec: 0.98795, prc: 0.99853, f1: 0.99321, f1_macro: 0.99635
# epoch: 6, passed number of graphs: 576, train running loss: 0.00298 (passed time: 17m 44s)
#           acc: 0.99807, fpr: 0.00025, fnr: 0.02460, rec: 0.97540, prc: 0.99663, f1: 0.98590, f1_macro: 0.99243
# epoch: 6, passed number of graphs: 672, train running loss: 0.00301 (passed time: 18m 5s)
#           acc: 0.99866, fpr: 0.00037, fnr: 0.01435, rec: 0.98565, prc: 0.99495, f1: 0.99028, f1_macro: 0.99478
# epoch: 6, passed number of graphs: 768, train running loss: 0.00315 (passed time: 18m 26s)
#           acc: 0.99846, fpr: 0.00048, fnr: 0.01575, rec: 0.98425, prc: 0.99349, f1: 0.98885, f1_macro: 0.99401
# Validation --- epoch: 6, loss: 0.02819
#           f1_macro: 0.96972, f1: 0.94344, fnr: 0.10438, rec: 0.89562, prc: 0.99668, acc: 0.99253, fpr: 0.00022
# epoch: 7, passed number of graphs: 96, train running loss: 0.00274 (passed time: 19m 7s)
#           acc: 0.99853, fpr: 0.00049, fnr: 0.01465, rec: 0.98535, prc: 0.99330, f1: 0.98931, f1_macro: 0.99426
# epoch: 7, passed number of graphs: 192, train running loss: 0.00257 (passed time: 19m 28s)
#           acc: 0.99867, fpr: 0.00029, fnr: 0.01520, rec: 0.98480, prc: 0.99606, f1: 0.99040, f1_macro: 0.99484
# epoch: 7, passed number of graphs: 288, train running loss: 0.00248 (passed time: 19m 49s)
#           acc: 0.99879, fpr: 0.00030, fnr: 0.01345, rec: 0.98655, prc: 0.99591, f1: 0.99121, f1_macro: 0.99528
# epoch: 7, passed number of graphs: 384, train running loss: 0.00240 (passed time: 20m 10s)
#           acc: 0.99866, fpr: 0.00032, fnr: 0.01465, rec: 0.98535, prc: 0.99576, f1: 0.99053, f1_macro: 0.99490
# epoch: 7, passed number of graphs: 480, train running loss: 0.00234 (passed time: 20m 31s)
#           acc: 0.99894, fpr: 0.00016, fnr: 0.01290, rec: 0.98710, prc: 0.99783, f1: 0.99243, f1_macro: 0.99593
# epoch: 7, passed number of graphs: 576, train running loss: 0.00231 (passed time: 20m 52s)
#           acc: 0.99903, fpr: 0.00017, fnr: 0.01175, rec: 0.98825, prc: 0.99768, f1: 0.99294, f1_macro: 0.99621
# epoch: 7, passed number of graphs: 672, train running loss: 0.00227 (passed time: 21m 13s)
#           acc: 0.99874, fpr: 0.00041, fnr: 0.01275, rec: 0.98725, prc: 0.99451, f1: 0.99087, f1_macro: 0.99510
# epoch: 7, passed number of graphs: 768, train running loss: 0.00224 (passed time: 21m 33s)
#           acc: 0.99895, fpr: 0.00018, fnr: 0.01270, rec: 0.98730, prc: 0.99752, f1: 0.99239, f1_macro: 0.99591
# Validation --- epoch: 7, loss: 0.00369
#           f1_macro: 0.99610, f1: 0.99274, fnr: 0.01315, rec: 0.98685, prc: 0.99870, acc: 0.99900, fpr: 0.00010
# Better model saved at ./saved_models/GIN_6: 0.992736275149698.pt.
# epoch: 8, passed number of graphs: 96, train running loss: 0.00206 (passed time: 22m 14s)
#           acc: 0.99890, fpr: 0.00031, fnr: 0.01180, rec: 0.98820, prc: 0.99582, f1: 0.99199, f1_macro: 0.99570
# epoch: 8, passed number of graphs: 192, train running loss: 0.00202 (passed time: 22m 35s)
#           acc: 0.99888, fpr: 0.00017, fnr: 0.01375, rec: 0.98625, prc: 0.99767, f1: 0.99193, f1_macro: 0.99566
# epoch: 8, passed number of graphs: 288, train running loss: 0.00199 (passed time: 22m 56s)
#           acc: 0.99901, fpr: 0.00015, fnr: 0.01225, rec: 0.98775, prc: 0.99793, f1: 0.99281, f1_macro: 0.99614
# epoch: 8, passed number of graphs: 384, train running loss: 0.00197 (passed time: 23m 17s)
#           acc: 0.99886, fpr: 0.00028, fnr: 0.01245, rec: 0.98755, prc: 0.99632, f1: 0.99191, f1_macro: 0.99565
# epoch: 8, passed number of graphs: 480, train running loss: 0.00198 (passed time: 23m 38s)
#           acc: 0.99896, fpr: 0.00014, fnr: 0.01285, rec: 0.98715, prc: 0.99813, f1: 0.99261, f1_macro: 0.99603
# epoch: 8, passed number of graphs: 576, train running loss: 0.00197 (passed time: 23m 59s)
#           acc: 0.99915, fpr: 0.00012, fnr: 0.01075, rec: 0.98925, prc: 0.99839, f1: 0.99380, f1_macro: 0.99667
# epoch: 8, passed number of graphs: 672, train running loss: 0.00195 (passed time: 24m 20s)
#           acc: 0.99888, fpr: 0.00035, fnr: 0.01160, rec: 0.98840, prc: 0.99532, f1: 0.99185, f1_macro: 0.99562
# epoch: 8, passed number of graphs: 768, train running loss: 0.00194 (passed time: 24m 41s)
#           acc: 0.99898, fpr: 0.00025, fnr: 0.01140, rec: 0.98860, prc: 0.99667, f1: 0.99262, f1_macro: 0.99604
# Validation --- epoch: 8, loss: 0.00327
#           f1_macro: 0.99648, f1: 0.99344, fnr: 0.01185, rec: 0.98815, prc: 0.99879, acc: 0.99909, fpr: 0.00009
# Better model saved at ./saved_models/GIN_7: 0.993439781535443.pt.
# epoch: 9, passed number of graphs: 96, train running loss: 0.00183 (passed time: 25m 22s)
#           acc: 0.99893, fpr: 0.00024, fnr: 0.01220, rec: 0.98780, prc: 0.99672, f1: 0.99224, f1_macro: 0.99583
# epoch: 9, passed number of graphs: 192, train running loss: 0.00183 (passed time: 25m 43s)
#           acc: 0.99898, fpr: 0.00010, fnr: 0.01325, rec: 0.98675, prc: 0.99868, f1: 0.99268, f1_macro: 0.99607
# epoch: 9, passed number of graphs: 288, train running loss: 0.00183 (passed time: 26m 3s)
#           acc: 0.99905, fpr: 0.00015, fnr: 0.01165, rec: 0.98835, prc: 0.99798, f1: 0.99314, f1_macro: 0.99632
# epoch: 9, passed number of graphs: 384, train running loss: 0.00184 (passed time: 26m 24s)
#           acc: 0.99888, fpr: 0.00025, fnr: 0.01255, rec: 0.98745, prc: 0.99667, f1: 0.99204, f1_macro: 0.99572
# epoch: 9, passed number of graphs: 480, train running loss: 0.00184 (passed time: 26m 45s)
#           acc: 0.99910, fpr: 0.00016, fnr: 0.01060, rec: 0.98940, prc: 0.99788, f1: 0.99362, f1_macro: 0.99657
# epoch: 9, passed number of graphs: 576, train running loss: 0.00189 (passed time: 27m 6s)
#           acc: 0.99904, fpr: 0.00012, fnr: 0.01225, rec: 0.98775, prc: 0.99838, f1: 0.99304, f1_macro: 0.99626
# epoch: 9, passed number of graphs: 672, train running loss: 0.00190 (passed time: 27m 27s)
#           acc: 0.99897, fpr: 0.00026, fnr: 0.01145, rec: 0.98855, prc: 0.99652, f1: 0.99252, f1_macro: 0.99598
# epoch: 9, passed number of graphs: 768, train running loss: 0.00188 (passed time: 27m 48s)
#           acc: 0.99907, fpr: 0.00016, fnr: 0.01135, rec: 0.98865, prc: 0.99788, f1: 0.99324, f1_macro: 0.99637
# Validation --- epoch: 9, loss: 0.00325
#           f1_macro: 0.99657, f1: 0.99361, fnr: 0.01158, rec: 0.98842, prc: 0.99885, acc: 0.99912, fpr: 0.00008
# Better model saved at ./saved_models/GIN_8: 0.993606414718477.pt.
# epoch: 10, passed number of graphs: 96, train running loss: 0.00296 (passed time: 28m 29s)
#           acc: 0.99729, fpr: 0.00087, fnr: 0.02745, rec: 0.97255, prc: 0.98816, f1: 0.98029, f1_macro: 0.98942
# epoch: 10, passed number of graphs: 192, train running loss: 0.00291 (passed time: 28m 50s)
#           acc: 0.99877, fpr: 0.00015, fnr: 0.01570, rec: 0.98430, prc: 0.99802, f1: 0.99111, f1_macro: 0.99523
# epoch: 10, passed number of graphs: 288, train running loss: 0.00260 (passed time: 29m 11s)
#           acc: 0.99903, fpr: 0.00015, fnr: 0.01200, rec: 0.98800, prc: 0.99803, f1: 0.99299, f1_macro: 0.99624
# epoch: 10, passed number of graphs: 384, train running loss: 0.00241 (passed time: 29m 31s)
#           acc: 0.99893, fpr: 0.00027, fnr: 0.01155, rec: 0.98845, prc: 0.99642, f1: 0.99242, f1_macro: 0.99592
# epoch: 10, passed number of graphs: 480, train running loss: 0.00228 (passed time: 29m 52s)
#           acc: 0.99911, fpr: 0.00014, fnr: 0.01080, rec: 0.98920, prc: 0.99813, f1: 0.99365, f1_macro: 0.99658
# epoch: 10, passed number of graphs: 576, train running loss: 0.00219 (passed time: 30m 13s)
#           acc: 0.99923, fpr: 0.00008, fnr: 0.01000, rec: 0.99000, prc: 0.99889, f1: 0.99443, f1_macro: 0.99701
# epoch: 10, passed number of graphs: 672, train running loss: 0.00211 (passed time: 30m 34s)
#           acc: 0.99906, fpr: 0.00018, fnr: 0.01120, rec: 0.98880, prc: 0.99753, f1: 0.99315, f1_macro: 0.99632
# epoch: 10, passed number of graphs: 768, train running loss: 0.00210 (passed time: 30m 55s)
#           acc: 0.99898, fpr: 0.00015, fnr: 0.01270, rec: 0.98730, prc: 0.99803, f1: 0.99264, f1_macro: 0.99605
# Validation --- epoch: 10, loss: 0.00672
#           f1_macro: 0.99443, f1: 0.98963, fnr: 0.01024, rec: 0.98976, prc: 0.98951, acc: 0.99856, fpr: 0.00078
# epoch: 11, passed number of graphs: 96, train running loss: 0.00182 (passed time: 31m 36s)
#           acc: 0.99904, fpr: 0.00013, fnr: 0.01200, rec: 0.98800, prc: 0.99818, f1: 0.99306, f1_macro: 0.99628
# epoch: 11, passed number of graphs: 192, train running loss: 0.00177 (passed time: 31m 57s)
#           acc: 0.99905, fpr: 0.00011, fnr: 0.01215, rec: 0.98785, prc: 0.99848, f1: 0.99314, f1_macro: 0.99631
# epoch: 11, passed number of graphs: 288, train running loss: 0.00185 (passed time: 32m 18s)
#           acc: 0.99736, fpr: 0.00174, fnr: 0.01470, rec: 0.98530, prc: 0.97675, f1: 0.98101, f1_macro: 0.98979
# epoch: 11, passed number of graphs: 384, train running loss: 0.00197 (passed time: 32m 39s)
#           acc: 0.99888, fpr: 0.00019, fnr: 0.01335, rec: 0.98665, prc: 0.99752, f1: 0.99206, f1_macro: 0.99573
# epoch: 11, passed number of graphs: 480, train running loss: 0.00194 (passed time: 33m 0s)
#           acc: 0.99911, fpr: 0.00013, fnr: 0.01095, rec: 0.98905, prc: 0.99833, f1: 0.99367, f1_macro: 0.99660
# epoch: 11, passed number of graphs: 576, train running loss: 0.00190 (passed time: 33m 21s)
#           acc: 0.99919, fpr: 0.00013, fnr: 0.00990, rec: 0.99010, prc: 0.99824, f1: 0.99415, f1_macro: 0.99686
# epoch: 11, passed number of graphs: 672, train running loss: 0.00186 (passed time: 33m 42s)
#           acc: 0.99908, fpr: 0.00014, fnr: 0.01135, rec: 0.98865, prc: 0.99803, f1: 0.99332, f1_macro: 0.99641
# epoch: 11, passed number of graphs: 768, train running loss: 0.00184 (passed time: 34m 3s)
#           acc: 0.99904, fpr: 0.00019, fnr: 0.01130, rec: 0.98870, prc: 0.99738, f1: 0.99302, f1_macro: 0.99625
# Validation --- epoch: 11, loss: 0.00333
#           f1_macro: 0.99659, f1: 0.99365, fnr: 0.01233, rec: 0.98767, prc: 0.99971, acc: 0.99912, fpr: 0.00002
# Better model saved at ./saved_models/GIN_10: 0.9936498869798033.pt.
# epoch: 12, passed number of graphs: 96, train running loss: 0.00163 (passed time: 34m 43s)
#           acc: 0.99910, fpr: 0.00012, fnr: 0.01140, rec: 0.98860, prc: 0.99833, f1: 0.99344, f1_macro: 0.99648
# epoch: 12, passed number of graphs: 192, train running loss: 0.00160 (passed time: 35m 4s)
#           acc: 0.99908, fpr: 0.00012, fnr: 0.01155, rec: 0.98845, prc: 0.99838, f1: 0.99339, f1_macro: 0.99645
# epoch: 12, passed number of graphs: 288, train running loss: 0.00159 (passed time: 35m 25s)
#           acc: 0.99909, fpr: 0.00019, fnr: 0.01055, rec: 0.98945, prc: 0.99743, f1: 0.99342, f1_macro: 0.99647
# epoch: 12, passed number of graphs: 384, train running loss: 0.00159 (passed time: 35m 46s)
#           acc: 0.99907, fpr: 0.00010, fnr: 0.01180, rec: 0.98820, prc: 0.99869, f1: 0.99342, f1_macro: 0.99646
# epoch: 12, passed number of graphs: 480, train running loss: 0.00158 (passed time: 36m 7s)
#           acc: 0.99919, fpr: 0.00007, fnr: 0.01055, rec: 0.98945, prc: 0.99909, f1: 0.99425, f1_macro: 0.99691
# epoch: 12, passed number of graphs: 576, train running loss: 0.00158 (passed time: 36m 28s)
#           acc: 0.99921, fpr: 0.00014, fnr: 0.00955, rec: 0.99045, prc: 0.99809, f1: 0.99425, f1_macro: 0.99691
# epoch: 12, passed number of graphs: 672, train running loss: 0.00158 (passed time: 36m 49s)
#           acc: 0.99914, fpr: 0.00010, fnr: 0.01110, rec: 0.98890, prc: 0.99859, f1: 0.99372, f1_macro: 0.99663
# epoch: 12, passed number of graphs: 768, train running loss: 0.00157 (passed time: 37m 10s)
#           acc: 0.99918, fpr: 0.00009, fnr: 0.01055, rec: 0.98945, prc: 0.99874, f1: 0.99407, f1_macro: 0.99682
# Validation --- epoch: 12, loss: 0.00286
#           f1_macro: 0.99701, f1: 0.99444, fnr: 0.01052, rec: 0.98947, prc: 0.99946, acc: 0.99923, fpr: 0.00004
# Better model saved at ./saved_models/GIN_11: 0.9944412095039393.pt.
# epoch: 13, passed number of graphs: 96, train running loss: 0.00154 (passed time: 37m 50s)
#           acc: 0.99913, fpr: 0.00014, fnr: 0.01060, rec: 0.98940, prc: 0.99808, f1: 0.99372, f1_macro: 0.99663
# epoch: 13, passed number of graphs: 192, train running loss: 0.00153 (passed time: 38m 11s)
#           acc: 0.99912, fpr: 0.00008, fnr: 0.01160, rec: 0.98840, prc: 0.99899, f1: 0.99367, f1_macro: 0.99660
# epoch: 13, passed number of graphs: 288, train running loss: 0.00153 (passed time: 38m 32s)
#           acc: 0.99918, fpr: 0.00011, fnr: 0.01035, rec: 0.98965, prc: 0.99849, f1: 0.99405, f1_macro: 0.99680
# epoch: 13, passed number of graphs: 384, train running loss: 0.00153 (passed time: 38m 53s)
#           acc: 0.99910, fpr: 0.00012, fnr: 0.01115, rec: 0.98885, prc: 0.99843, f1: 0.99362, f1_macro: 0.99657
# epoch: 13, passed number of graphs: 480, train running loss: 0.00153 (passed time: 39m 14s)
#           acc: 0.99919, fpr: 0.00010, fnr: 0.01015, rec: 0.98985, prc: 0.99874, f1: 0.99427, f1_macro: 0.99692
# epoch: 13, passed number of graphs: 576, train running loss: 0.00153 (passed time: 39m 35s)
#           acc: 0.99932, fpr: 0.00005, fnr: 0.00920, rec: 0.99080, prc: 0.99929, f1: 0.99503, f1_macro: 0.99733
# epoch: 13, passed number of graphs: 672, train running loss: 0.00153 (passed time: 39m 56s)
#           acc: 0.99912, fpr: 0.00014, fnr: 0.01075, rec: 0.98925, prc: 0.99803, f1: 0.99362, f1_macro: 0.99658
# epoch: 13, passed number of graphs: 768, train running loss: 0.00152 (passed time: 40m 17s)
#           acc: 0.99916, fpr: 0.00009, fnr: 0.01095, rec: 0.98905, prc: 0.99884, f1: 0.99392, f1_macro: 0.99673
# Validation --- epoch: 13, loss: 0.00291
#           f1_macro: 0.99695, f1: 0.99432, fnr: 0.01095, rec: 0.98905, prc: 0.99965, acc: 0.99921, fpr: 0.00003
# epoch: 14, passed number of graphs: 96, train running loss: 0.00156 (passed time: 40m 57s)
#           acc: 0.99919, fpr: 0.00013, fnr: 0.00995, rec: 0.99005, prc: 0.99829, f1: 0.99415, f1_macro: 0.99686
# epoch: 14, passed number of graphs: 192, train running loss: 0.00153 (passed time: 41m 18s)
#           acc: 0.99913, fpr: 0.00007, fnr: 0.01145, rec: 0.98855, prc: 0.99904, f1: 0.99377, f1_macro: 0.99665
# epoch: 14, passed number of graphs: 288, train running loss: 0.00152 (passed time: 41m 39s)
#           acc: 0.99920, fpr: 0.00011, fnr: 0.01005, rec: 0.98995, prc: 0.99849, f1: 0.99420, f1_macro: 0.99689
# epoch: 14, passed number of graphs: 384, train running loss: 0.00152 (passed time: 42m 0s)
#           acc: 0.99905, fpr: 0.00019, fnr: 0.01080, rec: 0.98920, prc: 0.99743, f1: 0.99330, f1_macro: 0.99639
# epoch: 14, passed number of graphs: 480, train running loss: 0.00151 (passed time: 42m 21s)
#           acc: 0.99919, fpr: 0.00009, fnr: 0.01030, rec: 0.98970, prc: 0.99884, f1: 0.99425, f1_macro: 0.99691
# epoch: 14, passed number of graphs: 576, train running loss: 0.00151 (passed time: 42m 42s)
#           acc: 0.99930, fpr: 0.00009, fnr: 0.00895, rec: 0.99105, prc: 0.99879, f1: 0.99491, f1_macro: 0.99726
# epoch: 14, passed number of graphs: 672, train running loss: 0.00151 (passed time: 43m 3s)
#           acc: 0.99912, fpr: 0.00016, fnr: 0.01055, rec: 0.98945, prc: 0.99788, f1: 0.99365, f1_macro: 0.99659
# epoch: 14, passed number of graphs: 768, train running loss: 0.00151 (passed time: 43m 24s)
#           acc: 0.99921, fpr: 0.00010, fnr: 0.01000, rec: 0.99000, prc: 0.99864, f1: 0.99430, f1_macro: 0.99694
# Validation --- epoch: 14, loss: 0.00278
#           f1_macro: 0.99709, f1: 0.99459, fnr: 0.01024, rec: 0.98976, prc: 0.99947, acc: 0.99925, fpr: 0.00004
# Better model saved at ./saved_models/GIN_13: 0.9945885459182402.pt.
# epoch: 15, passed number of graphs: 96, train running loss: 0.00149 (passed time: 44m 4s)
#           acc: 0.99922, fpr: 0.00011, fnr: 0.00985, rec: 0.99015, prc: 0.99854, f1: 0.99433, f1_macro: 0.99695
# epoch: 15, passed number of graphs: 192, train running loss: 0.00148 (passed time: 44m 25s)
#           acc: 0.99918, fpr: 0.00008, fnr: 0.01060, rec: 0.98940, prc: 0.99889, f1: 0.99412, f1_macro: 0.99684
# epoch: 15, passed number of graphs: 288, train running loss: 0.00147 (passed time: 44m 46s)
#           acc: 0.99920, fpr: 0.00009, fnr: 0.01030, rec: 0.98970, prc: 0.99874, f1: 0.99420, f1_macro: 0.99688
# epoch: 15, passed number of graphs: 384, train running loss: 0.00147 (passed time: 45m 7s)
#           acc: 0.99917, fpr: 0.00011, fnr: 0.01020, rec: 0.98980, prc: 0.99849, f1: 0.99412, f1_macro: 0.99684
# epoch: 15, passed number of graphs: 480, train running loss: 0.00147 (passed time: 45m 28s)
#           acc: 0.99924, fpr: 0.00010, fnr: 0.00950, rec: 0.99050, prc: 0.99874, f1: 0.99460, f1_macro: 0.99710
# epoch: 15, passed number of graphs: 576, train running loss: 0.00147 (passed time: 45m 49s)
#           acc: 0.99934, fpr: 0.00006, fnr: 0.00865, rec: 0.99135, prc: 0.99914, f1: 0.99523, f1_macro: 0.99744
# epoch: 15, passed number of graphs: 672, train running loss: 0.00147 (passed time: 46m 9s)
#           acc: 0.99918, fpr: 0.00013, fnr: 0.01015, rec: 0.98985, prc: 0.99829, f1: 0.99405, f1_macro: 0.99680
# epoch: 15, passed number of graphs: 768, train running loss: 0.00256 (passed time: 46m 30s)
#           acc: 0.99829, fpr: 0.00058, fnr: 0.01685, rec: 0.98315, prc: 0.99208, f1: 0.98759, f1_macro: 0.99334
# Validation --- epoch: 15, loss: 0.01998
#           f1_macro: 0.97680, f1: 0.95670, fnr: 0.08138, rec: 0.91862, prc: 0.99809, acc: 0.99422, fpr: 0.00013
# epoch: 16, passed number of graphs: 96, train running loss: 0.00291 (passed time: 47m 11s)
#           acc: 0.99851, fpr: 0.00058, fnr: 0.01380, rec: 0.98620, prc: 0.99215, f1: 0.98917, f1_macro: 0.99418
# epoch: 16, passed number of graphs: 192, train running loss: 0.00266 (passed time: 47m 32s)
#           acc: 0.99869, fpr: 0.00030, fnr: 0.01465, rec: 0.98535, prc: 0.99591, f1: 0.99060, f1_macro: 0.99495
# epoch: 16, passed number of graphs: 288, train running loss: 0.00252 (passed time: 47m 53s)
#           acc: 0.99885, fpr: 0.00026, fnr: 0.01315, rec: 0.98685, prc: 0.99647, f1: 0.99163, f1_macro: 0.99551
# epoch: 16, passed number of graphs: 384, train running loss: 0.00243 (passed time: 48m 13s)
#           acc: 0.99867, fpr: 0.00031, fnr: 0.01475, rec: 0.98525, prc: 0.99596, f1: 0.99057, f1_macro: 0.99493
# epoch: 16, passed number of graphs: 480, train running loss: 0.00235 (passed time: 48m 34s)
#           acc: 0.99891, fpr: 0.00018, fnr: 0.01305, rec: 0.98695, prc: 0.99762, f1: 0.99226, f1_macro: 0.99584
# epoch: 16, passed number of graphs: 576, train running loss: 0.00229 (passed time: 48m 55s)
#           acc: 0.99908, fpr: 0.00018, fnr: 0.01090, rec: 0.98910, prc: 0.99758, f1: 0.99332, f1_macro: 0.99641
# epoch: 16, passed number of graphs: 672, train running loss: 0.00223 (passed time: 49m 16s)
#           acc: 0.99885, fpr: 0.00029, fnr: 0.01265, rec: 0.98735, prc: 0.99607, f1: 0.99169, f1_macro: 0.99554
# epoch: 16, passed number of graphs: 768, train running loss: 0.00218 (passed time: 49m 37s)
#           acc: 0.99892, fpr: 0.00023, fnr: 0.01255, rec: 0.98745, prc: 0.99692, f1: 0.99216, f1_macro: 0.99579
# Validation --- epoch: 16, loss: 0.00412
#           f1_macro: 0.99585, f1: 0.99227, fnr: 0.01333, rec: 0.98667, prc: 0.99795, acc: 0.99893, fpr: 0.00015
# epoch: 17, passed number of graphs: 96, train running loss: 0.00182 (passed time: 50m 17s)
#           acc: 0.99896, fpr: 0.00024, fnr: 0.01175, rec: 0.98825, prc: 0.99672, f1: 0.99247, f1_macro: 0.99596
# epoch: 17, passed number of graphs: 192, train running loss: 0.00181 (passed time: 50m 38s)
#           acc: 0.99903, fpr: 0.00012, fnr: 0.01220, rec: 0.98780, prc: 0.99833, f1: 0.99304, f1_macro: 0.99626
# epoch: 17, passed number of graphs: 288, train running loss: 0.00180 (passed time: 50m 59s)
#           acc: 0.99902, fpr: 0.00017, fnr: 0.01180, rec: 0.98820, prc: 0.99763, f1: 0.99289, f1_macro: 0.99618
# epoch: 17, passed number of graphs: 384, train running loss: 0.00179 (passed time: 51m 20s)
#           acc: 0.99894, fpr: 0.00015, fnr: 0.01300, rec: 0.98700, prc: 0.99803, f1: 0.99248, f1_macro: 0.99596
# epoch: 17, passed number of graphs: 480, train running loss: 0.00179 (passed time: 51m 41s)
#           acc: 0.99907, fpr: 0.00007, fnr: 0.01220, rec: 0.98780, prc: 0.99904, f1: 0.99339, f1_macro: 0.99644
# epoch: 17, passed number of graphs: 576, train running loss: 0.00178 (passed time: 52m 2s)
#           acc: 0.99920, fpr: 0.00010, fnr: 0.01030, rec: 0.98970, prc: 0.99869, f1: 0.99417, f1_macro: 0.99687
# epoch: 17, passed number of graphs: 672, train running loss: 0.00178 (passed time: 52m 23s)
#           acc: 0.99899, fpr: 0.00018, fnr: 0.01210, rec: 0.98790, prc: 0.99753, f1: 0.99269, f1_macro: 0.99607
# epoch: 17, passed number of graphs: 768, train running loss: 0.00177 (passed time: 52m 44s)
#           acc: 0.99899, fpr: 0.00017, fnr: 0.01225, rec: 0.98775, prc: 0.99773, f1: 0.99271, f1_macro: 0.99609
# Validation --- epoch: 17, loss: 0.00344
#           f1_macro: 0.99639, f1: 0.99329, fnr: 0.01185, rec: 0.98815, prc: 0.99848, acc: 0.99907, fpr: 0.00011
# epoch: 18, passed number of graphs: 96, train running loss: 0.00174 (passed time: 53m 24s)
#           acc: 0.99898, fpr: 0.00023, fnr: 0.01160, rec: 0.98840, prc: 0.99687, f1: 0.99262, f1_macro: 0.99604
# epoch: 18, passed number of graphs: 192, train running loss: 0.00173 (passed time: 53m 45s)
#           acc: 0.99902, fpr: 0.00014, fnr: 0.01225, rec: 0.98775, prc: 0.99818, f1: 0.99294, f1_macro: 0.99621
# epoch: 18, passed number of graphs: 288, train running loss: 0.00172 (passed time: 54m 6s)
#           acc: 0.99904, fpr: 0.00015, fnr: 0.01175, rec: 0.98825, prc: 0.99793, f1: 0.99307, f1_macro: 0.99628
# epoch: 18, passed number of graphs: 384, train running loss: 0.00172 (passed time: 54m 27s)
#           acc: 0.99893, fpr: 0.00018, fnr: 0.01285, rec: 0.98715, prc: 0.99768, f1: 0.99238, f1_macro: 0.99590
# epoch: 18, passed number of graphs: 480, train running loss: 0.00171 (passed time: 54m 48s)
#           acc: 0.99907, fpr: 0.00010, fnr: 0.01190, rec: 0.98810, prc: 0.99869, f1: 0.99336, f1_macro: 0.99643
# epoch: 18, passed number of graphs: 576, train running loss: 0.00171 (passed time: 55m 9s)
#           acc: 0.99919, fpr: 0.00013, fnr: 0.01005, rec: 0.98995, prc: 0.99829, f1: 0.99410, f1_macro: 0.99683
# epoch: 18, passed number of graphs: 672, train running loss: 0.00170 (passed time: 55m 29s)
#           acc: 0.99899, fpr: 0.00018, fnr: 0.01210, rec: 0.98790, prc: 0.99753, f1: 0.99269, f1_macro: 0.99607
# epoch: 18, passed number of graphs: 768, train running loss: 0.00170 (passed time: 55m 50s)
#           acc: 0.99908, fpr: 0.00013, fnr: 0.01155, rec: 0.98845, prc: 0.99828, f1: 0.99334, f1_macro: 0.99642
# Validation --- epoch: 18, loss: 0.00312
#           f1_macro: 0.99664, f1: 0.99375, fnr: 0.01135, rec: 0.98865, prc: 0.99890, acc: 0.99913, fpr: 0.00008
# epoch: 19, passed number of graphs: 96, train running loss: 0.00166 (passed time: 56m 31s)
#           acc: 0.99905, fpr: 0.00015, fnr: 0.01165, rec: 0.98835, prc: 0.99793, f1: 0.99312, f1_macro: 0.99630
# epoch: 19, passed number of graphs: 192, train running loss: 0.00165 (passed time: 56m 52s)
#           acc: 0.99908, fpr: 0.00010, fnr: 0.01190, rec: 0.98810, prc: 0.99869, f1: 0.99336, f1_macro: 0.99643
# epoch: 19, passed number of graphs: 288, train running loss: 0.00165 (passed time: 57m 13s)
#           acc: 0.99905, fpr: 0.00015, fnr: 0.01175, rec: 0.98825, prc: 0.99803, f1: 0.99312, f1_macro: 0.99630
# epoch: 19, passed number of graphs: 384, train running loss: 0.00165 (passed time: 57m 34s)
#           acc: 0.99896, fpr: 0.00015, fnr: 0.01270, rec: 0.98730, prc: 0.99798, f1: 0.99261, f1_macro: 0.99602
# epoch: 19, passed number of graphs: 480, train running loss: 0.00165 (passed time: 57m 55s)
#           acc: 0.99911, fpr: 0.00007, fnr: 0.01170, rec: 0.98830, prc: 0.99909, f1: 0.99367, f1_macro: 0.99659
# epoch: 19, passed number of graphs: 576, train running loss: 0.00165 (passed time: 58m 16s)
#           acc: 0.99925, fpr: 0.00007, fnr: 0.00990, rec: 0.99010, prc: 0.99899, f1: 0.99453, f1_macro: 0.99706
# epoch: 19, passed number of graphs: 672, train running loss: 0.00165 (passed time: 58m 37s)
#           acc: 0.99900, fpr: 0.00017, fnr: 0.01205, rec: 0.98795, prc: 0.99763, f1: 0.99276, f1_macro: 0.99611
# epoch: 19, passed number of graphs: 768, train running loss: 0.00164 (passed time: 58m 58s)
#           acc: 0.99904, fpr: 0.00015, fnr: 0.01185, rec: 0.98815, prc: 0.99793, f1: 0.99302, f1_macro: 0.99625
# Validation --- epoch: 19, loss: 0.00319
#           f1_macro: 0.99661, f1: 0.99369, fnr: 0.01166, rec: 0.98834, prc: 0.99911, acc: 0.99913, fpr: 0.00007
# epoch: 20, passed number of graphs: 96, train running loss: 0.00164 (passed time: 59m 39s)
#           acc: 0.99913, fpr: 0.00013, fnr: 0.01080, rec: 0.98920, prc: 0.99818, f1: 0.99367, f1_macro: 0.99660
# epoch: 20, passed number of graphs: 192, train running loss: 0.00163 (passed time: 1h 0m 0s)
#           acc: 0.99906, fpr: 0.00012, fnr: 0.01185, rec: 0.98815, prc: 0.99838, f1: 0.99324, f1_macro: 0.99637
# epoch: 20, passed number of graphs: 288, train running loss: 0.00163 (passed time: 1h 0m 20s)
#           acc: 0.99908, fpr: 0.00014, fnr: 0.01135, rec: 0.98865, prc: 0.99808, f1: 0.99334, f1_macro: 0.99643
# epoch: 20, passed number of graphs: 384, train running loss: 0.00163 (passed time: 1h 0m 41s)
#           acc: 0.99897, fpr: 0.00016, fnr: 0.01240, rec: 0.98760, prc: 0.99783, f1: 0.99269, f1_macro: 0.99607
# epoch: 20, passed number of graphs: 480, train running loss: 0.00163 (passed time: 1h 1m 2s)
#           acc: 0.99910, fpr: 0.00007, fnr: 0.01175, rec: 0.98825, prc: 0.99904, f1: 0.99362, f1_macro: 0.99657
# epoch: 20, passed number of graphs: 576, train running loss: 0.00163 (passed time: 1h 1m 23s)
#           acc: 0.99923, fpr: 0.00007, fnr: 0.01015, rec: 0.98985, prc: 0.99899, f1: 0.99440, f1_macro: 0.99699
# epoch: 20, passed number of graphs: 672, train running loss: 0.00163 (passed time: 1h 1m 44s)
#           acc: 0.99906, fpr: 0.00015, fnr: 0.01165, rec: 0.98835, prc: 0.99798, f1: 0.99314, f1_macro: 0.99632
# epoch: 20, passed number of graphs: 768, train running loss: 0.00163 (passed time: 1h 2m 5s)
#           acc: 0.99907, fpr: 0.00012, fnr: 0.01185, rec: 0.98815, prc: 0.99843, f1: 0.99327, f1_macro: 0.99638
# Validation --- epoch: 20, loss: 0.00309
#           f1_macro: 0.99670, f1: 0.99386, fnr: 0.01141, rec: 0.98859, prc: 0.99918, acc: 0.99915, fpr: 0.00006
# epoch: 21, passed number of graphs: 96, train running loss: 0.00162 (passed time: 1h 2m 46s)
#           acc: 0.99910, fpr: 0.00013, fnr: 0.01125, rec: 0.98875, prc: 0.99818, f1: 0.99344, f1_macro: 0.99648
# epoch: 21, passed number of graphs: 192, train running loss: 0.00162 (passed time: 1h 3m 7s)
#           acc: 0.99906, fpr: 0.00012, fnr: 0.01185, rec: 0.98815, prc: 0.99843, f1: 0.99327, f1_macro: 0.99638
# epoch: 21, passed number of graphs: 288, train running loss: 0.00162 (passed time: 1h 3m 28s)
#           acc: 0.99911, fpr: 0.00009, fnr: 0.01155, rec: 0.98845, prc: 0.99874, f1: 0.99357, f1_macro: 0.99655
# epoch: 21, passed number of graphs: 384, train running loss: 0.00162 (passed time: 1h 3m 49s)
#           acc: 0.99902, fpr: 0.00010, fnr: 0.01255, rec: 0.98745, prc: 0.99869, f1: 0.99304, f1_macro: 0.99625
# epoch: 21, passed number of graphs: 480, train running loss: 0.00162 (passed time: 1h 4m 10s)
#           acc: 0.99912, fpr: 0.00005, fnr: 0.01180, rec: 0.98820, prc: 0.99934, f1: 0.99374, f1_macro: 0.99663
# epoch: 21, passed number of graphs: 576, train running loss: 0.00162 (passed time: 1h 4m 31s)
#           acc: 0.99924, fpr: 0.00008, fnr: 0.00995, rec: 0.99005, prc: 0.99889, f1: 0.99445, f1_macro: 0.99702
# epoch: 21, passed number of graphs: 672, train running loss: 0.00162 (passed time: 1h 4m 52s)
#           acc: 0.99907, fpr: 0.00013, fnr: 0.01170, rec: 0.98830, prc: 0.99818, f1: 0.99322, f1_macro: 0.99636
# epoch: 21, passed number of graphs: 768, train running loss: 0.00161 (passed time: 1h 5m 13s)
#           acc: 0.99910, fpr: 0.00012, fnr: 0.01145, rec: 0.98855, prc: 0.99843, f1: 0.99347, f1_macro: 0.99649
# Validation --- epoch: 21, loss: 0.00308
#           f1_macro: 0.99671, f1: 0.99387, fnr: 0.01140, rec: 0.98860, prc: 0.99921, acc: 0.99915, fpr: 0.00006
# epoch: 22, passed number of graphs: 96, train running loss: 0.00162 (passed time: 1h 5m 54s)
#           acc: 0.99913, fpr: 0.00014, fnr: 0.01065, rec: 0.98935, prc: 0.99808, f1: 0.99370, f1_macro: 0.99662
# epoch: 22, passed number of graphs: 192, train running loss: 0.00161 (passed time: 1h 6m 15s)
#           acc: 0.99906, fpr: 0.00012, fnr: 0.01180, rec: 0.98820, prc: 0.99833, f1: 0.99324, f1_macro: 0.99637
# epoch: 22, passed number of graphs: 288, train running loss: 0.00161 (passed time: 1h 6m 35s)
#           acc: 0.99909, fpr: 0.00014, fnr: 0.01130, rec: 0.98870, prc: 0.99813, f1: 0.99339, f1_macro: 0.99645
# epoch: 22, passed number of graphs: 384, train running loss: 0.00161 (passed time: 1h 6m 56s)
# ...
#           acc: 0.99909, fpr: 0.00012, fnr: 0.01150, rec: 0.98850, prc: 0.99838, f1: 0.99342, f1_macro: 0.99647
# epoch: 42, passed number of graphs: 384, train running loss: 0.00160 (passed time: 2h 9m 35s)
#           acc: 0.99904, fpr: 0.00012, fnr: 0.01205, rec: 0.98795, prc: 0.99843, f1: 0.99316, f1_macro: 0.99632
# epoch: 42, passed number of graphs: 480, train running loss: 0.00160 (passed time: 2h 9m 56s)
#           acc: 0.99912, fpr: 0.00007, fnr: 0.01155, rec: 0.98845, prc: 0.99904, f1: 0.99372, f1_macro: 0.99662
# epoch: 42, passed number of graphs: 576, train running loss: 0.00160 (passed time: 2h 10m 17s)
#           acc: 0.99922, fpr: 0.00011, fnr: 0.00990, rec: 0.99010, prc: 0.99854, f1: 0.99430, f1_macro: 0.99694
# epoch: 42, passed number of graphs: 672, train running loss: 0.00160 (passed time: 2h 10m 38s)
#           acc: 0.99905, fpr: 0.00012, fnr: 0.01210, rec: 0.98790, prc: 0.99833, f1: 0.99309, f1_macro: 0.99629
# epoch: 42, passed number of graphs: 768, train running loss: 0.00160 (passed time: 2h 10m 59s)
#           acc: 0.99908, fpr: 0.00013, fnr: 0.01155, rec: 0.98845, prc: 0.99823, f1: 0.99332, f1_macro: 0.99641
# Validation --- epoch: 42, loss: 0.00304
#           f1_macro: 0.99674, f1: 0.99393, fnr: 0.01130, rec: 0.98870, prc: 0.99921, acc: 0.99916, fpr: 0.00006
# epoch: 43, passed number of graphs: 96, train running loss: 0.00160 (passed time: 2h 11m 41s)
#           acc: 0.99911, fpr: 0.00015, fnr: 0.01090, rec: 0.98910, prc: 0.99798, f1: 0.99352, f1_macro: 0.99652
# epoch: 43, passed number of graphs: 192, train running loss: 0.00160 (passed time: 2h 12m 2s)
#           acc: 0.99909, fpr: 0.00011, fnr: 0.01165, rec: 0.98835, prc: 0.99854, f1: 0.99342, f1_macro: 0.99646
# epoch: 43, passed number of graphs: 288, train running loss: 0.00160 (passed time: 2h 12m 23s)
#           acc: 0.99911, fpr: 0.00012, fnr: 0.01120, rec: 0.98880, prc: 0.99838, f1: 0.99357, f1_macro: 0.99655
# epoch: 43, passed number of graphs: 384, train running loss: 0.00160 (passed time: 2h 12m 44s)
#           acc: 0.99899, fpr: 0.00015, fnr: 0.01230, rec: 0.98770, prc: 0.99808, f1: 0.99286, f1_macro: 0.99616
# epoch: 43, passed number of graphs: 480, train running loss: 0.00160 (passed time: 2h 13m 5s)
#           acc: 0.99912, fpr: 0.00007, fnr: 0.01155, rec: 0.98845, prc: 0.99909, f1: 0.99374, f1_macro: 0.99663
# epoch: 43, passed number of graphs: 576, train running loss: 0.00160 (passed time: 2h 13m 26s)
#           acc: 0.99922, fpr: 0.00010, fnr: 0.00995, rec: 0.99005, prc: 0.99864, f1: 0.99433, f1_macro: 0.99695
# epoch: 43, passed number of graphs: 672, train running loss: 0.00160 (passed time: 2h 13m 47s)
#           acc: 0.99900, fpr: 0.00019, fnr: 0.01180, rec: 0.98820, prc: 0.99738, f1: 0.99277, f1_macro: 0.99612
# epoch: 43, passed number of graphs: 768, train running loss: 0.00160 (passed time: 2h 14m 8s)
#           acc: 0.99910, fpr: 0.00009, fnr: 0.01185, rec: 0.98815, prc: 0.99879, f1: 0.99344, f1_macro: 0.99648
# Validation --- epoch: 43, loss: 0.00304
#           f1_macro: 0.99674, f1: 0.99393, fnr: 0.01131, rec: 0.98869, prc: 0.99921, acc: 0.99916, fpr: 0.00006
# epoch: 44, passed number of graphs: 96, train running loss: 0.00160 (passed time: 2h 14m 49s)
#           acc: 0.99910, fpr: 0.00014, fnr: 0.01110, rec: 0.98890, prc: 0.99813, f1: 0.99349, f1_macro: 0.99651
# epoch: 44, passed number of graphs: 192, train running loss: 0.00160 (passed time: 2h 15m 11s)
#           acc: 0.99911, fpr: 0.00009, fnr: 0.01160, rec: 0.98840, prc: 0.99884, f1: 0.99359, f1_macro: 0.99656
# epoch: 44, passed number of graphs: 288, train running loss: 0.00160 (passed time: 2h 15m 31s)
#           acc: 0.99912, fpr: 0.00012, fnr: 0.01110, rec: 0.98890, prc: 0.99844, f1: 0.99364, f1_macro: 0.99659
# epoch: 44, passed number of graphs: 384, train running loss: 0.00160 (passed time: 2h 15m 53s)
#           acc: 0.99905, fpr: 0.00010, fnr: 0.01210, rec: 0.98790, prc: 0.99874, f1: 0.99329, f1_macro: 0.99639
# epoch: 44, passed number of graphs: 480, train running loss: 0.00160 (passed time: 2h 16m 14s)
#           acc: 0.99914, fpr: 0.00006, fnr: 0.01140, rec: 0.98860, prc: 0.99919, f1: 0.99387, f1_macro: 0.99670
# epoch: 44, passed number of graphs: 576, train running loss: 0.00160 (passed time: 2h 16m 35s)
#           acc: 0.99923, fpr: 0.00009, fnr: 0.00995, rec: 0.99005, prc: 0.99874, f1: 0.99438, f1_macro: 0.99698
# epoch: 44, passed number of graphs: 672, train running loss: 0.00160 (passed time: 2h 16m 56s)
#           acc: 0.99908, fpr: 0.00014, fnr: 0.01135, rec: 0.98865, prc: 0.99803, f1: 0.99332, f1_macro: 0.99641
# epoch: 44, passed number of graphs: 768, train running loss: 0.00160 (passed time: 2h 17m 17s)
#           acc: 0.99911, fpr: 0.00012, fnr: 0.01125, rec: 0.98875, prc: 0.99843, f1: 0.99357, f1_macro: 0.99655
# Validation --- epoch: 44, loss: 0.00305
#           f1_macro: 0.99673, f1: 0.99392, fnr: 0.01132, rec: 0.98867, prc: 0.99922, acc: 0.99916, fpr: 0.00006
# epoch: 45, passed number of graphs: 96, train running loss: 0.00161 (passed time: 2h 17m 58s)
#           acc: 0.99912, fpr: 0.00011, fnr: 0.01115, rec: 0.98885, prc: 0.99849, f1: 0.99364, f1_macro: 0.99659
# epoch: 45, passed number of graphs: 192, train running loss: 0.00160 (passed time: 2h 18m 19s)
#           acc: 0.99907, fpr: 0.00010, fnr: 0.01205, rec: 0.98795, prc: 0.99869, f1: 0.99329, f1_macro: 0.99639
# epoch: 45, passed number of graphs: 288, train running loss: 0.00160 (passed time: 2h 18m 40s)
#           acc: 0.99910, fpr: 0.00013, fnr: 0.01125, rec: 0.98875, prc: 0.99828, f1: 0.99349, f1_macro: 0.99651
# epoch: 45, passed number of graphs: 384, train running loss: 0.00160 (passed time: 2h 19m 1s)
#           acc: 0.99902, fpr: 0.00011, fnr: 0.01225, rec: 0.98775, prc: 0.99848, f1: 0.99309, f1_macro: 0.99628
# epoch: 45, passed number of graphs: 480, train running loss: 0.00160 (passed time: 2h 19m 22s)
#           acc: 0.99914, fpr: 0.00005, fnr: 0.01150, rec: 0.98850, prc: 0.99939, f1: 0.99392, f1_macro: 0.99673
# epoch: 45, passed number of graphs: 576, train running loss: 0.00160 (passed time: 2h 19m 44s)
#           acc: 0.99925, fpr: 0.00009, fnr: 0.00965, rec: 0.99035, prc: 0.99884, f1: 0.99458, f1_macro: 0.99709
# epoch: 45, passed number of graphs: 672, train running loss: 0.00160 (passed time: 2h 20m 5s)
#           acc: 0.99903, fpr: 0.00013, fnr: 0.01235, rec: 0.98765, prc: 0.99828, f1: 0.99294, f1_macro: 0.99621
# epoch: 45, passed number of graphs: 768, train running loss: 0.00160 (passed time: 2h 20m 26s)
#           acc: 0.99912, fpr: 0.00009, fnr: 0.01155, rec: 0.98845, prc: 0.99879, f1: 0.99359, f1_macro: 0.99656
# Validation --- epoch: 45, loss: 0.00305
#           f1_macro: 0.99674, f1: 0.99392, fnr: 0.01131, rec: 0.98869, prc: 0.99921, acc: 0.99916, fpr: 0.00006
# epoch: 46, passed number of graphs: 96, train running loss: 0.00161 (passed time: 2h 21m 7s)
#           acc: 0.99910, fpr: 0.00016, fnr: 0.01080, rec: 0.98920, prc: 0.99783, f1: 0.99350, f1_macro: 0.99651
# epoch: 46, passed number of graphs: 192, train running loss: 0.00160 (passed time: 2h 21m 29s)
#           acc: 0.99909, fpr: 0.00008, fnr: 0.01200, rec: 0.98800, prc: 0.99889, f1: 0.99341, f1_macro: 0.99646
# epoch: 46, passed number of graphs: 288, train running loss: 0.00160 (passed time: 2h 21m 50s)
#           acc: 0.99909, fpr: 0.00013, fnr: 0.01135, rec: 0.98865, prc: 0.99823, f1: 0.99342, f1_macro: 0.99647
# epoch: 46, passed number of graphs: 384, train running loss: 0.00160 (passed time: 2h 22m 11s)
#           acc: 0.99901, fpr: 0.00013, fnr: 0.01235, rec: 0.98765, prc: 0.99833, f1: 0.99296, f1_macro: 0.99621
# epoch: 46, passed number of graphs: 480, train running loss: 0.00160 (passed time: 2h 22m 32s)
#           acc: 0.99913, fpr: 0.00005, fnr: 0.01160, rec: 0.98840, prc: 0.99934, f1: 0.99384, f1_macro: 0.99669
# epoch: 46, passed number of graphs: 576, train running loss: 0.00160 (passed time: 2h 22m 53s)
#           acc: 0.99926, fpr: 0.00006, fnr: 0.00980, rec: 0.99020, prc: 0.99914, f1: 0.99465, f1_macro: 0.99713
# epoch: 46, passed number of graphs: 672, train running loss: 0.00160 (passed time: 2h 23m 14s)
#           acc: 0.99905, fpr: 0.00013, fnr: 0.01195, rec: 0.98805, prc: 0.99823, f1: 0.99311, f1_macro: 0.99630
# epoch: 46, passed number of graphs: 768, train running loss: 0.00160 (passed time: 2h 23m 35s)
#           acc: 0.99913, fpr: 0.00011, fnr: 0.01115, rec: 0.98885, prc: 0.99854, f1: 0.99367, f1_macro: 0.99660
# Validation --- epoch: 46, loss: 0.00304
#           f1_macro: 0.99674, f1: 0.99392, fnr: 0.01130, rec: 0.98870, prc: 0.99921, acc: 0.99916, fpr: 0.00006
# epoch: 47, passed number of graphs: 96, train running loss: 0.00161 (passed time: 2h 24m 17s)
#           acc: 0.99907, fpr: 0.00018, fnr: 0.01105, rec: 0.98895, prc: 0.99758, f1: 0.99325, f1_macro: 0.99637
# epoch: 47, passed number of graphs: 192, train running loss: 0.00160 (passed time: 2h 24m 38s)
#           acc: 0.99906, fpr: 0.00011, fnr: 0.01195, rec: 0.98805, prc: 0.99853, f1: 0.99326, f1_macro: 0.99638
# epoch: 47, passed number of graphs: 288, train running loss: 0.00160 (passed time: 2h 24m 59s)
#           acc: 0.99912, fpr: 0.00009, fnr: 0.01150, rec: 0.98850, prc: 0.99884, f1: 0.99364, f1_macro: 0.99659
# epoch: 47, passed number of graphs: 384, train running loss: 0.00160 (passed time: 2h 25m 20s)
#           acc: 0.99904, fpr: 0.00011, fnr: 0.01220, rec: 0.98780, prc: 0.99858, f1: 0.99316, f1_macro: 0.99632
# epoch: 47, passed number of graphs: 480, train running loss: 0.00160 (passed time: 2h 25m 41s)
#           acc: 0.99912, fpr: 0.00007, fnr: 0.01150, rec: 0.98850, prc: 0.99909, f1: 0.99377, f1_macro: 0.99665
# epoch: 47, passed number of graphs: 576, train running loss: 0.00160 (passed time: 2h 26m 2s)
#           acc: 0.99924, fpr: 0.00007, fnr: 0.01005, rec: 0.98995, prc: 0.99904, f1: 0.99447, f1_macro: 0.99703
# epoch: 47, passed number of graphs: 672, train running loss: 0.00160 (passed time: 2h 26m 23s)
#           acc: 0.99905, fpr: 0.00014, fnr: 0.01185, rec: 0.98815, prc: 0.99808, f1: 0.99309, f1_macro: 0.99629
# epoch: 47, passed number of graphs: 768, train running loss: 0.00160 (passed time: 2h 26m 44s)
#           acc: 0.99910, fpr: 0.00014, fnr: 0.01115, rec: 0.98885, prc: 0.99808, f1: 0.99344, f1_macro: 0.99648
# Validation --- epoch: 47, loss: 0.00305
#           f1_macro: 0.99674, f1: 0.99392, fnr: 0.01132, rec: 0.98868, prc: 0.99922, acc: 0.99916, fpr: 0.00006
# epoch: 48, passed number of graphs: 96, train running loss: 0.00161 (passed time: 2h 27m 26s)
#           acc: 0.99908, fpr: 0.00017, fnr: 0.01100, rec: 0.98900, prc: 0.99768, f1: 0.99332, f1_macro: 0.99641
# epoch: 48, passed number of graphs: 192, train running loss: 0.00160 (passed time: 2h 27m 47s)
#           acc: 0.99913, fpr: 0.00009, fnr: 0.01130, rec: 0.98870, prc: 0.99879, f1: 0.99372, f1_macro: 0.99662
# epoch: 48, passed number of graphs: 288, train running loss: 0.00160 (passed time: 2h 28m 8s)
#           acc: 0.99908, fpr: 0.00017, fnr: 0.01105, rec: 0.98895, prc: 0.99768, f1: 0.99330, f1_macro: 0.99640
# epoch: 48, passed number of graphs: 384, train running loss: 0.00160 (passed time: 2h 28m 29s)
#           acc: 0.99900, fpr: 0.00011, fnr: 0.01275, rec: 0.98725, prc: 0.99858, f1: 0.99288, f1_macro: 0.99617
# epoch: 48, passed number of graphs: 480, train running loss: 0.00160 (passed time: 2h 28m 50s)
#           acc: 0.99908, fpr: 0.00009, fnr: 0.01175, rec: 0.98825, prc: 0.99879, f1: 0.99349, f1_macro: 0.99650
# epoch: 48, passed number of graphs: 576, train running loss: 0.00160 (passed time: 2h 29m 11s)
#           acc: 0.99923, fpr: 0.00007, fnr: 0.01010, rec: 0.98990, prc: 0.99899, f1: 0.99442, f1_macro: 0.99701
# epoch: 48, passed number of graphs: 672, train running loss: 0.00160 (passed time: 2h 29m 32s)
#           acc: 0.99905, fpr: 0.00016, fnr: 0.01160, rec: 0.98840, prc: 0.99778, f1: 0.99307, f1_macro: 0.99628
# epoch: 48, passed number of graphs: 768, train running loss: 0.00160 (passed time: 2h 29m 54s)
#           acc: 0.99908, fpr: 0.00014, fnr: 0.01135, rec: 0.98865, prc: 0.99808, f1: 0.99334, f1_macro: 0.99643
# Validation --- epoch: 48, loss: 0.00304
#           f1_macro: 0.99674, f1: 0.99392, fnr: 0.01131, rec: 0.98869, prc: 0.99922, acc: 0.99916, fpr: 0.00006
# epoch: 49, passed number of graphs: 96, train running loss: 0.00161 (passed time: 2h 30m 35s)
#           acc: 0.99907, fpr: 0.00018, fnr: 0.01110, rec: 0.98890, prc: 0.99758, f1: 0.99322, f1_macro: 0.99636
# epoch: 49, passed number of graphs: 192, train running loss: 0.00160 (passed time: 2h 30m 56s)
#           acc: 0.99906, fpr: 0.00011, fnr: 0.01205, rec: 0.98795, prc: 0.99858, f1: 0.99324, f1_macro: 0.99637
# epoch: 49, passed number of graphs: 288, train running loss: 0.00160 (passed time: 2h 31m 17s)
#           acc: 0.99910, fpr: 0.00013, fnr: 0.01130, rec: 0.98870, prc: 0.99823, f1: 0.99344, f1_macro: 0.99648
# epoch: 49, passed number of graphs: 384, train running loss: 0.00160 (passed time: 2h 31m 38s)
#           acc: 0.99899, fpr: 0.00015, fnr: 0.01230, rec: 0.98770, prc: 0.99808, f1: 0.99286, f1_macro: 0.99616
# epoch: 49, passed number of graphs: 480, train running loss: 0.00160 (passed time: 2h 31m 59s)
#           acc: 0.99909, fpr: 0.00008, fnr: 0.01175, rec: 0.98825, prc: 0.99889, f1: 0.99354, f1_macro: 0.99653
# epoch: 49, passed number of graphs: 576, train running loss: 0.00160 (passed time: 2h 32m 20s)
#           acc: 0.99922, fpr: 0.00010, fnr: 0.00995, rec: 0.99005, prc: 0.99859, f1: 0.99430, f1_macro: 0.99694
# epoch: 49, passed number of graphs: 672, train running loss: 0.00160 (passed time: 2h 32m 41s)
#           acc: 0.99906, fpr: 0.00013, fnr: 0.01185, rec: 0.98815, prc: 0.99823, f1: 0.99317, f1_macro: 0.99633
# epoch: 49, passed number of graphs: 768, train running loss: 0.00160 (passed time: 2h 33m 2s)
#           acc: 0.99911, fpr: 0.00009, fnr: 0.01170, rec: 0.98830, prc: 0.99879, f1: 0.99352, f1_macro: 0.99652
# Validation --- epoch: 49, loss: 0.00305
#           f1_macro: 0.99673, f1: 0.99392, fnr: 0.01132, rec: 0.98868, prc: 0.99921, acc: 0.99916, fpr: 0.00006
# epoch: 50, passed number of graphs: 96, train running loss: 0.00161 (passed time: 2h 33m 44s)
#           acc: 0.99912, fpr: 0.00015, fnr: 0.01075, rec: 0.98925, prc: 0.99798, f1: 0.99360, f1_macro: 0.99656
# epoch: 50, passed number of graphs: 192, train running loss: 0.00160 (passed time: 2h 34m 5s)
#           acc: 0.99911, fpr: 0.00011, fnr: 0.01135, rec: 0.98865, prc: 0.99859, f1: 0.99359, f1_macro: 0.99656
# epoch: 50, passed number of graphs: 288, train running loss: 0.00160 (passed time: 2h 34m 26s)
#           acc: 0.99912, fpr: 0.00012, fnr: 0.01120, rec: 0.98880, prc: 0.99843, f1: 0.99359, f1_macro: 0.99656
# epoch: 50, passed number of graphs: 384, train running loss: 0.00160 (passed time: 2h 34m 47s)
#           acc: 0.99900, fpr: 0.00013, fnr: 0.01245, rec: 0.98755, prc: 0.99828, f1: 0.99289, f1_macro: 0.99617
# epoch: 50, passed number of graphs: 480, train running loss: 0.00160 (passed time: 2h 35m 8s)
#           acc: 0.99914, fpr: 0.00007, fnr: 0.01125, rec: 0.98875, prc: 0.99909, f1: 0.99389, f1_macro: 0.99672
# epoch: 50, passed number of graphs: 576, train running loss: 0.00160 (passed time: 2h 35m 29s)
#           acc: 0.99923, fpr: 0.00008, fnr: 0.01010, rec: 0.98990, prc: 0.99894, f1: 0.99440, f1_macro: 0.99699
# epoch: 50, passed number of graphs: 672, train running loss: 0.00160 (passed time: 2h 35m 50s)
#           acc: 0.99903, fpr: 0.00016, fnr: 0.01180, rec: 0.98820, prc: 0.99778, f1: 0.99297, f1_macro: 0.99622
# epoch: 50, passed number of graphs: 768, train running loss: 0.00160 (passed time: 2h 36m 11s)
#           acc: 0.99910, fpr: 0.00012, fnr: 0.01145, rec: 0.98855, prc: 0.99843, f1: 0.99347, f1_macro: 0.99649
# Validation --- epoch: 50, loss: 0.00304
#           f1_macro: 0.99674, f1: 0.99393, fnr: 0.01130, rec: 0.98870, prc: 0.99921, acc: 0.99916, fpr: 0.00006
# ************ best model obtained after epoch 14, saved at ./saved_models/GIN_13: 0.9945885459182402.pt ************
# Testing --- loss: 0.00282
#           f1_macro: 0.99702, f1: 0.99445, fnr: 0.01056, rec: 0.98944, prc: 0.99951, acc: 0.99923, fpr: 0.00004

# %% [markdown]
# 12GIN_MLP_4Layer_Chord
