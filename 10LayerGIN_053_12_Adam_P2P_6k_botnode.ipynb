# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/Do_an_tot_nghiep/blob/main/10LayerGIN_053_12_Adam_P2P_6k_botnode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric==1.4.3
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5
# !pip install torch-optimizer

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter_
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset
import torch_optimizer as optimization


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric==1.4.3 in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.21.6)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (6.2.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.18.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.6.3)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.23.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.56.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.3.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.0.2)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.7.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.12.1+cu113)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.7.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->torch-geometric==1.4.3) (1.5.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (4.13.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (0.39.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (4.1.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.4.3) (1.15.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (3.0.9)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (0.6.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2022.9.24)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (7.1.2)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (3.2.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2.9.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (1.3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2021.11.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-optimizer in /usr/local/lib/python3.7/dist-packages (0.3.0)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (1.12.1+cu113)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (0.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->torch-optimizer) (4.1.1)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
            self.num_graphs = 768
        elif split == 'val':
            self.path = self.processed_paths[1]
            self.num_graphs = 96
        elif split == 'test':
            self.path = self.processed_paths[2]
            self.num_graphs = 96

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GINConv, ARMAConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_input_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU())))
          else:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU()))) 

        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                add_xr_at = n
            if n == add_xr_at:
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/p2p_6k_botnode'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=True, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 2
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 10
num_classes = 2 

dropout = 0.0
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    class_weight = torch.Tensor([0.53, 12])
    class_weight = class_weight.cuda(device=0)
    criterion = torch.nn.CrossEntropyLoss(weight=class_weight)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    print(class_weight)
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-57515b7c-6fc8-49c5-91ad-41ca72ab3d29.json
# ------------------------------
# ------------------------------
# Wed Nov  2 23:53:25 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GINConv(nn=Sequential(
#       (0): Linear(in_features=1, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (1): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (2): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (3): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (4): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (5): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (6): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (7): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (8): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (9): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 2
# tensor([ 0.5300, 12.0000], device='cuda:0')
# epoch: 1, passed number of graphs: 96, train running loss: 0.26203 (passed time: 13s)
#           acc: 0.85169, fpr: 0.15421, fnr: 0.01612, rec: 0.98388, prc: 0.22159, f1: 0.36171, f1_macro: 0.63890
# epoch: 1, passed number of graphs: 192, train running loss: 0.17007 (passed time: 24s)
#           acc: 0.96847, fpr: 0.03289, fnr: 0.00050, rec: 0.99950, prc: 0.57185, f1: 0.72748, f1_macro: 0.85537
# epoch: 1, passed number of graphs: 288, train running loss: 0.12518 (passed time: 35s)
#           acc: 0.99080, fpr: 0.00702, fnr: 0.05935, rec: 0.94065, prc: 0.85363, f1: 0.89503, f1_macro: 0.94511
# epoch: 1, passed number of graphs: 384, train running loss: 0.10145 (passed time: 46s)
#           acc: 0.99861, fpr: 0.00115, fnr: 0.00663, rec: 0.99337, prc: 0.97511, f1: 0.98416, f1_macro: 0.99172
# epoch: 1, passed number of graphs: 480, train running loss: 0.08577 (passed time: 57s)
#           acc: 0.99454, fpr: 0.00562, fnr: 0.00191, rec: 0.99809, prc: 0.88757, f1: 0.93959, f1_macro: 0.96837
# epoch: 1, passed number of graphs: 576, train running loss: 0.07544 (passed time: 1m 9s)
#           acc: 0.99703, fpr: 0.00296, fnr: 0.00311, rec: 0.99689, prc: 0.93684, f1: 0.96593, f1_macro: 0.98219
# epoch: 1, passed number of graphs: 672, train running loss: 0.06779 (passed time: 1m 20s)
#           acc: 0.99282, fpr: 0.00473, fnr: 0.06214, rec: 0.93786, prc: 0.89822, f1: 0.91761, f1_macro: 0.95693
# epoch: 1, passed number of graphs: 768, train running loss: 0.06126 (passed time: 1m 31s)
#           acc: 0.99695, fpr: 0.00306, fnr: 0.00290, rec: 0.99710, prc: 0.93442, f1: 0.96475, f1_macro: 0.98158
# Validation --- epoch: 1, loss: 0.01226
#           f1: 0.97056, fnr: 0.01835, fpr: 0.00096, prc: 0.96477, acc: 0.99866, rec: 0.98165, f1_macro: 0.98494
# Better model saved at ./saved_models/GIN_0: 0.9705596921245333.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.01080 (passed time: 2m 18s)
#           acc: 0.99953, fpr: 0.00049, fnr: 0.00008, rec: 0.99992, prc: 0.98918, f1: 0.99452, f1_macro: 0.99714
# epoch: 2, passed number of graphs: 192, train running loss: 0.01180 (passed time: 2m 30s)
#           acc: 0.99951, fpr: 0.00051, fnr: 0.00000, rec: 1.00000, prc: 0.98861, f1: 0.99427, f1_macro: 0.99701
# epoch: 2, passed number of graphs: 288, train running loss: 0.01055 (passed time: 2m 41s)
#           acc: 0.99609, fpr: 0.00407, fnr: 0.00017, rec: 0.99983, prc: 0.91444, f1: 0.95523, f1_macro: 0.97659
# epoch: 2, passed number of graphs: 384, train running loss: 0.01099 (passed time: 2m 53s)
#           acc: 0.99959, fpr: 0.00042, fnr: 0.00025, rec: 0.99975, prc: 0.99084, f1: 0.99528, f1_macro: 0.99753
# epoch: 2, passed number of graphs: 480, train running loss: 0.01793 (passed time: 3m 4s)
#           acc: 0.97034, fpr: 0.03096, fnr: 0.00033, rec: 0.99967, prc: 0.58921, f1: 0.74142, f1_macro: 0.86284
# epoch: 2, passed number of graphs: 576, train running loss: 0.01861 (passed time: 3m 16s)
#           acc: 0.99358, fpr: 0.00663, fnr: 0.00172, rec: 0.99828, prc: 0.86901, f1: 0.92917, f1_macro: 0.96290
# epoch: 2, passed number of graphs: 672, train running loss: 0.01799 (passed time: 3m 27s)
#           acc: 0.99467, fpr: 0.00310, fnr: 0.05557, rec: 0.94443, prc: 0.93143, f1: 0.93789, f1_macro: 0.96755
# epoch: 2, passed number of graphs: 768, train running loss: 0.01745 (passed time: 3m 39s)
#           acc: 0.99325, fpr: 0.00704, fnr: 0.00008, rec: 0.99992, prc: 0.86115, f1: 0.92536, f1_macro: 0.96091
# Validation --- epoch: 2, loss: 0.05372
#           f1: 0.73817, fnr: 0.22212, fpr: 0.00755, prc: 0.72518, acc: 0.98784, rec: 0.77788, f1_macro: 0.86596
# epoch: 3, passed number of graphs: 96, train running loss: 0.01838 (passed time: 4m 9s)
#           acc: 0.99871, fpr: 0.00135, fnr: 0.00008, rec: 0.99992, prc: 0.97066, f1: 0.98507, f1_macro: 0.99220
# epoch: 3, passed number of graphs: 192, train running loss: 0.01560 (passed time: 4m 20s)
#           acc: 0.99949, fpr: 0.00053, fnr: 0.00000, rec: 1.00000, prc: 0.98812, f1: 0.99403, f1_macro: 0.99688
# epoch: 3, passed number of graphs: 288, train running loss: 0.01372 (passed time: 4m 32s)
#           acc: 0.99766, fpr: 0.00241, fnr: 0.00075, rec: 0.99925, prc: 0.94743, f1: 0.97265, f1_macro: 0.98571
# epoch: 3, passed number of graphs: 384, train running loss: 0.02253 (passed time: 4m 44s)
#           acc: 0.99068, fpr: 0.00949, fnr: 0.00573, rec: 0.99427, prc: 0.82614, f1: 0.90244, f1_macro: 0.94877
# epoch: 3, passed number of graphs: 480, train running loss: 0.02252 (passed time: 4m 55s)
#           acc: 0.99443, fpr: 0.00581, fnr: 0.00025, rec: 0.99975, prc: 0.88434, f1: 0.93851, f1_macro: 0.96780
# epoch: 3, passed number of graphs: 576, train running loss: 0.02070 (passed time: 5m 6s)
#           acc: 0.99432, fpr: 0.00590, fnr: 0.00049, rec: 0.99951, prc: 0.88171, f1: 0.93692, f1_macro: 0.96698
# epoch: 3, passed number of graphs: 672, train running loss: 0.01911 (passed time: 5m 18s)
#           acc: 0.99673, fpr: 0.00280, fnr: 0.01379, rec: 0.98621, prc: 0.94014, f1: 0.96263, f1_macro: 0.98046
# epoch: 3, passed number of graphs: 768, train running loss: 0.01793 (passed time: 5m 29s)
#           acc: 0.99778, fpr: 0.00228, fnr: 0.00099, rec: 0.99901, prc: 0.95045, f1: 0.97412, f1_macro: 0.98648
# Validation --- epoch: 3, loss: 0.00813
#           f1: 0.97969, fnr: 0.01378, fpr: 0.00063, prc: 0.97788, acc: 0.99909, rec: 0.98622, f1_macro: 0.98961
# Better model saved at ./saved_models/GIN_2: 0.9796878126263215.pt.
# epoch: 4, passed number of graphs: 96, train running loss: 0.00636 (passed time: 5m 59s)
#           acc: 0.99900, fpr: 0.00104, fnr: 0.00000, rec: 1.00000, prc: 0.97712, f1: 0.98843, f1_macro: 0.99395
# epoch: 4, passed number of graphs: 192, train running loss: 0.00627 (passed time: 6m 11s)
#           acc: 0.99978, fpr: 0.00023, fnr: 0.00008, rec: 0.99992, prc: 0.99480, f1: 0.99735, f1_macro: 0.99862
# epoch: 4, passed number of graphs: 288, train running loss: 0.00512 (passed time: 6m 22s)
#           acc: 0.99774, fpr: 0.00231, fnr: 0.00108, rec: 0.99892, prc: 0.94958, f1: 0.97362, f1_macro: 0.98622
# epoch: 4, passed number of graphs: 384, train running loss: 0.00448 (passed time: 6m 34s)
#           acc: 0.99972, fpr: 0.00027, fnr: 0.00041, rec: 0.99959, prc: 0.99398, f1: 0.99678, f1_macro: 0.99832
# epoch: 4, passed number of graphs: 480, train running loss: 0.00644 (passed time: 6m 45s)
#           acc: 0.99476, fpr: 0.00546, fnr: 0.00042, rec: 0.99958, prc: 0.89054, f1: 0.94192, f1_macro: 0.96959
# epoch: 4, passed number of graphs: 576, train running loss: 0.00736 (passed time: 6m 57s)
#           acc: 0.99608, fpr: 0.00408, fnr: 0.00041, rec: 0.99959, prc: 0.91520, f1: 0.95554, f1_macro: 0.97674
# epoch: 4, passed number of graphs: 672, train running loss: 0.00749 (passed time: 7m 8s)
#           acc: 0.99954, fpr: 0.00039, fnr: 0.00195, rec: 0.99805, prc: 0.99122, f1: 0.99462, f1_macro: 0.99719
# epoch: 4, passed number of graphs: 768, train running loss: 0.01142 (passed time: 7m 20s)
#           acc: 0.99009, fpr: 0.01002, fnr: 0.00754, rec: 0.99246, prc: 0.81232, f1: 0.89340, f1_macro: 0.94410
# Validation --- epoch: 4, loss: 0.01876
#           f1: 0.90234, fnr: 0.05344, fpr: 0.00365, prc: 0.87637, acc: 0.99527, rec: 0.94656, f1_macro: 0.94996
# epoch: 5, passed number of graphs: 96, train running loss: 0.01992 (passed time: 7m 50s)
#           acc: 0.99031, fpr: 0.00996, fnr: 0.00365, rec: 0.99635, prc: 0.81693, f1: 0.89776, f1_macro: 0.94634
# epoch: 5, passed number of graphs: 192, train running loss: 0.01923 (passed time: 8m 1s)
#           acc: 0.99827, fpr: 0.00173, fnr: 0.00174, rec: 0.99826, prc: 0.96198, f1: 0.97978, f1_macro: 0.98944
# epoch: 5, passed number of graphs: 288, train running loss: 0.01747 (passed time: 8m 13s)
#           acc: 0.99762, fpr: 0.00246, fnr: 0.00050, rec: 0.99950, prc: 0.94655, f1: 0.97230, f1_macro: 0.98553
# epoch: 5, passed number of graphs: 384, train running loss: 0.01598 (passed time: 8m 24s)
#           acc: 0.99941, fpr: 0.00061, fnr: 0.00000, rec: 1.00000, prc: 0.98668, f1: 0.99330, f1_macro: 0.99650
# epoch: 5, passed number of graphs: 480, train running loss: 0.01586 (passed time: 8m 36s)
#           acc: 0.99752, fpr: 0.00256, fnr: 0.00083, rec: 0.99917, prc: 0.94552, f1: 0.97161, f1_macro: 0.98515
# epoch: 5, passed number of graphs: 576, train running loss: 0.01551 (passed time: 8m 47s)
#           acc: 0.98616, fpr: 0.01442, fnr: 0.00049, rec: 0.99951, prc: 0.75315, f1: 0.85901, f1_macro: 0.92587
# epoch: 5, passed number of graphs: 672, train running loss: 0.01553 (passed time: 8m 58s)
#           acc: 0.99571, fpr: 0.00195, fnr: 0.05670, rec: 0.94330, prc: 0.95562, f1: 0.94942, f1_macro: 0.97359
# epoch: 5, passed number of graphs: 768, train running loss: 0.01490 (passed time: 9m 10s)
#           acc: 0.99813, fpr: 0.00192, fnr: 0.00075, rec: 0.99925, prc: 0.95777, f1: 0.97807, f1_macro: 0.98855
# Validation --- epoch: 5, loss: 0.15830
#           f1: 0.52926, fnr: 0.00820, fpr: 0.04044, prc: 0.36479, acc: 0.96025, rec: 0.99180, f1_macro: 0.75424
# epoch: 6, passed number of graphs: 96, train running loss: 0.00558 (passed time: 9m 40s)
#           acc: 0.99991, fpr: 0.00009, fnr: 0.00008, rec: 0.99992, prc: 0.99798, f1: 0.99895, f1_macro: 0.99945
# epoch: 6, passed number of graphs: 192, train running loss: 0.00580 (passed time: 9m 51s)
#           acc: 0.99932, fpr: 0.00071, fnr: 0.00008, rec: 0.99992, prc: 0.98409, f1: 0.99194, f1_macro: 0.99579
# epoch: 6, passed number of graphs: 288, train running loss: 0.00505 (passed time: 10m 3s)
#           acc: 0.99852, fpr: 0.00153, fnr: 0.00033, rec: 0.99967, prc: 0.96599, f1: 0.98254, f1_macro: 0.99088
# epoch: 6, passed number of graphs: 384, train running loss: 0.00493 (passed time: 10m 14s)
#           acc: 0.99973, fpr: 0.00024, fnr: 0.00074, rec: 0.99926, prc: 0.99463, f1: 0.99694, f1_macro: 0.99840
# epoch: 6, passed number of graphs: 480, train running loss: 0.00473 (passed time: 10m 26s)
#           acc: 0.99964, fpr: 0.00037, fnr: 0.00017, rec: 0.99983, prc: 0.99168, f1: 0.99574, f1_macro: 0.99777
# epoch: 6, passed number of graphs: 576, train running loss: 0.00421 (passed time: 10m 37s)
#           acc: 0.99960, fpr: 0.00041, fnr: 0.00016, rec: 0.99984, prc: 0.99066, f1: 0.99523, f1_macro: 0.99751
# epoch: 6, passed number of graphs: 672, train running loss: 0.00391 (passed time: 10m 48s)
#           acc: 0.99954, fpr: 0.00044, fnr: 0.00097, rec: 0.99903, prc: 0.99027, f1: 0.99463, f1_macro: 0.99719
# epoch: 6, passed number of graphs: 768, train running loss: 0.00400 (passed time: 11m 0s)
#           acc: 0.99943, fpr: 0.00052, fnr: 0.00182, rec: 0.99818, prc: 0.98828, f1: 0.99320, f1_macro: 0.99645
# Validation --- epoch: 6, loss: 0.00915
#           f1: 0.96924, fnr: 0.00471, fpr: 0.00136, prc: 0.94876, acc: 0.99857, rec: 0.99529, f1_macro: 0.98426
# epoch: 7, passed number of graphs: 96, train running loss: 0.00298 (passed time: 11m 30s)
#           acc: 0.99992, fpr: 0.00007, fnr: 0.00016, rec: 0.99984, prc: 0.99838, f1: 0.99911, f1_macro: 0.99953
# epoch: 7, passed number of graphs: 192, train running loss: 0.00261 (passed time: 11m 41s)
#           acc: 0.99988, fpr: 0.00010, fnr: 0.00050, rec: 0.99950, prc: 0.99768, f1: 0.99859, f1_macro: 0.99927
# epoch: 7, passed number of graphs: 288, train running loss: 0.00223 (passed time: 11m 53s)
#           acc: 0.99972, fpr: 0.00027, fnr: 0.00042, rec: 0.99958, prc: 0.99373, f1: 0.99665, f1_macro: 0.99825
# epoch: 7, passed number of graphs: 384, train running loss: 0.00208 (passed time: 12m 4s)
#           acc: 0.99972, fpr: 0.00027, fnr: 0.00041, rec: 0.99959, prc: 0.99398, f1: 0.99678, f1_macro: 0.99832
# epoch: 7, passed number of graphs: 480, train running loss: 0.00212 (passed time: 12m 16s)
#           acc: 0.99970, fpr: 0.00029, fnr: 0.00042, rec: 0.99958, prc: 0.99348, f1: 0.99652, f1_macro: 0.99818
# epoch: 7, passed number of graphs: 576, train running loss: 0.00195 (passed time: 12m 27s)
#           acc: 0.99957, fpr: 0.00044, fnr: 0.00016, rec: 0.99984, prc: 0.99018, f1: 0.99498, f1_macro: 0.99738
# epoch: 7, passed number of graphs: 672, train running loss: 0.00187 (passed time: 12m 38s)
#           acc: 0.99945, fpr: 0.00057, fnr: 0.00000, rec: 1.00000, prc: 0.98734, f1: 0.99363, f1_macro: 0.99667
# epoch: 7, passed number of graphs: 768, train running loss: 0.00179 (passed time: 12m 50s)
#           acc: 0.99979, fpr: 0.00022, fnr: 0.00000, rec: 1.00000, prc: 0.99489, f1: 0.99744, f1_macro: 0.99866
# Validation --- epoch: 7, loss: 0.08584
#           f1: 0.75386, fnr: 0.00423, fpr: 0.01680, prc: 0.62584, acc: 0.98347, rec: 0.99577, f1_macro: 0.87264
# epoch: 8, passed number of graphs: 96, train running loss: 0.00117 (passed time: 13m 20s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00008, rec: 0.99992, prc: 0.99838, f1: 0.99915, f1_macro: 0.99956
# epoch: 8, passed number of graphs: 192, train running loss: 0.00112 (passed time: 13m 32s)
#           acc: 0.99990, fpr: 0.00011, fnr: 0.00008, rec: 0.99992, prc: 0.99760, f1: 0.99876, f1_macro: 0.99935
# epoch: 8, passed number of graphs: 288, train running loss: 0.00103 (passed time: 13m 43s)
#           acc: 0.99977, fpr: 0.00023, fnr: 0.00017, rec: 0.99983, prc: 0.99463, f1: 0.99723, f1_macro: 0.99855
# epoch: 8, passed number of graphs: 384, train running loss: 0.00100 (passed time: 13m 54s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00041, rec: 0.99959, prc: 0.99422, f1: 0.99690, f1_macro: 0.99838
# epoch: 8, passed number of graphs: 480, train running loss: 0.00103 (passed time: 14m 6s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00033, rec: 0.99967, prc: 0.99413, f1: 0.99689, f1_macro: 0.99838
# epoch: 8, passed number of graphs: 576, train running loss: 0.00098 (passed time: 14m 17s)
#           acc: 0.99958, fpr: 0.00043, fnr: 0.00016, rec: 0.99984, prc: 0.99034, f1: 0.99507, f1_macro: 0.99742
# epoch: 8, passed number of graphs: 672, train running loss: 0.00097 (passed time: 14m 29s)
#           acc: 0.99951, fpr: 0.00051, fnr: 0.00008, rec: 0.99992, prc: 0.98877, f1: 0.99431, f1_macro: 0.99703
# epoch: 8, passed number of graphs: 768, train running loss: 0.00098 (passed time: 14m 40s)
#           acc: 0.99981, fpr: 0.00020, fnr: 0.00000, rec: 1.00000, prc: 0.99547, f1: 0.99773, f1_macro: 0.99881
# Validation --- epoch: 8, loss: 0.00257
#           f1: 0.99301, fnr: 0.00431, fpr: 0.00020, prc: 0.99170, acc: 0.99971, rec: 0.99569, f1_macro: 0.99643
# Better model saved at ./saved_models/GIN_7: 0.9930146115570548.pt.
# epoch: 9, passed number of graphs: 96, train running loss: 0.00101 (passed time: 15m 11s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00008, rec: 0.99992, prc: 0.99846, f1: 0.99919, f1_macro: 0.99958
# epoch: 9, passed number of graphs: 192, train running loss: 0.00099 (passed time: 15m 22s)
#           acc: 0.99990, fpr: 0.00010, fnr: 0.00008, rec: 0.99992, prc: 0.99768, f1: 0.99880, f1_macro: 0.99937
# epoch: 9, passed number of graphs: 288, train running loss: 0.00090 (passed time: 15m 34s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00025, rec: 0.99975, prc: 0.99455, f1: 0.99714, f1_macro: 0.99851
# epoch: 9, passed number of graphs: 384, train running loss: 0.00088 (passed time: 15m 45s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00033, rec: 0.99967, prc: 0.99414, f1: 0.99690, f1_macro: 0.99838
# epoch: 9, passed number of graphs: 480, train running loss: 0.00091 (passed time: 15m 56s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00033, rec: 0.99967, prc: 0.99438, f1: 0.99702, f1_macro: 0.99844
# epoch: 9, passed number of graphs: 576, train running loss: 0.00088 (passed time: 16m 8s)
#           acc: 0.99957, fpr: 0.00043, fnr: 0.00025, rec: 0.99975, prc: 0.99026, f1: 0.99498, f1_macro: 0.99738
# epoch: 9, passed number of graphs: 672, train running loss: 0.00087 (passed time: 16m 19s)
#           acc: 0.99947, fpr: 0.00055, fnr: 0.00016, rec: 0.99984, prc: 0.98790, f1: 0.99383, f1_macro: 0.99678
# epoch: 9, passed number of graphs: 768, train running loss: 0.00088 (passed time: 16m 31s)
#           acc: 0.99981, fpr: 0.00020, fnr: 0.00000, rec: 1.00000, prc: 0.99547, f1: 0.99773, f1_macro: 0.99881
# Validation --- epoch: 9, loss: 0.00273
#           f1: 0.99094, fnr: 0.00429, fpr: 0.00029, prc: 0.98779, acc: 0.99962, rec: 0.99571, f1_macro: 0.99537
# epoch: 10, passed number of graphs: 96, train running loss: 0.00098 (passed time: 17m 1s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99822, f1: 0.99907, f1_macro: 0.99951
# epoch: 10, passed number of graphs: 192, train running loss: 0.00094 (passed time: 17m 13s)
#           acc: 0.99989, fpr: 0.00011, fnr: 0.00017, rec: 0.99983, prc: 0.99760, f1: 0.99872, f1_macro: 0.99933
# epoch: 10, passed number of graphs: 288, train running loss: 0.00085 (passed time: 17m 24s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00025, rec: 0.99975, prc: 0.99447, f1: 0.99710, f1_macro: 0.99849
# epoch: 10, passed number of graphs: 384, train running loss: 0.00083 (passed time: 17m 36s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00033, rec: 0.99967, prc: 0.99422, f1: 0.99694, f1_macro: 0.99840
# epoch: 10, passed number of graphs: 480, train running loss: 0.00087 (passed time: 17m 47s)
#           acc: 0.99975, fpr: 0.00024, fnr: 0.00042, rec: 0.99958, prc: 0.99463, f1: 0.99710, f1_macro: 0.99849
# epoch: 10, passed number of graphs: 576, train running loss: 0.00083 (passed time: 17m 59s)
#           acc: 0.99958, fpr: 0.00043, fnr: 0.00025, rec: 0.99975, prc: 0.99034, f1: 0.99502, f1_macro: 0.99740
# epoch: 10, passed number of graphs: 672, train running loss: 0.00083 (passed time: 18m 10s)
#           acc: 0.99947, fpr: 0.00055, fnr: 0.00016, rec: 0.99984, prc: 0.98790, f1: 0.99383, f1_macro: 0.99678
# epoch: 10, passed number of graphs: 768, train running loss: 0.00084 (passed time: 18m 21s)
#           acc: 0.99981, fpr: 0.00020, fnr: 0.00000, rec: 1.00000, prc: 0.99547, f1: 0.99773, f1_macro: 0.99881
# Validation --- epoch: 10, loss: 0.00509
#           f1: 0.97933, fnr: 0.00429, fpr: 0.00088, prc: 0.96685, acc: 0.99905, rec: 0.99571, f1_macro: 0.98942
# epoch: 11, passed number of graphs: 96, train running loss: 0.00087 (passed time: 18m 52s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00008, rec: 0.99992, prc: 0.99846, f1: 0.99919, f1_macro: 0.99958
# epoch: 11, passed number of graphs: 192, train running loss: 0.00085 (passed time: 19m 4s)
#           acc: 0.99988, fpr: 0.00011, fnr: 0.00017, rec: 0.99983, prc: 0.99744, f1: 0.99863, f1_macro: 0.99929
# epoch: 11, passed number of graphs: 288, train running loss: 0.00078 (passed time: 19m 15s)
#           acc: 0.99976, fpr: 0.00025, fnr: 0.00008, rec: 0.99992, prc: 0.99439, f1: 0.99714, f1_macro: 0.99851
# epoch: 11, passed number of graphs: 384, train running loss: 0.00077 (passed time: 19m 27s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00033, rec: 0.99967, prc: 0.99406, f1: 0.99686, f1_macro: 0.99836
# epoch: 11, passed number of graphs: 480, train running loss: 0.00081 (passed time: 19m 38s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00033, rec: 0.99967, prc: 0.99405, f1: 0.99685, f1_macro: 0.99836
# epoch: 11, passed number of graphs: 576, train running loss: 0.00077 (passed time: 19m 49s)
#           acc: 0.99956, fpr: 0.00045, fnr: 0.00016, rec: 0.99984, prc: 0.98986, f1: 0.99482, f1_macro: 0.99730
# epoch: 11, passed number of graphs: 672, train running loss: 0.00077 (passed time: 20m 1s)
#           acc: 0.99951, fpr: 0.00051, fnr: 0.00008, rec: 0.99992, prc: 0.98861, f1: 0.99423, f1_macro: 0.99699
# epoch: 11, passed number of graphs: 768, train running loss: 0.00078 (passed time: 20m 12s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00000, rec: 1.00000, prc: 0.99579, f1: 0.99789, f1_macro: 0.99890
# Validation --- epoch: 11, loss: 0.00201
#           f1: 0.99384, fnr: 0.00434, fpr: 0.00016, prc: 0.99331, acc: 0.99975, rec: 0.99566, f1_macro: 0.99685
# Better model saved at ./saved_models/GIN_10: 0.993836406215685.pt.
# epoch: 12, passed number of graphs: 96, train running loss: 0.00085 (passed time: 20m 43s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00008, rec: 0.99992, prc: 0.99838, f1: 0.99915, f1_macro: 0.99956
# epoch: 12, passed number of graphs: 192, train running loss: 0.00084 (passed time: 20m 54s)
#           acc: 0.99989, fpr: 0.00011, fnr: 0.00017, rec: 0.99983, prc: 0.99760, f1: 0.99872, f1_macro: 0.99933
# epoch: 12, passed number of graphs: 288, train running loss: 0.00077 (passed time: 21m 6s)
#           acc: 0.99976, fpr: 0.00025, fnr: 0.00017, rec: 0.99983, prc: 0.99439, f1: 0.99710, f1_macro: 0.99849
# epoch: 12, passed number of graphs: 384, train running loss: 0.00075 (passed time: 21m 17s)
#           acc: 0.99972, fpr: 0.00027, fnr: 0.00041, rec: 0.99959, prc: 0.99398, f1: 0.99678, f1_macro: 0.99832
# epoch: 12, passed number of graphs: 480, train running loss: 0.00079 (passed time: 21m 28s)
#           acc: 0.99974, fpr: 0.00026, fnr: 0.00033, rec: 0.99967, prc: 0.99422, f1: 0.99693, f1_macro: 0.99840
# epoch: 12, passed number of graphs: 576, train running loss: 0.00076 (passed time: 21m 40s)
#           acc: 0.99956, fpr: 0.00045, fnr: 0.00016, rec: 0.99984, prc: 0.98986, f1: 0.99482, f1_macro: 0.99730
# epoch: 12, passed number of graphs: 672, train running loss: 0.00076 (passed time: 21m 51s)
#           acc: 0.99949, fpr: 0.00053, fnr: 0.00008, rec: 0.99992, prc: 0.98829, f1: 0.99407, f1_macro: 0.99690
# epoch: 12, passed number of graphs: 768, train running loss: 0.00077 (passed time: 22m 3s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00000, rec: 1.00000, prc: 0.99563, f1: 0.99781, f1_macro: 0.99886
# Validation --- epoch: 12, loss: 0.00206
#           f1: 0.99359, fnr: 0.00431, fpr: 0.00017, prc: 0.99282, acc: 0.99974, rec: 0.99569, f1_macro: 0.99673
# epoch: 13, passed number of graphs: 96, train running loss: 0.00084 (passed time: 22m 33s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00008, rec: 0.99992, prc: 0.99838, f1: 0.99915, f1_macro: 0.99956
# epoch: 13, passed number of graphs: 192, train running loss: 0.00083 (passed time: 22m 44s)
#           acc: 0.99990, fpr: 0.00010, fnr: 0.00017, rec: 0.99983, prc: 0.99768, f1: 0.99876, f1_macro: 0.99935
# epoch: 13, passed number of graphs: 288, train running loss: 0.00076 (passed time: 22m 56s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00017, rec: 0.99983, prc: 0.99455, f1: 0.99719, f1_macro: 0.99853
# epoch: 13, passed number of graphs: 384, train running loss: 0.00074 (passed time: 23m 7s)
#           acc: 0.99972, fpr: 0.00027, fnr: 0.00041, rec: 0.99959, prc: 0.99398, f1: 0.99678, f1_macro: 0.99832
# epoch: 13, passed number of graphs: 480, train running loss: 0.00078 (passed time: 23m 19s)
#           acc: 0.99974, fpr: 0.00026, fnr: 0.00033, rec: 0.99967, prc: 0.99422, f1: 0.99693, f1_macro: 0.99840
# epoch: 13, passed number of graphs: 576, train running loss: 0.00075 (passed time: 23m 30s)
#           acc: 0.99955, fpr: 0.00046, fnr: 0.00016, rec: 0.99984, prc: 0.98970, f1: 0.99474, f1_macro: 0.99725
# epoch: 13, passed number of graphs: 672, train running loss: 0.00075 (passed time: 23m 42s)
#           acc: 0.99948, fpr: 0.00053, fnr: 0.00008, rec: 0.99992, prc: 0.98814, f1: 0.99399, f1_macro: 0.99686
# epoch: 13, passed number of graphs: 768, train running loss: 0.00076 (passed time: 23m 53s)
#           acc: 0.99981, fpr: 0.00020, fnr: 0.00000, rec: 1.00000, prc: 0.99538, f1: 0.99769, f1_macro: 0.99879
# Validation --- epoch: 13, loss: 0.00218
#           f1: 0.99288, fnr: 0.00426, fpr: 0.00020, prc: 0.99140, acc: 0.99971, rec: 0.99574, f1_macro: 0.99636
# epoch: 14, passed number of graphs: 96, train running loss: 0.00082 (passed time: 24m 23s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00008, rec: 0.99992, prc: 0.99846, f1: 0.99919, f1_macro: 0.99958
# epoch: 14, passed number of graphs: 192, train running loss: 0.00081 (passed time: 24m 35s)
#           acc: 0.99989, fpr: 0.00011, fnr: 0.00008, rec: 0.99992, prc: 0.99752, f1: 0.99872, f1_macro: 0.99933
# epoch: 14, passed number of graphs: 288, train running loss: 0.00074 (passed time: 24m 46s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00008, rec: 0.99992, prc: 0.99447, f1: 0.99719, f1_macro: 0.99853
# epoch: 14, passed number of graphs: 384, train running loss: 0.00073 (passed time: 24m 58s)
#           acc: 0.99971, fpr: 0.00028, fnr: 0.00041, rec: 0.99959, prc: 0.99382, f1: 0.99670, f1_macro: 0.99827
# epoch: 14, passed number of graphs: 480, train running loss: 0.00077 (passed time: 25m 9s)
#           acc: 0.99973, fpr: 0.00028, fnr: 0.00017, rec: 0.99983, prc: 0.99381, f1: 0.99681, f1_macro: 0.99833
# epoch: 14, passed number of graphs: 576, train running loss: 0.00074 (passed time: 25m 21s)
#           acc: 0.99958, fpr: 0.00043, fnr: 0.00016, rec: 0.99984, prc: 0.99034, f1: 0.99507, f1_macro: 0.99742
# epoch: 14, passed number of graphs: 672, train running loss: 0.00074 (passed time: 25m 32s)
#           acc: 0.99950, fpr: 0.00051, fnr: 0.00016, rec: 0.99984, prc: 0.98861, f1: 0.99419, f1_macro: 0.99697
# epoch: 14, passed number of graphs: 768, train running loss: 0.00075 (passed time: 25m 43s)
#           acc: 0.99985, fpr: 0.00016, fnr: 0.00000, rec: 1.00000, prc: 0.99637, f1: 0.99818, f1_macro: 0.99905
# Validation --- epoch: 14, loss: 0.00188
#           f1: 0.99400, fnr: 0.00439, fpr: 0.00015, prc: 0.99370, acc: 0.99976, rec: 0.99561, f1_macro: 0.99694
# Better model saved at ./saved_models/GIN_13: 0.9940035970164236.pt.
# epoch: 15, passed number of graphs: 96, train running loss: 0.00082 (passed time: 26m 13s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99830, f1: 0.99911, f1_macro: 0.99953
# epoch: 15, passed number of graphs: 192, train running loss: 0.00081 (passed time: 26m 25s)
#           acc: 0.99990, fpr: 0.00011, fnr: 0.00008, rec: 0.99992, prc: 0.99760, f1: 0.99876, f1_macro: 0.99935
# epoch: 15, passed number of graphs: 288, train running loss: 0.00074 (passed time: 26m 36s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00008, rec: 0.99992, prc: 0.99447, f1: 0.99719, f1_macro: 0.99853
# epoch: 15, passed number of graphs: 384, train running loss: 0.00073 (passed time: 26m 48s)
#           acc: 0.99971, fpr: 0.00028, fnr: 0.00041, rec: 0.99959, prc: 0.99382, f1: 0.99670, f1_macro: 0.99827
# epoch: 15, passed number of graphs: 480, train running loss: 0.00077 (passed time: 26m 59s)
#           acc: 0.99973, fpr: 0.00028, fnr: 0.00017, rec: 0.99983, prc: 0.99381, f1: 0.99681, f1_macro: 0.99833
# epoch: 15, passed number of graphs: 576, train running loss: 0.00074 (passed time: 27m 11s)
#           acc: 0.99958, fpr: 0.00043, fnr: 0.00016, rec: 0.99984, prc: 0.99034, f1: 0.99507, f1_macro: 0.99742
# epoch: 15, passed number of graphs: 672, train running loss: 0.00074 (passed time: 27m 22s)
#           acc: 0.99951, fpr: 0.00051, fnr: 0.00016, rec: 0.99984, prc: 0.98869, f1: 0.99423, f1_macro: 0.99699
# epoch: 15, passed number of graphs: 768, train running loss: 0.00075 (passed time: 27m 34s)
#           acc: 0.99985, fpr: 0.00016, fnr: 0.00000, rec: 1.00000, prc: 0.99637, f1: 0.99818, f1_macro: 0.99905
# Validation --- epoch: 15, loss: 0.00186
#           f1: 0.99401, fnr: 0.00439, fpr: 0.00015, prc: 0.99372, acc: 0.99976, rec: 0.99561, f1_macro: 0.99694
# Better model saved at ./saved_models/GIN_14: 0.9940126036853445.pt.
# epoch: 16, passed number of graphs: 96, train running loss: 0.00082 (passed time: 28m 4s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99830, f1: 0.99911, f1_macro: 0.99953
# epoch: 16, passed number of graphs: 192, train running loss: 0.00080 (passed time: 28m 15s)
#           acc: 0.99990, fpr: 0.00010, fnr: 0.00008, rec: 0.99992, prc: 0.99768, f1: 0.99880, f1_macro: 0.99937
# epoch: 16, passed number of graphs: 288, train running loss: 0.00074 (passed time: 28m 27s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00008, rec: 0.99992, prc: 0.99447, f1: 0.99719, f1_macro: 0.99853
# epoch: 16, passed number of graphs: 384, train running loss: 0.00073 (passed time: 28m 38s)
#           acc: 0.99971, fpr: 0.00028, fnr: 0.00041, rec: 0.99959, prc: 0.99382, f1: 0.99670, f1_macro: 0.99827
# epoch: 16, passed number of graphs: 480, train running loss: 0.00077 (passed time: 28m 49s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99389, f1: 0.99685, f1_macro: 0.99836
# epoch: 16, passed number of graphs: 576, train running loss: 0.00073 (passed time: 29m 1s)
#           acc: 0.99958, fpr: 0.00043, fnr: 0.00016, rec: 0.99984, prc: 0.99034, f1: 0.99507, f1_macro: 0.99742
# epoch: 16, passed number of graphs: 672, train running loss: 0.00073 (passed time: 29m 12s)
#           acc: 0.99951, fpr: 0.00051, fnr: 0.00016, rec: 0.99984, prc: 0.98877, f1: 0.99427, f1_macro: 0.99701
# epoch: 16, passed number of graphs: 768, train running loss: 0.00075 (passed time: 29m 24s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00000, rec: 1.00000, prc: 0.99629, f1: 0.99814, f1_macro: 0.99903
# Validation --- epoch: 16, loss: 0.00186
#           f1: 0.99400, fnr: 0.00438, fpr: 0.00015, prc: 0.99368, acc: 0.99976, rec: 0.99562, f1_macro: 0.99694
# epoch: 17, passed number of graphs: 96, train running loss: 0.00082 (passed time: 29m 54s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00008, rec: 0.99992, prc: 0.99838, f1: 0.99915, f1_macro: 0.99956
# epoch: 17, passed number of graphs: 192, train running loss: 0.00080 (passed time: 30m 5s)
#           acc: 0.99990, fpr: 0.00010, fnr: 0.00008, rec: 0.99992, prc: 0.99768, f1: 0.99880, f1_macro: 0.99937
# epoch: 17, passed number of graphs: 288, train running loss: 0.00073 (passed time: 30m 17s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00008, rec: 0.99992, prc: 0.99447, f1: 0.99719, f1_macro: 0.99853
# epoch: 17, passed number of graphs: 384, train running loss: 0.00072 (passed time: 30m 28s)
#           acc: 0.99971, fpr: 0.00028, fnr: 0.00041, rec: 0.99959, prc: 0.99382, f1: 0.99670, f1_macro: 0.99827
# epoch: 17, passed number of graphs: 480, train running loss: 0.00076 (passed time: 30m 40s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99389, f1: 0.99685, f1_macro: 0.99836
# epoch: 17, passed number of graphs: 576, train running loss: 0.00073 (passed time: 30m 51s)
#           acc: 0.99958, fpr: 0.00043, fnr: 0.00016, rec: 0.99984, prc: 0.99034, f1: 0.99507, f1_macro: 0.99742
# epoch: 17, passed number of graphs: 672, train running loss: 0.00073 (passed time: 31m 2s)
#           acc: 0.99951, fpr: 0.00051, fnr: 0.00016, rec: 0.99984, prc: 0.98877, f1: 0.99427, f1_macro: 0.99701
# epoch: 17, passed number of graphs: 768, train running loss: 0.00074 (passed time: 31m 14s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00000, rec: 1.00000, prc: 0.99629, f1: 0.99814, f1_macro: 0.99903
# Validation --- epoch: 17, loss: 0.00187
#           f1: 0.99399, fnr: 0.00437, fpr: 0.00015, prc: 0.99364, acc: 0.99976, rec: 0.99563, f1_macro: 0.99693
# epoch: 18, passed number of graphs: 96, train running loss: 0.00082 (passed time: 31m 44s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00008, rec: 0.99992, prc: 0.99838, f1: 0.99915, f1_macro: 0.99956
# epoch: 18, passed number of graphs: 192, train running loss: 0.00080 (passed time: 31m 55s)
#           acc: 0.99990, fpr: 0.00010, fnr: 0.00008, rec: 0.99992, prc: 0.99768, f1: 0.99880, f1_macro: 0.99937
# epoch: 18, passed number of graphs: 288, train running loss: 0.00073 (passed time: 32m 7s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00008, rec: 0.99992, prc: 0.99447, f1: 0.99719, f1_macro: 0.99853
# epoch: 18, passed number of graphs: 384, train running loss: 0.00072 (passed time: 32m 18s)
#           acc: 0.99971, fpr: 0.00028, fnr: 0.00041, rec: 0.99959, prc: 0.99382, f1: 0.99670, f1_macro: 0.99827
# epoch: 18, passed number of graphs: 480, train running loss: 0.00076 (passed time: 32m 30s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99389, f1: 0.99685, f1_macro: 0.99836
# epoch: 18, passed number of graphs: 576, train running loss: 0.00073 (passed time: 32m 41s)
#           acc: 0.99958, fpr: 0.00043, fnr: 0.00016, rec: 0.99984, prc: 0.99034, f1: 0.99507, f1_macro: 0.99742
# epoch: 18, passed number of graphs: 672, train running loss: 0.00073 (passed time: 32m 52s)
#           acc: 0.99951, fpr: 0.00051, fnr: 0.00016, rec: 0.99984, prc: 0.98869, f1: 0.99423, f1_macro: 0.99699
# epoch: 18, passed number of graphs: 768, train running loss: 0.00074 (passed time: 33m 4s)
#           acc: 0.99984, fpr: 0.00017, fnr: 0.00000, rec: 1.00000, prc: 0.99621, f1: 0.99810, f1_macro: 0.99901
# Validation --- epoch: 18, loss: 0.00188
#           f1: 0.99395, fnr: 0.00436, fpr: 0.00015, prc: 0.99357, acc: 0.99976, rec: 0.99564, f1_macro: 0.99691
# epoch: 19, passed number of graphs: 96, train running loss: 0.00081 (passed time: 33m 35s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99822, f1: 0.99907, f1_macro: 0.99951
# epoch: 19, passed number of graphs: 192, train running loss: 0.00079 (passed time: 33m 46s)
#           acc: 0.99990, fpr: 0.00011, fnr: 0.00000, rec: 1.00000, prc: 0.99752, f1: 0.99876, f1_macro: 0.99935
# epoch: 19, passed number of graphs: 288, train running loss: 0.00073 (passed time: 33m 58s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00017, rec: 0.99983, prc: 0.99455, f1: 0.99719, f1_macro: 0.99853
# epoch: 19, passed number of graphs: 384, train running loss: 0.00071 (passed time: 34m 9s)
#           acc: 0.99971, fpr: 0.00029, fnr: 0.00041, rec: 0.99959, prc: 0.99374, f1: 0.99666, f1_macro: 0.99825
# epoch: 19, passed number of graphs: 480, train running loss: 0.00075 (passed time: 34m 20s)
#           acc: 0.99973, fpr: 0.00028, fnr: 0.00017, rec: 0.99983, prc: 0.99381, f1: 0.99681, f1_macro: 0.99833
# epoch: 19, passed number of graphs: 576, train running loss: 0.00072 (passed time: 34m 32s)
#           acc: 0.99959, fpr: 0.00042, fnr: 0.00025, rec: 0.99975, prc: 0.99050, f1: 0.99511, f1_macro: 0.99744
# epoch: 19, passed number of graphs: 672, train running loss: 0.00072 (passed time: 34m 43s)
#           acc: 0.99951, fpr: 0.00051, fnr: 0.00016, rec: 0.99984, prc: 0.98869, f1: 0.99423, f1_macro: 0.99699
# epoch: 19, passed number of graphs: 768, train running loss: 0.00074 (passed time: 34m 55s)
#           acc: 0.99985, fpr: 0.00016, fnr: 0.00000, rec: 1.00000, prc: 0.99637, f1: 0.99818, f1_macro: 0.99905
# Validation --- epoch: 19, loss: 0.00185
#           f1: 0.99401, fnr: 0.00440, fpr: 0.00015, prc: 0.99371, acc: 0.99976, rec: 0.99560, f1_macro: 0.99694
# epoch: 20, passed number of graphs: 96, train running loss: 0.00080 (passed time: 35m 25s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99822, f1: 0.99907, f1_macro: 0.99951
# epoch: 20, passed number of graphs: 192, train running loss: 0.00079 (passed time: 35m 36s)
#           acc: 0.99990, fpr: 0.00011, fnr: 0.00000, rec: 1.00000, prc: 0.99752, f1: 0.99876, f1_macro: 0.99935
# epoch: 20, passed number of graphs: 288, train running loss: 0.00072 (passed time: 35m 48s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00017, rec: 0.99983, prc: 0.99455, f1: 0.99719, f1_macro: 0.99853
# epoch: 20, passed number of graphs: 384, train running loss: 0.00071 (passed time: 35m 59s)
#           acc: 0.99971, fpr: 0.00029, fnr: 0.00041, rec: 0.99959, prc: 0.99374, f1: 0.99666, f1_macro: 0.99825
# epoch: 20, passed number of graphs: 480, train running loss: 0.00075 (passed time: 36m 11s)
#           acc: 0.99973, fpr: 0.00028, fnr: 0.00017, rec: 0.99983, prc: 0.99381, f1: 0.99681, f1_macro: 0.99833
# epoch: 20, passed number of graphs: 576, train running loss: 0.00072 (passed time: 36m 22s)
#           acc: 0.99959, fpr: 0.00042, fnr: 0.00025, rec: 0.99975, prc: 0.99050, f1: 0.99511, f1_macro: 0.99744
# epoch: 20, passed number of graphs: 672, train running loss: 0.00072 (passed time: 36m 34s)
#           acc: 0.99951, fpr: 0.00051, fnr: 0.00016, rec: 0.99984, prc: 0.98869, f1: 0.99423, f1_macro: 0.99699
# epoch: 20, passed number of graphs: 768, train running loss: 0.00074 (passed time: 36m 45s)
#           acc: 0.99985, fpr: 0.00016, fnr: 0.00000, rec: 1.00000, prc: 0.99637, f1: 0.99818, f1_macro: 0.99905
# Validation --- epoch: 20, loss: 0.00185
#           f1: 0.99400, fnr: 0.00440, fpr: 0.00015, prc: 0.99371, acc: 0.99976, rec: 0.99560, f1_macro: 0.99694
# epoch: 21, passed number of graphs: 96, train running loss: 0.00080 (passed time: 37m 16s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99822, f1: 0.99907, f1_macro: 0.99951
# epoch: 21, passed number of graphs: 192, train running loss: 0.00079 (passed time: 37m 27s)
#           acc: 0.99990, fpr: 0.00011, fnr: 0.00000, rec: 1.00000, prc: 0.99760, f1: 0.99880, f1_macro: 0.99937
# epoch: 21, passed number of graphs: 288, train running loss: 0.00072 (passed time: 37m 39s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00017, rec: 0.99983, prc: 0.99455, f1: 0.99719, f1_macro: 0.99853
# epoch: 21, passed number of graphs: 384, train running loss: 0.00071 (passed time: 37m 50s)
#           acc: 0.99971, fpr: 0.00029, fnr: 0.00041, rec: 0.99959, prc: 0.99374, f1: 0.99666, f1_macro: 0.99825
# epoch: 21, passed number of graphs: 480, train running loss: 0.00075 (passed time: 38m 2s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99389, f1: 0.99685, f1_macro: 0.99836
# epoch: 21, passed number of graphs: 576, train running loss: 0.00072 (passed time: 38m 13s)
#           acc: 0.99959, fpr: 0.00042, fnr: 0.00016, rec: 0.99984, prc: 0.99050, f1: 0.99515, f1_macro: 0.99747
# epoch: 21, passed number of graphs: 672, train running loss: 0.00072 (passed time: 38m 24s)
#           acc: 0.99951, fpr: 0.00051, fnr: 0.00016, rec: 0.99984, prc: 0.98869, f1: 0.99423, f1_macro: 0.99699
# epoch: 21, passed number of graphs: 768, train running loss: 0.00073 (passed time: 38m 36s)
#           acc: 0.99985, fpr: 0.00016, fnr: 0.00000, rec: 1.00000, prc: 0.99637, f1: 0.99818, f1_macro: 0.99905
# Validation --- epoch: 21, loss: 0.00185
#           f1: 0.99400, fnr: 0.00439, fpr: 0.00015, prc: 0.99369, acc: 0.99976, rec: 0.99561, f1_macro: 0.99694
# epoch: 22, passed number of graphs: 96, train running loss: 0.00080 (passed time: 39m 6s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99822, f1: 0.99907, f1_macro: 0.99951
# epoch: 22, passed number of graphs: 192, train running loss: 0.00078 (passed time: 39m 17s)
#           acc: 0.99990, fpr: 0.00011, fnr: 0.00000, rec: 1.00000, prc: 0.99760, f1: 0.99880, f1_macro: 0.99937
# epoch: 22, passed number of graphs: 288, train running loss: 0.00072 (passed time: 39m 29s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00017, rec: 0.99983, prc: 0.99455, f1: 0.99719, f1_macro: 0.99853
# epoch: 22, passed number of graphs: 384, train running loss: 0.00071 (passed time: 39m 40s)
#           acc: 0.99971, fpr: 0.00029, fnr: 0.00041, rec: 0.99959, prc: 0.99374, f1: 0.99666, f1_macro: 0.99825
# epoch: 22, passed number of graphs: 480, train running loss: 0.00075 (passed time: 39m 52s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99389, f1: 0.99685, f1_macro: 0.99836
# epoch: 22, passed number of graphs: 576, train running loss: 0.00072 (passed time: 40m 3s)
#           acc: 0.99959, fpr: 0.00042, fnr: 0.00016, rec: 0.99984, prc: 0.99050, f1: 0.99515, f1_macro: 0.99747
# epoch: 22, passed number of graphs: 672, train running loss: 0.00072 (passed time: 40m 15s)
#           acc: 0.99951, fpr: 0.00051, fnr: 0.00016, rec: 0.99984, prc: 0.98869, f1: 0.99423, f1_macro: 0.99699
# epoch: 22, passed number of graphs: 768, train running loss: 0.00073 (passed time: 40m 26s)
#           acc: 0.99985, fpr: 0.00016, fnr: 0.00000, rec: 1.00000, prc: 0.99637, f1: 0.99818, f1_macro: 0.99905
# Validation --- epoch: 22, loss: 0.00184
#           f1: 0.99399, fnr: 0.00439, fpr: 0.00015, prc: 0.99367, acc: 0.99976, rec: 0.99561, f1_macro: 0.99693
# epoch: 23, passed number of graphs: 96, train running loss: 0.00080 (passed time: 40m 56s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99822, f1: 0.99907, f1_macro: 0.99951
# epoch: 23, passed number of graphs: 192, train running loss: 0.00078 (passed time: 41m 8s)
#           acc: 0.99990, fpr: 0.00011, fnr: 0.00000, rec: 1.00000, prc: 0.99760, f1: 0.99880, f1_macro: 0.99937
# epoch: 23, passed number of graphs: 288, train running loss: 0.00072 (passed time: 41m 19s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00017, rec: 0.99983, prc: 0.99455, f1: 0.99719, f1_macro: 0.99853
# epoch: 23, passed number of graphs: 384, train running loss: 0.00071 (passed time: 41m 31s)
#           acc: 0.99971, fpr: 0.00029, fnr: 0.00041, rec: 0.99959, prc: 0.99374, f1: 0.99666, f1_macro: 0.99825
# epoch: 23, passed number of graphs: 480, train running loss: 0.00075 (passed time: 41m 42s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99389, f1: 0.99685, f1_macro: 0.99836
# epoch: 23, passed number of graphs: 576, train running loss: 0.00072 (passed time: 41m 53s)
#           acc: 0.99959, fpr: 0.00042, fnr: 0.00016, rec: 0.99984, prc: 0.99050, f1: 0.99515, f1_macro: 0.99747
# epoch: 23, passed number of graphs: 672, train running loss: 0.00072 (passed time: 42m 5s)
#           acc: 0.99950, fpr: 0.00051, fnr: 0.00016, rec: 0.99984, prc: 0.98861, f1: 0.99419, f1_macro: 0.99697
# epoch: 23, passed number of graphs: 768, train running loss: 0.00073 (passed time: 42m 16s)
#           acc: 0.99985, fpr: 0.00016, fnr: 0.00000, rec: 1.00000, prc: 0.99637, f1: 0.99818, f1_macro: 0.99905
# Validation --- epoch: 23, loss: 0.00184
#           f1: 0.99399, fnr: 0.00439, fpr: 0.00015, prc: 0.99368, acc: 0.99976, rec: 0.99561, f1_macro: 0.99693
# epoch: 24, passed number of graphs: 96, train running loss: 0.00080 (passed time: 42m 46s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99822, f1: 0.99907, f1_macro: 0.99951
# epoch: 24, passed number of graphs: 192, train running loss: 0.00078 (passed time: 42m 57s)
#           acc: 0.99990, fpr: 0.00011, fnr: 0.00000, rec: 1.00000, prc: 0.99760, f1: 0.99880, f1_macro: 0.99937
# epoch: 24, passed number of graphs: 288, train running loss: 0.00072 (passed time: 43m 9s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00017, rec: 0.99983, prc: 0.99455, f1: 0.99719, f1_macro: 0.99853
# epoch: 24, passed number of graphs: 384, train running loss: 0.00071 (passed time: 43m 20s)
#           acc: 0.99971, fpr: 0.00029, fnr: 0.00041, rec: 0.99959, prc: 0.99374, f1: 0.99666, f1_macro: 0.99825
# epoch: 24, passed number of graphs: 480, train running loss: 0.00075 (passed time: 43m 31s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99389, f1: 0.99685, f1_macro: 0.99836
# epoch: 24, passed number of graphs: 576, train running loss: 0.00072 (passed time: 43m 43s)
#           acc: 0.99959, fpr: 0.00042, fnr: 0.00016, rec: 0.99984, prc: 0.99050, f1: 0.99515, f1_macro: 0.99747
# epoch: 24, passed number of graphs: 672, train running loss: 0.00072 (passed time: 43m 54s)
#           acc: 0.99950, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98853, f1: 0.99415, f1_macro: 0.99694
# epoch: 24, passed number of graphs: 768, train running loss: 0.00073 (passed time: 44m 6s)
#           acc: 0.99985, fpr: 0.00016, fnr: 0.00000, rec: 1.00000, prc: 0.99645, f1: 0.99822, f1_macro: 0.99907
# Validation --- epoch: 24, loss: 0.00184
#           f1: 0.99400, fnr: 0.00439, fpr: 0.00015, prc: 0.99368, acc: 0.99976, rec: 0.99561, f1_macro: 0.99694
# epoch: 25, passed number of graphs: 96, train running loss: 0.00080 (passed time: 44m 35s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99822, f1: 0.99907, f1_macro: 0.99951
# epoch: 25, passed number of graphs: 192, train running loss: 0.00078 (passed time: 44m 47s)
#           acc: 0.99990, fpr: 0.00011, fnr: 0.00000, rec: 1.00000, prc: 0.99760, f1: 0.99880, f1_macro: 0.99937
# epoch: 25, passed number of graphs: 288, train running loss: 0.00072 (passed time: 44m 58s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00017, rec: 0.99983, prc: 0.99455, f1: 0.99719, f1_macro: 0.99853
# epoch: 25, passed number of graphs: 384, train running loss: 0.00071 (passed time: 45m 10s)
#           acc: 0.99971, fpr: 0.00029, fnr: 0.00041, rec: 0.99959, prc: 0.99374, f1: 0.99666, f1_macro: 0.99825
# epoch: 25, passed number of graphs: 480, train running loss: 0.00075 (passed time: 45m 21s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99397, f1: 0.99689, f1_macro: 0.99838
# epoch: 25, passed number of graphs: 576, train running loss: 0.00072 (passed time: 45m 33s)
#           acc: 0.99959, fpr: 0.00042, fnr: 0.00016, rec: 0.99984, prc: 0.99050, f1: 0.99515, f1_macro: 0.99747
# epoch: 25, passed number of graphs: 672, train running loss: 0.00072 (passed time: 45m 44s)
#           acc: 0.99950, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98853, f1: 0.99415, f1_macro: 0.99694
# ...
#           acc: 0.99977, fpr: 0.00024, fnr: 0.00008, rec: 0.99992, prc: 0.99455, f1: 0.99723, f1_macro: 0.99855
# epoch: 42, passed number of graphs: 384, train running loss: 0.00069 (passed time: 1h 16m 20s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00033, rec: 0.99967, prc: 0.99350, f1: 0.99658, f1_macro: 0.99821
# epoch: 42, passed number of graphs: 480, train running loss: 0.00073 (passed time: 1h 16m 31s)
#           acc: 0.99974, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99405, f1: 0.99694, f1_macro: 0.99840
# epoch: 42, passed number of graphs: 576, train running loss: 0.00070 (passed time: 1h 16m 43s)
#           acc: 0.99959, fpr: 0.00043, fnr: 0.00008, rec: 0.99992, prc: 0.99034, f1: 0.99511, f1_macro: 0.99744
# epoch: 42, passed number of graphs: 672, train running loss: 0.00070 (passed time: 1h 16m 54s)
#           acc: 0.99949, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98837, f1: 0.99407, f1_macro: 0.99690
# epoch: 42, passed number of graphs: 768, train running loss: 0.00072 (passed time: 1h 17m 6s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00000, rec: 1.00000, prc: 0.99653, f1: 0.99826, f1_macro: 0.99909
# Validation --- epoch: 42, loss: 0.00178
#           f1: 0.99404, fnr: 0.00440, fpr: 0.00015, prc: 0.99378, acc: 0.99976, rec: 0.99560, f1_macro: 0.99696
# Better model saved at ./saved_models/GIN_41: 0.9940399305817209.pt.
# epoch: 43, passed number of graphs: 96, train running loss: 0.00078 (passed time: 1h 17m 36s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99822, f1: 0.99907, f1_macro: 0.99951
# epoch: 43, passed number of graphs: 192, train running loss: 0.00077 (passed time: 1h 17m 48s)
#           acc: 0.99990, fpr: 0.00011, fnr: 0.00008, rec: 0.99992, prc: 0.99760, f1: 0.99876, f1_macro: 0.99935
# epoch: 43, passed number of graphs: 288, train running loss: 0.00070 (passed time: 1h 17m 59s)
#           acc: 0.99977, fpr: 0.00024, fnr: 0.00008, rec: 0.99992, prc: 0.99455, f1: 0.99723, f1_macro: 0.99855
# epoch: 43, passed number of graphs: 384, train running loss: 0.00069 (passed time: 1h 18m 11s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00033, rec: 0.99967, prc: 0.99350, f1: 0.99658, f1_macro: 0.99821
# epoch: 43, passed number of graphs: 480, train running loss: 0.00073 (passed time: 1h 18m 22s)
#           acc: 0.99974, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99405, f1: 0.99694, f1_macro: 0.99840
# epoch: 43, passed number of graphs: 576, train running loss: 0.00070 (passed time: 1h 18m 33s)
#           acc: 0.99958, fpr: 0.00043, fnr: 0.00016, rec: 0.99984, prc: 0.99034, f1: 0.99507, f1_macro: 0.99742
# epoch: 43, passed number of graphs: 672, train running loss: 0.00070 (passed time: 1h 18m 45s)
#           acc: 0.99949, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98837, f1: 0.99407, f1_macro: 0.99690
# epoch: 43, passed number of graphs: 768, train running loss: 0.00072 (passed time: 1h 18m 56s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00000, rec: 1.00000, prc: 0.99653, f1: 0.99826, f1_macro: 0.99909
# Validation --- epoch: 43, loss: 0.00178
#           f1: 0.99404, fnr: 0.00440, fpr: 0.00015, prc: 0.99377, acc: 0.99976, rec: 0.99560, f1_macro: 0.99696
# epoch: 44, passed number of graphs: 96, train running loss: 0.00078 (passed time: 1h 19m 27s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99822, f1: 0.99907, f1_macro: 0.99951
# epoch: 44, passed number of graphs: 192, train running loss: 0.00077 (passed time: 1h 19m 38s)
#           acc: 0.99990, fpr: 0.00011, fnr: 0.00008, rec: 0.99992, prc: 0.99760, f1: 0.99876, f1_macro: 0.99935
# epoch: 44, passed number of graphs: 288, train running loss: 0.00070 (passed time: 1h 19m 50s)
#           acc: 0.99977, fpr: 0.00024, fnr: 0.00008, rec: 0.99992, prc: 0.99455, f1: 0.99723, f1_macro: 0.99855
# epoch: 44, passed number of graphs: 384, train running loss: 0.00069 (passed time: 1h 20m 1s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00033, rec: 0.99967, prc: 0.99350, f1: 0.99658, f1_macro: 0.99821
# epoch: 44, passed number of graphs: 480, train running loss: 0.00073 (passed time: 1h 20m 13s)
#           acc: 0.99974, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99405, f1: 0.99694, f1_macro: 0.99840
# epoch: 44, passed number of graphs: 576, train running loss: 0.00070 (passed time: 1h 20m 24s)
#           acc: 0.99958, fpr: 0.00043, fnr: 0.00016, rec: 0.99984, prc: 0.99034, f1: 0.99507, f1_macro: 0.99742
# epoch: 44, passed number of graphs: 672, train running loss: 0.00070 (passed time: 1h 20m 35s)
#           acc: 0.99949, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98837, f1: 0.99407, f1_macro: 0.99690
# epoch: 44, passed number of graphs: 768, train running loss: 0.00072 (passed time: 1h 20m 47s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00000, rec: 1.00000, prc: 0.99653, f1: 0.99826, f1_macro: 0.99909
# Validation --- epoch: 44, loss: 0.00178
#           f1: 0.99404, fnr: 0.00440, fpr: 0.00015, prc: 0.99377, acc: 0.99976, rec: 0.99560, f1_macro: 0.99696
# epoch: 45, passed number of graphs: 96, train running loss: 0.00078 (passed time: 1h 21m 19s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99822, f1: 0.99907, f1_macro: 0.99951
# epoch: 45, passed number of graphs: 192, train running loss: 0.00077 (passed time: 1h 21m 30s)
#           acc: 0.99990, fpr: 0.00011, fnr: 0.00008, rec: 0.99992, prc: 0.99760, f1: 0.99876, f1_macro: 0.99935
# epoch: 45, passed number of graphs: 288, train running loss: 0.00070 (passed time: 1h 21m 42s)
#           acc: 0.99977, fpr: 0.00024, fnr: 0.00008, rec: 0.99992, prc: 0.99455, f1: 0.99723, f1_macro: 0.99855
# epoch: 45, passed number of graphs: 384, train running loss: 0.00069 (passed time: 1h 21m 54s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00033, rec: 0.99967, prc: 0.99350, f1: 0.99658, f1_macro: 0.99821
# epoch: 45, passed number of graphs: 480, train running loss: 0.00073 (passed time: 1h 22m 5s)
#           acc: 0.99974, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99405, f1: 0.99694, f1_macro: 0.99840
# epoch: 45, passed number of graphs: 576, train running loss: 0.00070 (passed time: 1h 22m 16s)
#           acc: 0.99958, fpr: 0.00043, fnr: 0.00016, rec: 0.99984, prc: 0.99034, f1: 0.99507, f1_macro: 0.99742
# epoch: 45, passed number of graphs: 672, train running loss: 0.00070 (passed time: 1h 22m 28s)
#           acc: 0.99949, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98837, f1: 0.99407, f1_macro: 0.99690
# epoch: 45, passed number of graphs: 768, train running loss: 0.00072 (passed time: 1h 22m 39s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00000, rec: 1.00000, prc: 0.99653, f1: 0.99826, f1_macro: 0.99909
# Validation --- epoch: 45, loss: 0.00178
#           f1: 0.99404, fnr: 0.00440, fpr: 0.00015, prc: 0.99377, acc: 0.99976, rec: 0.99560, f1_macro: 0.99696
# epoch: 46, passed number of graphs: 96, train running loss: 0.00078 (passed time: 1h 23m 11s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99822, f1: 0.99907, f1_macro: 0.99951
# epoch: 46, passed number of graphs: 192, train running loss: 0.00077 (passed time: 1h 23m 22s)
#           acc: 0.99990, fpr: 0.00011, fnr: 0.00008, rec: 0.99992, prc: 0.99760, f1: 0.99876, f1_macro: 0.99935
# epoch: 46, passed number of graphs: 288, train running loss: 0.00070 (passed time: 1h 23m 34s)
#           acc: 0.99977, fpr: 0.00024, fnr: 0.00008, rec: 0.99992, prc: 0.99455, f1: 0.99723, f1_macro: 0.99855
# epoch: 46, passed number of graphs: 384, train running loss: 0.00069 (passed time: 1h 23m 45s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00033, rec: 0.99967, prc: 0.99350, f1: 0.99658, f1_macro: 0.99821
# epoch: 46, passed number of graphs: 480, train running loss: 0.00073 (passed time: 1h 23m 57s)
#           acc: 0.99974, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99405, f1: 0.99694, f1_macro: 0.99840
# epoch: 46, passed number of graphs: 576, train running loss: 0.00070 (passed time: 1h 24m 8s)
#           acc: 0.99958, fpr: 0.00043, fnr: 0.00016, rec: 0.99984, prc: 0.99034, f1: 0.99507, f1_macro: 0.99742
# epoch: 46, passed number of graphs: 672, train running loss: 0.00070 (passed time: 1h 24m 19s)
#           acc: 0.99949, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98837, f1: 0.99407, f1_macro: 0.99690
# epoch: 46, passed number of graphs: 768, train running loss: 0.00072 (passed time: 1h 24m 31s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00000, rec: 1.00000, prc: 0.99653, f1: 0.99826, f1_macro: 0.99909
# Validation --- epoch: 46, loss: 0.00178
#           f1: 0.99404, fnr: 0.00439, fpr: 0.00015, prc: 0.99377, acc: 0.99976, rec: 0.99561, f1_macro: 0.99696
# epoch: 47, passed number of graphs: 96, train running loss: 0.00078 (passed time: 1h 25m 2s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99822, f1: 0.99907, f1_macro: 0.99951
# epoch: 47, passed number of graphs: 192, train running loss: 0.00077 (passed time: 1h 25m 14s)
#           acc: 0.99990, fpr: 0.00011, fnr: 0.00008, rec: 0.99992, prc: 0.99760, f1: 0.99876, f1_macro: 0.99935
# epoch: 47, passed number of graphs: 288, train running loss: 0.00070 (passed time: 1h 25m 25s)
#           acc: 0.99977, fpr: 0.00024, fnr: 0.00008, rec: 0.99992, prc: 0.99455, f1: 0.99723, f1_macro: 0.99855
# epoch: 47, passed number of graphs: 384, train running loss: 0.00069 (passed time: 1h 25m 37s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00033, rec: 0.99967, prc: 0.99350, f1: 0.99658, f1_macro: 0.99821
# epoch: 47, passed number of graphs: 480, train running loss: 0.00073 (passed time: 1h 25m 48s)
#           acc: 0.99974, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99405, f1: 0.99694, f1_macro: 0.99840
# epoch: 47, passed number of graphs: 576, train running loss: 0.00070 (passed time: 1h 26m 0s)
#           acc: 0.99958, fpr: 0.00043, fnr: 0.00016, rec: 0.99984, prc: 0.99034, f1: 0.99507, f1_macro: 0.99742
# epoch: 47, passed number of graphs: 672, train running loss: 0.00070 (passed time: 1h 26m 11s)
#           acc: 0.99949, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98837, f1: 0.99407, f1_macro: 0.99690
# epoch: 47, passed number of graphs: 768, train running loss: 0.00072 (passed time: 1h 26m 22s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00000, rec: 1.00000, prc: 0.99653, f1: 0.99826, f1_macro: 0.99909
# Validation --- epoch: 47, loss: 0.00178
#           f1: 0.99404, fnr: 0.00439, fpr: 0.00015, prc: 0.99377, acc: 0.99976, rec: 0.99561, f1_macro: 0.99696
# epoch: 48, passed number of graphs: 96, train running loss: 0.00078 (passed time: 1h 26m 53s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99822, f1: 0.99907, f1_macro: 0.99951
# epoch: 48, passed number of graphs: 192, train running loss: 0.00077 (passed time: 1h 27m 4s)
#           acc: 0.99990, fpr: 0.00011, fnr: 0.00008, rec: 0.99992, prc: 0.99760, f1: 0.99876, f1_macro: 0.99935
# epoch: 48, passed number of graphs: 288, train running loss: 0.00070 (passed time: 1h 27m 16s)
#           acc: 0.99977, fpr: 0.00024, fnr: 0.00008, rec: 0.99992, prc: 0.99455, f1: 0.99723, f1_macro: 0.99855
# epoch: 48, passed number of graphs: 384, train running loss: 0.00069 (passed time: 1h 27m 27s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00033, rec: 0.99967, prc: 0.99350, f1: 0.99658, f1_macro: 0.99821
# epoch: 48, passed number of graphs: 480, train running loss: 0.00073 (passed time: 1h 27m 39s)
#           acc: 0.99974, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99405, f1: 0.99694, f1_macro: 0.99840
# epoch: 48, passed number of graphs: 576, train running loss: 0.00070 (passed time: 1h 27m 50s)
#           acc: 0.99959, fpr: 0.00043, fnr: 0.00008, rec: 0.99992, prc: 0.99034, f1: 0.99511, f1_macro: 0.99744
# epoch: 48, passed number of graphs: 672, train running loss: 0.00070 (passed time: 1h 28m 1s)
#           acc: 0.99949, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98837, f1: 0.99407, f1_macro: 0.99690
# epoch: 48, passed number of graphs: 768, train running loss: 0.00072 (passed time: 1h 28m 13s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00000, rec: 1.00000, prc: 0.99653, f1: 0.99826, f1_macro: 0.99909
# Validation --- epoch: 48, loss: 0.00178
#           f1: 0.99404, fnr: 0.00440, fpr: 0.00015, prc: 0.99378, acc: 0.99976, rec: 0.99560, f1_macro: 0.99696
# epoch: 49, passed number of graphs: 96, train running loss: 0.00078 (passed time: 1h 28m 43s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99822, f1: 0.99907, f1_macro: 0.99951
# epoch: 49, passed number of graphs: 192, train running loss: 0.00077 (passed time: 1h 28m 54s)
#           acc: 0.99990, fpr: 0.00011, fnr: 0.00008, rec: 0.99992, prc: 0.99760, f1: 0.99876, f1_macro: 0.99935
# epoch: 49, passed number of graphs: 288, train running loss: 0.00070 (passed time: 1h 29m 6s)
#           acc: 0.99977, fpr: 0.00024, fnr: 0.00008, rec: 0.99992, prc: 0.99455, f1: 0.99723, f1_macro: 0.99855
# epoch: 49, passed number of graphs: 384, train running loss: 0.00069 (passed time: 1h 29m 17s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00033, rec: 0.99967, prc: 0.99350, f1: 0.99658, f1_macro: 0.99821
# epoch: 49, passed number of graphs: 480, train running loss: 0.00073 (passed time: 1h 29m 28s)
#           acc: 0.99974, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99405, f1: 0.99694, f1_macro: 0.99840
# epoch: 49, passed number of graphs: 576, train running loss: 0.00070 (passed time: 1h 29m 40s)
#           acc: 0.99959, fpr: 0.00043, fnr: 0.00008, rec: 0.99992, prc: 0.99034, f1: 0.99511, f1_macro: 0.99744
# epoch: 49, passed number of graphs: 672, train running loss: 0.00070 (passed time: 1h 29m 51s)
#           acc: 0.99949, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98837, f1: 0.99407, f1_macro: 0.99690
# epoch: 49, passed number of graphs: 768, train running loss: 0.00072 (passed time: 1h 30m 3s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00000, rec: 1.00000, prc: 0.99653, f1: 0.99826, f1_macro: 0.99909
# Validation --- epoch: 49, loss: 0.00178
#           f1: 0.99404, fnr: 0.00439, fpr: 0.00015, prc: 0.99377, acc: 0.99976, rec: 0.99561, f1_macro: 0.99696
# epoch: 50, passed number of graphs: 96, train running loss: 0.00078 (passed time: 1h 30m 33s)
#           acc: 0.99992, fpr: 0.00008, fnr: 0.00008, rec: 0.99992, prc: 0.99822, f1: 0.99907, f1_macro: 0.99951
# epoch: 50, passed number of graphs: 192, train running loss: 0.00077 (passed time: 1h 30m 45s)
#           acc: 0.99990, fpr: 0.00011, fnr: 0.00008, rec: 0.99992, prc: 0.99760, f1: 0.99876, f1_macro: 0.99935
# epoch: 50, passed number of graphs: 288, train running loss: 0.00070 (passed time: 1h 30m 56s)
#           acc: 0.99977, fpr: 0.00024, fnr: 0.00008, rec: 0.99992, prc: 0.99455, f1: 0.99723, f1_macro: 0.99855
# epoch: 50, passed number of graphs: 384, train running loss: 0.00069 (passed time: 1h 31m 8s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00033, rec: 0.99967, prc: 0.99350, f1: 0.99658, f1_macro: 0.99821
# epoch: 50, passed number of graphs: 480, train running loss: 0.00073 (passed time: 1h 31m 19s)
#           acc: 0.99974, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99405, f1: 0.99694, f1_macro: 0.99840
# epoch: 50, passed number of graphs: 576, train running loss: 0.00070 (passed time: 1h 31m 31s)
#           acc: 0.99959, fpr: 0.00043, fnr: 0.00008, rec: 0.99992, prc: 0.99034, f1: 0.99511, f1_macro: 0.99744
# epoch: 50, passed number of graphs: 672, train running loss: 0.00070 (passed time: 1h 31m 42s)
#           acc: 0.99949, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98837, f1: 0.99407, f1_macro: 0.99690
# epoch: 50, passed number of graphs: 768, train running loss: 0.00072 (passed time: 1h 31m 53s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00000, rec: 1.00000, prc: 0.99653, f1: 0.99826, f1_macro: 0.99909
# Validation --- epoch: 50, loss: 0.00178
#           f1: 0.99404, fnr: 0.00439, fpr: 0.00015, prc: 0.99377, acc: 0.99976, rec: 0.99561, f1_macro: 0.99696
# ************ best model obtained after epoch 42, saved at ./saved_models/GIN_41: 0.9940399305817209.pt ************
# Testing --- loss: 0.00139
#           f1: 0.99484, fnr: 0.00289, fpr: 0.00016, prc: 0.99313, acc: 0.99978, rec: 0.99711, f1_macro: 0.99736

# %% [markdown]
# 10layer
