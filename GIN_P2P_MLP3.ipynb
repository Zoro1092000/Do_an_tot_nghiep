# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/Do_an_tot_nghiep/blob/main/GIN_P2P_MLP3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric==1.4.3
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter_
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric==1.4.3 in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.6.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.18.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.23.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.12.1+cu113)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.3.5)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.56.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (6.2.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.0.2)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.7.4)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.21.6)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->torch-geometric==1.4.3) (1.5.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (4.13.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (3.10.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2022.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.4.3) (1.15.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (3.0.9)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (0.6.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2022.9.24)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2021.11.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (1.3.0)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (3.2.2)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (7.1.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2.9.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (0.11.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
        elif split == 'val':
            self.path = self.processed_paths[1]
        elif split == 'test':
            self.path = self.processed_paths[2]

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
            self.num_graphs = self.data['num_graphs']
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            with h5py.File(self.path, 'r') as f:
                self.num_graphs = f.attrs['num_graphs']
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GINConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_input_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU())))
          else:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU()))) 

        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                add_xr_at = n
            if n == add_xr_at:
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/P2P'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=True, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 2
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.0
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-ad26b88f-28df-42dc-9121-fdd443d7b1ed.json
# ------------------------------
# ------------------------------
# Sun Nov  6 04:00:35 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GINConv(nn=Sequential(
#       (0): Linear(in_features=1, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (1): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (2): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (3): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (4): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (5): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (6): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (7): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (8): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (9): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (10): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (11): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 2
# epoch: 1, passed number of graphs: 96, train running loss: 0.06022 (passed time: 19s)
#           acc: 0.97831, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 192, train running loss: 0.04473 (passed time: 36s)
#           acc: 0.98100, fpr: 0.00003, fnr: 0.88747, rec: 0.11253, prc: 0.98711, f1: 0.20202, f1_macro: 0.59621
# epoch: 1, passed number of graphs: 288, train running loss: 0.03718 (passed time: 53s)
#           acc: 0.97871, fpr: 0.00011, fnr: 0.99935, rec: 0.00065, prc: 0.11111, f1: 0.00130, f1_macro: 0.49527
# epoch: 1, passed number of graphs: 384, train running loss: 0.03320 (passed time: 1m 10s)
#           acc: 0.97798, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 480, train running loss: 0.03545 (passed time: 1m 28s)
#           acc: 0.97838, fpr: 0.00001, fnr: 0.99918, rec: 0.00082, prc: 0.62500, f1: 0.00163, f1_macro: 0.49535
# epoch: 1, passed number of graphs: 576, train running loss: 0.03268 (passed time: 1m 45s)
#           acc: 0.99587, fpr: 0.00007, fnr: 0.18999, rec: 0.81001, prc: 0.99623, f1: 0.89352, f1_macro: 0.94571
# epoch: 1, passed number of graphs: 672, train running loss: 0.02901 (passed time: 2m 3s)
#           acc: 0.99522, fpr: 0.00205, fnr: 0.12816, rec: 0.87184, prc: 0.90406, f1: 0.88766, f1_macro: 0.94261
# epoch: 1, passed number of graphs: 768, train running loss: 0.02659 (passed time: 2m 21s)
#           acc: 0.97951, fpr: 0.00001, fnr: 0.96427, rec: 0.03573, prc: 0.99095, f1: 0.06897, f1_macro: 0.52930
# Validation --- epoch: 1, loss: 0.13547
#           acc: 0.97848, fpr: 0.00000, prc: -1.00000, rec: 0.00000, f1: 0.00000, fnr: 1.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 96, train running loss: 0.00822 (passed time: 3m 12s)
#           acc: 0.99807, fpr: 0.00001, fnr: 0.08869, rec: 0.91131, prc: 0.99948, f1: 0.95336, f1_macro: 0.97619
# epoch: 2, passed number of graphs: 192, train running loss: 0.00897 (passed time: 3m 30s)
#           acc: 0.99983, fpr: 0.00000, fnr: 0.00817, rec: 0.99183, prc: 1.00000, f1: 0.99590, f1_macro: 0.99791
# epoch: 2, passed number of graphs: 288, train running loss: 0.00725 (passed time: 3m 47s)
#           acc: 0.99987, fpr: 0.00004, fnr: 0.00425, rec: 0.99575, prc: 0.99820, f1: 0.99697, f1_macro: 0.99845
# epoch: 2, passed number of graphs: 384, train running loss: 0.00744 (passed time: 4m 5s)
#           acc: 0.99989, fpr: 0.00004, fnr: 0.00306, rec: 0.99694, prc: 0.99806, f1: 0.99750, f1_macro: 0.99872
# epoch: 2, passed number of graphs: 480, train running loss: 0.00878 (passed time: 4m 22s)
#           acc: 0.97875, fpr: 0.00001, fnr: 0.98187, rec: 0.01813, prc: 0.98230, f1: 0.03561, f1_macro: 0.51243
# epoch: 2, passed number of graphs: 576, train running loss: 0.00894 (passed time: 4m 40s)
#           acc: 0.99136, fpr: 0.00219, fnr: 0.30347, rec: 0.69653, prc: 0.87454, f1: 0.77545, f1_macro: 0.88552
# epoch: 2, passed number of graphs: 672, train running loss: 0.00834 (passed time: 4m 58s)
#           acc: 0.99865, fpr: 0.00124, fnr: 0.00655, rec: 0.99345, prc: 0.94670, f1: 0.96951, f1_macro: 0.98441
# epoch: 2, passed number of graphs: 768, train running loss: 0.00754 (passed time: 5m 15s)
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00294, rec: 0.99706, prc: 0.99902, f1: 0.99804, f1_macro: 0.99900
# Validation --- epoch: 2, loss: 0.14654
#           acc: 0.97848, fpr: 0.00000, prc: -1.00000, rec: 0.00000, f1: 0.00000, fnr: 1.00000, f1_macro: nan
# epoch: 3, passed number of graphs: 96, train running loss: 0.00767 (passed time: 5m 52s)
#           acc: 0.99945, fpr: 0.00010, fnr: 0.02106, rec: 0.97894, prc: 0.99562, f1: 0.98721, f1_macro: 0.99347
# epoch: 3, passed number of graphs: 192, train running loss: 0.01559 (passed time: 6m 9s)
#           acc: 0.99968, fpr: 0.00001, fnr: 0.01454, rec: 0.98546, prc: 0.99967, f1: 0.99252, f1_macro: 0.99618
# epoch: 3, passed number of graphs: 288, train running loss: 0.01092 (passed time: 6m 27s)
#           acc: 0.99982, fpr: 0.00011, fnr: 0.00343, rec: 0.99657, prc: 0.99478, f1: 0.99567, f1_macro: 0.99779
# epoch: 3, passed number of graphs: 384, train running loss: 0.00836 (passed time: 6m 44s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00354, rec: 0.99646, prc: 0.99935, f1: 0.99790, f1_macro: 0.99893
# epoch: 3, passed number of graphs: 480, train running loss: 0.00682 (passed time: 7m 2s)
#           acc: 0.99989, fpr: 0.00007, fnr: 0.00196, rec: 0.99804, prc: 0.99706, f1: 0.99755, f1_macro: 0.99875
# epoch: 3, passed number of graphs: 576, train running loss: 0.00584 (passed time: 7m 20s)
#           acc: 0.99901, fpr: 0.00025, fnr: 0.03487, rec: 0.96513, prc: 0.98843, f1: 0.97664, f1_macro: 0.98807
# epoch: 3, passed number of graphs: 672, train running loss: 0.00549 (passed time: 7m 37s)
#           acc: 0.99501, fpr: 0.00221, fnr: 0.13055, rec: 0.86945, prc: 0.89711, f1: 0.88306, f1_macro: 0.94026
# epoch: 3, passed number of graphs: 768, train running loss: 0.00572 (passed time: 7m 55s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.03752, rec: 0.96248, prc: 0.99949, f1: 0.98064, f1_macro: 0.99011
# Validation --- epoch: 3, loss: 0.14832
#           acc: 0.97848, fpr: 0.00000, prc: -1.00000, rec: 0.00000, f1: 0.00000, fnr: 1.00000, f1_macro: nan
# epoch: 4, passed number of graphs: 96, train running loss: 0.00197 (passed time: 8m 31s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00064, rec: 0.99936, prc: 0.99888, f1: 0.99912, f1_macro: 0.99955
# epoch: 4, passed number of graphs: 192, train running loss: 0.00171 (passed time: 8m 49s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00180, rec: 0.99820, prc: 0.99935, f1: 0.99877, f1_macro: 0.99937
# epoch: 4, passed number of graphs: 288, train running loss: 0.00135 (passed time: 9m 6s)
#           acc: 0.99957, fpr: 0.00041, fnr: 0.00114, rec: 0.99886, prc: 0.98122, f1: 0.98996, f1_macro: 0.99487
# epoch: 4, passed number of graphs: 384, train running loss: 0.00117 (passed time: 9m 24s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00113, rec: 0.99887, prc: 0.99839, f1: 0.99863, f1_macro: 0.99930
# epoch: 4, passed number of graphs: 480, train running loss: 0.00108 (passed time: 9m 41s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00065, rec: 0.99935, prc: 0.99286, f1: 0.99609, f1_macro: 0.99800
# epoch: 4, passed number of graphs: 576, train running loss: 0.00097 (passed time: 9m 59s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00048, rec: 0.99952, prc: 0.98756, f1: 0.99350, f1_macro: 0.99668
# epoch: 4, passed number of graphs: 672, train running loss: 0.00098 (passed time: 10m 17s)
#           acc: 0.99963, fpr: 0.00036, fnr: 0.00096, rec: 0.99904, prc: 0.98410, f1: 0.99152, f1_macro: 0.99566
# epoch: 4, passed number of graphs: 768, train running loss: 0.00099 (passed time: 10m 34s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00114, rec: 0.99886, prc: 0.99918, f1: 0.99902, f1_macro: 0.99950
# Validation --- epoch: 4, loss: 0.00203
#           acc: 0.99975, fpr: 0.00009, prc: 0.99572, rec: 0.99249, f1: 0.99335, fnr: 0.00751, f1_macro: 0.99661
# Better model saved at ./saved_models/GIN_3: 0.9933459973767603.pt.
# epoch: 5, passed number of graphs: 96, train running loss: 0.00057 (passed time: 11m 11s)
#           acc: 0.99997, fpr: 0.00002, fnr: 0.00048, rec: 0.99952, prc: 0.99920, f1: 0.99936, f1_macro: 0.99967
# epoch: 5, passed number of graphs: 192, train running loss: 0.00056 (passed time: 11m 29s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00147, rec: 0.99853, prc: 0.99935, f1: 0.99894, f1_macro: 0.99946
# epoch: 5, passed number of graphs: 288, train running loss: 0.00051 (passed time: 11m 46s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00131, rec: 0.99869, prc: 0.99205, f1: 0.99536, f1_macro: 0.99763
# epoch: 5, passed number of graphs: 384, train running loss: 0.00050 (passed time: 12m 4s)
#           acc: 0.99995, fpr: 0.00004, fnr: 0.00081, rec: 0.99919, prc: 0.99839, f1: 0.99879, f1_macro: 0.99938
# epoch: 5, passed number of graphs: 480, train running loss: 0.00072 (passed time: 12m 21s)
#           acc: 0.99972, fpr: 0.00001, fnr: 0.01241, rec: 0.98759, prc: 0.99967, f1: 0.99359, f1_macro: 0.99672
# epoch: 5, passed number of graphs: 576, train running loss: 0.00071 (passed time: 12m 39s)
#           acc: 0.99984, fpr: 0.00007, fnr: 0.00420, rec: 0.99580, prc: 0.99661, f1: 0.99621, f1_macro: 0.99806
# epoch: 5, passed number of graphs: 672, train running loss: 0.00071 (passed time: 12m 57s)
#           acc: 0.99962, fpr: 0.00031, fnr: 0.00384, rec: 0.99616, prc: 0.98624, f1: 0.99118, f1_macro: 0.99549
# epoch: 5, passed number of graphs: 768, train running loss: 0.00075 (passed time: 13m 14s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00310, rec: 0.99690, prc: 0.99935, f1: 0.99812, f1_macro: 0.99904
# Validation --- epoch: 5, loss: 0.00365
#           acc: 0.99930, fpr: 0.00001, prc: 0.99958, rec: 0.96770, f1: 0.98162, fnr: 0.03230, f1_macro: 0.99063
# epoch: 6, passed number of graphs: 96, train running loss: 0.00097 (passed time: 13m 51s)
#           acc: 0.99980, fpr: 0.00000, fnr: 0.00909, rec: 0.99091, prc: 0.99984, f1: 0.99535, f1_macro: 0.99763
# epoch: 6, passed number of graphs: 192, train running loss: 0.00110 (passed time: 14m 8s)
#           acc: 0.99992, fpr: 0.00004, fnr: 0.00229, rec: 0.99771, prc: 0.99837, f1: 0.99804, f1_macro: 0.99900
# epoch: 6, passed number of graphs: 288, train running loss: 0.00095 (passed time: 14m 26s)
#           acc: 0.99982, fpr: 0.00012, fnr: 0.00310, rec: 0.99690, prc: 0.99446, f1: 0.99568, f1_macro: 0.99779
# epoch: 6, passed number of graphs: 384, train running loss: 0.00085 (passed time: 14m 43s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00258, rec: 0.99742, prc: 0.99919, f1: 0.99831, f1_macro: 0.99913
# epoch: 6, passed number of graphs: 480, train running loss: 0.00075 (passed time: 15m 1s)
#           acc: 0.99986, fpr: 0.00009, fnr: 0.00229, rec: 0.99771, prc: 0.99576, f1: 0.99674, f1_macro: 0.99833
# epoch: 6, passed number of graphs: 576, train running loss: 0.00070 (passed time: 15m 19s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00161, rec: 0.99839, prc: 0.99214, f1: 0.99525, f1_macro: 0.99757
# epoch: 6, passed number of graphs: 672, train running loss: 0.00073 (passed time: 15m 36s)
#           acc: 0.99962, fpr: 0.00018, fnr: 0.00943, rec: 0.99057, prc: 0.99168, f1: 0.99113, f1_macro: 0.99547
# epoch: 6, passed number of graphs: 768, train running loss: 0.00078 (passed time: 15m 54s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00147, rec: 0.99853, prc: 0.99935, f1: 0.99894, f1_macro: 0.99946
# Validation --- epoch: 6, loss: 0.00503
#           acc: 0.99921, fpr: 0.00001, prc: 0.99942, rec: 0.96370, f1: 0.97891, fnr: 0.03630, f1_macro: 0.98925
# epoch: 7, passed number of graphs: 96, train running loss: 0.00100 (passed time: 16m 30s)
#           acc: 0.99998, fpr: 0.00001, fnr: 0.00016, rec: 0.99984, prc: 0.99936, f1: 0.99960, f1_macro: 0.99980
# epoch: 7, passed number of graphs: 192, train running loss: 0.00076 (passed time: 16m 48s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00163, rec: 0.99837, prc: 0.99951, f1: 0.99894, f1_macro: 0.99946
# epoch: 7, passed number of graphs: 288, train running loss: 0.00063 (passed time: 17m 6s)
#           acc: 0.99982, fpr: 0.00015, fnr: 0.00163, rec: 0.99837, prc: 0.99317, f1: 0.99576, f1_macro: 0.99784
# epoch: 7, passed number of graphs: 384, train running loss: 0.00061 (passed time: 17m 23s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00209, rec: 0.99791, prc: 0.99903, f1: 0.99847, f1_macro: 0.99922
# epoch: 7, passed number of graphs: 480, train running loss: 0.00056 (passed time: 17m 41s)
#           acc: 0.99986, fpr: 0.00013, fnr: 0.00098, rec: 0.99902, prc: 0.99431, f1: 0.99666, f1_macro: 0.99829
# epoch: 7, passed number of graphs: 576, train running loss: 0.00052 (passed time: 17m 59s)
#           acc: 0.99979, fpr: 0.00019, fnr: 0.00113, rec: 0.99887, prc: 0.99151, f1: 0.99518, f1_macro: 0.99753
# epoch: 7, passed number of graphs: 672, train running loss: 0.00053 (passed time: 18m 16s)
#           acc: 0.99961, fpr: 0.00037, fnr: 0.00128, rec: 0.99872, prc: 0.98348, f1: 0.99104, f1_macro: 0.99542
# epoch: 7, passed number of graphs: 768, train running loss: 0.00056 (passed time: 18m 34s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00179, rec: 0.99821, prc: 0.99935, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 7, loss: 0.00202
#           acc: 0.99970, fpr: 0.00003, prc: 0.99848, rec: 0.98774, f1: 0.99217, fnr: 0.01226, f1_macro: 0.99601
# epoch: 8, passed number of graphs: 96, train running loss: 0.00041 (passed time: 19m 10s)
#           acc: 0.99998, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99936, f1: 0.99952, f1_macro: 0.99976
# epoch: 8, passed number of graphs: 192, train running loss: 0.00042 (passed time: 19m 28s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00229, rec: 0.99771, prc: 0.99951, f1: 0.99861, f1_macro: 0.99929
# epoch: 8, passed number of graphs: 288, train running loss: 0.00040 (passed time: 19m 46s)
#           acc: 0.99982, fpr: 0.00015, fnr: 0.00196, rec: 0.99804, prc: 0.99333, f1: 0.99568, f1_macro: 0.99779
# epoch: 8, passed number of graphs: 384, train running loss: 0.00043 (passed time: 20m 3s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00161, rec: 0.99839, prc: 0.99919, f1: 0.99879, f1_macro: 0.99938
# epoch: 8, passed number of graphs: 480, train running loss: 0.00041 (passed time: 20m 21s)
#           acc: 0.99987, fpr: 0.00012, fnr: 0.00098, rec: 0.99902, prc: 0.99480, f1: 0.99690, f1_macro: 0.99842
# epoch: 8, passed number of graphs: 576, train running loss: 0.00040 (passed time: 20m 38s)
#           acc: 0.99980, fpr: 0.00018, fnr: 0.00129, rec: 0.99871, prc: 0.99198, f1: 0.99533, f1_macro: 0.99762
# epoch: 8, passed number of graphs: 672, train running loss: 0.00042 (passed time: 20m 56s)
#           acc: 0.99961, fpr: 0.00037, fnr: 0.00128, rec: 0.99872, prc: 0.98348, f1: 0.99104, f1_macro: 0.99542
# epoch: 8, passed number of graphs: 768, train running loss: 0.00046 (passed time: 21m 14s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00163, rec: 0.99837, prc: 0.99951, f1: 0.99894, f1_macro: 0.99946
# Validation --- epoch: 8, loss: 0.00223
#           acc: 0.99964, fpr: 0.00003, prc: 0.99881, rec: 0.98454, f1: 0.99054, fnr: 0.01546, f1_macro: 0.99518
# epoch: 9, passed number of graphs: 96, train running loss: 0.00040 (passed time: 21m 50s)
#           acc: 0.99998, fpr: 0.00001, fnr: 0.00016, rec: 0.99984, prc: 0.99936, f1: 0.99960, f1_macro: 0.99980
# epoch: 9, passed number of graphs: 192, train running loss: 0.00041 (passed time: 22m 8s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00229, rec: 0.99771, prc: 0.99951, f1: 0.99861, f1_macro: 0.99929
# epoch: 9, passed number of graphs: 288, train running loss: 0.00039 (passed time: 22m 25s)
#           acc: 0.99982, fpr: 0.00015, fnr: 0.00180, rec: 0.99820, prc: 0.99333, f1: 0.99576, f1_macro: 0.99784
# epoch: 9, passed number of graphs: 384, train running loss: 0.00042 (passed time: 22m 43s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00161, rec: 0.99839, prc: 0.99903, f1: 0.99871, f1_macro: 0.99934
# epoch: 9, passed number of graphs: 480, train running loss: 0.00040 (passed time: 23m 1s)
#           acc: 0.99986, fpr: 0.00012, fnr: 0.00131, rec: 0.99869, prc: 0.99463, f1: 0.99666, f1_macro: 0.99829
# epoch: 9, passed number of graphs: 576, train running loss: 0.00039 (passed time: 23m 18s)
#           acc: 0.99980, fpr: 0.00018, fnr: 0.00129, rec: 0.99871, prc: 0.99198, f1: 0.99533, f1_macro: 0.99762
# epoch: 9, passed number of graphs: 672, train running loss: 0.00041 (passed time: 23m 36s)
#           acc: 0.99963, fpr: 0.00034, fnr: 0.00160, rec: 0.99840, prc: 0.98471, f1: 0.99151, f1_macro: 0.99566
# epoch: 9, passed number of graphs: 768, train running loss: 0.00045 (passed time: 23m 53s)
#           acc: 0.99992, fpr: 0.00005, fnr: 0.00147, rec: 0.99853, prc: 0.99756, f1: 0.99804, f1_macro: 0.99900
# Validation --- epoch: 9, loss: 0.00165
#           acc: 0.99972, fpr: 0.00011, prc: 0.99518, rec: 0.99189, f1: 0.99276, fnr: 0.00811, f1_macro: 0.99631
# epoch: 10, passed number of graphs: 96, train running loss: 0.00041 (passed time: 24m 30s)
#           acc: 0.99998, fpr: 0.00001, fnr: 0.00016, rec: 0.99984, prc: 0.99936, f1: 0.99960, f1_macro: 0.99980
# epoch: 10, passed number of graphs: 192, train running loss: 0.00042 (passed time: 24m 48s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99877, f1_macro: 0.99937
# epoch: 10, passed number of graphs: 288, train running loss: 0.00039 (passed time: 25m 5s)
#           acc: 0.99982, fpr: 0.00015, fnr: 0.00163, rec: 0.99837, prc: 0.99317, f1: 0.99576, f1_macro: 0.99784
# epoch: 10, passed number of graphs: 384, train running loss: 0.00042 (passed time: 25m 23s)
#           acc: 0.99995, fpr: 0.00003, fnr: 0.00129, rec: 0.99871, prc: 0.99887, f1: 0.99879, f1_macro: 0.99938
# epoch: 10, passed number of graphs: 480, train running loss: 0.00041 (passed time: 25m 40s)
#           acc: 0.99984, fpr: 0.00013, fnr: 0.00163, rec: 0.99837, prc: 0.99431, f1: 0.99633, f1_macro: 0.99813
# epoch: 10, passed number of graphs: 576, train running loss: 0.00040 (passed time: 25m 58s)
#           acc: 0.99978, fpr: 0.00019, fnr: 0.00129, rec: 0.99871, prc: 0.99119, f1: 0.99493, f1_macro: 0.99741
# epoch: 10, passed number of graphs: 672, train running loss: 0.00041 (passed time: 26m 16s)
#           acc: 0.99964, fpr: 0.00031, fnr: 0.00240, rec: 0.99760, prc: 0.98594, f1: 0.99174, f1_macro: 0.99578
# epoch: 10, passed number of graphs: 768, train running loss: 0.00045 (passed time: 26m 33s)
#           acc: 0.99991, fpr: 0.00005, fnr: 0.00212, rec: 0.99788, prc: 0.99772, f1: 0.99780, f1_macro: 0.99888
# Validation --- epoch: 10, loss: 0.00294
#           acc: 0.99927, fpr: 0.00055, prc: 0.97635, rec: 0.99096, f1: 0.98266, fnr: 0.00904, f1_macro: 0.99114
# epoch: 11, passed number of graphs: 96, train running loss: 0.00039 (passed time: 27m 10s)
#           acc: 0.99998, fpr: 0.00001, fnr: 0.00016, rec: 0.99984, prc: 0.99936, f1: 0.99960, f1_macro: 0.99980
# epoch: 11, passed number of graphs: 192, train running loss: 0.00040 (passed time: 27m 27s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00180, rec: 0.99820, prc: 0.99951, f1: 0.99886, f1_macro: 0.99942
# epoch: 11, passed number of graphs: 288, train running loss: 0.00038 (passed time: 27m 45s)
#           acc: 0.99981, fpr: 0.00016, fnr: 0.00147, rec: 0.99853, prc: 0.99269, f1: 0.99560, f1_macro: 0.99775
# epoch: 11, passed number of graphs: 384, train running loss: 0.00041 (passed time: 28m 2s)
#           acc: 0.99995, fpr: 0.00003, fnr: 0.00129, rec: 0.99871, prc: 0.99887, f1: 0.99879, f1_macro: 0.99938
# epoch: 11, passed number of graphs: 480, train running loss: 0.00040 (passed time: 28m 20s)
#           acc: 0.99983, fpr: 0.00013, fnr: 0.00163, rec: 0.99837, prc: 0.99398, f1: 0.99617, f1_macro: 0.99804
# epoch: 11, passed number of graphs: 576, train running loss: 0.00040 (passed time: 28m 38s)
#           acc: 0.99975, fpr: 0.00023, fnr: 0.00097, rec: 0.99903, prc: 0.98961, f1: 0.99430, f1_macro: 0.99709
# epoch: 11, passed number of graphs: 672, train running loss: 0.00041 (passed time: 28m 55s)
#           acc: 0.99966, fpr: 0.00029, fnr: 0.00272, rec: 0.99728, prc: 0.98703, f1: 0.99213, f1_macro: 0.99598
# epoch: 11, passed number of graphs: 768, train running loss: 0.00045 (passed time: 29m 13s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99935, f1: 0.99869, f1_macro: 0.99933
# Validation --- epoch: 11, loss: 0.00163
#           acc: 0.99974, fpr: 0.00006, prc: 0.99714, rec: 0.99095, f1: 0.99328, fnr: 0.00905, f1_macro: 0.99658
# epoch: 12, passed number of graphs: 96, train running loss: 0.00038 (passed time: 29m 49s)
#           acc: 0.99998, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99936, f1: 0.99952, f1_macro: 0.99976
# epoch: 12, passed number of graphs: 192, train running loss: 0.00040 (passed time: 30m 7s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00098, rec: 0.99902, prc: 0.99918, f1: 0.99910, f1_macro: 0.99954
# epoch: 12, passed number of graphs: 288, train running loss: 0.00037 (passed time: 30m 24s)
#           acc: 0.99981, fpr: 0.00018, fnr: 0.00098, rec: 0.99902, prc: 0.99189, f1: 0.99544, f1_macro: 0.99767
# epoch: 12, passed number of graphs: 384, train running loss: 0.00040 (passed time: 30m 42s)
#           acc: 0.99995, fpr: 0.00003, fnr: 0.00113, rec: 0.99887, prc: 0.99871, f1: 0.99879, f1_macro: 0.99938
# epoch: 12, passed number of graphs: 480, train running loss: 0.00039 (passed time: 31m 0s)
#           acc: 0.99983, fpr: 0.00013, fnr: 0.00163, rec: 0.99837, prc: 0.99398, f1: 0.99617, f1_macro: 0.99804
# epoch: 12, passed number of graphs: 576, train running loss: 0.00038 (passed time: 31m 17s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00113, rec: 0.99887, prc: 0.98992, f1: 0.99438, f1_macro: 0.99713
# epoch: 12, passed number of graphs: 672, train running loss: 0.00039 (passed time: 31m 35s)
#           acc: 0.99964, fpr: 0.00027, fnr: 0.00431, rec: 0.99569, prc: 0.98795, f1: 0.99180, f1_macro: 0.99581
# epoch: 12, passed number of graphs: 768, train running loss: 0.00043 (passed time: 31m 53s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00310, rec: 0.99690, prc: 0.99951, f1: 0.99820, f1_macro: 0.99908
# Validation --- epoch: 12, loss: 0.00179
#           acc: 0.99970, fpr: 0.00008, prc: 0.99619, rec: 0.98991, f1: 0.99229, fnr: 0.01009, f1_macro: 0.99607
# epoch: 13, passed number of graphs: 96, train running loss: 0.00037 (passed time: 32m 29s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00000, rec: 1.00000, prc: 0.99936, f1: 0.99968, f1_macro: 0.99984
# epoch: 13, passed number of graphs: 192, train running loss: 0.00039 (passed time: 32m 47s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00163, rec: 0.99837, prc: 0.99951, f1: 0.99894, f1_macro: 0.99946
# epoch: 13, passed number of graphs: 288, train running loss: 0.00037 (passed time: 33m 4s)
#           acc: 0.99981, fpr: 0.00018, fnr: 0.00082, rec: 0.99918, prc: 0.99189, f1: 0.99552, f1_macro: 0.99771
# epoch: 13, passed number of graphs: 384, train running loss: 0.00039 (passed time: 33m 22s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00129, rec: 0.99871, prc: 0.99871, f1: 0.99871, f1_macro: 0.99934
# epoch: 13, passed number of graphs: 480, train running loss: 0.00039 (passed time: 33m 40s)
#           acc: 0.99982, fpr: 0.00012, fnr: 0.00261, rec: 0.99739, prc: 0.99446, f1: 0.99592, f1_macro: 0.99792
# epoch: 13, passed number of graphs: 576, train running loss: 0.00038 (passed time: 33m 57s)
#           acc: 0.99967, fpr: 0.00033, fnr: 0.00032, rec: 0.99968, prc: 0.98505, f1: 0.99231, f1_macro: 0.99607
# epoch: 13, passed number of graphs: 672, train running loss: 0.00039 (passed time: 34m 15s)
#           acc: 0.99965, fpr: 0.00027, fnr: 0.00431, rec: 0.99569, prc: 0.98811, f1: 0.99188, f1_macro: 0.99585
# epoch: 13, passed number of graphs: 768, train running loss: 0.00044 (passed time: 34m 32s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00245, rec: 0.99755, prc: 0.99951, f1: 0.99853, f1_macro: 0.99925
# Validation --- epoch: 13, loss: 0.00189
#           acc: 0.99971, fpr: 0.00003, prc: 0.99863, rec: 0.98805, f1: 0.99256, fnr: 0.01195, f1_macro: 0.99621
# epoch: 14, passed number of graphs: 96, train running loss: 0.00044 (passed time: 35m 10s)
#           acc: 0.99998, fpr: 0.00001, fnr: 0.00016, rec: 0.99984, prc: 0.99936, f1: 0.99960, f1_macro: 0.99980
# epoch: 14, passed number of graphs: 192, train running loss: 0.00044 (passed time: 35m 27s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00180, rec: 0.99820, prc: 0.99951, f1: 0.99886, f1_macro: 0.99942
# epoch: 14, passed number of graphs: 288, train running loss: 0.00040 (passed time: 35m 45s)
#           acc: 0.99982, fpr: 0.00017, fnr: 0.00082, rec: 0.99918, prc: 0.99237, f1: 0.99577, f1_macro: 0.99784
# epoch: 14, passed number of graphs: 384, train running loss: 0.00042 (passed time: 36m 3s)
#           acc: 0.99995, fpr: 0.00003, fnr: 0.00097, rec: 0.99903, prc: 0.99871, f1: 0.99887, f1_macro: 0.99942
# epoch: 14, passed number of graphs: 480, train running loss: 0.00041 (passed time: 36m 20s)
#           acc: 0.99984, fpr: 0.00014, fnr: 0.00065, rec: 0.99935, prc: 0.99350, f1: 0.99642, f1_macro: 0.99817
# epoch: 14, passed number of graphs: 576, train running loss: 0.00040 (passed time: 36m 38s)
#           acc: 0.99975, fpr: 0.00024, fnr: 0.00081, rec: 0.99919, prc: 0.98929, f1: 0.99422, f1_macro: 0.99705
# epoch: 14, passed number of graphs: 672, train running loss: 0.00041 (passed time: 36m 55s)
#           acc: 0.99966, fpr: 0.00033, fnr: 0.00096, rec: 0.99904, prc: 0.98534, f1: 0.99214, f1_macro: 0.99598
# epoch: 14, passed number of graphs: 768, train running loss: 0.00044 (passed time: 37m 13s)
#           acc: 0.99992, fpr: 0.00007, fnr: 0.00049, rec: 0.99951, prc: 0.99658, f1: 0.99805, f1_macro: 0.99900
# Validation --- epoch: 14, loss: 0.00517
#           acc: 0.99842, fpr: 0.00151, prc: 0.93891, rec: 0.99541, f1: 0.96487, fnr: 0.00459, f1_macro: 0.98203
# epoch: 15, passed number of graphs: 96, train running loss: 0.00042 (passed time: 37m 50s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00000, rec: 1.00000, prc: 0.99920, f1: 0.99960, f1_macro: 0.99980
# epoch: 15, passed number of graphs: 192, train running loss: 0.00041 (passed time: 38m 8s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00180, rec: 0.99820, prc: 0.99935, f1: 0.99877, f1_macro: 0.99937
# epoch: 15, passed number of graphs: 288, train running loss: 0.00038 (passed time: 38m 26s)
#           acc: 0.99981, fpr: 0.00018, fnr: 0.00098, rec: 0.99902, prc: 0.99189, f1: 0.99544, f1_macro: 0.99767
# epoch: 15, passed number of graphs: 384, train running loss: 0.00038 (passed time: 38m 43s)
#           acc: 0.99995, fpr: 0.00003, fnr: 0.00113, rec: 0.99887, prc: 0.99871, f1: 0.99879, f1_macro: 0.99938
# epoch: 15, passed number of graphs: 480, train running loss: 0.00038 (passed time: 39m 1s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00082, rec: 0.99918, prc: 0.99302, f1: 0.99609, f1_macro: 0.99800
# epoch: 15, passed number of graphs: 576, train running loss: 0.00037 (passed time: 39m 19s)
#           acc: 0.99975, fpr: 0.00022, fnr: 0.00129, rec: 0.99871, prc: 0.98992, f1: 0.99429, f1_macro: 0.99708
# epoch: 15, passed number of graphs: 672, train running loss: 0.00037 (passed time: 39m 36s)
#           acc: 0.99965, fpr: 0.00031, fnr: 0.00208, rec: 0.99792, prc: 0.98595, f1: 0.99190, f1_macro: 0.99586
# epoch: 15, passed number of graphs: 768, train running loss: 0.00039 (passed time: 39m 54s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99886, f1: 0.99902, f1_macro: 0.99950
# Validation --- epoch: 15, loss: 0.00151
#           acc: 0.99972, fpr: 0.00012, prc: 0.99437, rec: 0.99285, f1: 0.99287, fnr: 0.00715, f1_macro: 0.99636
# epoch: 16, passed number of graphs: 96, train running loss: 0.00039 (passed time: 40m 31s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00000, rec: 1.00000, prc: 0.99904, f1: 0.99952, f1_macro: 0.99976
# epoch: 16, passed number of graphs: 192, train running loss: 0.00040 (passed time: 40m 49s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00163, rec: 0.99837, prc: 0.99918, f1: 0.99877, f1_macro: 0.99937
# epoch: 16, passed number of graphs: 288, train running loss: 0.00037 (passed time: 41m 6s)
#           acc: 0.99981, fpr: 0.00018, fnr: 0.00082, rec: 0.99918, prc: 0.99189, f1: 0.99552, f1_macro: 0.99771
# epoch: 16, passed number of graphs: 384, train running loss: 0.00038 (passed time: 41m 24s)
#           acc: 0.99995, fpr: 0.00003, fnr: 0.00113, rec: 0.99887, prc: 0.99871, f1: 0.99879, f1_macro: 0.99938
# epoch: 16, passed number of graphs: 480, train running loss: 0.00037 (passed time: 41m 41s)
#           acc: 0.99983, fpr: 0.00015, fnr: 0.00098, rec: 0.99902, prc: 0.99318, f1: 0.99609, f1_macro: 0.99800
# epoch: 16, passed number of graphs: 576, train running loss: 0.00036 (passed time: 41m 59s)
#           acc: 0.99975, fpr: 0.00022, fnr: 0.00129, rec: 0.99871, prc: 0.98992, f1: 0.99429, f1_macro: 0.99708
# epoch: 16, passed number of graphs: 672, train running loss: 0.00037 (passed time: 42m 17s)
#           acc: 0.99965, fpr: 0.00031, fnr: 0.00208, rec: 0.99792, prc: 0.98595, f1: 0.99190, f1_macro: 0.99586
# epoch: 16, passed number of graphs: 768, train running loss: 0.00038 (passed time: 42m 34s)
#           acc: 0.99996, fpr: 0.00003, fnr: 0.00065, rec: 0.99935, prc: 0.99870, f1: 0.99902, f1_macro: 0.99950
# Validation --- epoch: 16, loss: 0.00147
#           acc: 0.99975, fpr: 0.00010, prc: 0.99557, rec: 0.99268, f1: 0.99338, fnr: 0.00732, f1_macro: 0.99662
# Better model saved at ./saved_models/GIN_15: 0.9933760483135384.pt.
# epoch: 17, passed number of graphs: 96, train running loss: 0.00039 (passed time: 43m 11s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00000, rec: 1.00000, prc: 0.99920, f1: 0.99960, f1_macro: 0.99980
# epoch: 17, passed number of graphs: 192, train running loss: 0.00040 (passed time: 43m 29s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00163, rec: 0.99837, prc: 0.99935, f1: 0.99886, f1_macro: 0.99942
# epoch: 17, passed number of graphs: 288, train running loss: 0.00037 (passed time: 43m 47s)
#           acc: 0.99981, fpr: 0.00018, fnr: 0.00082, rec: 0.99918, prc: 0.99189, f1: 0.99552, f1_macro: 0.99771
# epoch: 17, passed number of graphs: 384, train running loss: 0.00037 (passed time: 44m 4s)
#           acc: 0.99995, fpr: 0.00003, fnr: 0.00113, rec: 0.99887, prc: 0.99871, f1: 0.99879, f1_macro: 0.99938
# epoch: 17, passed number of graphs: 480, train running loss: 0.00037 (passed time: 44m 22s)
#           acc: 0.99983, fpr: 0.00015, fnr: 0.00114, rec: 0.99886, prc: 0.99334, f1: 0.99609, f1_macro: 0.99800
# epoch: 17, passed number of graphs: 576, train running loss: 0.00036 (passed time: 44m 40s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00129, rec: 0.99871, prc: 0.99024, f1: 0.99445, f1_macro: 0.99717
# epoch: 17, passed number of graphs: 672, train running loss: 0.00036 (passed time: 44m 57s)
#           acc: 0.99965, fpr: 0.00031, fnr: 0.00240, rec: 0.99760, prc: 0.98626, f1: 0.99190, f1_macro: 0.99586
# epoch: 17, passed number of graphs: 768, train running loss: 0.00038 (passed time: 45m 15s)
#           acc: 0.99996, fpr: 0.00003, fnr: 0.00065, rec: 0.99935, prc: 0.99870, f1: 0.99902, f1_macro: 0.99950
# Validation --- epoch: 17, loss: 0.00147
#           acc: 0.99976, fpr: 0.00006, prc: 0.99722, rec: 0.99161, f1: 0.99365, fnr: 0.00839, f1_macro: 0.99676
# Better model saved at ./saved_models/GIN_16: 0.9936527751653768.pt.
# epoch: 18, passed number of graphs: 96, train running loss: 0.00038 (passed time: 45m 52s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00000, rec: 1.00000, prc: 0.99920, f1: 0.99960, f1_macro: 0.99980
# epoch: 18, passed number of graphs: 192, train running loss: 0.00039 (passed time: 46m 10s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00163, rec: 0.99837, prc: 0.99935, f1: 0.99886, f1_macro: 0.99942
# epoch: 18, passed number of graphs: 288, train running loss: 0.00037 (passed time: 46m 27s)
#           acc: 0.99981, fpr: 0.00018, fnr: 0.00082, rec: 0.99918, prc: 0.99189, f1: 0.99552, f1_macro: 0.99771
# epoch: 18, passed number of graphs: 384, train running loss: 0.00037 (passed time: 46m 45s)
#           acc: 0.99995, fpr: 0.00003, fnr: 0.00113, rec: 0.99887, prc: 0.99871, f1: 0.99879, f1_macro: 0.99938
# epoch: 18, passed number of graphs: 480, train running loss: 0.00037 (passed time: 47m 2s)
#           acc: 0.99984, fpr: 0.00014, fnr: 0.00114, rec: 0.99886, prc: 0.99366, f1: 0.99625, f1_macro: 0.99808
# epoch: 18, passed number of graphs: 576, train running loss: 0.00036 (passed time: 47m 20s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00129, rec: 0.99871, prc: 0.99087, f1: 0.99477, f1_macro: 0.99733
# epoch: 18, passed number of graphs: 672, train running loss: 0.00036 (passed time: 47m 37s)
#           acc: 0.99965, fpr: 0.00030, fnr: 0.00256, rec: 0.99744, prc: 0.98657, f1: 0.99197, f1_macro: 0.99590
# epoch: 18, passed number of graphs: 768, train running loss: 0.00037 (passed time: 47m 55s)
#           acc: 0.99996, fpr: 0.00003, fnr: 0.00065, rec: 0.99935, prc: 0.99870, f1: 0.99902, f1_macro: 0.99950
# Validation --- epoch: 18, loss: 0.00213
#           acc: 0.99956, fpr: 0.00004, prc: 0.99828, rec: 0.98124, f1: 0.98860, fnr: 0.01876, f1_macro: 0.99419
# epoch: 19, passed number of graphs: 96, train running loss: 0.00040 (passed time: 48m 32s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 19, passed number of graphs: 192, train running loss: 0.00041 (passed time: 48m 50s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00180, rec: 0.99820, prc: 0.99935, f1: 0.99877, f1_macro: 0.99937
# epoch: 19, passed number of graphs: 288, train running loss: 0.00038 (passed time: 49m 8s)
#           acc: 0.99981, fpr: 0.00017, fnr: 0.00098, rec: 0.99902, prc: 0.99205, f1: 0.99552, f1_macro: 0.99771
# epoch: 19, passed number of graphs: 384, train running loss: 0.00037 (passed time: 49m 25s)
#           acc: 0.99995, fpr: 0.00003, fnr: 0.00113, rec: 0.99887, prc: 0.99871, f1: 0.99879, f1_macro: 0.99938
# epoch: 19, passed number of graphs: 480, train running loss: 0.00037 (passed time: 49m 43s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00082, rec: 0.99918, prc: 0.99302, f1: 0.99609, f1_macro: 0.99800
# epoch: 19, passed number of graphs: 576, train running loss: 0.00036 (passed time: 50m 0s)
#           acc: 0.99976, fpr: 0.00023, fnr: 0.00097, rec: 0.99903, prc: 0.98976, f1: 0.99438, f1_macro: 0.99713
# epoch: 19, passed number of graphs: 672, train running loss: 0.00036 (passed time: 50m 18s)
#           acc: 0.99964, fpr: 0.00034, fnr: 0.00144, rec: 0.99856, prc: 0.98503, f1: 0.99175, f1_macro: 0.99578
# epoch: 19, passed number of graphs: 768, train running loss: 0.00036 (passed time: 50m 35s)
#           acc: 0.99997, fpr: 0.00001, fnr: 0.00082, rec: 0.99918, prc: 0.99935, f1: 0.99927, f1_macro: 0.99962
# Validation --- epoch: 19, loss: 0.00137
#           acc: 0.99977, fpr: 0.00007, prc: 0.99688, rec: 0.99251, f1: 0.99394, fnr: 0.00749, f1_macro: 0.99691
# Better model saved at ./saved_models/GIN_18: 0.9939393193559781.pt.
# epoch: 20, passed number of graphs: 96, train running loss: 0.00034 (passed time: 51m 13s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00000, rec: 1.00000, prc: 0.99904, f1: 0.99952, f1_macro: 0.99976
# epoch: 20, passed number of graphs: 192, train running loss: 0.00037 (passed time: 51m 30s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00180, rec: 0.99820, prc: 0.99935, f1: 0.99877, f1_macro: 0.99937
# epoch: 20, passed number of graphs: 288, train running loss: 0.00035 (passed time: 51m 48s)
#           acc: 0.99981, fpr: 0.00017, fnr: 0.00082, rec: 0.99918, prc: 0.99205, f1: 0.99560, f1_macro: 0.99775
# epoch: 20, passed number of graphs: 384, train running loss: 0.00035 (passed time: 52m 5s)
#           acc: 0.99995, fpr: 0.00003, fnr: 0.00113, rec: 0.99887, prc: 0.99871, f1: 0.99879, f1_macro: 0.99938
# epoch: 20, passed number of graphs: 480, train running loss: 0.00035 (passed time: 52m 23s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00082, rec: 0.99918, prc: 0.99302, f1: 0.99609, f1_macro: 0.99800
# epoch: 20, passed number of graphs: 576, train running loss: 0.00034 (passed time: 52m 41s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00097, rec: 0.99903, prc: 0.99008, f1: 0.99454, f1_macro: 0.99721
# epoch: 20, passed number of graphs: 672, train running loss: 0.00035 (passed time: 52m 58s)
#           acc: 0.99964, fpr: 0.00034, fnr: 0.00144, rec: 0.99856, prc: 0.98503, f1: 0.99175, f1_macro: 0.99578
# epoch: 20, passed number of graphs: 768, train running loss: 0.00035 (passed time: 53m 16s)
#           acc: 0.99997, fpr: 0.00001, fnr: 0.00065, rec: 0.99935, prc: 0.99935, f1: 0.99935, f1_macro: 0.99967
# Validation --- epoch: 20, loss: 0.00136
#           acc: 0.99977, fpr: 0.00007, prc: 0.99672, rec: 0.99258, f1: 0.99389, fnr: 0.00742, f1_macro: 0.99689
# epoch: 21, passed number of graphs: 96, train running loss: 0.00034 (passed time: 53m 53s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00000, rec: 1.00000, prc: 0.99904, f1: 0.99952, f1_macro: 0.99976
# epoch: 21, passed number of graphs: 192, train running loss: 0.00037 (passed time: 54m 11s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00180, rec: 0.99820, prc: 0.99935, f1: 0.99877, f1_macro: 0.99937
# epoch: 21, passed number of graphs: 288, train running loss: 0.00035 (passed time: 54m 28s)
#           acc: 0.99981, fpr: 0.00017, fnr: 0.00082, rec: 0.99918, prc: 0.99205, f1: 0.99560, f1_macro: 0.99775
# epoch: 21, passed number of graphs: 384, train running loss: 0.00035 (passed time: 54m 46s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00129, rec: 0.99871, prc: 0.99871, f1: 0.99871, f1_macro: 0.99934
# epoch: 21, passed number of graphs: 480, train running loss: 0.00035 (passed time: 55m 3s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00082, rec: 0.99918, prc: 0.99302, f1: 0.99609, f1_macro: 0.99800
# epoch: 21, passed number of graphs: 576, train running loss: 0.00034 (passed time: 55m 21s)
#           acc: 0.99978, fpr: 0.00021, fnr: 0.00097, rec: 0.99903, prc: 0.99056, f1: 0.99478, f1_macro: 0.99733
# epoch: 21, passed number of graphs: 672, train running loss: 0.00035 (passed time: 55m 39s)
#           acc: 0.99964, fpr: 0.00034, fnr: 0.00128, rec: 0.99872, prc: 0.98503, f1: 0.99183, f1_macro: 0.99582
# epoch: 21, passed number of graphs: 768, train running loss: 0.00035 (passed time: 55m 56s)
#           acc: 0.99997, fpr: 0.00001, fnr: 0.00065, rec: 0.99935, prc: 0.99935, f1: 0.99935, f1_macro: 0.99967
# Validation --- epoch: 21, loss: 0.00137
#           acc: 0.99977, fpr: 0.00007, prc: 0.99667, rec: 0.99259, f1: 0.99387, fnr: 0.00741, f1_macro: 0.99688
# epoch: 22, passed number of graphs: 96, train running loss: 0.00034 (passed time: 56m 33s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00000, rec: 1.00000, prc: 0.99904, f1: 0.99952, f1_macro: 0.99976
# epoch: 22, passed number of graphs: 192, train running loss: 0.00037 (passed time: 56m 51s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00180, rec: 0.99820, prc: 0.99935, f1: 0.99877, f1_macro: 0.99937
# epoch: 22, passed number of graphs: 288, train running loss: 0.00035 (passed time: 57m 9s)
#           acc: 0.99981, fpr: 0.00017, fnr: 0.00098, rec: 0.99902, prc: 0.99205, f1: 0.99552, f1_macro: 0.99771
# epoch: 22, passed number of graphs: 384, train running loss: 0.00035 (passed time: 57m 26s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 22, passed number of graphs: 480, train running loss: 0.00035 (passed time: 57m 44s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00082, rec: 0.99918, prc: 0.99302, f1: 0.99609, f1_macro: 0.99800
# epoch: 22, passed number of graphs: 576, train running loss: 0.00034 (passed time: 58m 1s)
#           acc: 0.99979, fpr: 0.00020, fnr: 0.00097, rec: 0.99903, prc: 0.99103, f1: 0.99502, f1_macro: 0.99745
# epoch: 22, passed number of graphs: 672, train running loss: 0.00035 (passed time: 58m 19s)
#           acc: 0.99964, fpr: 0.00034, fnr: 0.00128, rec: 0.99872, prc: 0.98503, f1: 0.99183, f1_macro: 0.99582
# epoch: 22, passed number of graphs: 768, train running loss: 0.00035 (passed time: 58m 37s)
#           acc: 0.99997, fpr: 0.00001, fnr: 0.00082, rec: 0.99918, prc: 0.99935, f1: 0.99927, f1_macro: 0.99962
# Validation --- epoch: 22, loss: 0.00136
#           acc: 0.99977, fpr: 0.00007, prc: 0.99673, rec: 0.99259, f1: 0.99390, fnr: 0.00741, f1_macro: 0.99689
# epoch: 23, passed number of graphs: 96, train running loss: 0.00034 (passed time: 59m 14s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00000, rec: 1.00000, prc: 0.99904, f1: 0.99952, f1_macro: 0.99976
# epoch: 23, passed number of graphs: 192, train running loss: 0.00037 (passed time: 59m 31s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00180, rec: 0.99820, prc: 0.99935, f1: 0.99877, f1_macro: 0.99937
# epoch: 23, passed number of graphs: 288, train running loss: 0.00035 (passed time: 59m 49s)
#           acc: 0.99981, fpr: 0.00017, fnr: 0.00098, rec: 0.99902, prc: 0.99221, f1: 0.99560, f1_macro: 0.99775
# epoch: 23, passed number of graphs: 384, train running loss: 0.00035 (passed time: 1h 0m 7s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 23, passed number of graphs: 480, train running loss: 0.00035 (passed time: 1h 0m 24s)
#           acc: 0.99983, fpr: 0.00015, fnr: 0.00082, rec: 0.99918, prc: 0.99318, f1: 0.99617, f1_macro: 0.99804
# epoch: 23, passed number of graphs: 576, train running loss: 0.00034 (passed time: 1h 0m 42s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00113, rec: 0.99887, prc: 0.99103, f1: 0.99494, f1_macro: 0.99741
# epoch: 23, passed number of graphs: 672, train running loss: 0.00035 (passed time: 1h 0m 59s)
#           acc: 0.99964, fpr: 0.00034, fnr: 0.00128, rec: 0.99872, prc: 0.98503, f1: 0.99183, f1_macro: 0.99582
# epoch: 23, passed number of graphs: 768, train running loss: 0.00035 (passed time: 1h 1m 17s)
#           acc: 0.99997, fpr: 0.00001, fnr: 0.00082, rec: 0.99918, prc: 0.99935, f1: 0.99927, f1_macro: 0.99962
# Validation --- epoch: 23, loss: 0.00136
#           acc: 0.99977, fpr: 0.00007, prc: 0.99685, rec: 0.99255, f1: 0.99394, fnr: 0.00745, f1_macro: 0.99691
# Better model saved at ./saved_models/GIN_22: 0.9939449422525984.pt.
# epoch: 24, passed number of graphs: 96, train running loss: 0.00034 (passed time: 1h 1m 54s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00000, rec: 1.00000, prc: 0.99904, f1: 0.99952, f1_macro: 0.99976
# epoch: 24, passed number of graphs: 192, train running loss: 0.00037 (passed time: 1h 2m 12s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00180, rec: 0.99820, prc: 0.99935, f1: 0.99877, f1_macro: 0.99937
# epoch: 24, passed number of graphs: 288, train running loss: 0.00035 (passed time: 1h 2m 30s)
#           acc: 0.99982, fpr: 0.00017, fnr: 0.00098, rec: 0.99902, prc: 0.99237, f1: 0.99568, f1_macro: 0.99780
# ...
# epoch: 42, passed number of graphs: 384, train running loss: 0.00033 (passed time: 1h 50m 52s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00177, rec: 0.99823, prc: 0.99871, f1: 0.99847, f1_macro: 0.99922
# epoch: 42, passed number of graphs: 480, train running loss: 0.00033 (passed time: 1h 51m 9s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00082, rec: 0.99918, prc: 0.99286, f1: 0.99601, f1_macro: 0.99796
# epoch: 42, passed number of graphs: 576, train running loss: 0.00032 (passed time: 1h 51m 27s)
#           acc: 0.99979, fpr: 0.00019, fnr: 0.00129, rec: 0.99871, prc: 0.99151, f1: 0.99509, f1_macro: 0.99749
# epoch: 42, passed number of graphs: 672, train running loss: 0.00033 (passed time: 1h 51m 44s)
#           acc: 0.99964, fpr: 0.00034, fnr: 0.00144, rec: 0.99856, prc: 0.98487, f1: 0.99167, f1_macro: 0.99574
# epoch: 42, passed number of graphs: 768, train running loss: 0.00033 (passed time: 1h 52m 2s)
#           acc: 0.99997, fpr: 0.00001, fnr: 0.00098, rec: 0.99902, prc: 0.99935, f1: 0.99918, f1_macro: 0.99958
# Validation --- epoch: 42, loss: 0.00132
#           acc: 0.99977, fpr: 0.00006, prc: 0.99737, rec: 0.99214, f1: 0.99400, fnr: 0.00786, f1_macro: 0.99694
# epoch: 43, passed number of graphs: 96, train running loss: 0.00031 (passed time: 1h 52m 39s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00000, rec: 1.00000, prc: 0.99904, f1: 0.99952, f1_macro: 0.99976
# epoch: 43, passed number of graphs: 192, train running loss: 0.00035 (passed time: 1h 52m 57s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00114, rec: 0.99886, prc: 0.99935, f1: 0.99910, f1_macro: 0.99954
# epoch: 43, passed number of graphs: 288, train running loss: 0.00033 (passed time: 1h 53m 14s)
#           acc: 0.99982, fpr: 0.00016, fnr: 0.00098, rec: 0.99902, prc: 0.99253, f1: 0.99577, f1_macro: 0.99784
# epoch: 43, passed number of graphs: 384, train running loss: 0.00033 (passed time: 1h 53m 32s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00177, rec: 0.99823, prc: 0.99871, f1: 0.99847, f1_macro: 0.99922
# epoch: 43, passed number of graphs: 480, train running loss: 0.00033 (passed time: 1h 53m 49s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00082, rec: 0.99918, prc: 0.99286, f1: 0.99601, f1_macro: 0.99796
# epoch: 43, passed number of graphs: 576, train running loss: 0.00032 (passed time: 1h 54m 7s)
#           acc: 0.99979, fpr: 0.00019, fnr: 0.00129, rec: 0.99871, prc: 0.99151, f1: 0.99509, f1_macro: 0.99749
# epoch: 43, passed number of graphs: 672, train running loss: 0.00033 (passed time: 1h 54m 24s)
#           acc: 0.99964, fpr: 0.00034, fnr: 0.00144, rec: 0.99856, prc: 0.98503, f1: 0.99175, f1_macro: 0.99578
# epoch: 43, passed number of graphs: 768, train running loss: 0.00033 (passed time: 1h 54m 42s)
#           acc: 0.99997, fpr: 0.00001, fnr: 0.00098, rec: 0.99902, prc: 0.99935, f1: 0.99918, f1_macro: 0.99958
# Validation --- epoch: 43, loss: 0.00132
#           acc: 0.99977, fpr: 0.00006, prc: 0.99739, rec: 0.99213, f1: 0.99400, fnr: 0.00787, f1_macro: 0.99694
# Better model saved at ./saved_models/GIN_42: 0.9940033800968621.pt.
# epoch: 44, passed number of graphs: 96, train running loss: 0.00031 (passed time: 1h 55m 19s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00000, rec: 1.00000, prc: 0.99904, f1: 0.99952, f1_macro: 0.99976
# epoch: 44, passed number of graphs: 192, train running loss: 0.00035 (passed time: 1h 55m 37s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00114, rec: 0.99886, prc: 0.99935, f1: 0.99910, f1_macro: 0.99954
# epoch: 44, passed number of graphs: 288, train running loss: 0.00033 (passed time: 1h 55m 54s)
#           acc: 0.99982, fpr: 0.00016, fnr: 0.00098, rec: 0.99902, prc: 0.99253, f1: 0.99577, f1_macro: 0.99784
# epoch: 44, passed number of graphs: 384, train running loss: 0.00033 (passed time: 1h 56m 12s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00177, rec: 0.99823, prc: 0.99871, f1: 0.99847, f1_macro: 0.99922
# epoch: 44, passed number of graphs: 480, train running loss: 0.00033 (passed time: 1h 56m 29s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00082, rec: 0.99918, prc: 0.99286, f1: 0.99601, f1_macro: 0.99796
# epoch: 44, passed number of graphs: 576, train running loss: 0.00032 (passed time: 1h 56m 47s)
#           acc: 0.99979, fpr: 0.00019, fnr: 0.00129, rec: 0.99871, prc: 0.99151, f1: 0.99509, f1_macro: 0.99749
# epoch: 44, passed number of graphs: 672, train running loss: 0.00033 (passed time: 1h 57m 4s)
#           acc: 0.99964, fpr: 0.00034, fnr: 0.00144, rec: 0.99856, prc: 0.98503, f1: 0.99175, f1_macro: 0.99578
# epoch: 44, passed number of graphs: 768, train running loss: 0.00033 (passed time: 1h 57m 22s)
#           acc: 0.99997, fpr: 0.00001, fnr: 0.00098, rec: 0.99902, prc: 0.99935, f1: 0.99918, f1_macro: 0.99958
# Validation --- epoch: 44, loss: 0.00132
#           acc: 0.99977, fpr: 0.00006, prc: 0.99736, rec: 0.99215, f1: 0.99399, fnr: 0.00785, f1_macro: 0.99694
# epoch: 45, passed number of graphs: 96, train running loss: 0.00031 (passed time: 1h 57m 59s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00000, rec: 1.00000, prc: 0.99904, f1: 0.99952, f1_macro: 0.99976
# epoch: 45, passed number of graphs: 192, train running loss: 0.00035 (passed time: 1h 58m 17s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00114, rec: 0.99886, prc: 0.99935, f1: 0.99910, f1_macro: 0.99954
# epoch: 45, passed number of graphs: 288, train running loss: 0.00033 (passed time: 1h 58m 34s)
#           acc: 0.99982, fpr: 0.00016, fnr: 0.00098, rec: 0.99902, prc: 0.99253, f1: 0.99577, f1_macro: 0.99784
# epoch: 45, passed number of graphs: 384, train running loss: 0.00033 (passed time: 1h 58m 52s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00177, rec: 0.99823, prc: 0.99871, f1: 0.99847, f1_macro: 0.99922
# epoch: 45, passed number of graphs: 480, train running loss: 0.00033 (passed time: 1h 59m 9s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00082, rec: 0.99918, prc: 0.99286, f1: 0.99601, f1_macro: 0.99796
# epoch: 45, passed number of graphs: 576, train running loss: 0.00032 (passed time: 1h 59m 27s)
#           acc: 0.99979, fpr: 0.00019, fnr: 0.00129, rec: 0.99871, prc: 0.99151, f1: 0.99509, f1_macro: 0.99749
# epoch: 45, passed number of graphs: 672, train running loss: 0.00033 (passed time: 1h 59m 44s)
#           acc: 0.99964, fpr: 0.00034, fnr: 0.00144, rec: 0.99856, prc: 0.98503, f1: 0.99175, f1_macro: 0.99578
# epoch: 45, passed number of graphs: 768, train running loss: 0.00033 (passed time: 2h 0m 2s)
#           acc: 0.99997, fpr: 0.00001, fnr: 0.00098, rec: 0.99902, prc: 0.99935, f1: 0.99918, f1_macro: 0.99958
# Validation --- epoch: 45, loss: 0.00131
#           acc: 0.99977, fpr: 0.00006, prc: 0.99733, rec: 0.99217, f1: 0.99400, fnr: 0.00783, f1_macro: 0.99694
# epoch: 46, passed number of graphs: 96, train running loss: 0.00031 (passed time: 2h 0m 39s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00000, rec: 1.00000, prc: 0.99904, f1: 0.99952, f1_macro: 0.99976
# epoch: 46, passed number of graphs: 192, train running loss: 0.00035 (passed time: 2h 0m 56s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00114, rec: 0.99886, prc: 0.99935, f1: 0.99910, f1_macro: 0.99954
# epoch: 46, passed number of graphs: 288, train running loss: 0.00033 (passed time: 2h 1m 14s)
#           acc: 0.99982, fpr: 0.00016, fnr: 0.00098, rec: 0.99902, prc: 0.99253, f1: 0.99577, f1_macro: 0.99784
# epoch: 46, passed number of graphs: 384, train running loss: 0.00033 (passed time: 2h 1m 31s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00161, rec: 0.99839, prc: 0.99871, f1: 0.99855, f1_macro: 0.99926
# epoch: 46, passed number of graphs: 480, train running loss: 0.00033 (passed time: 2h 1m 49s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00082, rec: 0.99918, prc: 0.99286, f1: 0.99601, f1_macro: 0.99796
# epoch: 46, passed number of graphs: 576, train running loss: 0.00032 (passed time: 2h 2m 6s)
#           acc: 0.99979, fpr: 0.00019, fnr: 0.00129, rec: 0.99871, prc: 0.99151, f1: 0.99509, f1_macro: 0.99749
# epoch: 46, passed number of graphs: 672, train running loss: 0.00033 (passed time: 2h 2m 24s)
#           acc: 0.99964, fpr: 0.00034, fnr: 0.00144, rec: 0.99856, prc: 0.98503, f1: 0.99175, f1_macro: 0.99578
# epoch: 46, passed number of graphs: 768, train running loss: 0.00033 (passed time: 2h 2m 41s)
#           acc: 0.99997, fpr: 0.00001, fnr: 0.00098, rec: 0.99902, prc: 0.99935, f1: 0.99918, f1_macro: 0.99958
# Validation --- epoch: 46, loss: 0.00131
#           acc: 0.99977, fpr: 0.00006, prc: 0.99735, rec: 0.99216, f1: 0.99400, fnr: 0.00784, f1_macro: 0.99694
# epoch: 47, passed number of graphs: 96, train running loss: 0.00031 (passed time: 2h 3m 18s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00000, rec: 1.00000, prc: 0.99904, f1: 0.99952, f1_macro: 0.99976
# epoch: 47, passed number of graphs: 192, train running loss: 0.00035 (passed time: 2h 3m 36s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00114, rec: 0.99886, prc: 0.99935, f1: 0.99910, f1_macro: 0.99954
# epoch: 47, passed number of graphs: 288, train running loss: 0.00033 (passed time: 2h 3m 54s)
#           acc: 0.99982, fpr: 0.00016, fnr: 0.00098, rec: 0.99902, prc: 0.99253, f1: 0.99577, f1_macro: 0.99784
# epoch: 47, passed number of graphs: 384, train running loss: 0.00033 (passed time: 2h 4m 11s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00161, rec: 0.99839, prc: 0.99871, f1: 0.99855, f1_macro: 0.99926
# epoch: 47, passed number of graphs: 480, train running loss: 0.00033 (passed time: 2h 4m 29s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00082, rec: 0.99918, prc: 0.99286, f1: 0.99601, f1_macro: 0.99796
# epoch: 47, passed number of graphs: 576, train running loss: 0.00032 (passed time: 2h 4m 46s)
#           acc: 0.99979, fpr: 0.00019, fnr: 0.00129, rec: 0.99871, prc: 0.99151, f1: 0.99509, f1_macro: 0.99749
# epoch: 47, passed number of graphs: 672, train running loss: 0.00033 (passed time: 2h 5m 4s)
#           acc: 0.99964, fpr: 0.00034, fnr: 0.00144, rec: 0.99856, prc: 0.98503, f1: 0.99175, f1_macro: 0.99578
# epoch: 47, passed number of graphs: 768, train running loss: 0.00033 (passed time: 2h 5m 21s)
#           acc: 0.99997, fpr: 0.00001, fnr: 0.00098, rec: 0.99902, prc: 0.99935, f1: 0.99918, f1_macro: 0.99958
# Validation --- epoch: 47, loss: 0.00131
#           acc: 0.99977, fpr: 0.00006, prc: 0.99733, rec: 0.99219, f1: 0.99400, fnr: 0.00781, f1_macro: 0.99694
# epoch: 48, passed number of graphs: 96, train running loss: 0.00031 (passed time: 2h 5m 58s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00000, rec: 1.00000, prc: 0.99904, f1: 0.99952, f1_macro: 0.99976
# epoch: 48, passed number of graphs: 192, train running loss: 0.00035 (passed time: 2h 6m 16s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00114, rec: 0.99886, prc: 0.99935, f1: 0.99910, f1_macro: 0.99954
# epoch: 48, passed number of graphs: 288, train running loss: 0.00033 (passed time: 2h 6m 33s)
#           acc: 0.99982, fpr: 0.00016, fnr: 0.00098, rec: 0.99902, prc: 0.99253, f1: 0.99577, f1_macro: 0.99784
# epoch: 48, passed number of graphs: 384, train running loss: 0.00032 (passed time: 2h 6m 51s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00161, rec: 0.99839, prc: 0.99871, f1: 0.99855, f1_macro: 0.99926
# epoch: 48, passed number of graphs: 480, train running loss: 0.00033 (passed time: 2h 7m 8s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00082, rec: 0.99918, prc: 0.99286, f1: 0.99601, f1_macro: 0.99796
# epoch: 48, passed number of graphs: 576, train running loss: 0.00032 (passed time: 2h 7m 26s)
#           acc: 0.99979, fpr: 0.00019, fnr: 0.00129, rec: 0.99871, prc: 0.99151, f1: 0.99509, f1_macro: 0.99749
# epoch: 48, passed number of graphs: 672, train running loss: 0.00033 (passed time: 2h 7m 43s)
#           acc: 0.99964, fpr: 0.00034, fnr: 0.00144, rec: 0.99856, prc: 0.98503, f1: 0.99175, f1_macro: 0.99578
# epoch: 48, passed number of graphs: 768, train running loss: 0.00033 (passed time: 2h 8m 1s)
#           acc: 0.99997, fpr: 0.00001, fnr: 0.00098, rec: 0.99902, prc: 0.99935, f1: 0.99918, f1_macro: 0.99958
# Validation --- epoch: 48, loss: 0.00131
#           acc: 0.99977, fpr: 0.00006, prc: 0.99733, rec: 0.99219, f1: 0.99400, fnr: 0.00781, f1_macro: 0.99694
# Better model saved at ./saved_models/GIN_47: 0.9940036562479165.pt.
# epoch: 49, passed number of graphs: 96, train running loss: 0.00031 (passed time: 2h 8m 38s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00000, rec: 1.00000, prc: 0.99904, f1: 0.99952, f1_macro: 0.99976
# epoch: 49, passed number of graphs: 192, train running loss: 0.00035 (passed time: 2h 8m 55s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00131, rec: 0.99869, prc: 0.99935, f1: 0.99902, f1_macro: 0.99950
# epoch: 49, passed number of graphs: 288, train running loss: 0.00033 (passed time: 2h 9m 13s)
#           acc: 0.99982, fpr: 0.00016, fnr: 0.00098, rec: 0.99902, prc: 0.99253, f1: 0.99577, f1_macro: 0.99784
# epoch: 49, passed number of graphs: 384, train running loss: 0.00032 (passed time: 2h 9m 30s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00161, rec: 0.99839, prc: 0.99871, f1: 0.99855, f1_macro: 0.99926
# epoch: 49, passed number of graphs: 480, train running loss: 0.00033 (passed time: 2h 9m 48s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00082, rec: 0.99918, prc: 0.99286, f1: 0.99601, f1_macro: 0.99796
# epoch: 49, passed number of graphs: 576, train running loss: 0.00032 (passed time: 2h 10m 5s)
#           acc: 0.99979, fpr: 0.00019, fnr: 0.00129, rec: 0.99871, prc: 0.99151, f1: 0.99509, f1_macro: 0.99749
# epoch: 49, passed number of graphs: 672, train running loss: 0.00033 (passed time: 2h 10m 23s)
#           acc: 0.99964, fpr: 0.00034, fnr: 0.00144, rec: 0.99856, prc: 0.98503, f1: 0.99175, f1_macro: 0.99578
# epoch: 49, passed number of graphs: 768, train running loss: 0.00033 (passed time: 2h 10m 40s)
#           acc: 0.99997, fpr: 0.00001, fnr: 0.00098, rec: 0.99902, prc: 0.99935, f1: 0.99918, f1_macro: 0.99958
# Validation --- epoch: 49, loss: 0.00131
#           acc: 0.99977, fpr: 0.00006, prc: 0.99732, rec: 0.99219, f1: 0.99400, fnr: 0.00781, f1_macro: 0.99694
# epoch: 50, passed number of graphs: 96, train running loss: 0.00031 (passed time: 2h 11m 17s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00000, rec: 1.00000, prc: 0.99904, f1: 0.99952, f1_macro: 0.99976
# epoch: 50, passed number of graphs: 192, train running loss: 0.00035 (passed time: 2h 11m 35s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00131, rec: 0.99869, prc: 0.99935, f1: 0.99902, f1_macro: 0.99950
# epoch: 50, passed number of graphs: 288, train running loss: 0.00033 (passed time: 2h 11m 52s)
#           acc: 0.99982, fpr: 0.00017, fnr: 0.00098, rec: 0.99902, prc: 0.99237, f1: 0.99568, f1_macro: 0.99780
# epoch: 50, passed number of graphs: 384, train running loss: 0.00032 (passed time: 2h 12m 10s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00161, rec: 0.99839, prc: 0.99871, f1: 0.99855, f1_macro: 0.99926
# epoch: 50, passed number of graphs: 480, train running loss: 0.00033 (passed time: 2h 12m 27s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00082, rec: 0.99918, prc: 0.99286, f1: 0.99601, f1_macro: 0.99796
# epoch: 50, passed number of graphs: 576, train running loss: 0.00032 (passed time: 2h 12m 45s)
#           acc: 0.99979, fpr: 0.00019, fnr: 0.00129, rec: 0.99871, prc: 0.99151, f1: 0.99509, f1_macro: 0.99749
# epoch: 50, passed number of graphs: 672, train running loss: 0.00032 (passed time: 2h 13m 2s)
#           acc: 0.99964, fpr: 0.00033, fnr: 0.00144, rec: 0.99856, prc: 0.98518, f1: 0.99183, f1_macro: 0.99582
# epoch: 50, passed number of graphs: 768, train running loss: 0.00033 (passed time: 2h 13m 19s)
#           acc: 0.99997, fpr: 0.00001, fnr: 0.00098, rec: 0.99902, prc: 0.99935, f1: 0.99918, f1_macro: 0.99958
# Validation --- epoch: 50, loss: 0.00131
#           acc: 0.99977, fpr: 0.00006, prc: 0.99730, rec: 0.99222, f1: 0.99401, fnr: 0.00778, f1_macro: 0.99695
# Better model saved at ./saved_models/GIN_49: 0.9940092742620922.pt.
# ************ best model obtained after epoch 50, saved at ./saved_models/GIN_49: 0.9940092742620922.pt ************
# Testing --- loss: 0.00102
#           acc: 0.99980, fpr: 0.00013, prc: 0.99443, rec: 0.99648, f1: 0.99518, fnr: 0.00352, f1_macro: 0.99754
