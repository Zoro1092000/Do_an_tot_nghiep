# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/Do_an_tot_nghiep/blob/main/GIN_P2P_4Layer_Dropout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric==1.4.3
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter_
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric==1.4.3 in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.3.5)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (6.2.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.21.6)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.18.3)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.4)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.56.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.7.3)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.7.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.12.1+cu113)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.23.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.6.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->torch-geometric==1.4.3) (1.5.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (0.39.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (4.13.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (57.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (3.10.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2022.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.4.3) (1.15.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (3.0.9)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (0.6.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (3.0.4)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (3.2.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2.9.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (7.1.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (1.3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2021.11.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (0.11.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
        elif split == 'val':
            self.path = self.processed_paths[1]
        elif split == 'test':
            self.path = self.processed_paths[2]

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
            self.num_graphs = self.data['num_graphs']
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            with h5py.File(self.path, 'r') as f:
                self.num_graphs = f.attrs['num_graphs']
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GINConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_input_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU())))
          else:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU()))) 

        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                add_xr_at = n
            if n == add_xr_at:
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/P2P'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=True, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 2
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.2
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-d22d3afc-ad51-4672-918d-0c2793297cb5.json
# ------------------------------
# ------------------------------
# Sun Nov  6 06:11:48 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GINConv(nn=Sequential(
#       (0): Linear(in_features=1, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): ReLU()
#     ))
#     (1): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): ReLU()
#     ))
#     (2): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): ReLU()
#     ))
#     (3): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): ReLU()
#     ))
#     (4): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): ReLU()
#     ))
#     (5): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): ReLU()
#     ))
#     (6): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): ReLU()
#     ))
#     (7): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): ReLU()
#     ))
#     (8): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): ReLU()
#     ))
#     (9): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): ReLU()
#     ))
#     (10): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): ReLU()
#     ))
#     (11): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): ReLU()
#     ))
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 2
# epoch: 1, passed number of graphs: 96, train running loss: 0.06928 (passed time: 20s)
#           acc: 0.97829, fpr: 0.00001, fnr: 1.00000, rec: 0.00000, prc: 0.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 192, train running loss: 0.04343 (passed time: 40s)
#           acc: 0.99866, fpr: 0.00112, fnr: 0.01143, rec: 0.98857, prc: 0.95068, f1: 0.96926, f1_macro: 0.98429
# epoch: 1, passed number of graphs: 288, train running loss: 0.03138 (passed time: 1m 0s)
#           acc: 0.99932, fpr: 0.00009, fnr: 0.02778, rec: 0.97222, prc: 0.99565, f1: 0.98380, f1_macro: 0.99172
# epoch: 1, passed number of graphs: 384, train running loss: 0.02545 (passed time: 1m 20s)
#           acc: 0.99937, fpr: 0.00004, fnr: 0.02658, rec: 0.97342, prc: 0.99802, f1: 0.98556, f1_macro: 0.99262
# epoch: 1, passed number of graphs: 480, train running loss: 0.02065 (passed time: 1m 40s)
#           acc: 0.99848, fpr: 0.00148, fnr: 0.00343, rec: 0.99657, prc: 0.93717, f1: 0.96596, f1_macro: 0.98259
# epoch: 1, passed number of graphs: 576, train running loss: 0.01832 (passed time: 2m 0s)
#           acc: 0.99976, fpr: 0.00019, fnr: 0.00210, rec: 0.99790, prc: 0.99118, f1: 0.99453, f1_macro: 0.99721
# epoch: 1, passed number of graphs: 672, train running loss: 0.01585 (passed time: 2m 20s)
#           acc: 0.99960, fpr: 0.00037, fnr: 0.00176, rec: 0.99824, prc: 0.98331, f1: 0.99072, f1_macro: 0.99526
# epoch: 1, passed number of graphs: 768, train running loss: 0.01400 (passed time: 2m 40s)
#           acc: 0.99993, fpr: 0.00004, fnr: 0.00147, rec: 0.99853, prc: 0.99837, f1: 0.99845, f1_macro: 0.99921
# Validation --- epoch: 1, loss: 0.46687
#           fnr: 0.00667, prc: 0.31499, acc: 0.95288, rec: 0.99333, f1: 0.47749, f1_macro: 0.72640, fpr: 0.04801
# Better model saved at ./saved_models/GIN_0: 0.47748830624775046.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.00179 (passed time: 3m 22s)
#           acc: 0.99686, fpr: 0.00002, fnr: 0.14388, rec: 0.85612, prc: 0.99907, f1: 0.92209, f1_macro: 0.96024
# epoch: 2, passed number of graphs: 192, train running loss: 0.00176 (passed time: 3m 43s)
#           acc: 0.99973, fpr: 0.00015, fnr: 0.00572, rec: 0.99428, prc: 0.99315, f1: 0.99372, f1_macro: 0.99679
# epoch: 2, passed number of graphs: 288, train running loss: 0.00143 (passed time: 4m 3s)
#           acc: 0.99977, fpr: 0.00008, fnr: 0.00670, rec: 0.99330, prc: 0.99607, f1: 0.99468, f1_macro: 0.99728
# epoch: 2, passed number of graphs: 384, train running loss: 0.00127 (passed time: 4m 23s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00354, rec: 0.99646, prc: 0.99935, f1: 0.99790, f1_macro: 0.99893
# epoch: 2, passed number of graphs: 480, train running loss: 0.00140 (passed time: 4m 43s)
#           acc: 0.99213, fpr: 0.00778, fnr: 0.01176, rec: 0.98824, prc: 0.73736, f1: 0.84456, f1_macro: 0.92026
# epoch: 2, passed number of graphs: 576, train running loss: 0.00233 (passed time: 5m 3s)
#           acc: 0.99654, fpr: 0.00003, fnr: 0.16029, rec: 0.83971, prc: 0.99827, f1: 0.91215, f1_macro: 0.95519
# epoch: 2, passed number of graphs: 672, train running loss: 0.00278 (passed time: 5m 23s)
#           acc: 0.99704, fpr: 0.00000, fnr: 0.13678, rec: 0.86322, prc: 1.00000, f1: 0.92659, f1_macro: 0.96254
# epoch: 2, passed number of graphs: 768, train running loss: 0.00262 (passed time: 5m 43s)
#           acc: 0.99987, fpr: 0.00001, fnr: 0.00571, rec: 0.99429, prc: 0.99951, f1: 0.99689, f1_macro: 0.99841
# Validation --- epoch: 2, loss: 0.00346
#           fnr: 0.01975, prc: 0.99115, acc: 0.99938, rec: 0.98025, f1: 0.98410, f1_macro: 0.99189, fpr: 0.00020
# Better model saved at ./saved_models/GIN_1: 0.9840957774766091.pt.
# epoch: 3, passed number of graphs: 96, train running loss: 0.00144 (passed time: 6m 25s)
#           acc: 0.99996, fpr: 0.00003, fnr: 0.00048, rec: 0.99952, prc: 0.99872, f1: 0.99912, f1_macro: 0.99955
# epoch: 3, passed number of graphs: 192, train running loss: 0.01052 (passed time: 6m 45s)
#           acc: 0.99879, fpr: 0.00000, fnr: 0.05651, rec: 0.94349, prc: 1.00000, f1: 0.97092, f1_macro: 0.98515
# epoch: 3, passed number of graphs: 288, train running loss: 0.00907 (passed time: 7m 5s)
#           acc: 0.99958, fpr: 0.00002, fnr: 0.01863, rec: 0.98137, prc: 0.99900, f1: 0.99011, f1_macro: 0.99495
# epoch: 3, passed number of graphs: 384, train running loss: 0.00714 (passed time: 7m 25s)
#           acc: 0.99990, fpr: 0.00003, fnr: 0.00306, rec: 0.99694, prc: 0.99855, f1: 0.99774, f1_macro: 0.99885
# epoch: 3, passed number of graphs: 480, train running loss: 0.00590 (passed time: 7m 45s)
#           acc: 0.99986, fpr: 0.00006, fnr: 0.00376, rec: 0.99624, prc: 0.99738, f1: 0.99681, f1_macro: 0.99837
# epoch: 3, passed number of graphs: 576, train running loss: 0.00506 (passed time: 8m 5s)
#           acc: 0.99987, fpr: 0.00009, fnr: 0.00210, rec: 0.99790, prc: 0.99581, f1: 0.99686, f1_macro: 0.99839
# epoch: 3, passed number of graphs: 672, train running loss: 0.00454 (passed time: 8m 25s)
#           acc: 0.99920, fpr: 0.00034, fnr: 0.02141, rec: 0.97859, prc: 0.98441, f1: 0.98149, f1_macro: 0.99054
# epoch: 3, passed number of graphs: 768, train running loss: 0.00413 (passed time: 8m 45s)
#           acc: 0.99997, fpr: 0.00002, fnr: 0.00065, rec: 0.99935, prc: 0.99918, f1: 0.99927, f1_macro: 0.99963
# Validation --- epoch: 3, loss: 0.00227
#           fnr: 0.00702, prc: 0.99277, acc: 0.99969, rec: 0.99298, f1: 0.99210, f1_macro: 0.99597, fpr: 0.00016
# Better model saved at ./saved_models/GIN_2: 0.9921003329611596.pt.
# epoch: 4, passed number of graphs: 96, train running loss: 0.00068 (passed time: 9m 28s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00271, rec: 0.99729, prc: 0.99984, f1: 0.99856, f1_macro: 0.99927
# epoch: 4, passed number of graphs: 192, train running loss: 0.00327 (passed time: 9m 48s)
#           acc: 0.99591, fpr: 0.00000, fnr: 0.19125, rec: 0.80875, prc: 1.00000, f1: 0.89427, f1_macro: 0.94609
# epoch: 4, passed number of graphs: 288, train running loss: 0.00289 (passed time: 10m 8s)
#           acc: 0.99972, fpr: 0.00000, fnr: 0.01307, rec: 0.98693, prc: 0.99983, f1: 0.99334, f1_macro: 0.99660
# epoch: 4, passed number of graphs: 384, train running loss: 0.00346 (passed time: 10m 28s)
#           acc: 0.99975, fpr: 0.00001, fnr: 0.01096, rec: 0.98904, prc: 0.99967, f1: 0.99433, f1_macro: 0.99710
# epoch: 4, passed number of graphs: 480, train running loss: 0.00294 (passed time: 10m 48s)
#           acc: 0.99986, fpr: 0.00003, fnr: 0.00490, rec: 0.99510, prc: 0.99852, f1: 0.99681, f1_macro: 0.99837
# epoch: 4, passed number of graphs: 576, train running loss: 0.00275 (passed time: 11m 8s)
#           acc: 0.99656, fpr: 0.00003, fnr: 0.15932, rec: 0.84068, prc: 0.99827, f1: 0.91272, f1_macro: 0.95548
# epoch: 4, passed number of graphs: 672, train running loss: 0.00258 (passed time: 11m 28s)
#           acc: 0.99958, fpr: 0.00031, fnr: 0.00527, rec: 0.99473, prc: 0.98606, f1: 0.99037, f1_macro: 0.99508
# epoch: 4, passed number of graphs: 768, train running loss: 0.00238 (passed time: 11m 48s)
#           acc: 0.99965, fpr: 0.00027, fnr: 0.00392, rec: 0.99608, prc: 0.98755, f1: 0.99180, f1_macro: 0.99581
# Validation --- epoch: 4, loss: 0.01025
#           fnr: 0.00686, prc: 0.88790, acc: 0.99690, rec: 0.99314, f1: 0.93450, f1_macro: 0.96646, fpr: 0.00301
# epoch: 5, passed number of graphs: 96, train running loss: 0.00075 (passed time: 12m 30s)
#           acc: 0.99992, fpr: 0.00004, fnr: 0.00223, rec: 0.99777, prc: 0.99840, f1: 0.99809, f1_macro: 0.99902
# epoch: 5, passed number of graphs: 192, train running loss: 0.00068 (passed time: 12m 51s)
#           acc: 0.99987, fpr: 0.00000, fnr: 0.00604, rec: 0.99396, prc: 0.99984, f1: 0.99689, f1_macro: 0.99841
# epoch: 5, passed number of graphs: 288, train running loss: 0.00065 (passed time: 13m 11s)
#           acc: 0.99985, fpr: 0.00003, fnr: 0.00572, rec: 0.99428, prc: 0.99852, f1: 0.99640, f1_macro: 0.99816
# epoch: 5, passed number of graphs: 384, train running loss: 0.00068 (passed time: 13m 30s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00371, rec: 0.99629, prc: 0.99935, f1: 0.99782, f1_macro: 0.99889
# epoch: 5, passed number of graphs: 480, train running loss: 0.00065 (passed time: 13m 50s)
#           acc: 0.99982, fpr: 0.00001, fnr: 0.00817, rec: 0.99183, prc: 0.99967, f1: 0.99574, f1_macro: 0.99782
# epoch: 5, passed number of graphs: 576, train running loss: 0.00063 (passed time: 14m 10s)
#           acc: 0.99982, fpr: 0.00015, fnr: 0.00161, rec: 0.99839, prc: 0.99310, f1: 0.99573, f1_macro: 0.99782
# epoch: 5, passed number of graphs: 672, train running loss: 0.00257 (passed time: 14m 30s)
#           acc: 0.97835, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 5, passed number of graphs: 768, train running loss: 0.00779 (passed time: 14m 50s)
#           acc: 0.97885, fpr: 0.00018, fnr: 0.98744, rec: 0.01256, prc: 0.60156, f1: 0.02461, f1_macro: 0.50696
# Validation --- epoch: 5, loss: 0.09239
#           fnr: 0.56112, prc: 0.24098, acc: 0.95423, rec: 0.43888, f1: 0.30226, f1_macro: 0.63929, fpr: 0.03444
# epoch: 6, passed number of graphs: 96, train running loss: 0.03104 (passed time: 15m 33s)
#           acc: 0.97703, fpr: 0.00626, fnr: 0.77620, rec: 0.22380, prc: 0.44203, f1: 0.29715, f1_macro: 0.64274
# epoch: 6, passed number of graphs: 192, train running loss: 0.03035 (passed time: 15m 53s)
#           acc: 0.97643, fpr: 0.00761, fnr: 0.75437, rec: 0.24563, prc: 0.41341, f1: 0.30817, f1_macro: 0.64809
# epoch: 6, passed number of graphs: 288, train running loss: 0.02968 (passed time: 16m 13s)
#           acc: 0.98629, fpr: 0.00347, fnr: 0.48660, rec: 0.51340, prc: 0.76207, f1: 0.61349, f1_macro: 0.80326
# epoch: 6, passed number of graphs: 384, train running loss: 0.02900 (passed time: 16m 33s)
#           acc: 0.97805, fpr: 0.00349, fnr: 0.84179, rec: 0.15821, prc: 0.50514, f1: 0.24095, f1_macro: 0.61491
# epoch: 6, passed number of graphs: 480, train running loss: 0.02848 (passed time: 16m 53s)
#           acc: 0.98334, fpr: 0.00502, fnr: 0.54312, rec: 0.45688, prc: 0.66786, f1: 0.54258, f1_macro: 0.76705
# epoch: 6, passed number of graphs: 576, train running loss: 0.02809 (passed time: 17m 13s)
#           acc: 0.98370, fpr: 0.00328, fnr: 0.61098, rec: 0.38902, prc: 0.72156, f1: 0.50551, f1_macro: 0.74861
# epoch: 6, passed number of graphs: 672, train running loss: 0.02757 (passed time: 17m 33s)
#           acc: 0.98975, fpr: 0.00013, fnr: 0.46724, rec: 0.53276, prc: 0.98873, f1: 0.69242, f1_macro: 0.84360
# epoch: 6, passed number of graphs: 768, train running loss: 0.02700 (passed time: 17m 53s)
#           acc: 0.99176, fpr: 0.00014, fnr: 0.38157, rec: 0.61843, prc: 0.98982, f1: 0.76124, f1_macro: 0.87853
# Validation --- epoch: 6, loss: 0.06234
#           fnr: 0.93342, prc: 0.92535, acc: 0.97990, rec: 0.06658, f1: 0.11482, f1_macro: nan, fpr: 0.00001
# epoch: 7, passed number of graphs: 96, train running loss: 0.01843 (passed time: 18m 36s)
#           acc: 0.99091, fpr: 0.00281, fnr: 0.29223, rec: 0.70777, prc: 0.84821, f1: 0.77165, f1_macro: 0.88351
# epoch: 7, passed number of graphs: 192, train running loss: 0.01666 (passed time: 18m 56s)
#           acc: 0.99632, fpr: 0.00001, fnr: 0.17148, rec: 0.82852, prc: 0.99921, f1: 0.90589, f1_macro: 0.95201
# epoch: 7, passed number of graphs: 288, train running loss: 0.01537 (passed time: 19m 15s)
#           acc: 0.99262, fpr: 0.00005, fnr: 0.34575, rec: 0.65425, prc: 0.99652, f1: 0.78990, f1_macro: 0.89307
# epoch: 7, passed number of graphs: 384, train running loss: 0.01445 (passed time: 19m 35s)
#           acc: 0.99461, fpr: 0.00003, fnr: 0.24327, rec: 0.75673, prc: 0.99809, f1: 0.86081, f1_macro: 0.92903
# epoch: 7, passed number of graphs: 480, train running loss: 0.01302 (passed time: 19m 55s)
#           acc: 0.99568, fpr: 0.00005, fnr: 0.19732, rec: 0.80268, prc: 0.99716, f1: 0.88941, f1_macro: 0.94360
# epoch: 7, passed number of graphs: 576, train running loss: 0.01167 (passed time: 20m 15s)
#           acc: 0.99936, fpr: 0.00024, fnr: 0.01889, rec: 0.98111, prc: 0.98894, f1: 0.98501, f1_macro: 0.99234
# epoch: 7, passed number of graphs: 672, train running loss: 0.01037 (passed time: 20m 35s)
#           acc: 0.99698, fpr: 0.00004, fnr: 0.13758, rec: 0.86242, prc: 0.99778, f1: 0.92517, f1_macro: 0.96182
# epoch: 7, passed number of graphs: 768, train running loss: 0.00930 (passed time: 20m 55s)
#           acc: 0.99963, fpr: 0.00007, fnr: 0.01419, rec: 0.98581, prc: 0.99670, f1: 0.99122, f1_macro: 0.99552
# Validation --- epoch: 7, loss: 0.00353
#           fnr: 0.02366, prc: 0.99523, acc: 0.99939, rec: 0.97634, f1: 0.98441, f1_macro: 0.99205, fpr: 0.00011
# epoch: 8, passed number of graphs: 96, train running loss: 0.00185 (passed time: 21m 38s)
#           acc: 0.99976, fpr: 0.00002, fnr: 0.00973, rec: 0.99027, prc: 0.99887, f1: 0.99455, f1_macro: 0.99722
# epoch: 8, passed number of graphs: 192, train running loss: 0.00198 (passed time: 21m 58s)
#           acc: 0.99972, fpr: 0.00004, fnr: 0.01160, rec: 0.98840, prc: 0.99835, f1: 0.99335, f1_macro: 0.99660
# epoch: 8, passed number of graphs: 288, train running loss: 0.00185 (passed time: 22m 18s)
#           acc: 0.99975, fpr: 0.00004, fnr: 0.01029, rec: 0.98971, prc: 0.99835, f1: 0.99401, f1_macro: 0.99694
# epoch: 8, passed number of graphs: 384, train running loss: 0.00164 (passed time: 22m 38s)
#           acc: 0.99976, fpr: 0.00001, fnr: 0.01047, rec: 0.98953, prc: 0.99951, f1: 0.99449, f1_macro: 0.99719
# epoch: 8, passed number of graphs: 480, train running loss: 0.00153 (passed time: 22m 58s)
#           acc: 0.99979, fpr: 0.00000, fnr: 0.00964, rec: 0.99036, prc: 1.00000, f1: 0.99516, f1_macro: 0.99753
# epoch: 8, passed number of graphs: 576, train running loss: 0.00145 (passed time: 23m 18s)
#           acc: 0.99985, fpr: 0.00000, fnr: 0.00710, rec: 0.99290, prc: 1.00000, f1: 0.99644, f1_macro: 0.99818
# epoch: 8, passed number of graphs: 672, train running loss: 0.00152 (passed time: 23m 38s)
#           acc: 0.99708, fpr: 0.00001, fnr: 0.13407, rec: 0.86593, prc: 0.99926, f1: 0.92783, f1_macro: 0.96317
# epoch: 8, passed number of graphs: 768, train running loss: 0.00149 (passed time: 23m 58s)
#           acc: 0.99972, fpr: 0.00005, fnr: 0.01093, rec: 0.98907, prc: 0.99786, f1: 0.99345, f1_macro: 0.99665
# Validation --- epoch: 8, loss: 0.00269
#           fnr: 0.01891, prc: 0.99836, acc: 0.99956, rec: 0.98109, f1: 0.98863, f1_macro: 0.99420, fpr: 0.00004
# epoch: 9, passed number of graphs: 96, train running loss: 0.00124 (passed time: 24m 40s)
#           acc: 0.99984, fpr: 0.00000, fnr: 0.00750, rec: 0.99250, prc: 1.00000, f1: 0.99624, f1_macro: 0.99808
# epoch: 9, passed number of graphs: 192, train running loss: 0.00133 (passed time: 25m 0s)
#           acc: 0.99974, fpr: 0.00000, fnr: 0.01209, rec: 0.98791, prc: 1.00000, f1: 0.99392, f1_macro: 0.99689
# epoch: 9, passed number of graphs: 288, train running loss: 0.00113 (passed time: 25m 20s)
#           acc: 0.99982, fpr: 0.00001, fnr: 0.00817, rec: 0.99183, prc: 0.99967, f1: 0.99573, f1_macro: 0.99782
# epoch: 9, passed number of graphs: 384, train running loss: 0.00105 (passed time: 25m 40s)
#           acc: 0.99980, fpr: 0.00000, fnr: 0.00902, rec: 0.99098, prc: 0.99984, f1: 0.99539, f1_macro: 0.99764
# epoch: 9, passed number of graphs: 480, train running loss: 0.00095 (passed time: 26m 0s)
#           acc: 0.99986, fpr: 0.00000, fnr: 0.00670, rec: 0.99330, prc: 1.00000, f1: 0.99664, f1_macro: 0.99828
# epoch: 9, passed number of graphs: 576, train running loss: 0.00089 (passed time: 26m 20s)
#           acc: 0.99988, fpr: 0.00002, fnr: 0.00452, rec: 0.99548, prc: 0.99903, f1: 0.99725, f1_macro: 0.99860
# epoch: 9, passed number of graphs: 672, train running loss: 0.00088 (passed time: 26m 40s)
#           acc: 0.99954, fpr: 0.00036, fnr: 0.00511, rec: 0.99489, prc: 0.98404, f1: 0.98943, f1_macro: 0.99460
# epoch: 9, passed number of graphs: 768, train running loss: 0.00089 (passed time: 27m 0s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00179, rec: 0.99821, prc: 0.99918, f1: 0.99869, f1_macro: 0.99933
# Validation --- epoch: 9, loss: 0.00257
#           fnr: 0.00721, prc: 0.98605, acc: 0.99954, rec: 0.99279, f1: 0.98859, f1_macro: 0.99418, fpr: 0.00032
# epoch: 10, passed number of graphs: 96, train running loss: 0.00047 (passed time: 27m 42s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00128, rec: 0.99872, prc: 0.99952, f1: 0.99912, f1_macro: 0.99955
# epoch: 10, passed number of graphs: 192, train running loss: 0.00061 (passed time: 28m 2s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00180, rec: 0.99820, prc: 0.99951, f1: 0.99886, f1_macro: 0.99942
# epoch: 10, passed number of graphs: 288, train running loss: 0.00056 (passed time: 28m 22s)
#           acc: 0.99982, fpr: 0.00013, fnr: 0.00245, rec: 0.99755, prc: 0.99398, f1: 0.99576, f1_macro: 0.99783
# epoch: 10, passed number of graphs: 384, train running loss: 0.00057 (passed time: 28m 42s)
#           acc: 0.99991, fpr: 0.00002, fnr: 0.00338, rec: 0.99662, prc: 0.99919, f1: 0.99790, f1_macro: 0.99893
# epoch: 10, passed number of graphs: 480, train running loss: 0.00054 (passed time: 29m 2s)
#           acc: 0.99984, fpr: 0.00012, fnr: 0.00196, rec: 0.99804, prc: 0.99463, f1: 0.99633, f1_macro: 0.99812
# epoch: 10, passed number of graphs: 576, train running loss: 0.00052 (passed time: 29m 22s)
#           acc: 0.99980, fpr: 0.00018, fnr: 0.00113, rec: 0.99887, prc: 0.99198, f1: 0.99542, f1_macro: 0.99766
# epoch: 10, passed number of graphs: 672, train running loss: 0.00055 (passed time: 29m 42s)
#           acc: 0.99956, fpr: 0.00042, fnr: 0.00144, rec: 0.99856, prc: 0.98147, f1: 0.98994, f1_macro: 0.99486
# epoch: 10, passed number of graphs: 768, train running loss: 0.00059 (passed time: 30m 2s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00245, rec: 0.99755, prc: 0.99935, f1: 0.99845, f1_macro: 0.99921
# Validation --- epoch: 10, loss: 0.00176
#           fnr: 0.00767, prc: 0.99655, acc: 0.99976, rec: 0.99233, f1: 0.99368, f1_macro: 0.99678, fpr: 0.00008
# Better model saved at ./saved_models/GIN_9: 0.993677101221096.pt.
# epoch: 11, passed number of graphs: 96, train running loss: 0.00041 (passed time: 30m 45s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00175, rec: 0.99825, prc: 0.99936, f1: 0.99880, f1_macro: 0.99939
# epoch: 11, passed number of graphs: 192, train running loss: 0.00061 (passed time: 31m 5s)
#           acc: 0.99988, fpr: 0.00000, fnr: 0.00523, rec: 0.99477, prc: 0.99984, f1: 0.99730, f1_macro: 0.99862
# epoch: 11, passed number of graphs: 288, train running loss: 0.00055 (passed time: 31m 25s)
#           acc: 0.99982, fpr: 0.00014, fnr: 0.00229, rec: 0.99771, prc: 0.99365, f1: 0.99568, f1_macro: 0.99779
# epoch: 11, passed number of graphs: 384, train running loss: 0.00056 (passed time: 31m 44s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00209, rec: 0.99791, prc: 0.99887, f1: 0.99839, f1_macro: 0.99918
# epoch: 11, passed number of graphs: 480, train running loss: 0.00053 (passed time: 32m 4s)
#           acc: 0.99985, fpr: 0.00010, fnr: 0.00229, rec: 0.99771, prc: 0.99527, f1: 0.99649, f1_macro: 0.99821
# epoch: 11, passed number of graphs: 576, train running loss: 0.00050 (passed time: 32m 24s)
#           acc: 0.99977, fpr: 0.00022, fnr: 0.00097, rec: 0.99903, prc: 0.99024, f1: 0.99462, f1_macro: 0.99725
# epoch: 11, passed number of graphs: 672, train running loss: 0.00053 (passed time: 32m 44s)
#           acc: 0.99960, fpr: 0.00030, fnr: 0.00479, rec: 0.99521, prc: 0.98654, f1: 0.99085, f1_macro: 0.99532
# epoch: 11, passed number of graphs: 768, train running loss: 0.00058 (passed time: 33m 4s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00245, rec: 0.99755, prc: 0.99951, f1: 0.99853, f1_macro: 0.99925
# Validation --- epoch: 11, loss: 0.00170
#           fnr: 0.00829, prc: 0.99750, acc: 0.99977, rec: 0.99171, f1: 0.99384, f1_macro: 0.99686, fpr: 0.00006
# Better model saved at ./saved_models/GIN_10: 0.9938442938770403.pt.
# epoch: 12, passed number of graphs: 96, train running loss: 0.00038 (passed time: 33m 47s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00112, rec: 0.99888, prc: 0.99936, f1: 0.99912, f1_macro: 0.99955
# epoch: 12, passed number of graphs: 192, train running loss: 0.00054 (passed time: 34m 7s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00278, rec: 0.99722, prc: 0.99967, f1: 0.99845, f1_macro: 0.99921
# epoch: 12, passed number of graphs: 288, train running loss: 0.00049 (passed time: 34m 27s)
#           acc: 0.99983, fpr: 0.00012, fnr: 0.00212, rec: 0.99788, prc: 0.99430, f1: 0.99609, f1_macro: 0.99800
# epoch: 12, passed number of graphs: 384, train running loss: 0.00051 (passed time: 34m 47s)
#           acc: 0.99989, fpr: 0.00004, fnr: 0.00322, rec: 0.99678, prc: 0.99839, f1: 0.99758, f1_macro: 0.99876
# epoch: 12, passed number of graphs: 480, train running loss: 0.00048 (passed time: 35m 7s)
#           acc: 0.99983, fpr: 0.00008, fnr: 0.00425, rec: 0.99575, prc: 0.99640, f1: 0.99608, f1_macro: 0.99800
# epoch: 12, passed number of graphs: 576, train running loss: 0.00047 (passed time: 35m 27s)
#           acc: 0.99989, fpr: 0.00008, fnr: 0.00145, rec: 0.99855, prc: 0.99614, f1: 0.99734, f1_macro: 0.99864
# epoch: 12, passed number of graphs: 672, train running loss: 0.00050 (passed time: 35m 47s)
#           acc: 0.99958, fpr: 0.00031, fnr: 0.00511, rec: 0.99489, prc: 0.98591, f1: 0.99038, f1_macro: 0.99508
# epoch: 12, passed number of graphs: 768, train running loss: 0.00055 (passed time: 36m 7s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00261, rec: 0.99739, prc: 0.99967, f1: 0.99853, f1_macro: 0.99925
# Validation --- epoch: 12, loss: 0.00170
#           fnr: 0.00790, prc: 0.99717, acc: 0.99977, rec: 0.99210, f1: 0.99388, f1_macro: 0.99688, fpr: 0.00006
# Better model saved at ./saved_models/GIN_11: 0.9938754997795639.pt.
# epoch: 13, passed number of graphs: 96, train running loss: 0.00038 (passed time: 36m 49s)
#           acc: 0.99997, fpr: 0.00001, fnr: 0.00112, rec: 0.99888, prc: 0.99952, f1: 0.99920, f1_macro: 0.99959
# epoch: 13, passed number of graphs: 192, train running loss: 0.00054 (passed time: 37m 9s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00278, rec: 0.99722, prc: 0.99951, f1: 0.99836, f1_macro: 0.99916
# epoch: 13, passed number of graphs: 288, train running loss: 0.00049 (passed time: 37m 29s)
#           acc: 0.99985, fpr: 0.00013, fnr: 0.00098, rec: 0.99902, prc: 0.99415, f1: 0.99658, f1_macro: 0.99825
# epoch: 13, passed number of graphs: 384, train running loss: 0.00050 (passed time: 37m 49s)
#           acc: 0.99989, fpr: 0.00002, fnr: 0.00387, rec: 0.99613, prc: 0.99903, f1: 0.99758, f1_macro: 0.99876
# epoch: 13, passed number of graphs: 480, train running loss: 0.00048 (passed time: 38m 9s)
#           acc: 0.99985, fpr: 0.00010, fnr: 0.00245, rec: 0.99755, prc: 0.99560, f1: 0.99657, f1_macro: 0.99825
# epoch: 13, passed number of graphs: 576, train running loss: 0.00045 (passed time: 38m 29s)
#           acc: 0.99975, fpr: 0.00022, fnr: 0.00129, rec: 0.99871, prc: 0.98992, f1: 0.99429, f1_macro: 0.99708
# epoch: 13, passed number of graphs: 672, train running loss: 0.00048 (passed time: 38m 49s)
#           acc: 0.99958, fpr: 0.00034, fnr: 0.00368, rec: 0.99632, prc: 0.98468, f1: 0.99047, f1_macro: 0.99513
# epoch: 13, passed number of graphs: 768, train running loss: 0.00053 (passed time: 39m 9s)
#           acc: 0.99997, fpr: 0.00002, fnr: 0.00065, rec: 0.99935, prc: 0.99902, f1: 0.99918, f1_macro: 0.99958
# Validation --- epoch: 13, loss: 0.01237
#           fnr: 0.00733, prc: 0.85893, acc: 0.99485, rec: 0.99267, f1: 0.90875, f1_macro: 0.95305, fpr: 0.00510
# epoch: 14, passed number of graphs: 96, train running loss: 0.00037 (passed time: 39m 51s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00112, rec: 0.99888, prc: 0.99936, f1: 0.99912, f1_macro: 0.99955
# epoch: 14, passed number of graphs: 192, train running loss: 0.00053 (passed time: 40m 11s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00229, rec: 0.99771, prc: 0.99951, f1: 0.99861, f1_macro: 0.99929
# epoch: 14, passed number of graphs: 288, train running loss: 0.00049 (passed time: 40m 31s)
#           acc: 0.99982, fpr: 0.00017, fnr: 0.00098, rec: 0.99902, prc: 0.99237, f1: 0.99568, f1_macro: 0.99780
# epoch: 14, passed number of graphs: 384, train running loss: 0.00638 (passed time: 40m 51s)
#           acc: 0.97772, fpr: 0.00027, fnr: 1.00000, rec: 0.00000, prc: 0.00000, f1: 0.00000, f1_macro: nan
# epoch: 14, passed number of graphs: 480, train running loss: 0.01550 (passed time: 41m 11s)
#           acc: 0.98188, fpr: 0.01120, fnr: 0.33110, rec: 0.66890, prc: 0.56899, f1: 0.61491, f1_macro: 0.80282
# epoch: 14, passed number of graphs: 576, train running loss: 0.01457 (passed time: 41m 31s)
#           acc: 0.99510, fpr: 0.00010, fnr: 0.22454, rec: 0.77546, prc: 0.99421, f1: 0.87132, f1_macro: 0.93441
# epoch: 14, passed number of graphs: 672, train running loss: 0.01294 (passed time: 41m 51s)
#           acc: 0.99708, fpr: 0.00000, fnr: 0.13471, rec: 0.86529, prc: 1.00000, f1: 0.92778, f1_macro: 0.96315
# epoch: 14, passed number of graphs: 768, train running loss: 0.01155 (passed time: 42m 11s)
#           acc: 0.99977, fpr: 0.00000, fnr: 0.01044, rec: 0.98956, prc: 0.99984, f1: 0.99467, f1_macro: 0.99728
# Validation --- epoch: 14, loss: 0.00369
#           fnr: 0.02505, prc: 0.99917, acc: 0.99945, rec: 0.97495, f1: 0.98548, f1_macro: 0.99260, fpr: 0.00002
# epoch: 15, passed number of graphs: 96, train running loss: 0.00195 (passed time: 42m 54s)
#           acc: 0.99985, fpr: 0.00000, fnr: 0.00670, rec: 0.99330, prc: 0.99984, f1: 0.99656, f1_macro: 0.99824
# epoch: 15, passed number of graphs: 192, train running loss: 0.00214 (passed time: 43m 14s)
#           acc: 0.99979, fpr: 0.00000, fnr: 0.00996, rec: 0.99004, prc: 1.00000, f1: 0.99499, f1_macro: 0.99744
# epoch: 15, passed number of graphs: 288, train running loss: 0.00197 (passed time: 43m 33s)
#           acc: 0.99985, fpr: 0.00000, fnr: 0.00703, rec: 0.99297, prc: 1.00000, f1: 0.99647, f1_macro: 0.99820
# epoch: 15, passed number of graphs: 384, train running loss: 0.00181 (passed time: 43m 53s)
#           acc: 0.99983, fpr: 0.00001, fnr: 0.00693, rec: 0.99307, prc: 0.99935, f1: 0.99620, f1_macro: 0.99806
# epoch: 15, passed number of graphs: 480, train running loss: 0.00169 (passed time: 44m 13s)
#           acc: 0.99984, fpr: 0.00000, fnr: 0.00719, rec: 0.99281, prc: 1.00000, f1: 0.99639, f1_macro: 0.99816
# epoch: 15, passed number of graphs: 576, train running loss: 0.00159 (passed time: 44m 33s)
#           acc: 0.99967, fpr: 0.00001, fnr: 0.01517, rec: 0.98483, prc: 0.99967, f1: 0.99219, f1_macro: 0.99601
# epoch: 15, passed number of graphs: 672, train running loss: 0.00166 (passed time: 44m 53s)
#           acc: 0.99741, fpr: 0.00004, fnr: 0.11761, rec: 0.88239, prc: 0.99783, f1: 0.93657, f1_macro: 0.96762
# epoch: 15, passed number of graphs: 768, train running loss: 0.00162 (passed time: 45m 13s)
#           acc: 0.99982, fpr: 0.00001, fnr: 0.00799, rec: 0.99201, prc: 0.99951, f1: 0.99574, f1_macro: 0.99783
# Validation --- epoch: 15, loss: 0.00272
#           fnr: 0.01894, prc: 0.99823, acc: 0.99956, rec: 0.98106, f1: 0.98837, f1_macro: 0.99407, fpr: 0.00004
# epoch: 16, passed number of graphs: 96, train running loss: 0.00154 (passed time: 45m 56s)
#           acc: 0.99987, fpr: 0.00002, fnr: 0.00494, rec: 0.99506, prc: 0.99904, f1: 0.99704, f1_macro: 0.99849
# epoch: 16, passed number of graphs: 192, train running loss: 0.00158 (passed time: 46m 16s)
#           acc: 0.99985, fpr: 0.00000, fnr: 0.00702, rec: 0.99298, prc: 1.00000, f1: 0.99648, f1_macro: 0.99820
# epoch: 16, passed number of graphs: 288, train running loss: 0.00149 (passed time: 46m 35s)
#           acc: 0.99984, fpr: 0.00005, fnr: 0.00539, rec: 0.99461, prc: 0.99787, f1: 0.99624, f1_macro: 0.99808
# epoch: 16, passed number of graphs: 384, train running loss: 0.00140 (passed time: 46m 55s)
#           acc: 0.99986, fpr: 0.00000, fnr: 0.00628, rec: 0.99372, prc: 1.00000, f1: 0.99685, f1_macro: 0.99839
# epoch: 16, passed number of graphs: 480, train running loss: 0.00132 (passed time: 47m 15s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00441, rec: 0.99559, prc: 0.99967, f1: 0.99763, f1_macro: 0.99879
# epoch: 16, passed number of graphs: 576, train running loss: 0.00125 (passed time: 47m 35s)
#           acc: 0.99990, fpr: 0.00004, fnr: 0.00274, rec: 0.99726, prc: 0.99822, f1: 0.99774, f1_macro: 0.99884
# epoch: 16, passed number of graphs: 672, train running loss: 0.00131 (passed time: 47m 55s)
#           acc: 0.99944, fpr: 0.00045, fnr: 0.00527, rec: 0.99473, prc: 0.97985, f1: 0.98723, f1_macro: 0.99347
# epoch: 16, passed number of graphs: 768, train running loss: 0.00131 (passed time: 48m 15s)
#           acc: 0.99985, fpr: 0.00001, fnr: 0.00636, rec: 0.99364, prc: 0.99951, f1: 0.99656, f1_macro: 0.99824
# Validation --- epoch: 16, loss: 0.00222
#           fnr: 0.01089, prc: 0.99779, acc: 0.99972, rec: 0.98911, f1: 0.99266, f1_macro: 0.99626, fpr: 0.00005
# epoch: 17, passed number of graphs: 96, train running loss: 0.00090 (passed time: 48m 58s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00271, rec: 0.99729, prc: 0.99936, f1: 0.99832, f1_macro: 0.99914
# epoch: 17, passed number of graphs: 192, train running loss: 0.00107 (passed time: 49m 18s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00392, rec: 0.99608, prc: 0.99951, f1: 0.99779, f1_macro: 0.99887
# epoch: 17, passed number of graphs: 288, train running loss: 0.00104 (passed time: 49m 38s)
#           acc: 0.99981, fpr: 0.00012, fnr: 0.00376, rec: 0.99624, prc: 0.99462, f1: 0.99543, f1_macro: 0.99766
# epoch: 17, passed number of graphs: 384, train running loss: 0.00103 (passed time: 49m 58s)
#           acc: 0.99987, fpr: 0.00002, fnr: 0.00499, rec: 0.99501, prc: 0.99919, f1: 0.99709, f1_macro: 0.99851
# epoch: 17, passed number of graphs: 480, train running loss: 0.00097 (passed time: 50m 18s)
#           acc: 0.99980, fpr: 0.00009, fnr: 0.00506, rec: 0.99494, prc: 0.99575, f1: 0.99534, f1_macro: 0.99762
# epoch: 17, passed number of graphs: 576, train running loss: 0.00093 (passed time: 50m 38s)
#           acc: 0.99991, fpr: 0.00003, fnr: 0.00274, rec: 0.99726, prc: 0.99855, f1: 0.99790, f1_macro: 0.99893
# epoch: 17, passed number of graphs: 672, train running loss: 0.00101 (passed time: 50m 57s)
#           acc: 0.99956, fpr: 0.00033, fnr: 0.00527, rec: 0.99473, prc: 0.98512, f1: 0.98990, f1_macro: 0.99484
# epoch: 17, passed number of graphs: 768, train running loss: 0.00103 (passed time: 51m 17s)
#           acc: 0.99989, fpr: 0.00001, fnr: 0.00473, rec: 0.99527, prc: 0.99967, f1: 0.99747, f1_macro: 0.99871
# Validation --- epoch: 17, loss: 0.00210
#           fnr: 0.00995, prc: 0.99735, acc: 0.99973, rec: 0.99005, f1: 0.99291, f1_macro: 0.99639, fpr: 0.00006
# epoch: 18, passed number of graphs: 96, train running loss: 0.00081 (passed time: 52m 0s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00223, rec: 0.99777, prc: 0.99920, f1: 0.99848, f1_macro: 0.99922
# epoch: 18, passed number of graphs: 192, train running loss: 0.00096 (passed time: 52m 20s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00359, rec: 0.99641, prc: 0.99951, f1: 0.99796, f1_macro: 0.99896
# epoch: 18, passed number of graphs: 288, train running loss: 0.00093 (passed time: 52m 40s)
#           acc: 0.99985, fpr: 0.00009, fnr: 0.00278, rec: 0.99722, prc: 0.99592, f1: 0.99657, f1_macro: 0.99825
# epoch: 18, passed number of graphs: 384, train running loss: 0.00093 (passed time: 53m 0s)
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00274, rec: 0.99726, prc: 0.99919, f1: 0.99823, f1_macro: 0.99909
# epoch: 18, passed number of graphs: 480, train running loss: 0.00088 (passed time: 53m 20s)
#           acc: 0.99984, fpr: 0.00007, fnr: 0.00392, rec: 0.99608, prc: 0.99673, f1: 0.99641, f1_macro: 0.99816
# epoch: 18, passed number of graphs: 576, train running loss: 0.00085 (passed time: 53m 40s)
#           acc: 0.99989, fpr: 0.00005, fnr: 0.00291, rec: 0.99709, prc: 0.99774, f1: 0.99742, f1_macro: 0.99868
# epoch: 18, passed number of graphs: 672, train running loss: 0.00093 (passed time: 54m 0s)
#           acc: 0.99948, fpr: 0.00037, fnr: 0.00703, rec: 0.99297, prc: 0.98323, f1: 0.98807, f1_macro: 0.99390
# epoch: 18, passed number of graphs: 768, train running loss: 0.00096 (passed time: 54m 20s)
#           acc: 0.99988, fpr: 0.00001, fnr: 0.00522, rec: 0.99478, prc: 0.99934, f1: 0.99706, f1_macro: 0.99850
# Validation --- epoch: 18, loss: 0.00204
#           fnr: 0.00927, prc: 0.99714, acc: 0.99974, rec: 0.99073, f1: 0.99315, f1_macro: 0.99651, fpr: 0.00006
# epoch: 19, passed number of graphs: 96, train running loss: 0.00077 (passed time: 55m 2s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00239, rec: 0.99761, prc: 0.99952, f1: 0.99856, f1_macro: 0.99927
# epoch: 19, passed number of graphs: 192, train running loss: 0.00100 (passed time: 55m 22s)
#           acc: 0.99988, fpr: 0.00001, fnr: 0.00523, rec: 0.99477, prc: 0.99967, f1: 0.99722, f1_macro: 0.99858
# epoch: 19, passed number of graphs: 288, train running loss: 0.00097 (passed time: 55m 42s)
#           acc: 0.99980, fpr: 0.00012, fnr: 0.00392, rec: 0.99608, prc: 0.99445, f1: 0.99527, f1_macro: 0.99758
# epoch: 19, passed number of graphs: 384, train running loss: 0.00096 (passed time: 56m 2s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00258, rec: 0.99742, prc: 0.99887, f1: 0.99815, f1_macro: 0.99905
# epoch: 19, passed number of graphs: 480, train running loss: 0.00091 (passed time: 56m 22s)
#           acc: 0.99988, fpr: 0.00006, fnr: 0.00310, rec: 0.99690, prc: 0.99739, f1: 0.99714, f1_macro: 0.99854
# epoch: 19, passed number of graphs: 576, train running loss: 0.00087 (passed time: 56m 42s)
#           acc: 0.99988, fpr: 0.00006, fnr: 0.00258, rec: 0.99742, prc: 0.99710, f1: 0.99726, f1_macro: 0.99860
# epoch: 19, passed number of graphs: 672, train running loss: 0.00095 (passed time: 57m 2s)
#           acc: 0.99960, fpr: 0.00031, fnr: 0.00431, rec: 0.99569, prc: 0.98607, f1: 0.99086, f1_macro: 0.99533
# epoch: 19, passed number of graphs: 768, train running loss: 0.00097 (passed time: 57m 22s)
#           acc: 0.99989, fpr: 0.00001, fnr: 0.00489, rec: 0.99511, prc: 0.99967, f1: 0.99738, f1_macro: 0.99866
# Validation --- epoch: 19, loss: 0.00202
#           fnr: 0.00930, prc: 0.99721, acc: 0.99974, rec: 0.99070, f1: 0.99317, f1_macro: 0.99652, fpr: 0.00006
# epoch: 20, passed number of graphs: 96, train running loss: 0.00081 (passed time: 58m 4s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00287, rec: 0.99713, prc: 0.99968, f1: 0.99840, f1_macro: 0.99918
# epoch: 20, passed number of graphs: 192, train running loss: 0.00094 (passed time: 58m 24s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00425, rec: 0.99575, prc: 0.99934, f1: 0.99755, f1_macro: 0.99875
# epoch: 20, passed number of graphs: 288, train running loss: 0.00091 (passed time: 58m 44s)
#           acc: 0.99983, fpr: 0.00010, fnr: 0.00359, rec: 0.99641, prc: 0.99559, f1: 0.99600, f1_macro: 0.99796
# epoch: 20, passed number of graphs: 384, train running loss: 0.00091 (passed time: 59m 4s)
#           acc: 0.99985, fpr: 0.00003, fnr: 0.00548, rec: 0.99452, prc: 0.99887, f1: 0.99669, f1_macro: 0.99831
# epoch: 20, passed number of graphs: 480, train running loss: 0.00086 (passed time: 59m 24s)
#           acc: 0.99986, fpr: 0.00007, fnr: 0.00327, rec: 0.99673, prc: 0.99690, f1: 0.99681, f1_macro: 0.99837
# epoch: 20, passed number of graphs: 576, train running loss: 0.00083 (passed time: 59m 44s)
#           acc: 0.99991, fpr: 0.00003, fnr: 0.00274, rec: 0.99726, prc: 0.99871, f1: 0.99798, f1_macro: 0.99897
# epoch: 20, passed number of graphs: 672, train running loss: 0.00092 (passed time: 1h 0m 4s)
#           acc: 0.99955, fpr: 0.00034, fnr: 0.00527, rec: 0.99473, prc: 0.98466, f1: 0.98967, f1_macro: 0.99472
# epoch: 20, passed number of graphs: 768, train running loss: 0.00095 (passed time: 1h 0m 24s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00424, rec: 0.99576, prc: 0.99967, f1: 0.99771, f1_macro: 0.99883
# Validation --- epoch: 20, loss: 0.00201
#           fnr: 0.00939, prc: 0.99767, acc: 0.99975, rec: 0.99061, f1: 0.99337, f1_macro: 0.99662, fpr: 0.00005
# epoch: 21, passed number of graphs: 96, train running loss: 0.00081 (passed time: 1h 1m 6s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00223, rec: 0.99777, prc: 0.99952, f1: 0.99864, f1_macro: 0.99931
# epoch: 21, passed number of graphs: 192, train running loss: 0.00092 (passed time: 1h 1m 26s)
#           acc: 0.99987, fpr: 0.00000, fnr: 0.00621, rec: 0.99379, prc: 1.00000, f1: 0.99689, f1_macro: 0.99841
# epoch: 21, passed number of graphs: 288, train running loss: 0.00090 (passed time: 1h 1m 46s)
#           acc: 0.99981, fpr: 0.00012, fnr: 0.00376, rec: 0.99624, prc: 0.99462, f1: 0.99543, f1_macro: 0.99766
# epoch: 21, passed number of graphs: 384, train running loss: 0.00089 (passed time: 1h 2m 6s)
#           acc: 0.99987, fpr: 0.00002, fnr: 0.00483, rec: 0.99517, prc: 0.99903, f1: 0.99709, f1_macro: 0.99851
# epoch: 21, passed number of graphs: 480, train running loss: 0.00084 (passed time: 1h 2m 26s)
#           acc: 0.99983, fpr: 0.00008, fnr: 0.00392, rec: 0.99608, prc: 0.99624, f1: 0.99616, f1_macro: 0.99804
# epoch: 21, passed number of graphs: 576, train running loss: 0.00081 (passed time: 1h 2m 46s)
#           acc: 0.99989, fpr: 0.00005, fnr: 0.00307, rec: 0.99693, prc: 0.99774, f1: 0.99734, f1_macro: 0.99864
# epoch: 21, passed number of graphs: 672, train running loss: 0.00089 (passed time: 1h 3m 6s)
#           acc: 0.99960, fpr: 0.00032, fnr: 0.00415, rec: 0.99585, prc: 0.98561, f1: 0.99070, f1_macro: 0.99525
# epoch: 21, passed number of graphs: 768, train running loss: 0.00092 (passed time: 1h 3m 26s)
#           acc: 0.99986, fpr: 0.00001, fnr: 0.00620, rec: 0.99380, prc: 0.99951, f1: 0.99665, f1_macro: 0.99829
# Validation --- epoch: 21, loss: 0.00201
#           fnr: 0.00931, prc: 0.99760, acc: 0.99975, rec: 0.99069, f1: 0.99337, f1_macro: 0.99662, fpr: 0.00005
# epoch: 22, passed number of graphs: 96, train running loss: 0.00079 (passed time: 1h 4m 8s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00144, rec: 0.99856, prc: 0.99920, f1: 0.99888, f1_macro: 0.99943
# epoch: 22, passed number of graphs: 192, train running loss: 0.00092 (passed time: 1h 4m 28s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00392, rec: 0.99608, prc: 0.99967, f1: 0.99787, f1_macro: 0.99891
# epoch: 22, passed number of graphs: 288, train running loss: 0.00089 (passed time: 1h 4m 48s)
#           acc: 0.99982, fpr: 0.00011, fnr: 0.00327, rec: 0.99673, prc: 0.99478, f1: 0.99576, f1_macro: 0.99783
# epoch: 22, passed number of graphs: 384, train running loss: 0.00088 (passed time: 1h 5m 8s)
#           acc: 0.99989, fpr: 0.00002, fnr: 0.00387, rec: 0.99613, prc: 0.99903, f1: 0.99758, f1_macro: 0.99876
# epoch: 22, passed number of graphs: 480, train running loss: 0.00084 (passed time: 1h 5m 28s)
#           acc: 0.99986, fpr: 0.00005, fnr: 0.00425, rec: 0.99575, prc: 0.99755, f1: 0.99665, f1_macro: 0.99829
# epoch: 22, passed number of graphs: 576, train running loss: 0.00082 (passed time: 1h 5m 48s)
#           acc: 0.99988, fpr: 0.00003, fnr: 0.00420, rec: 0.99580, prc: 0.99854, f1: 0.99717, f1_macro: 0.99855
# epoch: 22, passed number of graphs: 672, train running loss: 0.00089 (passed time: 1h 6m 8s)
#           acc: 0.99958, fpr: 0.00031, fnr: 0.00511, rec: 0.99489, prc: 0.98606, f1: 0.99045, f1_macro: 0.99512
# epoch: 22, passed number of graphs: 768, train running loss: 0.00091 (passed time: 1h 6m 28s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00326, rec: 0.99674, prc: 0.99935, f1: 0.99804, f1_macro: 0.99900
# Validation --- epoch: 22, loss: 0.00200
#           fnr: 0.00912, prc: 0.99737, acc: 0.99975, rec: 0.99088, f1: 0.99335, f1_macro: 0.99661, fpr: 0.00006
# epoch: 23, passed number of graphs: 96, train running loss: 0.00084 (passed time: 1h 7m 10s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00191, rec: 0.99809, prc: 0.99952, f1: 0.99880, f1_macro: 0.99939
# epoch: 23, passed number of graphs: 192, train running loss: 0.00093 (passed time: 1h 7m 30s)
# ...
# epoch: 42, passed number of graphs: 288, train running loss: 0.00090 (passed time: 2h 5m 28s)
#           acc: 0.99983, fpr: 0.00011, fnr: 0.00278, rec: 0.99722, prc: 0.99495, f1: 0.99608, f1_macro: 0.99800
# epoch: 42, passed number of graphs: 384, train running loss: 0.00089 (passed time: 2h 5m 48s)
#           acc: 0.99983, fpr: 0.00003, fnr: 0.00644, rec: 0.99356, prc: 0.99887, f1: 0.99620, f1_macro: 0.99806
# epoch: 42, passed number of graphs: 480, train running loss: 0.00085 (passed time: 2h 6m 8s)
#           acc: 0.99978, fpr: 0.00015, fnr: 0.00343, rec: 0.99657, prc: 0.99332, f1: 0.99494, f1_macro: 0.99742
# epoch: 42, passed number of graphs: 576, train running loss: 0.00081 (passed time: 2h 6m 28s)
#           acc: 0.99989, fpr: 0.00004, fnr: 0.00323, rec: 0.99677, prc: 0.99822, f1: 0.99750, f1_macro: 0.99872
# epoch: 42, passed number of graphs: 672, train running loss: 0.00088 (passed time: 2h 6m 48s)
#           acc: 0.99960, fpr: 0.00032, fnr: 0.00431, rec: 0.99569, prc: 0.98576, f1: 0.99070, f1_macro: 0.99525
# epoch: 42, passed number of graphs: 768, train running loss: 0.00092 (passed time: 2h 7m 8s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00375, rec: 0.99625, prc: 0.99951, f1: 0.99788, f1_macro: 0.99891
# Validation --- epoch: 42, loss: 0.00200
#           fnr: 0.00914, prc: 0.99751, acc: 0.99975, rec: 0.99086, f1: 0.99341, f1_macro: 0.99664, fpr: 0.00006
# epoch: 43, passed number of graphs: 96, train running loss: 0.00082 (passed time: 2h 7m 51s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00175, rec: 0.99825, prc: 0.99936, f1: 0.99880, f1_macro: 0.99939
# epoch: 43, passed number of graphs: 192, train running loss: 0.00092 (passed time: 2h 8m 11s)
#           acc: 0.99987, fpr: 0.00000, fnr: 0.00604, rec: 0.99396, prc: 0.99984, f1: 0.99689, f1_macro: 0.99841
# epoch: 43, passed number of graphs: 288, train running loss: 0.00090 (passed time: 2h 8m 31s)
#           acc: 0.99982, fpr: 0.00012, fnr: 0.00294, rec: 0.99706, prc: 0.99446, f1: 0.99576, f1_macro: 0.99783
# epoch: 43, passed number of graphs: 384, train running loss: 0.00090 (passed time: 2h 8m 51s)
#           acc: 0.99987, fpr: 0.00003, fnr: 0.00467, rec: 0.99533, prc: 0.99887, f1: 0.99709, f1_macro: 0.99851
# epoch: 43, passed number of graphs: 480, train running loss: 0.00085 (passed time: 2h 9m 11s)
#           acc: 0.99984, fpr: 0.00007, fnr: 0.00425, rec: 0.99575, prc: 0.99706, f1: 0.99640, f1_macro: 0.99816
# epoch: 43, passed number of graphs: 576, train running loss: 0.00082 (passed time: 2h 9m 31s)
#           acc: 0.99986, fpr: 0.00009, fnr: 0.00226, rec: 0.99774, prc: 0.99581, f1: 0.99677, f1_macro: 0.99835
# epoch: 43, passed number of graphs: 672, train running loss: 0.00090 (passed time: 2h 9m 51s)
#           acc: 0.99934, fpr: 0.00022, fnr: 0.02077, rec: 0.97923, prc: 0.99014, f1: 0.98465, f1_macro: 0.99216
# epoch: 43, passed number of graphs: 768, train running loss: 0.00093 (passed time: 2h 10m 11s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00457, rec: 0.99543, prc: 0.99967, f1: 0.99755, f1_macro: 0.99875
# Validation --- epoch: 43, loss: 0.00200
#           fnr: 0.00901, prc: 0.99728, acc: 0.99975, rec: 0.99099, f1: 0.99336, f1_macro: 0.99661, fpr: 0.00006
# epoch: 44, passed number of graphs: 96, train running loss: 0.00077 (passed time: 2h 10m 53s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00128, rec: 0.99872, prc: 0.99920, f1: 0.99896, f1_macro: 0.99947
# epoch: 44, passed number of graphs: 192, train running loss: 0.00091 (passed time: 2h 11m 13s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00359, rec: 0.99641, prc: 0.99951, f1: 0.99796, f1_macro: 0.99896
# epoch: 44, passed number of graphs: 288, train running loss: 0.00088 (passed time: 2h 11m 33s)
#           acc: 0.99981, fpr: 0.00013, fnr: 0.00294, rec: 0.99706, prc: 0.99381, f1: 0.99543, f1_macro: 0.99767
# epoch: 44, passed number of graphs: 384, train running loss: 0.00088 (passed time: 2h 11m 53s)
#           acc: 0.99987, fpr: 0.00002, fnr: 0.00483, rec: 0.99517, prc: 0.99903, f1: 0.99709, f1_macro: 0.99851
# epoch: 44, passed number of graphs: 480, train running loss: 0.00084 (passed time: 2h 12m 13s)
#           acc: 0.99980, fpr: 0.00014, fnr: 0.00278, rec: 0.99722, prc: 0.99365, f1: 0.99543, f1_macro: 0.99767
# epoch: 44, passed number of graphs: 576, train running loss: 0.00082 (passed time: 2h 12m 33s)
#           acc: 0.99990, fpr: 0.00004, fnr: 0.00307, rec: 0.99693, prc: 0.99822, f1: 0.99758, f1_macro: 0.99876
# epoch: 44, passed number of graphs: 672, train running loss: 0.00089 (passed time: 2h 12m 53s)
#           acc: 0.99961, fpr: 0.00033, fnr: 0.00336, rec: 0.99664, prc: 0.98531, f1: 0.99094, f1_macro: 0.99537
# epoch: 44, passed number of graphs: 768, train running loss: 0.00091 (passed time: 2h 13m 13s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00277, rec: 0.99723, prc: 0.99951, f1: 0.99837, f1_macro: 0.99917
# Validation --- epoch: 44, loss: 0.00200
#           fnr: 0.00894, prc: 0.99717, acc: 0.99975, rec: 0.99106, f1: 0.99334, f1_macro: 0.99661, fpr: 0.00006
# epoch: 45, passed number of graphs: 96, train running loss: 0.00071 (passed time: 2h 13m 55s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00239, rec: 0.99761, prc: 0.99952, f1: 0.99856, f1_macro: 0.99927
# epoch: 45, passed number of graphs: 192, train running loss: 0.00088 (passed time: 2h 14m 15s)
#           acc: 0.99988, fpr: 0.00001, fnr: 0.00523, rec: 0.99477, prc: 0.99951, f1: 0.99714, f1_macro: 0.99854
# epoch: 45, passed number of graphs: 288, train running loss: 0.00086 (passed time: 2h 14m 35s)
#           acc: 0.99982, fpr: 0.00010, fnr: 0.00392, rec: 0.99608, prc: 0.99543, f1: 0.99575, f1_macro: 0.99783
# epoch: 45, passed number of graphs: 384, train running loss: 0.00087 (passed time: 2h 14m 55s)
#           acc: 0.99989, fpr: 0.00001, fnr: 0.00435, rec: 0.99565, prc: 0.99951, f1: 0.99758, f1_macro: 0.99876
# epoch: 45, passed number of graphs: 480, train running loss: 0.00084 (passed time: 2h 15m 15s)
#           acc: 0.99983, fpr: 0.00011, fnr: 0.00294, rec: 0.99706, prc: 0.99511, f1: 0.99608, f1_macro: 0.99800
# epoch: 45, passed number of graphs: 576, train running loss: 0.00080 (passed time: 2h 15m 35s)
#           acc: 0.99985, fpr: 0.00010, fnr: 0.00226, rec: 0.99774, prc: 0.99533, f1: 0.99653, f1_macro: 0.99823
# epoch: 45, passed number of graphs: 672, train running loss: 0.00089 (passed time: 2h 15m 55s)
#           acc: 0.99960, fpr: 0.00031, fnr: 0.00447, rec: 0.99553, prc: 0.98592, f1: 0.99070, f1_macro: 0.99525
# epoch: 45, passed number of graphs: 768, train running loss: 0.00091 (passed time: 2h 16m 15s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00294, rec: 0.99706, prc: 0.99935, f1: 0.99820, f1_macro: 0.99908
# Validation --- epoch: 45, loss: 0.00200
#           fnr: 0.00893, prc: 0.99711, acc: 0.99974, rec: 0.99107, f1: 0.99331, f1_macro: 0.99659, fpr: 0.00006
# epoch: 46, passed number of graphs: 96, train running loss: 0.00067 (passed time: 2h 16m 58s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00207, rec: 0.99793, prc: 0.99888, f1: 0.99840, f1_macro: 0.99918
# epoch: 46, passed number of graphs: 192, train running loss: 0.00090 (passed time: 2h 17m 18s)
#           acc: 0.99988, fpr: 0.00001, fnr: 0.00523, rec: 0.99477, prc: 0.99951, f1: 0.99714, f1_macro: 0.99854
# epoch: 46, passed number of graphs: 288, train running loss: 0.00090 (passed time: 2h 17m 38s)
#           acc: 0.99981, fpr: 0.00011, fnr: 0.00408, rec: 0.99592, prc: 0.99510, f1: 0.99551, f1_macro: 0.99771
# epoch: 46, passed number of graphs: 384, train running loss: 0.00089 (passed time: 2h 17m 58s)
#           acc: 0.99988, fpr: 0.00001, fnr: 0.00483, rec: 0.99517, prc: 0.99951, f1: 0.99734, f1_macro: 0.99864
# epoch: 46, passed number of graphs: 480, train running loss: 0.00085 (passed time: 2h 18m 17s)
#           acc: 0.99980, fpr: 0.00014, fnr: 0.00294, rec: 0.99706, prc: 0.99381, f1: 0.99543, f1_macro: 0.99767
# epoch: 46, passed number of graphs: 576, train running loss: 0.00082 (passed time: 2h 18m 37s)
#           acc: 0.99983, fpr: 0.00012, fnr: 0.00210, rec: 0.99790, prc: 0.99437, f1: 0.99613, f1_macro: 0.99802
# epoch: 46, passed number of graphs: 672, train running loss: 0.00089 (passed time: 2h 18m 57s)
#           acc: 0.99959, fpr: 0.00033, fnr: 0.00415, rec: 0.99585, prc: 0.98545, f1: 0.99062, f1_macro: 0.99521
# epoch: 46, passed number of graphs: 768, train running loss: 0.00091 (passed time: 2h 19m 17s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00375, rec: 0.99625, prc: 0.99967, f1: 0.99796, f1_macro: 0.99896
# Validation --- epoch: 46, loss: 0.00200
#           fnr: 0.00913, prc: 0.99749, acc: 0.99975, rec: 0.99087, f1: 0.99341, f1_macro: 0.99664, fpr: 0.00006
# epoch: 47, passed number of graphs: 96, train running loss: 0.00080 (passed time: 2h 20m 0s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00319, rec: 0.99681, prc: 0.99936, f1: 0.99808, f1_macro: 0.99902
# epoch: 47, passed number of graphs: 192, train running loss: 0.00091 (passed time: 2h 20m 20s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00294, rec: 0.99706, prc: 0.99935, f1: 0.99820, f1_macro: 0.99908
# epoch: 47, passed number of graphs: 288, train running loss: 0.00088 (passed time: 2h 20m 40s)
#           acc: 0.99982, fpr: 0.00013, fnr: 0.00229, rec: 0.99771, prc: 0.99398, f1: 0.99584, f1_macro: 0.99788
# epoch: 47, passed number of graphs: 384, train running loss: 0.00090 (passed time: 2h 21m 0s)
#           acc: 0.99987, fpr: 0.00001, fnr: 0.00548, rec: 0.99452, prc: 0.99935, f1: 0.99693, f1_macro: 0.99843
# epoch: 47, passed number of graphs: 480, train running loss: 0.00086 (passed time: 2h 21m 20s)
#           acc: 0.99982, fpr: 0.00012, fnr: 0.00310, rec: 0.99690, prc: 0.99462, f1: 0.99576, f1_macro: 0.99783
# epoch: 47, passed number of graphs: 576, train running loss: 0.00082 (passed time: 2h 21m 40s)
#           acc: 0.99990, fpr: 0.00006, fnr: 0.00194, rec: 0.99806, prc: 0.99726, f1: 0.99766, f1_macro: 0.99880
# epoch: 47, passed number of graphs: 672, train running loss: 0.00089 (passed time: 2h 22m 0s)
#           acc: 0.99963, fpr: 0.00031, fnr: 0.00320, rec: 0.99680, prc: 0.98625, f1: 0.99150, f1_macro: 0.99565
# epoch: 47, passed number of graphs: 768, train running loss: 0.00091 (passed time: 2h 22m 19s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00326, rec: 0.99674, prc: 0.99951, f1: 0.99812, f1_macro: 0.99904
# Validation --- epoch: 47, loss: 0.00200
#           fnr: 0.00899, prc: 0.99721, acc: 0.99975, rec: 0.99101, f1: 0.99333, f1_macro: 0.99660, fpr: 0.00006
# epoch: 48, passed number of graphs: 96, train running loss: 0.00076 (passed time: 2h 23m 2s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00191, rec: 0.99809, prc: 0.99888, f1: 0.99848, f1_macro: 0.99923
# epoch: 48, passed number of graphs: 192, train running loss: 0.00089 (passed time: 2h 23m 22s)
#           acc: 0.99988, fpr: 0.00000, fnr: 0.00523, rec: 0.99477, prc: 0.99984, f1: 0.99730, f1_macro: 0.99862
# epoch: 48, passed number of graphs: 288, train running loss: 0.00093 (passed time: 2h 23m 42s)
#           acc: 0.99981, fpr: 0.00014, fnr: 0.00229, rec: 0.99771, prc: 0.99349, f1: 0.99560, f1_macro: 0.99775
# epoch: 48, passed number of graphs: 384, train running loss: 0.00093 (passed time: 2h 24m 2s)
#           acc: 0.99988, fpr: 0.00002, fnr: 0.00451, rec: 0.99549, prc: 0.99919, f1: 0.99734, f1_macro: 0.99864
# epoch: 48, passed number of graphs: 480, train running loss: 0.00087 (passed time: 2h 24m 22s)
#           acc: 0.99982, fpr: 0.00012, fnr: 0.00327, rec: 0.99673, prc: 0.99478, f1: 0.99576, f1_macro: 0.99783
# epoch: 48, passed number of graphs: 576, train running loss: 0.00085 (passed time: 2h 24m 42s)
#           acc: 0.99991, fpr: 0.00004, fnr: 0.00242, rec: 0.99758, prc: 0.99822, f1: 0.99790, f1_macro: 0.99893
# epoch: 48, passed number of graphs: 672, train running loss: 0.00093 (passed time: 2h 25m 2s)
#           acc: 0.99959, fpr: 0.00034, fnr: 0.00384, rec: 0.99616, prc: 0.98499, f1: 0.99055, f1_macro: 0.99517
# epoch: 48, passed number of graphs: 768, train running loss: 0.00095 (passed time: 2h 25m 22s)
#           acc: 0.99984, fpr: 0.00001, fnr: 0.00669, rec: 0.99331, prc: 0.99934, f1: 0.99632, f1_macro: 0.99812
# Validation --- epoch: 48, loss: 0.00200
#           fnr: 0.00922, prc: 0.99758, acc: 0.99975, rec: 0.99078, f1: 0.99341, f1_macro: 0.99664, fpr: 0.00005
# epoch: 49, passed number of graphs: 96, train running loss: 0.00070 (passed time: 2h 26m 4s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00287, rec: 0.99713, prc: 0.99952, f1: 0.99832, f1_macro: 0.99914
# epoch: 49, passed number of graphs: 192, train running loss: 0.00084 (passed time: 2h 26m 24s)
#           acc: 0.99991, fpr: 0.00000, fnr: 0.00425, rec: 0.99575, prc: 0.99984, f1: 0.99779, f1_macro: 0.99887
# epoch: 49, passed number of graphs: 288, train running loss: 0.00084 (passed time: 2h 26m 44s)
#           acc: 0.99979, fpr: 0.00013, fnr: 0.00359, rec: 0.99641, prc: 0.99381, f1: 0.99510, f1_macro: 0.99750
# epoch: 49, passed number of graphs: 384, train running loss: 0.00084 (passed time: 2h 27m 4s)
#           acc: 0.99990, fpr: 0.00002, fnr: 0.00387, rec: 0.99613, prc: 0.99919, f1: 0.99766, f1_macro: 0.99880
# epoch: 49, passed number of graphs: 480, train running loss: 0.00081 (passed time: 2h 27m 24s)
#           acc: 0.99983, fpr: 0.00012, fnr: 0.00261, rec: 0.99739, prc: 0.99479, f1: 0.99608, f1_macro: 0.99800
# epoch: 49, passed number of graphs: 576, train running loss: 0.00078 (passed time: 2h 27m 44s)
#           acc: 0.99988, fpr: 0.00007, fnr: 0.00258, rec: 0.99742, prc: 0.99677, f1: 0.99710, f1_macro: 0.99852
# epoch: 49, passed number of graphs: 672, train running loss: 0.00086 (passed time: 2h 28m 4s)
#           acc: 0.99954, fpr: 0.00025, fnr: 0.00959, rec: 0.99041, prc: 0.98852, f1: 0.98946, f1_macro: 0.99462
# epoch: 49, passed number of graphs: 768, train running loss: 0.00090 (passed time: 2h 28m 24s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00343, rec: 0.99657, prc: 0.99935, f1: 0.99796, f1_macro: 0.99896
# Validation --- epoch: 49, loss: 0.00200
#           fnr: 0.00892, prc: 0.99711, acc: 0.99974, rec: 0.99108, f1: 0.99332, f1_macro: 0.99659, fpr: 0.00006
# epoch: 50, passed number of graphs: 96, train running loss: 0.00070 (passed time: 2h 29m 6s)
#           acc: 0.99991, fpr: 0.00002, fnr: 0.00319, rec: 0.99681, prc: 0.99920, f1: 0.99800, f1_macro: 0.99898
# epoch: 50, passed number of graphs: 192, train running loss: 0.00087 (passed time: 2h 29m 26s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00441, rec: 0.99559, prc: 0.99951, f1: 0.99755, f1_macro: 0.99875
# epoch: 50, passed number of graphs: 288, train running loss: 0.00086 (passed time: 2h 29m 46s)
#           acc: 0.99981, fpr: 0.00014, fnr: 0.00278, rec: 0.99722, prc: 0.99365, f1: 0.99543, f1_macro: 0.99767
# epoch: 50, passed number of graphs: 384, train running loss: 0.00087 (passed time: 2h 30m 6s)
#           acc: 0.99987, fpr: 0.00002, fnr: 0.00516, rec: 0.99484, prc: 0.99919, f1: 0.99701, f1_macro: 0.99847
# epoch: 50, passed number of graphs: 480, train running loss: 0.00083 (passed time: 2h 30m 26s)
#           acc: 0.99981, fpr: 0.00010, fnr: 0.00441, rec: 0.99559, prc: 0.99559, f1: 0.99559, f1_macro: 0.99775
# epoch: 50, passed number of graphs: 576, train running loss: 0.00080 (passed time: 2h 30m 46s)
#           acc: 0.99988, fpr: 0.00006, fnr: 0.00274, rec: 0.99726, prc: 0.99709, f1: 0.99718, f1_macro: 0.99856
# epoch: 50, passed number of graphs: 672, train running loss: 0.00088 (passed time: 2h 31m 6s)
#           acc: 0.99961, fpr: 0.00032, fnr: 0.00384, rec: 0.99616, prc: 0.98577, f1: 0.99094, f1_macro: 0.99537
# epoch: 50, passed number of graphs: 768, train running loss: 0.00090 (passed time: 2h 31m 25s)
#           acc: 0.99989, fpr: 0.00001, fnr: 0.00473, rec: 0.99527, prc: 0.99934, f1: 0.99730, f1_macro: 0.99862
# Validation --- epoch: 50, loss: 0.00200
#           fnr: 0.00893, prc: 0.99716, acc: 0.99975, rec: 0.99107, f1: 0.99334, f1_macro: 0.99660, fpr: 0.00006
# ************ best model obtained after epoch 12, saved at ./saved_models/GIN_11: 0.9938754997795639.pt ************
# Testing --- loss: 0.00109
#           fnr: 0.00391, prc: 0.99581, acc: 0.99982, rec: 0.99609, f1: 0.99572, f1_macro: 0.99782, fpr: 0.00009
