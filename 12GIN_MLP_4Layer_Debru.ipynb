# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/Do_an_tot_nghiep/blob/main/12GIN_MLP_4Layer_Debru.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric==1.4.3
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter_
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric==1.4.3 in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.21.6)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.0.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.56.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.23.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.6.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.18.3)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (6.2.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.7.3)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.7.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.12.1+cu113)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->torch-geometric==1.4.3) (1.5.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (57.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (0.39.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (4.13.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (3.10.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2022.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.4.3) (1.15.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (0.6.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2022.9.24)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (1.3.0)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (3.2.2)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2021.11.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2.9.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (7.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (0.11.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
        elif split == 'val':
            self.path = self.processed_paths[1]
        elif split == 'test':
            self.path = self.processed_paths[2]

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
            self.num_graphs = self.data['num_graphs']
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            with h5py.File(self.path, 'r') as f:
                self.num_graphs = f.attrs['num_graphs']
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GINConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_input_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), 
                             BatchNorm1d(self.dim_hidden_feature), ReLU())))
          else:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), 
                             BatchNorm1d(self.dim_hidden_feature), ReLU()))) 

        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                add_xr_at = n
            if n == add_xr_at:
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/Debru'
data_name = 'debru' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=False, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=True, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=True, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 2
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.2
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-02a279da-4338-40e9-b944-8b64b0b6e354.json
# ------------------------------
# ------------------------------
# Tue Nov  8 00:50:25 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GINConv(nn=Sequential(
#       (0): Linear(in_features=1, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (1): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (2): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (3): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (4): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (5): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (6): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (7): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (8): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (9): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (10): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (11): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 2
# epoch: 1, passed number of graphs: 96, train running loss: 0.04811 (passed time: 1m 41s)
#           acc: 0.99802, fpr: 0.00061, fnr: 0.02045, rec: 0.97955, prc: 0.99175, f1: 0.98561, f1_macro: 0.99227
# epoch: 1, passed number of graphs: 192, train running loss: 0.02605 (passed time: 2m 31s)
#           acc: 0.99912, fpr: 0.00050, fnr: 0.00600, rec: 0.99400, prc: 0.99335, f1: 0.99368, f1_macro: 0.99660
# epoch: 1, passed number of graphs: 288, train running loss: 0.01825 (passed time: 3m 13s)
#           acc: 0.99900, fpr: 0.00055, fnr: 0.00705, rec: 0.99295, prc: 0.99255, f1: 0.99275, f1_macro: 0.99611
# epoch: 1, passed number of graphs: 384, train running loss: 0.01421 (passed time: 3m 52s)
#           acc: 0.99963, fpr: 0.00013, fnr: 0.00350, rec: 0.99650, prc: 0.99830, f1: 0.99740, f1_macro: 0.99860
# epoch: 1, passed number of graphs: 480, train running loss: 0.01175 (passed time: 4m 29s)
#           acc: 0.99967, fpr: 0.00017, fnr: 0.00230, rec: 0.99770, prc: 0.99770, f1: 0.99770, f1_macro: 0.99876
# epoch: 1, passed number of graphs: 576, train running loss: 0.01000 (passed time: 5m 10s)
#           acc: 0.99980, fpr: 0.00004, fnr: 0.00235, rec: 0.99765, prc: 0.99950, f1: 0.99857, f1_macro: 0.99923
# epoch: 1, passed number of graphs: 672, train running loss: 0.00871 (passed time: 5m 52s)
#           acc: 0.99977, fpr: 0.00006, fnr: 0.00255, rec: 0.99745, prc: 0.99920, f1: 0.99832, f1_macro: 0.99910
# epoch: 1, passed number of graphs: 768, train running loss: 0.00831 (passed time: 6m 30s)
#           acc: 0.99885, fpr: 0.00022, fnr: 0.01370, rec: 0.98630, prc: 0.99707, f1: 0.99165, f1_macro: 0.99552
# Validation --- epoch: 1, loss: 0.04345
#           acc: 0.99079, fpr: 0.00000, fnr: 0.13230, rec: 0.86770, f1: 0.92908, f1_macro: 0.96208, prc: 0.99998
# Better model saved at ./saved_models/GIN_0: 0.9290781122381025.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.00219 (passed time: 7m 18s)
#           acc: 0.99966, fpr: 0.00018, fnr: 0.00250, rec: 0.99750, prc: 0.99755, f1: 0.99752, f1_macro: 0.99867
# epoch: 2, passed number of graphs: 192, train running loss: 0.00160 (passed time: 7m 55s)
#           acc: 0.99975, fpr: 0.00018, fnr: 0.00115, rec: 0.99885, prc: 0.99755, f1: 0.99820, f1_macro: 0.99903
# epoch: 2, passed number of graphs: 288, train running loss: 0.00135 (passed time: 8m 32s)
#           acc: 0.99978, fpr: 0.00012, fnr: 0.00155, rec: 0.99845, prc: 0.99840, f1: 0.99843, f1_macro: 0.99915
# epoch: 2, passed number of graphs: 384, train running loss: 0.00122 (passed time: 9m 10s)
#           acc: 0.99983, fpr: 0.00011, fnr: 0.00100, rec: 0.99900, prc: 0.99855, f1: 0.99878, f1_macro: 0.99934
# epoch: 2, passed number of graphs: 480, train running loss: 0.00190 (passed time: 9m 48s)
#           acc: 0.99952, fpr: 0.00012, fnr: 0.00525, rec: 0.99475, prc: 0.99839, f1: 0.99657, f1_macro: 0.99815
# epoch: 2, passed number of graphs: 576, train running loss: 0.00180 (passed time: 10m 26s)
#           acc: 0.99979, fpr: 0.00009, fnr: 0.00175, rec: 0.99825, prc: 0.99875, f1: 0.99850, f1_macro: 0.99919
# epoch: 2, passed number of graphs: 672, train running loss: 0.00164 (passed time: 11m 4s)
#           acc: 0.99976, fpr: 0.00004, fnr: 0.00300, rec: 0.99700, prc: 0.99950, f1: 0.99825, f1_macro: 0.99906
# epoch: 2, passed number of graphs: 768, train running loss: 0.00153 (passed time: 11m 42s)
#           acc: 0.99981, fpr: 0.00011, fnr: 0.00125, rec: 0.99875, prc: 0.99850, f1: 0.99863, f1_macro: 0.99926
# Validation --- epoch: 2, loss: 7.84324
#           acc: 0.73988, fpr: 0.27958, fnr: 0.00000, rec: 1.00000, f1: 0.34896, f1_macro: 0.59317, prc: 0.21142
# epoch: 3, passed number of graphs: 96, train running loss: 0.00053 (passed time: 12m 31s)
#           acc: 0.99986, fpr: 0.00007, fnr: 0.00105, rec: 0.99895, prc: 0.99900, f1: 0.99897, f1_macro: 0.99945
# epoch: 3, passed number of graphs: 192, train running loss: 0.00050 (passed time: 13m 9s)
#           acc: 0.99986, fpr: 0.00007, fnr: 0.00105, rec: 0.99895, prc: 0.99910, f1: 0.99902, f1_macro: 0.99948
# epoch: 3, passed number of graphs: 288, train running loss: 0.00049 (passed time: 13m 47s)
#           acc: 0.99987, fpr: 0.00006, fnr: 0.00105, rec: 0.99895, prc: 0.99920, f1: 0.99907, f1_macro: 0.99950
# epoch: 3, passed number of graphs: 384, train running loss: 0.00049 (passed time: 14m 25s)
#           acc: 0.99987, fpr: 0.00005, fnr: 0.00125, rec: 0.99875, prc: 0.99940, f1: 0.99907, f1_macro: 0.99950
# epoch: 3, passed number of graphs: 480, train running loss: 0.00048 (passed time: 15m 2s)
#           acc: 0.99989, fpr: 0.00003, fnr: 0.00120, rec: 0.99880, prc: 0.99960, f1: 0.99920, f1_macro: 0.99957
# epoch: 3, passed number of graphs: 576, train running loss: 0.00047 (passed time: 15m 40s)
#           acc: 0.99987, fpr: 0.00004, fnr: 0.00135, rec: 0.99865, prc: 0.99950, f1: 0.99907, f1_macro: 0.99950
# epoch: 3, passed number of graphs: 672, train running loss: 0.00049 (passed time: 16m 18s)
#           acc: 0.99983, fpr: 0.00003, fnr: 0.00210, rec: 0.99790, prc: 0.99965, f1: 0.99877, f1_macro: 0.99934
# epoch: 3, passed number of graphs: 768, train running loss: 0.00047 (passed time: 16m 55s)
#           acc: 0.99987, fpr: 0.00008, fnr: 0.00080, rec: 0.99920, prc: 0.99895, f1: 0.99908, f1_macro: 0.99950
# Validation --- epoch: 3, loss: 0.00132
#           acc: 0.99972, fpr: 0.00000, fnr: 0.00396, rec: 0.99604, f1: 0.99801, f1_macro: 0.99893, prc: 0.99999
# Better model saved at ./saved_models/GIN_2: 0.9980147012749412.pt.
# epoch: 4, passed number of graphs: 96, train running loss: 0.00035 (passed time: 17m 42s)
#           acc: 0.99989, fpr: 0.00004, fnr: 0.00105, rec: 0.99895, prc: 0.99945, f1: 0.99920, f1_macro: 0.99957
# epoch: 4, passed number of graphs: 192, train running loss: 0.00036 (passed time: 18m 20s)
#           acc: 0.99990, fpr: 0.00002, fnr: 0.00110, rec: 0.99890, prc: 0.99970, f1: 0.99930, f1_macro: 0.99962
# epoch: 4, passed number of graphs: 288, train running loss: 0.00050 (passed time: 18m 59s)
#           acc: 0.99945, fpr: 0.00000, fnr: 0.00800, rec: 0.99200, prc: 1.00000, f1: 0.99598, f1_macro: 0.99784
# epoch: 4, passed number of graphs: 384, train running loss: 0.00050 (passed time: 19m 36s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00070, rec: 0.99930, prc: 0.99900, f1: 0.99915, f1_macro: 0.99954
# epoch: 4, passed number of graphs: 480, train running loss: 0.00048 (passed time: 20m 14s)
#           acc: 0.99989, fpr: 0.00005, fnr: 0.00090, rec: 0.99910, prc: 0.99940, f1: 0.99925, f1_macro: 0.99960
# epoch: 4, passed number of graphs: 576, train running loss: 0.00045 (passed time: 20m 51s)
#           acc: 0.99988, fpr: 0.00003, fnr: 0.00135, rec: 0.99865, prc: 0.99965, f1: 0.99915, f1_macro: 0.99954
# epoch: 4, passed number of graphs: 672, train running loss: 0.00043 (passed time: 21m 29s)
#           acc: 0.99988, fpr: 0.00002, fnr: 0.00150, rec: 0.99850, prc: 0.99975, f1: 0.99912, f1_macro: 0.99953
# epoch: 4, passed number of graphs: 768, train running loss: 0.00043 (passed time: 22m 6s)
#           acc: 0.99990, fpr: 0.00002, fnr: 0.00125, rec: 0.99875, prc: 0.99975, f1: 0.99925, f1_macro: 0.99960
# Validation --- epoch: 4, loss: 0.00103
#           acc: 0.99978, fpr: 0.00019, fnr: 0.00058, rec: 0.99942, f1: 0.99843, f1_macro: 0.99915, prc: 0.99743
# Better model saved at ./saved_models/GIN_3: 0.998425224502406.pt.
# epoch: 5, passed number of graphs: 96, train running loss: 0.00033 (passed time: 22m 53s)
#           acc: 0.99988, fpr: 0.00003, fnr: 0.00140, rec: 0.99860, prc: 0.99965, f1: 0.99912, f1_macro: 0.99953
# epoch: 5, passed number of graphs: 192, train running loss: 0.00033 (passed time: 23m 31s)
#           acc: 0.99989, fpr: 0.00001, fnr: 0.00140, rec: 0.99860, prc: 0.99985, f1: 0.99922, f1_macro: 0.99958
# epoch: 5, passed number of graphs: 288, train running loss: 0.00035 (passed time: 24m 8s)
#           acc: 0.99991, fpr: 0.00003, fnr: 0.00095, rec: 0.99905, prc: 0.99960, f1: 0.99932, f1_macro: 0.99964
# epoch: 5, passed number of graphs: 384, train running loss: 0.00033 (passed time: 24m 46s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00065, rec: 0.99935, prc: 0.99980, f1: 0.99957, f1_macro: 0.99977
# epoch: 5, passed number of graphs: 480, train running loss: 0.00033 (passed time: 25m 23s)
#           acc: 0.99990, fpr: 0.00005, fnr: 0.00075, rec: 0.99925, prc: 0.99930, f1: 0.99927, f1_macro: 0.99961
# epoch: 5, passed number of graphs: 576, train running loss: 0.00032 (passed time: 26m 0s)
#           acc: 0.99984, fpr: 0.00000, fnr: 0.00225, rec: 0.99775, prc: 1.00000, f1: 0.99887, f1_macro: 0.99940
# epoch: 5, passed number of graphs: 672, train running loss: 0.00031 (passed time: 26m 38s)
#           acc: 0.99989, fpr: 0.00006, fnr: 0.00080, rec: 0.99920, prc: 0.99915, f1: 0.99918, f1_macro: 0.99956
# epoch: 5, passed number of graphs: 768, train running loss: 0.00144 (passed time: 27m 15s)
#           acc: 0.98703, fpr: 0.00083, fnr: 0.17590, rec: 0.82410, prc: 0.98665, f1: 0.89808, f1_macro: 0.94558
# Validation --- epoch: 5, loss: 111.96529
#           acc: 0.93043, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, f1: 0.00000, f1_macro: nan, prc: -1.00000
# epoch: 6, passed number of graphs: 96, train running loss: 0.00521 (passed time: 28m 2s)
#           acc: 0.99927, fpr: 0.00028, fnr: 0.00675, rec: 0.99325, prc: 0.99619, f1: 0.99472, f1_macro: 0.99716
# epoch: 6, passed number of graphs: 192, train running loss: 0.00297 (passed time: 28m 40s)
#           acc: 0.99968, fpr: 0.00000, fnr: 0.00465, rec: 0.99535, prc: 1.00000, f1: 0.99767, f1_macro: 0.99875
# epoch: 6, passed number of graphs: 288, train running loss: 0.00216 (passed time: 29m 18s)
#           acc: 0.99975, fpr: 0.00000, fnr: 0.00350, rec: 0.99650, prc: 0.99995, f1: 0.99822, f1_macro: 0.99904
# epoch: 6, passed number of graphs: 384, train running loss: 0.00172 (passed time: 29m 55s)
#           acc: 0.99987, fpr: 0.00004, fnr: 0.00135, rec: 0.99865, prc: 0.99950, f1: 0.99907, f1_macro: 0.99950
# epoch: 6, passed number of graphs: 480, train running loss: 0.00145 (passed time: 30m 33s)
#           acc: 0.99988, fpr: 0.00002, fnr: 0.00150, rec: 0.99850, prc: 0.99980, f1: 0.99915, f1_macro: 0.99954
# epoch: 6, passed number of graphs: 576, train running loss: 0.00126 (passed time: 31m 10s)
#           acc: 0.99971, fpr: 0.00001, fnr: 0.00410, rec: 0.99590, prc: 0.99990, f1: 0.99790, f1_macro: 0.99887
# epoch: 6, passed number of graphs: 672, train running loss: 0.00113 (passed time: 31m 47s)
#           acc: 0.99988, fpr: 0.00005, fnr: 0.00110, rec: 0.99890, prc: 0.99935, f1: 0.99912, f1_macro: 0.99953
# epoch: 6, passed number of graphs: 768, train running loss: 0.00103 (passed time: 32m 25s)
#           acc: 0.99988, fpr: 0.00003, fnr: 0.00140, rec: 0.99860, prc: 0.99965, f1: 0.99912, f1_macro: 0.99953
# Validation --- epoch: 6, loss: 0.00068
#           acc: 0.99986, fpr: 0.00005, fnr: 0.00136, rec: 0.99864, f1: 0.99899, f1_macro: 0.99946, prc: 0.99933
# Better model saved at ./saved_models/GIN_5: 0.9989860724505317.pt.
# epoch: 7, passed number of graphs: 96, train running loss: 0.00026 (passed time: 33m 12s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00105, rec: 0.99895, prc: 0.99990, f1: 0.99942, f1_macro: 0.99969
# epoch: 7, passed number of graphs: 192, train running loss: 0.00031 (passed time: 33m 50s)
#           acc: 0.99989, fpr: 0.00003, fnr: 0.00120, rec: 0.99880, prc: 0.99965, f1: 0.99922, f1_macro: 0.99958
# epoch: 7, passed number of graphs: 288, train running loss: 0.00030 (passed time: 34m 28s)
#           acc: 0.99991, fpr: 0.00003, fnr: 0.00100, rec: 0.99900, prc: 0.99965, f1: 0.99932, f1_macro: 0.99964
# epoch: 7, passed number of graphs: 384, train running loss: 0.00028 (passed time: 35m 6s)
#           acc: 0.99989, fpr: 0.00001, fnr: 0.00140, rec: 0.99860, prc: 0.99990, f1: 0.99925, f1_macro: 0.99960
# epoch: 7, passed number of graphs: 480, train running loss: 0.00315 (passed time: 35m 44s)
#           acc: 0.99907, fpr: 0.00010, fnr: 0.01190, rec: 0.98810, prc: 0.99869, f1: 0.99336, f1_macro: 0.99643
# epoch: 7, passed number of graphs: 576, train running loss: 0.00282 (passed time: 36m 22s)
#           acc: 0.99974, fpr: 0.00009, fnr: 0.00260, rec: 0.99740, prc: 0.99880, f1: 0.99810, f1_macro: 0.99898
# epoch: 7, passed number of graphs: 672, train running loss: 0.00247 (passed time: 37m 0s)
#           acc: 0.99984, fpr: 0.00006, fnr: 0.00140, rec: 0.99860, prc: 0.99915, f1: 0.99887, f1_macro: 0.99940
# epoch: 7, passed number of graphs: 768, train running loss: 0.00221 (passed time: 37m 38s)
#           acc: 0.99989, fpr: 0.00002, fnr: 0.00135, rec: 0.99865, prc: 0.99975, f1: 0.99920, f1_macro: 0.99957
# Validation --- epoch: 7, loss: 0.00128
#           acc: 0.99963, fpr: 0.00038, fnr: 0.00028, rec: 0.99972, f1: 0.99732, f1_macro: 0.99856, prc: 0.99494
# epoch: 8, passed number of graphs: 96, train running loss: 0.00029 (passed time: 38m 26s)
#           acc: 0.99990, fpr: 0.00002, fnr: 0.00110, rec: 0.99890, prc: 0.99970, f1: 0.99930, f1_macro: 0.99962
# epoch: 8, passed number of graphs: 192, train running loss: 0.00086 (passed time: 39m 4s)
#           acc: 0.99966, fpr: 0.00007, fnr: 0.00390, rec: 0.99610, prc: 0.99905, f1: 0.99757, f1_macro: 0.99869
# epoch: 8, passed number of graphs: 288, train running loss: 0.00076 (passed time: 39m 42s)
#           acc: 0.99983, fpr: 0.00007, fnr: 0.00155, rec: 0.99845, prc: 0.99910, f1: 0.99877, f1_macro: 0.99934
# epoch: 8, passed number of graphs: 384, train running loss: 0.00066 (passed time: 40m 21s)
#           acc: 0.99989, fpr: 0.00003, fnr: 0.00110, rec: 0.99890, prc: 0.99960, f1: 0.99925, f1_macro: 0.99960
# epoch: 8, passed number of graphs: 480, train running loss: 0.00060 (passed time: 40m 59s)
#           acc: 0.99985, fpr: 0.00005, fnr: 0.00150, rec: 0.99850, prc: 0.99935, f1: 0.99892, f1_macro: 0.99942
# epoch: 8, passed number of graphs: 576, train running loss: 0.00055 (passed time: 41m 38s)
#           acc: 0.99985, fpr: 0.00003, fnr: 0.00165, rec: 0.99835, prc: 0.99955, f1: 0.99895, f1_macro: 0.99944
# epoch: 8, passed number of graphs: 672, train running loss: 0.00051 (passed time: 42m 16s)
#           acc: 0.99989, fpr: 0.00002, fnr: 0.00135, rec: 0.99865, prc: 0.99970, f1: 0.99917, f1_macro: 0.99956
# epoch: 8, passed number of graphs: 768, train running loss: 0.00048 (passed time: 42m 54s)
#           acc: 0.99988, fpr: 0.00002, fnr: 0.00145, rec: 0.99855, prc: 0.99970, f1: 0.99912, f1_macro: 0.99953
# Validation --- epoch: 8, loss: 0.00364
#           acc: 0.99875, fpr: 0.00134, fnr: 0.00007, rec: 0.99993, f1: 0.99112, f1_macro: 0.99522, prc: 0.98247
# epoch: 9, passed number of graphs: 96, train running loss: 0.00025 (passed time: 43m 41s)
#           acc: 0.99991, fpr: 0.00004, fnr: 0.00075, rec: 0.99925, prc: 0.99940, f1: 0.99932, f1_macro: 0.99964
# epoch: 9, passed number of graphs: 192, train running loss: 0.00025 (passed time: 44m 19s)
#           acc: 0.99989, fpr: 0.00001, fnr: 0.00145, rec: 0.99855, prc: 0.99990, f1: 0.99922, f1_macro: 0.99958
# epoch: 9, passed number of graphs: 288, train running loss: 0.00025 (passed time: 44m 57s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00095, rec: 0.99905, prc: 0.99980, f1: 0.99942, f1_macro: 0.99969
# epoch: 9, passed number of graphs: 384, train running loss: 0.00025 (passed time: 45m 35s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00070, rec: 0.99930, prc: 0.99960, f1: 0.99945, f1_macro: 0.99970
# epoch: 9, passed number of graphs: 480, train running loss: 0.00025 (passed time: 46m 12s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00070, rec: 0.99930, prc: 0.99965, f1: 0.99947, f1_macro: 0.99972
# epoch: 9, passed number of graphs: 576, train running loss: 0.00025 (passed time: 46m 50s)
#           acc: 0.99990, fpr: 0.00005, fnr: 0.00075, rec: 0.99925, prc: 0.99935, f1: 0.99930, f1_macro: 0.99962
# epoch: 9, passed number of graphs: 672, train running loss: 0.00025 (passed time: 47m 27s)
#           acc: 0.99989, fpr: 0.00003, fnr: 0.00120, rec: 0.99880, prc: 0.99955, f1: 0.99917, f1_macro: 0.99956
# epoch: 9, passed number of graphs: 768, train running loss: 0.00025 (passed time: 48m 4s)
#           acc: 0.99990, fpr: 0.00003, fnr: 0.00095, rec: 0.99905, prc: 0.99955, f1: 0.99930, f1_macro: 0.99962
# Validation --- epoch: 9, loss: 0.00070
#           acc: 0.99981, fpr: 0.00018, fnr: 0.00032, rec: 0.99968, f1: 0.99867, f1_macro: 0.99929, prc: 0.99766
# epoch: 10, passed number of graphs: 96, train running loss: 0.00024 (passed time: 48m 52s)
#           acc: 0.99991, fpr: 0.00005, fnr: 0.00065, rec: 0.99935, prc: 0.99930, f1: 0.99933, f1_macro: 0.99964
# epoch: 10, passed number of graphs: 192, train running loss: 0.00024 (passed time: 49m 29s)
#           acc: 0.99990, fpr: 0.00003, fnr: 0.00100, rec: 0.99900, prc: 0.99960, f1: 0.99930, f1_macro: 0.99962
# epoch: 10, passed number of graphs: 288, train running loss: 0.00024 (passed time: 50m 8s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00115, rec: 0.99885, prc: 0.99985, f1: 0.99935, f1_macro: 0.99965
# epoch: 10, passed number of graphs: 384, train running loss: 0.00023 (passed time: 50m 46s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00070, rec: 0.99930, prc: 0.99980, f1: 0.99955, f1_macro: 0.99976
# epoch: 10, passed number of graphs: 480, train running loss: 0.00024 (passed time: 51m 24s)
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00090, rec: 0.99910, prc: 0.99970, f1: 0.99940, f1_macro: 0.99968
# epoch: 10, passed number of graphs: 576, train running loss: 0.00024 (passed time: 52m 2s)
#           acc: 0.99992, fpr: 0.00005, fnr: 0.00050, rec: 0.99950, prc: 0.99935, f1: 0.99943, f1_macro: 0.99969
# epoch: 10, passed number of graphs: 672, train running loss: 0.00023 (passed time: 52m 40s)
#           acc: 0.99990, fpr: 0.00002, fnr: 0.00115, rec: 0.99885, prc: 0.99970, f1: 0.99927, f1_macro: 0.99961
# epoch: 10, passed number of graphs: 768, train running loss: 0.00023 (passed time: 53m 17s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00080, rec: 0.99920, prc: 0.99965, f1: 0.99942, f1_macro: 0.99969
# Validation --- epoch: 10, loss: 0.00102
#           acc: 0.99987, fpr: 0.00001, fnr: 0.00164, rec: 0.99836, f1: 0.99908, f1_macro: 0.99951, prc: 0.99980
# Better model saved at ./saved_models/GIN_9: 0.9990794930305354.pt.
# epoch: 11, passed number of graphs: 96, train running loss: 0.00022 (passed time: 54m 5s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00055, rec: 0.99945, prc: 0.99955, f1: 0.99950, f1_macro: 0.99973
# epoch: 11, passed number of graphs: 192, train running loss: 0.00022 (passed time: 54m 42s)
#           acc: 0.99991, fpr: 0.00002, fnr: 0.00110, rec: 0.99890, prc: 0.99980, f1: 0.99935, f1_macro: 0.99965
# epoch: 11, passed number of graphs: 288, train running loss: 0.00022 (passed time: 55m 19s)
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00095, rec: 0.99905, prc: 0.99975, f1: 0.99940, f1_macro: 0.99968
# epoch: 11, passed number of graphs: 384, train running loss: 0.00022 (passed time: 55m 57s)
#           acc: 0.99993, fpr: 0.00000, fnr: 0.00100, rec: 0.99900, prc: 0.99995, f1: 0.99947, f1_macro: 0.99972
# epoch: 11, passed number of graphs: 480, train running loss: 0.00022 (passed time: 56m 34s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00065, rec: 0.99935, prc: 0.99980, f1: 0.99957, f1_macro: 0.99977
# epoch: 11, passed number of graphs: 576, train running loss: 0.00022 (passed time: 57m 11s)
#           acc: 0.99991, fpr: 0.00003, fnr: 0.00095, rec: 0.99905, prc: 0.99960, f1: 0.99932, f1_macro: 0.99964
# epoch: 11, passed number of graphs: 672, train running loss: 0.00022 (passed time: 57m 49s)
#           acc: 0.99990, fpr: 0.00003, fnr: 0.00100, rec: 0.99900, prc: 0.99955, f1: 0.99927, f1_macro: 0.99961
# epoch: 11, passed number of graphs: 768, train running loss: 0.00022 (passed time: 58m 26s)
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00090, rec: 0.99910, prc: 0.99975, f1: 0.99942, f1_macro: 0.99969
# Validation --- epoch: 11, loss: 0.00231
#           acc: 0.99948, fpr: 0.00052, fnr: 0.00042, rec: 0.99958, f1: 0.99631, f1_macro: 0.99802, prc: 0.99307
# epoch: 12, passed number of graphs: 96, train running loss: 0.00022 (passed time: 59m 14s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00055, rec: 0.99945, prc: 0.99970, f1: 0.99957, f1_macro: 0.99977
# epoch: 12, passed number of graphs: 192, train running loss: 0.00022 (passed time: 59m 52s)
#           acc: 0.99991, fpr: 0.00002, fnr: 0.00100, rec: 0.99900, prc: 0.99975, f1: 0.99937, f1_macro: 0.99966
# epoch: 12, passed number of graphs: 288, train running loss: 0.00022 (passed time: 1h 0m 30s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00090, rec: 0.99910, prc: 0.99980, f1: 0.99945, f1_macro: 0.99970
# epoch: 12, passed number of graphs: 384, train running loss: 0.00022 (passed time: 1h 1m 8s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00075, rec: 0.99925, prc: 0.99990, f1: 0.99957, f1_macro: 0.99977
# epoch: 12, passed number of graphs: 480, train running loss: 0.00022 (passed time: 1h 1m 46s)
#           acc: 0.99993, fpr: 0.00004, fnr: 0.00055, rec: 0.99945, prc: 0.99950, f1: 0.99947, f1_macro: 0.99972
# epoch: 12, passed number of graphs: 576, train running loss: 0.00022 (passed time: 1h 2m 24s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00060, rec: 0.99940, prc: 0.99965, f1: 0.99952, f1_macro: 0.99974
# epoch: 12, passed number of graphs: 672, train running loss: 0.00022 (passed time: 1h 3m 1s)
#           acc: 0.99990, fpr: 0.00003, fnr: 0.00115, rec: 0.99885, prc: 0.99965, f1: 0.99925, f1_macro: 0.99960
# epoch: 12, passed number of graphs: 768, train running loss: 0.00022 (passed time: 1h 3m 39s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00060, rec: 0.99940, prc: 0.99960, f1: 0.99950, f1_macro: 0.99973
# Validation --- epoch: 12, loss: 0.00043
#           acc: 0.99991, fpr: 0.00005, fnr: 0.00065, rec: 0.99935, f1: 0.99932, f1_macro: 0.99963, prc: 0.99929
# Better model saved at ./saved_models/GIN_11: 0.9993198140832221.pt.
# epoch: 13, passed number of graphs: 96, train running loss: 0.00021 (passed time: 1h 4m 26s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00065, rec: 0.99935, prc: 0.99960, f1: 0.99947, f1_macro: 0.99972
# epoch: 13, passed number of graphs: 192, train running loss: 0.00021 (passed time: 1h 5m 4s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00090, rec: 0.99910, prc: 0.99990, f1: 0.99950, f1_macro: 0.99973
# epoch: 13, passed number of graphs: 288, train running loss: 0.00021 (passed time: 1h 5m 41s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00110, rec: 0.99890, prc: 0.99985, f1: 0.99937, f1_macro: 0.99966
# epoch: 13, passed number of graphs: 384, train running loss: 0.00021 (passed time: 1h 6m 19s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00080, rec: 0.99920, prc: 0.99985, f1: 0.99952, f1_macro: 0.99974
# epoch: 13, passed number of graphs: 480, train running loss: 0.00021 (passed time: 1h 6m 55s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00060, rec: 0.99940, prc: 0.99960, f1: 0.99950, f1_macro: 0.99973
# epoch: 13, passed number of graphs: 576, train running loss: 0.00021 (passed time: 1h 7m 33s)
#           acc: 0.99991, fpr: 0.00004, fnr: 0.00070, rec: 0.99930, prc: 0.99945, f1: 0.99937, f1_macro: 0.99966
# epoch: 13, passed number of graphs: 672, train running loss: 0.00021 (passed time: 1h 8m 9s)
#           acc: 0.99990, fpr: 0.00002, fnr: 0.00120, rec: 0.99880, prc: 0.99970, f1: 0.99925, f1_macro: 0.99960
# epoch: 13, passed number of graphs: 768, train running loss: 0.00021 (passed time: 1h 8m 46s)
#           acc: 0.99991, fpr: 0.00002, fnr: 0.00105, rec: 0.99895, prc: 0.99975, f1: 0.99935, f1_macro: 0.99965
# Validation --- epoch: 13, loss: 0.00072
#           acc: 0.99983, fpr: 0.00008, fnr: 0.00141, rec: 0.99859, f1: 0.99877, f1_macro: 0.99934, prc: 0.99895
# epoch: 14, passed number of graphs: 96, train running loss: 0.00021 (passed time: 1h 9m 32s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00075, rec: 0.99925, prc: 0.99960, f1: 0.99942, f1_macro: 0.99969
# epoch: 14, passed number of graphs: 192, train running loss: 0.00021 (passed time: 1h 10m 10s)
#           acc: 0.99991, fpr: 0.00002, fnr: 0.00100, rec: 0.99900, prc: 0.99970, f1: 0.99935, f1_macro: 0.99965
# epoch: 14, passed number of graphs: 288, train running loss: 0.00021 (passed time: 1h 10m 47s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00115, rec: 0.99885, prc: 0.99980, f1: 0.99932, f1_macro: 0.99964
# epoch: 14, passed number of graphs: 384, train running loss: 0.00021 (passed time: 1h 11m 26s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00090, rec: 0.99910, prc: 0.99990, f1: 0.99950, f1_macro: 0.99973
# epoch: 14, passed number of graphs: 480, train running loss: 0.00021 (passed time: 1h 12m 4s)
#           acc: 0.99992, fpr: 0.00004, fnr: 0.00060, rec: 0.99940, prc: 0.99950, f1: 0.99945, f1_macro: 0.99970
# epoch: 14, passed number of graphs: 576, train running loss: 0.00021 (passed time: 1h 12m 42s)
#           acc: 0.99991, fpr: 0.00003, fnr: 0.00080, rec: 0.99920, prc: 0.99955, f1: 0.99937, f1_macro: 0.99966
# epoch: 14, passed number of graphs: 672, train running loss: 0.00025 (passed time: 1h 13m 19s)
#           acc: 0.99975, fpr: 0.00006, fnr: 0.00280, rec: 0.99720, prc: 0.99920, f1: 0.99820, f1_macro: 0.99903
# epoch: 14, passed number of graphs: 768, train running loss: 0.00026 (passed time: 1h 13m 57s)
#           acc: 0.99990, fpr: 0.00003, fnr: 0.00115, rec: 0.99885, prc: 0.99965, f1: 0.99925, f1_macro: 0.99960
# Validation --- epoch: 14, loss: 0.00056
#           acc: 0.99988, fpr: 0.00009, fnr: 0.00054, rec: 0.99946, f1: 0.99915, f1_macro: 0.99954, prc: 0.99884
# epoch: 15, passed number of graphs: 96, train running loss: 0.00027 (passed time: 1h 14m 43s)
#           acc: 0.99991, fpr: 0.00003, fnr: 0.00080, rec: 0.99920, prc: 0.99955, f1: 0.99937, f1_macro: 0.99966
# epoch: 15, passed number of graphs: 192, train running loss: 0.00027 (passed time: 1h 15m 21s)
#           acc: 0.99990, fpr: 0.00002, fnr: 0.00115, rec: 0.99885, prc: 0.99975, f1: 0.99930, f1_macro: 0.99962
# epoch: 15, passed number of graphs: 288, train running loss: 0.00026 (passed time: 1h 15m 57s)
#           acc: 0.99990, fpr: 0.00002, fnr: 0.00115, rec: 0.99885, prc: 0.99975, f1: 0.99930, f1_macro: 0.99962
# epoch: 15, passed number of graphs: 384, train running loss: 0.00026 (passed time: 1h 16m 34s)
#           acc: 0.99990, fpr: 0.00002, fnr: 0.00115, rec: 0.99885, prc: 0.99975, f1: 0.99930, f1_macro: 0.99962
# epoch: 15, passed number of graphs: 480, train running loss: 0.00026 (passed time: 1h 17m 10s)
#           acc: 0.99991, fpr: 0.00003, fnr: 0.00085, rec: 0.99915, prc: 0.99955, f1: 0.99935, f1_macro: 0.99965
# epoch: 15, passed number of graphs: 576, train running loss: 0.00026 (passed time: 1h 17m 47s)
#           acc: 0.99990, fpr: 0.00004, fnr: 0.00080, rec: 0.99920, prc: 0.99940, f1: 0.99930, f1_macro: 0.99962
# epoch: 15, passed number of graphs: 672, train running loss: 0.00026 (passed time: 1h 18m 23s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00120, rec: 0.99880, prc: 0.99950, f1: 0.99915, f1_macro: 0.99954
# epoch: 15, passed number of graphs: 768, train running loss: 0.00025 (passed time: 1h 19m 0s)
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00080, rec: 0.99920, prc: 0.99970, f1: 0.99945, f1_macro: 0.99970
# Validation --- epoch: 15, loss: 0.00041
#           acc: 0.99991, fpr: 0.00002, fnr: 0.00098, rec: 0.99902, f1: 0.99938, f1_macro: 0.99967, prc: 0.99974
# Better model saved at ./saved_models/GIN_14: 0.9993830903434858.pt.
# epoch: 16, passed number of graphs: 96, train running loss: 0.00024 (passed time: 1h 19m 47s)
#           acc: 0.99991, fpr: 0.00003, fnr: 0.00085, rec: 0.99915, prc: 0.99960, f1: 0.99937, f1_macro: 0.99966
# epoch: 16, passed number of graphs: 192, train running loss: 0.00024 (passed time: 1h 20m 25s)
#           acc: 0.99989, fpr: 0.00002, fnr: 0.00125, rec: 0.99875, prc: 0.99970, f1: 0.99922, f1_macro: 0.99958
# epoch: 16, passed number of graphs: 288, train running loss: 0.00024 (passed time: 1h 21m 2s)
#           acc: 0.99990, fpr: 0.00002, fnr: 0.00110, rec: 0.99890, prc: 0.99970, f1: 0.99930, f1_macro: 0.99962
# epoch: 16, passed number of graphs: 384, train running loss: 0.00024 (passed time: 1h 21m 39s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00090, rec: 0.99910, prc: 0.99990, f1: 0.99950, f1_macro: 0.99973
# epoch: 16, passed number of graphs: 480, train running loss: 0.00024 (passed time: 1h 22m 17s)
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00095, rec: 0.99905, prc: 0.99975, f1: 0.99940, f1_macro: 0.99968
# epoch: 16, passed number of graphs: 576, train running loss: 0.00024 (passed time: 1h 22m 54s)
#           acc: 0.99990, fpr: 0.00004, fnr: 0.00090, rec: 0.99910, prc: 0.99945, f1: 0.99927, f1_macro: 0.99961
# epoch: 16, passed number of graphs: 672, train running loss: 0.00024 (passed time: 1h 23m 31s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00120, rec: 0.99880, prc: 0.99950, f1: 0.99915, f1_macro: 0.99954
# epoch: 16, passed number of graphs: 768, train running loss: 0.00024 (passed time: 1h 24m 8s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00090, rec: 0.99910, prc: 0.99985, f1: 0.99947, f1_macro: 0.99972
# Validation --- epoch: 16, loss: 0.00039
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00094, rec: 0.99906, f1: 0.99940, f1_macro: 0.99968, prc: 0.99974
# Better model saved at ./saved_models/GIN_15: 0.9994018612438298.pt.
# epoch: 17, passed number of graphs: 96, train running loss: 0.00023 (passed time: 1h 24m 55s)
#           acc: 0.99991, fpr: 0.00003, fnr: 0.00085, rec: 0.99915, prc: 0.99955, f1: 0.99935, f1_macro: 0.99965
# epoch: 17, passed number of graphs: 192, train running loss: 0.00023 (passed time: 1h 25m 32s)
#           acc: 0.99990, fpr: 0.00003, fnr: 0.00105, rec: 0.99895, prc: 0.99960, f1: 0.99927, f1_macro: 0.99961
# epoch: 17, passed number of graphs: 288, train running loss: 0.00023 (passed time: 1h 26m 8s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00095, rec: 0.99905, prc: 0.99985, f1: 0.99945, f1_macro: 0.99970
# epoch: 17, passed number of graphs: 384, train running loss: 0.00023 (passed time: 1h 26m 45s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00110, rec: 0.99890, prc: 0.99985, f1: 0.99937, f1_macro: 0.99966
# epoch: 17, passed number of graphs: 480, train running loss: 0.00023 (passed time: 1h 27m 22s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00075, rec: 0.99925, prc: 0.99970, f1: 0.99947, f1_macro: 0.99972
# epoch: 17, passed number of graphs: 576, train running loss: 0.00023 (passed time: 1h 27m 59s)
#           acc: 0.99991, fpr: 0.00004, fnr: 0.00075, rec: 0.99925, prc: 0.99950, f1: 0.99937, f1_macro: 0.99966
# epoch: 17, passed number of graphs: 672, train running loss: 0.00023 (passed time: 1h 28m 36s)
#           acc: 0.99991, fpr: 0.00002, fnr: 0.00105, rec: 0.99895, prc: 0.99970, f1: 0.99932, f1_macro: 0.99964
# epoch: 17, passed number of graphs: 768, train running loss: 0.00023 (passed time: 1h 29m 14s)
#           acc: 0.99990, fpr: 0.00002, fnr: 0.00110, rec: 0.99890, prc: 0.99970, f1: 0.99930, f1_macro: 0.99962
# Validation --- epoch: 17, loss: 0.00039
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00103, rec: 0.99897, f1: 0.99939, f1_macro: 0.99967, prc: 0.99981
# epoch: 18, passed number of graphs: 96, train running loss: 0.00022 (passed time: 1h 30m 1s)
#           acc: 0.99991, fpr: 0.00005, fnr: 0.00060, rec: 0.99940, prc: 0.99935, f1: 0.99938, f1_macro: 0.99966
# epoch: 18, passed number of graphs: 192, train running loss: 0.00022 (passed time: 1h 30m 39s)
#           acc: 0.99990, fpr: 0.00002, fnr: 0.00120, rec: 0.99880, prc: 0.99970, f1: 0.99925, f1_macro: 0.99960
# epoch: 18, passed number of graphs: 288, train running loss: 0.00022 (passed time: 1h 31m 17s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00100, rec: 0.99900, prc: 0.99985, f1: 0.99942, f1_macro: 0.99969
# epoch: 18, passed number of graphs: 384, train running loss: 0.00022 (passed time: 1h 31m 55s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00130, rec: 0.99870, prc: 0.99985, f1: 0.99927, f1_macro: 0.99961
# epoch: 18, passed number of graphs: 480, train running loss: 0.00022 (passed time: 1h 32m 33s)
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00085, rec: 0.99915, prc: 0.99975, f1: 0.99945, f1_macro: 0.99970
# epoch: 18, passed number of graphs: 576, train running loss: 0.00022 (passed time: 1h 33m 11s)
#           acc: 0.99991, fpr: 0.00004, fnr: 0.00075, rec: 0.99925, prc: 0.99945, f1: 0.99935, f1_macro: 0.99965
# epoch: 18, passed number of graphs: 672, train running loss: 0.00022 (passed time: 1h 33m 49s)
#           acc: 0.99991, fpr: 0.00003, fnr: 0.00100, rec: 0.99900, prc: 0.99965, f1: 0.99932, f1_macro: 0.99964
# epoch: 18, passed number of graphs: 768, train running loss: 0.00022 (passed time: 1h 34m 26s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00075, rec: 0.99925, prc: 0.99970, f1: 0.99947, f1_macro: 0.99972
# Validation --- epoch: 18, loss: 0.00039
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00108, rec: 0.99893, f1: 0.99938, f1_macro: 0.99966, prc: 0.99983
# epoch: 19, passed number of graphs: 96, train running loss: 0.00022 (passed time: 1h 35m 13s)
#           acc: 0.99993, fpr: 0.00004, fnr: 0.00055, rec: 0.99945, prc: 0.99950, f1: 0.99947, f1_macro: 0.99972
# epoch: 19, passed number of graphs: 192, train running loss: 0.00022 (passed time: 1h 35m 51s)
#           acc: 0.99991, fpr: 0.00002, fnr: 0.00105, rec: 0.99895, prc: 0.99975, f1: 0.99935, f1_macro: 0.99965
# epoch: 19, passed number of graphs: 288, train running loss: 0.00022 (passed time: 1h 36m 29s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00100, rec: 0.99900, prc: 0.99980, f1: 0.99940, f1_macro: 0.99968
# epoch: 19, passed number of graphs: 384, train running loss: 0.00022 (passed time: 1h 37m 6s)
#           acc: 0.99991, fpr: 0.00002, fnr: 0.00095, rec: 0.99905, prc: 0.99975, f1: 0.99940, f1_macro: 0.99968
# epoch: 19, passed number of graphs: 480, train running loss: 0.00022 (passed time: 1h 37m 44s)
#           acc: 0.99990, fpr: 0.00005, fnr: 0.00080, rec: 0.99920, prc: 0.99940, f1: 0.99930, f1_macro: 0.99962
# epoch: 19, passed number of graphs: 576, train running loss: 0.00022 (passed time: 1h 38m 21s)
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00080, rec: 0.99920, prc: 0.99970, f1: 0.99945, f1_macro: 0.99970
# epoch: 19, passed number of graphs: 672, train running loss: 0.00022 (passed time: 1h 38m 58s)
#           acc: 0.99991, fpr: 0.00002, fnr: 0.00100, rec: 0.99900, prc: 0.99970, f1: 0.99935, f1_macro: 0.99965
# epoch: 19, passed number of graphs: 768, train running loss: 0.00022 (passed time: 1h 39m 36s)
#           acc: 0.99991, fpr: 0.00002, fnr: 0.00105, rec: 0.99895, prc: 0.99975, f1: 0.99935, f1_macro: 0.99965
# Validation --- epoch: 19, loss: 0.00037
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00096, rec: 0.99904, f1: 0.99941, f1_macro: 0.99968, prc: 0.99978
# Better model saved at ./saved_models/GIN_18: 0.9994112153419655.pt.
# epoch: 20, passed number of graphs: 96, train running loss: 0.00021 (passed time: 1h 40m 24s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00060, rec: 0.99940, prc: 0.99960, f1: 0.99950, f1_macro: 0.99973
# epoch: 20, passed number of graphs: 192, train running loss: 0.00021 (passed time: 1h 41m 2s)
#           acc: 0.99990, fpr: 0.00003, fnr: 0.00115, rec: 0.99885, prc: 0.99965, f1: 0.99925, f1_macro: 0.99960
# epoch: 20, passed number of graphs: 288, train running loss: 0.00021 (passed time: 1h 41m 39s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00085, rec: 0.99915, prc: 0.99985, f1: 0.99950, f1_macro: 0.99973
# epoch: 20, passed number of graphs: 384, train running loss: 0.00021 (passed time: 1h 42m 17s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00105, rec: 0.99895, prc: 0.99990, f1: 0.99942, f1_macro: 0.99969
# epoch: 20, passed number of graphs: 480, train running loss: 0.00021 (passed time: 1h 42m 54s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00060, rec: 0.99940, prc: 0.99960, f1: 0.99950, f1_macro: 0.99973
# epoch: 20, passed number of graphs: 576, train running loss: 0.00021 (passed time: 1h 43m 31s)
#           acc: 0.99989, fpr: 0.00005, fnr: 0.00090, rec: 0.99910, prc: 0.99935, f1: 0.99922, f1_macro: 0.99958
# epoch: 20, passed number of graphs: 672, train running loss: 0.00021 (passed time: 1h 44m 9s)
#           acc: 0.99989, fpr: 0.00003, fnr: 0.00115, rec: 0.99885, prc: 0.99955, f1: 0.99920, f1_macro: 0.99957
# epoch: 20, passed number of graphs: 768, train running loss: 0.00021 (passed time: 1h 44m 46s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00085, rec: 0.99915, prc: 0.99980, f1: 0.99947, f1_macro: 0.99972
# Validation --- epoch: 20, loss: 0.00037
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00091, rec: 0.99909, f1: 0.99943, f1_macro: 0.99969, prc: 0.99977
# Better model saved at ./saved_models/GIN_19: 0.9994299879641176.pt.
# epoch: 21, passed number of graphs: 96, train running loss: 0.00021 (passed time: 1h 45m 33s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00055, rec: 0.99945, prc: 0.99960, f1: 0.99952, f1_macro: 0.99974
# epoch: 21, passed number of graphs: 192, train running loss: 0.00021 (passed time: 1h 46m 11s)
#           acc: 0.99990, fpr: 0.00003, fnr: 0.00105, rec: 0.99895, prc: 0.99965, f1: 0.99930, f1_macro: 0.99962
# epoch: 21, passed number of graphs: 288, train running loss: 0.00021 (passed time: 1h 46m 48s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00085, rec: 0.99915, prc: 0.99980, f1: 0.99947, f1_macro: 0.99972
# epoch: 21, passed number of graphs: 384, train running loss: 0.00021 (passed time: 1h 47m 25s)
#           acc: 0.99991, fpr: 0.00002, fnr: 0.00100, rec: 0.99900, prc: 0.99980, f1: 0.99940, f1_macro: 0.99968
# epoch: 21, passed number of graphs: 480, train running loss: 0.00021 (passed time: 1h 48m 2s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00075, rec: 0.99925, prc: 0.99960, f1: 0.99942, f1_macro: 0.99969
# epoch: 21, passed number of graphs: 576, train running loss: 0.00021 (passed time: 1h 48m 39s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00075, rec: 0.99925, prc: 0.99955, f1: 0.99940, f1_macro: 0.99968
# epoch: 21, passed number of graphs: 672, train running loss: 0.00021 (passed time: 1h 49m 16s)
#           acc: 0.99990, fpr: 0.00003, fnr: 0.00105, rec: 0.99895, prc: 0.99960, f1: 0.99927, f1_macro: 0.99961
# epoch: 21, passed number of graphs: 768, train running loss: 0.00021 (passed time: 1h 49m 53s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00080, rec: 0.99920, prc: 0.99985, f1: 0.99952, f1_macro: 0.99974
# Validation --- epoch: 21, loss: 0.02784
#           acc: 0.99498, fpr: 0.00538, fnr: 0.00020, rec: 0.99980, f1: 0.96521, f1_macro: 0.98126, prc: 0.93296
# epoch: 22, passed number of graphs: 96, train running loss: 0.00021 (passed time: 1h 50m 40s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00055, rec: 0.99945, prc: 0.99965, f1: 0.99955, f1_macro: 0.99976
# epoch: 22, passed number of graphs: 192, train running loss: 0.00021 (passed time: 1h 51m 17s)
#           acc: 0.99991, fpr: 0.00003, fnr: 0.00100, rec: 0.99900, prc: 0.99965, f1: 0.99932, f1_macro: 0.99964
# ...
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00090, rec: 0.99910, prc: 0.99980, f1: 0.99945, f1_macro: 0.99970
# epoch: 42, passed number of graphs: 384, train running loss: 0.00019 (passed time: 3h 34m 56s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00065, rec: 0.99935, prc: 0.99980, f1: 0.99957, f1_macro: 0.99977
# epoch: 42, passed number of graphs: 480, train running loss: 0.00019 (passed time: 3h 35m 33s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00055, rec: 0.99945, prc: 0.99975, f1: 0.99960, f1_macro: 0.99978
# epoch: 42, passed number of graphs: 576, train running loss: 0.00019 (passed time: 3h 36m 10s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00065, rec: 0.99935, prc: 0.99965, f1: 0.99950, f1_macro: 0.99973
# epoch: 42, passed number of graphs: 672, train running loss: 0.00019 (passed time: 3h 36m 47s)
#           acc: 0.99991, fpr: 0.00003, fnr: 0.00080, rec: 0.99920, prc: 0.99955, f1: 0.99937, f1_macro: 0.99966
# epoch: 42, passed number of graphs: 768, train running loss: 0.00019 (passed time: 3h 37m 24s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00060, rec: 0.99940, prc: 0.99980, f1: 0.99960, f1_macro: 0.99979
# Validation --- epoch: 42, loss: 0.00031
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00072, rec: 0.99928, f1: 0.99952, f1_macro: 0.99974, prc: 0.99976
# epoch: 43, passed number of graphs: 96, train running loss: 0.00018 (passed time: 3h 38m 10s)
#           acc: 0.99993, fpr: 0.00004, fnr: 0.00050, rec: 0.99950, prc: 0.99950, f1: 0.99950, f1_macro: 0.99973
# epoch: 43, passed number of graphs: 192, train running loss: 0.00019 (passed time: 3h 38m 47s)
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00090, rec: 0.99910, prc: 0.99980, f1: 0.99945, f1_macro: 0.99970
# epoch: 43, passed number of graphs: 288, train running loss: 0.00019 (passed time: 3h 39m 24s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00085, rec: 0.99915, prc: 0.99985, f1: 0.99950, f1_macro: 0.99973
# epoch: 43, passed number of graphs: 384, train running loss: 0.00018 (passed time: 3h 40m 1s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00075, rec: 0.99925, prc: 0.99965, f1: 0.99945, f1_macro: 0.99970
# epoch: 43, passed number of graphs: 480, train running loss: 0.00019 (passed time: 3h 40m 38s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00070, rec: 0.99930, prc: 0.99985, f1: 0.99957, f1_macro: 0.99977
# epoch: 43, passed number of graphs: 576, train running loss: 0.00019 (passed time: 3h 41m 15s)
#           acc: 0.99992, fpr: 0.00004, fnr: 0.00065, rec: 0.99935, prc: 0.99950, f1: 0.99942, f1_macro: 0.99969
# epoch: 43, passed number of graphs: 672, train running loss: 0.00019 (passed time: 3h 41m 52s)
#           acc: 0.99991, fpr: 0.00004, fnr: 0.00085, rec: 0.99915, prc: 0.99950, f1: 0.99932, f1_macro: 0.99964
# epoch: 43, passed number of graphs: 768, train running loss: 0.00019 (passed time: 3h 42m 28s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00060, rec: 0.99940, prc: 0.99980, f1: 0.99960, f1_macro: 0.99979
# Validation --- epoch: 43, loss: 0.00032
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00075, rec: 0.99925, f1: 0.99950, f1_macro: 0.99973, prc: 0.99975
# epoch: 44, passed number of graphs: 96, train running loss: 0.00018 (passed time: 3h 43m 15s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00055, rec: 0.99945, prc: 0.99965, f1: 0.99955, f1_macro: 0.99976
# epoch: 44, passed number of graphs: 192, train running loss: 0.00019 (passed time: 3h 43m 51s)
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00080, rec: 0.99920, prc: 0.99970, f1: 0.99945, f1_macro: 0.99970
# epoch: 44, passed number of graphs: 288, train running loss: 0.00019 (passed time: 3h 44m 28s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00075, rec: 0.99925, prc: 0.99985, f1: 0.99955, f1_macro: 0.99976
# epoch: 44, passed number of graphs: 384, train running loss: 0.00018 (passed time: 3h 45m 4s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00065, rec: 0.99935, prc: 0.99980, f1: 0.99957, f1_macro: 0.99977
# epoch: 44, passed number of graphs: 480, train running loss: 0.00019 (passed time: 3h 45m 41s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00070, rec: 0.99930, prc: 0.99980, f1: 0.99955, f1_macro: 0.99976
# epoch: 44, passed number of graphs: 576, train running loss: 0.00019 (passed time: 3h 46m 17s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00080, rec: 0.99920, prc: 0.99965, f1: 0.99942, f1_macro: 0.99969
# epoch: 44, passed number of graphs: 672, train running loss: 0.00019 (passed time: 3h 46m 53s)
#           acc: 0.99990, fpr: 0.00005, fnr: 0.00080, rec: 0.99920, prc: 0.99935, f1: 0.99927, f1_macro: 0.99961
# epoch: 44, passed number of graphs: 768, train running loss: 0.00019 (passed time: 3h 47m 29s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00045, rec: 0.99955, prc: 0.99980, f1: 0.99967, f1_macro: 0.99983
# Validation --- epoch: 44, loss: 0.00031
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00074, rec: 0.99926, f1: 0.99952, f1_macro: 0.99974, prc: 0.99977
# epoch: 45, passed number of graphs: 96, train running loss: 0.00018 (passed time: 3h 48m 16s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00070, rec: 0.99930, prc: 0.99960, f1: 0.99945, f1_macro: 0.99970
# epoch: 45, passed number of graphs: 192, train running loss: 0.00019 (passed time: 3h 48m 53s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00070, rec: 0.99930, prc: 0.99980, f1: 0.99955, f1_macro: 0.99976
# epoch: 45, passed number of graphs: 288, train running loss: 0.00019 (passed time: 3h 49m 30s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00090, rec: 0.99910, prc: 0.99980, f1: 0.99945, f1_macro: 0.99970
# epoch: 45, passed number of graphs: 384, train running loss: 0.00018 (passed time: 3h 50m 7s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00060, rec: 0.99940, prc: 0.99980, f1: 0.99960, f1_macro: 0.99978
# epoch: 45, passed number of graphs: 480, train running loss: 0.00018 (passed time: 3h 50m 45s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00080, rec: 0.99920, prc: 0.99980, f1: 0.99950, f1_macro: 0.99973
# epoch: 45, passed number of graphs: 576, train running loss: 0.00019 (passed time: 3h 51m 22s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00055, rec: 0.99945, prc: 0.99970, f1: 0.99957, f1_macro: 0.99977
# epoch: 45, passed number of graphs: 672, train running loss: 0.00019 (passed time: 3h 51m 59s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00075, rec: 0.99925, prc: 0.99970, f1: 0.99947, f1_macro: 0.99972
# epoch: 45, passed number of graphs: 768, train running loss: 0.00019 (passed time: 3h 52m 36s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00050, rec: 0.99950, prc: 0.99975, f1: 0.99962, f1_macro: 0.99980
# Validation --- epoch: 45, loss: 0.00031
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00071, rec: 0.99929, f1: 0.99952, f1_macro: 0.99974, prc: 0.99975
# epoch: 46, passed number of graphs: 96, train running loss: 0.00019 (passed time: 3h 53m 23s)
#           acc: 0.99992, fpr: 0.00004, fnr: 0.00070, rec: 0.99930, prc: 0.99950, f1: 0.99940, f1_macro: 0.99968
# epoch: 46, passed number of graphs: 192, train running loss: 0.00019 (passed time: 3h 54m 0s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00080, rec: 0.99920, prc: 0.99975, f1: 0.99947, f1_macro: 0.99972
# epoch: 46, passed number of graphs: 288, train running loss: 0.00018 (passed time: 3h 54m 36s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00075, rec: 0.99925, prc: 0.99980, f1: 0.99952, f1_macro: 0.99974
# epoch: 46, passed number of graphs: 384, train running loss: 0.00018 (passed time: 3h 55m 13s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00070, rec: 0.99930, prc: 0.99975, f1: 0.99952, f1_macro: 0.99974
# epoch: 46, passed number of graphs: 480, train running loss: 0.00018 (passed time: 3h 55m 50s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00055, rec: 0.99945, prc: 0.99970, f1: 0.99957, f1_macro: 0.99977
# epoch: 46, passed number of graphs: 576, train running loss: 0.00019 (passed time: 3h 56m 27s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00065, rec: 0.99935, prc: 0.99970, f1: 0.99952, f1_macro: 0.99974
# epoch: 46, passed number of graphs: 672, train running loss: 0.00018 (passed time: 3h 57m 3s)
#           acc: 0.99991, fpr: 0.00004, fnr: 0.00085, rec: 0.99915, prc: 0.99950, f1: 0.99932, f1_macro: 0.99964
# epoch: 46, passed number of graphs: 768, train running loss: 0.00018 (passed time: 3h 57m 40s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00060, rec: 0.99940, prc: 0.99955, f1: 0.99947, f1_macro: 0.99972
# Validation --- epoch: 46, loss: 0.00031
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00073, rec: 0.99927, f1: 0.99952, f1_macro: 0.99974, prc: 0.99976
# epoch: 47, passed number of graphs: 96, train running loss: 0.00018 (passed time: 3h 58m 27s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00055, rec: 0.99945, prc: 0.99965, f1: 0.99955, f1_macro: 0.99976
# epoch: 47, passed number of graphs: 192, train running loss: 0.00018 (passed time: 3h 59m 4s)
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00085, rec: 0.99915, prc: 0.99975, f1: 0.99945, f1_macro: 0.99970
# epoch: 47, passed number of graphs: 288, train running loss: 0.00018 (passed time: 3h 59m 41s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00075, rec: 0.99925, prc: 0.99980, f1: 0.99952, f1_macro: 0.99974
# epoch: 47, passed number of graphs: 384, train running loss: 0.00018 (passed time: 4h 0m 19s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00065, rec: 0.99935, prc: 0.99980, f1: 0.99957, f1_macro: 0.99977
# epoch: 47, passed number of graphs: 480, train running loss: 0.00018 (passed time: 4h 0m 56s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00080, rec: 0.99920, prc: 0.99975, f1: 0.99947, f1_macro: 0.99972
# epoch: 47, passed number of graphs: 576, train running loss: 0.00018 (passed time: 4h 1m 33s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00080, rec: 0.99920, prc: 0.99960, f1: 0.99940, f1_macro: 0.99968
# epoch: 47, passed number of graphs: 672, train running loss: 0.00018 (passed time: 4h 2m 10s)
#           acc: 0.99991, fpr: 0.00003, fnr: 0.00080, rec: 0.99920, prc: 0.99955, f1: 0.99937, f1_macro: 0.99966
# epoch: 47, passed number of graphs: 768, train running loss: 0.00018 (passed time: 4h 2m 47s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00055, rec: 0.99945, prc: 0.99970, f1: 0.99957, f1_macro: 0.99977
# Validation --- epoch: 47, loss: 0.00031
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00072, rec: 0.99928, f1: 0.99952, f1_macro: 0.99974, prc: 0.99976
# epoch: 48, passed number of graphs: 96, train running loss: 0.00018 (passed time: 4h 3m 34s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00065, rec: 0.99935, prc: 0.99970, f1: 0.99952, f1_macro: 0.99974
# epoch: 48, passed number of graphs: 192, train running loss: 0.00019 (passed time: 4h 4m 11s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00070, rec: 0.99930, prc: 0.99970, f1: 0.99950, f1_macro: 0.99973
# epoch: 48, passed number of graphs: 288, train running loss: 0.00019 (passed time: 4h 4m 48s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00070, rec: 0.99930, prc: 0.99980, f1: 0.99955, f1_macro: 0.99976
# epoch: 48, passed number of graphs: 384, train running loss: 0.00018 (passed time: 4h 5m 25s)
#           acc: 0.99995, fpr: 0.00000, fnr: 0.00065, rec: 0.99935, prc: 0.99995, f1: 0.99965, f1_macro: 0.99981
# epoch: 48, passed number of graphs: 480, train running loss: 0.00018 (passed time: 4h 6m 2s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00070, rec: 0.99930, prc: 0.99980, f1: 0.99955, f1_macro: 0.99976
# epoch: 48, passed number of graphs: 576, train running loss: 0.00018 (passed time: 4h 6m 39s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00070, rec: 0.99930, prc: 0.99955, f1: 0.99942, f1_macro: 0.99969
# epoch: 48, passed number of graphs: 672, train running loss: 0.00018 (passed time: 4h 7m 15s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00075, rec: 0.99925, prc: 0.99955, f1: 0.99940, f1_macro: 0.99968
# epoch: 48, passed number of graphs: 768, train running loss: 0.00018 (passed time: 4h 7m 52s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00070, rec: 0.99930, prc: 0.99965, f1: 0.99947, f1_macro: 0.99972
# Validation --- epoch: 48, loss: 0.00031
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00073, rec: 0.99928, f1: 0.99952, f1_macro: 0.99974, prc: 0.99977
# Better model saved at ./saved_models/GIN_47: 0.9995212230501295.pt.
# epoch: 49, passed number of graphs: 96, train running loss: 0.00018 (passed time: 4h 8m 39s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00065, rec: 0.99935, prc: 0.99965, f1: 0.99950, f1_macro: 0.99973
# epoch: 49, passed number of graphs: 192, train running loss: 0.00018 (passed time: 4h 9m 16s)
#           acc: 0.99991, fpr: 0.00002, fnr: 0.00100, rec: 0.99900, prc: 0.99975, f1: 0.99937, f1_macro: 0.99966
# epoch: 49, passed number of graphs: 288, train running loss: 0.00018 (passed time: 4h 9m 53s)
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00090, rec: 0.99910, prc: 0.99975, f1: 0.99942, f1_macro: 0.99969
# epoch: 49, passed number of graphs: 384, train running loss: 0.00018 (passed time: 4h 10m 30s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00080, rec: 0.99920, prc: 0.99985, f1: 0.99952, f1_macro: 0.99974
# epoch: 49, passed number of graphs: 480, train running loss: 0.00018 (passed time: 4h 11m 7s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00075, rec: 0.99925, prc: 0.99975, f1: 0.99950, f1_macro: 0.99973
# epoch: 49, passed number of graphs: 576, train running loss: 0.00018 (passed time: 4h 11m 43s)
#           acc: 0.99992, fpr: 0.00004, fnr: 0.00070, rec: 0.99930, prc: 0.99950, f1: 0.99940, f1_macro: 0.99968
# epoch: 49, passed number of graphs: 672, train running loss: 0.00018 (passed time: 4h 12m 20s)
#           acc: 0.99990, fpr: 0.00004, fnr: 0.00085, rec: 0.99915, prc: 0.99945, f1: 0.99930, f1_macro: 0.99962
# epoch: 49, passed number of graphs: 768, train running loss: 0.00018 (passed time: 4h 12m 57s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00065, rec: 0.99935, prc: 0.99970, f1: 0.99952, f1_macro: 0.99974
# Validation --- epoch: 49, loss: 0.00031
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00072, rec: 0.99928, f1: 0.99952, f1_macro: 0.99974, prc: 0.99976
# epoch: 50, passed number of graphs: 96, train running loss: 0.00018 (passed time: 4h 13m 44s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00060, rec: 0.99940, prc: 0.99955, f1: 0.99947, f1_macro: 0.99972
# epoch: 50, passed number of graphs: 192, train running loss: 0.00018 (passed time: 4h 14m 22s)
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00080, rec: 0.99920, prc: 0.99970, f1: 0.99945, f1_macro: 0.99970
# epoch: 50, passed number of graphs: 288, train running loss: 0.00018 (passed time: 4h 14m 59s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00080, rec: 0.99920, prc: 0.99975, f1: 0.99947, f1_macro: 0.99972
# epoch: 50, passed number of graphs: 384, train running loss: 0.00018 (passed time: 4h 15m 36s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00065, rec: 0.99935, prc: 0.99980, f1: 0.99957, f1_macro: 0.99977
# epoch: 50, passed number of graphs: 480, train running loss: 0.00018 (passed time: 4h 16m 13s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00080, rec: 0.99920, prc: 0.99965, f1: 0.99942, f1_macro: 0.99969
# epoch: 50, passed number of graphs: 576, train running loss: 0.00018 (passed time: 4h 16m 49s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00080, rec: 0.99920, prc: 0.99965, f1: 0.99942, f1_macro: 0.99969
# epoch: 50, passed number of graphs: 672, train running loss: 0.00018 (passed time: 4h 17m 26s)
#           acc: 0.99991, fpr: 0.00003, fnr: 0.00085, rec: 0.99915, prc: 0.99955, f1: 0.99935, f1_macro: 0.99965
# epoch: 50, passed number of graphs: 768, train running loss: 0.00018 (passed time: 4h 18m 2s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00060, rec: 0.99940, prc: 0.99965, f1: 0.99952, f1_macro: 0.99974
# Validation --- epoch: 50, loss: 0.00031
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00073, rec: 0.99927, f1: 0.99952, f1_macro: 0.99974, prc: 0.99976
# ************ best model obtained after epoch 48, saved at ./saved_models/GIN_47: 0.9995212230501295.pt ************
# Testing --- loss: 0.00032
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00073, rec: 0.99927, f1: 0.99950, f1_macro: 0.99973, prc: 0.99974

# %% [markdown]
# 12GIN_MLP_4Layer_Debru
