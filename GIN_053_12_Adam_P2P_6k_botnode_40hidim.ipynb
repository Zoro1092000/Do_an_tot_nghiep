# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/Do_an_tot_nghiep/blob/main/GIN_053_12_Adam_P2P_6k_botnode_40hidim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric==1.4.3
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5
# !pip install torch-optimizer

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter_
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset
import torch_optimizer as optimization


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric==1.4.3 in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.56.3)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (6.2.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.6.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.7.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.18.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.3.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.0.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.12.1+cu113)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.23.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.21.6)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.7.4)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.4)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->torch-geometric==1.4.3) (1.5.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (0.39.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (4.13.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (57.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (4.1.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.4.3) (1.15.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (3.0.9)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (0.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (3.0.4)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2.9.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (1.3.0)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (3.2.2)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2021.11.2)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (7.1.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-optimizer in /usr/local/lib/python3.7/dist-packages (0.3.0)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (1.12.1+cu113)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (0.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->torch-optimizer) (4.1.1)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
            self.num_graphs = 768
        elif split == 'val':
            self.path = self.processed_paths[1]
            self.num_graphs = 96
        elif split == 'test':
            self.path = self.processed_paths[2]
            self.num_graphs = 96

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GINConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_input_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU())))
          else:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU()))) 

        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                add_xr_at = n
            if n == add_xr_at:
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/p2p_6k_botnode'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=True, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
torch.cuda.empty_cache()

# %%
batch_size = 4
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 40
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.0
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    class_weight = torch.Tensor([0.53, 12])
    class_weight = class_weight.cuda(device=0)
    criterion = torch.nn.CrossEntropyLoss(weight=class_weight)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    print(class_weight)
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-97beedc6-1a8b-42fb-a045-b3cc73232d1e.json
# ------------------------------
# ------------------------------
# Tue Nov  1 07:00:51 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GINConv(nn=Sequential(
#       (0): Linear(in_features=1, out_features=40, bias=True)
#       (1): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=40, out_features=40, bias=True)
#       (4): ReLU()
#     ))
#     (1): GINConv(nn=Sequential(
#       (0): Linear(in_features=40, out_features=40, bias=True)
#       (1): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=40, out_features=40, bias=True)
#       (4): ReLU()
#     ))
#     (2): GINConv(nn=Sequential(
#       (0): Linear(in_features=40, out_features=40, bias=True)
#       (1): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=40, out_features=40, bias=True)
#       (4): ReLU()
#     ))
#     (3): GINConv(nn=Sequential(
#       (0): Linear(in_features=40, out_features=40, bias=True)
#       (1): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=40, out_features=40, bias=True)
#       (4): ReLU()
#     ))
#     (4): GINConv(nn=Sequential(
#       (0): Linear(in_features=40, out_features=40, bias=True)
#       (1): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=40, out_features=40, bias=True)
#       (4): ReLU()
#     ))
#     (5): GINConv(nn=Sequential(
#       (0): Linear(in_features=40, out_features=40, bias=True)
#       (1): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=40, out_features=40, bias=True)
#       (4): ReLU()
#     ))
#     (6): GINConv(nn=Sequential(
#       (0): Linear(in_features=40, out_features=40, bias=True)
#       (1): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=40, out_features=40, bias=True)
#       (4): ReLU()
#     ))
#     (7): GINConv(nn=Sequential(
#       (0): Linear(in_features=40, out_features=40, bias=True)
#       (1): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=40, out_features=40, bias=True)
#       (4): ReLU()
#     ))
#     (8): GINConv(nn=Sequential(
#       (0): Linear(in_features=40, out_features=40, bias=True)
#       (1): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=40, out_features=40, bias=True)
#       (4): ReLU()
#     ))
#     (9): GINConv(nn=Sequential(
#       (0): Linear(in_features=40, out_features=40, bias=True)
#       (1): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=40, out_features=40, bias=True)
#       (4): ReLU()
#     ))
#     (10): GINConv(nn=Sequential(
#       (0): Linear(in_features=40, out_features=40, bias=True)
#       (1): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=40, out_features=40, bias=True)
#       (4): ReLU()
#     ))
#     (11): GINConv(nn=Sequential(
#       (0): Linear(in_features=40, out_features=40, bias=True)
#       (1): BatchNorm1d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=40, out_features=40, bias=True)
#       (4): ReLU()
#     ))
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=40, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=40, out_features=2, bias=True)
# )
# Batch size: 4
# tensor([ 0.5300, 12.0000], device='cuda:0')
# epoch: 1, passed number of graphs: 96, train running loss: 0.17231 (passed time: 20s)
#           acc: 0.66135, fpr: 0.33809, fnr: 0.35147, rec: 0.64853, prc: 0.07840, f1: 0.13989, f1_macro: 0.46453
# epoch: 1, passed number of graphs: 192, train running loss: 0.14647 (passed time: 38s)
#           acc: 0.84981, fpr: 0.15549, fnr: 0.02907, rec: 0.97093, prc: 0.21474, f1: 0.35169, f1_macro: 0.63338
# epoch: 1, passed number of graphs: 288, train running loss: 0.11356 (passed time: 55s)
#           acc: 0.97512, fpr: 0.02492, fnr: 0.02382, rec: 0.97618, prc: 0.63253, f1: 0.76765, f1_macro: 0.87725
# epoch: 1, passed number of graphs: 384, train running loss: 0.08999 (passed time: 1m 13s)
#           acc: 0.98992, fpr: 0.01016, fnr: 0.00824, rec: 0.99176, prc: 0.81296, f1: 0.89350, f1_macro: 0.94411
# epoch: 1, passed number of graphs: 480, train running loss: 0.07849 (passed time: 1m 31s)
#           acc: 0.98712, fpr: 0.01332, fnr: 0.00279, rec: 0.99721, prc: 0.76864, f1: 0.86813, f1_macro: 0.93068
# epoch: 1, passed number of graphs: 576, train running loss: 0.06782 (passed time: 1m 49s)
#           acc: 0.99046, fpr: 0.00844, fnr: 0.03426, rec: 0.96574, prc: 0.83569, f1: 0.89602, f1_macro: 0.94551
# epoch: 1, passed number of graphs: 672, train running loss: 0.05990 (passed time: 2m 7s)
#           acc: 0.99238, fpr: 0.00650, fnr: 0.03305, rec: 0.96695, prc: 0.86788, f1: 0.91474, f1_macro: 0.95537
# epoch: 1, passed number of graphs: 768, train running loss: 0.05351 (passed time: 2m 25s)
#           acc: 0.99663, fpr: 0.00343, fnr: 0.00182, rec: 0.99818, prc: 0.92687, f1: 0.96121, f1_macro: 0.97972
# Validation --- epoch: 1, loss: 0.03077
#           f1: 0.66477, fnr: 0.47524, f1_macro: 0.82975, fpr: 0.00013, acc: 0.98964, prc: 0.99080, rec: 0.52476
# Better model saved at ./saved_models/GIN_0: 0.6647710410899228.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.00722 (passed time: 3m 25s)
#           acc: 0.99113, fpr: 0.00925, fnr: 0.00024, rec: 0.99976, prc: 0.82742, f1: 0.90546, f1_macro: 0.95041
# epoch: 2, passed number of graphs: 192, train running loss: 0.00748 (passed time: 3m 43s)
#           acc: 0.99595, fpr: 0.00208, fnr: 0.04902, rec: 0.95098, prc: 0.95252, f1: 0.95175, f1_macro: 0.97482
# epoch: 2, passed number of graphs: 288, train running loss: 0.00749 (passed time: 4m 1s)
#           acc: 0.97938, fpr: 0.02140, fnr: 0.00294, rec: 0.99706, prc: 0.67191, f1: 0.80281, f1_macro: 0.89597
# epoch: 2, passed number of graphs: 384, train running loss: 0.00965 (passed time: 4m 19s)
#           acc: 0.99140, fpr: 0.00885, fnr: 0.00299, rec: 0.99701, prc: 0.83383, f1: 0.90815, f1_macro: 0.95182
# epoch: 2, passed number of graphs: 480, train running loss: 0.01035 (passed time: 4m 37s)
#           acc: 0.99091, fpr: 0.00939, fnr: 0.00229, rec: 0.99771, prc: 0.82499, f1: 0.90317, f1_macro: 0.94920
# epoch: 2, passed number of graphs: 576, train running loss: 0.01042 (passed time: 4m 55s)
#           acc: 0.99384, fpr: 0.00483, fnr: 0.03621, rec: 0.96379, prc: 0.89880, f1: 0.93016, f1_macro: 0.96347
# epoch: 2, passed number of graphs: 672, train running loss: 0.01026 (passed time: 5m 13s)
#           acc: 0.99621, fpr: 0.00258, fnr: 0.03130, rec: 0.96870, prc: 0.94318, f1: 0.95577, f1_macro: 0.97689
# epoch: 2, passed number of graphs: 768, train running loss: 0.00988 (passed time: 5m 31s)
#           acc: 0.99756, fpr: 0.00253, fnr: 0.00033, rec: 0.99967, prc: 0.94520, f1: 0.97167, f1_macro: 0.98520
# Validation --- epoch: 2, loss: 0.01116
#           f1: 0.96894, fnr: 0.03642, f1_macro: 0.98414, fpr: 0.00053, acc: 0.99870, prc: 0.97747, rec: 0.96358
# Better model saved at ./saved_models/GIN_1: 0.9689368954295715.pt.
# epoch: 3, passed number of graphs: 96, train running loss: 0.00652 (passed time: 6m 11s)
#           acc: 0.99893, fpr: 0.00107, fnr: 0.00102, rec: 0.99898, prc: 0.97639, f1: 0.98756, f1_macro: 0.99350
# epoch: 3, passed number of graphs: 192, train running loss: 0.00690 (passed time: 6m 30s)
#           acc: 0.98814, fpr: 0.01025, fnr: 0.04856, rec: 0.95144, prc: 0.80259, f1: 0.87070, f1_macro: 0.93224
# epoch: 3, passed number of graphs: 288, train running loss: 0.00675 (passed time: 6m 48s)
#           acc: 0.99561, fpr: 0.00454, fnr: 0.00091, rec: 0.99909, prc: 0.90621, f1: 0.95038, f1_macro: 0.97404
# epoch: 3, passed number of graphs: 384, train running loss: 0.00624 (passed time: 7m 6s)
#           acc: 0.99936, fpr: 0.00065, fnr: 0.00045, rec: 0.99955, prc: 0.98556, f1: 0.99251, f1_macro: 0.99609
# epoch: 3, passed number of graphs: 480, train running loss: 0.00697 (passed time: 7m 24s)
#           acc: 0.99951, fpr: 0.00045, fnr: 0.00154, rec: 0.99846, prc: 0.99005, f1: 0.99423, f1_macro: 0.99699
# epoch: 3, passed number of graphs: 576, train running loss: 0.00909 (passed time: 7m 42s)
#           acc: 0.98443, fpr: 0.01181, fnr: 0.09996, rec: 0.90004, prc: 0.77211, f1: 0.83118, f1_macro: 0.91151
# epoch: 3, passed number of graphs: 672, train running loss: 0.01056 (passed time: 8m 0s)
#           acc: 0.98883, fpr: 0.01033, fnr: 0.03020, rec: 0.96980, prc: 0.80561, f1: 0.88011, f1_macro: 0.93713
# epoch: 3, passed number of graphs: 768, train running loss: 0.01060 (passed time: 8m 18s)
#           acc: 0.98562, fpr: 0.01499, fnr: 0.00037, rec: 0.99963, prc: 0.74407, f1: 0.85312, f1_macro: 0.92278
# Validation --- epoch: 3, loss: 0.34528
#           f1: 0.48216, fnr: 0.01244, f1_macro: 0.72903, fpr: 0.04677, acc: 0.95397, prc: 0.31974, rec: 0.98756
# epoch: 4, passed number of graphs: 96, train running loss: 0.00700 (passed time: 8m 57s)
#           acc: 0.99817, fpr: 0.00190, fnr: 0.00016, rec: 0.99984, prc: 0.95892, f1: 0.97895, f1_macro: 0.98900
# epoch: 4, passed number of graphs: 192, train running loss: 0.00686 (passed time: 9m 15s)
#           acc: 0.99658, fpr: 0.00139, fnr: 0.04984, rec: 0.95016, prc: 0.96766, f1: 0.95883, f1_macro: 0.97852
# epoch: 4, passed number of graphs: 288, train running loss: 0.00625 (passed time: 9m 33s)
#           acc: 0.99732, fpr: 0.00275, fnr: 0.00087, rec: 0.99913, prc: 0.94097, f1: 0.96918, f1_macro: 0.98389
# epoch: 4, passed number of graphs: 384, train running loss: 0.00566 (passed time: 9m 51s)
#           acc: 0.99777, fpr: 0.00232, fnr: 0.00025, rec: 0.99975, prc: 0.95056, f1: 0.97454, f1_macro: 0.98669
# epoch: 4, passed number of graphs: 480, train running loss: 0.00648 (passed time: 10m 9s)
#           acc: 0.99250, fpr: 0.00782, fnr: 0.00046, rec: 0.99954, prc: 0.85020, f1: 0.91884, f1_macro: 0.95745
# epoch: 4, passed number of graphs: 576, train running loss: 0.00681 (passed time: 10m 27s)
#           acc: 0.99546, fpr: 0.00330, fnr: 0.03246, rec: 0.96754, prc: 0.92879, f1: 0.94777, f1_macro: 0.97270
# epoch: 4, passed number of graphs: 672, train running loss: 0.00698 (passed time: 10m 45s)
#           acc: 0.99464, fpr: 0.00511, fnr: 0.01113, rec: 0.98887, prc: 0.89525, f1: 0.93974, f1_macro: 0.96847
# epoch: 4, passed number of graphs: 768, train running loss: 0.00728 (passed time: 11m 3s)
#           acc: 0.99087, fpr: 0.00939, fnr: 0.00314, rec: 0.99686, prc: 0.82235, f1: 0.90124, f1_macro: 0.94823
# Validation --- epoch: 4, loss: 0.01017
#           f1: 0.96487, fnr: 0.05801, f1_macro: 0.98207, fpr: 0.00017, acc: 0.99859, prc: 0.99354, rec: 0.94199
# epoch: 5, passed number of graphs: 96, train running loss: 0.00554 (passed time: 11m 43s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00012, rec: 0.99988, prc: 0.99662, f1: 0.99825, f1_macro: 0.99909
# epoch: 5, passed number of graphs: 192, train running loss: 0.00560 (passed time: 12m 1s)
#           acc: 0.99645, fpr: 0.00161, fnr: 0.04782, rec: 0.95218, prc: 0.96288, f1: 0.95750, f1_macro: 0.97782
# epoch: 5, passed number of graphs: 288, train running loss: 0.00527 (passed time: 12m 19s)
#           acc: 0.99495, fpr: 0.00525, fnr: 0.00058, rec: 0.99942, prc: 0.89328, f1: 0.94338, f1_macro: 0.97037
# epoch: 5, passed number of graphs: 384, train running loss: 0.00515 (passed time: 12m 37s)
#           acc: 0.99798, fpr: 0.00209, fnr: 0.00041, rec: 0.99959, prc: 0.95521, f1: 0.97690, f1_macro: 0.98792
# epoch: 5, passed number of graphs: 480, train running loss: 0.00563 (passed time: 12m 55s)
#           acc: 0.99966, fpr: 0.00031, fnr: 0.00108, rec: 0.99892, prc: 0.99317, f1: 0.99603, f1_macro: 0.99793
# epoch: 5, passed number of graphs: 576, train running loss: 0.00505 (passed time: 13m 13s)
#           acc: 0.99960, fpr: 0.00036, fnr: 0.00135, rec: 0.99865, prc: 0.99194, f1: 0.99529, f1_macro: 0.99754
# epoch: 5, passed number of graphs: 672, train running loss: 0.00467 (passed time: 13m 31s)
#           acc: 0.99965, fpr: 0.00034, fnr: 0.00061, rec: 0.99939, prc: 0.99227, f1: 0.99582, f1_macro: 0.99782
# epoch: 5, passed number of graphs: 768, train running loss: 0.00454 (passed time: 13m 49s)
#           acc: 0.99164, fpr: 0.00858, fnr: 0.00339, rec: 0.99661, prc: 0.83516, f1: 0.90877, f1_macro: 0.95220
# Validation --- epoch: 5, loss: 0.00419
#           f1: 0.98538, fnr: 0.02582, f1_macro: 0.99255, fpr: 0.00001, acc: 0.99944, prc: 0.99946, rec: 0.97418
# Better model saved at ./saved_models/GIN_4: 0.9853822159413236.pt.
# epoch: 6, passed number of graphs: 96, train running loss: 0.00712 (passed time: 14m 28s)
#           acc: 0.98742, fpr: 0.01313, fnr: 0.00008, rec: 0.99992, prc: 0.77152, f1: 0.87100, f1_macro: 0.93219
# epoch: 6, passed number of graphs: 192, train running loss: 0.00691 (passed time: 14m 46s)
#           acc: 0.99491, fpr: 0.00317, fnr: 0.04902, rec: 0.95098, prc: 0.92930, f1: 0.94002, f1_macro: 0.96868
# epoch: 6, passed number of graphs: 288, train running loss: 0.00639 (passed time: 15m 4s)
#           acc: 0.99499, fpr: 0.00522, fnr: 0.00012, rec: 0.99988, prc: 0.89379, f1: 0.94386, f1_macro: 0.97062
# epoch: 6, passed number of graphs: 384, train running loss: 0.00565 (passed time: 15m 22s)
#           acc: 0.99937, fpr: 0.00064, fnr: 0.00037, rec: 0.99963, prc: 0.98588, f1: 0.99271, f1_macro: 0.99619
# epoch: 6, passed number of graphs: 480, train running loss: 0.00564 (passed time: 15m 40s)
#           acc: 0.99929, fpr: 0.00072, fnr: 0.00042, rec: 0.99958, prc: 0.98393, f1: 0.99169, f1_macro: 0.99566
# epoch: 6, passed number of graphs: 576, train running loss: 0.00495 (passed time: 15m 58s)
#           acc: 0.99914, fpr: 0.00085, fnr: 0.00102, rec: 0.99898, prc: 0.98114, f1: 0.98998, f1_macro: 0.99476
# epoch: 6, passed number of graphs: 672, train running loss: 0.00459 (passed time: 16m 16s)
#           acc: 0.99699, fpr: 0.00314, fnr: 0.00008, rec: 0.99992, prc: 0.93364, f1: 0.96564, f1_macro: 0.98203
# epoch: 6, passed number of graphs: 768, train running loss: 0.00487 (passed time: 16m 34s)
#           acc: 0.98869, fpr: 0.01176, fnr: 0.00083, rec: 0.99917, prc: 0.78739, f1: 0.88073, f1_macro: 0.93740
# Validation --- epoch: 6, loss: 0.07328
#           f1: 0.01986, fnr: 0.98986, f1_macro: nan, fpr: 0.00002, acc: 0.97868, prc: 0.38676, rec: 0.01014
# epoch: 7, passed number of graphs: 96, train running loss: 0.01425 (passed time: 17m 13s)
#           acc: 0.97007, fpr: 0.02600, fnr: 0.11864, rec: 0.88136, prc: 0.60055, f1: 0.71435, f1_macro: 0.84928
# epoch: 7, passed number of graphs: 192, train running loss: 0.02444 (passed time: 17m 31s)
#           acc: 0.97964, fpr: 0.01880, fnr: 0.05604, rec: 0.94396, prc: 0.68745, f1: 0.79554, f1_macro: 0.89241
# epoch: 7, passed number of graphs: 288, train running loss: 0.02080 (passed time: 17m 49s)
#           acc: 0.98460, fpr: 0.01607, fnr: 0.00004, rec: 0.99996, prc: 0.73220, f1: 0.84538, f1_macro: 0.91864
# epoch: 7, passed number of graphs: 384, train running loss: 0.01849 (passed time: 18m 7s)
#           acc: 0.93906, fpr: 0.06363, fnr: 0.00070, rec: 0.99930, prc: 0.41151, f1: 0.58296, f1_macro: 0.77504
# epoch: 7, passed number of graphs: 480, train running loss: 0.01821 (passed time: 18m 25s)
#           acc: 0.99059, fpr: 0.00977, fnr: 0.00129, rec: 0.99871, prc: 0.81938, f1: 0.90020, f1_macro: 0.94763
# epoch: 7, passed number of graphs: 576, train running loss: 0.01654 (passed time: 18m 43s)
#           acc: 0.99627, fpr: 0.00222, fnr: 0.03772, rec: 0.96228, prc: 0.95068, f1: 0.95645, f1_macro: 0.97725
# epoch: 7, passed number of graphs: 672, train running loss: 0.01585 (passed time: 19m 0s)
#           acc: 0.99427, fpr: 0.00456, fnr: 0.03240, rec: 0.96760, prc: 0.90356, f1: 0.93449, f1_macro: 0.96574
# epoch: 7, passed number of graphs: 768, train running loss: 0.01477 (passed time: 19m 18s)
#           acc: 0.99544, fpr: 0.00476, fnr: 0.00008, rec: 0.99992, prc: 0.90163, f1: 0.94823, f1_macro: 0.97292
# Validation --- epoch: 7, loss: 0.02182
#           f1: 0.90785, fnr: 0.01028, f1_macro: 0.95271, fpr: 0.00462, acc: 0.99526, prc: 0.85139, rec: 0.98972
# epoch: 8, passed number of graphs: 96, train running loss: 0.00452 (passed time: 19m 57s)
#           acc: 0.99866, fpr: 0.00138, fnr: 0.00045, rec: 0.99955, prc: 0.96984, f1: 0.98447, f1_macro: 0.99188
# epoch: 8, passed number of graphs: 192, train running loss: 0.00447 (passed time: 20m 16s)
#           acc: 0.99471, fpr: 0.00388, fnr: 0.03745, rec: 0.96255, prc: 0.91566, f1: 0.93852, f1_macro: 0.96788
# epoch: 8, passed number of graphs: 288, train running loss: 0.00418 (passed time: 20m 33s)
#           acc: 0.99617, fpr: 0.00399, fnr: 0.00008, rec: 0.99992, prc: 0.91667, f1: 0.95649, f1_macro: 0.97724
# epoch: 8, passed number of graphs: 384, train running loss: 0.00412 (passed time: 20m 51s)
#           acc: 0.99810, fpr: 0.00197, fnr: 0.00025, rec: 0.99975, prc: 0.95762, f1: 0.97823, f1_macro: 0.98862
# epoch: 8, passed number of graphs: 480, train running loss: 0.00456 (passed time: 21m 9s)
#           acc: 0.99780, fpr: 0.00224, fnr: 0.00129, rec: 0.99871, prc: 0.95188, f1: 0.97473, f1_macro: 0.98679
# epoch: 8, passed number of graphs: 576, train running loss: 0.00417 (passed time: 21m 27s)
#           acc: 0.99923, fpr: 0.00075, fnr: 0.00114, rec: 0.99886, prc: 0.98338, f1: 0.99106, f1_macro: 0.99533
# epoch: 8, passed number of graphs: 672, train running loss: 0.00399 (passed time: 21m 45s)
#           acc: 0.99814, fpr: 0.00193, fnr: 0.00033, rec: 0.99967, prc: 0.95809, f1: 0.97844, f1_macro: 0.98873
# epoch: 8, passed number of graphs: 768, train running loss: 0.00400 (passed time: 22m 3s)
#           acc: 0.99737, fpr: 0.00272, fnr: 0.00054, rec: 0.99946, prc: 0.94118, f1: 0.96944, f1_macro: 0.98403
# Validation --- epoch: 8, loss: 0.00680
#           f1: 0.97342, fnr: 0.00997, f1_macro: 0.98639, fpr: 0.00104, acc: 0.99877, prc: 0.96228, rec: 0.99003
# epoch: 9, passed number of graphs: 96, train running loss: 0.00143 (passed time: 22m 42s)
#           acc: 0.99948, fpr: 0.00053, fnr: 0.00037, rec: 0.99963, prc: 0.98818, f1: 0.99387, f1_macro: 0.99680
# epoch: 9, passed number of graphs: 192, train running loss: 0.00177 (passed time: 23m 0s)
#           acc: 0.99515, fpr: 0.00501, fnr: 0.00136, rec: 0.99864, prc: 0.89726, f1: 0.94524, f1_macro: 0.97135
# epoch: 9, passed number of graphs: 288, train running loss: 0.00177 (passed time: 23m 18s)
#           acc: 0.99809, fpr: 0.00199, fnr: 0.00008, rec: 0.99992, prc: 0.95671, f1: 0.97784, f1_macro: 0.98842
# epoch: 9, passed number of graphs: 384, train running loss: 0.00195 (passed time: 23m 36s)
#           acc: 0.99962, fpr: 0.00039, fnr: 0.00025, rec: 0.99975, prc: 0.99138, f1: 0.99555, f1_macro: 0.99767
# epoch: 9, passed number of graphs: 480, train running loss: 0.00244 (passed time: 23m 54s)
#           acc: 0.99959, fpr: 0.00037, fnr: 0.00129, rec: 0.99871, prc: 0.99181, f1: 0.99525, f1_macro: 0.99752
# epoch: 9, passed number of graphs: 576, train running loss: 0.00224 (passed time: 24m 12s)
#           acc: 0.99961, fpr: 0.00035, fnr: 0.00131, rec: 0.99869, prc: 0.99214, f1: 0.99541, f1_macro: 0.99760
# epoch: 9, passed number of graphs: 672, train running loss: 0.00214 (passed time: 24m 30s)
#           acc: 0.99847, fpr: 0.00158, fnr: 0.00045, rec: 0.99955, prc: 0.96544, f1: 0.98220, f1_macro: 0.99070
# epoch: 9, passed number of graphs: 768, train running loss: 0.00222 (passed time: 24m 48s)
#           acc: 0.99804, fpr: 0.00202, fnr: 0.00037, rec: 0.99963, prc: 0.95562, f1: 0.97713, f1_macro: 0.98805
# Validation --- epoch: 9, loss: 0.00379
#           f1: 0.98772, fnr: 0.00816, f1_macro: 0.99372, fpr: 0.00036, acc: 0.99947, prc: 0.98621, rec: 0.99184
# Better model saved at ./saved_models/GIN_8: 0.9877178353059569.pt.
# epoch: 10, passed number of graphs: 96, train running loss: 0.00187 (passed time: 25m 28s)
#           acc: 0.99936, fpr: 0.00064, fnr: 0.00053, rec: 0.99947, prc: 0.98576, f1: 0.99257, f1_macro: 0.99612
# epoch: 10, passed number of graphs: 192, train running loss: 0.00180 (passed time: 25m 46s)
#           acc: 0.99832, fpr: 0.00170, fnr: 0.00111, rec: 0.99889, prc: 0.96252, f1: 0.98036, f1_macro: 0.98974
# epoch: 10, passed number of graphs: 288, train running loss: 0.00161 (passed time: 26m 4s)
#           acc: 0.99848, fpr: 0.00156, fnr: 0.00058, rec: 0.99942, prc: 0.96573, f1: 0.98229, f1_macro: 0.99075
# epoch: 10, passed number of graphs: 384, train running loss: 0.00169 (passed time: 26m 22s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00041, rec: 0.99959, prc: 0.99413, f1: 0.99685, f1_macro: 0.99836
# epoch: 10, passed number of graphs: 480, train running loss: 0.00223 (passed time: 26m 40s)
#           acc: 0.99933, fpr: 0.00067, fnr: 0.00046, rec: 0.99954, prc: 0.98502, f1: 0.99223, f1_macro: 0.99594
# epoch: 10, passed number of graphs: 576, train running loss: 0.00199 (passed time: 26m 58s)
#           acc: 0.99961, fpr: 0.00036, fnr: 0.00114, rec: 0.99886, prc: 0.99198, f1: 0.99541, f1_macro: 0.99760
# epoch: 10, passed number of graphs: 672, train running loss: 0.00186 (passed time: 27m 16s)
#           acc: 0.99938, fpr: 0.00063, fnr: 0.00033, rec: 0.99967, prc: 0.98581, f1: 0.99270, f1_macro: 0.99619
# epoch: 10, passed number of graphs: 768, train running loss: 0.00183 (passed time: 27m 34s)
#           acc: 0.99821, fpr: 0.00187, fnr: 0.00012, rec: 0.99988, prc: 0.95896, f1: 0.97899, f1_macro: 0.98903
# Validation --- epoch: 10, loss: 0.00258
#           f1: 0.99149, fnr: 0.00778, f1_macro: 0.99566, fpr: 0.00018, acc: 0.99965, prc: 0.99270, rec: 0.99222
# Better model saved at ./saved_models/GIN_9: 0.9914907676247928.pt.
# epoch: 11, passed number of graphs: 96, train running loss: 0.00154 (passed time: 28m 14s)
#           acc: 0.99948, fpr: 0.00051, fnr: 0.00069, rec: 0.99931, prc: 0.98854, f1: 0.99389, f1_macro: 0.99681
# epoch: 11, passed number of graphs: 192, train running loss: 0.00136 (passed time: 28m 32s)
#           acc: 0.99789, fpr: 0.00219, fnr: 0.00021, rec: 0.99979, prc: 0.95236, f1: 0.97550, f1_macro: 0.98720
# epoch: 11, passed number of graphs: 288, train running loss: 0.00118 (passed time: 28m 50s)
#           acc: 0.99868, fpr: 0.00137, fnr: 0.00008, rec: 0.99992, prc: 0.96975, f1: 0.98460, f1_macro: 0.99196
# epoch: 11, passed number of graphs: 384, train running loss: 0.00128 (passed time: 29m 7s)
#           acc: 0.99972, fpr: 0.00027, fnr: 0.00045, rec: 0.99955, prc: 0.99392, f1: 0.99673, f1_macro: 0.99829
# epoch: 11, passed number of graphs: 480, train running loss: 0.00145 (passed time: 29m 25s)
#           acc: 0.99963, fpr: 0.00036, fnr: 0.00050, rec: 0.99950, prc: 0.99190, f1: 0.99568, f1_macro: 0.99775
# epoch: 11, passed number of graphs: 576, train running loss: 0.00134 (passed time: 29m 43s)
#           acc: 0.99958, fpr: 0.00037, fnr: 0.00139, rec: 0.99861, prc: 0.99166, f1: 0.99512, f1_macro: 0.99745
# epoch: 11, passed number of graphs: 672, train running loss: 0.00131 (passed time: 30m 1s)
#           acc: 0.99851, fpr: 0.00155, fnr: 0.00000, rec: 1.00000, prc: 0.96599, f1: 0.98270, f1_macro: 0.99096
# epoch: 11, passed number of graphs: 768, train running loss: 0.00132 (passed time: 30m 19s)
#           acc: 0.99857, fpr: 0.00148, fnr: 0.00017, rec: 0.99983, prc: 0.96709, f1: 0.98319, f1_macro: 0.99122
# Validation --- epoch: 11, loss: 0.01094
#           f1: 0.93606, fnr: 0.00443, f1_macro: 0.96722, fpr: 0.00311, acc: 0.99686, prc: 0.89140, rec: 0.99557
# epoch: 12, passed number of graphs: 96, train running loss: 0.00111 (passed time: 30m 59s)
#           acc: 0.99967, fpr: 0.00033, fnr: 0.00029, rec: 0.99971, prc: 0.99267, f1: 0.99618, f1_macro: 0.99800
# epoch: 12, passed number of graphs: 192, train running loss: 0.00140 (passed time: 31m 17s)
#           acc: 0.99747, fpr: 0.00258, fnr: 0.00136, rec: 0.99864, prc: 0.94428, f1: 0.97070, f1_macro: 0.98469
# epoch: 12, passed number of graphs: 288, train running loss: 0.00134 (passed time: 31m 35s)
#           acc: 0.99873, fpr: 0.00130, fnr: 0.00062, rec: 0.99938, prc: 0.97129, f1: 0.98513, f1_macro: 0.99224
# epoch: 12, passed number of graphs: 384, train running loss: 0.00135 (passed time: 31m 53s)
#           acc: 0.99974, fpr: 0.00026, fnr: 0.00037, rec: 0.99963, prc: 0.99421, f1: 0.99691, f1_macro: 0.99839
# epoch: 12, passed number of graphs: 480, train running loss: 0.00156 (passed time: 32m 11s)
#           acc: 0.99971, fpr: 0.00027, fnr: 0.00071, rec: 0.99929, prc: 0.99403, f1: 0.99666, f1_macro: 0.99825
# epoch: 12, passed number of graphs: 576, train running loss: 0.00143 (passed time: 32m 29s)
#           acc: 0.99958, fpr: 0.00039, fnr: 0.00118, rec: 0.99882, prc: 0.99138, f1: 0.99508, f1_macro: 0.99743
# epoch: 12, passed number of graphs: 672, train running loss: 0.00139 (passed time: 32m 47s)
#           acc: 0.99858, fpr: 0.00149, fnr: 0.00004, rec: 0.99996, prc: 0.96743, f1: 0.98343, f1_macro: 0.99134
# epoch: 12, passed number of graphs: 768, train running loss: 0.00134 (passed time: 33m 5s)
#           acc: 0.99827, fpr: 0.00179, fnr: 0.00045, rec: 0.99955, prc: 0.96055, f1: 0.97966, f1_macro: 0.98938
# Validation --- epoch: 12, loss: 0.00293
#           f1: 0.99145, fnr: 0.00494, f1_macro: 0.99563, fpr: 0.00026, acc: 0.99964, prc: 0.98947, rec: 0.99506
# epoch: 13, passed number of graphs: 96, train running loss: 0.00061 (passed time: 33m 44s)
#           acc: 0.99977, fpr: 0.00022, fnr: 0.00024, rec: 0.99976, prc: 0.99497, f1: 0.99735, f1_macro: 0.99862
# epoch: 13, passed number of graphs: 192, train running loss: 0.00062 (passed time: 34m 2s)
#           acc: 0.99921, fpr: 0.00080, fnr: 0.00054, rec: 0.99946, prc: 0.98203, f1: 0.99067, f1_macro: 0.99513
# epoch: 13, passed number of graphs: 288, train running loss: 0.00059 (passed time: 34m 19s)
#           acc: 0.99897, fpr: 0.00107, fnr: 0.00012, rec: 0.99988, prc: 0.97618, f1: 0.98788, f1_macro: 0.99367
# epoch: 13, passed number of graphs: 384, train running loss: 0.00072 (passed time: 34m 37s)
#           acc: 0.99974, fpr: 0.00026, fnr: 0.00037, rec: 0.99963, prc: 0.99421, f1: 0.99691, f1_macro: 0.99839
# epoch: 13, passed number of graphs: 480, train running loss: 0.00080 (passed time: 34m 55s)
#           acc: 0.99958, fpr: 0.00041, fnr: 0.00054, rec: 0.99946, prc: 0.99083, f1: 0.99513, f1_macro: 0.99745
# epoch: 13, passed number of graphs: 576, train running loss: 0.00075 (passed time: 35m 13s)
#           acc: 0.99965, fpr: 0.00032, fnr: 0.00090, rec: 0.99910, prc: 0.99283, f1: 0.99596, f1_macro: 0.99789
# epoch: 13, passed number of graphs: 672, train running loss: 0.00073 (passed time: 35m 31s)
#           acc: 0.99967, fpr: 0.00033, fnr: 0.00020, rec: 0.99980, prc: 0.99252, f1: 0.99614, f1_macro: 0.99799
# epoch: 13, passed number of graphs: 768, train running loss: 0.00072 (passed time: 35m 49s)
#           acc: 0.99966, fpr: 0.00034, fnr: 0.00021, rec: 0.99979, prc: 0.99225, f1: 0.99601, f1_macro: 0.99792
# Validation --- epoch: 13, loss: 0.00207
#           f1: 0.99488, fnr: 0.00527, f1_macro: 0.99739, fpr: 0.00009, acc: 0.99980, prc: 0.99614, rec: 0.99473
# Better model saved at ./saved_models/GIN_12: 0.9948805051129131.pt.
# epoch: 14, passed number of graphs: 96, train running loss: 0.00053 (passed time: 36m 28s)
#           acc: 0.99980, fpr: 0.00020, fnr: 0.00024, rec: 0.99976, prc: 0.99561, f1: 0.99768, f1_macro: 0.99879
# epoch: 14, passed number of graphs: 192, train running loss: 0.00055 (passed time: 36m 46s)
#           acc: 0.99924, fpr: 0.00078, fnr: 0.00045, rec: 0.99955, prc: 0.98255, f1: 0.99097, f1_macro: 0.99529
# epoch: 14, passed number of graphs: 288, train running loss: 0.00052 (passed time: 37m 4s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00012, rec: 0.99988, prc: 0.99382, f1: 0.99684, f1_macro: 0.99835
# epoch: 14, passed number of graphs: 384, train running loss: 0.00062 (passed time: 37m 22s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00029, rec: 0.99971, prc: 0.99441, f1: 0.99706, f1_macro: 0.99846
# epoch: 14, passed number of graphs: 480, train running loss: 0.00069 (passed time: 37m 40s)
#           acc: 0.99965, fpr: 0.00034, fnr: 0.00050, rec: 0.99950, prc: 0.99243, f1: 0.99595, f1_macro: 0.99789
# epoch: 14, passed number of graphs: 576, train running loss: 0.00065 (passed time: 37m 58s)
#           acc: 0.99966, fpr: 0.00031, fnr: 0.00090, rec: 0.99910, prc: 0.99307, f1: 0.99608, f1_macro: 0.99795
# epoch: 14, passed number of graphs: 672, train running loss: 0.00064 (passed time: 38m 16s)
#           acc: 0.99966, fpr: 0.00034, fnr: 0.00020, rec: 0.99980, prc: 0.99227, f1: 0.99602, f1_macro: 0.99792
# epoch: 14, passed number of graphs: 768, train running loss: 0.00063 (passed time: 38m 34s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00021, rec: 0.99979, prc: 0.99388, f1: 0.99683, f1_macro: 0.99834
# Validation --- epoch: 14, loss: 0.00198
#           f1: 0.99469, fnr: 0.00522, f1_macro: 0.99729, fpr: 0.00010, acc: 0.99979, prc: 0.99575, rec: 0.99478
# epoch: 15, passed number of graphs: 96, train running loss: 0.00052 (passed time: 39m 13s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00024, rec: 0.99976, prc: 0.99606, f1: 0.99790, f1_macro: 0.99890
# epoch: 15, passed number of graphs: 192, train running loss: 0.00053 (passed time: 39m 31s)
#           acc: 0.99922, fpr: 0.00079, fnr: 0.00045, rec: 0.99955, prc: 0.98223, f1: 0.99081, f1_macro: 0.99520
# epoch: 15, passed number of graphs: 288, train running loss: 0.00050 (passed time: 39m 49s)
#           acc: 0.99976, fpr: 0.00025, fnr: 0.00008, rec: 0.99992, prc: 0.99431, f1: 0.99711, f1_macro: 0.99849
# epoch: 15, passed number of graphs: 384, train running loss: 0.00058 (passed time: 40m 7s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00029, rec: 0.99971, prc: 0.99461, f1: 0.99716, f1_macro: 0.99852
# epoch: 15, passed number of graphs: 480, train running loss: 0.00064 (passed time: 40m 25s)
#           acc: 0.99968, fpr: 0.00031, fnr: 0.00050, rec: 0.99950, prc: 0.99313, f1: 0.99630, f1_macro: 0.99807
# epoch: 15, passed number of graphs: 576, train running loss: 0.00060 (passed time: 40m 43s)
#           acc: 0.99968, fpr: 0.00030, fnr: 0.00077, rec: 0.99923, prc: 0.99319, f1: 0.99620, f1_macro: 0.99801
# epoch: 15, passed number of graphs: 672, train running loss: 0.00060 (passed time: 41m 1s)
#           acc: 0.99968, fpr: 0.00033, fnr: 0.00020, rec: 0.99980, prc: 0.99260, f1: 0.99618, f1_macro: 0.99801
# epoch: 15, passed number of graphs: 768, train running loss: 0.00060 (passed time: 41m 19s)
#           acc: 0.99957, fpr: 0.00044, fnr: 0.00025, rec: 0.99975, prc: 0.99009, f1: 0.99490, f1_macro: 0.99734
# Validation --- epoch: 15, loss: 0.00197
#           f1: 0.99449, fnr: 0.00516, f1_macro: 0.99719, fpr: 0.00011, acc: 0.99978, prc: 0.99533, rec: 0.99484
# epoch: 16, passed number of graphs: 96, train running loss: 0.00053 (passed time: 41m 58s)
#           acc: 0.99983, fpr: 0.00017, fnr: 0.00024, rec: 0.99976, prc: 0.99626, f1: 0.99800, f1_macro: 0.99896
# epoch: 16, passed number of graphs: 192, train running loss: 0.00052 (passed time: 42m 16s)
#           acc: 0.99923, fpr: 0.00079, fnr: 0.00045, rec: 0.99955, prc: 0.98235, f1: 0.99087, f1_macro: 0.99523
# epoch: 16, passed number of graphs: 288, train running loss: 0.00049 (passed time: 42m 34s)
#           acc: 0.99976, fpr: 0.00025, fnr: 0.00008, rec: 0.99992, prc: 0.99431, f1: 0.99711, f1_macro: 0.99849
# epoch: 16, passed number of graphs: 384, train running loss: 0.00056 (passed time: 42m 52s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00029, rec: 0.99971, prc: 0.99470, f1: 0.99720, f1_macro: 0.99854
# epoch: 16, passed number of graphs: 480, train running loss: 0.00061 (passed time: 43m 10s)
#           acc: 0.99970, fpr: 0.00029, fnr: 0.00050, rec: 0.99950, prc: 0.99354, f1: 0.99651, f1_macro: 0.99818
# epoch: 16, passed number of graphs: 576, train running loss: 0.00058 (passed time: 43m 28s)
#           acc: 0.99966, fpr: 0.00032, fnr: 0.00077, rec: 0.99923, prc: 0.99295, f1: 0.99608, f1_macro: 0.99795
# epoch: 16, passed number of graphs: 672, train running loss: 0.00057 (passed time: 43m 46s)
#           acc: 0.99968, fpr: 0.00033, fnr: 0.00020, rec: 0.99980, prc: 0.99268, f1: 0.99622, f1_macro: 0.99803
# epoch: 16, passed number of graphs: 768, train running loss: 0.00057 (passed time: 44m 4s)
#           acc: 0.99969, fpr: 0.00031, fnr: 0.00025, rec: 0.99975, prc: 0.99294, f1: 0.99633, f1_macro: 0.99809
# Validation --- epoch: 16, loss: 0.00188
#           f1: 0.99456, fnr: 0.00525, f1_macro: 0.99723, fpr: 0.00010, acc: 0.99979, prc: 0.99556, rec: 0.99475
# epoch: 17, passed number of graphs: 96, train running loss: 0.00051 (passed time: 44m 43s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00020, rec: 0.99980, prc: 0.99638, f1: 0.99809, f1_macro: 0.99900
# epoch: 17, passed number of graphs: 192, train running loss: 0.00050 (passed time: 45m 1s)
#           acc: 0.99923, fpr: 0.00079, fnr: 0.00045, rec: 0.99955, prc: 0.98231, f1: 0.99085, f1_macro: 0.99522
# epoch: 17, passed number of graphs: 288, train running loss: 0.00047 (passed time: 45m 19s)
#           acc: 0.99976, fpr: 0.00025, fnr: 0.00008, rec: 0.99992, prc: 0.99431, f1: 0.99711, f1_macro: 0.99849
# epoch: 17, passed number of graphs: 384, train running loss: 0.00053 (passed time: 45m 37s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00029, rec: 0.99971, prc: 0.99466, f1: 0.99718, f1_macro: 0.99853
# epoch: 17, passed number of graphs: 480, train running loss: 0.00058 (passed time: 45m 55s)
#           acc: 0.99971, fpr: 0.00028, fnr: 0.00050, rec: 0.99950, prc: 0.99375, f1: 0.99661, f1_macro: 0.99823
# epoch: 17, passed number of graphs: 576, train running loss: 0.00055 (passed time: 46m 13s)
#           acc: 0.99966, fpr: 0.00032, fnr: 0.00077, rec: 0.99923, prc: 0.99291, f1: 0.99606, f1_macro: 0.99794
# epoch: 17, passed number of graphs: 672, train running loss: 0.00055 (passed time: 46m 31s)
#           acc: 0.99961, fpr: 0.00041, fnr: 0.00008, rec: 0.99992, prc: 0.99087, f1: 0.99538, f1_macro: 0.99758
# epoch: 17, passed number of graphs: 768, train running loss: 0.00056 (passed time: 46m 49s)
#           acc: 0.99943, fpr: 0.00059, fnr: 0.00017, rec: 0.99983, prc: 0.98670, f1: 0.99322, f1_macro: 0.99646
# Validation --- epoch: 17, loss: 0.00194
#           f1: 0.99441, fnr: 0.00544, f1_macro: 0.99715, fpr: 0.00010, acc: 0.99978, prc: 0.99543, rec: 0.99456
# epoch: 18, passed number of graphs: 96, train running loss: 0.00055 (passed time: 47m 28s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00016, rec: 0.99984, prc: 0.99658, f1: 0.99821, f1_macro: 0.99906
# epoch: 18, passed number of graphs: 192, train running loss: 0.00053 (passed time: 47m 46s)
#           acc: 0.99920, fpr: 0.00081, fnr: 0.00045, rec: 0.99955, prc: 0.98175, f1: 0.99057, f1_macro: 0.99507
# epoch: 18, passed number of graphs: 288, train running loss: 0.00048 (passed time: 48m 4s)
#           acc: 0.99976, fpr: 0.00025, fnr: 0.00004, rec: 0.99996, prc: 0.99432, f1: 0.99713, f1_macro: 0.99850
# epoch: 18, passed number of graphs: 384, train running loss: 0.00056 (passed time: 48m 22s)
#           acc: 0.99975, fpr: 0.00024, fnr: 0.00033, rec: 0.99967, prc: 0.99453, f1: 0.99710, f1_macro: 0.99848
# epoch: 18, passed number of graphs: 480, train running loss: 0.00061 (passed time: 48m 40s)
#           acc: 0.99963, fpr: 0.00036, fnr: 0.00050, rec: 0.99950, prc: 0.99186, f1: 0.99566, f1_macro: 0.99774
# epoch: 18, passed number of graphs: 576, train running loss: 0.00057 (passed time: 48m 57s)
#           acc: 0.99965, fpr: 0.00033, fnr: 0.00073, rec: 0.99927, prc: 0.99255, f1: 0.99589, f1_macro: 0.99786
# epoch: 18, passed number of graphs: 672, train running loss: 0.00056 (passed time: 49m 15s)
#           acc: 0.99968, fpr: 0.00032, fnr: 0.00020, rec: 0.99980, prc: 0.99280, f1: 0.99628, f1_macro: 0.99806
# epoch: 18, passed number of graphs: 768, train running loss: 0.00056 (passed time: 49m 33s)
#           acc: 0.99976, fpr: 0.00025, fnr: 0.00017, rec: 0.99983, prc: 0.99441, f1: 0.99711, f1_macro: 0.99849
# Validation --- epoch: 18, loss: 0.00185
#           f1: 0.99445, fnr: 0.00528, f1_macro: 0.99717, fpr: 0.00011, acc: 0.99978, prc: 0.99538, rec: 0.99472
# epoch: 19, passed number of graphs: 96, train running loss: 0.00047 (passed time: 50m 12s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00020, rec: 0.99980, prc: 0.99683, f1: 0.99831, f1_macro: 0.99912
# epoch: 19, passed number of graphs: 192, train running loss: 0.00047 (passed time: 50m 30s)
#           acc: 0.99922, fpr: 0.00080, fnr: 0.00037, rec: 0.99963, prc: 0.98203, f1: 0.99075, f1_macro: 0.99517
# epoch: 19, passed number of graphs: 288, train running loss: 0.00043 (passed time: 50m 48s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00008, rec: 0.99992, prc: 0.99448, f1: 0.99719, f1_macro: 0.99853
# epoch: 19, passed number of graphs: 384, train running loss: 0.00049 (passed time: 51m 6s)
#           acc: 0.99977, fpr: 0.00023, fnr: 0.00037, rec: 0.99963, prc: 0.99494, f1: 0.99728, f1_macro: 0.99858
# epoch: 19, passed number of graphs: 480, train running loss: 0.00053 (passed time: 51m 24s)
#           acc: 0.99971, fpr: 0.00028, fnr: 0.00050, rec: 0.99950, prc: 0.99366, f1: 0.99657, f1_macro: 0.99821
# epoch: 19, passed number of graphs: 576, train running loss: 0.00051 (passed time: 51m 42s)
#           acc: 0.99966, fpr: 0.00032, fnr: 0.00073, rec: 0.99927, prc: 0.99291, f1: 0.99608, f1_macro: 0.99795
# epoch: 19, passed number of graphs: 672, train running loss: 0.00057 (passed time: 52m 0s)
#           acc: 0.99941, fpr: 0.00061, fnr: 0.00004, rec: 0.99996, prc: 0.98633, f1: 0.99310, f1_macro: 0.99640
# epoch: 19, passed number of graphs: 768, train running loss: 0.00079 (passed time: 52m 18s)
#           acc: 0.99026, fpr: 0.01016, fnr: 0.00012, rec: 0.99988, prc: 0.81096, f1: 0.89556, f1_macro: 0.94523
# Validation --- epoch: 19, loss: 0.05281
#           f1: 0.73639, fnr: 0.00443, f1_macro: 0.86358, fpr: 0.01810, acc: 0.98219, prc: 0.60955, rec: 0.99557
# epoch: 20, passed number of graphs: 96, train running loss: 0.00107 (passed time: 52m 57s)
#           acc: 0.99980, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99565, f1: 0.99766, f1_macro: 0.99878
# epoch: 20, passed number of graphs: 192, train running loss: 0.00091 (passed time: 53m 15s)
#           acc: 0.99917, fpr: 0.00085, fnr: 0.00037, rec: 0.99963, prc: 0.98087, f1: 0.99016, f1_macro: 0.99486
# epoch: 20, passed number of graphs: 288, train running loss: 0.00078 (passed time: 53m 32s)
#           acc: 0.99958, fpr: 0.00044, fnr: 0.00008, rec: 0.99992, prc: 0.99019, f1: 0.99503, f1_macro: 0.99741
# epoch: 20, passed number of graphs: 384, train running loss: 0.00087 (passed time: 53m 50s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00033, rec: 0.99967, prc: 0.99405, f1: 0.99685, f1_macro: 0.99836
# epoch: 20, passed number of graphs: 480, train running loss: 0.00091 (passed time: 54m 8s)
#           acc: 0.99963, fpr: 0.00036, fnr: 0.00050, rec: 0.99950, prc: 0.99186, f1: 0.99566, f1_macro: 0.99774
# epoch: 20, passed number of graphs: 576, train running loss: 0.00082 (passed time: 54m 26s)
#           acc: 0.99964, fpr: 0.00034, fnr: 0.00069, rec: 0.99931, prc: 0.99239, f1: 0.99583, f1_macro: 0.99782
# epoch: 20, passed number of graphs: 672, train running loss: 0.00079 (passed time: 54m 44s)
#           acc: 0.99970, fpr: 0.00031, fnr: 0.00008, rec: 0.99992, prc: 0.99300, f1: 0.99645, f1_macro: 0.99814
# epoch: 20, passed number of graphs: 768, train running loss: 0.00076 (passed time: 55m 2s)
#           acc: 0.99980, fpr: 0.00019, fnr: 0.00025, rec: 0.99975, prc: 0.99555, f1: 0.99765, f1_macro: 0.99877
# Validation --- epoch: 20, loss: 0.00186
#           f1: 0.99453, fnr: 0.00534, f1_macro: 0.99721, fpr: 0.00010, acc: 0.99978, prc: 0.99559, rec: 0.99466
# epoch: 21, passed number of graphs: 96, train running loss: 0.00046 (passed time: 55m 41s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00020, rec: 0.99980, prc: 0.99533, f1: 0.99756, f1_macro: 0.99872
# epoch: 21, passed number of graphs: 192, train running loss: 0.00047 (passed time: 55m 59s)
#           acc: 0.99924, fpr: 0.00078, fnr: 0.00025, rec: 0.99975, prc: 0.98243, f1: 0.99101, f1_macro: 0.99531
# epoch: 21, passed number of graphs: 288, train running loss: 0.00045 (passed time: 56m 17s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00008, rec: 0.99992, prc: 0.99452, f1: 0.99721, f1_macro: 0.99854
# epoch: 21, passed number of graphs: 384, train running loss: 0.00054 (passed time: 56m 34s)
#           acc: 0.99975, fpr: 0.00024, fnr: 0.00037, rec: 0.99963, prc: 0.99461, f1: 0.99712, f1_macro: 0.99849
# epoch: 21, passed number of graphs: 480, train running loss: 0.00059 (passed time: 56m 52s)
#           acc: 0.99959, fpr: 0.00040, fnr: 0.00054, rec: 0.99946, prc: 0.99104, f1: 0.99523, f1_macro: 0.99751
# epoch: 21, passed number of graphs: 576, train running loss: 0.00055 (passed time: 57m 10s)
#           acc: 0.99967, fpr: 0.00031, fnr: 0.00073, rec: 0.99927, prc: 0.99303, f1: 0.99614, f1_macro: 0.99798
# epoch: 21, passed number of graphs: 672, train running loss: 0.00054 (passed time: 57m 28s)
#           acc: 0.99968, fpr: 0.00033, fnr: 0.00008, rec: 0.99992, prc: 0.99260, f1: 0.99624, f1_macro: 0.99804
# epoch: 21, passed number of graphs: 768, train running loss: 0.00054 (passed time: 57m 46s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00021, rec: 0.99979, prc: 0.99564, f1: 0.99771, f1_macro: 0.99881
# Validation --- epoch: 21, loss: 0.00183
#           f1: 0.99442, fnr: 0.00517, f1_macro: 0.99715, fpr: 0.00011, acc: 0.99978, prc: 0.99523, rec: 0.99483
# epoch: 22, passed number of graphs: 96, train running loss: 0.00045 (passed time: 58m 25s)
#           acc: 0.99980, fpr: 0.00019, fnr: 0.00024, rec: 0.99976, prc: 0.99565, f1: 0.99770, f1_macro: 0.99880
# epoch: 22, passed number of graphs: 192, train running loss: 0.00046 (passed time: 58m 43s)
#           acc: 0.99923, fpr: 0.00080, fnr: 0.00021, rec: 0.99979, prc: 0.98207, f1: 0.99085, f1_macro: 0.99522
# epoch: 22, passed number of graphs: 288, train running loss: 0.00044 (passed time: 59m 1s)
#           acc: 0.99977, fpr: 0.00024, fnr: 0.00012, rec: 0.99988, prc: 0.99464, f1: 0.99725, f1_macro: 0.99857
# epoch: 22, passed number of graphs: 384, train running loss: 0.00052 (passed time: 59m 19s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00029, rec: 0.99971, prc: 0.99457, f1: 0.99714, f1_macro: 0.99850
# epoch: 22, passed number of graphs: 480, train running loss: 0.00056 (passed time: 59m 37s)
#           acc: 0.99962, fpr: 0.00038, fnr: 0.00050, rec: 0.99950, prc: 0.99153, f1: 0.99550, f1_macro: 0.99765
# epoch: 22, passed number of graphs: 576, train running loss: 0.00053 (passed time: 59m 55s)
#           acc: 0.99966, fpr: 0.00032, fnr: 0.00069, rec: 0.99931, prc: 0.99279, f1: 0.99604, f1_macro: 0.99793
# epoch: 22, passed number of graphs: 672, train running loss: 0.00052 (passed time: 1h 0m 13s)
#           acc: 0.99969, fpr: 0.00032, fnr: 0.00008, rec: 0.99992, prc: 0.99280, f1: 0.99635, f1_macro: 0.99809
# epoch: 22, passed number of graphs: 768, train running loss: 0.00052 (passed time: 1h 0m 30s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00017, rec: 0.99983, prc: 0.99572, f1: 0.99777, f1_macro: 0.99884
# Validation --- epoch: 22, loss: 0.00181
#           f1: 0.99435, fnr: 0.00517, f1_macro: 0.99712, fpr: 0.00011, acc: 0.99978, prc: 0.99511, rec: 0.99483
# epoch: 23, passed number of graphs: 96, train running loss: 0.00044 (passed time: 1h 1m 10s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00020, rec: 0.99980, prc: 0.99590, f1: 0.99784, f1_macro: 0.99887
# epoch: 23, passed number of graphs: 192, train running loss: 0.00045 (passed time: 1h 1m 28s)
#           acc: 0.99922, fpr: 0.00080, fnr: 0.00021, rec: 0.99979, prc: 0.98203, f1: 0.99083, f1_macro: 0.99521
# epoch: 23, passed number of graphs: 288, train running loss: 0.00043 (passed time: 1h 1m 46s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00012, rec: 0.99988, prc: 0.99456, f1: 0.99721, f1_macro: 0.99854
# epoch: 23, passed number of graphs: 384, train running loss: 0.00050 (passed time: 1h 2m 3s)
#           acc: 0.99976, fpr: 0.00024, fnr: 0.00025, rec: 0.99975, prc: 0.99474, f1: 0.99724, f1_macro: 0.99856
# epoch: 23, passed number of graphs: 480, train running loss: 0.00054 (passed time: 1h 2m 21s)
#           acc: 0.99964, fpr: 0.00035, fnr: 0.00050, rec: 0.99950, prc: 0.99210, f1: 0.99579, f1_macro: 0.99780
# epoch: 23, passed number of graphs: 576, train running loss: 0.00051 (passed time: 1h 2m 39s)
#           acc: 0.99966, fpr: 0.00032, fnr: 0.00073, rec: 0.99927, prc: 0.99279, f1: 0.99602, f1_macro: 0.99792
# epoch: 23, passed number of graphs: 672, train running loss: 0.00050 (passed time: 1h 2m 57s)
#           acc: 0.99969, fpr: 0.00032, fnr: 0.00008, rec: 0.99992, prc: 0.99288, f1: 0.99639, f1_macro: 0.99811
# epoch: 23, passed number of graphs: 768, train running loss: 0.00050 (passed time: 1h 3m 15s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00017, rec: 0.99983, prc: 0.99584, f1: 0.99783, f1_macro: 0.99887
# Validation --- epoch: 23, loss: 0.00180
#           f1: 0.99425, fnr: 0.00522, f1_macro: 0.99707, fpr: 0.00012, acc: 0.99977, prc: 0.99499, rec: 0.99478
# epoch: 24, passed number of graphs: 96, train running loss: 0.00044 (passed time: 1h 3m 54s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00020, rec: 0.99980, prc: 0.99590, f1: 0.99784, f1_macro: 0.99887
# epoch: 24, passed number of graphs: 192, train running loss: 0.00044 (passed time: 1h 4m 12s)
#           acc: 0.99923, fpr: 0.00080, fnr: 0.00021, rec: 0.99979, prc: 0.98207, f1: 0.99085, f1_macro: 0.99522
# epoch: 24, passed number of graphs: 288, train running loss: 0.00042 (passed time: 1h 4m 30s)
#           acc: 0.99977, fpr: 0.00024, fnr: 0.00012, rec: 0.99988, prc: 0.99460, f1: 0.99723, f1_macro: 0.99855
# epoch: 24, passed number of graphs: 384, train running loss: 0.00048 (passed time: 1h 4m 48s)
#           acc: 0.99977, fpr: 0.00023, fnr: 0.00025, rec: 0.99975, prc: 0.99494, f1: 0.99734, f1_macro: 0.99861
# epoch: 24, passed number of graphs: 480, train running loss: 0.00052 (passed time: 1h 5m 6s)
#           acc: 0.99965, fpr: 0.00035, fnr: 0.00050, rec: 0.99950, prc: 0.99227, f1: 0.99587, f1_macro: 0.99784
# epoch: 24, passed number of graphs: 576, train running loss: 0.00049 (passed time: 1h 5m 24s)
#           acc: 0.99966, fpr: 0.00033, fnr: 0.00073, rec: 0.99927, prc: 0.99271, f1: 0.99598, f1_macro: 0.99790
# epoch: 24, passed number of graphs: 672, train running loss: 0.00049 (passed time: 1h 5m 42s)
#           acc: 0.99970, fpr: 0.00031, fnr: 0.00008, rec: 0.99992, prc: 0.99292, f1: 0.99641, f1_macro: 0.99812
# epoch: 24, passed number of graphs: 768, train running loss: 0.00049 (passed time: 1h 6m 0s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00017, rec: 0.99983, prc: 0.99584, f1: 0.99783, f1_macro: 0.99887
# Validation --- epoch: 24, loss: 0.00179
#           f1: 0.99421, fnr: 0.00519, f1_macro: 0.99704, fpr: 0.00012, acc: 0.99977, prc: 0.99489, rec: 0.99481
# epoch: 25, passed number of graphs: 96, train running loss: 0.00043 (passed time: 1h 6m 39s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00020, rec: 0.99980, prc: 0.99598, f1: 0.99788, f1_macro: 0.99889
# epoch: 25, passed number of graphs: 192, train running loss: 0.00044 (passed time: 1h 6m 57s)
#           acc: 0.99922, fpr: 0.00080, fnr: 0.00025, rec: 0.99975, prc: 0.98207, f1: 0.99083, f1_macro: 0.99521
# epoch: 25, passed number of graphs: 288, train running loss: 0.00041 (passed time: 1h 7m 15s)
#           acc: 0.99977, fpr: 0.00023, fnr: 0.00012, rec: 0.99988, prc: 0.99468, f1: 0.99727, f1_macro: 0.99858
# epoch: 25, passed number of graphs: 384, train running loss: 0.00047 (passed time: 1h 7m 33s)
#           acc: 0.99977, fpr: 0.00023, fnr: 0.00025, rec: 0.99975, prc: 0.99486, f1: 0.99730, f1_macro: 0.99859
# ...
# epoch: 42, passed number of graphs: 288, train running loss: 0.00036 (passed time: 1h 53m 56s)
#           acc: 0.99977, fpr: 0.00023, fnr: 0.00004, rec: 0.99996, prc: 0.99468, f1: 0.99731, f1_macro: 0.99860
# epoch: 42, passed number of graphs: 384, train running loss: 0.00039 (passed time: 1h 54m 13s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00033, rec: 0.99967, prc: 0.99539, f1: 0.99752, f1_macro: 0.99871
# epoch: 42, passed number of graphs: 480, train running loss: 0.00041 (passed time: 1h 54m 31s)
#           acc: 0.99969, fpr: 0.00031, fnr: 0.00037, rec: 0.99963, prc: 0.99313, f1: 0.99637, f1_macro: 0.99810
# epoch: 42, passed number of graphs: 576, train running loss: 0.00039 (passed time: 1h 54m 49s)
#           acc: 0.99966, fpr: 0.00032, fnr: 0.00082, rec: 0.99918, prc: 0.99283, f1: 0.99600, f1_macro: 0.99791
# epoch: 42, passed number of graphs: 672, train running loss: 0.00039 (passed time: 1h 55m 7s)
#           acc: 0.99971, fpr: 0.00029, fnr: 0.00012, rec: 0.99988, prc: 0.99340, f1: 0.99663, f1_macro: 0.99824
# epoch: 42, passed number of graphs: 768, train running loss: 0.00040 (passed time: 1h 55m 25s)
#           acc: 0.99985, fpr: 0.00016, fnr: 0.00012, rec: 0.99988, prc: 0.99646, f1: 0.99816, f1_macro: 0.99904
# Validation --- epoch: 42, loss: 0.00169
#           f1: 0.99409, fnr: 0.00506, f1_macro: 0.99699, fpr: 0.00013, acc: 0.99976, prc: 0.99457, rec: 0.99494
# epoch: 43, passed number of graphs: 96, train running loss: 0.00039 (passed time: 1h 56m 5s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00016, rec: 0.99984, prc: 0.99695, f1: 0.99839, f1_macro: 0.99916
# epoch: 43, passed number of graphs: 192, train running loss: 0.00039 (passed time: 1h 56m 23s)
#           acc: 0.99924, fpr: 0.00078, fnr: 0.00021, rec: 0.99979, prc: 0.98243, f1: 0.99104, f1_macro: 0.99532
# epoch: 43, passed number of graphs: 288, train running loss: 0.00036 (passed time: 1h 56m 40s)
#           acc: 0.99977, fpr: 0.00024, fnr: 0.00004, rec: 0.99996, prc: 0.99464, f1: 0.99729, f1_macro: 0.99859
# epoch: 43, passed number of graphs: 384, train running loss: 0.00038 (passed time: 1h 56m 58s)
#           acc: 0.99978, fpr: 0.00021, fnr: 0.00033, rec: 0.99967, prc: 0.99526, f1: 0.99746, f1_macro: 0.99867
# epoch: 43, passed number of graphs: 480, train running loss: 0.00041 (passed time: 1h 57m 16s)
#           acc: 0.99969, fpr: 0.00030, fnr: 0.00037, rec: 0.99963, prc: 0.99321, f1: 0.99641, f1_macro: 0.99812
# epoch: 43, passed number of graphs: 576, train running loss: 0.00039 (passed time: 1h 57m 34s)
#           acc: 0.99966, fpr: 0.00032, fnr: 0.00082, rec: 0.99918, prc: 0.99291, f1: 0.99604, f1_macro: 0.99793
# epoch: 43, passed number of graphs: 672, train running loss: 0.00039 (passed time: 1h 57m 52s)
#           acc: 0.99971, fpr: 0.00029, fnr: 0.00012, rec: 0.99988, prc: 0.99340, f1: 0.99663, f1_macro: 0.99824
# epoch: 43, passed number of graphs: 768, train running loss: 0.00039 (passed time: 1h 58m 10s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00012, rec: 0.99988, prc: 0.99658, f1: 0.99823, f1_macro: 0.99907
# Validation --- epoch: 43, loss: 0.00168
#           f1: 0.99410, fnr: 0.00505, f1_macro: 0.99699, fpr: 0.00013, acc: 0.99976, prc: 0.99458, rec: 0.99495
# epoch: 44, passed number of graphs: 96, train running loss: 0.00039 (passed time: 1h 58m 49s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00016, rec: 0.99984, prc: 0.99695, f1: 0.99839, f1_macro: 0.99916
# epoch: 44, passed number of graphs: 192, train running loss: 0.00038 (passed time: 1h 59m 7s)
#           acc: 0.99924, fpr: 0.00078, fnr: 0.00021, rec: 0.99979, prc: 0.98247, f1: 0.99106, f1_macro: 0.99533
# epoch: 44, passed number of graphs: 288, train running loss: 0.00036 (passed time: 1h 59m 25s)
#           acc: 0.99977, fpr: 0.00023, fnr: 0.00004, rec: 0.99996, prc: 0.99468, f1: 0.99731, f1_macro: 0.99860
# epoch: 44, passed number of graphs: 384, train running loss: 0.00038 (passed time: 1h 59m 43s)
#           acc: 0.99979, fpr: 0.00020, fnr: 0.00037, rec: 0.99963, prc: 0.99551, f1: 0.99757, f1_macro: 0.99873
# epoch: 44, passed number of graphs: 480, train running loss: 0.00040 (passed time: 2h 0m 1s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00037, rec: 0.99963, prc: 0.99329, f1: 0.99645, f1_macro: 0.99815
# epoch: 44, passed number of graphs: 576, train running loss: 0.00038 (passed time: 2h 0m 19s)
#           acc: 0.99966, fpr: 0.00032, fnr: 0.00082, rec: 0.99918, prc: 0.99291, f1: 0.99604, f1_macro: 0.99793
# epoch: 44, passed number of graphs: 672, train running loss: 0.00038 (passed time: 2h 0m 37s)
#           acc: 0.99972, fpr: 0.00029, fnr: 0.00012, rec: 0.99988, prc: 0.99348, f1: 0.99667, f1_macro: 0.99826
# epoch: 44, passed number of graphs: 768, train running loss: 0.00039 (passed time: 2h 0m 55s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00012, rec: 0.99988, prc: 0.99662, f1: 0.99825, f1_macro: 0.99908
# Validation --- epoch: 44, loss: 0.00170
#           f1: 0.99406, fnr: 0.00502, f1_macro: 0.99697, fpr: 0.00013, acc: 0.99976, prc: 0.99448, rec: 0.99498
# epoch: 45, passed number of graphs: 96, train running loss: 0.00039 (passed time: 2h 1m 34s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00016, rec: 0.99984, prc: 0.99683, f1: 0.99833, f1_macro: 0.99913
# epoch: 45, passed number of graphs: 192, train running loss: 0.00038 (passed time: 2h 1m 52s)
#           acc: 0.99924, fpr: 0.00079, fnr: 0.00021, rec: 0.99979, prc: 0.98231, f1: 0.99097, f1_macro: 0.99529
# epoch: 45, passed number of graphs: 288, train running loss: 0.00036 (passed time: 2h 2m 10s)
#           acc: 0.99977, fpr: 0.00024, fnr: 0.00004, rec: 0.99996, prc: 0.99464, f1: 0.99729, f1_macro: 0.99859
# epoch: 45, passed number of graphs: 384, train running loss: 0.00038 (passed time: 2h 2m 28s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00033, rec: 0.99967, prc: 0.99539, f1: 0.99752, f1_macro: 0.99871
# epoch: 45, passed number of graphs: 480, train running loss: 0.00040 (passed time: 2h 2m 46s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00037, rec: 0.99963, prc: 0.99338, f1: 0.99649, f1_macro: 0.99817
# epoch: 45, passed number of graphs: 576, train running loss: 0.00038 (passed time: 2h 3m 4s)
#           acc: 0.99966, fpr: 0.00032, fnr: 0.00077, rec: 0.99923, prc: 0.99295, f1: 0.99608, f1_macro: 0.99795
# epoch: 45, passed number of graphs: 672, train running loss: 0.00038 (passed time: 2h 3m 22s)
#           acc: 0.99971, fpr: 0.00029, fnr: 0.00012, rec: 0.99988, prc: 0.99340, f1: 0.99663, f1_macro: 0.99824
# epoch: 45, passed number of graphs: 768, train running loss: 0.00039 (passed time: 2h 3m 40s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00012, rec: 0.99988, prc: 0.99654, f1: 0.99820, f1_macro: 0.99906
# Validation --- epoch: 45, loss: 0.00168
#           f1: 0.99409, fnr: 0.00504, f1_macro: 0.99698, fpr: 0.00013, acc: 0.99976, prc: 0.99454, rec: 0.99496
# epoch: 46, passed number of graphs: 96, train running loss: 0.00039 (passed time: 2h 4m 20s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00016, rec: 0.99984, prc: 0.99695, f1: 0.99839, f1_macro: 0.99916
# epoch: 46, passed number of graphs: 192, train running loss: 0.00038 (passed time: 2h 4m 38s)
#           acc: 0.99924, fpr: 0.00079, fnr: 0.00021, rec: 0.99979, prc: 0.98235, f1: 0.99100, f1_macro: 0.99530
# epoch: 46, passed number of graphs: 288, train running loss: 0.00035 (passed time: 2h 4m 56s)
#           acc: 0.99977, fpr: 0.00024, fnr: 0.00004, rec: 0.99996, prc: 0.99456, f1: 0.99725, f1_macro: 0.99857
# epoch: 46, passed number of graphs: 384, train running loss: 0.00038 (passed time: 2h 5m 14s)
#           acc: 0.99979, fpr: 0.00020, fnr: 0.00037, rec: 0.99963, prc: 0.99551, f1: 0.99757, f1_macro: 0.99873
# epoch: 46, passed number of graphs: 480, train running loss: 0.00040 (passed time: 2h 5m 31s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00033, rec: 0.99967, prc: 0.99338, f1: 0.99651, f1_macro: 0.99818
# epoch: 46, passed number of graphs: 576, train running loss: 0.00038 (passed time: 2h 5m 49s)
#           acc: 0.99967, fpr: 0.00031, fnr: 0.00077, rec: 0.99923, prc: 0.99299, f1: 0.99610, f1_macro: 0.99796
# epoch: 46, passed number of graphs: 672, train running loss: 0.00038 (passed time: 2h 6m 7s)
#           acc: 0.99971, fpr: 0.00029, fnr: 0.00012, rec: 0.99988, prc: 0.99340, f1: 0.99663, f1_macro: 0.99824
# epoch: 46, passed number of graphs: 768, train running loss: 0.00039 (passed time: 2h 6m 25s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00012, rec: 0.99988, prc: 0.99662, f1: 0.99825, f1_macro: 0.99908
# Validation --- epoch: 46, loss: 0.00167
#           f1: 0.99408, fnr: 0.00505, f1_macro: 0.99698, fpr: 0.00013, acc: 0.99976, prc: 0.99455, rec: 0.99495
# epoch: 47, passed number of graphs: 96, train running loss: 0.00039 (passed time: 2h 7m 5s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00016, rec: 0.99984, prc: 0.99691, f1: 0.99837, f1_macro: 0.99915
# epoch: 47, passed number of graphs: 192, train running loss: 0.00038 (passed time: 2h 7m 23s)
#           acc: 0.99924, fpr: 0.00079, fnr: 0.00021, rec: 0.99979, prc: 0.98231, f1: 0.99097, f1_macro: 0.99529
# epoch: 47, passed number of graphs: 288, train running loss: 0.00035 (passed time: 2h 7m 41s)
#           acc: 0.99977, fpr: 0.00024, fnr: 0.00004, rec: 0.99996, prc: 0.99464, f1: 0.99729, f1_macro: 0.99859
# epoch: 47, passed number of graphs: 384, train running loss: 0.00037 (passed time: 2h 7m 59s)
#           acc: 0.99979, fpr: 0.00020, fnr: 0.00037, rec: 0.99963, prc: 0.99547, f1: 0.99754, f1_macro: 0.99872
# epoch: 47, passed number of graphs: 480, train running loss: 0.00040 (passed time: 2h 8m 17s)
#           acc: 0.99971, fpr: 0.00029, fnr: 0.00033, rec: 0.99967, prc: 0.99346, f1: 0.99655, f1_macro: 0.99820
# epoch: 47, passed number of graphs: 576, train running loss: 0.00038 (passed time: 2h 8m 35s)
#           acc: 0.99967, fpr: 0.00031, fnr: 0.00077, rec: 0.99923, prc: 0.99303, f1: 0.99612, f1_macro: 0.99797
# epoch: 47, passed number of graphs: 672, train running loss: 0.00038 (passed time: 2h 8m 53s)
#           acc: 0.99971, fpr: 0.00029, fnr: 0.00012, rec: 0.99988, prc: 0.99340, f1: 0.99663, f1_macro: 0.99824
# epoch: 47, passed number of graphs: 768, train running loss: 0.00039 (passed time: 2h 9m 11s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00012, rec: 0.99988, prc: 0.99670, f1: 0.99829, f1_macro: 0.99911
# Validation --- epoch: 47, loss: 0.00170
#           f1: 0.99404, fnr: 0.00498, f1_macro: 0.99696, fpr: 0.00013, acc: 0.99976, prc: 0.99440, rec: 0.99502
# epoch: 48, passed number of graphs: 96, train running loss: 0.00039 (passed time: 2h 9m 50s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00016, rec: 0.99984, prc: 0.99695, f1: 0.99839, f1_macro: 0.99916
# epoch: 48, passed number of graphs: 192, train running loss: 0.00038 (passed time: 2h 10m 8s)
#           acc: 0.99923, fpr: 0.00079, fnr: 0.00021, rec: 0.99979, prc: 0.98227, f1: 0.99095, f1_macro: 0.99528
# epoch: 48, passed number of graphs: 288, train running loss: 0.00035 (passed time: 2h 10m 26s)
#           acc: 0.99977, fpr: 0.00023, fnr: 0.00004, rec: 0.99996, prc: 0.99468, f1: 0.99731, f1_macro: 0.99860
# epoch: 48, passed number of graphs: 384, train running loss: 0.00037 (passed time: 2h 10m 44s)
#           acc: 0.99979, fpr: 0.00020, fnr: 0.00041, rec: 0.99959, prc: 0.99547, f1: 0.99752, f1_macro: 0.99871
# epoch: 48, passed number of graphs: 480, train running loss: 0.00039 (passed time: 2h 11m 2s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00033, rec: 0.99967, prc: 0.99338, f1: 0.99651, f1_macro: 0.99818
# epoch: 48, passed number of graphs: 576, train running loss: 0.00038 (passed time: 2h 11m 20s)
#           acc: 0.99967, fpr: 0.00031, fnr: 0.00077, rec: 0.99923, prc: 0.99299, f1: 0.99610, f1_macro: 0.99796
# epoch: 48, passed number of graphs: 672, train running loss: 0.00038 (passed time: 2h 11m 38s)
#           acc: 0.99971, fpr: 0.00029, fnr: 0.00012, rec: 0.99988, prc: 0.99340, f1: 0.99663, f1_macro: 0.99824
# epoch: 48, passed number of graphs: 768, train running loss: 0.00038 (passed time: 2h 11m 56s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00012, rec: 0.99988, prc: 0.99666, f1: 0.99827, f1_macro: 0.99910
# Validation --- epoch: 48, loss: 0.00167
#           f1: 0.99407, fnr: 0.00502, f1_macro: 0.99697, fpr: 0.00013, acc: 0.99976, prc: 0.99450, rec: 0.99498
# epoch: 49, passed number of graphs: 96, train running loss: 0.00039 (passed time: 2h 12m 36s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00016, rec: 0.99984, prc: 0.99671, f1: 0.99827, f1_macro: 0.99910
# epoch: 49, passed number of graphs: 192, train running loss: 0.00038 (passed time: 2h 12m 54s)
#           acc: 0.99926, fpr: 0.00076, fnr: 0.00021, rec: 0.99979, prc: 0.98283, f1: 0.99124, f1_macro: 0.99543
# epoch: 49, passed number of graphs: 288, train running loss: 0.00035 (passed time: 2h 13m 11s)
#           acc: 0.99977, fpr: 0.00023, fnr: 0.00004, rec: 0.99996, prc: 0.99468, f1: 0.99731, f1_macro: 0.99860
# epoch: 49, passed number of graphs: 384, train running loss: 0.00037 (passed time: 2h 13m 29s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00029, rec: 0.99971, prc: 0.99530, f1: 0.99750, f1_macro: 0.99870
# epoch: 49, passed number of graphs: 480, train running loss: 0.00039 (passed time: 2h 13m 47s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00033, rec: 0.99967, prc: 0.99325, f1: 0.99645, f1_macro: 0.99815
# epoch: 49, passed number of graphs: 576, train running loss: 0.00037 (passed time: 2h 14m 5s)
#           acc: 0.99966, fpr: 0.00032, fnr: 0.00073, rec: 0.99927, prc: 0.99279, f1: 0.99602, f1_macro: 0.99792
# epoch: 49, passed number of graphs: 672, train running loss: 0.00037 (passed time: 2h 14m 23s)
#           acc: 0.99972, fpr: 0.00029, fnr: 0.00012, rec: 0.99988, prc: 0.99352, f1: 0.99669, f1_macro: 0.99827
# epoch: 49, passed number of graphs: 768, train running loss: 0.00038 (passed time: 2h 14m 41s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00012, rec: 0.99988, prc: 0.99679, f1: 0.99833, f1_macro: 0.99913
# Validation --- epoch: 49, loss: 0.00166
#           f1: 0.99409, fnr: 0.00504, f1_macro: 0.99698, fpr: 0.00013, acc: 0.99976, prc: 0.99455, rec: 0.99496
# epoch: 50, passed number of graphs: 96, train running loss: 0.00038 (passed time: 2h 15m 21s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00016, rec: 0.99984, prc: 0.99662, f1: 0.99823, f1_macro: 0.99907
# epoch: 50, passed number of graphs: 192, train running loss: 0.00037 (passed time: 2h 15m 39s)
#           acc: 0.99925, fpr: 0.00077, fnr: 0.00021, rec: 0.99979, prc: 0.98275, f1: 0.99120, f1_macro: 0.99540
# epoch: 50, passed number of graphs: 288, train running loss: 0.00035 (passed time: 2h 15m 57s)
#           acc: 0.99978, fpr: 0.00023, fnr: 0.00004, rec: 0.99996, prc: 0.99472, f1: 0.99733, f1_macro: 0.99861
# epoch: 50, passed number of graphs: 384, train running loss: 0.00036 (passed time: 2h 16m 14s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00029, rec: 0.99971, prc: 0.99530, f1: 0.99750, f1_macro: 0.99870
# epoch: 50, passed number of graphs: 480, train running loss: 0.00039 (passed time: 2h 16m 32s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00029, rec: 0.99971, prc: 0.99330, f1: 0.99649, f1_macro: 0.99817
# epoch: 50, passed number of graphs: 576, train running loss: 0.00037 (passed time: 2h 16m 50s)
#           acc: 0.99966, fpr: 0.00032, fnr: 0.00073, rec: 0.99927, prc: 0.99287, f1: 0.99606, f1_macro: 0.99794
# epoch: 50, passed number of graphs: 672, train running loss: 0.00037 (passed time: 2h 17m 8s)
#           acc: 0.99972, fpr: 0.00029, fnr: 0.00012, rec: 0.99988, prc: 0.99352, f1: 0.99669, f1_macro: 0.99827
# epoch: 50, passed number of graphs: 768, train running loss: 0.00038 (passed time: 2h 17m 26s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00012, rec: 0.99988, prc: 0.99679, f1: 0.99833, f1_macro: 0.99913
# Validation --- epoch: 50, loss: 0.00166
#           f1: 0.99409, fnr: 0.00504, f1_macro: 0.99698, fpr: 0.00013, acc: 0.99976, prc: 0.99455, rec: 0.99496
# ************ best model obtained after epoch 13, saved at ./saved_models/GIN_12: 0.9948805051129131.pt ************
# Testing --- loss: 0.00179
#           f1: 0.99413, fnr: 0.00368, f1_macro: 0.99700, fpr: 0.00017, acc: 0.99975, prc: 0.99265, rec: 0.99632

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !zip -r /content/GIN_053_12_Adam_P2P_6k_botnode_40hidim.zip /content/saved_models
# Out:
#   adding: content/saved_models/ (stored 0%)
#   adding: content/saved_models/GIN_1: 0.9689368954295715.pt (deflated 23%)
#   adding: content/saved_models/GIN_9: 0.9914907676247928.pt (deflated 22%)
#   adding: content/saved_models/GIN_4: 0.9853822159413236.pt (deflated 22%)
#   adding: content/saved_models/GIN_8: 0.9877178353059569.pt (deflated 22%)
#   adding: content/saved_models/GIN_0: 0.6647710410899228.pt (deflated 24%)
#   adding: content/saved_models/GIN_12: 0.9948805051129131.pt (deflated 22%)

# %%
from google.colab import files
files.download("/content/GIN_053_12_Adam_P2P_6k_botnode_40hidim.zip")

# %%
# from google.colab import runtime
# runtime.unassign()
