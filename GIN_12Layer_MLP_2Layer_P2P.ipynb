# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/Do_an_tot_nghiep/blob/main/GIN_12Layer_MLP_2Layer_P2P.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric==1.4.3
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter_
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric==1.4.3 in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.56.3)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.12.1+cu113)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (6.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.21.6)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.3.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.23.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.18.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.6.3)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.7.4)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->torch-geometric==1.4.3) (1.5.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (4.13.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (57.4.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (0.39.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (3.10.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.4.3) (1.15.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (0.6.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2.10)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2.9.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (1.3.0)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (3.2.2)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (7.1.2)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2021.11.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
        elif split == 'val':
            self.path = self.processed_paths[1]
        elif split == 'test':
            self.path = self.processed_paths[2]

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
            self.num_graphs = self.data['num_graphs']
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            with h5py.File(self.path, 'r') as f:
                self.num_graphs = f.attrs['num_graphs']
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GINConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_input_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), 
                             BatchNorm1d(self.dim_hidden_feature), ReLU())))
          else:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), 
                             BatchNorm1d(self.dim_hidden_feature), ReLU()))) 

        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                add_xr_at = n
            if n == add_xr_at:
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/P2P'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=False, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=True, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=True, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 2
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.0
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-9dd64b04-ed61-46b8-b360-0ab495cb2612.json
# ------------------------------
# ------------------------------
# Sun Nov  6 12:29:17 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GINConv(nn=Sequential(
#       (0): Linear(in_features=1, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     ))
#     (1): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     ))
#     (2): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     ))
#     (3): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     ))
#     (4): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     ))
#     (5): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     ))
#     (6): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     ))
#     (7): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     ))
#     (8): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     ))
#     (9): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     ))
#     (10): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     ))
#     (11): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#     ))
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 2
# epoch: 1, passed number of graphs: 96, train running loss: 0.07643 (passed time: 2m 13s)
#           acc: 0.97831, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 192, train running loss: 0.06041 (passed time: 2m 41s)
#           acc: 0.97863, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 288, train running loss: 0.05211 (passed time: 3m 9s)
#           acc: 0.97926, fpr: 0.00000, fnr: 0.97876, rec: 0.02124, prc: 1.00000, f1: 0.04160, f1_macro: 0.51556
# epoch: 1, passed number of graphs: 384, train running loss: 0.04617 (passed time: 3m 40s)
#           acc: 0.97921, fpr: 0.00034, fnr: 0.92911, rec: 0.07089, prc: 0.82552, f1: 0.13056, f1_macro: 0.56002
# epoch: 1, passed number of graphs: 480, train running loss: 0.03970 (passed time: 4m 13s)
#           acc: 0.99799, fpr: 0.00040, fnr: 0.07514, rec: 0.92486, prc: 0.98094, f1: 0.95208, f1_macro: 0.97552
# epoch: 1, passed number of graphs: 576, train running loss: 0.03410 (passed time: 4m 44s)
#           acc: 0.99836, fpr: 0.00002, fnr: 0.07554, rec: 0.92446, prc: 0.99895, f1: 0.96026, f1_macro: 0.97971
# epoch: 1, passed number of graphs: 672, train running loss: 0.03040 (passed time: 5m 14s)
#           acc: 0.98642, fpr: 0.00000, fnr: 0.62704, rec: 0.37296, prc: 1.00000, f1: 0.54330, f1_macro: 0.76820
# epoch: 1, passed number of graphs: 768, train running loss: 0.02726 (passed time: 5m 42s)
#           acc: 0.99823, fpr: 0.00001, fnr: 0.08320, rec: 0.91680, prc: 0.99964, f1: 0.95643, f1_macro: 0.97776
# Validation --- epoch: 1, loss: 0.01485
#           f1_macro: 0.93949, f1: 0.88108, fpr: 0.00003, rec: 0.81017, acc: 0.99587, prc: 0.99838, fnr: 0.18983
# Better model saved at ./saved_models/GIN_0: 0.8810832244838149.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.00448 (passed time: 6m 18s)
#           acc: 0.99862, fpr: 0.00100, fnr: 0.01818, rec: 0.98182, prc: 0.95589, f1: 0.96868, f1_macro: 0.98399
# epoch: 2, passed number of graphs: 192, train running loss: 0.00485 (passed time: 6m 46s)
#           acc: 0.99866, fpr: 0.00000, fnr: 0.06255, rec: 0.93745, prc: 1.00000, f1: 0.96771, f1_macro: 0.98352
# epoch: 2, passed number of graphs: 288, train running loss: 0.00446 (passed time: 7m 14s)
#           acc: 0.99970, fpr: 0.00017, fnr: 0.00654, rec: 0.99346, prc: 0.99233, f1: 0.99290, f1_macro: 0.99637
# epoch: 2, passed number of graphs: 384, train running loss: 0.00502 (passed time: 7m 42s)
#           acc: 0.99904, fpr: 0.00000, fnr: 0.04350, rec: 0.95650, prc: 1.00000, f1: 0.97777, f1_macro: 0.98864
# epoch: 2, passed number of graphs: 480, train running loss: 0.00670 (passed time: 8m 10s)
#           acc: 0.99954, fpr: 0.00026, fnr: 0.00964, rec: 0.99036, prc: 0.98843, f1: 0.98939, f1_macro: 0.99458
# epoch: 2, passed number of graphs: 576, train running loss: 0.00830 (passed time: 8m 38s)
#           acc: 0.99516, fpr: 0.00001, fnr: 0.22550, rec: 0.77450, prc: 0.99958, f1: 0.87276, f1_macro: 0.93515
# epoch: 2, passed number of graphs: 672, train running loss: 0.00823 (passed time: 9m 7s)
#           acc: 0.99612, fpr: 0.00029, fnr: 0.16587, rec: 0.83413, prc: 0.98435, f1: 0.90304, f1_macro: 0.95053
# epoch: 2, passed number of graphs: 768, train running loss: 0.00853 (passed time: 9m 35s)
#           acc: 0.99725, fpr: 0.00000, fnr: 0.12953, rec: 0.87047, prc: 1.00000, f1: 0.93075, f1_macro: 0.96467
# Validation --- epoch: 2, loss: 0.13985
#           f1_macro: nan, f1: 0.00000, fpr: 0.00000, rec: 0.00000, acc: 0.97848, prc: -1.00000, fnr: 1.00000
# epoch: 3, passed number of graphs: 96, train running loss: 0.00752 (passed time: 10m 11s)
#           acc: 0.99786, fpr: 0.00123, fnr: 0.04307, rec: 0.95693, prc: 0.94532, f1: 0.95109, f1_macro: 0.97500
# epoch: 3, passed number of graphs: 192, train running loss: 0.00659 (passed time: 10m 39s)
#           acc: 0.99903, fpr: 0.00000, fnr: 0.04540, rec: 0.95460, prc: 1.00000, f1: 0.97677, f1_macro: 0.98814
# epoch: 3, passed number of graphs: 288, train running loss: 0.00558 (passed time: 11m 7s)
#           acc: 0.99897, fpr: 0.00000, fnr: 0.04869, rec: 0.95131, prc: 1.00000, f1: 0.97505, f1_macro: 0.98726
# epoch: 3, passed number of graphs: 384, train running loss: 0.00950 (passed time: 11m 35s)
#           acc: 0.99883, fpr: 0.00000, fnr: 0.05284, rec: 0.94716, prc: 0.99983, f1: 0.97278, f1_macro: 0.98609
# epoch: 3, passed number of graphs: 480, train running loss: 0.00831 (passed time: 12m 3s)
#           acc: 0.99897, fpr: 0.00000, fnr: 0.04753, rec: 0.95247, prc: 1.00000, f1: 0.97565, f1_macro: 0.98756
# epoch: 3, passed number of graphs: 576, train running loss: 0.00764 (passed time: 12m 32s)
#           acc: 0.99895, fpr: 0.00000, fnr: 0.04923, rec: 0.95077, prc: 1.00000, f1: 0.97476, f1_macro: 0.98711
# epoch: 3, passed number of graphs: 672, train running loss: 0.00710 (passed time: 13m 0s)
#           acc: 0.99650, fpr: 0.00000, fnr: 0.16139, rec: 0.83861, prc: 0.99981, f1: 0.91214, f1_macro: 0.95518
# epoch: 3, passed number of graphs: 768, train running loss: 0.00660 (passed time: 13m 28s)
#           acc: 0.99840, fpr: 0.00057, fnr: 0.04894, rec: 0.95106, prc: 0.97313, f1: 0.96197, f1_macro: 0.98058
# Validation --- epoch: 3, loss: 0.13769
#           f1_macro: 0.50168, f1: 0.01624, fpr: 0.00418, rec: 0.00979, acc: 0.97460, prc: 0.04765, fnr: 0.99021
# epoch: 4, passed number of graphs: 96, train running loss: 0.00279 (passed time: 14m 4s)
#           acc: 0.99898, fpr: 0.00098, fnr: 0.00287, rec: 0.99713, prc: 0.95757, f1: 0.97695, f1_macro: 0.98821
# epoch: 4, passed number of graphs: 192, train running loss: 0.00293 (passed time: 14m 32s)
#           acc: 0.99989, fpr: 0.00000, fnr: 0.00506, rec: 0.99494, prc: 1.00000, f1: 0.99746, f1_macro: 0.99870
# epoch: 4, passed number of graphs: 288, train running loss: 0.00268 (passed time: 15m 0s)
#           acc: 0.99982, fpr: 0.00011, fnr: 0.00343, rec: 0.99657, prc: 0.99478, f1: 0.99567, f1_macro: 0.99779
# epoch: 4, passed number of graphs: 384, train running loss: 0.00235 (passed time: 15m 28s)
#           acc: 0.99944, fpr: 0.00000, fnr: 0.02513, rec: 0.97487, prc: 0.99983, f1: 0.98719, f1_macro: 0.99345
# epoch: 4, passed number of graphs: 480, train running loss: 0.00207 (passed time: 15m 57s)
#           acc: 0.99975, fpr: 0.00008, fnr: 0.00833, rec: 0.99167, prc: 0.99655, f1: 0.99411, f1_macro: 0.99699
# epoch: 4, passed number of graphs: 576, train running loss: 0.00224 (passed time: 16m 25s)
#           acc: 0.99262, fpr: 0.00073, fnr: 0.31138, rec: 0.68862, prc: 0.95394, f1: 0.79985, f1_macro: 0.89805
# epoch: 4, passed number of graphs: 672, train running loss: 0.00237 (passed time: 16m 53s)
#           acc: 0.99702, fpr: 0.00017, fnr: 0.12975, rec: 0.87025, prc: 0.99126, f1: 0.92682, f1_macro: 0.96265
# epoch: 4, passed number of graphs: 768, train running loss: 0.00244 (passed time: 17m 22s)
#           acc: 0.99749, fpr: 0.00229, fnr: 0.01256, rec: 0.98744, prc: 0.90330, f1: 0.94350, f1_macro: 0.97111
# Validation --- epoch: 4, loss: 0.01065
#           f1_macro: 0.97699, f1: 0.95489, fpr: 0.00004, rec: 0.91996, acc: 0.99823, prc: 0.99819, fnr: 0.08004
# Better model saved at ./saved_models/GIN_3: 0.9548877898863503.pt.
# epoch: 5, passed number of graphs: 96, train running loss: 0.00216 (passed time: 17m 57s)
#           acc: 0.99785, fpr: 0.00219, fnr: 0.00016, rec: 0.99984, prc: 0.90999, f1: 0.95280, f1_macro: 0.97585
# epoch: 5, passed number of graphs: 192, train running loss: 0.00249 (passed time: 18m 26s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00261, rec: 0.99739, prc: 1.00000, f1: 0.99869, f1_macro: 0.99933
# epoch: 5, passed number of graphs: 288, train running loss: 0.00229 (passed time: 18m 54s)
#           acc: 0.99981, fpr: 0.00014, fnr: 0.00245, rec: 0.99755, prc: 0.99365, f1: 0.99560, f1_macro: 0.99775
# epoch: 5, passed number of graphs: 384, train running loss: 0.00193 (passed time: 19m 22s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00387, rec: 0.99613, prc: 0.99968, f1: 0.99790, f1_macro: 0.99893
# epoch: 5, passed number of graphs: 480, train running loss: 0.00171 (passed time: 19m 50s)
#           acc: 0.99982, fpr: 0.00008, fnr: 0.00490, rec: 0.99510, prc: 0.99640, f1: 0.99575, f1_macro: 0.99783
# epoch: 5, passed number of graphs: 576, train running loss: 0.00189 (passed time: 20m 18s)
#           acc: 0.99344, fpr: 0.00004, fnr: 0.30476, rec: 0.69524, prc: 0.99768, f1: 0.81944, f1_macro: 0.90805
# epoch: 5, passed number of graphs: 672, train running loss: 0.00211 (passed time: 20m 46s)
#           acc: 0.99724, fpr: 0.00002, fnr: 0.12640, rec: 0.87360, prc: 0.99890, f1: 0.93206, f1_macro: 0.96533
# epoch: 5, passed number of graphs: 768, train running loss: 0.00215 (passed time: 21m 14s)
#           acc: 0.99937, fpr: 0.00062, fnr: 0.00098, rec: 0.99902, prc: 0.97222, f1: 0.98544, f1_macro: 0.99256
# Validation --- epoch: 5, loss: 0.00680
#           f1_macro: 0.98705, f1: 0.97459, fpr: 0.00007, rec: 0.95883, acc: 0.99904, prc: 0.99702, fnr: 0.04117
# Better model saved at ./saved_models/GIN_4: 0.9745871456094105.pt.
# epoch: 6, passed number of graphs: 96, train running loss: 0.00317 (passed time: 21m 49s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00016, rec: 0.99984, prc: 0.99445, f1: 0.99714, f1_macro: 0.99854
# epoch: 6, passed number of graphs: 192, train running loss: 0.00307 (passed time: 22m 17s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00196, rec: 0.99804, prc: 0.99918, f1: 0.99861, f1_macro: 0.99929
# epoch: 6, passed number of graphs: 288, train running loss: 0.00274 (passed time: 22m 45s)
#           acc: 0.99980, fpr: 0.00016, fnr: 0.00212, rec: 0.99788, prc: 0.99285, f1: 0.99535, f1_macro: 0.99763
# epoch: 6, passed number of graphs: 384, train running loss: 0.00228 (passed time: 23m 12s)
#           acc: 0.99989, fpr: 0.00003, fnr: 0.00354, rec: 0.99646, prc: 0.99871, f1: 0.99758, f1_macro: 0.99876
# epoch: 6, passed number of graphs: 480, train running loss: 0.00199 (passed time: 23m 39s)
#           acc: 0.99981, fpr: 0.00008, fnr: 0.00523, rec: 0.99477, prc: 0.99640, f1: 0.99559, f1_macro: 0.99774
# epoch: 6, passed number of graphs: 576, train running loss: 0.00191 (passed time: 24m 7s)
#           acc: 0.99981, fpr: 0.00015, fnr: 0.00226, rec: 0.99774, prc: 0.99325, f1: 0.99549, f1_macro: 0.99770
# epoch: 6, passed number of graphs: 672, train running loss: 0.00187 (passed time: 24m 34s)
#           acc: 0.99725, fpr: 0.00002, fnr: 0.12608, rec: 0.87392, prc: 0.99909, f1: 0.93232, f1_macro: 0.96546
# epoch: 6, passed number of graphs: 768, train running loss: 0.00185 (passed time: 25m 2s)
#           acc: 0.99990, fpr: 0.00005, fnr: 0.00228, rec: 0.99772, prc: 0.99772, f1: 0.99772, f1_macro: 0.99883
# Validation --- epoch: 6, loss: 0.02104
#           f1_macro: 0.94273, f1: 0.88813, fpr: 0.00481, rec: 0.97630, acc: 0.99478, prc: 0.81628, fnr: 0.02370
# epoch: 7, passed number of graphs: 96, train running loss: 0.00150 (passed time: 25m 36s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00000, rec: 1.00000, prc: 0.99698, f1: 0.99849, f1_macro: 0.99923
# epoch: 7, passed number of graphs: 192, train running loss: 0.00186 (passed time: 26m 3s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00278, rec: 0.99722, prc: 0.99984, f1: 0.99853, f1_macro: 0.99925
# epoch: 7, passed number of graphs: 288, train running loss: 0.00182 (passed time: 26m 30s)
#           acc: 0.99981, fpr: 0.00010, fnr: 0.00458, rec: 0.99542, prc: 0.99559, f1: 0.99551, f1_macro: 0.99770
# epoch: 7, passed number of graphs: 384, train running loss: 0.00156 (passed time: 26m 58s)
#           acc: 0.99989, fpr: 0.00002, fnr: 0.00403, rec: 0.99597, prc: 0.99919, f1: 0.99758, f1_macro: 0.99876
# epoch: 7, passed number of graphs: 480, train running loss: 0.00142 (passed time: 27m 25s)
#           acc: 0.99970, fpr: 0.00007, fnr: 0.01111, rec: 0.98889, prc: 0.99704, f1: 0.99295, f1_macro: 0.99640
# epoch: 7, passed number of graphs: 576, train running loss: 0.00141 (passed time: 27m 52s)
#           acc: 0.99963, fpr: 0.00037, fnr: 0.00048, rec: 0.99952, prc: 0.98333, f1: 0.99135, f1_macro: 0.99558
# epoch: 7, passed number of graphs: 672, train running loss: 0.00145 (passed time: 28m 20s)
#           acc: 0.99726, fpr: 0.00001, fnr: 0.12608, rec: 0.87392, prc: 0.99927, f1: 0.93240, f1_macro: 0.96550
# epoch: 7, passed number of graphs: 768, train running loss: 0.00145 (passed time: 28m 47s)
#           acc: 0.99991, fpr: 0.00006, fnr: 0.00114, rec: 0.99886, prc: 0.99707, f1: 0.99796, f1_macro: 0.99896
# Validation --- epoch: 7, loss: 0.00719
#           f1_macro: 0.98449, f1: 0.96960, fpr: 0.00005, rec: 0.94600, acc: 0.99879, prc: 0.99820, fnr: 0.05400
# epoch: 8, passed number of graphs: 96, train running loss: 0.00143 (passed time: 29m 22s)
#           acc: 0.99994, fpr: 0.00006, fnr: 0.00016, rec: 0.99984, prc: 0.99745, f1: 0.99865, f1_macro: 0.99931
# epoch: 8, passed number of graphs: 192, train running loss: 0.00182 (passed time: 29m 49s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99877, f1_macro: 0.99937
# epoch: 8, passed number of graphs: 288, train running loss: 0.00176 (passed time: 30m 16s)
#           acc: 0.99979, fpr: 0.00016, fnr: 0.00229, rec: 0.99771, prc: 0.99252, f1: 0.99511, f1_macro: 0.99750
# epoch: 8, passed number of graphs: 384, train running loss: 0.00152 (passed time: 30m 43s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00226, rec: 0.99774, prc: 0.99903, f1: 0.99839, f1_macro: 0.99918
# epoch: 8, passed number of graphs: 480, train running loss: 0.00138 (passed time: 31m 10s)
#           acc: 0.99975, fpr: 0.00014, fnr: 0.00539, rec: 0.99461, prc: 0.99380, f1: 0.99420, f1_macro: 0.99704
# epoch: 8, passed number of graphs: 576, train running loss: 0.00134 (passed time: 31m 37s)
#           acc: 0.99966, fpr: 0.00034, fnr: 0.00048, rec: 0.99952, prc: 0.98489, f1: 0.99215, f1_macro: 0.99599
# epoch: 8, passed number of graphs: 672, train running loss: 0.00139 (passed time: 32m 5s)
#           acc: 0.99724, fpr: 0.00003, fnr: 0.12640, rec: 0.87360, prc: 0.99854, f1: 0.93190, f1_macro: 0.96525
# epoch: 8, passed number of graphs: 768, train running loss: 0.00136 (passed time: 32m 32s)
#           acc: 0.99968, fpr: 0.00030, fnr: 0.00147, rec: 0.99853, prc: 0.98646, f1: 0.99246, f1_macro: 0.99615
# Validation --- epoch: 8, loss: 0.00280
#           f1_macro: 0.99448, f1: 0.98918, fpr: 0.00008, rec: 0.98469, acc: 0.99959, prc: 0.99620, fnr: 0.01531
# Better model saved at ./saved_models/GIN_7: 0.9891761061023726.pt.
# epoch: 9, passed number of graphs: 96, train running loss: 0.00114 (passed time: 33m 8s)
#           acc: 0.99993, fpr: 0.00006, fnr: 0.00016, rec: 0.99984, prc: 0.99714, f1: 0.99849, f1_macro: 0.99923
# epoch: 9, passed number of graphs: 192, train running loss: 0.00157 (passed time: 33m 36s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00147, rec: 0.99853, prc: 0.99951, f1: 0.99902, f1_macro: 0.99950
# epoch: 9, passed number of graphs: 288, train running loss: 0.00150 (passed time: 34m 3s)
#           acc: 0.99978, fpr: 0.00015, fnr: 0.00359, rec: 0.99641, prc: 0.99332, f1: 0.99486, f1_macro: 0.99737
# epoch: 9, passed number of graphs: 384, train running loss: 0.00130 (passed time: 34m 31s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00258, rec: 0.99742, prc: 0.99887, f1: 0.99815, f1_macro: 0.99905
# epoch: 9, passed number of graphs: 480, train running loss: 0.00121 (passed time: 34m 59s)
#           acc: 0.99976, fpr: 0.00013, fnr: 0.00490, rec: 0.99510, prc: 0.99396, f1: 0.99453, f1_macro: 0.99721
# epoch: 9, passed number of graphs: 576, train running loss: 0.00113 (passed time: 35m 27s)
#           acc: 0.99968, fpr: 0.00032, fnr: 0.00048, rec: 0.99952, prc: 0.98552, f1: 0.99247, f1_macro: 0.99615
# epoch: 9, passed number of graphs: 672, train running loss: 0.00120 (passed time: 35m 55s)
#           acc: 0.99724, fpr: 0.00002, fnr: 0.12624, rec: 0.87376, prc: 0.99872, f1: 0.93207, f1_macro: 0.96533
# epoch: 9, passed number of graphs: 768, train running loss: 0.00119 (passed time: 36m 23s)
#           acc: 0.99977, fpr: 0.00020, fnr: 0.00147, rec: 0.99853, prc: 0.99093, f1: 0.99472, f1_macro: 0.99730
# Validation --- epoch: 9, loss: 0.00266
#           f1_macro: 0.99478, f1: 0.98976, fpr: 0.00007, rec: 0.98549, acc: 0.99962, prc: 0.99657, fnr: 0.01451
# Better model saved at ./saved_models/GIN_8: 0.9897615707482945.pt.
# epoch: 10, passed number of graphs: 96, train running loss: 0.00106 (passed time: 36m 58s)
#           acc: 0.99994, fpr: 0.00005, fnr: 0.00016, rec: 0.99984, prc: 0.99761, f1: 0.99873, f1_macro: 0.99935
# epoch: 10, passed number of graphs: 192, train running loss: 0.00160 (passed time: 37m 26s)
#           acc: 0.99992, fpr: 0.00000, fnr: 0.00376, rec: 0.99624, prc: 0.99984, f1: 0.99804, f1_macro: 0.99900
# epoch: 10, passed number of graphs: 288, train running loss: 0.00154 (passed time: 37m 54s)
#           acc: 0.99978, fpr: 0.00014, fnr: 0.00392, rec: 0.99608, prc: 0.99364, f1: 0.99486, f1_macro: 0.99737
# epoch: 10, passed number of graphs: 384, train running loss: 0.00132 (passed time: 38m 21s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00193, rec: 0.99807, prc: 0.99871, f1: 0.99839, f1_macro: 0.99918
# epoch: 10, passed number of graphs: 480, train running loss: 0.00123 (passed time: 38m 49s)
#           acc: 0.99975, fpr: 0.00015, fnr: 0.00506, rec: 0.99494, prc: 0.99331, f1: 0.99412, f1_macro: 0.99700
# epoch: 10, passed number of graphs: 576, train running loss: 0.00114 (passed time: 39m 17s)
#           acc: 0.99967, fpr: 0.00033, fnr: 0.00032, rec: 0.99968, prc: 0.98521, f1: 0.99239, f1_macro: 0.99611
# epoch: 10, passed number of graphs: 672, train running loss: 0.00121 (passed time: 39m 45s)
#           acc: 0.99725, fpr: 0.00002, fnr: 0.12608, rec: 0.87392, prc: 0.99890, f1: 0.93224, f1_macro: 0.96542
# epoch: 10, passed number of graphs: 768, train running loss: 0.00119 (passed time: 40m 13s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00131, rec: 0.99869, prc: 0.99013, f1: 0.99440, f1_macro: 0.99714
# Validation --- epoch: 10, loss: 0.00264
#           f1_macro: 0.99468, f1: 0.98956, fpr: 0.00005, rec: 0.98403, acc: 0.99961, prc: 0.99766, fnr: 0.01597
# epoch: 11, passed number of graphs: 96, train running loss: 0.00100 (passed time: 40m 48s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00016, rec: 0.99984, prc: 0.99825, f1: 0.99904, f1_macro: 0.99951
# epoch: 11, passed number of graphs: 192, train running loss: 0.00147 (passed time: 41m 16s)
#           acc: 0.99991, fpr: 0.00000, fnr: 0.00408, rec: 0.99592, prc: 0.99984, f1: 0.99787, f1_macro: 0.99891
# epoch: 11, passed number of graphs: 288, train running loss: 0.00146 (passed time: 41m 43s)
#           acc: 0.99979, fpr: 0.00014, fnr: 0.00376, rec: 0.99624, prc: 0.99364, f1: 0.99494, f1_macro: 0.99742
# epoch: 11, passed number of graphs: 384, train running loss: 0.00126 (passed time: 42m 11s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00193, rec: 0.99807, prc: 0.99871, f1: 0.99839, f1_macro: 0.99918
# epoch: 11, passed number of graphs: 480, train running loss: 0.00117 (passed time: 42m 38s)
#           acc: 0.99981, fpr: 0.00011, fnr: 0.00376, rec: 0.99624, prc: 0.99511, f1: 0.99567, f1_macro: 0.99779
# epoch: 11, passed number of graphs: 576, train running loss: 0.00109 (passed time: 43m 6s)
#           acc: 0.99966, fpr: 0.00033, fnr: 0.00097, rec: 0.99903, prc: 0.98520, f1: 0.99207, f1_macro: 0.99595
# epoch: 11, passed number of graphs: 672, train running loss: 0.00118 (passed time: 43m 34s)
#           acc: 0.99724, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99945, f1: 0.93203, f1_macro: 0.96531
# epoch: 11, passed number of graphs: 768, train running loss: 0.00116 (passed time: 44m 2s)
#           acc: 0.99965, fpr: 0.00033, fnr: 0.00131, rec: 0.99869, prc: 0.98504, f1: 0.99182, f1_macro: 0.99582
# Validation --- epoch: 11, loss: 0.00254
#           f1_macro: 0.99476, f1: 0.98971, fpr: 0.00008, rec: 0.98559, acc: 0.99961, prc: 0.99632, fnr: 0.01441
# epoch: 12, passed number of graphs: 96, train running loss: 0.00099 (passed time: 44m 37s)
#           acc: 0.99997, fpr: 0.00003, fnr: 0.00016, rec: 0.99984, prc: 0.99857, f1: 0.99920, f1_macro: 0.99959
# epoch: 12, passed number of graphs: 192, train running loss: 0.00173 (passed time: 45m 5s)
#           acc: 0.99979, fpr: 0.00001, fnr: 0.00931, rec: 0.99069, prc: 0.99967, f1: 0.99516, f1_macro: 0.99753
# epoch: 12, passed number of graphs: 288, train running loss: 0.00195 (passed time: 45m 33s)
#           acc: 0.99981, fpr: 0.00014, fnr: 0.00245, rec: 0.99755, prc: 0.99365, f1: 0.99560, f1_macro: 0.99775
# epoch: 12, passed number of graphs: 384, train running loss: 0.00175 (passed time: 46m 1s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00242, rec: 0.99758, prc: 0.99887, f1: 0.99823, f1_macro: 0.99909
# epoch: 12, passed number of graphs: 480, train running loss: 0.00158 (passed time: 46m 29s)
#           acc: 0.99983, fpr: 0.00010, fnr: 0.00310, rec: 0.99690, prc: 0.99543, f1: 0.99616, f1_macro: 0.99804
# epoch: 12, passed number of graphs: 576, train running loss: 0.00156 (passed time: 46m 56s)
#           acc: 0.99966, fpr: 0.00033, fnr: 0.00081, rec: 0.99919, prc: 0.98504, f1: 0.99207, f1_macro: 0.99595
# epoch: 12, passed number of graphs: 672, train running loss: 0.00158 (passed time: 47m 24s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12640, rec: 0.87360, prc: 0.99927, f1: 0.93222, f1_macro: 0.96541
# epoch: 12, passed number of graphs: 768, train running loss: 0.00157 (passed time: 47m 51s)
#           acc: 0.99992, fpr: 0.00006, fnr: 0.00098, rec: 0.99902, prc: 0.99739, f1: 0.99821, f1_macro: 0.99908
# Validation --- epoch: 12, loss: 0.00304
#           f1_macro: 0.99369, f1: 0.98762, fpr: 0.00009, rec: 0.98186, acc: 0.99953, prc: 0.99633, fnr: 0.01814
# epoch: 13, passed number of graphs: 96, train running loss: 0.00137 (passed time: 48m 27s)
#           acc: 0.99997, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99888, f1: 0.99928, f1_macro: 0.99963
# epoch: 13, passed number of graphs: 192, train running loss: 0.00178 (passed time: 48m 54s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00147, rec: 0.99853, prc: 0.99951, f1: 0.99902, f1_macro: 0.99950
# epoch: 13, passed number of graphs: 288, train running loss: 0.00177 (passed time: 49m 22s)
#           acc: 0.99981, fpr: 0.00009, fnr: 0.00474, rec: 0.99526, prc: 0.99591, f1: 0.99559, f1_macro: 0.99775
# epoch: 13, passed number of graphs: 384, train running loss: 0.00154 (passed time: 49m 50s)
#           acc: 0.99990, fpr: 0.00002, fnr: 0.00371, rec: 0.99629, prc: 0.99903, f1: 0.99766, f1_macro: 0.99880
# epoch: 13, passed number of graphs: 480, train running loss: 0.00140 (passed time: 50m 17s)
#           acc: 0.99979, fpr: 0.00010, fnr: 0.00523, rec: 0.99477, prc: 0.99542, f1: 0.99510, f1_macro: 0.99749
# epoch: 13, passed number of graphs: 576, train running loss: 0.00135 (passed time: 50m 45s)
#           acc: 0.99953, fpr: 0.00045, fnr: 0.00129, rec: 0.99871, prc: 0.97973, f1: 0.98913, f1_macro: 0.99444
# epoch: 13, passed number of graphs: 672, train running loss: 0.00140 (passed time: 51m 13s)
#           acc: 0.99724, fpr: 0.00002, fnr: 0.12672, rec: 0.87328, prc: 0.99909, f1: 0.93196, f1_macro: 0.96527
# epoch: 13, passed number of graphs: 768, train running loss: 0.00137 (passed time: 51m 41s)
#           acc: 0.99952, fpr: 0.00046, fnr: 0.00163, rec: 0.99837, prc: 0.97936, f1: 0.98877, f1_macro: 0.99426
# Validation --- epoch: 13, loss: 0.00275
#           f1_macro: 0.99415, f1: 0.98853, fpr: 0.00009, rec: 0.98377, acc: 0.99956, prc: 0.99578, fnr: 0.01623
# epoch: 14, passed number of graphs: 96, train running loss: 0.00106 (passed time: 52m 16s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00016, rec: 0.99984, prc: 0.99130, f1: 0.99555, f1_macro: 0.99773
# epoch: 14, passed number of graphs: 192, train running loss: 0.00149 (passed time: 52m 44s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00163, rec: 0.99837, prc: 0.99967, f1: 0.99902, f1_macro: 0.99950
# epoch: 14, passed number of graphs: 288, train running loss: 0.00143 (passed time: 53m 12s)
#           acc: 0.99979, fpr: 0.00015, fnr: 0.00310, rec: 0.99690, prc: 0.99300, f1: 0.99494, f1_macro: 0.99742
# epoch: 14, passed number of graphs: 384, train running loss: 0.00124 (passed time: 53m 39s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00209, rec: 0.99791, prc: 0.99887, f1: 0.99839, f1_macro: 0.99918
# epoch: 14, passed number of graphs: 480, train running loss: 0.00115 (passed time: 54m 7s)
#           acc: 0.99975, fpr: 0.00016, fnr: 0.00425, rec: 0.99575, prc: 0.99283, f1: 0.99429, f1_macro: 0.99708
# epoch: 14, passed number of graphs: 576, train running loss: 0.00107 (passed time: 54m 35s)
#           acc: 0.99967, fpr: 0.00032, fnr: 0.00097, rec: 0.99903, prc: 0.98567, f1: 0.99230, f1_macro: 0.99607
# epoch: 14, passed number of graphs: 672, train running loss: 0.00115 (passed time: 55m 3s)
#           acc: 0.99724, fpr: 0.00002, fnr: 0.12656, rec: 0.87344, prc: 0.99872, f1: 0.93189, f1_macro: 0.96524
# epoch: 14, passed number of graphs: 768, train running loss: 0.00114 (passed time: 55m 31s)
#           acc: 0.99981, fpr: 0.00017, fnr: 0.00098, rec: 0.99902, prc: 0.99206, f1: 0.99553, f1_macro: 0.99772
# Validation --- epoch: 14, loss: 0.00275
#           f1_macro: 0.99455, f1: 0.98932, fpr: 0.00012, rec: 0.98657, acc: 0.99960, prc: 0.99454, fnr: 0.01343
# epoch: 15, passed number of graphs: 96, train running loss: 0.00103 (passed time: 56m 6s)
#           acc: 0.99993, fpr: 0.00007, fnr: 0.00016, rec: 0.99984, prc: 0.99698, f1: 0.99841, f1_macro: 0.99919
# epoch: 15, passed number of graphs: 192, train running loss: 0.00147 (passed time: 56m 34s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00163, rec: 0.99837, prc: 0.99935, f1: 0.99886, f1_macro: 0.99942
# epoch: 15, passed number of graphs: 288, train running loss: 0.00141 (passed time: 57m 2s)
#           acc: 0.99977, fpr: 0.00017, fnr: 0.00294, rec: 0.99706, prc: 0.99220, f1: 0.99462, f1_macro: 0.99725
# epoch: 15, passed number of graphs: 384, train running loss: 0.00124 (passed time: 57m 29s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00242, rec: 0.99758, prc: 0.99871, f1: 0.99815, f1_macro: 0.99905
# epoch: 15, passed number of graphs: 480, train running loss: 0.00116 (passed time: 57m 57s)
#           acc: 0.99972, fpr: 0.00016, fnr: 0.00588, rec: 0.99412, prc: 0.99298, f1: 0.99355, f1_macro: 0.99670
# epoch: 15, passed number of graphs: 576, train running loss: 0.00107 (passed time: 58m 25s)
#           acc: 0.99967, fpr: 0.00031, fnr: 0.00097, rec: 0.99903, prc: 0.98582, f1: 0.99238, f1_macro: 0.99611
# epoch: 15, passed number of graphs: 672, train running loss: 0.00115 (passed time: 58m 52s)
#           acc: 0.99725, fpr: 0.00002, fnr: 0.12640, rec: 0.87360, prc: 0.99909, f1: 0.93214, f1_macro: 0.96537
# epoch: 15, passed number of graphs: 768, train running loss: 0.00113 (passed time: 59m 20s)
#           acc: 0.99988, fpr: 0.00009, fnr: 0.00147, rec: 0.99853, prc: 0.99593, f1: 0.99723, f1_macro: 0.99859
# Validation --- epoch: 15, loss: 0.00258
#           f1_macro: 0.99469, f1: 0.98958, fpr: 0.00010, rec: 0.98636, acc: 0.99961, prc: 0.99528, fnr: 0.01364
# epoch: 16, passed number of graphs: 96, train running loss: 0.00098 (passed time: 59m 55s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00016, rec: 0.99984, prc: 0.99825, f1: 0.99904, f1_macro: 0.99951
# epoch: 16, passed number of graphs: 192, train running loss: 0.00137 (passed time: 1h 0m 23s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00163, rec: 0.99837, prc: 0.99951, f1: 0.99894, f1_macro: 0.99946
# epoch: 16, passed number of graphs: 288, train running loss: 0.00130 (passed time: 1h 0m 51s)
#           acc: 0.99978, fpr: 0.00017, fnr: 0.00278, rec: 0.99722, prc: 0.99236, f1: 0.99478, f1_macro: 0.99734
# epoch: 16, passed number of graphs: 384, train running loss: 0.00115 (passed time: 1h 1m 18s)
#           acc: 0.99993, fpr: 0.00004, fnr: 0.00145, rec: 0.99855, prc: 0.99839, f1: 0.99847, f1_macro: 0.99922
# epoch: 16, passed number of graphs: 480, train running loss: 0.00108 (passed time: 1h 1m 46s)
#           acc: 0.99974, fpr: 0.00016, fnr: 0.00474, rec: 0.99526, prc: 0.99283, f1: 0.99405, f1_macro: 0.99696
# epoch: 16, passed number of graphs: 576, train running loss: 0.00101 (passed time: 1h 2m 15s)
#           acc: 0.99966, fpr: 0.00032, fnr: 0.00113, rec: 0.99887, prc: 0.98535, f1: 0.99206, f1_macro: 0.99594
# epoch: 16, passed number of graphs: 672, train running loss: 0.00110 (passed time: 1h 2m 42s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12656, rec: 0.87344, prc: 0.99945, f1: 0.93221, f1_macro: 0.96540
# epoch: 16, passed number of graphs: 768, train running loss: 0.00108 (passed time: 1h 3m 10s)
#           acc: 0.99991, fpr: 0.00006, fnr: 0.00163, rec: 0.99837, prc: 0.99739, f1: 0.99788, f1_macro: 0.99892
# Validation --- epoch: 16, loss: 0.00252
#           f1_macro: 0.99480, f1: 0.98979, fpr: 0.00008, rec: 0.98563, acc: 0.99962, prc: 0.99645, fnr: 0.01437
# Better model saved at ./saved_models/GIN_15: 0.9897862003061961.pt.
# epoch: 17, passed number of graphs: 96, train running loss: 0.00098 (passed time: 1h 3m 46s)
#           acc: 0.99997, fpr: 0.00003, fnr: 0.00016, rec: 0.99984, prc: 0.99857, f1: 0.99920, f1_macro: 0.99959
# epoch: 17, passed number of graphs: 192, train running loss: 0.00131 (passed time: 1h 4m 13s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00163, rec: 0.99837, prc: 0.99951, f1: 0.99894, f1_macro: 0.99946
# epoch: 17, passed number of graphs: 288, train running loss: 0.00121 (passed time: 1h 4m 41s)
#           acc: 0.99977, fpr: 0.00017, fnr: 0.00294, rec: 0.99706, prc: 0.99203, f1: 0.99454, f1_macro: 0.99721
# epoch: 17, passed number of graphs: 384, train running loss: 0.00110 (passed time: 1h 5m 9s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00193, rec: 0.99807, prc: 0.99855, f1: 0.99831, f1_macro: 0.99913
# epoch: 17, passed number of graphs: 480, train running loss: 0.00104 (passed time: 1h 5m 36s)
#           acc: 0.99974, fpr: 0.00014, fnr: 0.00539, rec: 0.99461, prc: 0.99347, f1: 0.99404, f1_macro: 0.99695
# epoch: 17, passed number of graphs: 576, train running loss: 0.00098 (passed time: 1h 6m 5s)
#           acc: 0.99965, fpr: 0.00033, fnr: 0.00113, rec: 0.99887, prc: 0.98504, f1: 0.99191, f1_macro: 0.99586
# epoch: 17, passed number of graphs: 672, train running loss: 0.00107 (passed time: 1h 6m 32s)
#           acc: 0.99725, fpr: 0.00002, fnr: 0.12592, rec: 0.87408, prc: 0.99890, f1: 0.93233, f1_macro: 0.96547
# epoch: 17, passed number of graphs: 768, train running loss: 0.00106 (passed time: 1h 7m 0s)
#           acc: 0.99992, fpr: 0.00005, fnr: 0.00163, rec: 0.99837, prc: 0.99788, f1: 0.99812, f1_macro: 0.99904
# Validation --- epoch: 17, loss: 0.00251
#           f1_macro: 0.99478, f1: 0.98976, fpr: 0.00008, rec: 0.98574, acc: 0.99962, prc: 0.99625, fnr: 0.01426
# epoch: 18, passed number of graphs: 96, train running loss: 0.00098 (passed time: 1h 7m 35s)
#           acc: 0.99997, fpr: 0.00003, fnr: 0.00032, rec: 0.99968, prc: 0.99873, f1: 0.99920, f1_macro: 0.99959
# epoch: 18, passed number of graphs: 192, train running loss: 0.00123 (passed time: 1h 8m 3s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00212, rec: 0.99788, prc: 0.99967, f1: 0.99877, f1_macro: 0.99937
# epoch: 18, passed number of graphs: 288, train running loss: 0.00113 (passed time: 1h 8m 31s)
#           acc: 0.99977, fpr: 0.00017, fnr: 0.00294, rec: 0.99706, prc: 0.99236, f1: 0.99470, f1_macro: 0.99729
# epoch: 18, passed number of graphs: 384, train running loss: 0.00103 (passed time: 1h 8m 59s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00193, rec: 0.99807, prc: 0.99871, f1: 0.99839, f1_macro: 0.99918
# epoch: 18, passed number of graphs: 480, train running loss: 0.00099 (passed time: 1h 9m 26s)
#           acc: 0.99974, fpr: 0.00015, fnr: 0.00523, rec: 0.99477, prc: 0.99331, f1: 0.99404, f1_macro: 0.99696
# epoch: 18, passed number of graphs: 576, train running loss: 0.00093 (passed time: 1h 9m 54s)
#           acc: 0.99965, fpr: 0.00033, fnr: 0.00113, rec: 0.99887, prc: 0.98519, f1: 0.99198, f1_macro: 0.99590
# epoch: 18, passed number of graphs: 672, train running loss: 0.00102 (passed time: 1h 10m 22s)
#           acc: 0.99725, fpr: 0.00002, fnr: 0.12608, rec: 0.87392, prc: 0.99890, f1: 0.93224, f1_macro: 0.96542
# epoch: 18, passed number of graphs: 768, train running loss: 0.00102 (passed time: 1h 10m 50s)
#           acc: 0.99993, fpr: 0.00004, fnr: 0.00163, rec: 0.99837, prc: 0.99821, f1: 0.99829, f1_macro: 0.99913
# Validation --- epoch: 18, loss: 0.00247
#           f1_macro: 0.99480, f1: 0.98979, fpr: 0.00008, rec: 0.98573, acc: 0.99962, prc: 0.99628, fnr: 0.01427
# Better model saved at ./saved_models/GIN_17: 0.9897871938676942.pt.
# epoch: 19, passed number of graphs: 96, train running loss: 0.00098 (passed time: 1h 11m 25s)
#           acc: 0.99997, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99888, f1: 0.99928, f1_macro: 0.99963
# epoch: 19, passed number of graphs: 192, train running loss: 0.00113 (passed time: 1h 11m 53s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00163, rec: 0.99837, prc: 0.99918, f1: 0.99877, f1_macro: 0.99937
# epoch: 19, passed number of graphs: 288, train running loss: 0.00103 (passed time: 1h 12m 21s)
#           acc: 0.99975, fpr: 0.00019, fnr: 0.00294, rec: 0.99706, prc: 0.99107, f1: 0.99405, f1_macro: 0.99696
# epoch: 19, passed number of graphs: 384, train running loss: 0.00096 (passed time: 1h 12m 48s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00193, rec: 0.99807, prc: 0.99855, f1: 0.99831, f1_macro: 0.99913
# epoch: 19, passed number of graphs: 480, train running loss: 0.00094 (passed time: 1h 13m 16s)
#           acc: 0.99975, fpr: 0.00014, fnr: 0.00523, rec: 0.99477, prc: 0.99347, f1: 0.99412, f1_macro: 0.99700
# epoch: 19, passed number of graphs: 576, train running loss: 0.00088 (passed time: 1h 13m 44s)
#           acc: 0.99965, fpr: 0.00034, fnr: 0.00113, rec: 0.99887, prc: 0.98488, f1: 0.99183, f1_macro: 0.99582
# epoch: 19, passed number of graphs: 672, train running loss: 0.00098 (passed time: 1h 14m 12s)
#           acc: 0.99725, fpr: 0.00002, fnr: 0.12592, rec: 0.87408, prc: 0.99872, f1: 0.93225, f1_macro: 0.96543
# epoch: 19, passed number of graphs: 768, train running loss: 0.00097 (passed time: 1h 14m 40s)
#           acc: 0.99993, fpr: 0.00004, fnr: 0.00163, rec: 0.99837, prc: 0.99837, f1: 0.99837, f1_macro: 0.99917
# Validation --- epoch: 19, loss: 0.00241
#           f1_macro: 0.99480, f1: 0.98980, fpr: 0.00008, rec: 0.98573, acc: 0.99962, prc: 0.99629, fnr: 0.01427
# Better model saved at ./saved_models/GIN_18: 0.9898032755661553.pt.
# epoch: 20, passed number of graphs: 96, train running loss: 0.00092 (passed time: 1h 15m 16s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00016, rec: 0.99984, prc: 0.99904, f1: 0.99944, f1_macro: 0.99971
# epoch: 20, passed number of graphs: 192, train running loss: 0.00104 (passed time: 1h 15m 43s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00180, rec: 0.99820, prc: 0.99951, f1: 0.99886, f1_macro: 0.99942
# epoch: 20, passed number of graphs: 288, train running loss: 0.00095 (passed time: 1h 16m 11s)
#           acc: 0.99976, fpr: 0.00018, fnr: 0.00310, rec: 0.99690, prc: 0.99187, f1: 0.99438, f1_macro: 0.99713
# epoch: 20, passed number of graphs: 384, train running loss: 0.00090 (passed time: 1h 16m 39s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00209, rec: 0.99791, prc: 0.99871, f1: 0.99831, f1_macro: 0.99913
# epoch: 20, passed number of graphs: 480, train running loss: 0.00088 (passed time: 1h 17m 7s)
#           acc: 0.99975, fpr: 0.00015, fnr: 0.00490, rec: 0.99510, prc: 0.99315, f1: 0.99413, f1_macro: 0.99700
# epoch: 20, passed number of graphs: 576, train running loss: 0.00083 (passed time: 1h 17m 36s)
#           acc: 0.99965, fpr: 0.00034, fnr: 0.00097, rec: 0.99903, prc: 0.98488, f1: 0.99191, f1_macro: 0.99586
# epoch: 20, passed number of graphs: 672, train running loss: 0.00093 (passed time: 1h 18m 3s)
#           acc: 0.99725, fpr: 0.00003, fnr: 0.12576, rec: 0.87424, prc: 0.99854, f1: 0.93227, f1_macro: 0.96543
# epoch: 20, passed number of graphs: 768, train running loss: 0.00093 (passed time: 1h 18m 31s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00163, rec: 0.99837, prc: 0.99853, f1: 0.99845, f1_macro: 0.99921
# Validation --- epoch: 20, loss: 0.00235
#           f1_macro: 0.99486, f1: 0.98990, fpr: 0.00007, rec: 0.98561, acc: 0.99962, prc: 0.99660, fnr: 0.01439
# Better model saved at ./saved_models/GIN_19: 0.989904684503441.pt.
# epoch: 21, passed number of graphs: 96, train running loss: 0.00086 (passed time: 1h 19m 6s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00016, rec: 0.99984, prc: 0.99920, f1: 0.99952, f1_macro: 0.99976
# epoch: 21, passed number of graphs: 192, train running loss: 0.00097 (passed time: 1h 19m 34s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99877, f1_macro: 0.99937
# epoch: 21, passed number of graphs: 288, train running loss: 0.00089 (passed time: 1h 20m 2s)
#           acc: 0.99977, fpr: 0.00017, fnr: 0.00310, rec: 0.99690, prc: 0.99236, f1: 0.99462, f1_macro: 0.99725
# epoch: 21, passed number of graphs: 384, train running loss: 0.00085 (passed time: 1h 20m 30s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00193, rec: 0.99807, prc: 0.99871, f1: 0.99839, f1_macro: 0.99918
# epoch: 21, passed number of graphs: 480, train running loss: 0.00083 (passed time: 1h 20m 58s)
#           acc: 0.99975, fpr: 0.00015, fnr: 0.00506, rec: 0.99494, prc: 0.99331, f1: 0.99412, f1_macro: 0.99700
# epoch: 21, passed number of graphs: 576, train running loss: 0.00079 (passed time: 1h 21m 26s)
#           acc: 0.99967, fpr: 0.00032, fnr: 0.00065, rec: 0.99935, prc: 0.98536, f1: 0.99231, f1_macro: 0.99607
# epoch: 21, passed number of graphs: 672, train running loss: 0.00089 (passed time: 1h 21m 54s)
#           acc: 0.99725, fpr: 0.00003, fnr: 0.12560, rec: 0.87440, prc: 0.99854, f1: 0.93236, f1_macro: 0.96548
# epoch: 21, passed number of graphs: 768, train running loss: 0.00090 (passed time: 1h 22m 22s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00163, rec: 0.99837, prc: 0.99869, f1: 0.99853, f1_macro: 0.99925
# Validation --- epoch: 21, loss: 0.00231
#           f1_macro: 0.99494, f1: 0.99007, fpr: 0.00007, rec: 0.98581, acc: 0.99963, prc: 0.99672, fnr: 0.01419
# Better model saved at ./saved_models/GIN_20: 0.990067919760086.pt.
# epoch: 22, passed number of graphs: 96, train running loss: 0.00083 (passed time: 1h 22m 58s)
#           acc: 0.99998, fpr: 0.00001, fnr: 0.00016, rec: 0.99984, prc: 0.99936, f1: 0.99960, f1_macro: 0.99980
# epoch: 22, passed number of graphs: 192, train running loss: 0.00092 (passed time: 1h 23m 25s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00180, rec: 0.99820, prc: 0.99935, f1: 0.99877, f1_macro: 0.99937
# epoch: 22, passed number of graphs: 288, train running loss: 0.00084 (passed time: 1h 23m 53s)
#           acc: 0.99977, fpr: 0.00016, fnr: 0.00327, rec: 0.99673, prc: 0.99268, f1: 0.99470, f1_macro: 0.99729
# epoch: 22, passed number of graphs: 384, train running loss: 0.00081 (passed time: 1h 24m 21s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00193, rec: 0.99807, prc: 0.99871, f1: 0.99839, f1_macro: 0.99918
# epoch: 22, passed number of graphs: 480, train running loss: 0.00080 (passed time: 1h 24m 49s)
#           acc: 0.99974, fpr: 0.00015, fnr: 0.00506, rec: 0.99494, prc: 0.99315, f1: 0.99404, f1_macro: 0.99696
# epoch: 22, passed number of graphs: 576, train running loss: 0.00075 (passed time: 1h 25m 18s)
#           acc: 0.99967, fpr: 0.00032, fnr: 0.00065, rec: 0.99935, prc: 0.98551, f1: 0.99239, f1_macro: 0.99611
# epoch: 22, passed number of graphs: 672, train running loss: 0.00084 (passed time: 1h 25m 46s)
#           acc: 0.99727, fpr: 0.00003, fnr: 0.12480, rec: 0.87520, prc: 0.99836, f1: 0.93273, f1_macro: 0.96567
# epoch: 22, passed number of graphs: 768, train running loss: 0.00084 (passed time: 1h 26m 14s)
#           acc: 0.99975, fpr: 0.00022, fnr: 0.00196, rec: 0.99804, prc: 0.99013, f1: 0.99407, f1_macro: 0.99697
# Validation --- epoch: 22, loss: 0.00286
#           f1_macro: 0.99281, f1: 0.98590, fpr: 0.00033, rec: 0.98821, acc: 0.99943, prc: 0.98598, fnr: 0.01179
# epoch: 23, passed number of graphs: 96, train running loss: 0.00069 (passed time: 1h 26m 50s)
#           acc: 0.99998, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99936, f1: 0.99952, f1_macro: 0.99976
# epoch: 23, passed number of graphs: 192, train running loss: 0.00082 (passed time: 1h 27m 18s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00163, rec: 0.99837, prc: 0.99951, f1: 0.99894, f1_macro: 0.99946
# epoch: 23, passed number of graphs: 288, train running loss: 0.00076 (passed time: 1h 27m 45s)
#           acc: 0.99978, fpr: 0.00016, fnr: 0.00327, rec: 0.99673, prc: 0.99284, f1: 0.99478, f1_macro: 0.99733
# epoch: 23, passed number of graphs: 384, train running loss: 0.00074 (passed time: 1h 28m 13s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00209, rec: 0.99791, prc: 0.99855, f1: 0.99823, f1_macro: 0.99909
# epoch: 23, passed number of graphs: 480, train running loss: 0.00074 (passed time: 1h 28m 41s)
#           acc: 0.99976, fpr: 0.00013, fnr: 0.00506, rec: 0.99494, prc: 0.99396, f1: 0.99445, f1_macro: 0.99716
# epoch: 23, passed number of graphs: 576, train running loss: 0.00069 (passed time: 1h 29m 9s)
#           acc: 0.99966, fpr: 0.00033, fnr: 0.00097, rec: 0.99903, prc: 0.98520, f1: 0.99207, f1_macro: 0.99595
# epoch: 23, passed number of graphs: 672, train running loss: 0.00076 (passed time: 1h 29m 37s)
#           acc: 0.99726, fpr: 0.00003, fnr: 0.12496, rec: 0.87504, prc: 0.99836, f1: 0.93264, f1_macro: 0.96562
# epoch: 23, passed number of graphs: 768, train running loss: 0.00076 (passed time: 1h 30m 4s)
#           acc: 0.99989, fpr: 0.00007, fnr: 0.00212, rec: 0.99788, prc: 0.99690, f1: 0.99739, f1_macro: 0.99867
# Validation --- epoch: 23, loss: 0.00266
#           f1_macro: 0.99354, f1: 0.98733, fpr: 0.00022, rec: 0.98630, acc: 0.99950, prc: 0.99058, fnr: 0.01370
# epoch: 24, passed number of graphs: 96, train running loss: 0.00072 (passed time: 1h 30m 40s)
#           acc: 0.99998, fpr: 0.00001, fnr: 0.00016, rec: 0.99984, prc: 0.99936, f1: 0.99960, f1_macro: 0.99980
# epoch: 24, passed number of graphs: 192, train running loss: 0.00077 (passed time: 1h 31m 7s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00212, rec: 0.99788, prc: 0.99967, f1: 0.99877, f1_macro: 0.99937
# epoch: 24, passed number of graphs: 288, train running loss: 0.00071 (passed time: 1h 31m 35s)
#           acc: 0.99978, fpr: 0.00016, fnr: 0.00327, rec: 0.99673, prc: 0.99284, f1: 0.99478, f1_macro: 0.99733
# epoch: 24, passed number of graphs: 384, train running loss: 0.00071 (passed time: 1h 32m 2s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00226, rec: 0.99774, prc: 0.99871, f1: 0.99823, f1_macro: 0.99909
# epoch: 24, passed number of graphs: 480, train running loss: 0.00068 (passed time: 1h 32m 30s)
#           acc: 0.99976, fpr: 0.00014, fnr: 0.00474, rec: 0.99526, prc: 0.99348, f1: 0.99437, f1_macro: 0.99712
# epoch: 24, passed number of graphs: 576, train running loss: 0.00064 (passed time: 1h 32m 58s)
# ...
# epoch: 42, passed number of graphs: 288, train running loss: 0.00058 (passed time: 2h 39m 32s)
#           acc: 0.99978, fpr: 0.00015, fnr: 0.00343, rec: 0.99657, prc: 0.99316, f1: 0.99486, f1_macro: 0.99738
# epoch: 42, passed number of graphs: 384, train running loss: 0.00060 (passed time: 2h 39m 59s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00161, rec: 0.99839, prc: 0.99871, f1: 0.99855, f1_macro: 0.99926
# epoch: 42, passed number of graphs: 480, train running loss: 0.00058 (passed time: 2h 40m 27s)
#           acc: 0.99976, fpr: 0.00013, fnr: 0.00506, rec: 0.99494, prc: 0.99396, f1: 0.99445, f1_macro: 0.99716
# epoch: 42, passed number of graphs: 576, train running loss: 0.00055 (passed time: 2h 40m 54s)
#           acc: 0.99966, fpr: 0.00031, fnr: 0.00161, rec: 0.99839, prc: 0.98597, f1: 0.99214, f1_macro: 0.99598
# epoch: 42, passed number of graphs: 672, train running loss: 0.00060 (passed time: 2h 41m 22s)
#           acc: 0.99726, fpr: 0.00003, fnr: 0.12496, rec: 0.87504, prc: 0.99836, f1: 0.93264, f1_macro: 0.96562
# epoch: 42, passed number of graphs: 768, train running loss: 0.00060 (passed time: 2h 41m 49s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00196, rec: 0.99804, prc: 0.99886, f1: 0.99845, f1_macro: 0.99921
# Validation --- epoch: 42, loss: 0.00202
#           f1_macro: 0.99575, f1: 0.99165, fpr: 0.00008, rec: 0.98877, acc: 0.99969, prc: 0.99656, fnr: 0.01123
# epoch: 43, passed number of graphs: 96, train running loss: 0.00059 (passed time: 2h 42m 24s)
#           acc: 0.99998, fpr: 0.00001, fnr: 0.00016, rec: 0.99984, prc: 0.99936, f1: 0.99960, f1_macro: 0.99980
# epoch: 43, passed number of graphs: 192, train running loss: 0.00062 (passed time: 2h 42m 52s)
#           acc: 0.99996, fpr: 0.00000, fnr: 0.00180, rec: 0.99820, prc: 0.99984, f1: 0.99902, f1_macro: 0.99950
# epoch: 43, passed number of graphs: 288, train running loss: 0.00058 (passed time: 2h 43m 19s)
#           acc: 0.99978, fpr: 0.00015, fnr: 0.00359, rec: 0.99641, prc: 0.99316, f1: 0.99478, f1_macro: 0.99733
# epoch: 43, passed number of graphs: 384, train running loss: 0.00060 (passed time: 2h 43m 46s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00161, rec: 0.99839, prc: 0.99871, f1: 0.99855, f1_macro: 0.99926
# epoch: 43, passed number of graphs: 480, train running loss: 0.00057 (passed time: 2h 44m 13s)
#           acc: 0.99976, fpr: 0.00013, fnr: 0.00506, rec: 0.99494, prc: 0.99396, f1: 0.99445, f1_macro: 0.99716
# epoch: 43, passed number of graphs: 576, train running loss: 0.00054 (passed time: 2h 44m 41s)
#           acc: 0.99966, fpr: 0.00031, fnr: 0.00161, rec: 0.99839, prc: 0.98597, f1: 0.99214, f1_macro: 0.99598
# epoch: 43, passed number of graphs: 672, train running loss: 0.00059 (passed time: 2h 45m 8s)
#           acc: 0.99726, fpr: 0.00003, fnr: 0.12496, rec: 0.87504, prc: 0.99836, f1: 0.93264, f1_macro: 0.96562
# epoch: 43, passed number of graphs: 768, train running loss: 0.00060 (passed time: 2h 45m 36s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00196, rec: 0.99804, prc: 0.99886, f1: 0.99845, f1_macro: 0.99921
# Validation --- epoch: 43, loss: 0.00201
#           f1_macro: 0.99575, f1: 0.99165, fpr: 0.00008, rec: 0.98875, acc: 0.99969, prc: 0.99657, fnr: 0.01125
# epoch: 44, passed number of graphs: 96, train running loss: 0.00059 (passed time: 2h 46m 11s)
#           acc: 0.99998, fpr: 0.00001, fnr: 0.00016, rec: 0.99984, prc: 0.99936, f1: 0.99960, f1_macro: 0.99980
# epoch: 44, passed number of graphs: 192, train running loss: 0.00062 (passed time: 2h 46m 38s)
#           acc: 0.99996, fpr: 0.00000, fnr: 0.00180, rec: 0.99820, prc: 0.99984, f1: 0.99902, f1_macro: 0.99950
# epoch: 44, passed number of graphs: 288, train running loss: 0.00058 (passed time: 2h 47m 6s)
#           acc: 0.99978, fpr: 0.00015, fnr: 0.00359, rec: 0.99641, prc: 0.99316, f1: 0.99478, f1_macro: 0.99733
# epoch: 44, passed number of graphs: 384, train running loss: 0.00060 (passed time: 2h 47m 33s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00161, rec: 0.99839, prc: 0.99871, f1: 0.99855, f1_macro: 0.99926
# epoch: 44, passed number of graphs: 480, train running loss: 0.00057 (passed time: 2h 48m 0s)
#           acc: 0.99976, fpr: 0.00013, fnr: 0.00506, rec: 0.99494, prc: 0.99396, f1: 0.99445, f1_macro: 0.99716
# epoch: 44, passed number of graphs: 576, train running loss: 0.00054 (passed time: 2h 48m 28s)
#           acc: 0.99966, fpr: 0.00031, fnr: 0.00161, rec: 0.99839, prc: 0.98597, f1: 0.99214, f1_macro: 0.99598
# epoch: 44, passed number of graphs: 672, train running loss: 0.00059 (passed time: 2h 48m 56s)
#           acc: 0.99726, fpr: 0.00003, fnr: 0.12496, rec: 0.87504, prc: 0.99836, f1: 0.93264, f1_macro: 0.96562
# epoch: 44, passed number of graphs: 768, train running loss: 0.00059 (passed time: 2h 49m 23s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00196, rec: 0.99804, prc: 0.99886, f1: 0.99845, f1_macro: 0.99921
# Validation --- epoch: 44, loss: 0.00201
#           f1_macro: 0.99575, f1: 0.99165, fpr: 0.00008, rec: 0.98875, acc: 0.99969, prc: 0.99657, fnr: 0.01125
# epoch: 45, passed number of graphs: 96, train running loss: 0.00059 (passed time: 2h 49m 58s)
#           acc: 0.99998, fpr: 0.00001, fnr: 0.00016, rec: 0.99984, prc: 0.99936, f1: 0.99960, f1_macro: 0.99980
# epoch: 45, passed number of graphs: 192, train running loss: 0.00062 (passed time: 2h 50m 26s)
#           acc: 0.99996, fpr: 0.00000, fnr: 0.00180, rec: 0.99820, prc: 0.99984, f1: 0.99902, f1_macro: 0.99950
# epoch: 45, passed number of graphs: 288, train running loss: 0.00057 (passed time: 2h 50m 53s)
#           acc: 0.99978, fpr: 0.00015, fnr: 0.00359, rec: 0.99641, prc: 0.99316, f1: 0.99478, f1_macro: 0.99733
# epoch: 45, passed number of graphs: 384, train running loss: 0.00059 (passed time: 2h 51m 20s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00161, rec: 0.99839, prc: 0.99871, f1: 0.99855, f1_macro: 0.99926
# epoch: 45, passed number of graphs: 480, train running loss: 0.00057 (passed time: 2h 51m 47s)
#           acc: 0.99976, fpr: 0.00013, fnr: 0.00506, rec: 0.99494, prc: 0.99396, f1: 0.99445, f1_macro: 0.99716
# epoch: 45, passed number of graphs: 576, train running loss: 0.00054 (passed time: 2h 52m 15s)
#           acc: 0.99966, fpr: 0.00031, fnr: 0.00161, rec: 0.99839, prc: 0.98581, f1: 0.99206, f1_macro: 0.99594
# epoch: 45, passed number of graphs: 672, train running loss: 0.00059 (passed time: 2h 52m 43s)
#           acc: 0.99726, fpr: 0.00003, fnr: 0.12496, rec: 0.87504, prc: 0.99836, f1: 0.93264, f1_macro: 0.96562
# epoch: 45, passed number of graphs: 768, train running loss: 0.00059 (passed time: 2h 53m 11s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00196, rec: 0.99804, prc: 0.99886, f1: 0.99845, f1_macro: 0.99921
# Validation --- epoch: 45, loss: 0.00201
#           f1_macro: 0.99575, f1: 0.99165, fpr: 0.00008, rec: 0.98877, acc: 0.99969, prc: 0.99655, fnr: 0.01123
# epoch: 46, passed number of graphs: 96, train running loss: 0.00059 (passed time: 2h 53m 45s)
#           acc: 0.99998, fpr: 0.00001, fnr: 0.00016, rec: 0.99984, prc: 0.99936, f1: 0.99960, f1_macro: 0.99980
# epoch: 46, passed number of graphs: 192, train running loss: 0.00062 (passed time: 2h 54m 13s)
#           acc: 0.99996, fpr: 0.00000, fnr: 0.00180, rec: 0.99820, prc: 0.99984, f1: 0.99902, f1_macro: 0.99950
# epoch: 46, passed number of graphs: 288, train running loss: 0.00057 (passed time: 2h 54m 41s)
#           acc: 0.99978, fpr: 0.00015, fnr: 0.00359, rec: 0.99641, prc: 0.99316, f1: 0.99478, f1_macro: 0.99733
# epoch: 46, passed number of graphs: 384, train running loss: 0.00059 (passed time: 2h 55m 8s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00161, rec: 0.99839, prc: 0.99871, f1: 0.99855, f1_macro: 0.99926
# epoch: 46, passed number of graphs: 480, train running loss: 0.00056 (passed time: 2h 55m 36s)
#           acc: 0.99976, fpr: 0.00013, fnr: 0.00506, rec: 0.99494, prc: 0.99396, f1: 0.99445, f1_macro: 0.99716
# epoch: 46, passed number of graphs: 576, train running loss: 0.00054 (passed time: 2h 56m 4s)
#           acc: 0.99966, fpr: 0.00031, fnr: 0.00161, rec: 0.99839, prc: 0.98581, f1: 0.99206, f1_macro: 0.99594
# epoch: 46, passed number of graphs: 672, train running loss: 0.00058 (passed time: 2h 56m 31s)
#           acc: 0.99726, fpr: 0.00003, fnr: 0.12496, rec: 0.87504, prc: 0.99836, f1: 0.93264, f1_macro: 0.96562
# epoch: 46, passed number of graphs: 768, train running loss: 0.00059 (passed time: 2h 56m 59s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00196, rec: 0.99804, prc: 0.99886, f1: 0.99845, f1_macro: 0.99921
# Validation --- epoch: 46, loss: 0.00200
#           f1_macro: 0.99575, f1: 0.99166, fpr: 0.00007, rec: 0.98876, acc: 0.99969, prc: 0.99658, fnr: 0.01124
# epoch: 47, passed number of graphs: 96, train running loss: 0.00059 (passed time: 2h 57m 34s)
#           acc: 0.99998, fpr: 0.00001, fnr: 0.00016, rec: 0.99984, prc: 0.99936, f1: 0.99960, f1_macro: 0.99980
# epoch: 47, passed number of graphs: 192, train running loss: 0.00061 (passed time: 2h 58m 1s)
#           acc: 0.99996, fpr: 0.00000, fnr: 0.00180, rec: 0.99820, prc: 0.99984, f1: 0.99902, f1_macro: 0.99950
# epoch: 47, passed number of graphs: 288, train running loss: 0.00057 (passed time: 2h 58m 29s)
#           acc: 0.99978, fpr: 0.00015, fnr: 0.00359, rec: 0.99641, prc: 0.99316, f1: 0.99478, f1_macro: 0.99733
# epoch: 47, passed number of graphs: 384, train running loss: 0.00059 (passed time: 2h 58m 56s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00161, rec: 0.99839, prc: 0.99871, f1: 0.99855, f1_macro: 0.99926
# epoch: 47, passed number of graphs: 480, train running loss: 0.00056 (passed time: 2h 59m 23s)
#           acc: 0.99976, fpr: 0.00013, fnr: 0.00506, rec: 0.99494, prc: 0.99396, f1: 0.99445, f1_macro: 0.99716
# epoch: 47, passed number of graphs: 576, train running loss: 0.00053 (passed time: 2h 59m 51s)
#           acc: 0.99966, fpr: 0.00031, fnr: 0.00161, rec: 0.99839, prc: 0.98581, f1: 0.99206, f1_macro: 0.99594
# epoch: 47, passed number of graphs: 672, train running loss: 0.00058 (passed time: 3h 0m 19s)
#           acc: 0.99726, fpr: 0.00003, fnr: 0.12496, rec: 0.87504, prc: 0.99836, f1: 0.93264, f1_macro: 0.96562
# epoch: 47, passed number of graphs: 768, train running loss: 0.00059 (passed time: 3h 0m 47s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00179, rec: 0.99821, prc: 0.99886, f1: 0.99853, f1_macro: 0.99925
# Validation --- epoch: 47, loss: 0.00200
#           f1_macro: 0.99575, f1: 0.99165, fpr: 0.00008, rec: 0.98876, acc: 0.99969, prc: 0.99656, fnr: 0.01124
# epoch: 48, passed number of graphs: 96, train running loss: 0.00059 (passed time: 3h 1m 22s)
#           acc: 0.99998, fpr: 0.00001, fnr: 0.00016, rec: 0.99984, prc: 0.99936, f1: 0.99960, f1_macro: 0.99980
# epoch: 48, passed number of graphs: 192, train running loss: 0.00061 (passed time: 3h 1m 49s)
#           acc: 0.99996, fpr: 0.00000, fnr: 0.00163, rec: 0.99837, prc: 0.99984, f1: 0.99910, f1_macro: 0.99954
# epoch: 48, passed number of graphs: 288, train running loss: 0.00057 (passed time: 3h 2m 17s)
#           acc: 0.99978, fpr: 0.00015, fnr: 0.00359, rec: 0.99641, prc: 0.99316, f1: 0.99478, f1_macro: 0.99733
# epoch: 48, passed number of graphs: 384, train running loss: 0.00059 (passed time: 3h 2m 44s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00161, rec: 0.99839, prc: 0.99871, f1: 0.99855, f1_macro: 0.99926
# epoch: 48, passed number of graphs: 480, train running loss: 0.00056 (passed time: 3h 3m 11s)
#           acc: 0.99976, fpr: 0.00013, fnr: 0.00506, rec: 0.99494, prc: 0.99396, f1: 0.99445, f1_macro: 0.99716
# epoch: 48, passed number of graphs: 576, train running loss: 0.00053 (passed time: 3h 3m 39s)
#           acc: 0.99966, fpr: 0.00031, fnr: 0.00161, rec: 0.99839, prc: 0.98581, f1: 0.99206, f1_macro: 0.99594
# epoch: 48, passed number of graphs: 672, train running loss: 0.00058 (passed time: 3h 4m 6s)
#           acc: 0.99726, fpr: 0.00003, fnr: 0.12496, rec: 0.87504, prc: 0.99836, f1: 0.93264, f1_macro: 0.96562
# epoch: 48, passed number of graphs: 768, train running loss: 0.00058 (passed time: 3h 4m 34s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00179, rec: 0.99821, prc: 0.99886, f1: 0.99853, f1_macro: 0.99925
# Validation --- epoch: 48, loss: 0.00200
#           f1_macro: 0.99574, f1: 0.99165, fpr: 0.00008, rec: 0.98878, acc: 0.99969, prc: 0.99654, fnr: 0.01122
# epoch: 49, passed number of graphs: 96, train running loss: 0.00059 (passed time: 3h 5m 9s)
#           acc: 0.99998, fpr: 0.00001, fnr: 0.00016, rec: 0.99984, prc: 0.99936, f1: 0.99960, f1_macro: 0.99980
# epoch: 49, passed number of graphs: 192, train running loss: 0.00061 (passed time: 3h 5m 36s)
#           acc: 0.99996, fpr: 0.00000, fnr: 0.00163, rec: 0.99837, prc: 0.99984, f1: 0.99910, f1_macro: 0.99954
# epoch: 49, passed number of graphs: 288, train running loss: 0.00057 (passed time: 3h 6m 4s)
#           acc: 0.99978, fpr: 0.00015, fnr: 0.00359, rec: 0.99641, prc: 0.99316, f1: 0.99478, f1_macro: 0.99733
# epoch: 49, passed number of graphs: 384, train running loss: 0.00058 (passed time: 3h 6m 32s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00161, rec: 0.99839, prc: 0.99871, f1: 0.99855, f1_macro: 0.99926
# epoch: 49, passed number of graphs: 480, train running loss: 0.00056 (passed time: 3h 6m 59s)
#           acc: 0.99976, fpr: 0.00013, fnr: 0.00523, rec: 0.99477, prc: 0.99396, f1: 0.99437, f1_macro: 0.99712
# epoch: 49, passed number of graphs: 576, train running loss: 0.00053 (passed time: 3h 7m 26s)
#           acc: 0.99966, fpr: 0.00031, fnr: 0.00161, rec: 0.99839, prc: 0.98581, f1: 0.99206, f1_macro: 0.99594
# epoch: 49, passed number of graphs: 672, train running loss: 0.00058 (passed time: 3h 7m 54s)
#           acc: 0.99726, fpr: 0.00003, fnr: 0.12496, rec: 0.87504, prc: 0.99836, f1: 0.93264, f1_macro: 0.96562
# epoch: 49, passed number of graphs: 768, train running loss: 0.00058 (passed time: 3h 8m 21s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00179, rec: 0.99821, prc: 0.99886, f1: 0.99853, f1_macro: 0.99925
# Validation --- epoch: 49, loss: 0.00200
#           f1_macro: 0.99575, f1: 0.99165, fpr: 0.00008, rec: 0.98887, acc: 0.99969, prc: 0.99646, fnr: 0.01113
# epoch: 50, passed number of graphs: 96, train running loss: 0.00058 (passed time: 3h 8m 56s)
#           acc: 0.99998, fpr: 0.00001, fnr: 0.00016, rec: 0.99984, prc: 0.99936, f1: 0.99960, f1_macro: 0.99980
# epoch: 50, passed number of graphs: 192, train running loss: 0.00061 (passed time: 3h 9m 24s)
#           acc: 0.99996, fpr: 0.00000, fnr: 0.00163, rec: 0.99837, prc: 0.99984, f1: 0.99910, f1_macro: 0.99954
# epoch: 50, passed number of graphs: 288, train running loss: 0.00056 (passed time: 3h 9m 51s)
#           acc: 0.99978, fpr: 0.00015, fnr: 0.00359, rec: 0.99641, prc: 0.99316, f1: 0.99478, f1_macro: 0.99733
# epoch: 50, passed number of graphs: 384, train running loss: 0.00058 (passed time: 3h 10m 18s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00161, rec: 0.99839, prc: 0.99871, f1: 0.99855, f1_macro: 0.99926
# epoch: 50, passed number of graphs: 480, train running loss: 0.00055 (passed time: 3h 10m 46s)
#           acc: 0.99976, fpr: 0.00013, fnr: 0.00523, rec: 0.99477, prc: 0.99396, f1: 0.99437, f1_macro: 0.99712
# epoch: 50, passed number of graphs: 576, train running loss: 0.00053 (passed time: 3h 11m 14s)
#           acc: 0.99966, fpr: 0.00031, fnr: 0.00161, rec: 0.99839, prc: 0.98581, f1: 0.99206, f1_macro: 0.99594
# epoch: 50, passed number of graphs: 672, train running loss: 0.00057 (passed time: 3h 11m 41s)
#           acc: 0.99726, fpr: 0.00003, fnr: 0.12496, rec: 0.87504, prc: 0.99836, f1: 0.93264, f1_macro: 0.96562
# epoch: 50, passed number of graphs: 768, train running loss: 0.00058 (passed time: 3h 12m 9s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00179, rec: 0.99821, prc: 0.99886, f1: 0.99853, f1_macro: 0.99925
# Validation --- epoch: 50, loss: 0.00199
#           f1_macro: 0.99575, f1: 0.99165, fpr: 0.00008, rec: 0.98885, acc: 0.99969, prc: 0.99647, fnr: 0.01115
# ************ best model obtained after epoch 38, saved at ./saved_models/GIN_37: 0.9916741596385027.pt ************
# Testing --- loss: 0.00157
#           f1_macro: 0.99504, f1: 0.99026, fpr: 0.00011, rec: 0.98748, acc: 0.99963, prc: 0.99510, fnr: 0.01252

# %% [markdown]
# GIN_12Layer_MLP_2Layer_P2P
