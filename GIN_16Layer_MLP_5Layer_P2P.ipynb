# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/Do_an_tot_nghiep/blob/main/GIN_16Layer_MLP_5Layer_P2P.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric==1.4.3
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter_
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric==1.4.3 in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.3.5)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (6.2.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.21.6)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.18.3)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.4)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.56.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.7.3)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.7.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.12.1+cu113)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.23.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.6.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->torch-geometric==1.4.3) (1.5.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (0.39.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (4.13.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (57.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (3.10.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2022.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.4.3) (1.15.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (3.0.9)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (0.6.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (3.0.4)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (3.2.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2.9.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (7.1.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (1.3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2021.11.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (0.11.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
        elif split == 'val':
            self.path = self.processed_paths[1]
        elif split == 'test':
            self.path = self.processed_paths[2]

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
            self.num_graphs = self.data['num_graphs']
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            with h5py.File(self.path, 'r') as f:
                self.num_graphs = f.attrs['num_graphs']
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GINConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_input_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), 
                             BatchNorm1d(self.dim_hidden_feature), ReLU())))
          else:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), 
                             BatchNorm1d(self.dim_hidden_feature), ReLU()))) 

        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                add_xr_at = n
            if n == add_xr_at:
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/P2P'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=True, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 2
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 16
num_classes = 2 

dropout = 0.2
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-d22d3afc-ad51-4672-918d-0c2793297cb5.json
# ------------------------------
# ------------------------------
# Sun Nov  6 12:16:16 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GINConv(nn=Sequential(
#       (0): Linear(in_features=1, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Linear(in_features=32, out_features=32, bias=True)
#       (13): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): ReLU()
#     ))
#     (1): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Linear(in_features=32, out_features=32, bias=True)
#       (13): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): ReLU()
#     ))
#     (2): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Linear(in_features=32, out_features=32, bias=True)
#       (13): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): ReLU()
#     ))
#     (3): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Linear(in_features=32, out_features=32, bias=True)
#       (13): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): ReLU()
#     ))
#     (4): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Linear(in_features=32, out_features=32, bias=True)
#       (13): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): ReLU()
#     ))
#     (5): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Linear(in_features=32, out_features=32, bias=True)
#       (13): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): ReLU()
#     ))
#     (6): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Linear(in_features=32, out_features=32, bias=True)
#       (13): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): ReLU()
#     ))
#     (7): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Linear(in_features=32, out_features=32, bias=True)
#       (13): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): ReLU()
#     ))
#     (8): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Linear(in_features=32, out_features=32, bias=True)
#       (13): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): ReLU()
#     ))
#     (9): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Linear(in_features=32, out_features=32, bias=True)
#       (13): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): ReLU()
#     ))
#     (10): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Linear(in_features=32, out_features=32, bias=True)
#       (13): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): ReLU()
#     ))
#     (11): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Linear(in_features=32, out_features=32, bias=True)
#       (13): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): ReLU()
#     ))
#     (12): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Linear(in_features=32, out_features=32, bias=True)
#       (13): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): ReLU()
#     ))
#     (13): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Linear(in_features=32, out_features=32, bias=True)
#       (13): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): ReLU()
#     ))
#     (14): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Linear(in_features=32, out_features=32, bias=True)
#       (13): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): ReLU()
#     ))
#     (15): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#       (12): Linear(in_features=32, out_features=32, bias=True)
#       (13): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): ReLU()
#     ))
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#     (12): Identity()
#     (13): Identity()
#     (14): Identity()
#     (15): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 2
# epoch: 1, passed number of graphs: 96, train running loss: 0.05858 (passed time: 30s)
#           acc: 0.98969, fpr: 0.00092, fnr: 0.43372, rec: 0.56628, prc: 0.93151, f1: 0.70437, f1_macro: 0.84956
# epoch: 1, passed number of graphs: 192, train running loss: 0.04023 (passed time: 1m 0s)
#           acc: 0.99640, fpr: 0.00290, fnr: 0.03593, rec: 0.96407, prc: 0.87908, f1: 0.91961, f1_macro: 0.95889
# epoch: 1, passed number of graphs: 288, train running loss: 0.03117 (passed time: 1m 31s)
#           acc: 0.99078, fpr: 0.00092, fnr: 0.39297, rec: 0.60703, prc: 0.93483, f1: 0.73608, f1_macro: 0.86569
# epoch: 1, passed number of graphs: 384, train running loss: 0.02448 (passed time: 2m 1s)
#           acc: 0.99947, fpr: 0.00007, fnr: 0.02078, rec: 0.97922, prc: 0.99672, f1: 0.98789, f1_macro: 0.99381
# epoch: 1, passed number of graphs: 480, train running loss: 0.02022 (passed time: 2m 31s)
#           acc: 0.99725, fpr: 0.00151, fnr: 0.05897, rec: 0.94103, prc: 0.93250, f1: 0.93675, f1_macro: 0.96767
# epoch: 1, passed number of graphs: 576, train running loss: 0.01821 (passed time: 3m 2s)
#           acc: 0.99710, fpr: 0.00079, fnr: 0.09927, rec: 0.90073, prc: 0.96141, f1: 0.93008, f1_macro: 0.96430
# epoch: 1, passed number of graphs: 672, train running loss: 0.01617 (passed time: 3m 32s)
#           acc: 0.99477, fpr: 0.00053, fnr: 0.21764, rec: 0.78236, prc: 0.97027, f1: 0.86624, f1_macro: 0.93179
# epoch: 1, passed number of graphs: 768, train running loss: 0.01440 (passed time: 4m 3s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00424, rec: 0.99576, prc: 0.99836, f1: 0.99706, f1_macro: 0.99850
# Validation --- epoch: 1, loss: 0.00402
#           fnr: 0.02941, prc: 0.99976, acc: 0.99936, rec: 0.97059, f1: 0.98362, f1_macro: 0.99165, fpr: 0.00001
# Better model saved at ./saved_models/GIN_0: 0.9836240271179887.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.00118 (passed time: 4m 59s)
#           acc: 0.99989, fpr: 0.00002, fnr: 0.00415, rec: 0.99585, prc: 0.99904, f1: 0.99744, f1_macro: 0.99869
# epoch: 2, passed number of graphs: 192, train running loss: 0.00310 (passed time: 5m 30s)
#           acc: 0.99968, fpr: 0.00012, fnr: 0.00947, rec: 0.99053, prc: 0.99426, f1: 0.99239, f1_macro: 0.99611
# epoch: 2, passed number of graphs: 288, train running loss: 0.00247 (passed time: 6m 0s)
#           acc: 0.99972, fpr: 0.00023, fnr: 0.00294, rec: 0.99706, prc: 0.98962, f1: 0.99333, f1_macro: 0.99659
# epoch: 2, passed number of graphs: 384, train running loss: 0.00208 (passed time: 6m 31s)
#           acc: 0.99984, fpr: 0.00002, fnr: 0.00612, rec: 0.99388, prc: 0.99903, f1: 0.99645, f1_macro: 0.99818
# epoch: 2, passed number of graphs: 480, train running loss: 0.00185 (passed time: 7m 1s)
#           acc: 0.99975, fpr: 0.00007, fnr: 0.00849, rec: 0.99151, prc: 0.99704, f1: 0.99427, f1_macro: 0.99707
# epoch: 2, passed number of graphs: 576, train running loss: 0.00226 (passed time: 7m 31s)
#           acc: 0.99314, fpr: 0.00004, fnr: 0.31881, rec: 0.68119, prc: 0.99740, f1: 0.80951, f1_macro: 0.90301
# epoch: 2, passed number of graphs: 672, train running loss: 0.00234 (passed time: 8m 2s)
#           acc: 0.99909, fpr: 0.00083, fnr: 0.00431, rec: 0.99569, prc: 0.96366, f1: 0.97941, f1_macro: 0.98947
# epoch: 2, passed number of graphs: 768, train running loss: 0.00231 (passed time: 8m 32s)
#           acc: 0.99872, fpr: 0.00000, fnr: 0.06020, rec: 0.93980, prc: 0.99983, f1: 0.96889, f1_macro: 0.98412
# Validation --- epoch: 2, loss: 4.94071
#           fnr: 0.22091, prc: 0.05708, acc: 0.71812, rec: 0.77909, f1: 0.10636, f1_macro: 0.46950, fpr: 0.28322
# epoch: 3, passed number of graphs: 96, train running loss: 0.00516 (passed time: 9m 29s)
#           acc: 0.99912, fpr: 0.00057, fnr: 0.01499, rec: 0.98501, prc: 0.97474, f1: 0.97985, f1_macro: 0.98970
# epoch: 3, passed number of graphs: 192, train running loss: 0.00401 (passed time: 10m 0s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.03315, rec: 0.96685, prc: 0.99966, f1: 0.98298, f1_macro: 0.99131
# epoch: 3, passed number of graphs: 288, train running loss: 0.00309 (passed time: 10m 30s)
#           acc: 0.99974, fpr: 0.00008, fnr: 0.00833, rec: 0.99167, prc: 0.99606, f1: 0.99386, f1_macro: 0.99686
# epoch: 3, passed number of graphs: 384, train running loss: 0.00252 (passed time: 11m 0s)
#           acc: 0.99978, fpr: 0.00001, fnr: 0.00951, rec: 0.99049, prc: 0.99951, f1: 0.99498, f1_macro: 0.99744
# epoch: 3, passed number of graphs: 480, train running loss: 0.00217 (passed time: 11m 31s)
#           acc: 0.99972, fpr: 0.00008, fnr: 0.00915, rec: 0.99085, prc: 0.99622, f1: 0.99353, f1_macro: 0.99669
# epoch: 3, passed number of graphs: 576, train running loss: 0.00204 (passed time: 12m 1s)
#           acc: 0.99929, fpr: 0.00011, fnr: 0.02776, rec: 0.97224, prc: 0.99472, f1: 0.98335, f1_macro: 0.99149
# epoch: 3, passed number of graphs: 672, train running loss: 0.00195 (passed time: 12m 31s)
#           acc: 0.99951, fpr: 0.00048, fnr: 0.00096, rec: 0.99904, prc: 0.97886, f1: 0.98885, f1_macro: 0.99430
# epoch: 3, passed number of graphs: 768, train running loss: 0.00187 (passed time: 13m 2s)
#           acc: 0.99979, fpr: 0.00003, fnr: 0.00865, rec: 0.99135, prc: 0.99869, f1: 0.99501, f1_macro: 0.99745
# Validation --- epoch: 3, loss: 3.76212
#           fnr: 0.00118, prc: 0.06782, acc: 0.70355, rec: 0.99882, f1: 0.12699, f1_macro: 0.47417, fpr: 0.30295
# epoch: 4, passed number of graphs: 96, train running loss: 0.00103 (passed time: 13m 59s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00271, rec: 0.99729, prc: 0.99936, f1: 0.99832, f1_macro: 0.99914
# epoch: 4, passed number of graphs: 192, train running loss: 0.00177 (passed time: 14m 30s)
#           acc: 0.99774, fpr: 0.00007, fnr: 0.10240, rec: 0.89760, prc: 0.99637, f1: 0.94441, f1_macro: 0.97163
# epoch: 4, passed number of graphs: 288, train running loss: 0.00188 (passed time: 15m 0s)
#           acc: 0.99977, fpr: 0.00017, fnr: 0.00261, rec: 0.99739, prc: 0.99204, f1: 0.99470, f1_macro: 0.99729
# epoch: 4, passed number of graphs: 384, train running loss: 0.00162 (passed time: 15m 30s)
#           acc: 0.99989, fpr: 0.00004, fnr: 0.00290, rec: 0.99710, prc: 0.99806, f1: 0.99758, f1_macro: 0.99876
# epoch: 4, passed number of graphs: 480, train running loss: 0.00142 (passed time: 16m 1s)
#           acc: 0.99987, fpr: 0.00005, fnr: 0.00359, rec: 0.99641, prc: 0.99755, f1: 0.99698, f1_macro: 0.99845
# epoch: 4, passed number of graphs: 576, train running loss: 0.00135 (passed time: 16m 31s)
#           acc: 0.99372, fpr: 0.00006, fnr: 0.29023, rec: 0.70977, prc: 0.99592, f1: 0.82884, f1_macro: 0.91282
# epoch: 4, passed number of graphs: 672, train running loss: 0.00135 (passed time: 17m 2s)
#           acc: 0.99949, fpr: 0.00017, fnr: 0.01598, rec: 0.98402, prc: 0.99243, f1: 0.98821, f1_macro: 0.99397
# epoch: 4, passed number of graphs: 768, train running loss: 0.00131 (passed time: 17m 32s)
#           acc: 0.99979, fpr: 0.00000, fnr: 0.00979, rec: 0.99021, prc: 0.99984, f1: 0.99500, f1_macro: 0.99745
# Validation --- epoch: 4, loss: 0.52393
#           fnr: 0.00621, prc: 0.18407, acc: 0.89652, rec: 0.99379, f1: 0.30747, f1_macro: 0.62566, fpr: 0.10562
# epoch: 5, passed number of graphs: 96, train running loss: 0.00077 (passed time: 18m 29s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00175, rec: 0.99825, prc: 0.99888, f1: 0.99856, f1_macro: 0.99927
# epoch: 5, passed number of graphs: 192, train running loss: 0.00069 (passed time: 19m 0s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00392, rec: 0.99608, prc: 0.99967, f1: 0.99787, f1_macro: 0.99891
# epoch: 5, passed number of graphs: 288, train running loss: 0.00073 (passed time: 19m 30s)
#           acc: 0.99979, fpr: 0.00017, fnr: 0.00196, rec: 0.99804, prc: 0.99204, f1: 0.99503, f1_macro: 0.99746
# epoch: 5, passed number of graphs: 384, train running loss: 0.00069 (passed time: 20m 0s)
#           acc: 0.99989, fpr: 0.00001, fnr: 0.00435, rec: 0.99565, prc: 0.99935, f1: 0.99750, f1_macro: 0.99872
# epoch: 5, passed number of graphs: 480, train running loss: 0.00064 (passed time: 20m 31s)
#           acc: 0.99988, fpr: 0.00006, fnr: 0.00294, rec: 0.99706, prc: 0.99739, f1: 0.99722, f1_macro: 0.99858
# epoch: 5, passed number of graphs: 576, train running loss: 0.00061 (passed time: 21m 1s)
#           acc: 0.99974, fpr: 0.00023, fnr: 0.00145, rec: 0.99855, prc: 0.98960, f1: 0.99405, f1_macro: 0.99696
# epoch: 5, passed number of graphs: 672, train running loss: 0.00061 (passed time: 21m 31s)
#           acc: 0.99958, fpr: 0.00028, fnr: 0.00687, rec: 0.99313, prc: 0.98745, f1: 0.99028, f1_macro: 0.99503
# epoch: 5, passed number of graphs: 768, train running loss: 0.00063 (passed time: 22m 2s)
#           acc: 0.99972, fpr: 0.00000, fnr: 0.01321, rec: 0.98679, prc: 0.99983, f1: 0.99327, f1_macro: 0.99656
# Validation --- epoch: 5, loss: 0.00345
#           fnr: 0.02063, prc: 0.99945, acc: 0.99954, rec: 0.97937, f1: 0.98856, f1_macro: 0.99416, fpr: 0.00001
# Better model saved at ./saved_models/GIN_4: 0.9885582490815747.pt.
# epoch: 6, passed number of graphs: 96, train running loss: 0.00073 (passed time: 22m 59s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00207, rec: 0.99793, prc: 0.99872, f1: 0.99832, f1_macro: 0.99914
# epoch: 6, passed number of graphs: 192, train running loss: 0.00078 (passed time: 23m 29s)
#           acc: 0.99983, fpr: 0.00001, fnr: 0.00751, rec: 0.99249, prc: 0.99967, f1: 0.99607, f1_macro: 0.99799
# epoch: 6, passed number of graphs: 288, train running loss: 0.00075 (passed time: 23m 59s)
#           acc: 0.99982, fpr: 0.00014, fnr: 0.00180, rec: 0.99820, prc: 0.99349, f1: 0.99584, f1_macro: 0.99788
# epoch: 6, passed number of graphs: 384, train running loss: 0.00068 (passed time: 24m 30s)
#           acc: 0.99989, fpr: 0.00004, fnr: 0.00354, rec: 0.99646, prc: 0.99839, f1: 0.99742, f1_macro: 0.99868
# epoch: 6, passed number of graphs: 480, train running loss: 0.00064 (passed time: 25m 0s)
#           acc: 0.99984, fpr: 0.00007, fnr: 0.00457, rec: 0.99543, prc: 0.99705, f1: 0.99624, f1_macro: 0.99808
# epoch: 6, passed number of graphs: 576, train running loss: 0.00062 (passed time: 25m 30s)
#           acc: 0.99982, fpr: 0.00011, fnr: 0.00307, rec: 0.99693, prc: 0.99485, f1: 0.99589, f1_macro: 0.99790
# epoch: 6, passed number of graphs: 672, train running loss: 0.00068 (passed time: 26m 1s)
#           acc: 0.99909, fpr: 0.00029, fnr: 0.02908, rec: 0.97092, prc: 0.98668, f1: 0.97874, f1_macro: 0.98914
# epoch: 6, passed number of graphs: 768, train running loss: 0.00077 (passed time: 26m 31s)
#           acc: 0.99982, fpr: 0.00005, fnr: 0.00604, rec: 0.99396, prc: 0.99771, f1: 0.99583, f1_macro: 0.99787
# Validation --- epoch: 6, loss: 0.00182
#           fnr: 0.01377, prc: 0.99872, acc: 0.99968, rec: 0.98623, f1: 0.99169, f1_macro: 0.99576, fpr: 0.00003
# Better model saved at ./saved_models/GIN_5: 0.9916881932756184.pt.
# epoch: 7, passed number of graphs: 96, train running loss: 0.00083 (passed time: 27m 28s)
#           acc: 0.99728, fpr: 0.00002, fnr: 0.12442, rec: 0.87558, prc: 0.99873, f1: 0.93311, f1_macro: 0.96586
# epoch: 7, passed number of graphs: 192, train running loss: 0.00076 (passed time: 27m 59s)
#           acc: 0.99988, fpr: 0.00001, fnr: 0.00506, rec: 0.99494, prc: 0.99934, f1: 0.99714, f1_macro: 0.99854
# epoch: 7, passed number of graphs: 288, train running loss: 0.00066 (passed time: 28m 29s)
#           acc: 0.99981, fpr: 0.00016, fnr: 0.00163, rec: 0.99837, prc: 0.99253, f1: 0.99544, f1_macro: 0.99767
# epoch: 7, passed number of graphs: 384, train running loss: 0.00067 (passed time: 28m 59s)
#           acc: 0.99991, fpr: 0.00002, fnr: 0.00306, rec: 0.99694, prc: 0.99903, f1: 0.99798, f1_macro: 0.99897
# epoch: 7, passed number of graphs: 480, train running loss: 0.00063 (passed time: 29m 30s)
#           acc: 0.99983, fpr: 0.00009, fnr: 0.00392, rec: 0.99608, prc: 0.99592, f1: 0.99600, f1_macro: 0.99795
# epoch: 7, passed number of graphs: 576, train running loss: 0.00059 (passed time: 30m 0s)
#           acc: 0.99977, fpr: 0.00021, fnr: 0.00113, rec: 0.99887, prc: 0.99040, f1: 0.99462, f1_macro: 0.99725
# epoch: 7, passed number of graphs: 672, train running loss: 0.00064 (passed time: 30m 30s)
#           acc: 0.99938, fpr: 0.00024, fnr: 0.01758, rec: 0.98242, prc: 0.98906, f1: 0.98573, f1_macro: 0.99271
# epoch: 7, passed number of graphs: 768, train running loss: 0.00068 (passed time: 31m 1s)
#           acc: 0.99980, fpr: 0.00002, fnr: 0.00881, rec: 0.99119, prc: 0.99918, f1: 0.99517, f1_macro: 0.99753
# Validation --- epoch: 7, loss: 0.00151
#           fnr: 0.00966, prc: 0.99810, acc: 0.99975, rec: 0.99034, f1: 0.99365, f1_macro: 0.99676, fpr: 0.00004
# Better model saved at ./saved_models/GIN_6: 0.9936470378032185.pt.
# epoch: 8, passed number of graphs: 96, train running loss: 0.00082 (passed time: 31m 58s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00223, rec: 0.99777, prc: 0.99952, f1: 0.99864, f1_macro: 0.99931
# epoch: 8, passed number of graphs: 192, train running loss: 0.00095 (passed time: 32m 28s)
#           acc: 0.99989, fpr: 0.00001, fnr: 0.00457, rec: 0.99543, prc: 0.99934, f1: 0.99738, f1_macro: 0.99866
# epoch: 8, passed number of graphs: 288, train running loss: 0.00085 (passed time: 32m 58s)
#           acc: 0.99980, fpr: 0.00016, fnr: 0.00212, rec: 0.99788, prc: 0.99252, f1: 0.99519, f1_macro: 0.99754
# epoch: 8, passed number of graphs: 384, train running loss: 0.00085 (passed time: 33m 29s)
#           acc: 0.99663, fpr: 0.00002, fnr: 0.15193, rec: 0.84807, prc: 0.99886, f1: 0.91731, f1_macro: 0.95780
# epoch: 8, passed number of graphs: 480, train running loss: 0.00079 (passed time: 33m 59s)
#           acc: 0.99984, fpr: 0.00009, fnr: 0.00343, rec: 0.99657, prc: 0.99608, f1: 0.99633, f1_macro: 0.99812
# epoch: 8, passed number of graphs: 576, train running loss: 0.00072 (passed time: 34m 29s)
#           acc: 0.99975, fpr: 0.00024, fnr: 0.00065, rec: 0.99935, prc: 0.98898, f1: 0.99414, f1_macro: 0.99700
# epoch: 8, passed number of graphs: 672, train running loss: 0.00073 (passed time: 35m 0s)
#           acc: 0.99959, fpr: 0.00024, fnr: 0.00815, rec: 0.99185, prc: 0.98916, f1: 0.99051, f1_macro: 0.99515
# epoch: 8, passed number of graphs: 768, train running loss: 0.00076 (passed time: 35m 30s)
#           acc: 0.99959, fpr: 0.00002, fnr: 0.01827, rec: 0.98173, prc: 0.99884, f1: 0.99021, f1_macro: 0.99500
# Validation --- epoch: 8, loss: 0.13209
#           fnr: 0.02070, prc: 0.57145, acc: 0.97172, rec: 0.97930, f1: 0.67671, f1_macro: 0.83095, fpr: 0.02845
# epoch: 9, passed number of graphs: 96, train running loss: 0.00059 (passed time: 36m 27s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00239, rec: 0.99761, prc: 0.99952, f1: 0.99856, f1_macro: 0.99927
# epoch: 9, passed number of graphs: 192, train running loss: 0.00058 (passed time: 36m 58s)
#           acc: 0.99993, fpr: 0.00000, fnr: 0.00294, rec: 0.99706, prc: 0.99984, f1: 0.99845, f1_macro: 0.99921
# epoch: 9, passed number of graphs: 288, train running loss: 0.00053 (passed time: 37m 28s)
#           acc: 0.99985, fpr: 0.00003, fnr: 0.00539, rec: 0.99461, prc: 0.99852, f1: 0.99656, f1_macro: 0.99824
# epoch: 9, passed number of graphs: 384, train running loss: 0.00060 (passed time: 37m 58s)
#           acc: 0.99711, fpr: 0.00002, fnr: 0.13066, rec: 0.86934, prc: 0.99907, f1: 0.92970, f1_macro: 0.96411
# epoch: 9, passed number of graphs: 480, train running loss: 0.00056 (passed time: 38m 28s)
#           acc: 0.99988, fpr: 0.00007, fnr: 0.00261, rec: 0.99739, prc: 0.99706, f1: 0.99722, f1_macro: 0.99858
# epoch: 9, passed number of graphs: 576, train running loss: 0.00052 (passed time: 38m 59s)
#           acc: 0.99977, fpr: 0.00020, fnr: 0.00161, rec: 0.99839, prc: 0.99087, f1: 0.99461, f1_macro: 0.99725
# epoch: 9, passed number of graphs: 672, train running loss: 0.00066 (passed time: 39m 29s)
#           acc: 0.99945, fpr: 0.00047, fnr: 0.00384, rec: 0.99616, prc: 0.97896, f1: 0.98749, f1_macro: 0.99360
# epoch: 9, passed number of graphs: 768, train running loss: 0.00076 (passed time: 39m 59s)
#           acc: 0.99983, fpr: 0.00005, fnr: 0.00587, rec: 0.99413, prc: 0.99771, f1: 0.99591, f1_macro: 0.99791
# Validation --- epoch: 9, loss: 0.13653
#           fnr: 0.99138, prc: 1.00000, acc: 0.97867, rec: 0.00862, f1: 0.01409, f1_macro: 0.50165, fpr: 0.00000
# epoch: 10, passed number of graphs: 96, train running loss: 0.00209 (passed time: 40m 57s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00319, rec: 0.99681, prc: 0.99936, f1: 0.99808, f1_macro: 0.99902
# epoch: 10, passed number of graphs: 192, train running loss: 0.00159 (passed time: 41m 27s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00229, rec: 0.99771, prc: 0.99951, f1: 0.99861, f1_macro: 0.99929
# epoch: 10, passed number of graphs: 288, train running loss: 0.00123 (passed time: 41m 57s)
#           acc: 0.99983, fpr: 0.00015, fnr: 0.00131, rec: 0.99869, prc: 0.99318, f1: 0.99593, f1_macro: 0.99792
# epoch: 10, passed number of graphs: 384, train running loss: 0.00105 (passed time: 42m 28s)
#           acc: 0.99991, fpr: 0.00006, fnr: 0.00145, rec: 0.99855, prc: 0.99743, f1: 0.99799, f1_macro: 0.99897
# epoch: 10, passed number of graphs: 480, train running loss: 0.00092 (passed time: 42m 58s)
#           acc: 0.99986, fpr: 0.00010, fnr: 0.00196, rec: 0.99804, prc: 0.99560, f1: 0.99682, f1_macro: 0.99837
# epoch: 10, passed number of graphs: 576, train running loss: 0.00084 (passed time: 43m 28s)
#           acc: 0.99981, fpr: 0.00015, fnr: 0.00210, rec: 0.99790, prc: 0.99325, f1: 0.99557, f1_macro: 0.99774
# epoch: 10, passed number of graphs: 672, train running loss: 0.00081 (passed time: 43m 59s)
#           acc: 0.99957, fpr: 0.00039, fnr: 0.00256, rec: 0.99744, prc: 0.98284, f1: 0.99009, f1_macro: 0.99493
# epoch: 10, passed number of graphs: 768, train running loss: 0.00078 (passed time: 44m 29s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00261, rec: 0.99739, prc: 0.99869, f1: 0.99804, f1_macro: 0.99900
# Validation --- epoch: 10, loss: 0.00155
#           fnr: 0.00669, prc: 0.99699, acc: 0.99979, rec: 0.99331, f1: 0.99460, f1_macro: 0.99725, fpr: 0.00007
# Better model saved at ./saved_models/GIN_9: 0.9945987356662966.pt.
# epoch: 11, passed number of graphs: 96, train running loss: 0.00048 (passed time: 45m 26s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00112, rec: 0.99888, prc: 0.99936, f1: 0.99912, f1_macro: 0.99955
# epoch: 11, passed number of graphs: 192, train running loss: 0.00050 (passed time: 45m 57s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00212, rec: 0.99788, prc: 0.99935, f1: 0.99861, f1_macro: 0.99929
# epoch: 11, passed number of graphs: 288, train running loss: 0.00049 (passed time: 46m 27s)
#           acc: 0.99981, fpr: 0.00015, fnr: 0.00212, rec: 0.99788, prc: 0.99333, f1: 0.99560, f1_macro: 0.99775
# epoch: 11, passed number of graphs: 384, train running loss: 0.00046 (passed time: 46m 58s)
#           acc: 0.99993, fpr: 0.00004, fnr: 0.00145, rec: 0.99855, prc: 0.99839, f1: 0.99847, f1_macro: 0.99922
# epoch: 11, passed number of graphs: 480, train running loss: 0.00046 (passed time: 47m 28s)
#           acc: 0.99983, fpr: 0.00012, fnr: 0.00278, rec: 0.99722, prc: 0.99479, f1: 0.99600, f1_macro: 0.99796
# epoch: 11, passed number of graphs: 576, train running loss: 0.00045 (passed time: 47m 58s)
#           acc: 0.99987, fpr: 0.00008, fnr: 0.00226, rec: 0.99774, prc: 0.99629, f1: 0.99702, f1_macro: 0.99848
# epoch: 11, passed number of graphs: 672, train running loss: 0.00045 (passed time: 48m 29s)
#           acc: 0.99958, fpr: 0.00034, fnr: 0.00384, rec: 0.99616, prc: 0.98468, f1: 0.99039, f1_macro: 0.99509
# epoch: 11, passed number of graphs: 768, train running loss: 0.00044 (passed time: 48m 59s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00131, rec: 0.99869, prc: 0.99886, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 11, loss: 0.00172
#           fnr: 0.00518, prc: 0.99602, acc: 0.99980, rec: 0.99482, f1: 0.99486, f1_macro: 0.99738, fpr: 0.00009
# Better model saved at ./saved_models/GIN_10: 0.9948641489358584.pt.
# epoch: 12, passed number of graphs: 96, train running loss: 0.00036 (passed time: 49m 56s)
#           acc: 0.99997, fpr: 0.00002, fnr: 0.00064, rec: 0.99936, prc: 0.99904, f1: 0.99920, f1_macro: 0.99959
# epoch: 12, passed number of graphs: 192, train running loss: 0.00040 (passed time: 50m 27s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99967, f1: 0.99886, f1_macro: 0.99942
# epoch: 12, passed number of graphs: 288, train running loss: 0.00037 (passed time: 50m 57s)
#           acc: 0.99985, fpr: 0.00012, fnr: 0.00163, rec: 0.99837, prc: 0.99463, f1: 0.99649, f1_macro: 0.99821
# epoch: 12, passed number of graphs: 384, train running loss: 0.00039 (passed time: 51m 27s)
#           acc: 0.99990, fpr: 0.00004, fnr: 0.00242, rec: 0.99758, prc: 0.99807, f1: 0.99782, f1_macro: 0.99889
# epoch: 12, passed number of graphs: 480, train running loss: 0.00038 (passed time: 51m 57s)
#           acc: 0.99983, fpr: 0.00012, fnr: 0.00245, rec: 0.99755, prc: 0.99479, f1: 0.99617, f1_macro: 0.99804
# epoch: 12, passed number of graphs: 576, train running loss: 0.00037 (passed time: 52m 28s)
#           acc: 0.99987, fpr: 0.00009, fnr: 0.00194, rec: 0.99806, prc: 0.99597, f1: 0.99702, f1_macro: 0.99848
# epoch: 12, passed number of graphs: 672, train running loss: 0.00039 (passed time: 52m 58s)
#           acc: 0.99961, fpr: 0.00036, fnr: 0.00176, rec: 0.99824, prc: 0.98378, f1: 0.99096, f1_macro: 0.99538
# epoch: 12, passed number of graphs: 768, train running loss: 0.00040 (passed time: 53m 28s)
#           acc: 0.99993, fpr: 0.00004, fnr: 0.00147, rec: 0.99853, prc: 0.99837, f1: 0.99845, f1_macro: 0.99921
# Validation --- epoch: 12, loss: 0.00128
#           fnr: 0.00641, prc: 0.99753, acc: 0.99981, rec: 0.99359, f1: 0.99500, f1_macro: 0.99745, fpr: 0.00005
# Better model saved at ./saved_models/GIN_11: 0.9950029786000268.pt.
# epoch: 13, passed number of graphs: 96, train running loss: 0.00036 (passed time: 54m 25s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00160, rec: 0.99840, prc: 0.99888, f1: 0.99864, f1_macro: 0.99931
# epoch: 13, passed number of graphs: 192, train running loss: 0.00039 (passed time: 54m 56s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00180, rec: 0.99820, prc: 0.99918, f1: 0.99869, f1_macro: 0.99933
# epoch: 13, passed number of graphs: 288, train running loss: 0.00037 (passed time: 55m 26s)
#           acc: 0.99979, fpr: 0.00016, fnr: 0.00278, rec: 0.99722, prc: 0.99284, f1: 0.99503, f1_macro: 0.99746
# epoch: 13, passed number of graphs: 384, train running loss: 0.00035 (passed time: 55m 56s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00177, rec: 0.99823, prc: 0.99871, f1: 0.99847, f1_macro: 0.99922
# epoch: 13, passed number of graphs: 480, train running loss: 0.00034 (passed time: 56m 26s)
#           acc: 0.99982, fpr: 0.00013, fnr: 0.00229, rec: 0.99771, prc: 0.99414, f1: 0.99592, f1_macro: 0.99792
# epoch: 13, passed number of graphs: 576, train running loss: 0.00034 (passed time: 56m 57s)
#           acc: 0.99984, fpr: 0.00007, fnr: 0.00404, rec: 0.99596, prc: 0.99677, f1: 0.99637, f1_macro: 0.99814
# epoch: 13, passed number of graphs: 672, train running loss: 0.00036 (passed time: 57m 27s)
#           acc: 0.99965, fpr: 0.00034, fnr: 0.00096, rec: 0.99904, prc: 0.98488, f1: 0.99191, f1_macro: 0.99586
# epoch: 13, passed number of graphs: 768, train running loss: 0.00036 (passed time: 57m 57s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00261, rec: 0.99739, prc: 0.99951, f1: 0.99845, f1_macro: 0.99921
# Validation --- epoch: 13, loss: 0.00128
#           fnr: 0.00585, prc: 0.99732, acc: 0.99982, rec: 0.99415, f1: 0.99518, f1_macro: 0.99754, fpr: 0.00006
# Better model saved at ./saved_models/GIN_12: 0.9951818437761215.pt.
# epoch: 14, passed number of graphs: 96, train running loss: 0.00035 (passed time: 58m 54s)
#           acc: 0.99997, fpr: 0.00001, fnr: 0.00096, rec: 0.99904, prc: 0.99936, f1: 0.99920, f1_macro: 0.99959
# epoch: 14, passed number of graphs: 192, train running loss: 0.00043 (passed time: 59m 24s)
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00261, rec: 0.99739, prc: 0.99902, f1: 0.99820, f1_macro: 0.99908
# epoch: 14, passed number of graphs: 288, train running loss: 0.00041 (passed time: 59m 55s)
#           acc: 0.99981, fpr: 0.00017, fnr: 0.00147, rec: 0.99853, prc: 0.99237, f1: 0.99544, f1_macro: 0.99767
# epoch: 14, passed number of graphs: 384, train running loss: 0.00038 (passed time: 1h 0m 25s)
#           acc: 0.99991, fpr: 0.00004, fnr: 0.00226, rec: 0.99774, prc: 0.99823, f1: 0.99799, f1_macro: 0.99897
# epoch: 14, passed number of graphs: 480, train running loss: 0.00037 (passed time: 1h 0m 55s)
#           acc: 0.99986, fpr: 0.00012, fnr: 0.00114, rec: 0.99886, prc: 0.99463, f1: 0.99674, f1_macro: 0.99833
# epoch: 14, passed number of graphs: 576, train running loss: 0.00036 (passed time: 1h 1m 25s)
#           acc: 0.99988, fpr: 0.00009, fnr: 0.00145, rec: 0.99855, prc: 0.99597, f1: 0.99726, f1_macro: 0.99860
# epoch: 14, passed number of graphs: 672, train running loss: 0.00039 (passed time: 1h 1m 56s)
#           acc: 0.99961, fpr: 0.00035, fnr: 0.00208, rec: 0.99792, prc: 0.98439, f1: 0.99111, f1_macro: 0.99546
# epoch: 14, passed number of graphs: 768, train running loss: 0.00039 (passed time: 1h 2m 26s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00212, rec: 0.99788, prc: 0.99918, f1: 0.99853, f1_macro: 0.99925
# Validation --- epoch: 14, loss: 0.00129
#           fnr: 0.00702, prc: 0.99755, acc: 0.99980, rec: 0.99298, f1: 0.99465, f1_macro: 0.99727, fpr: 0.00005
# epoch: 15, passed number of graphs: 96, train running loss: 0.00036 (passed time: 1h 3m 23s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00128, rec: 0.99872, prc: 0.99904, f1: 0.99888, f1_macro: 0.99943
# epoch: 15, passed number of graphs: 192, train running loss: 0.00039 (passed time: 1h 3m 53s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00245, rec: 0.99755, prc: 0.99918, f1: 0.99837, f1_macro: 0.99916
# epoch: 15, passed number of graphs: 288, train running loss: 0.00036 (passed time: 1h 4m 23s)
#           acc: 0.99981, fpr: 0.00016, fnr: 0.00196, rec: 0.99804, prc: 0.99285, f1: 0.99544, f1_macro: 0.99767
# epoch: 15, passed number of graphs: 384, train running loss: 0.00036 (passed time: 1h 4m 53s)
#           acc: 0.99990, fpr: 0.00004, fnr: 0.00274, rec: 0.99726, prc: 0.99839, f1: 0.99782, f1_macro: 0.99889
# epoch: 15, passed number of graphs: 480, train running loss: 0.00036 (passed time: 1h 5m 24s)
#           acc: 0.99984, fpr: 0.00014, fnr: 0.00098, rec: 0.99902, prc: 0.99383, f1: 0.99642, f1_macro: 0.99817
# epoch: 15, passed number of graphs: 576, train running loss: 0.00035 (passed time: 1h 5m 54s)
#           acc: 0.99982, fpr: 0.00014, fnr: 0.00210, rec: 0.99790, prc: 0.99373, f1: 0.99581, f1_macro: 0.99786
# epoch: 15, passed number of graphs: 672, train running loss: 0.00035 (passed time: 1h 6m 24s)
#           acc: 0.99960, fpr: 0.00036, fnr: 0.00208, rec: 0.99792, prc: 0.98377, f1: 0.99080, f1_macro: 0.99530
# epoch: 15, passed number of graphs: 768, train running loss: 0.00036 (passed time: 1h 6m 54s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00261, rec: 0.99739, prc: 0.99935, f1: 0.99837, f1_macro: 0.99917
# Validation --- epoch: 15, loss: 0.00128
#           fnr: 0.00546, prc: 0.99708, acc: 0.99982, rec: 0.99454, f1: 0.99526, f1_macro: 0.99758, fpr: 0.00006
# Better model saved at ./saved_models/GIN_14: 0.9952578494000542.pt.
# epoch: 16, passed number of graphs: 96, train running loss: 0.00040 (passed time: 1h 7m 51s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00096, rec: 0.99904, prc: 0.99920, f1: 0.99912, f1_macro: 0.99955
# epoch: 16, passed number of graphs: 192, train running loss: 0.00041 (passed time: 1h 8m 21s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00196, rec: 0.99804, prc: 0.99902, f1: 0.99853, f1_macro: 0.99925
# epoch: 16, passed number of graphs: 288, train running loss: 0.00038 (passed time: 1h 8m 51s)
#           acc: 0.99982, fpr: 0.00015, fnr: 0.00147, rec: 0.99853, prc: 0.99301, f1: 0.99576, f1_macro: 0.99784
# epoch: 16, passed number of graphs: 384, train running loss: 0.00036 (passed time: 1h 9m 22s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00193, rec: 0.99807, prc: 0.99887, f1: 0.99847, f1_macro: 0.99922
# epoch: 16, passed number of graphs: 480, train running loss: 0.00035 (passed time: 1h 9m 52s)
#           acc: 0.99985, fpr: 0.00010, fnr: 0.00229, rec: 0.99771, prc: 0.99527, f1: 0.99649, f1_macro: 0.99821
# epoch: 16, passed number of graphs: 576, train running loss: 0.00034 (passed time: 1h 10m 22s)
#           acc: 0.99979, fpr: 0.00019, fnr: 0.00145, rec: 0.99855, prc: 0.99151, f1: 0.99501, f1_macro: 0.99745
# epoch: 16, passed number of graphs: 672, train running loss: 0.00041 (passed time: 1h 10m 53s)
#           acc: 0.99954, fpr: 0.00041, fnr: 0.00256, rec: 0.99744, prc: 0.98176, f1: 0.98954, f1_macro: 0.99465
# epoch: 16, passed number of graphs: 768, train running loss: 0.00041 (passed time: 1h 11m 23s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00196, rec: 0.99804, prc: 0.99902, f1: 0.99853, f1_macro: 0.99925
# Validation --- epoch: 16, loss: 0.00135
#           fnr: 0.00606, prc: 0.99747, acc: 0.99981, rec: 0.99394, f1: 0.99517, f1_macro: 0.99754, fpr: 0.00006
# epoch: 17, passed number of graphs: 96, train running loss: 0.00040 (passed time: 1h 12m 19s)
#           acc: 0.99996, fpr: 0.00003, fnr: 0.00080, rec: 0.99920, prc: 0.99872, f1: 0.99896, f1_macro: 0.99947
# epoch: 17, passed number of graphs: 192, train running loss: 0.00042 (passed time: 1h 12m 49s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00310, rec: 0.99690, prc: 0.99935, f1: 0.99812, f1_macro: 0.99904
# epoch: 17, passed number of graphs: 288, train running loss: 0.00042 (passed time: 1h 13m 20s)
#           acc: 0.99981, fpr: 0.00015, fnr: 0.00196, rec: 0.99804, prc: 0.99317, f1: 0.99560, f1_macro: 0.99775
# epoch: 17, passed number of graphs: 384, train running loss: 0.00039 (passed time: 1h 13m 50s)
#           acc: 0.99991, fpr: 0.00003, fnr: 0.00290, rec: 0.99710, prc: 0.99871, f1: 0.99790, f1_macro: 0.99893
# epoch: 17, passed number of graphs: 480, train running loss: 0.00038 (passed time: 1h 14m 20s)
#           acc: 0.99983, fpr: 0.00014, fnr: 0.00131, rec: 0.99869, prc: 0.99350, f1: 0.99609, f1_macro: 0.99800
# epoch: 17, passed number of graphs: 576, train running loss: 0.00036 (passed time: 1h 14m 51s)
#           acc: 0.99981, fpr: 0.00014, fnr: 0.00242, rec: 0.99758, prc: 0.99357, f1: 0.99557, f1_macro: 0.99774
# epoch: 17, passed number of graphs: 672, train running loss: 0.00036 (passed time: 1h 15m 21s)
#           acc: 0.99957, fpr: 0.00037, fnr: 0.00288, rec: 0.99712, prc: 0.98330, f1: 0.99016, f1_macro: 0.99497
# epoch: 17, passed number of graphs: 768, train running loss: 0.00036 (passed time: 1h 15m 51s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00245, rec: 0.99755, prc: 0.99918, f1: 0.99837, f1_macro: 0.99917
# Validation --- epoch: 17, loss: 0.00124
#           fnr: 0.00554, prc: 0.99725, acc: 0.99982, rec: 0.99446, f1: 0.99531, f1_macro: 0.99761, fpr: 0.00006
# Better model saved at ./saved_models/GIN_16: 0.9953070751856407.pt.
# epoch: 18, passed number of graphs: 96, train running loss: 0.00032 (passed time: 1h 16m 48s)
#           acc: 0.99997, fpr: 0.00002, fnr: 0.00064, rec: 0.99936, prc: 0.99904, f1: 0.99920, f1_macro: 0.99959
# epoch: 18, passed number of graphs: 192, train running loss: 0.00036 (passed time: 1h 17m 18s)
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00294, rec: 0.99706, prc: 0.99918, f1: 0.99812, f1_macro: 0.99904
# epoch: 18, passed number of graphs: 288, train running loss: 0.00034 (passed time: 1h 17m 48s)
#           acc: 0.99981, fpr: 0.00015, fnr: 0.00229, rec: 0.99771, prc: 0.99317, f1: 0.99544, f1_macro: 0.99767
# epoch: 18, passed number of graphs: 384, train running loss: 0.00033 (passed time: 1h 18m 19s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00226, rec: 0.99774, prc: 0.99887, f1: 0.99831, f1_macro: 0.99913
# epoch: 18, passed number of graphs: 480, train running loss: 0.00032 (passed time: 1h 18m 49s)
#           acc: 0.99983, fpr: 0.00014, fnr: 0.00163, rec: 0.99837, prc: 0.99366, f1: 0.99601, f1_macro: 0.99796
# epoch: 18, passed number of graphs: 576, train running loss: 0.00032 (passed time: 1h 19m 19s)
#           acc: 0.99981, fpr: 0.00014, fnr: 0.00258, rec: 0.99742, prc: 0.99373, f1: 0.99557, f1_macro: 0.99774
# epoch: 18, passed number of graphs: 672, train running loss: 0.00032 (passed time: 1h 19m 49s)
#           acc: 0.99960, fpr: 0.00035, fnr: 0.00304, rec: 0.99696, prc: 0.98454, f1: 0.99071, f1_macro: 0.99525
# epoch: 18, passed number of graphs: 768, train running loss: 0.00033 (passed time: 1h 20m 20s)
#           acc: 0.99987, fpr: 0.00004, fnr: 0.00457, rec: 0.99543, prc: 0.99836, f1: 0.99690, f1_macro: 0.99841
# Validation --- epoch: 18, loss: 0.00124
#           fnr: 0.00582, prc: 0.99674, acc: 0.99980, rec: 0.99418, f1: 0.99490, f1_macro: 0.99740, fpr: 0.00007
# epoch: 19, passed number of graphs: 96, train running loss: 0.00034 (passed time: 1h 21m 16s)
#           acc: 0.99997, fpr: 0.00002, fnr: 0.00080, rec: 0.99920, prc: 0.99920, f1: 0.99920, f1_macro: 0.99959
# epoch: 19, passed number of graphs: 192, train running loss: 0.00038 (passed time: 1h 21m 46s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00180, rec: 0.99820, prc: 0.99935, f1: 0.99877, f1_macro: 0.99937
# epoch: 19, passed number of graphs: 288, train running loss: 0.00035 (passed time: 1h 22m 16s)
#           acc: 0.99981, fpr: 0.00017, fnr: 0.00131, rec: 0.99869, prc: 0.99237, f1: 0.99552, f1_macro: 0.99771
# epoch: 19, passed number of graphs: 384, train running loss: 0.00038 (passed time: 1h 22m 47s)
#           acc: 0.99990, fpr: 0.00002, fnr: 0.00354, rec: 0.99646, prc: 0.99919, f1: 0.99782, f1_macro: 0.99889
# epoch: 19, passed number of graphs: 480, train running loss: 0.00036 (passed time: 1h 23m 17s)
#           acc: 0.99987, fpr: 0.00010, fnr: 0.00163, rec: 0.99837, prc: 0.99544, f1: 0.99690, f1_macro: 0.99842
# epoch: 19, passed number of graphs: 576, train running loss: 0.00035 (passed time: 1h 23m 47s)
#           acc: 0.99979, fpr: 0.00019, fnr: 0.00129, rec: 0.99871, prc: 0.99135, f1: 0.99501, f1_macro: 0.99745
# epoch: 19, passed number of graphs: 672, train running loss: 0.00036 (passed time: 1h 24m 18s)
#           acc: 0.99941, fpr: 0.00056, fnr: 0.00192, rec: 0.99808, prc: 0.97533, f1: 0.98657, f1_macro: 0.99314
# epoch: 19, passed number of graphs: 768, train running loss: 0.00036 (passed time: 1h 24m 48s)
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00261, rec: 0.99739, prc: 0.99902, f1: 0.99820, f1_macro: 0.99908
# Validation --- epoch: 19, loss: 0.00127
#           fnr: 0.00567, prc: 0.99721, acc: 0.99982, rec: 0.99433, f1: 0.99522, f1_macro: 0.99756, fpr: 0.00006
# epoch: 20, passed number of graphs: 96, train running loss: 0.00043 (passed time: 1h 25m 44s)
#           acc: 0.99998, fpr: 0.00001, fnr: 0.00048, rec: 0.99952, prc: 0.99968, f1: 0.99960, f1_macro: 0.99980
# epoch: 20, passed number of graphs: 192, train running loss: 0.00042 (passed time: 1h 26m 15s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00212, rec: 0.99788, prc: 0.99935, f1: 0.99861, f1_macro: 0.99929
# epoch: 20, passed number of graphs: 288, train running loss: 0.00038 (passed time: 1h 26m 45s)
#           acc: 0.99982, fpr: 0.00013, fnr: 0.00245, rec: 0.99755, prc: 0.99398, f1: 0.99576, f1_macro: 0.99783
# epoch: 20, passed number of graphs: 384, train running loss: 0.00035 (passed time: 1h 27m 15s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00209, rec: 0.99791, prc: 0.99871, f1: 0.99831, f1_macro: 0.99913
# epoch: 20, passed number of graphs: 480, train running loss: 0.00034 (passed time: 1h 27m 45s)
#           acc: 0.99982, fpr: 0.00014, fnr: 0.00180, rec: 0.99820, prc: 0.99350, f1: 0.99584, f1_macro: 0.99788
# epoch: 20, passed number of graphs: 576, train running loss: 0.00033 (passed time: 1h 28m 16s)
#           acc: 0.99975, fpr: 0.00021, fnr: 0.00178, rec: 0.99822, prc: 0.99039, f1: 0.99429, f1_macro: 0.99708
# epoch: 20, passed number of graphs: 672, train running loss: 0.00033 (passed time: 1h 28m 46s)
#           acc: 0.99963, fpr: 0.00031, fnr: 0.00288, rec: 0.99712, prc: 0.98609, f1: 0.99158, f1_macro: 0.99570
# epoch: 20, passed number of graphs: 768, train running loss: 0.00035 (passed time: 1h 29m 16s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00228, rec: 0.99772, prc: 0.99918, f1: 0.99845, f1_macro: 0.99921
# Validation --- epoch: 20, loss: 0.00126
#           fnr: 0.00598, prc: 0.99724, acc: 0.99981, rec: 0.99402, f1: 0.99508, f1_macro: 0.99749, fpr: 0.00006
# epoch: 21, passed number of graphs: 96, train running loss: 0.00030 (passed time: 1h 30m 13s)
#           acc: 0.99997, fpr: 0.00002, fnr: 0.00080, rec: 0.99920, prc: 0.99920, f1: 0.99920, f1_macro: 0.99959
# epoch: 21, passed number of graphs: 192, train running loss: 0.00037 (passed time: 1h 30m 43s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00196, rec: 0.99804, prc: 0.99918, f1: 0.99861, f1_macro: 0.99929
# epoch: 21, passed number of graphs: 288, train running loss: 0.00034 (passed time: 1h 31m 13s)
#           acc: 0.99982, fpr: 0.00016, fnr: 0.00131, rec: 0.99869, prc: 0.99285, f1: 0.99576, f1_macro: 0.99784
# epoch: 21, passed number of graphs: 384, train running loss: 0.00032 (passed time: 1h 31m 43s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00193, rec: 0.99807, prc: 0.99887, f1: 0.99847, f1_macro: 0.99922
# epoch: 21, passed number of graphs: 480, train running loss: 0.00032 (passed time: 1h 32m 14s)
#           acc: 0.99982, fpr: 0.00010, fnr: 0.00376, rec: 0.99624, prc: 0.99527, f1: 0.99576, f1_macro: 0.99783
# epoch: 21, passed number of graphs: 576, train running loss: 0.00031 (passed time: 1h 32m 44s)
#           acc: 0.99978, fpr: 0.00019, fnr: 0.00161, rec: 0.99839, prc: 0.99119, f1: 0.99477, f1_macro: 0.99733
# epoch: 21, passed number of graphs: 672, train running loss: 0.00032 (passed time: 1h 33m 14s)
#           acc: 0.99963, fpr: 0.00028, fnr: 0.00431, rec: 0.99569, prc: 0.98732, f1: 0.99149, f1_macro: 0.99565
# epoch: 21, passed number of graphs: 768, train running loss: 0.00033 (passed time: 1h 33m 45s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00212, rec: 0.99788, prc: 0.99951, f1: 0.99869, f1_macro: 0.99933
# Validation --- epoch: 21, loss: 0.00123
#           fnr: 0.00514, prc: 0.99672, acc: 0.99982, rec: 0.99486, f1: 0.99523, f1_macro: 0.99757, fpr: 0.00007
# epoch: 22, passed number of graphs: 96, train running loss: 0.00029 (passed time: 1h 34m 41s)
#           acc: 0.99996, fpr: 0.00003, fnr: 0.00080, rec: 0.99920, prc: 0.99872, f1: 0.99896, f1_macro: 0.99947
# epoch: 22, passed number of graphs: 192, train running loss: 0.00035 (passed time: 1h 35m 11s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00147, rec: 0.99853, prc: 0.99967, f1: 0.99910, f1_macro: 0.99954
# epoch: 22, passed number of graphs: 288, train running loss: 0.00034 (passed time: 1h 35m 41s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00098, rec: 0.99902, prc: 0.99285, f1: 0.99593, f1_macro: 0.99792
# epoch: 22, passed number of graphs: 384, train running loss: 0.00032 (passed time: 1h 36m 12s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00209, rec: 0.99791, prc: 0.99871, f1: 0.99831, f1_macro: 0.99913
# epoch: 22, passed number of graphs: 480, train running loss: 0.00031 (passed time: 1h 36m 42s)
#           acc: 0.99982, fpr: 0.00013, fnr: 0.00229, rec: 0.99771, prc: 0.99414, f1: 0.99592, f1_macro: 0.99792
# epoch: 22, passed number of graphs: 576, train running loss: 0.00030 (passed time: 1h 37m 12s)
#           acc: 0.99972, fpr: 0.00026, fnr: 0.00097, rec: 0.99903, prc: 0.98803, f1: 0.99350, f1_macro: 0.99668
# epoch: 22, passed number of graphs: 672, train running loss: 0.00031 (passed time: 1h 37m 43s)
#           acc: 0.99965, fpr: 0.00032, fnr: 0.00176, rec: 0.99824, prc: 0.98580, f1: 0.99198, f1_macro: 0.99590

# %% [markdown]
# GIN_16Layer_MLP_5Layer_P2P
