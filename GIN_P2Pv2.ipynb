# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/Do_an_tot_nghiep/blob/main/GIN_P2Pv2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric==1.4.3
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter_
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric==1.4.3 in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.56.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.7.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.23.0)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (6.2.0)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.7.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.3.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.21.6)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.18.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.12.1+cu113)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.4)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->torch-geometric==1.4.3) (1.5.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (4.13.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (57.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (4.1.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.4.3) (1.15.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (3.0.9)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (0.6.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (3.0.4)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (3.2.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2.9.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (1.3.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (7.1.2)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2021.11.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (0.11.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric==1.4.3 in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.7.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.12.1+cu113)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.0.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.56.3)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.21.6)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (6.2.0)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.7.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.6.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.18.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.3.5)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->torch-geometric==1.4.3) (1.5.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (4.1.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.4.3) (1.15.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (3.0.9)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (0.6.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2022.9.24)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2021.11.2)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (3.2.2)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (7.1.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (1.3.0)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2.9.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
        elif split == 'val':
            self.path = self.processed_paths[1]
        elif split == 'test':
            self.path = self.processed_paths[2]

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
            self.num_graphs = self.data['num_graphs']
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            with h5py.File(self.path, 'r') as f:
                self.num_graphs = f.attrs['num_graphs']
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GINConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_input_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU())))
          else:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU()))) 

        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                add_xr_at = n
            if n == add_xr_at:
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/P2P'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=False, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...
# loading dataset...

# %%
batch_size = 2
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.0
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-a9ecc7de-3985-47da-bf30-524f7403f456.json
# ------------------------------
# ------------------------------
# Sat Nov  5 15:29:14 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GINConv(nn=Sequential(
#       (0): Linear(in_features=1, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (1): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (2): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (3): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (4): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (5): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (6): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (7): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (8): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (9): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (10): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (11): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 2
# epoch: 1, passed number of graphs: 96, train running loss: 0.07324 (passed time: 22s)
#           acc: 0.97831, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 192, train running loss: 0.05728 (passed time: 44s)
#           acc: 0.97863, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 288, train running loss: 0.04599 (passed time: 1m 5s)
#           acc: 0.98080, fpr: 0.00005, fnr: 0.90392, rec: 0.09608, prc: 0.97674, f1: 0.17495, f1_macro: 0.58262
# epoch: 1, passed number of graphs: 384, train running loss: 0.03713 (passed time: 1m 26s)
#           acc: 0.99979, fpr: 0.00001, fnr: 0.00902, rec: 0.99098, prc: 0.99935, f1: 0.99515, f1_macro: 0.99752
# epoch: 1, passed number of graphs: 480, train running loss: 0.03160 (passed time: 1m 48s)
#           acc: 0.99508, fpr: 0.00414, fnr: 0.04051, rec: 0.95949, prc: 0.83687, f1: 0.89400, f1_macro: 0.94574
# epoch: 1, passed number of graphs: 576, train running loss: 0.02732 (passed time: 2m 10s)
#           acc: 0.99985, fpr: 0.00002, fnr: 0.00581, rec: 0.99419, prc: 0.99886, f1: 0.99652, f1_macro: 0.99822
# epoch: 1, passed number of graphs: 672, train running loss: 0.02400 (passed time: 2m 33s)
#           acc: 0.99664, fpr: 0.00048, fnr: 0.13327, rec: 0.86673, prc: 0.97536, f1: 0.91784, f1_macro: 0.95806
# epoch: 1, passed number of graphs: 768, train running loss: 0.02178 (passed time: 2m 56s)
#           acc: 0.99902, fpr: 0.00010, fnr: 0.04160, rec: 0.95840, prc: 0.99543, f1: 0.97656, f1_macro: 0.98803
# Validation --- epoch: 1, loss: 0.07086
#           acc: 0.97754, fnr: 0.93953, prc: 0.59987, rec: 0.06047, f1_macro: 0.54566, f1: 0.10269, fpr: 0.00229
# Better model saved at ./saved_models/GIN_0: 0.10269273115944655.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.00357 (passed time: 3m 39s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00271, rec: 0.99729, prc: 0.99968, f1: 0.99848, f1_macro: 0.99922
# epoch: 2, passed number of graphs: 192, train running loss: 0.00344 (passed time: 4m 2s)
#           acc: 0.99979, fpr: 0.00015, fnr: 0.00278, rec: 0.99722, prc: 0.99301, f1: 0.99511, f1_macro: 0.99750
# epoch: 2, passed number of graphs: 288, train running loss: 0.00299 (passed time: 4m 24s)
#           acc: 0.99977, fpr: 0.00016, fnr: 0.00343, rec: 0.99657, prc: 0.99284, f1: 0.99470, f1_macro: 0.99729
# epoch: 2, passed number of graphs: 384, train running loss: 0.00240 (passed time: 4m 47s)
#           acc: 0.99989, fpr: 0.00001, fnr: 0.00419, rec: 0.99581, prc: 0.99935, f1: 0.99758, f1_macro: 0.99876
# epoch: 2, passed number of graphs: 480, train running loss: 0.00207 (passed time: 5m 9s)
#           acc: 0.99984, fpr: 0.00007, fnr: 0.00392, rec: 0.99608, prc: 0.99673, f1: 0.99641, f1_macro: 0.99816
# epoch: 2, passed number of graphs: 576, train running loss: 0.00391 (passed time: 5m 31s)
#           acc: 0.97950, fpr: 0.00013, fnr: 0.95125, rec: 0.04875, prc: 0.88824, f1: 0.09243, f1_macro: 0.54103
# epoch: 2, passed number of graphs: 672, train running loss: 0.00519 (passed time: 5m 54s)
#           acc: 0.99503, fpr: 0.00227, fnr: 0.12704, rec: 0.87296, prc: 0.89469, f1: 0.88369, f1_macro: 0.94058
# epoch: 2, passed number of graphs: 768, train running loss: 0.00592 (passed time: 6m 16s)
#           acc: 0.99958, fpr: 0.00002, fnr: 0.01876, rec: 0.98124, prc: 0.99917, f1: 0.99012, f1_macro: 0.99496
# Validation --- epoch: 2, loss: 0.01094
#           acc: 0.99787, fnr: 0.06123, prc: 0.96878, rec: 0.93877, f1_macro: 0.97446, f1: 0.95001, fpr: 0.00083
# Better model saved at ./saved_models/GIN_1: 0.9500062466588727.pt.
# epoch: 3, passed number of graphs: 96, train running loss: 0.00601 (passed time: 6m 59s)
#           acc: 0.99948, fpr: 0.00000, fnr: 0.02393, rec: 0.97607, prc: 0.99984, f1: 0.98781, f1_macro: 0.99377
# epoch: 3, passed number of graphs: 192, train running loss: 0.00427 (passed time: 7m 21s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00408, rec: 0.99592, prc: 0.99967, f1: 0.99779, f1_macro: 0.99887
# epoch: 3, passed number of graphs: 288, train running loss: 0.00334 (passed time: 7m 44s)
#           acc: 0.99983, fpr: 0.00008, fnr: 0.00392, rec: 0.99608, prc: 0.99608, f1: 0.99608, f1_macro: 0.99800
# epoch: 3, passed number of graphs: 384, train running loss: 0.00266 (passed time: 8m 7s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00403, rec: 0.99597, prc: 0.99935, f1: 0.99766, f1_macro: 0.99880
# epoch: 3, passed number of graphs: 480, train running loss: 0.00227 (passed time: 8m 29s)
#           acc: 0.99981, fpr: 0.00017, fnr: 0.00098, rec: 0.99902, prc: 0.99237, f1: 0.99569, f1_macro: 0.99780
# epoch: 3, passed number of graphs: 576, train running loss: 0.00211 (passed time: 8m 51s)
#           acc: 0.99976, fpr: 0.00011, fnr: 0.00613, rec: 0.99387, prc: 0.99515, f1: 0.99451, f1_macro: 0.99719
# epoch: 3, passed number of graphs: 672, train running loss: 0.00207 (passed time: 9m 14s)
#           acc: 0.99726, fpr: 0.00003, fnr: 0.12528, rec: 0.87472, prc: 0.99854, f1: 0.93254, f1_macro: 0.96557
# epoch: 3, passed number of graphs: 768, train running loss: 0.00199 (passed time: 9m 37s)
#           acc: 0.99996, fpr: 0.00003, fnr: 0.00065, rec: 0.99935, prc: 0.99870, f1: 0.99902, f1_macro: 0.99950
# Validation --- epoch: 3, loss: 0.00523
#           acc: 0.99876, fnr: 0.01272, prc: 0.96536, rec: 0.98728, f1_macro: 0.98626, f1: 0.97316, fpr: 0.00099
# Better model saved at ./saved_models/GIN_2: 0.9731551477500093.pt.
# epoch: 4, passed number of graphs: 96, train running loss: 0.03331 (passed time: 10m 20s)
#           acc: 0.99851, fpr: 0.00083, fnr: 0.03126, rec: 0.96874, prc: 0.96290, f1: 0.96581, f1_macro: 0.98252
# epoch: 4, passed number of graphs: 192, train running loss: 0.02170 (passed time: 10m 43s)
#           acc: 0.99966, fpr: 0.00008, fnr: 0.01241, rec: 0.98759, prc: 0.99638, f1: 0.99196, f1_macro: 0.99589
# epoch: 4, passed number of graphs: 288, train running loss: 0.01585 (passed time: 11m 5s)
#           acc: 0.99761, fpr: 0.00228, fnr: 0.00752, rec: 0.99248, prc: 0.90414, f1: 0.94625, f1_macro: 0.97252
# epoch: 4, passed number of graphs: 384, train running loss: 0.01246 (passed time: 11m 28s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00258, rec: 0.99742, prc: 0.99919, f1: 0.99831, f1_macro: 0.99913
# epoch: 4, passed number of graphs: 480, train running loss: 0.01021 (passed time: 11m 50s)
#           acc: 0.99978, fpr: 0.00012, fnr: 0.00506, rec: 0.99494, prc: 0.99477, f1: 0.99486, f1_macro: 0.99737
# epoch: 4, passed number of graphs: 576, train running loss: 0.00902 (passed time: 12m 13s)
#           acc: 0.99969, fpr: 0.00024, fnr: 0.00371, rec: 0.99629, prc: 0.98926, f1: 0.99276, f1_macro: 0.99630
# epoch: 4, passed number of graphs: 672, train running loss: 0.00814 (passed time: 12m 36s)
#           acc: 0.99722, fpr: 0.00001, fnr: 0.12784, rec: 0.87216, prc: 0.99927, f1: 0.93140, f1_macro: 0.96499
# epoch: 4, passed number of graphs: 768, train running loss: 0.00732 (passed time: 12m 59s)
#           acc: 0.99992, fpr: 0.00007, fnr: 0.00049, rec: 0.99951, prc: 0.99691, f1: 0.99821, f1_macro: 0.99908
# Validation --- epoch: 4, loss: 0.00381
#           acc: 0.99930, fnr: 0.01629, prc: 0.98557, rec: 0.98371, f1_macro: 0.99136, f1: 0.98309, fpr: 0.00036
# Better model saved at ./saved_models/GIN_3: 0.9830873274727819.pt.
# epoch: 5, passed number of graphs: 96, train running loss: 0.00289 (passed time: 13m 43s)
#           acc: 0.99986, fpr: 0.00000, fnr: 0.00622, rec: 0.99378, prc: 0.99984, f1: 0.99680, f1_macro: 0.99836
# epoch: 5, passed number of graphs: 192, train running loss: 0.00290 (passed time: 14m 6s)
#           acc: 0.99989, fpr: 0.00000, fnr: 0.00490, rec: 0.99510, prc: 0.99984, f1: 0.99746, f1_macro: 0.99870
# epoch: 5, passed number of graphs: 288, train running loss: 0.00250 (passed time: 14m 29s)
#           acc: 0.99981, fpr: 0.00003, fnr: 0.00752, rec: 0.99248, prc: 0.99868, f1: 0.99557, f1_macro: 0.99774
# epoch: 5, passed number of graphs: 384, train running loss: 0.00210 (passed time: 14m 52s)
#           acc: 0.99989, fpr: 0.00001, fnr: 0.00435, rec: 0.99565, prc: 0.99935, f1: 0.99750, f1_macro: 0.99872
# epoch: 5, passed number of graphs: 480, train running loss: 0.00220 (passed time: 15m 15s)
#           acc: 0.99899, fpr: 0.00100, fnr: 0.00147, rec: 0.99853, prc: 0.95650, f1: 0.97706, f1_macro: 0.98827
# epoch: 5, passed number of graphs: 576, train running loss: 0.00254 (passed time: 15m 38s)
#           acc: 0.99952, fpr: 0.00043, fnr: 0.00291, rec: 0.99709, prc: 0.98063, f1: 0.98879, f1_macro: 0.99427
# epoch: 5, passed number of graphs: 672, train running loss: 0.00259 (passed time: 16m 0s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12640, rec: 0.87360, prc: 0.99927, f1: 0.93222, f1_macro: 0.96541
# epoch: 5, passed number of graphs: 768, train running loss: 0.00248 (passed time: 16m 23s)
#           acc: 0.99988, fpr: 0.00001, fnr: 0.00538, rec: 0.99462, prc: 0.99951, f1: 0.99706, f1_macro: 0.99850
# Validation --- epoch: 5, loss: 0.00565
#           acc: 0.99921, fnr: 0.03535, prc: 0.99866, rec: 0.96465, f1_macro: 0.98939, f1: 0.97918, fpr: 0.00003
# epoch: 6, passed number of graphs: 96, train running loss: 0.00138 (passed time: 17m 6s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00112, rec: 0.99888, prc: 0.99936, f1: 0.99912, f1_macro: 0.99955
# epoch: 6, passed number of graphs: 192, train running loss: 0.00182 (passed time: 17m 29s)
#           acc: 0.99992, fpr: 0.00000, fnr: 0.00376, rec: 0.99624, prc: 1.00000, f1: 0.99812, f1_macro: 0.99904
# epoch: 6, passed number of graphs: 288, train running loss: 0.00172 (passed time: 17m 51s)
#           acc: 0.99986, fpr: 0.00003, fnr: 0.00523, rec: 0.99477, prc: 0.99852, f1: 0.99664, f1_macro: 0.99829
# epoch: 6, passed number of graphs: 384, train running loss: 0.00148 (passed time: 18m 15s)
#           acc: 0.99990, fpr: 0.00002, fnr: 0.00354, rec: 0.99646, prc: 0.99919, f1: 0.99782, f1_macro: 0.99889
# epoch: 6, passed number of graphs: 480, train running loss: 0.00132 (passed time: 18m 37s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00180, rec: 0.99820, prc: 0.99625, f1: 0.99723, f1_macro: 0.99858
# epoch: 6, passed number of graphs: 576, train running loss: 0.00195 (passed time: 19m 0s)
#           acc: 0.99178, fpr: 0.00168, fnr: 0.30734, rec: 0.69266, prc: 0.90034, f1: 0.78296, f1_macro: 0.88938
# epoch: 6, passed number of graphs: 672, train running loss: 0.00232 (passed time: 19m 22s)
#           acc: 0.99679, fpr: 0.00043, fnr: 0.12880, rec: 0.87120, prc: 0.97811, f1: 0.92157, f1_macro: 0.95996
# epoch: 6, passed number of graphs: 768, train running loss: 0.00221 (passed time: 19m 45s)
#           acc: 0.99997, fpr: 0.00002, fnr: 0.00049, rec: 0.99951, prc: 0.99918, f1: 0.99935, f1_macro: 0.99967
# Validation --- epoch: 6, loss: 0.00319
#           acc: 0.99954, fnr: 0.01922, prc: 0.99781, rec: 0.98078, f1_macro: 0.99370, f1: 0.98763, fpr: 0.00005
# Better model saved at ./saved_models/GIN_5: 0.9876267957269023.pt.
# epoch: 7, passed number of graphs: 96, train running loss: 0.01374 (passed time: 20m 28s)
#           acc: 0.99917, fpr: 0.00070, fnr: 0.00670, rec: 0.99330, prc: 0.96933, f1: 0.98117, f1_macro: 0.99037
# epoch: 7, passed number of graphs: 192, train running loss: 0.00949 (passed time: 20m 51s)
#           acc: 0.99992, fpr: 0.00000, fnr: 0.00359, rec: 0.99641, prc: 1.00000, f1: 0.99820, f1_macro: 0.99908
# epoch: 7, passed number of graphs: 288, train running loss: 0.00699 (passed time: 21m 13s)
#           acc: 0.99981, fpr: 0.00011, fnr: 0.00359, rec: 0.99641, prc: 0.99478, f1: 0.99559, f1_macro: 0.99775
# epoch: 7, passed number of graphs: 384, train running loss: 0.00553 (passed time: 21m 37s)
#           acc: 0.99989, fpr: 0.00001, fnr: 0.00435, rec: 0.99565, prc: 0.99935, f1: 0.99750, f1_macro: 0.99872
# epoch: 7, passed number of graphs: 480, train running loss: 0.00459 (passed time: 21m 59s)
#           acc: 0.99984, fpr: 0.00012, fnr: 0.00180, rec: 0.99820, prc: 0.99447, f1: 0.99633, f1_macro: 0.99813
# epoch: 7, passed number of graphs: 576, train running loss: 0.00463 (passed time: 22m 22s)
#           acc: 0.98984, fpr: 0.00000, fnr: 0.47441, rec: 0.52559, prc: 1.00000, f1: 0.68903, f1_macro: 0.84193
# epoch: 7, passed number of graphs: 672, train running loss: 0.00579 (passed time: 22m 46s)
#           acc: 0.97760, fpr: 0.00491, fnr: 0.81272, rec: 0.18728, prc: 0.45763, f1: 0.26579, f1_macro: 0.62721
# epoch: 7, passed number of graphs: 768, train running loss: 0.00774 (passed time: 23m 9s)
#           acc: 0.99504, fpr: 0.00358, fnr: 0.06835, rec: 0.93165, prc: 0.84960, f1: 0.88873, f1_macro: 0.94310
# Validation --- epoch: 7, loss: 0.02263
#           acc: 0.99610, fnr: 0.12781, prc: 0.95695, rec: 0.87219, f1_macro: 0.95257, f1: 0.90713, fpr: 0.00117
# epoch: 8, passed number of graphs: 96, train running loss: 0.00525 (passed time: 23m 54s)
#           acc: 0.99770, fpr: 0.00221, fnr: 0.00622, rec: 0.99378, prc: 0.90869, f1: 0.94933, f1_macro: 0.97408
# epoch: 8, passed number of graphs: 192, train running loss: 0.00693 (passed time: 24m 16s)
#           acc: 0.99686, fpr: 0.00001, fnr: 0.14650, rec: 0.85350, prc: 0.99924, f1: 0.92064, f1_macro: 0.95952
# epoch: 8, passed number of graphs: 288, train running loss: 0.00579 (passed time: 24m 39s)
#           acc: 0.99966, fpr: 0.00030, fnr: 0.00180, rec: 0.99820, prc: 0.98612, f1: 0.99212, f1_macro: 0.99598
# epoch: 8, passed number of graphs: 384, train running loss: 0.00491 (passed time: 25m 3s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00322, rec: 0.99678, prc: 0.99935, f1: 0.99806, f1_macro: 0.99901
# epoch: 8, passed number of graphs: 480, train running loss: 0.00421 (passed time: 25m 26s)
#           acc: 0.99978, fpr: 0.00017, fnr: 0.00261, rec: 0.99739, prc: 0.99252, f1: 0.99495, f1_macro: 0.99742
# epoch: 8, passed number of graphs: 576, train running loss: 0.00400 (passed time: 25m 49s)
#           acc: 0.99973, fpr: 0.00025, fnr: 0.00113, rec: 0.99887, prc: 0.98866, f1: 0.99374, f1_macro: 0.99680
# epoch: 8, passed number of graphs: 672, train running loss: 0.00395 (passed time: 26m 12s)
#           acc: 0.99722, fpr: 0.00002, fnr: 0.12736, rec: 0.87264, prc: 0.99872, f1: 0.93143, f1_macro: 0.96501
# epoch: 8, passed number of graphs: 768, train running loss: 0.00375 (passed time: 26m 35s)
#           acc: 0.99961, fpr: 0.00036, fnr: 0.00147, rec: 0.99853, prc: 0.98345, f1: 0.99093, f1_macro: 0.99537
# Validation --- epoch: 8, loss: 0.00460
#           acc: 0.99921, fnr: 0.02228, prc: 0.98727, rec: 0.97772, f1_macro: 0.99008, f1: 0.98056, fpr: 0.00032
# epoch: 9, passed number of graphs: 96, train running loss: 0.00215 (passed time: 27m 17s)
#           acc: 0.99997, fpr: 0.00002, fnr: 0.00080, rec: 0.99920, prc: 0.99920, f1: 0.99920, f1_macro: 0.99959
# epoch: 9, passed number of graphs: 192, train running loss: 0.00258 (passed time: 27m 40s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00180, rec: 0.99820, prc: 0.99935, f1: 0.99877, f1_macro: 0.99937
# epoch: 9, passed number of graphs: 288, train running loss: 0.00249 (passed time: 28m 2s)
#           acc: 0.99982, fpr: 0.00016, fnr: 0.00147, rec: 0.99853, prc: 0.99285, f1: 0.99568, f1_macro: 0.99779
# epoch: 9, passed number of graphs: 384, train running loss: 0.00223 (passed time: 28m 26s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00161, rec: 0.99839, prc: 0.99871, f1: 0.99855, f1_macro: 0.99926
# epoch: 9, passed number of graphs: 480, train running loss: 0.00201 (passed time: 28m 49s)
#           acc: 0.99978, fpr: 0.00019, fnr: 0.00131, rec: 0.99869, prc: 0.99141, f1: 0.99504, f1_macro: 0.99746
# epoch: 9, passed number of graphs: 576, train running loss: 0.00196 (passed time: 29m 12s)
#           acc: 0.99968, fpr: 0.00032, fnr: 0.00032, rec: 0.99968, prc: 0.98552, f1: 0.99255, f1_macro: 0.99619
# epoch: 9, passed number of graphs: 672, train running loss: 0.00200 (passed time: 29m 35s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 9, passed number of graphs: 768, train running loss: 0.00199 (passed time: 29m 58s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00131, rec: 0.99869, prc: 0.99902, f1: 0.99886, f1_macro: 0.99942
# Validation --- epoch: 9, loss: 0.00390
#           acc: 0.99932, fnr: 0.01928, prc: 0.98937, rec: 0.98072, f1_macro: 0.99155, f1: 0.98344, fpr: 0.00027
# epoch: 10, passed number of graphs: 96, train running loss: 0.00169 (passed time: 30m 42s)
#           acc: 0.99997, fpr: 0.00002, fnr: 0.00048, rec: 0.99952, prc: 0.99920, f1: 0.99936, f1_macro: 0.99967
# epoch: 10, passed number of graphs: 192, train running loss: 0.00228 (passed time: 31m 5s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00131, rec: 0.99869, prc: 0.99935, f1: 0.99902, f1_macro: 0.99950
# epoch: 10, passed number of graphs: 288, train running loss: 0.00224 (passed time: 31m 28s)
#           acc: 0.99981, fpr: 0.00016, fnr: 0.00163, rec: 0.99837, prc: 0.99253, f1: 0.99544, f1_macro: 0.99767
# epoch: 10, passed number of graphs: 384, train running loss: 0.00201 (passed time: 31m 50s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00161, rec: 0.99839, prc: 0.99871, f1: 0.99855, f1_macro: 0.99926
# epoch: 10, passed number of graphs: 480, train running loss: 0.00182 (passed time: 32m 13s)
#           acc: 0.99979, fpr: 0.00018, fnr: 0.00147, rec: 0.99853, prc: 0.99173, f1: 0.99512, f1_macro: 0.99750
# epoch: 10, passed number of graphs: 576, train running loss: 0.00179 (passed time: 32m 36s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00081, rec: 0.99919, prc: 0.98834, f1: 0.99374, f1_macro: 0.99680
# epoch: 10, passed number of graphs: 672, train running loss: 0.00183 (passed time: 32m 58s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12656, rec: 0.87344, prc: 0.99945, f1: 0.93221, f1_macro: 0.96540
# epoch: 10, passed number of graphs: 768, train running loss: 0.00185 (passed time: 33m 22s)
#           acc: 0.99993, fpr: 0.00000, fnr: 0.00310, rec: 0.99690, prc: 0.99984, f1: 0.99837, f1_macro: 0.99917
# Validation --- epoch: 10, loss: 0.00403
#           acc: 0.99928, fnr: 0.02161, prc: 0.98989, rec: 0.97839, f1_macro: 0.99105, f1: 0.98246, fpr: 0.00026
# epoch: 11, passed number of graphs: 96, train running loss: 0.00188 (passed time: 34m 7s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 11, passed number of graphs: 192, train running loss: 0.00223 (passed time: 34m 31s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99886, f1: 0.99902, f1_macro: 0.99950
# epoch: 11, passed number of graphs: 288, train running loss: 0.00218 (passed time: 34m 54s)
#           acc: 0.99981, fpr: 0.00017, fnr: 0.00114, rec: 0.99886, prc: 0.99221, f1: 0.99552, f1_macro: 0.99771
# epoch: 11, passed number of graphs: 384, train running loss: 0.00195 (passed time: 35m 17s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 11, passed number of graphs: 480, train running loss: 0.00176 (passed time: 35m 41s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00114, rec: 0.99886, prc: 0.99028, f1: 0.99455, f1_macro: 0.99722
# epoch: 11, passed number of graphs: 576, train running loss: 0.00174 (passed time: 36m 5s)
#           acc: 0.99975, fpr: 0.00023, fnr: 0.00081, rec: 0.99919, prc: 0.98945, f1: 0.99430, f1_macro: 0.99709
# epoch: 11, passed number of graphs: 672, train running loss: 0.00178 (passed time: 36m 28s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 11, passed number of graphs: 768, train running loss: 0.00177 (passed time: 36m 52s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00147, rec: 0.99853, prc: 0.99935, f1: 0.99894, f1_macro: 0.99946
# Validation --- epoch: 11, loss: 0.00376
#           acc: 0.99938, fnr: 0.01668, prc: 0.98942, rec: 0.98332, f1_macro: 0.99229, f1: 0.98490, fpr: 0.00027
# epoch: 12, passed number of graphs: 96, train running loss: 0.00160 (passed time: 37m 37s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 12, passed number of graphs: 192, train running loss: 0.00205 (passed time: 38m 1s)
#           acc: 0.99997, fpr: 0.00002, fnr: 0.00065, rec: 0.99935, prc: 0.99902, f1: 0.99918, f1_macro: 0.99958
# epoch: 12, passed number of graphs: 288, train running loss: 0.00205 (passed time: 38m 25s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00147, rec: 0.99853, prc: 0.99221, f1: 0.99536, f1_macro: 0.99763
# epoch: 12, passed number of graphs: 384, train running loss: 0.00184 (passed time: 38m 49s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 12, passed number of graphs: 480, train running loss: 0.00167 (passed time: 39m 12s)
#           acc: 0.99977, fpr: 0.00020, fnr: 0.00131, rec: 0.99869, prc: 0.99092, f1: 0.99479, f1_macro: 0.99734
# epoch: 12, passed number of graphs: 576, train running loss: 0.00166 (passed time: 39m 36s)
#           acc: 0.99978, fpr: 0.00021, fnr: 0.00081, rec: 0.99919, prc: 0.99056, f1: 0.99486, f1_macro: 0.99737
# epoch: 12, passed number of graphs: 672, train running loss: 0.00170 (passed time: 39m 59s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 12, passed number of graphs: 768, train running loss: 0.00170 (passed time: 40m 23s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00147, rec: 0.99853, prc: 0.99935, f1: 0.99894, f1_macro: 0.99946
# Validation --- epoch: 12, loss: 0.00375
#           acc: 0.99938, fnr: 0.01668, prc: 0.98936, rec: 0.98332, f1_macro: 0.99228, f1: 0.98487, fpr: 0.00027
# epoch: 13, passed number of graphs: 96, train running loss: 0.00158 (passed time: 41m 8s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 13, passed number of graphs: 192, train running loss: 0.00203 (passed time: 41m 32s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00098, rec: 0.99902, prc: 0.99902, f1: 0.99902, f1_macro: 0.99950
# epoch: 13, passed number of graphs: 288, train running loss: 0.00202 (passed time: 41m 55s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00147, rec: 0.99853, prc: 0.99221, f1: 0.99536, f1_macro: 0.99763
# epoch: 13, passed number of graphs: 384, train running loss: 0.00181 (passed time: 42m 18s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 13, passed number of graphs: 480, train running loss: 0.00164 (passed time: 42m 41s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00114, rec: 0.99886, prc: 0.99093, f1: 0.99488, f1_macro: 0.99738
# epoch: 13, passed number of graphs: 576, train running loss: 0.00164 (passed time: 43m 5s)
#           acc: 0.99975, fpr: 0.00024, fnr: 0.00081, rec: 0.99919, prc: 0.98913, f1: 0.99414, f1_macro: 0.99700
# epoch: 13, passed number of graphs: 672, train running loss: 0.00168 (passed time: 43m 30s)
#           acc: 0.99724, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99945, f1: 0.93203, f1_macro: 0.96531
# epoch: 13, passed number of graphs: 768, train running loss: 0.00168 (passed time: 43m 53s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00179, rec: 0.99821, prc: 0.99951, f1: 0.99886, f1_macro: 0.99942
# Validation --- epoch: 13, loss: 0.00363
#           acc: 0.99938, fnr: 0.01698, prc: 0.98976, rec: 0.98302, f1_macro: 0.99230, f1: 0.98492, fpr: 0.00026
# epoch: 14, passed number of graphs: 96, train running loss: 0.00157 (passed time: 44m 38s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 14, passed number of graphs: 192, train running loss: 0.00201 (passed time: 45m 1s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 14, passed number of graphs: 288, train running loss: 0.00201 (passed time: 45m 24s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99221, f1: 0.99528, f1_macro: 0.99759
# epoch: 14, passed number of graphs: 384, train running loss: 0.00180 (passed time: 45m 48s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 14, passed number of graphs: 480, train running loss: 0.00163 (passed time: 46m 11s)
#           acc: 0.99977, fpr: 0.00021, fnr: 0.00114, rec: 0.99886, prc: 0.99060, f1: 0.99471, f1_macro: 0.99730
# epoch: 14, passed number of graphs: 576, train running loss: 0.00163 (passed time: 46m 34s)
#           acc: 0.99975, fpr: 0.00024, fnr: 0.00081, rec: 0.99919, prc: 0.98913, f1: 0.99414, f1_macro: 0.99700
# epoch: 14, passed number of graphs: 672, train running loss: 0.00167 (passed time: 46m 57s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 14, passed number of graphs: 768, train running loss: 0.00167 (passed time: 47m 21s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00179, rec: 0.99821, prc: 0.99951, f1: 0.99886, f1_macro: 0.99942
# Validation --- epoch: 14, loss: 0.00362
#           acc: 0.99938, fnr: 0.01693, prc: 0.98976, rec: 0.98307, f1_macro: 0.99231, f1: 0.98494, fpr: 0.00026
# epoch: 15, passed number of graphs: 96, train running loss: 0.00156 (passed time: 48m 6s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00016, rec: 0.99984, prc: 0.99920, f1: 0.99952, f1_macro: 0.99976
# epoch: 15, passed number of graphs: 192, train running loss: 0.00201 (passed time: 48m 29s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 15, passed number of graphs: 288, train running loss: 0.00200 (passed time: 48m 52s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
# epoch: 15, passed number of graphs: 384, train running loss: 0.00179 (passed time: 49m 16s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 15, passed number of graphs: 480, train running loss: 0.00162 (passed time: 49m 39s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00114, rec: 0.99886, prc: 0.99093, f1: 0.99488, f1_macro: 0.99738
# epoch: 15, passed number of graphs: 576, train running loss: 0.00162 (passed time: 50m 2s)
#           acc: 0.99978, fpr: 0.00021, fnr: 0.00081, rec: 0.99919, prc: 0.99056, f1: 0.99486, f1_macro: 0.99737
# epoch: 15, passed number of graphs: 672, train running loss: 0.00166 (passed time: 50m 25s)
#           acc: 0.99724, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99945, f1: 0.93203, f1_macro: 0.96531
# epoch: 15, passed number of graphs: 768, train running loss: 0.00166 (passed time: 50m 49s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 15, loss: 0.00361
#           acc: 0.99938, fnr: 0.01709, prc: 0.98989, rec: 0.98291, f1_macro: 0.99231, f1: 0.98493, fpr: 0.00026
# epoch: 16, passed number of graphs: 96, train running loss: 0.00156 (passed time: 51m 33s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 16, passed number of graphs: 192, train running loss: 0.00200 (passed time: 51m 57s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00098, rec: 0.99902, prc: 0.99902, f1: 0.99902, f1_macro: 0.99950
# epoch: 16, passed number of graphs: 288, train running loss: 0.00200 (passed time: 52m 20s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
# epoch: 16, passed number of graphs: 384, train running loss: 0.00179 (passed time: 52m 43s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 16, passed number of graphs: 480, train running loss: 0.00162 (passed time: 53m 7s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00114, rec: 0.99886, prc: 0.99093, f1: 0.99488, f1_macro: 0.99738
# epoch: 16, passed number of graphs: 576, train running loss: 0.00162 (passed time: 53m 30s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00081, rec: 0.99919, prc: 0.99072, f1: 0.99494, f1_macro: 0.99741
# epoch: 16, passed number of graphs: 672, train running loss: 0.00166 (passed time: 53m 53s)
#           acc: 0.99724, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99945, f1: 0.93203, f1_macro: 0.96531
# epoch: 16, passed number of graphs: 768, train running loss: 0.00166 (passed time: 54m 17s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 16, loss: 0.00361
#           acc: 0.99938, fnr: 0.01709, prc: 0.98989, rec: 0.98291, f1_macro: 0.99231, f1: 0.98493, fpr: 0.00026
# epoch: 17, passed number of graphs: 96, train running loss: 0.00155 (passed time: 55m 1s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 17, passed number of graphs: 192, train running loss: 0.00200 (passed time: 55m 24s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 17, passed number of graphs: 288, train running loss: 0.00199 (passed time: 55m 48s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
# epoch: 17, passed number of graphs: 384, train running loss: 0.00179 (passed time: 56m 11s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 17, passed number of graphs: 480, train running loss: 0.00162 (passed time: 56m 34s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00114, rec: 0.99886, prc: 0.99028, f1: 0.99455, f1_macro: 0.99722
# epoch: 17, passed number of graphs: 576, train running loss: 0.00161 (passed time: 56m 58s)
#           acc: 0.99979, fpr: 0.00020, fnr: 0.00081, rec: 0.99919, prc: 0.99088, f1: 0.99502, f1_macro: 0.99745
# epoch: 17, passed number of graphs: 672, train running loss: 0.00166 (passed time: 57m 21s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 17, passed number of graphs: 768, train running loss: 0.00166 (passed time: 57m 44s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 17, loss: 0.00361
#           acc: 0.99938, fnr: 0.01712, prc: 0.98996, rec: 0.98288, f1_macro: 0.99232, f1: 0.98495, fpr: 0.00025
# epoch: 18, passed number of graphs: 96, train running loss: 0.00155 (passed time: 58m 29s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 18, passed number of graphs: 192, train running loss: 0.00200 (passed time: 58m 52s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 18, passed number of graphs: 288, train running loss: 0.00199 (passed time: 59m 15s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
# epoch: 18, passed number of graphs: 384, train running loss: 0.00178 (passed time: 59m 39s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 18, passed number of graphs: 480, train running loss: 0.00162 (passed time: 1h 0m 2s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00114, rec: 0.99886, prc: 0.99028, f1: 0.99455, f1_macro: 0.99722
# epoch: 18, passed number of graphs: 576, train running loss: 0.00161 (passed time: 1h 0m 25s)
#           acc: 0.99979, fpr: 0.00020, fnr: 0.00081, rec: 0.99919, prc: 0.99088, f1: 0.99502, f1_macro: 0.99745
# epoch: 18, passed number of graphs: 672, train running loss: 0.00166 (passed time: 1h 0m 47s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 18, passed number of graphs: 768, train running loss: 0.00166 (passed time: 1h 1m 11s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 18, loss: 0.00361
#           acc: 0.99938, fnr: 0.01712, prc: 0.98995, rec: 0.98288, f1_macro: 0.99231, f1: 0.98494, fpr: 0.00025
# epoch: 19, passed number of graphs: 96, train running loss: 0.00155 (passed time: 1h 1m 54s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 19, passed number of graphs: 192, train running loss: 0.00200 (passed time: 1h 2m 17s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 19, passed number of graphs: 288, train running loss: 0.00199 (passed time: 1h 2m 39s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
# epoch: 19, passed number of graphs: 384, train running loss: 0.00178 (passed time: 1h 3m 2s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 19, passed number of graphs: 480, train running loss: 0.00162 (passed time: 1h 3m 25s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00114, rec: 0.99886, prc: 0.99012, f1: 0.99447, f1_macro: 0.99717
# epoch: 19, passed number of graphs: 576, train running loss: 0.00161 (passed time: 1h 3m 49s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00081, rec: 0.99919, prc: 0.99072, f1: 0.99494, f1_macro: 0.99741
# epoch: 19, passed number of graphs: 672, train running loss: 0.00165 (passed time: 1h 4m 12s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 19, passed number of graphs: 768, train running loss: 0.00165 (passed time: 1h 4m 35s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 19, loss: 0.00361
#           acc: 0.99939, fnr: 0.01714, prc: 0.98999, rec: 0.98286, f1_macro: 0.99232, f1: 0.98495, fpr: 0.00025
# epoch: 20, passed number of graphs: 96, train running loss: 0.00155 (passed time: 1h 5m 19s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 20, passed number of graphs: 192, train running loss: 0.00200 (passed time: 1h 5m 43s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 20, passed number of graphs: 288, train running loss: 0.00199 (passed time: 1h 6m 5s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
# epoch: 20, passed number of graphs: 384, train running loss: 0.00178 (passed time: 1h 6m 29s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 20, passed number of graphs: 480, train running loss: 0.00162 (passed time: 1h 6m 51s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00114, rec: 0.99886, prc: 0.99012, f1: 0.99447, f1_macro: 0.99717
# epoch: 20, passed number of graphs: 576, train running loss: 0.00161 (passed time: 1h 7m 15s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00081, rec: 0.99919, prc: 0.99072, f1: 0.99494, f1_macro: 0.99741
# epoch: 20, passed number of graphs: 672, train running loss: 0.00165 (passed time: 1h 7m 38s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 20, passed number of graphs: 768, train running loss: 0.00165 (passed time: 1h 8m 1s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 20, loss: 0.00361
#           acc: 0.99938, fnr: 0.01715, prc: 0.98999, rec: 0.98285, f1_macro: 0.99232, f1: 0.98495, fpr: 0.00025
# epoch: 21, passed number of graphs: 96, train running loss: 0.00155 (passed time: 1h 8m 46s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 21, passed number of graphs: 192, train running loss: 0.00200 (passed time: 1h 9m 9s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 21, passed number of graphs: 288, train running loss: 0.00199 (passed time: 1h 9m 31s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
# epoch: 21, passed number of graphs: 384, train running loss: 0.00178 (passed time: 1h 9m 54s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 21, passed number of graphs: 480, train running loss: 0.00162 (passed time: 1h 10m 17s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00114, rec: 0.99886, prc: 0.99012, f1: 0.99447, f1_macro: 0.99717
# epoch: 21, passed number of graphs: 576, train running loss: 0.00161 (passed time: 1h 10m 40s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00081, rec: 0.99919, prc: 0.99072, f1: 0.99494, f1_macro: 0.99741
# epoch: 21, passed number of graphs: 672, train running loss: 0.00165 (passed time: 1h 11m 4s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 21, passed number of graphs: 768, train running loss: 0.00165 (passed time: 1h 11m 27s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 21, loss: 0.00361
#           acc: 0.99938, fnr: 0.01715, prc: 0.98999, rec: 0.98285, f1_macro: 0.99232, f1: 0.98495, fpr: 0.00025
# epoch: 22, passed number of graphs: 96, train running loss: 0.00155 (passed time: 1h 12m 11s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 22, passed number of graphs: 192, train running loss: 0.00200 (passed time: 1h 12m 34s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 22, passed number of graphs: 288, train running loss: 0.00199 (passed time: 1h 12m 57s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
# epoch: 22, passed number of graphs: 384, train running loss: 0.00178 (passed time: 1h 13m 20s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 22, passed number of graphs: 480, train running loss: 0.00162 (passed time: 1h 13m 43s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00114, rec: 0.99886, prc: 0.99012, f1: 0.99447, f1_macro: 0.99717
# epoch: 22, passed number of graphs: 576, train running loss: 0.00161 (passed time: 1h 14m 6s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00081, rec: 0.99919, prc: 0.99072, f1: 0.99494, f1_macro: 0.99741
# epoch: 22, passed number of graphs: 672, train running loss: 0.00165 (passed time: 1h 14m 29s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 22, passed number of graphs: 768, train running loss: 0.00165 (passed time: 1h 14m 53s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 22, loss: 0.00360
#           acc: 0.99938, fnr: 0.01715, prc: 0.98999, rec: 0.98285, f1_macro: 0.99232, f1: 0.98495, fpr: 0.00025
# epoch: 23, passed number of graphs: 96, train running loss: 0.00155 (passed time: 1h 15m 37s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 23, passed number of graphs: 192, train running loss: 0.00200 (passed time: 1h 16m 0s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 23, passed number of graphs: 288, train running loss: 0.00199 (passed time: 1h 16m 22s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
# epoch: 23, passed number of graphs: 384, train running loss: 0.00178 (passed time: 1h 16m 45s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 23, passed number of graphs: 480, train running loss: 0.00162 (passed time: 1h 17m 8s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00114, rec: 0.99886, prc: 0.99012, f1: 0.99447, f1_macro: 0.99717
# epoch: 23, passed number of graphs: 576, train running loss: 0.00161 (passed time: 1h 17m 31s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00081, rec: 0.99919, prc: 0.99072, f1: 0.99494, f1_macro: 0.99741
# epoch: 23, passed number of graphs: 672, train running loss: 0.00165 (passed time: 1h 17m 54s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 23, passed number of graphs: 768, train running loss: 0.00165 (passed time: 1h 18m 17s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 23, loss: 0.00360
#           acc: 0.99938, fnr: 0.01715, prc: 0.98999, rec: 0.98285, f1_macro: 0.99232, f1: 0.98495, fpr: 0.00025
# epoch: 24, passed number of graphs: 96, train running loss: 0.00155 (passed time: 1h 19m 1s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 24, passed number of graphs: 192, train running loss: 0.00200 (passed time: 1h 19m 24s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 24, passed number of graphs: 288, train running loss: 0.00199 (passed time: 1h 19m 47s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
# epoch: 24, passed number of graphs: 384, train running loss: 0.00178 (passed time: 1h 20m 10s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 24, passed number of graphs: 480, train running loss: 0.00162 (passed time: 1h 20m 33s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00114, rec: 0.99886, prc: 0.99012, f1: 0.99447, f1_macro: 0.99717
# epoch: 24, passed number of graphs: 576, train running loss: 0.00161 (passed time: 1h 20m 56s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00081, rec: 0.99919, prc: 0.99072, f1: 0.99494, f1_macro: 0.99741
# epoch: 24, passed number of graphs: 672, train running loss: 0.00165 (passed time: 1h 21m 19s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 24, passed number of graphs: 768, train running loss: 0.00165 (passed time: 1h 21m 43s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 24, loss: 0.00360
#           acc: 0.99938, fnr: 0.01715, prc: 0.98999, rec: 0.98285, f1_macro: 0.99232, f1: 0.98495, fpr: 0.00025
# epoch: 25, passed number of graphs: 96, train running loss: 0.00155 (passed time: 1h 22m 27s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 25, passed number of graphs: 192, train running loss: 0.00200 (passed time: 1h 22m 50s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 25, passed number of graphs: 288, train running loss: 0.00199 (passed time: 1h 23m 13s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
# epoch: 25, passed number of graphs: 384, train running loss: 0.00178 (passed time: 1h 23m 36s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# ...
# epoch: 29, passed number of graphs: 480, train running loss: 0.00162 (passed time: 1h 37m 41s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00114, rec: 0.99886, prc: 0.99012, f1: 0.99447, f1_macro: 0.99717
# epoch: 29, passed number of graphs: 576, train running loss: 0.00161 (passed time: 1h 38m 4s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00081, rec: 0.99919, prc: 0.99072, f1: 0.99494, f1_macro: 0.99741
# epoch: 29, passed number of graphs: 672, train running loss: 0.00165 (passed time: 1h 38m 27s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 29, passed number of graphs: 768, train running loss: 0.00165 (passed time: 1h 38m 50s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 29, loss: 0.00360
#           acc: 0.99938, fnr: 0.01715, prc: 0.98999, rec: 0.98285, f1_macro: 0.99232, f1: 0.98495, fpr: 0.00025
# epoch: 30, passed number of graphs: 96, train running loss: 0.00155 (passed time: 1h 39m 34s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 30, passed number of graphs: 192, train running loss: 0.00200 (passed time: 1h 39m 57s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 30, passed number of graphs: 288, train running loss: 0.00199 (passed time: 1h 40m 20s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
# epoch: 30, passed number of graphs: 384, train running loss: 0.00178 (passed time: 1h 40m 43s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 30, passed number of graphs: 480, train running loss: 0.00162 (passed time: 1h 41m 6s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00114, rec: 0.99886, prc: 0.99012, f1: 0.99447, f1_macro: 0.99717
# epoch: 30, passed number of graphs: 576, train running loss: 0.00161 (passed time: 1h 41m 29s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00081, rec: 0.99919, prc: 0.99072, f1: 0.99494, f1_macro: 0.99741
# epoch: 30, passed number of graphs: 672, train running loss: 0.00165 (passed time: 1h 41m 53s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 30, passed number of graphs: 768, train running loss: 0.00165 (passed time: 1h 42m 16s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 30, loss: 0.00360
#           acc: 0.99938, fnr: 0.01715, prc: 0.98999, rec: 0.98285, f1_macro: 0.99232, f1: 0.98495, fpr: 0.00025
# epoch: 31, passed number of graphs: 96, train running loss: 0.00155 (passed time: 1h 43m 0s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 31, passed number of graphs: 192, train running loss: 0.00200 (passed time: 1h 43m 23s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 31, passed number of graphs: 288, train running loss: 0.00199 (passed time: 1h 43m 46s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
# epoch: 31, passed number of graphs: 384, train running loss: 0.00178 (passed time: 1h 44m 9s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 31, passed number of graphs: 480, train running loss: 0.00162 (passed time: 1h 44m 32s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00114, rec: 0.99886, prc: 0.99012, f1: 0.99447, f1_macro: 0.99717
# epoch: 31, passed number of graphs: 576, train running loss: 0.00161 (passed time: 1h 44m 56s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00081, rec: 0.99919, prc: 0.99072, f1: 0.99494, f1_macro: 0.99741
# epoch: 31, passed number of graphs: 672, train running loss: 0.00165 (passed time: 1h 45m 19s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 31, passed number of graphs: 768, train running loss: 0.00165 (passed time: 1h 45m 43s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 31, loss: 0.00360
#           acc: 0.99938, fnr: 0.01715, prc: 0.98999, rec: 0.98285, f1_macro: 0.99232, f1: 0.98495, fpr: 0.00025
# epoch: 32, passed number of graphs: 96, train running loss: 0.00155 (passed time: 1h 46m 27s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 32, passed number of graphs: 192, train running loss: 0.00200 (passed time: 1h 46m 50s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 32, passed number of graphs: 288, train running loss: 0.00199 (passed time: 1h 47m 13s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
# epoch: 32, passed number of graphs: 384, train running loss: 0.00178 (passed time: 1h 47m 35s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 32, passed number of graphs: 480, train running loss: 0.00162 (passed time: 1h 47m 58s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00114, rec: 0.99886, prc: 0.99012, f1: 0.99447, f1_macro: 0.99717
# epoch: 32, passed number of graphs: 576, train running loss: 0.00161 (passed time: 1h 48m 22s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00081, rec: 0.99919, prc: 0.99072, f1: 0.99494, f1_macro: 0.99741
# epoch: 32, passed number of graphs: 672, train running loss: 0.00165 (passed time: 1h 48m 45s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 32, passed number of graphs: 768, train running loss: 0.00165 (passed time: 1h 49m 8s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 32, loss: 0.00360
#           acc: 0.99938, fnr: 0.01715, prc: 0.98999, rec: 0.98285, f1_macro: 0.99232, f1: 0.98495, fpr: 0.00025
# epoch: 33, passed number of graphs: 96, train running loss: 0.00155 (passed time: 1h 49m 53s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 33, passed number of graphs: 192, train running loss: 0.00200 (passed time: 1h 50m 16s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 33, passed number of graphs: 288, train running loss: 0.00199 (passed time: 1h 50m 38s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
# epoch: 33, passed number of graphs: 384, train running loss: 0.00178 (passed time: 1h 51m 1s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 33, passed number of graphs: 480, train running loss: 0.00162 (passed time: 1h 51m 24s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00114, rec: 0.99886, prc: 0.99012, f1: 0.99447, f1_macro: 0.99717
# epoch: 33, passed number of graphs: 576, train running loss: 0.00161 (passed time: 1h 51m 47s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00081, rec: 0.99919, prc: 0.99072, f1: 0.99494, f1_macro: 0.99741
# epoch: 33, passed number of graphs: 672, train running loss: 0.00165 (passed time: 1h 52m 10s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 33, passed number of graphs: 768, train running loss: 0.00165 (passed time: 1h 52m 34s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 33, loss: 0.00360
#           acc: 0.99938, fnr: 0.01715, prc: 0.98999, rec: 0.98285, f1_macro: 0.99232, f1: 0.98495, fpr: 0.00025
# epoch: 34, passed number of graphs: 96, train running loss: 0.00155 (passed time: 1h 53m 18s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 34, passed number of graphs: 192, train running loss: 0.00200 (passed time: 1h 53m 41s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 34, passed number of graphs: 288, train running loss: 0.00199 (passed time: 1h 54m 4s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
# epoch: 34, passed number of graphs: 384, train running loss: 0.00178 (passed time: 1h 54m 27s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 34, passed number of graphs: 480, train running loss: 0.00162 (passed time: 1h 54m 50s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00114, rec: 0.99886, prc: 0.99012, f1: 0.99447, f1_macro: 0.99717
# epoch: 34, passed number of graphs: 576, train running loss: 0.00161 (passed time: 1h 55m 13s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00081, rec: 0.99919, prc: 0.99072, f1: 0.99494, f1_macro: 0.99741
# epoch: 34, passed number of graphs: 672, train running loss: 0.00165 (passed time: 1h 55m 36s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 34, passed number of graphs: 768, train running loss: 0.00165 (passed time: 1h 56m 0s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 34, loss: 0.00360
#           acc: 0.99938, fnr: 0.01715, prc: 0.98999, rec: 0.98285, f1_macro: 0.99232, f1: 0.98495, fpr: 0.00025
# epoch: 35, passed number of graphs: 96, train running loss: 0.00155 (passed time: 1h 56m 44s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 35, passed number of graphs: 192, train running loss: 0.00200 (passed time: 1h 57m 7s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 35, passed number of graphs: 288, train running loss: 0.00199 (passed time: 1h 57m 30s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
# epoch: 35, passed number of graphs: 384, train running loss: 0.00178 (passed time: 1h 57m 53s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 35, passed number of graphs: 480, train running loss: 0.00162 (passed time: 1h 58m 16s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00114, rec: 0.99886, prc: 0.99012, f1: 0.99447, f1_macro: 0.99717
# epoch: 35, passed number of graphs: 576, train running loss: 0.00161 (passed time: 1h 58m 40s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00081, rec: 0.99919, prc: 0.99072, f1: 0.99494, f1_macro: 0.99741
# epoch: 35, passed number of graphs: 672, train running loss: 0.00165 (passed time: 1h 59m 3s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 35, passed number of graphs: 768, train running loss: 0.00165 (passed time: 1h 59m 26s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 35, loss: 0.00360
#           acc: 0.99938, fnr: 0.01715, prc: 0.98999, rec: 0.98285, f1_macro: 0.99232, f1: 0.98495, fpr: 0.00025
# epoch: 36, passed number of graphs: 96, train running loss: 0.00155 (passed time: 2h 0m 10s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 36, passed number of graphs: 192, train running loss: 0.00200 (passed time: 2h 0m 33s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 36, passed number of graphs: 288, train running loss: 0.00199 (passed time: 2h 0m 55s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
# epoch: 36, passed number of graphs: 384, train running loss: 0.00178 (passed time: 2h 1m 18s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 36, passed number of graphs: 480, train running loss: 0.00162 (passed time: 2h 1m 40s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00114, rec: 0.99886, prc: 0.99012, f1: 0.99447, f1_macro: 0.99717
# epoch: 36, passed number of graphs: 576, train running loss: 0.00161 (passed time: 2h 2m 3s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00081, rec: 0.99919, prc: 0.99072, f1: 0.99494, f1_macro: 0.99741
# epoch: 36, passed number of graphs: 672, train running loss: 0.00165 (passed time: 2h 2m 26s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 36, passed number of graphs: 768, train running loss: 0.00165 (passed time: 2h 2m 48s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 36, loss: 0.00360
#           acc: 0.99938, fnr: 0.01715, prc: 0.98999, rec: 0.98285, f1_macro: 0.99232, f1: 0.98495, fpr: 0.00025
# epoch: 37, passed number of graphs: 96, train running loss: 0.00155 (passed time: 2h 3m 32s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 37, passed number of graphs: 192, train running loss: 0.00200 (passed time: 2h 3m 55s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 37, passed number of graphs: 288, train running loss: 0.00199 (passed time: 2h 4m 18s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
# epoch: 37, passed number of graphs: 384, train running loss: 0.00178 (passed time: 2h 4m 41s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00145, rec: 0.99855, prc: 0.99871, f1: 0.99863, f1_macro: 0.99930
# epoch: 37, passed number of graphs: 480, train running loss: 0.00162 (passed time: 2h 5m 4s)
#           acc: 0.99976, fpr: 0.00022, fnr: 0.00114, rec: 0.99886, prc: 0.99012, f1: 0.99447, f1_macro: 0.99717
# epoch: 37, passed number of graphs: 576, train running loss: 0.00161 (passed time: 2h 5m 27s)
#           acc: 0.99978, fpr: 0.00020, fnr: 0.00081, rec: 0.99919, prc: 0.99072, f1: 0.99494, f1_macro: 0.99741
# epoch: 37, passed number of graphs: 672, train running loss: 0.00165 (passed time: 2h 5m 50s)
#           acc: 0.99725, fpr: 0.00001, fnr: 0.12688, rec: 0.87312, prc: 0.99963, f1: 0.93211, f1_macro: 0.96535
# epoch: 37, passed number of graphs: 768, train running loss: 0.00165 (passed time: 2h 6m 13s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00196, rec: 0.99804, prc: 0.99951, f1: 0.99878, f1_macro: 0.99937
# Validation --- epoch: 37, loss: 0.00360
#           acc: 0.99938, fnr: 0.01715, prc: 0.98999, rec: 0.98285, f1_macro: 0.99232, f1: 0.98495, fpr: 0.00025
# epoch: 38, passed number of graphs: 96, train running loss: 0.00155 (passed time: 2h 6m 57s)
#           acc: 0.99998, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99920, f1: 0.99944, f1_macro: 0.99971
# epoch: 38, passed number of graphs: 192, train running loss: 0.00200 (passed time: 2h 7m 20s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00082, rec: 0.99918, prc: 0.99902, f1: 0.99910, f1_macro: 0.99954
# epoch: 38, passed number of graphs: 288, train running loss: 0.00199 (passed time: 2h 7m 43s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00163, rec: 0.99837, prc: 0.99237, f1: 0.99536, f1_macro: 0.99763
