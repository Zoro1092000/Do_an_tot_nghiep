# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/Do_an_tot_nghiep/blob/main/GIN_P2P_3Layer_Dropout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric==1.4.3
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter_
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric==1.4.3 in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.6.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.18.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.23.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.12.1+cu113)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.3.5)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.56.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (6.2.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.0.2)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.7.4)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.21.6)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->torch-geometric==1.4.3) (1.5.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (4.13.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (3.10.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2022.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.4.3) (1.15.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (3.0.9)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (0.6.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2022.9.24)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2021.11.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (1.3.0)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (3.2.2)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (7.1.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2.9.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (0.11.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
        elif split == 'val':
            self.path = self.processed_paths[1]
        elif split == 'test':
            self.path = self.processed_paths[2]

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
            self.num_graphs = self.data['num_graphs']
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            with h5py.File(self.path, 'r') as f:
                self.num_graphs = f.attrs['num_graphs']
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GINConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_input_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU())))
          else:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU()))) 

        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                add_xr_at = n
            if n == add_xr_at:
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/P2P'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=True, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 2
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.2
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-ad26b88f-28df-42dc-9121-fdd443d7b1ed.json
# ------------------------------
# ------------------------------
# Sun Nov  6 06:15:28 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GINConv(nn=Sequential(
#       (0): Linear(in_features=1, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (1): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (2): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (3): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (4): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (5): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (6): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (7): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (8): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (9): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (10): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#     (11): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): ReLU()
#     ))
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 2
# epoch: 1, passed number of graphs: 96, train running loss: 0.06281 (passed time: 17s)
#           acc: 0.97830, fpr: 0.00001, fnr: 1.00000, rec: 0.00000, prc: 0.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 192, train running loss: 0.04782 (passed time: 35s)
#           acc: 0.97881, fpr: 0.00000, fnr: 0.99183, rec: 0.00817, prc: 1.00000, f1: 0.01620, f1_macro: 0.50274
# epoch: 1, passed number of graphs: 288, train running loss: 0.03760 (passed time: 52s)
#           acc: 0.99685, fpr: 0.00204, fnr: 0.05474, rec: 0.94526, prc: 0.90945, f1: 0.92701, f1_macro: 0.96270
# epoch: 1, passed number of graphs: 384, train running loss: 0.03045 (passed time: 1m 10s)
#           acc: 0.99991, fpr: 0.00003, fnr: 0.00274, rec: 0.99726, prc: 0.99871, f1: 0.99798, f1_macro: 0.99897
# epoch: 1, passed number of graphs: 480, train running loss: 0.02457 (passed time: 1m 28s)
#           acc: 0.99986, fpr: 0.00011, fnr: 0.00180, rec: 0.99820, prc: 0.99511, f1: 0.99666, f1_macro: 0.99829
# epoch: 1, passed number of graphs: 576, train running loss: 0.02133 (passed time: 1m 46s)
#           acc: 0.98956, fpr: 0.00001, fnr: 0.48749, rec: 0.51251, prc: 0.99937, f1: 0.67755, f1_macro: 0.83612
# epoch: 1, passed number of graphs: 672, train running loss: 0.01984 (passed time: 2m 3s)
#           acc: 0.99732, fpr: 0.00178, fnr: 0.04378, rec: 0.95622, prc: 0.92260, f1: 0.93911, f1_macro: 0.96887
# epoch: 1, passed number of graphs: 768, train running loss: 0.02160 (passed time: 2m 21s)
#           acc: 0.98776, fpr: 0.00005, fnr: 0.57390, rec: 0.42610, prc: 0.99505, f1: 0.59669, f1_macro: 0.79524
# Validation --- epoch: 1, loss: 0.49704
#           acc: 0.65706, fpr: 0.35037, prc: 0.05886, rec: 0.99494, f1: 0.11113, fnr: 0.00506, f1_macro: 0.44931
# Better model saved at ./saved_models/GIN_0: 0.11113344224900114.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.01043 (passed time: 2m 59s)
#           acc: 0.99976, fpr: 0.00001, fnr: 0.01021, rec: 0.98979, prc: 0.99936, f1: 0.99455, f1_macro: 0.99722
# epoch: 2, passed number of graphs: 192, train running loss: 0.00907 (passed time: 3m 16s)
#           acc: 0.99896, fpr: 0.00028, fnr: 0.03577, rec: 0.96423, prc: 0.98696, f1: 0.97546, f1_macro: 0.98747
# epoch: 2, passed number of graphs: 288, train running loss: 0.00690 (passed time: 3m 34s)
#           acc: 0.99965, fpr: 0.00010, fnr: 0.01176, rec: 0.98824, prc: 0.99523, f1: 0.99172, f1_macro: 0.99577
# epoch: 2, passed number of graphs: 384, train running loss: 0.00907 (passed time: 3m 52s)
#           acc: 0.99972, fpr: 0.00000, fnr: 0.01257, rec: 0.98743, prc: 1.00000, f1: 0.99368, f1_macro: 0.99677
# epoch: 2, passed number of graphs: 480, train running loss: 0.01086 (passed time: 4m 10s)
#           acc: 0.97837, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 576, train running loss: 0.01717 (passed time: 4m 28s)
#           acc: 0.97852, fpr: 0.00007, fnr: 1.00000, rec: 0.00000, prc: 0.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 672, train running loss: 0.02112 (passed time: 4m 45s)
#           acc: 0.97835, fpr: 0.00000, fnr: 0.99984, rec: 0.00016, prc: 1.00000, f1: 0.00032, f1_macro: 0.49469
# epoch: 2, passed number of graphs: 768, train running loss: 0.02009 (passed time: 5m 3s)
#           acc: 0.99947, fpr: 0.00001, fnr: 0.02447, rec: 0.97553, prc: 0.99950, f1: 0.98737, f1_macro: 0.99355
# Validation --- epoch: 2, loss: 6.82968
#           acc: 0.27744, fpr: 0.73845, prc: 0.02893, rec: 0.99999, f1: 0.05624, fnr: 0.00001, f1_macro: 0.23526
# epoch: 3, passed number of graphs: 96, train running loss: 0.00974 (passed time: 5m 41s)
#           acc: 0.99766, fpr: 0.00120, fnr: 0.05408, rec: 0.94592, prc: 0.94608, f1: 0.94600, f1_macro: 0.97240
# epoch: 3, passed number of graphs: 192, train running loss: 0.00642 (passed time: 5m 59s)
#           acc: 0.99969, fpr: 0.00000, fnr: 0.01437, rec: 0.98563, prc: 0.99983, f1: 0.99268, f1_macro: 0.99626
# epoch: 3, passed number of graphs: 288, train running loss: 0.00920 (passed time: 6m 16s)
#           acc: 0.99930, fpr: 0.00000, fnr: 0.03301, rec: 0.96699, prc: 0.99983, f1: 0.98314, f1_macro: 0.99139
# epoch: 3, passed number of graphs: 384, train running loss: 0.00750 (passed time: 6m 34s)
#           acc: 0.99973, fpr: 0.00000, fnr: 0.01208, rec: 0.98792, prc: 1.00000, f1: 0.99392, f1_macro: 0.99689
# epoch: 3, passed number of graphs: 480, train running loss: 0.00617 (passed time: 6m 52s)
#           acc: 0.99978, fpr: 0.00000, fnr: 0.01013, rec: 0.98987, prc: 1.00000, f1: 0.99491, f1_macro: 0.99740
# epoch: 3, passed number of graphs: 576, train running loss: 0.00527 (passed time: 7m 10s)
#           acc: 0.99986, fpr: 0.00005, fnr: 0.00420, rec: 0.99580, prc: 0.99757, f1: 0.99669, f1_macro: 0.99831
# epoch: 3, passed number of graphs: 672, train running loss: 0.01248 (passed time: 7m 28s)
#           acc: 0.97833, fpr: 0.00002, fnr: 1.00000, rec: 0.00000, prc: 0.00000, f1: 0.00000, f1_macro: nan
# epoch: 3, passed number of graphs: 768, train running loss: 0.01744 (passed time: 7m 46s)
#           acc: 0.97871, fpr: 0.00005, fnr: 1.00000, rec: 0.00000, prc: 0.00000, f1: 0.00000, f1_macro: nan
# Validation --- epoch: 3, loss: 0.10318
#           acc: 0.97848, fpr: 0.00000, prc: -1.00000, rec: 0.00000, f1: 0.00000, fnr: 1.00000, f1_macro: nan
# epoch: 4, passed number of graphs: 96, train running loss: 0.05164 (passed time: 8m 23s)
#           acc: 0.97828, fpr: 0.00003, fnr: 1.00000, rec: 0.00000, prc: 0.00000, f1: 0.00000, f1_macro: nan
# epoch: 4, passed number of graphs: 192, train running loss: 0.05099 (passed time: 8m 41s)
#           acc: 0.97855, fpr: 0.00009, fnr: 0.99967, rec: 0.00033, prc: 0.07143, f1: 0.00065, f1_macro: 0.49490
# epoch: 4, passed number of graphs: 288, train running loss: 0.04720 (passed time: 8m 58s)
#           acc: 0.97924, fpr: 0.00014, fnr: 0.97288, rec: 0.02712, prc: 0.80583, f1: 0.05248, f1_macro: 0.52099
# epoch: 4, passed number of graphs: 384, train running loss: 0.03915 (passed time: 9m 16s)
#           acc: 0.99916, fpr: 0.00015, fnr: 0.03190, rec: 0.96810, prc: 0.99339, f1: 0.98058, f1_macro: 0.99007
# epoch: 4, passed number of graphs: 480, train running loss: 0.03308 (passed time: 9m 34s)
#           acc: 0.99735, fpr: 0.00206, fnr: 0.02924, rec: 0.97076, prc: 0.91248, f1: 0.94072, f1_macro: 0.96968
# epoch: 4, passed number of graphs: 576, train running loss: 0.02896 (passed time: 9m 52s)
#           acc: 0.99201, fpr: 0.00000, fnr: 0.37288, rec: 0.62712, prc: 0.99974, f1: 0.77076, f1_macro: 0.88335
# epoch: 4, passed number of graphs: 672, train running loss: 0.02578 (passed time: 10m 10s)
#           acc: 0.97835, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 4, passed number of graphs: 768, train running loss: 0.02495 (passed time: 10m 28s)
#           acc: 0.99496, fpr: 0.00435, fnr: 0.03670, rec: 0.96330, prc: 0.82784, f1: 0.89045, f1_macro: 0.94394
# Validation --- epoch: 4, loss: 0.01536
#           acc: 0.99631, fpr: 0.00258, prc: 0.89808, rec: 0.94569, f1: 0.91854, fnr: 0.05431, f1_macro: 0.95832
# Better model saved at ./saved_models/GIN_3: 0.9185374060838681.pt.
# epoch: 5, passed number of graphs: 96, train running loss: 0.00833 (passed time: 11m 5s)
#           acc: 0.99720, fpr: 0.00212, fnr: 0.03318, rec: 0.96682, prc: 0.90992, f1: 0.93751, f1_macro: 0.96804
# epoch: 5, passed number of graphs: 192, train running loss: 0.00701 (passed time: 11m 23s)
#           acc: 0.99931, fpr: 0.00014, fnr: 0.02564, rec: 0.97436, prc: 0.99334, f1: 0.98376, f1_macro: 0.99170
# epoch: 5, passed number of graphs: 288, train running loss: 0.00589 (passed time: 11m 40s)
#           acc: 0.99948, fpr: 0.00000, fnr: 0.02451, rec: 0.97549, prc: 1.00000, f1: 0.98759, f1_macro: 0.99366
# epoch: 5, passed number of graphs: 384, train running loss: 0.00572 (passed time: 11m 58s)
#           acc: 0.99855, fpr: 0.00095, fnr: 0.02384, rec: 0.97616, prc: 0.95855, f1: 0.96727, f1_macro: 0.98326
# epoch: 5, passed number of graphs: 480, train running loss: 0.00520 (passed time: 12m 16s)
#           acc: 0.99872, fpr: 0.00105, fnr: 0.01127, rec: 0.98873, prc: 0.95398, f1: 0.97104, f1_macro: 0.98520
# epoch: 5, passed number of graphs: 576, train running loss: 0.00497 (passed time: 12m 34s)
#           acc: 0.99976, fpr: 0.00000, fnr: 0.01098, rec: 0.98902, prc: 1.00000, f1: 0.99448, f1_macro: 0.99718
# epoch: 5, passed number of graphs: 672, train running loss: 0.00472 (passed time: 12m 52s)
#           acc: 0.99695, fpr: 0.00011, fnr: 0.13583, rec: 0.86417, prc: 0.99430, f1: 0.92468, f1_macro: 0.96156
# epoch: 5, passed number of graphs: 768, train running loss: 0.00446 (passed time: 13m 10s)
#           acc: 0.99974, fpr: 0.00000, fnr: 0.01223, rec: 0.98777, prc: 1.00000, f1: 0.99384, f1_macro: 0.99686
# Validation --- epoch: 5, loss: 0.17390
#           acc: 0.97848, fpr: 0.00000, prc: -1.00000, rec: 0.00000, f1: 0.00000, fnr: 1.00000, f1_macro: nan
# epoch: 6, passed number of graphs: 96, train running loss: 0.00478 (passed time: 13m 47s)
#           acc: 0.99584, fpr: 0.00382, fnr: 0.01946, rec: 0.98054, prc: 0.85056, f1: 0.91094, f1_macro: 0.95440
# epoch: 6, passed number of graphs: 192, train running loss: 0.00573 (passed time: 14m 5s)
#           acc: 0.99950, fpr: 0.00010, fnr: 0.01878, rec: 0.98122, prc: 0.99520, f1: 0.98816, f1_macro: 0.99395
# epoch: 6, passed number of graphs: 288, train running loss: 0.00549 (passed time: 14m 22s)
#           acc: 0.99944, fpr: 0.00018, fnr: 0.01797, rec: 0.98203, prc: 0.99142, f1: 0.98670, f1_macro: 0.99321
# epoch: 6, passed number of graphs: 384, train running loss: 0.00494 (passed time: 14m 40s)
#           acc: 0.99947, fpr: 0.00002, fnr: 0.02336, rec: 0.97664, prc: 0.99918, f1: 0.98778, f1_macro: 0.99375
# epoch: 6, passed number of graphs: 480, train running loss: 0.00435 (passed time: 14m 58s)
#           acc: 0.99967, fpr: 0.00001, fnr: 0.01437, rec: 0.98563, prc: 0.99934, f1: 0.99243, f1_macro: 0.99613
# epoch: 6, passed number of graphs: 576, train running loss: 0.00405 (passed time: 15m 16s)
#           acc: 0.99979, fpr: 0.00002, fnr: 0.00904, rec: 0.99096, prc: 0.99919, f1: 0.99506, f1_macro: 0.99747
# epoch: 6, passed number of graphs: 672, train running loss: 0.00397 (passed time: 15m 33s)
#           acc: 0.99701, fpr: 0.00003, fnr: 0.13678, rec: 0.86322, prc: 0.99834, f1: 0.92587, f1_macro: 0.96217
# epoch: 6, passed number of graphs: 768, train running loss: 0.00382 (passed time: 15m 51s)
#           acc: 0.99966, fpr: 0.00006, fnr: 0.01321, rec: 0.98679, prc: 0.99703, f1: 0.99188, f1_macro: 0.99585
# Validation --- epoch: 6, loss: 0.00919
#           acc: 0.99788, fpr: 0.00167, prc: 0.94083, rec: 0.97711, f1: 0.95518, fnr: 0.02289, f1_macro: 0.97705
# Better model saved at ./saved_models/GIN_5: 0.9551798616374002.pt.
# epoch: 7, passed number of graphs: 96, train running loss: 0.00227 (passed time: 16m 29s)
#           acc: 0.99768, fpr: 0.00220, fnr: 0.00766, rec: 0.99234, prc: 0.90910, f1: 0.94890, f1_macro: 0.97386
# epoch: 7, passed number of graphs: 192, train running loss: 0.00262 (passed time: 16m 47s)
#           acc: 0.99972, fpr: 0.00001, fnr: 0.01241, rec: 0.98759, prc: 0.99934, f1: 0.99343, f1_macro: 0.99664
# epoch: 7, passed number of graphs: 288, train running loss: 0.00300 (passed time: 17m 4s)
#           acc: 0.99682, fpr: 0.00001, fnr: 0.14967, rec: 0.85033, prc: 0.99942, f1: 0.91887, f1_macro: 0.95862
# epoch: 7, passed number of graphs: 384, train running loss: 0.00299 (passed time: 17m 22s)
#           acc: 0.99972, fpr: 0.00000, fnr: 0.01289, rec: 0.98711, prc: 1.00000, f1: 0.99351, f1_macro: 0.99668
# epoch: 7, passed number of graphs: 480, train running loss: 0.00279 (passed time: 17m 40s)
#           acc: 0.99977, fpr: 0.00001, fnr: 0.01029, rec: 0.98971, prc: 0.99967, f1: 0.99466, f1_macro: 0.99727
# epoch: 7, passed number of graphs: 576, train running loss: 0.00272 (passed time: 17m 58s)
#           acc: 0.99980, fpr: 0.00001, fnr: 0.00872, rec: 0.99128, prc: 0.99951, f1: 0.99538, f1_macro: 0.99764
# epoch: 7, passed number of graphs: 672, train running loss: 0.00276 (passed time: 18m 15s)
#           acc: 0.99706, fpr: 0.00001, fnr: 0.13535, rec: 0.86465, prc: 0.99945, f1: 0.92718, f1_macro: 0.96284
# epoch: 7, passed number of graphs: 768, train running loss: 0.00331 (passed time: 18m 33s)
#           acc: 0.98105, fpr: 0.00001, fnr: 0.89152, rec: 0.10848, prc: 0.99402, f1: 0.19562, f1_macro: 0.59301
# Validation --- epoch: 7, loss: 0.05106
#           acc: 0.98663, fpr: 0.00465, prc: 0.76863, rec: 0.58999, f1: 0.65967, fnr: 0.41001, f1_macro: 0.82642
# epoch: 8, passed number of graphs: 96, train running loss: 0.01074 (passed time: 19m 11s)
#           acc: 0.99841, fpr: 0.00003, fnr: 0.07194, rec: 0.92806, prc: 0.99846, f1: 0.96197, f1_macro: 0.98058
# epoch: 8, passed number of graphs: 192, train running loss: 0.00713 (passed time: 19m 28s)
#           acc: 0.99954, fpr: 0.00000, fnr: 0.02156, rec: 0.97844, prc: 1.00000, f1: 0.98910, f1_macro: 0.99443
# epoch: 8, passed number of graphs: 288, train running loss: 0.00677 (passed time: 19m 46s)
#           acc: 0.99971, fpr: 0.00004, fnr: 0.01193, rec: 0.98807, prc: 0.99818, f1: 0.99310, f1_macro: 0.99648
# epoch: 8, passed number of graphs: 384, train running loss: 0.00621 (passed time: 20m 4s)
#           acc: 0.99917, fpr: 0.00000, fnr: 0.03786, rec: 0.96214, prc: 1.00000, f1: 0.98070, f1_macro: 0.99014
# epoch: 8, passed number of graphs: 480, train running loss: 0.00657 (passed time: 20m 22s)
#           acc: 0.99448, fpr: 0.00510, fnr: 0.02434, rec: 0.97566, prc: 0.80869, f1: 0.88436, f1_macro: 0.94077
# epoch: 8, passed number of graphs: 576, train running loss: 0.00622 (passed time: 20m 39s)
#           acc: 0.99980, fpr: 0.00001, fnr: 0.00904, rec: 0.99096, prc: 0.99951, f1: 0.99522, f1_macro: 0.99756
# epoch: 8, passed number of graphs: 672, train running loss: 0.00580 (passed time: 20m 57s)
#           acc: 0.99705, fpr: 0.00001, fnr: 0.13583, rec: 0.86417, prc: 0.99926, f1: 0.92682, f1_macro: 0.96266
# epoch: 8, passed number of graphs: 768, train running loss: 0.00530 (passed time: 21m 15s)
#           acc: 0.99977, fpr: 0.00003, fnr: 0.00914, rec: 0.99086, prc: 0.99852, f1: 0.99468, f1_macro: 0.99728
# Validation --- epoch: 8, loss: 0.01178
#           acc: 0.99650, fpr: 0.00319, prc: 0.88498, rec: 0.98251, f1: 0.92691, fnr: 0.01749, f1_macro: 0.96256
# epoch: 9, passed number of graphs: 96, train running loss: 0.00146 (passed time: 21m 52s)
#           acc: 0.99988, fpr: 0.00001, fnr: 0.00510, rec: 0.99490, prc: 0.99952, f1: 0.99720, f1_macro: 0.99857
# epoch: 9, passed number of graphs: 192, train running loss: 0.00186 (passed time: 22m 10s)
#           acc: 0.99981, fpr: 0.00000, fnr: 0.00882, rec: 0.99118, prc: 1.00000, f1: 0.99557, f1_macro: 0.99774
# epoch: 9, passed number of graphs: 288, train running loss: 0.00179 (passed time: 22m 28s)
#           acc: 0.99985, fpr: 0.00001, fnr: 0.00654, rec: 0.99346, prc: 0.99934, f1: 0.99639, f1_macro: 0.99816
# epoch: 9, passed number of graphs: 384, train running loss: 0.00160 (passed time: 22m 46s)
#           acc: 0.99973, fpr: 0.00000, fnr: 0.01208, rec: 0.98792, prc: 1.00000, f1: 0.99392, f1_macro: 0.99689
# epoch: 9, passed number of graphs: 480, train running loss: 0.00149 (passed time: 23m 3s)
#           acc: 0.99986, fpr: 0.00001, fnr: 0.00588, rec: 0.99412, prc: 0.99951, f1: 0.99681, f1_macro: 0.99837
# epoch: 9, passed number of graphs: 576, train running loss: 0.00138 (passed time: 23m 21s)
#           acc: 0.99988, fpr: 0.00001, fnr: 0.00517, rec: 0.99483, prc: 0.99935, f1: 0.99709, f1_macro: 0.99851
# epoch: 9, passed number of graphs: 672, train running loss: 0.00150 (passed time: 23m 39s)
#           acc: 0.99641, fpr: 0.00075, fnr: 0.13215, rec: 0.86785, prc: 0.96243, f1: 0.91270, f1_macro: 0.95543
# epoch: 9, passed number of graphs: 768, train running loss: 0.00149 (passed time: 23m 57s)
#           acc: 0.99981, fpr: 0.00001, fnr: 0.00848, rec: 0.99152, prc: 0.99967, f1: 0.99558, f1_macro: 0.99774
# Validation --- epoch: 9, loss: 0.00288
#           acc: 0.99962, fpr: 0.00002, prc: 0.99920, rec: 0.98314, f1: 0.99011, fnr: 0.01686, f1_macro: 0.99496
# Better model saved at ./saved_models/GIN_8: 0.99010850708315.pt.
# epoch: 10, passed number of graphs: 96, train running loss: 0.00159 (passed time: 24m 34s)
#           acc: 0.99987, fpr: 0.00001, fnr: 0.00542, rec: 0.99458, prc: 0.99936, f1: 0.99696, f1_macro: 0.99845
# epoch: 10, passed number of graphs: 192, train running loss: 0.00196 (passed time: 24m 52s)
#           acc: 0.99982, fpr: 0.00000, fnr: 0.00817, rec: 0.99183, prc: 0.99984, f1: 0.99582, f1_macro: 0.99786
# epoch: 10, passed number of graphs: 288, train running loss: 0.00185 (passed time: 25m 10s)
#           acc: 0.99985, fpr: 0.00001, fnr: 0.00637, rec: 0.99363, prc: 0.99934, f1: 0.99648, f1_macro: 0.99820
# epoch: 10, passed number of graphs: 384, train running loss: 0.00164 (passed time: 25m 27s)
#           acc: 0.99971, fpr: 0.00000, fnr: 0.01337, rec: 0.98663, prc: 1.00000, f1: 0.99327, f1_macro: 0.99656
# epoch: 10, passed number of graphs: 480, train running loss: 0.00154 (passed time: 25m 45s)
#           acc: 0.99985, fpr: 0.00001, fnr: 0.00670, rec: 0.99330, prc: 0.99967, f1: 0.99648, f1_macro: 0.99820
# epoch: 10, passed number of graphs: 576, train running loss: 0.00275 (passed time: 26m 3s)
#           acc: 0.98461, fpr: 0.00000, fnr: 0.71897, rec: 0.28103, prc: 1.00000, f1: 0.43876, f1_macro: 0.71548
# epoch: 10, passed number of graphs: 672, train running loss: 0.00351 (passed time: 26m 21s)
#           acc: 0.99707, fpr: 0.00000, fnr: 0.13535, rec: 0.86465, prc: 1.00000, f1: 0.92741, f1_macro: 0.96296
# epoch: 10, passed number of graphs: 768, train running loss: 0.00332 (passed time: 26m 38s)
#           acc: 0.99980, fpr: 0.00000, fnr: 0.00946, rec: 0.99054, prc: 0.99984, f1: 0.99517, f1_macro: 0.99753
# Validation --- epoch: 10, loss: 0.00358
#           acc: 0.99952, fpr: 0.00000, prc: 0.99989, rec: 0.97748, f1: 0.98731, fnr: 0.02252, f1_macro: 0.99353
# epoch: 11, passed number of graphs: 96, train running loss: 0.00162 (passed time: 27m 16s)
#           acc: 0.99989, fpr: 0.00000, fnr: 0.00510, rec: 0.99490, prc: 0.99984, f1: 0.99736, f1_macro: 0.99865
# epoch: 11, passed number of graphs: 192, train running loss: 0.00213 (passed time: 27m 33s)
#           acc: 0.99976, fpr: 0.00000, fnr: 0.01111, rec: 0.98889, prc: 1.00000, f1: 0.99442, f1_macro: 0.99715
# epoch: 11, passed number of graphs: 288, train running loss: 0.00201 (passed time: 27m 51s)
#           acc: 0.99983, fpr: 0.00003, fnr: 0.00654, rec: 0.99346, prc: 0.99869, f1: 0.99607, f1_macro: 0.99799
# epoch: 11, passed number of graphs: 384, train running loss: 0.00181 (passed time: 28m 9s)
#           acc: 0.99983, fpr: 0.00000, fnr: 0.00741, rec: 0.99259, prc: 0.99984, f1: 0.99620, f1_macro: 0.99806
# epoch: 11, passed number of graphs: 480, train running loss: 0.00166 (passed time: 28m 27s)
#           acc: 0.99987, fpr: 0.00001, fnr: 0.00555, rec: 0.99445, prc: 0.99934, f1: 0.99689, f1_macro: 0.99841
# epoch: 11, passed number of graphs: 576, train running loss: 0.00164 (passed time: 28m 44s)
#           acc: 0.99988, fpr: 0.00002, fnr: 0.00468, rec: 0.99532, prc: 0.99919, f1: 0.99725, f1_macro: 0.99860
# epoch: 11, passed number of graphs: 672, train running loss: 0.00169 (passed time: 29m 2s)
#           acc: 0.99921, fpr: 0.00024, fnr: 0.02541, rec: 0.97459, prc: 0.98881, f1: 0.98165, f1_macro: 0.99062
# epoch: 11, passed number of graphs: 768, train running loss: 0.00164 (passed time: 29m 20s)
#           acc: 0.99982, fpr: 0.00000, fnr: 0.00832, rec: 0.99168, prc: 0.99984, f1: 0.99574, f1_macro: 0.99782
# Validation --- epoch: 11, loss: 0.00228
#           acc: 0.99969, fpr: 0.00002, prc: 0.99920, rec: 0.98659, f1: 0.99212, fnr: 0.01341, f1_macro: 0.99598
# Better model saved at ./saved_models/GIN_10: 0.9921175608795268.pt.
# epoch: 12, passed number of graphs: 96, train running loss: 0.00130 (passed time: 29m 57s)
#           acc: 0.99988, fpr: 0.00000, fnr: 0.00542, rec: 0.99458, prc: 0.99984, f1: 0.99720, f1_macro: 0.99857
# epoch: 12, passed number of graphs: 192, train running loss: 0.00169 (passed time: 30m 15s)
#           acc: 0.99978, fpr: 0.00001, fnr: 0.00947, rec: 0.99053, prc: 0.99934, f1: 0.99491, f1_macro: 0.99740
# epoch: 12, passed number of graphs: 288, train running loss: 0.00164 (passed time: 30m 33s)
#           acc: 0.99983, fpr: 0.00001, fnr: 0.00752, rec: 0.99248, prc: 0.99934, f1: 0.99590, f1_macro: 0.99791
# epoch: 12, passed number of graphs: 384, train running loss: 0.00155 (passed time: 30m 50s)
#           acc: 0.99969, fpr: 0.00000, fnr: 0.01402, rec: 0.98598, prc: 0.99984, f1: 0.99286, f1_macro: 0.99635
# epoch: 12, passed number of graphs: 480, train running loss: 0.00145 (passed time: 31m 8s)
#           acc: 0.99984, fpr: 0.00001, fnr: 0.00719, rec: 0.99281, prc: 0.99967, f1: 0.99623, f1_macro: 0.99807
# epoch: 12, passed number of graphs: 576, train running loss: 0.00140 (passed time: 31m 26s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00404, rec: 0.99596, prc: 0.99838, f1: 0.99717, f1_macro: 0.99855
# epoch: 12, passed number of graphs: 672, train running loss: 0.00152 (passed time: 31m 43s)
#           acc: 0.99713, fpr: 0.00000, fnr: 0.13247, rec: 0.86753, prc: 0.99982, f1: 0.92899, f1_macro: 0.96376
# epoch: 12, passed number of graphs: 768, train running loss: 0.00152 (passed time: 32m 1s)
#           acc: 0.99982, fpr: 0.00000, fnr: 0.00832, rec: 0.99168, prc: 0.99984, f1: 0.99574, f1_macro: 0.99782
# Validation --- epoch: 12, loss: 0.00273
#           acc: 0.99961, fpr: 0.00002, prc: 0.99895, rec: 0.98308, f1: 0.98994, fnr: 0.01692, f1_macro: 0.99487
# epoch: 13, passed number of graphs: 96, train running loss: 0.00137 (passed time: 32m 38s)
#           acc: 0.99978, fpr: 0.00000, fnr: 0.01005, rec: 0.98995, prc: 0.99984, f1: 0.99487, f1_macro: 0.99738
# epoch: 13, passed number of graphs: 192, train running loss: 0.00165 (passed time: 32m 56s)
#           acc: 0.99955, fpr: 0.00000, fnr: 0.02123, rec: 0.97877, prc: 1.00000, f1: 0.98927, f1_macro: 0.99452
# epoch: 13, passed number of graphs: 288, train running loss: 0.00165 (passed time: 33m 14s)
#           acc: 0.99985, fpr: 0.00002, fnr: 0.00605, rec: 0.99395, prc: 0.99918, f1: 0.99656, f1_macro: 0.99824
# epoch: 13, passed number of graphs: 384, train running loss: 0.00149 (passed time: 33m 32s)
#           acc: 0.99985, fpr: 0.00001, fnr: 0.00628, rec: 0.99372, prc: 0.99951, f1: 0.99661, f1_macro: 0.99827
# epoch: 13, passed number of graphs: 480, train running loss: 0.00138 (passed time: 33m 49s)
#           acc: 0.99987, fpr: 0.00001, fnr: 0.00588, rec: 0.99412, prc: 0.99967, f1: 0.99689, f1_macro: 0.99841
# epoch: 13, passed number of graphs: 576, train running loss: 0.00132 (passed time: 34m 7s)
#           acc: 0.99986, fpr: 0.00002, fnr: 0.00565, rec: 0.99435, prc: 0.99903, f1: 0.99668, f1_macro: 0.99831
# epoch: 13, passed number of graphs: 672, train running loss: 0.00137 (passed time: 34m 25s)
#           acc: 0.99703, fpr: 0.00001, fnr: 0.13678, rec: 0.86322, prc: 0.99963, f1: 0.92643, f1_macro: 0.96246
# epoch: 13, passed number of graphs: 768, train running loss: 0.00144 (passed time: 34m 43s)
#           acc: 0.99985, fpr: 0.00000, fnr: 0.00685, rec: 0.99315, prc: 0.99984, f1: 0.99648, f1_macro: 0.99820
# Validation --- epoch: 13, loss: 0.00273
#           acc: 0.99955, fpr: 0.00001, prc: 0.99956, rec: 0.97969, f1: 0.98819, fnr: 0.02031, f1_macro: 0.99398
# epoch: 14, passed number of graphs: 96, train running loss: 0.00179 (passed time: 35m 20s)
#           acc: 0.99990, fpr: 0.00000, fnr: 0.00463, rec: 0.99537, prc: 0.99984, f1: 0.99760, f1_macro: 0.99877
# epoch: 14, passed number of graphs: 192, train running loss: 0.00192 (passed time: 35m 38s)
#           acc: 0.99985, fpr: 0.00000, fnr: 0.00702, rec: 0.99298, prc: 0.99984, f1: 0.99639, f1_macro: 0.99816
# epoch: 14, passed number of graphs: 288, train running loss: 0.00153 (passed time: 35m 55s)
#           acc: 0.99988, fpr: 0.00001, fnr: 0.00490, rec: 0.99510, prc: 0.99934, f1: 0.99722, f1_macro: 0.99858
# epoch: 14, passed number of graphs: 384, train running loss: 0.00135 (passed time: 36m 13s)
#           acc: 0.99988, fpr: 0.00001, fnr: 0.00483, rec: 0.99517, prc: 0.99951, f1: 0.99734, f1_macro: 0.99864
# epoch: 14, passed number of graphs: 480, train running loss: 0.00125 (passed time: 36m 31s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00376, rec: 0.99624, prc: 0.99934, f1: 0.99779, f1_macro: 0.99887
# epoch: 14, passed number of graphs: 576, train running loss: 0.00115 (passed time: 36m 49s)
#           acc: 0.99984, fpr: 0.00010, fnr: 0.00323, rec: 0.99677, prc: 0.99565, f1: 0.99621, f1_macro: 0.99806
# epoch: 14, passed number of graphs: 672, train running loss: 0.00120 (passed time: 37m 6s)
#           acc: 0.99949, fpr: 0.00040, fnr: 0.00543, rec: 0.99457, prc: 0.98217, f1: 0.98833, f1_macro: 0.99403
# epoch: 14, passed number of graphs: 768, train running loss: 0.00118 (passed time: 37m 24s)
#           acc: 0.99989, fpr: 0.00000, fnr: 0.00506, rec: 0.99494, prc: 0.99984, f1: 0.99738, f1_macro: 0.99866
# Validation --- epoch: 14, loss: 0.00196
#           acc: 0.99973, fpr: 0.00003, prc: 0.99845, rec: 0.98919, f1: 0.99305, fnr: 0.01081, f1_macro: 0.99646
# Better model saved at ./saved_models/GIN_13: 0.9930509286555466.pt.
# epoch: 15, passed number of graphs: 96, train running loss: 0.00098 (passed time: 38m 1s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00255, rec: 0.99745, prc: 0.99968, f1: 0.99856, f1_macro: 0.99927
# epoch: 15, passed number of graphs: 192, train running loss: 0.00098 (passed time: 38m 19s)
#           acc: 0.99989, fpr: 0.00001, fnr: 0.00457, rec: 0.99543, prc: 0.99951, f1: 0.99746, f1_macro: 0.99870
# epoch: 15, passed number of graphs: 288, train running loss: 0.00086 (passed time: 38m 37s)
#           acc: 0.99985, fpr: 0.00005, fnr: 0.00458, rec: 0.99542, prc: 0.99771, f1: 0.99656, f1_macro: 0.99825
# epoch: 15, passed number of graphs: 384, train running loss: 0.00081 (passed time: 38m 54s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00322, rec: 0.99678, prc: 0.99935, f1: 0.99806, f1_macro: 0.99901
# epoch: 15, passed number of graphs: 480, train running loss: 0.00081 (passed time: 39m 12s)
#           acc: 0.99989, fpr: 0.00005, fnr: 0.00294, rec: 0.99706, prc: 0.99787, f1: 0.99747, f1_macro: 0.99871
# epoch: 15, passed number of graphs: 576, train running loss: 0.00077 (passed time: 39m 30s)
#           acc: 0.99979, fpr: 0.00015, fnr: 0.00291, rec: 0.99709, prc: 0.99325, f1: 0.99517, f1_macro: 0.99753
# epoch: 15, passed number of graphs: 672, train running loss: 0.00085 (passed time: 39m 48s)
#           acc: 0.99954, fpr: 0.00030, fnr: 0.00751, rec: 0.99249, prc: 0.98634, f1: 0.98941, f1_macro: 0.99459
# epoch: 15, passed number of graphs: 768, train running loss: 0.00087 (passed time: 40m 5s)
#           acc: 0.99986, fpr: 0.00000, fnr: 0.00636, rec: 0.99364, prc: 0.99984, f1: 0.99673, f1_macro: 0.99833
# Validation --- epoch: 15, loss: 0.00185
#           acc: 0.99975, fpr: 0.00004, prc: 0.99814, rec: 0.99031, f1: 0.99346, fnr: 0.00969, f1_macro: 0.99667
# Better model saved at ./saved_models/GIN_14: 0.9934633018494686.pt.
# epoch: 16, passed number of graphs: 96, train running loss: 0.00090 (passed time: 40m 43s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00255, rec: 0.99745, prc: 0.99952, f1: 0.99848, f1_macro: 0.99922
# epoch: 16, passed number of graphs: 192, train running loss: 0.00092 (passed time: 41m 1s)
#           acc: 0.99990, fpr: 0.00000, fnr: 0.00457, rec: 0.99543, prc: 1.00000, f1: 0.99771, f1_macro: 0.99883
# epoch: 16, passed number of graphs: 288, train running loss: 0.00079 (passed time: 41m 18s)
#           acc: 0.99976, fpr: 0.00007, fnr: 0.00784, rec: 0.99216, prc: 0.99672, f1: 0.99443, f1_macro: 0.99716
# epoch: 16, passed number of graphs: 384, train running loss: 0.00076 (passed time: 41m 36s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00338, rec: 0.99662, prc: 0.99952, f1: 0.99806, f1_macro: 0.99901
# epoch: 16, passed number of graphs: 480, train running loss: 0.00076 (passed time: 41m 54s)
#           acc: 0.99987, fpr: 0.00006, fnr: 0.00310, rec: 0.99690, prc: 0.99722, f1: 0.99706, f1_macro: 0.99850
# epoch: 16, passed number of graphs: 576, train running loss: 0.00072 (passed time: 42m 12s)
#           acc: 0.99975, fpr: 0.00020, fnr: 0.00210, rec: 0.99790, prc: 0.99071, f1: 0.99429, f1_macro: 0.99708
# epoch: 16, passed number of graphs: 672, train running loss: 0.00079 (passed time: 42m 29s)
#           acc: 0.99946, fpr: 0.00046, fnr: 0.00415, rec: 0.99585, prc: 0.97972, f1: 0.98772, f1_macro: 0.99372
# epoch: 16, passed number of graphs: 768, train running loss: 0.00082 (passed time: 42m 47s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00359, rec: 0.99641, prc: 0.99967, f1: 0.99804, f1_macro: 0.99900
# Validation --- epoch: 16, loss: 0.00194
#           acc: 0.99975, fpr: 0.00005, prc: 0.99770, rec: 0.99068, f1: 0.99342, fnr: 0.00932, f1_macro: 0.99665
# epoch: 17, passed number of graphs: 96, train running loss: 0.00072 (passed time: 43m 24s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00175, rec: 0.99825, prc: 0.99952, f1: 0.99888, f1_macro: 0.99943
# epoch: 17, passed number of graphs: 192, train running loss: 0.00079 (passed time: 43m 42s)
#           acc: 0.99991, fpr: 0.00000, fnr: 0.00408, rec: 0.99592, prc: 1.00000, f1: 0.99795, f1_macro: 0.99895
# epoch: 17, passed number of graphs: 288, train running loss: 0.00070 (passed time: 44m 0s)
#           acc: 0.99984, fpr: 0.00008, fnr: 0.00392, rec: 0.99608, prc: 0.99624, f1: 0.99616, f1_macro: 0.99804
# epoch: 17, passed number of graphs: 384, train running loss: 0.00068 (passed time: 44m 18s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00290, rec: 0.99710, prc: 0.99935, f1: 0.99823, f1_macro: 0.99909
# epoch: 17, passed number of graphs: 480, train running loss: 0.00070 (passed time: 44m 35s)
#           acc: 0.99987, fpr: 0.00007, fnr: 0.00294, rec: 0.99706, prc: 0.99673, f1: 0.99690, f1_macro: 0.99841
# epoch: 17, passed number of graphs: 576, train running loss: 0.00067 (passed time: 44m 53s)
#           acc: 0.99975, fpr: 0.00017, fnr: 0.00355, rec: 0.99645, prc: 0.99212, f1: 0.99428, f1_macro: 0.99708
# epoch: 17, passed number of graphs: 672, train running loss: 0.00074 (passed time: 45m 11s)
#           acc: 0.99950, fpr: 0.00044, fnr: 0.00304, rec: 0.99696, prc: 0.98036, f1: 0.98859, f1_macro: 0.99417
# epoch: 17, passed number of graphs: 768, train running loss: 0.00078 (passed time: 45m 29s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00408, rec: 0.99592, prc: 0.99967, f1: 0.99779, f1_macro: 0.99887
# Validation --- epoch: 17, loss: 0.00191
#           acc: 0.99975, fpr: 0.00005, prc: 0.99775, rec: 0.99073, f1: 0.99347, fnr: 0.00927, f1_macro: 0.99667
# Better model saved at ./saved_models/GIN_16: 0.9934694377984753.pt.
# epoch: 18, passed number of graphs: 96, train running loss: 0.00058 (passed time: 46m 6s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00144, rec: 0.99856, prc: 0.99952, f1: 0.99904, f1_macro: 0.99951
# epoch: 18, passed number of graphs: 192, train running loss: 0.00080 (passed time: 46m 24s)
#           acc: 0.99995, fpr: 0.00000, fnr: 0.00245, rec: 0.99755, prc: 1.00000, f1: 0.99877, f1_macro: 0.99937
# epoch: 18, passed number of graphs: 288, train running loss: 0.00072 (passed time: 46m 41s)
#           acc: 0.99983, fpr: 0.00010, fnr: 0.00343, rec: 0.99657, prc: 0.99559, f1: 0.99608, f1_macro: 0.99800
# epoch: 18, passed number of graphs: 384, train running loss: 0.00070 (passed time: 46m 59s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00322, rec: 0.99678, prc: 0.99935, f1: 0.99806, f1_macro: 0.99901
# epoch: 18, passed number of graphs: 480, train running loss: 0.00071 (passed time: 47m 17s)
#           acc: 0.99987, fpr: 0.00007, fnr: 0.00261, rec: 0.99739, prc: 0.99674, f1: 0.99706, f1_macro: 0.99850
# epoch: 18, passed number of graphs: 576, train running loss: 0.00068 (passed time: 47m 35s)
#           acc: 0.99976, fpr: 0.00017, fnr: 0.00339, rec: 0.99661, prc: 0.99229, f1: 0.99444, f1_macro: 0.99716
# epoch: 18, passed number of graphs: 672, train running loss: 0.00074 (passed time: 47m 53s)
#           acc: 0.99955, fpr: 0.00038, fnr: 0.00368, rec: 0.99632, prc: 0.98313, f1: 0.98968, f1_macro: 0.99473
# epoch: 18, passed number of graphs: 768, train running loss: 0.00078 (passed time: 48m 11s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00424, rec: 0.99576, prc: 0.99951, f1: 0.99763, f1_macro: 0.99879
# Validation --- epoch: 18, loss: 0.00190
#           acc: 0.99975, fpr: 0.00005, prc: 0.99766, rec: 0.99086, f1: 0.99349, fnr: 0.00914, f1_macro: 0.99668
# Better model saved at ./saved_models/GIN_17: 0.9934911726559511.pt.
# epoch: 19, passed number of graphs: 96, train running loss: 0.00055 (passed time: 48m 48s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00239, rec: 0.99761, prc: 0.99952, f1: 0.99856, f1_macro: 0.99927
# epoch: 19, passed number of graphs: 192, train running loss: 0.00072 (passed time: 49m 6s)
#           acc: 0.99992, fpr: 0.00000, fnr: 0.00359, rec: 0.99641, prc: 1.00000, f1: 0.99820, f1_macro: 0.99908
# epoch: 19, passed number of graphs: 288, train running loss: 0.00068 (passed time: 49m 24s)
#           acc: 0.99983, fpr: 0.00010, fnr: 0.00359, rec: 0.99641, prc: 0.99543, f1: 0.99592, f1_macro: 0.99791
# epoch: 19, passed number of graphs: 384, train running loss: 0.00067 (passed time: 49m 42s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00338, rec: 0.99662, prc: 0.99935, f1: 0.99798, f1_macro: 0.99897
# epoch: 19, passed number of graphs: 480, train running loss: 0.00069 (passed time: 49m 59s)
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00327, rec: 0.99673, prc: 0.99641, f1: 0.99657, f1_macro: 0.99825
# epoch: 19, passed number of graphs: 576, train running loss: 0.00066 (passed time: 50m 17s)
#           acc: 0.99972, fpr: 0.00019, fnr: 0.00452, rec: 0.99548, prc: 0.99148, f1: 0.99348, f1_macro: 0.99667
# epoch: 19, passed number of graphs: 672, train running loss: 0.00072 (passed time: 50m 35s)
#           acc: 0.99956, fpr: 0.00038, fnr: 0.00304, rec: 0.99696, prc: 0.98314, f1: 0.99000, f1_macro: 0.99489
# epoch: 19, passed number of graphs: 768, train running loss: 0.00076 (passed time: 50m 53s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00424, rec: 0.99576, prc: 0.99967, f1: 0.99771, f1_macro: 0.99883
# Validation --- epoch: 19, loss: 0.00189
#           acc: 0.99975, fpr: 0.00006, prc: 0.99753, rec: 0.99102, f1: 0.99351, fnr: 0.00898, f1_macro: 0.99669
# Better model saved at ./saved_models/GIN_18: 0.9935078064512752.pt.
# epoch: 20, passed number of graphs: 96, train running loss: 0.00063 (passed time: 51m 30s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00239, rec: 0.99761, prc: 0.99952, f1: 0.99856, f1_macro: 0.99927
# epoch: 20, passed number of graphs: 192, train running loss: 0.00083 (passed time: 51m 48s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00294, rec: 0.99706, prc: 1.00000, f1: 0.99853, f1_macro: 0.99925
# epoch: 20, passed number of graphs: 288, train running loss: 0.00073 (passed time: 52m 6s)
#           acc: 0.99984, fpr: 0.00010, fnr: 0.00327, rec: 0.99673, prc: 0.99559, f1: 0.99616, f1_macro: 0.99804
# epoch: 20, passed number of graphs: 384, train running loss: 0.00071 (passed time: 52m 24s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00403, rec: 0.99597, prc: 0.99935, f1: 0.99766, f1_macro: 0.99880
# epoch: 20, passed number of graphs: 480, train running loss: 0.00073 (passed time: 52m 42s)
#           acc: 0.99985, fpr: 0.00009, fnr: 0.00294, rec: 0.99706, prc: 0.99592, f1: 0.99649, f1_macro: 0.99821
# epoch: 20, passed number of graphs: 576, train running loss: 0.00069 (passed time: 53m 0s)
#           acc: 0.99974, fpr: 0.00019, fnr: 0.00339, rec: 0.99661, prc: 0.99117, f1: 0.99388, f1_macro: 0.99687
# epoch: 20, passed number of graphs: 672, train running loss: 0.00074 (passed time: 53m 17s)
#           acc: 0.99956, fpr: 0.00034, fnr: 0.00479, rec: 0.99521, prc: 0.98466, f1: 0.98991, f1_macro: 0.99484
# epoch: 20, passed number of graphs: 768, train running loss: 0.00080 (passed time: 53m 35s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00375, rec: 0.99625, prc: 0.99967, f1: 0.99796, f1_macro: 0.99896
# Validation --- epoch: 20, loss: 0.00187
#           acc: 0.99975, fpr: 0.00005, prc: 0.99761, rec: 0.99103, f1: 0.99356, fnr: 0.00897, f1_macro: 0.99672
# Better model saved at ./saved_models/GIN_19: 0.9935562760706143.pt.
# epoch: 21, passed number of graphs: 96, train running loss: 0.00056 (passed time: 54m 13s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00175, rec: 0.99825, prc: 0.99952, f1: 0.99888, f1_macro: 0.99943
# epoch: 21, passed number of graphs: 192, train running loss: 0.00068 (passed time: 54m 31s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00261, rec: 0.99739, prc: 1.00000, f1: 0.99869, f1_macro: 0.99933
# epoch: 21, passed number of graphs: 288, train running loss: 0.00066 (passed time: 54m 48s)
#           acc: 0.99982, fpr: 0.00010, fnr: 0.00376, rec: 0.99624, prc: 0.99543, f1: 0.99584, f1_macro: 0.99787
# epoch: 21, passed number of graphs: 384, train running loss: 0.00065 (passed time: 55m 6s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00338, rec: 0.99662, prc: 0.99935, f1: 0.99798, f1_macro: 0.99897
# epoch: 21, passed number of graphs: 480, train running loss: 0.00067 (passed time: 55m 24s)
#           acc: 0.99987, fpr: 0.00008, fnr: 0.00245, rec: 0.99755, prc: 0.99625, f1: 0.99690, f1_macro: 0.99841
# epoch: 21, passed number of graphs: 576, train running loss: 0.00065 (passed time: 55m 42s)
#           acc: 0.99973, fpr: 0.00018, fnr: 0.00404, rec: 0.99596, prc: 0.99164, f1: 0.99380, f1_macro: 0.99683
# epoch: 21, passed number of graphs: 672, train running loss: 0.00073 (passed time: 55m 59s)
#           acc: 0.99957, fpr: 0.00034, fnr: 0.00431, rec: 0.99569, prc: 0.98467, f1: 0.99015, f1_macro: 0.99496
# epoch: 21, passed number of graphs: 768, train running loss: 0.00076 (passed time: 56m 17s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00440, rec: 0.99560, prc: 0.99967, f1: 0.99763, f1_macro: 0.99879
# Validation --- epoch: 21, loss: 0.00188
#           acc: 0.99975, fpr: 0.00005, prc: 0.99756, rec: 0.99106, f1: 0.99355, fnr: 0.00894, f1_macro: 0.99671
# epoch: 22, passed number of graphs: 96, train running loss: 0.00063 (passed time: 56m 54s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00255, rec: 0.99745, prc: 0.99952, f1: 0.99848, f1_macro: 0.99922
# epoch: 22, passed number of graphs: 192, train running loss: 0.00073 (passed time: 57m 12s)
#           acc: 0.99993, fpr: 0.00000, fnr: 0.00327, rec: 0.99673, prc: 1.00000, f1: 0.99836, f1_macro: 0.99916
# epoch: 22, passed number of graphs: 288, train running loss: 0.00067 (passed time: 57m 30s)
#           acc: 0.99983, fpr: 0.00010, fnr: 0.00343, rec: 0.99657, prc: 0.99543, f1: 0.99600, f1_macro: 0.99796
# epoch: 22, passed number of graphs: 384, train running loss: 0.00066 (passed time: 57m 47s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00274, rec: 0.99726, prc: 0.99935, f1: 0.99831, f1_macro: 0.99913
# epoch: 22, passed number of graphs: 480, train running loss: 0.00068 (passed time: 58m 5s)
#           acc: 0.99986, fpr: 0.00009, fnr: 0.00245, rec: 0.99755, prc: 0.99592, f1: 0.99674, f1_macro: 0.99833
# epoch: 22, passed number of graphs: 576, train running loss: 0.00065 (passed time: 58m 22s)
#           acc: 0.99975, fpr: 0.00019, fnr: 0.00274, rec: 0.99726, prc: 0.99118, f1: 0.99421, f1_macro: 0.99704
# epoch: 22, passed number of graphs: 672, train running loss: 0.00071 (passed time: 58m 40s)
#           acc: 0.99953, fpr: 0.00041, fnr: 0.00336, rec: 0.99664, prc: 0.98174, f1: 0.98914, f1_macro: 0.99445
# epoch: 22, passed number of graphs: 768, train running loss: 0.00073 (passed time: 58m 58s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00375, rec: 0.99625, prc: 0.99967, f1: 0.99796, f1_macro: 0.99896
# Validation --- epoch: 22, loss: 0.00187
#           acc: 0.99975, fpr: 0.00005, prc: 0.99754, rec: 0.99107, f1: 0.99354, fnr: 0.00893, f1_macro: 0.99671
# epoch: 23, passed number of graphs: 96, train running loss: 0.00053 (passed time: 59m 35s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00175, rec: 0.99825, prc: 0.99968, f1: 0.99896, f1_macro: 0.99947
# epoch: 23, passed number of graphs: 192, train running loss: 0.00065 (passed time: 59m 52s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00294, rec: 0.99706, prc: 1.00000, f1: 0.99853, f1_macro: 0.99925
# epoch: 23, passed number of graphs: 288, train running loss: 0.00060 (passed time: 1h 0m 10s)
#           acc: 0.99984, fpr: 0.00009, fnr: 0.00327, rec: 0.99673, prc: 0.99576, f1: 0.99624, f1_macro: 0.99808
# epoch: 23, passed number of graphs: 384, train running loss: 0.00062 (passed time: 1h 0m 27s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00403, rec: 0.99597, prc: 0.99935, f1: 0.99766, f1_macro: 0.99880
# epoch: 23, passed number of graphs: 480, train running loss: 0.00065 (passed time: 1h 0m 45s)
#           acc: 0.99987, fpr: 0.00008, fnr: 0.00245, rec: 0.99755, prc: 0.99641, f1: 0.99698, f1_macro: 0.99846
# epoch: 23, passed number of graphs: 576, train running loss: 0.00062 (passed time: 1h 1m 3s)
#           acc: 0.99974, fpr: 0.00019, fnr: 0.00323, rec: 0.99677, prc: 0.99133, f1: 0.99404, f1_macro: 0.99696
# epoch: 23, passed number of graphs: 672, train running loss: 0.00069 (passed time: 1h 1m 20s)
#           acc: 0.99957, fpr: 0.00030, fnr: 0.00655, rec: 0.99345, prc: 0.98667, f1: 0.99005, f1_macro: 0.99491
# epoch: 23, passed number of graphs: 768, train running loss: 0.00073 (passed time: 1h 1m 38s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00294, rec: 0.99706, prc: 0.99967, f1: 0.99837, f1_macro: 0.99917
# Validation --- epoch: 23, loss: 0.00188
#           acc: 0.99975, fpr: 0.00006, prc: 0.99753, rec: 0.99107, f1: 0.99354, fnr: 0.00893, f1_macro: 0.99671
# epoch: 24, passed number of graphs: 96, train running loss: 0.00047 (passed time: 1h 2m 15s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00144, rec: 0.99856, prc: 0.99936, f1: 0.99896, f1_macro: 0.99947
# epoch: 24, passed number of graphs: 192, train running loss: 0.00070 (passed time: 1h 2m 33s)
# ...
# epoch: 42, passed number of graphs: 288, train running loss: 0.00069 (passed time: 1h 51m 22s)
#           acc: 0.99983, fpr: 0.00010, fnr: 0.00359, rec: 0.99641, prc: 0.99559, f1: 0.99600, f1_macro: 0.99796
# epoch: 42, passed number of graphs: 384, train running loss: 0.00068 (passed time: 1h 51m 40s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00209, rec: 0.99791, prc: 0.99935, f1: 0.99863, f1_macro: 0.99930
# epoch: 42, passed number of graphs: 480, train running loss: 0.00070 (passed time: 1h 51m 58s)
#           acc: 0.99987, fpr: 0.00008, fnr: 0.00229, rec: 0.99771, prc: 0.99625, f1: 0.99698, f1_macro: 0.99846
# epoch: 42, passed number of graphs: 576, train running loss: 0.00066 (passed time: 1h 52m 16s)
#           acc: 0.99980, fpr: 0.00014, fnr: 0.00274, rec: 0.99726, prc: 0.99341, f1: 0.99533, f1_macro: 0.99761
# epoch: 42, passed number of graphs: 672, train running loss: 0.00072 (passed time: 1h 52m 33s)
#           acc: 0.99959, fpr: 0.00029, fnr: 0.00575, rec: 0.99425, prc: 0.98684, f1: 0.99053, f1_macro: 0.99516
# epoch: 42, passed number of graphs: 768, train running loss: 0.00075 (passed time: 1h 52m 51s)
#           acc: 0.99992, fpr: 0.00000, fnr: 0.00343, rec: 0.99657, prc: 0.99984, f1: 0.99820, f1_macro: 0.99908
# Validation --- epoch: 42, loss: 0.00187
#           acc: 0.99976, fpr: 0.00005, prc: 0.99759, rec: 0.99106, f1: 0.99356, fnr: 0.00894, f1_macro: 0.99672
# epoch: 43, passed number of graphs: 96, train running loss: 0.00052 (passed time: 1h 53m 28s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00144, rec: 0.99856, prc: 0.99952, f1: 0.99904, f1_macro: 0.99951
# epoch: 43, passed number of graphs: 192, train running loss: 0.00064 (passed time: 1h 53m 46s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00278, rec: 0.99722, prc: 1.00000, f1: 0.99861, f1_macro: 0.99929
# epoch: 43, passed number of graphs: 288, train running loss: 0.00059 (passed time: 1h 54m 4s)
#           acc: 0.99982, fpr: 0.00009, fnr: 0.00441, rec: 0.99559, prc: 0.99591, f1: 0.99575, f1_macro: 0.99783
# epoch: 43, passed number of graphs: 384, train running loss: 0.00061 (passed time: 1h 54m 22s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00338, rec: 0.99662, prc: 0.99935, f1: 0.99798, f1_macro: 0.99897
# epoch: 43, passed number of graphs: 480, train running loss: 0.00064 (passed time: 1h 54m 40s)
#           acc: 0.99984, fpr: 0.00009, fnr: 0.00294, rec: 0.99706, prc: 0.99576, f1: 0.99641, f1_macro: 0.99816
# epoch: 43, passed number of graphs: 576, train running loss: 0.00061 (passed time: 1h 54m 57s)
#           acc: 0.99975, fpr: 0.00020, fnr: 0.00242, rec: 0.99758, prc: 0.99070, f1: 0.99413, f1_macro: 0.99700
# epoch: 43, passed number of graphs: 672, train running loss: 0.00069 (passed time: 1h 55m 15s)
#           acc: 0.99958, fpr: 0.00037, fnr: 0.00272, rec: 0.99728, prc: 0.98345, f1: 0.99032, f1_macro: 0.99505
# epoch: 43, passed number of graphs: 768, train running loss: 0.00073 (passed time: 1h 55m 33s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00343, rec: 0.99657, prc: 0.99951, f1: 0.99804, f1_macro: 0.99900
# Validation --- epoch: 43, loss: 0.00187
#           acc: 0.99975, fpr: 0.00005, prc: 0.99758, rec: 0.99106, f1: 0.99356, fnr: 0.00894, f1_macro: 0.99672
# epoch: 44, passed number of graphs: 96, train running loss: 0.00048 (passed time: 1h 56m 10s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00351, rec: 0.99649, prc: 0.99952, f1: 0.99800, f1_macro: 0.99898
# epoch: 44, passed number of graphs: 192, train running loss: 0.00067 (passed time: 1h 56m 28s)
#           acc: 0.99990, fpr: 0.00000, fnr: 0.00457, rec: 0.99543, prc: 1.00000, f1: 0.99771, f1_macro: 0.99883
# epoch: 44, passed number of graphs: 288, train running loss: 0.00061 (passed time: 1h 56m 46s)
#           acc: 0.99985, fpr: 0.00010, fnr: 0.00261, rec: 0.99739, prc: 0.99560, f1: 0.99649, f1_macro: 0.99821
# epoch: 44, passed number of graphs: 384, train running loss: 0.00062 (passed time: 1h 57m 4s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00290, rec: 0.99710, prc: 0.99935, f1: 0.99823, f1_macro: 0.99909
# epoch: 44, passed number of graphs: 480, train running loss: 0.00065 (passed time: 1h 57m 22s)
#           acc: 0.99987, fpr: 0.00008, fnr: 0.00261, rec: 0.99739, prc: 0.99641, f1: 0.99690, f1_macro: 0.99841
# epoch: 44, passed number of graphs: 576, train running loss: 0.00062 (passed time: 1h 57m 39s)
#           acc: 0.99974, fpr: 0.00019, fnr: 0.00323, rec: 0.99677, prc: 0.99133, f1: 0.99404, f1_macro: 0.99696
# epoch: 44, passed number of graphs: 672, train running loss: 0.00069 (passed time: 1h 57m 57s)
#           acc: 0.99955, fpr: 0.00037, fnr: 0.00384, rec: 0.99616, prc: 0.98344, f1: 0.98976, f1_macro: 0.99477
# epoch: 44, passed number of graphs: 768, train running loss: 0.00073 (passed time: 1h 58m 15s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00326, rec: 0.99674, prc: 0.99967, f1: 0.99820, f1_macro: 0.99908
# Validation --- epoch: 44, loss: 0.00186
#           acc: 0.99976, fpr: 0.00005, prc: 0.99760, rec: 0.99106, f1: 0.99356, fnr: 0.00894, f1_macro: 0.99672
# epoch: 45, passed number of graphs: 96, train running loss: 0.00064 (passed time: 1h 58m 52s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00207, rec: 0.99793, prc: 0.99952, f1: 0.99872, f1_macro: 0.99935
# epoch: 45, passed number of graphs: 192, train running loss: 0.00077 (passed time: 1h 59m 10s)
#           acc: 0.99992, fpr: 0.00000, fnr: 0.00392, rec: 0.99608, prc: 1.00000, f1: 0.99804, f1_macro: 0.99900
# epoch: 45, passed number of graphs: 288, train running loss: 0.00068 (passed time: 1h 59m 28s)
#           acc: 0.99982, fpr: 0.00010, fnr: 0.00408, rec: 0.99592, prc: 0.99543, f1: 0.99567, f1_macro: 0.99779
# epoch: 45, passed number of graphs: 384, train running loss: 0.00067 (passed time: 1h 59m 46s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00354, rec: 0.99646, prc: 0.99952, f1: 0.99798, f1_macro: 0.99897
# epoch: 45, passed number of graphs: 480, train running loss: 0.00069 (passed time: 2h 0m 4s)
#           acc: 0.99986, fpr: 0.00008, fnr: 0.00261, rec: 0.99739, prc: 0.99625, f1: 0.99682, f1_macro: 0.99837
# epoch: 45, passed number of graphs: 576, train running loss: 0.00066 (passed time: 2h 0m 22s)
#           acc: 0.99975, fpr: 0.00020, fnr: 0.00226, rec: 0.99774, prc: 0.99086, f1: 0.99429, f1_macro: 0.99708
# epoch: 45, passed number of graphs: 672, train running loss: 0.00073 (passed time: 2h 0m 39s)
#           acc: 0.99953, fpr: 0.00042, fnr: 0.00272, rec: 0.99728, prc: 0.98114, f1: 0.98914, f1_macro: 0.99445
# epoch: 45, passed number of graphs: 768, train running loss: 0.00076 (passed time: 2h 0m 57s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00392, rec: 0.99608, prc: 0.99967, f1: 0.99788, f1_macro: 0.99891
# Validation --- epoch: 45, loss: 0.00187
#           acc: 0.99975, fpr: 0.00005, prc: 0.99758, rec: 0.99106, f1: 0.99356, fnr: 0.00894, f1_macro: 0.99672
# epoch: 46, passed number of graphs: 96, train running loss: 0.00063 (passed time: 2h 1m 35s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00160, rec: 0.99840, prc: 0.99952, f1: 0.99896, f1_macro: 0.99947
# epoch: 46, passed number of graphs: 192, train running loss: 0.00076 (passed time: 2h 1m 53s)
#           acc: 0.99993, fpr: 0.00000, fnr: 0.00327, rec: 0.99673, prc: 1.00000, f1: 0.99836, f1_macro: 0.99916
# epoch: 46, passed number of graphs: 288, train running loss: 0.00069 (passed time: 2h 2m 10s)
#           acc: 0.99984, fpr: 0.00010, fnr: 0.00327, rec: 0.99673, prc: 0.99559, f1: 0.99616, f1_macro: 0.99804
# epoch: 46, passed number of graphs: 384, train running loss: 0.00068 (passed time: 2h 2m 28s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00290, rec: 0.99710, prc: 0.99935, f1: 0.99823, f1_macro: 0.99909
# epoch: 46, passed number of graphs: 480, train running loss: 0.00070 (passed time: 2h 2m 46s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00196, rec: 0.99804, prc: 0.99641, f1: 0.99723, f1_macro: 0.99858
# epoch: 46, passed number of graphs: 576, train running loss: 0.00066 (passed time: 2h 3m 4s)
#           acc: 0.99975, fpr: 0.00019, fnr: 0.00258, rec: 0.99742, prc: 0.99118, f1: 0.99429, f1_macro: 0.99708
# epoch: 46, passed number of graphs: 672, train running loss: 0.00072 (passed time: 2h 3m 22s)
#           acc: 0.99955, fpr: 0.00030, fnr: 0.00719, rec: 0.99281, prc: 0.98635, f1: 0.98957, f1_macro: 0.99467
# epoch: 46, passed number of graphs: 768, train running loss: 0.00075 (passed time: 2h 3m 40s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00392, rec: 0.99608, prc: 0.99967, f1: 0.99788, f1_macro: 0.99891
# Validation --- epoch: 46, loss: 0.00186
#           acc: 0.99976, fpr: 0.00005, prc: 0.99760, rec: 0.99106, f1: 0.99356, fnr: 0.00894, f1_macro: 0.99672
# epoch: 47, passed number of graphs: 96, train running loss: 0.00048 (passed time: 2h 4m 18s)
#           acc: 0.99996, fpr: 0.00001, fnr: 0.00160, rec: 0.99840, prc: 0.99952, f1: 0.99896, f1_macro: 0.99947
# epoch: 47, passed number of graphs: 192, train running loss: 0.00068 (passed time: 2h 4m 36s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00278, rec: 0.99722, prc: 1.00000, f1: 0.99861, f1_macro: 0.99929
# epoch: 47, passed number of graphs: 288, train running loss: 0.00063 (passed time: 2h 4m 54s)
#           acc: 0.99984, fpr: 0.00010, fnr: 0.00327, rec: 0.99673, prc: 0.99559, f1: 0.99616, f1_macro: 0.99804
# epoch: 47, passed number of graphs: 384, train running loss: 0.00063 (passed time: 2h 5m 12s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00242, rec: 0.99758, prc: 0.99919, f1: 0.99839, f1_macro: 0.99918
# epoch: 47, passed number of graphs: 480, train running loss: 0.00066 (passed time: 2h 5m 29s)
#           acc: 0.99988, fpr: 0.00007, fnr: 0.00261, rec: 0.99739, prc: 0.99690, f1: 0.99714, f1_macro: 0.99854
# epoch: 47, passed number of graphs: 576, train running loss: 0.00063 (passed time: 2h 5m 47s)
#           acc: 0.99974, fpr: 0.00020, fnr: 0.00291, rec: 0.99709, prc: 0.99086, f1: 0.99397, f1_macro: 0.99692
# epoch: 47, passed number of graphs: 672, train running loss: 0.00069 (passed time: 2h 6m 5s)
#           acc: 0.99954, fpr: 0.00041, fnr: 0.00304, rec: 0.99696, prc: 0.98190, f1: 0.98938, f1_macro: 0.99457
# epoch: 47, passed number of graphs: 768, train running loss: 0.00073 (passed time: 2h 6m 23s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00392, rec: 0.99608, prc: 0.99967, f1: 0.99788, f1_macro: 0.99891
# Validation --- epoch: 47, loss: 0.00187
#           acc: 0.99976, fpr: 0.00005, prc: 0.99759, rec: 0.99107, f1: 0.99356, fnr: 0.00893, f1_macro: 0.99672
# epoch: 48, passed number of graphs: 96, train running loss: 0.00056 (passed time: 2h 7m 1s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00191, rec: 0.99809, prc: 0.99952, f1: 0.99880, f1_macro: 0.99939
# epoch: 48, passed number of graphs: 192, train running loss: 0.00079 (passed time: 2h 7m 19s)
#           acc: 0.99993, fpr: 0.00000, fnr: 0.00343, rec: 0.99657, prc: 1.00000, f1: 0.99828, f1_macro: 0.99912
# epoch: 48, passed number of graphs: 288, train running loss: 0.00073 (passed time: 2h 7m 37s)
#           acc: 0.99982, fpr: 0.00010, fnr: 0.00359, rec: 0.99641, prc: 0.99527, f1: 0.99584, f1_macro: 0.99787
# epoch: 48, passed number of graphs: 384, train running loss: 0.00071 (passed time: 2h 7m 55s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00306, rec: 0.99694, prc: 0.99952, f1: 0.99823, f1_macro: 0.99909
# epoch: 48, passed number of graphs: 480, train running loss: 0.00072 (passed time: 2h 8m 13s)
#           acc: 0.99989, fpr: 0.00007, fnr: 0.00196, rec: 0.99804, prc: 0.99674, f1: 0.99739, f1_macro: 0.99867
# epoch: 48, passed number of graphs: 576, train running loss: 0.00068 (passed time: 2h 8m 30s)
#           acc: 0.99973, fpr: 0.00021, fnr: 0.00307, rec: 0.99693, prc: 0.99054, f1: 0.99372, f1_macro: 0.99679
# epoch: 48, passed number of graphs: 672, train running loss: 0.00074 (passed time: 2h 8m 48s)
#           acc: 0.99946, fpr: 0.00026, fnr: 0.01294, rec: 0.98706, prc: 0.98816, f1: 0.98761, f1_macro: 0.99367
# epoch: 48, passed number of graphs: 768, train running loss: 0.00077 (passed time: 2h 9m 6s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00310, rec: 0.99690, prc: 0.99951, f1: 0.99820, f1_macro: 0.99908
# Validation --- epoch: 48, loss: 0.00186
#           acc: 0.99976, fpr: 0.00005, prc: 0.99759, rec: 0.99106, f1: 0.99356, fnr: 0.00894, f1_macro: 0.99672
# epoch: 49, passed number of graphs: 96, train running loss: 0.00058 (passed time: 2h 9m 44s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00255, rec: 0.99745, prc: 0.99952, f1: 0.99848, f1_macro: 0.99922
# epoch: 49, passed number of graphs: 192, train running loss: 0.00072 (passed time: 2h 10m 2s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00278, rec: 0.99722, prc: 1.00000, f1: 0.99861, f1_macro: 0.99929
# epoch: 49, passed number of graphs: 288, train running loss: 0.00066 (passed time: 2h 10m 20s)
#           acc: 0.99984, fpr: 0.00009, fnr: 0.00327, rec: 0.99673, prc: 0.99576, f1: 0.99624, f1_macro: 0.99808
# epoch: 49, passed number of graphs: 384, train running loss: 0.00066 (passed time: 2h 10m 38s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00371, rec: 0.99629, prc: 0.99935, f1: 0.99782, f1_macro: 0.99889
# epoch: 49, passed number of graphs: 480, train running loss: 0.00068 (passed time: 2h 10m 55s)
#           acc: 0.99985, fpr: 0.00009, fnr: 0.00278, rec: 0.99722, prc: 0.99592, f1: 0.99657, f1_macro: 0.99825
# epoch: 49, passed number of graphs: 576, train running loss: 0.00065 (passed time: 2h 11m 13s)
#           acc: 0.99974, fpr: 0.00021, fnr: 0.00242, rec: 0.99758, prc: 0.99054, f1: 0.99405, f1_macro: 0.99696
# epoch: 49, passed number of graphs: 672, train running loss: 0.00071 (passed time: 2h 11m 31s)
#           acc: 0.99956, fpr: 0.00036, fnr: 0.00384, rec: 0.99616, prc: 0.98375, f1: 0.98992, f1_macro: 0.99485
# epoch: 49, passed number of graphs: 768, train running loss: 0.00075 (passed time: 2h 11m 49s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00343, rec: 0.99657, prc: 0.99951, f1: 0.99804, f1_macro: 0.99900
# Validation --- epoch: 49, loss: 0.00186
#           acc: 0.99976, fpr: 0.00005, prc: 0.99760, rec: 0.99106, f1: 0.99356, fnr: 0.00894, f1_macro: 0.99672
# epoch: 50, passed number of graphs: 96, train running loss: 0.00063 (passed time: 2h 12m 26s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00191, rec: 0.99809, prc: 0.99952, f1: 0.99880, f1_macro: 0.99939
# epoch: 50, passed number of graphs: 192, train running loss: 0.00067 (passed time: 2h 12m 44s)
#           acc: 0.99991, fpr: 0.00000, fnr: 0.00408, rec: 0.99592, prc: 1.00000, f1: 0.99795, f1_macro: 0.99895
# epoch: 50, passed number of graphs: 288, train running loss: 0.00062 (passed time: 2h 13m 2s)
#           acc: 0.99986, fpr: 0.00007, fnr: 0.00343, rec: 0.99657, prc: 0.99673, f1: 0.99665, f1_macro: 0.99829
# epoch: 50, passed number of graphs: 384, train running loss: 0.00063 (passed time: 2h 13m 19s)
#           acc: 0.99993, fpr: 0.00001, fnr: 0.00242, rec: 0.99758, prc: 0.99935, f1: 0.99847, f1_macro: 0.99922
# epoch: 50, passed number of graphs: 480, train running loss: 0.00065 (passed time: 2h 13m 37s)
#           acc: 0.99986, fpr: 0.00009, fnr: 0.00261, rec: 0.99739, prc: 0.99592, f1: 0.99665, f1_macro: 0.99829
# epoch: 50, passed number of graphs: 576, train running loss: 0.00062 (passed time: 2h 13m 55s)
#           acc: 0.99983, fpr: 0.00006, fnr: 0.00484, rec: 0.99516, prc: 0.99709, f1: 0.99612, f1_macro: 0.99802
# epoch: 50, passed number of graphs: 672, train running loss: 0.00070 (passed time: 2h 14m 13s)
#           acc: 0.99958, fpr: 0.00034, fnr: 0.00415, rec: 0.99585, prc: 0.98483, f1: 0.99031, f1_macro: 0.99505
# epoch: 50, passed number of graphs: 768, train running loss: 0.00074 (passed time: 2h 14m 31s)
#           acc: 0.99991, fpr: 0.00001, fnr: 0.00359, rec: 0.99641, prc: 0.99951, f1: 0.99796, f1_macro: 0.99896
# Validation --- epoch: 50, loss: 0.00186
#           acc: 0.99976, fpr: 0.00005, prc: 0.99759, rec: 0.99106, f1: 0.99356, fnr: 0.00894, f1_macro: 0.99672
# ************ best model obtained after epoch 28, saved at ./saved_models/GIN_27: 0.9935649216209121.pt ************
# Testing --- loss: 0.00129
#           acc: 0.99980, fpr: 0.00009, prc: 0.99586, rec: 0.99511, f1: 0.99524, fnr: 0.00489, f1_macro: 0.99757
