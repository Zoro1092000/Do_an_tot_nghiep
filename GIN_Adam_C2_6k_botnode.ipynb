# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/Do_an_tot_nghiep/blob/main/GIN_Adam_C2_6k_botnode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Oct 25 15:06:06 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    23W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric==1.4.3
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5
# !pip install torch-optimizer

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter_
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset
import torch_optimizer as optimization


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric==1.4.3 in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.7.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.23.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.56.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.6.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.21.6)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.3.5)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (6.2.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.12.1+cu113)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.18.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.0.2)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->torch-geometric==1.4.3) (1.5.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (4.13.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (0.39.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (3.9.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2022.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.4.3) (1.15.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (0.6.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (3.0.4)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2021.11.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2.9.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (7.1.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (1.3.0)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (3.2.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-optimizer in /usr/local/lib/python3.7/dist-packages (0.3.0)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (1.12.1+cu113)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (0.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->torch-optimizer) (4.1.1)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
            self.num_graphs = 768
        elif split == 'val':
            self.path = self.processed_paths[1]
            self.num_graphs = 96
        elif split == 'test':
            self.path = self.processed_paths[2]
            self.num_graphs = 96

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GINConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_input_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU())))
          else:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU()))) 

        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                add_xr_at = n
            if n == add_xr_at:
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/C2_6k_botnet'
data_name = 'c2' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=True, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 2
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# !rm -rf /content/saved_models

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.0
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}_{result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    # class_weight = torch.Tensor([0.53, 12])
    # class_weight = class_weight.cuda(device=0)
    # criterion = torch.nn.CrossEntropyLoss(weight=class_weight)
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    # print(class_weight)
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-289d6260-8875-4907-be81-9114613cb420.json
# ------------------------------
# ------------------------------
# Tue Oct 25 16:16:31 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GINConv(nn=Sequential(
#       (0): Linear(in_features=1, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (1): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (2): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (3): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (4): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (5): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (6): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (7): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (8): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (9): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (10): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (11): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 2
# epoch: 1, passed number of graphs: 96, train running loss: 0.10999 (passed time: 5s)
#           acc: 0.95994, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 192, train running loss: 0.09088 (passed time: 10s)
#           acc: 0.95379, fpr: 0.00035, fnr: 0.93446, rec: 0.06554, prc: 0.90659, f1: 0.12224, f1_macro: 0.54926
# epoch: 1, passed number of graphs: 288, train running loss: 0.07120 (passed time: 15s)
#           acc: 0.99598, fpr: 0.00021, fnr: 0.09755, rec: 0.90245, prc: 0.99425, f1: 0.94613, f1_macro: 0.97202
# epoch: 1, passed number of graphs: 384, train running loss: 0.05469 (passed time: 20s)
#           acc: 0.99955, fpr: 0.00033, fnr: 0.00313, rec: 0.99687, prc: 0.99261, f1: 0.99473, f1_macro: 0.99725
# epoch: 1, passed number of graphs: 480, train running loss: 0.04455 (passed time: 26s)
#           acc: 0.99868, fpr: 0.00003, fnr: 0.02758, rec: 0.97242, prc: 0.99938, f1: 0.98572, f1_macro: 0.99251
# epoch: 1, passed number of graphs: 576, train running loss: 0.03787 (passed time: 31s)
#           acc: 0.99420, fpr: 0.00398, fnr: 0.04685, rec: 0.95315, prc: 0.91417, f1: 0.93325, f1_macro: 0.96511
# epoch: 1, passed number of graphs: 672, train running loss: 0.03461 (passed time: 36s)
#           acc: 0.98299, fpr: 0.00005, fnr: 0.33401, rec: 0.66599, prc: 0.99867, f1: 0.79908, f1_macro: 0.89510
# epoch: 1, passed number of graphs: 768, train running loss: 0.03135 (passed time: 42s)
#           acc: 0.99850, fpr: 0.00041, fnr: 0.02642, rec: 0.97358, prc: 0.99042, f1: 0.98193, f1_macro: 0.99057
# Validation --- epoch: 1, loss: 0.04634
#           f1_macro: 0.92499, fnr: 0.01658, prc: 0.78989, f1: 0.85515, fpr: 0.00985, acc: 0.99006, rec: 0.98342
# Better model saved at ./saved_models/GIN_0_0.8551473715225834.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.00216 (passed time: 1m 3s)
#           acc: 0.99946, fpr: 0.00026, fnr: 0.00743, rec: 0.99257, prc: 0.99386, f1: 0.99322, f1_macro: 0.99647
# epoch: 2, passed number of graphs: 192, train running loss: 0.03644 (passed time: 1m 8s)
#           acc: 0.95090, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 288, train running loss: 0.05337 (passed time: 1m 14s)
#           acc: 0.96084, fpr: 0.00007, fnr: 0.99841, rec: 0.00159, prc: 0.47368, f1: 0.00317, f1_macro: 0.49160
# epoch: 2, passed number of graphs: 384, train running loss: 0.05327 (passed time: 1m 19s)
#           acc: 0.96573, fpr: 0.00079, fnr: 0.77918, rec: 0.22082, prc: 0.92598, f1: 0.35660, f1_macro: 0.66950
# epoch: 2, passed number of graphs: 480, train running loss: 0.05434 (passed time: 1m 24s)
#           acc: 0.95341, fpr: 0.00005, fnr: 0.99254, rec: 0.00746, prc: 0.88393, f1: 0.01479, f1_macro: 0.49547
# epoch: 2, passed number of graphs: 576, train running loss: 0.05264 (passed time: 1m 29s)
#           acc: 0.97201, fpr: 0.00108, fnr: 0.63313, rec: 0.36687, prc: 0.93773, f1: 0.52740, f1_macro: 0.75649
# epoch: 2, passed number of graphs: 672, train running loss: 0.04675 (passed time: 1m 35s)
#           acc: 0.99947, fpr: 0.00023, fnr: 0.00613, rec: 0.99387, prc: 0.99577, f1: 0.99482, f1_macro: 0.99727
# epoch: 2, passed number of graphs: 768, train running loss: 0.04212 (passed time: 1m 40s)
#           acc: 0.99489, fpr: 0.00262, fnr: 0.06176, rec: 0.93824, prc: 0.94002, f1: 0.93913, f1_macro: 0.96823
# Validation --- epoch: 2, loss: 0.26287
#           f1_macro: 0.65453, fnr: 0.01863, prc: 0.22302, f1: 0.35587, fpr: 0.08866, acc: 0.91295, rec: 0.98137
# epoch: 3, passed number of graphs: 96, train running loss: 0.01272 (passed time: 2m 1s)
#           acc: 0.99700, fpr: 0.00251, fnr: 0.01477, rec: 0.98523, prc: 0.94257, f1: 0.96343, f1_macro: 0.98093
# epoch: 3, passed number of graphs: 192, train running loss: 0.00879 (passed time: 2m 7s)
#           acc: 0.99964, fpr: 0.00012, fnr: 0.00498, rec: 0.99502, prc: 0.99772, f1: 0.99637, f1_macro: 0.99809
# epoch: 3, passed number of graphs: 288, train running loss: 0.00705 (passed time: 2m 12s)
#           acc: 0.99524, fpr: 0.00030, fnr: 0.11435, rec: 0.88565, prc: 0.99188, f1: 0.93576, f1_macro: 0.96664
# epoch: 3, passed number of graphs: 384, train running loss: 0.00582 (passed time: 2m 17s)
#           acc: 0.99967, fpr: 0.00016, fnr: 0.00412, rec: 0.99588, prc: 0.99637, f1: 0.99612, f1_macro: 0.99797
# epoch: 3, passed number of graphs: 480, train running loss: 0.00551 (passed time: 2m 23s)
#           acc: 0.99865, fpr: 0.00019, fnr: 0.02494, rec: 0.97506, prc: 0.99607, f1: 0.98545, f1_macro: 0.99237
# epoch: 3, passed number of graphs: 576, train running loss: 0.00512 (passed time: 2m 28s)
#           acc: 0.99961, fpr: 0.00019, fnr: 0.00495, rec: 0.99505, prc: 0.99577, f1: 0.99541, f1_macro: 0.99760
# epoch: 3, passed number of graphs: 672, train running loss: 0.00467 (passed time: 2m 33s)
#           acc: 0.99974, fpr: 0.00006, fnr: 0.00388, rec: 0.99612, prc: 0.99884, f1: 0.99748, f1_macro: 0.99867
# epoch: 3, passed number of graphs: 768, train running loss: 0.00446 (passed time: 2m 38s)
#           acc: 0.99845, fpr: 0.00018, fnr: 0.03278, rec: 0.96722, prc: 0.99567, f1: 0.98124, f1_macro: 0.99021
# Validation --- epoch: 3, loss: 0.00365
#           f1_macro: 0.99104, fnr: 0.03234, prc: 0.99880, f1: 0.98244, fpr: 0.00003, acc: 0.99931, rec: 0.96766
# Better model saved at ./saved_models/GIN_2_0.9824360420059933.pt.
# epoch: 4, passed number of graphs: 96, train running loss: 0.00252 (passed time: 3m 0s)
#           acc: 0.99718, fpr: 0.00240, fnr: 0.01270, rec: 0.98730, prc: 0.94487, f1: 0.96562, f1_macro: 0.98208
# epoch: 4, passed number of graphs: 192, train running loss: 0.00244 (passed time: 3m 5s)
#           acc: 0.99972, fpr: 0.00009, fnr: 0.00398, rec: 0.99602, prc: 0.99829, f1: 0.99715, f1_macro: 0.99850
# epoch: 4, passed number of graphs: 288, train running loss: 0.00222 (passed time: 3m 10s)
#           acc: 0.99795, fpr: 0.00008, fnr: 0.05032, rec: 0.94968, prc: 0.99796, f1: 0.97322, f1_macro: 0.98608
# epoch: 4, passed number of graphs: 384, train running loss: 0.00221 (passed time: 3m 16s)
#           acc: 0.99952, fpr: 0.00026, fnr: 0.00553, rec: 0.99447, prc: 0.99431, f1: 0.99439, f1_macro: 0.99707
# epoch: 4, passed number of graphs: 480, train running loss: 0.00232 (passed time: 3m 21s)
#           acc: 0.99867, fpr: 0.00004, fnr: 0.02750, rec: 0.97250, prc: 0.99923, f1: 0.98568, f1_macro: 0.99249
# epoch: 4, passed number of graphs: 576, train running loss: 0.00834 (passed time: 3m 26s)
#           acc: 0.96563, fpr: 0.00023, fnr: 0.80219, rec: 0.19781, prc: 0.97401, f1: 0.32883, f1_macro: 0.65560
# epoch: 4, passed number of graphs: 672, train running loss: 0.01035 (passed time: 3m 31s)
#           acc: 0.99690, fpr: 0.00234, fnr: 0.01737, rec: 0.98263, prc: 0.95739, f1: 0.96984, f1_macro: 0.98410
# epoch: 4, passed number of graphs: 768, train running loss: 0.01117 (passed time: 3m 37s)
#           acc: 0.99389, fpr: 0.00415, fnr: 0.05078, rec: 0.94922, prc: 0.90921, f1: 0.92878, f1_macro: 0.96280
# Validation --- epoch: 4, loss: 0.03759
#           f1_macro: 0.89550, fnr: 0.04063, prc: 0.70225, f1: 0.79733, fpr: 0.01163, acc: 0.98775, rec: 0.95937
# epoch: 5, passed number of graphs: 96, train running loss: 0.00866 (passed time: 3m 58s)
#           acc: 0.99383, fpr: 0.00162, fnr: 0.11513, rec: 0.88487, prc: 0.95792, f1: 0.91995, f1_macro: 0.95837
# epoch: 5, passed number of graphs: 192, train running loss: 0.00788 (passed time: 4m 4s)
#           acc: 0.99866, fpr: 0.00012, fnr: 0.02488, rec: 0.97512, prc: 0.99760, f1: 0.98623, f1_macro: 0.99277
# epoch: 5, passed number of graphs: 288, train running loss: 0.00717 (passed time: 4m 9s)
#           acc: 0.99632, fpr: 0.00022, fnr: 0.08862, rec: 0.91138, prc: 0.99402, f1: 0.95091, f1_macro: 0.97450
# epoch: 5, passed number of graphs: 384, train running loss: 0.01295 (passed time: 4m 14s)
#           acc: 0.97589, fpr: 0.00033, fnr: 0.55325, rec: 0.44675, prc: 0.98383, f1: 0.61448, f1_macro: 0.80102
# epoch: 5, passed number of graphs: 480, train running loss: 0.01284 (passed time: 4m 19s)
#           acc: 0.99674, fpr: 0.00174, fnr: 0.03413, rec: 0.96587, prc: 0.96470, f1: 0.96528, f1_macro: 0.98179
# epoch: 5, passed number of graphs: 576, train running loss: 0.01146 (passed time: 4m 25s)
#           acc: 0.99798, fpr: 0.00075, fnr: 0.03053, rec: 0.96947, prc: 0.98288, f1: 0.97613, f1_macro: 0.98754
# epoch: 5, passed number of graphs: 672, train running loss: 0.01029 (passed time: 4m 30s)
#           acc: 0.99951, fpr: 0.00011, fnr: 0.00756, rec: 0.99244, prc: 0.99794, f1: 0.99518, f1_macro: 0.99746
# epoch: 5, passed number of graphs: 768, train running loss: 0.00966 (passed time: 4m 35s)
#           acc: 0.99747, fpr: 0.00232, fnr: 0.00743, rec: 0.99257, prc: 0.94938, f1: 0.97049, f1_macro: 0.98458
# Validation --- epoch: 5, loss: 0.00442
#           f1_macro: 0.99006, fnr: 0.03197, prc: 0.99578, f1: 0.98050, fpr: 0.00010, acc: 0.99925, rec: 0.96803
# epoch: 6, passed number of graphs: 96, train running loss: 0.00276 (passed time: 4m 57s)
#           acc: 0.99728, fpr: 0.00237, fnr: 0.01114, rec: 0.98886, prc: 0.94565, f1: 0.96677, f1_macro: 0.98268
# epoch: 6, passed number of graphs: 192, train running loss: 0.00262 (passed time: 5m 2s)
#           acc: 0.99959, fpr: 0.00010, fnr: 0.00633, rec: 0.99367, prc: 0.99800, f1: 0.99583, f1_macro: 0.99781
# epoch: 6, passed number of graphs: 288, train running loss: 0.00271 (passed time: 5m 7s)
#           acc: 0.99650, fpr: 0.00009, fnr: 0.08720, rec: 0.91280, prc: 0.99749, f1: 0.95326, f1_macro: 0.97572
# epoch: 6, passed number of graphs: 384, train running loss: 0.00258 (passed time: 5m 12s)
#           acc: 0.99964, fpr: 0.00009, fnr: 0.00652, rec: 0.99348, prc: 0.99809, f1: 0.99578, f1_macro: 0.99780
# epoch: 6, passed number of graphs: 480, train running loss: 0.00259 (passed time: 5m 18s)
#           acc: 0.99867, fpr: 0.00009, fnr: 0.02652, rec: 0.97348, prc: 0.99815, f1: 0.98566, f1_macro: 0.99248
# epoch: 6, passed number of graphs: 576, train running loss: 0.00260 (passed time: 5m 23s)
#           acc: 0.99967, fpr: 0.00008, fnr: 0.00585, rec: 0.99415, prc: 0.99812, f1: 0.99614, f1_macro: 0.99798
# epoch: 6, passed number of graphs: 672, train running loss: 0.00256 (passed time: 5m 28s)
#           acc: 0.99965, fpr: 0.00006, fnr: 0.00572, rec: 0.99428, prc: 0.99884, f1: 0.99655, f1_macro: 0.99818
# epoch: 6, passed number of graphs: 768, train running loss: 0.00262 (passed time: 5m 34s)
#           acc: 0.99963, fpr: 0.00016, fnr: 0.00512, rec: 0.99488, prc: 0.99636, f1: 0.99562, f1_macro: 0.99771
# Validation --- epoch: 6, loss: 0.00282
#           f1_macro: 0.99391, fnr: 0.01797, prc: 0.99481, f1: 0.98808, fpr: 0.00013, acc: 0.99950, rec: 0.98203
# Better model saved at ./saved_models/GIN_5_0.9880787226319954.pt.
# epoch: 7, passed number of graphs: 96, train running loss: 0.00226 (passed time: 5m 55s)
#           acc: 0.99742, fpr: 0.00233, fnr: 0.00872, rec: 0.99128, prc: 0.94679, f1: 0.96852, f1_macro: 0.98359
# epoch: 7, passed number of graphs: 192, train running loss: 0.00221 (passed time: 6m 0s)
#           acc: 0.99968, fpr: 0.00009, fnr: 0.00476, rec: 0.99524, prc: 0.99822, f1: 0.99673, f1_macro: 0.99828
# epoch: 7, passed number of graphs: 288, train running loss: 0.00230 (passed time: 6m 6s)
#           acc: 0.99658, fpr: 0.00011, fnr: 0.08464, rec: 0.91536, prc: 0.99701, f1: 0.95444, f1_macro: 0.97633
# epoch: 7, passed number of graphs: 384, train running loss: 0.00216 (passed time: 6m 11s)
#           acc: 0.99970, fpr: 0.00014, fnr: 0.00388, rec: 0.99612, prc: 0.99686, f1: 0.99649, f1_macro: 0.99817
# epoch: 7, passed number of graphs: 480, train running loss: 0.00222 (passed time: 6m 16s)
#           acc: 0.99878, fpr: 0.00012, fnr: 0.02343, rec: 0.97657, prc: 0.99746, f1: 0.98690, f1_macro: 0.99313
# epoch: 7, passed number of graphs: 576, train running loss: 0.00228 (passed time: 6m 22s)
#           acc: 0.99976, fpr: 0.00011, fnr: 0.00309, rec: 0.99691, prc: 0.99756, f1: 0.99724, f1_macro: 0.99856
# epoch: 7, passed number of graphs: 672, train running loss: 0.00224 (passed time: 6m 27s)
#           acc: 0.99976, fpr: 0.00006, fnr: 0.00361, rec: 0.99639, prc: 0.99884, f1: 0.99761, f1_macro: 0.99874
# epoch: 7, passed number of graphs: 768, train running loss: 0.00230 (passed time: 6m 32s)
#           acc: 0.99978, fpr: 0.00007, fnr: 0.00355, rec: 0.99645, prc: 0.99835, f1: 0.99740, f1_macro: 0.99864
# Validation --- epoch: 7, loss: 0.00264
#           f1_macro: 0.99359, fnr: 0.02068, prc: 0.99717, f1: 0.98743, fpr: 0.00007, acc: 0.99951, rec: 0.97932
# epoch: 8, passed number of graphs: 96, train running loss: 0.00212 (passed time: 6m 53s)
#           acc: 0.99743, fpr: 0.00233, fnr: 0.00821, rec: 0.99179, prc: 0.94666, f1: 0.96870, f1_macro: 0.98368
# epoch: 8, passed number of graphs: 192, train running loss: 0.00204 (passed time: 6m 59s)
#           acc: 0.99975, fpr: 0.00013, fnr: 0.00256, rec: 0.99744, prc: 0.99751, f1: 0.99748, f1_macro: 0.99867
# epoch: 8, passed number of graphs: 288, train running loss: 0.00216 (passed time: 7m 4s)
#           acc: 0.99661, fpr: 0.00005, fnr: 0.08552, rec: 0.91448, prc: 0.99874, f1: 0.95476, f1_macro: 0.97650
# epoch: 8, passed number of graphs: 384, train running loss: 0.00201 (passed time: 7m 9s)
#           acc: 0.99972, fpr: 0.00013, fnr: 0.00379, rec: 0.99621, prc: 0.99719, f1: 0.99670, f1_macro: 0.99828
# epoch: 8, passed number of graphs: 480, train running loss: 0.00207 (passed time: 7m 14s)
#           acc: 0.99879, fpr: 0.00004, fnr: 0.02487, rec: 0.97513, prc: 0.99907, f1: 0.98696, f1_macro: 0.99316
# epoch: 8, passed number of graphs: 576, train running loss: 0.00214 (passed time: 7m 20s)
#           acc: 0.99973, fpr: 0.00008, fnr: 0.00471, rec: 0.99529, prc: 0.99829, f1: 0.99679, f1_macro: 0.99832
# epoch: 8, passed number of graphs: 672, train running loss: 0.00211 (passed time: 7m 25s)
#           acc: 0.99973, fpr: 0.00005, fnr: 0.00429, rec: 0.99571, prc: 0.99904, f1: 0.99737, f1_macro: 0.99862
# epoch: 8, passed number of graphs: 768, train running loss: 0.00216 (passed time: 7m 30s)
#           acc: 0.99973, fpr: 0.00021, fnr: 0.00165, rec: 0.99835, prc: 0.99523, f1: 0.99678, f1_macro: 0.99832
# Validation --- epoch: 8, loss: 0.00251
#           f1_macro: 0.99401, fnr: 0.01941, prc: 0.99747, f1: 0.98825, fpr: 0.00006, acc: 0.99955, rec: 0.98059
# Better model saved at ./saved_models/GIN_7_0.9882519596783794.pt.
# epoch: 9, passed number of graphs: 96, train running loss: 0.00213 (passed time: 7m 52s)
#           acc: 0.99728, fpr: 0.00252, fnr: 0.00743, rec: 0.99257, prc: 0.94259, f1: 0.96693, f1_macro: 0.98276
# epoch: 9, passed number of graphs: 192, train running loss: 0.00198 (passed time: 7m 57s)
#           acc: 0.99977, fpr: 0.00016, fnr: 0.00156, rec: 0.99844, prc: 0.99695, f1: 0.99769, f1_macro: 0.99879
# epoch: 9, passed number of graphs: 288, train running loss: 0.00206 (passed time: 8m 2s)
#           acc: 0.99816, fpr: 0.00008, fnr: 0.04502, rec: 0.95498, prc: 0.99806, f1: 0.97605, f1_macro: 0.98755
# epoch: 9, passed number of graphs: 384, train running loss: 0.00189 (passed time: 8m 8s)
#           acc: 0.99972, fpr: 0.00019, fnr: 0.00239, rec: 0.99761, prc: 0.99588, f1: 0.99674, f1_macro: 0.99830
# epoch: 9, passed number of graphs: 480, train running loss: 0.00196 (passed time: 8m 13s)
#           acc: 0.99881, fpr: 0.00004, fnr: 0.02449, rec: 0.97551, prc: 0.99907, f1: 0.98715, f1_macro: 0.99326
# epoch: 9, passed number of graphs: 576, train running loss: 0.00209 (passed time: 8m 18s)
#           acc: 0.99972, fpr: 0.00008, fnr: 0.00479, rec: 0.99521, prc: 0.99829, f1: 0.99675, f1_macro: 0.99830
# epoch: 9, passed number of graphs: 672, train running loss: 0.00209 (passed time: 8m 23s)
#           acc: 0.99973, fpr: 0.00006, fnr: 0.00429, rec: 0.99571, prc: 0.99891, f1: 0.99730, f1_macro: 0.99858
# epoch: 9, passed number of graphs: 768, train running loss: 0.00215 (passed time: 8m 29s)
#           acc: 0.99977, fpr: 0.00007, fnr: 0.00396, rec: 0.99604, prc: 0.99843, f1: 0.99723, f1_macro: 0.99855
# Validation --- epoch: 9, loss: 0.00249
#           f1_macro: 0.99547, fnr: 0.01488, prc: 0.99772, f1: 0.99112, fpr: 0.00005, acc: 0.99964, rec: 0.98512
# Better model saved at ./saved_models/GIN_8_0.9911201659292012.pt.
# epoch: 10, passed number of graphs: 96, train running loss: 0.00194 (passed time: 8m 51s)
#           acc: 0.99751, fpr: 0.00228, fnr: 0.00751, rec: 0.99249, prc: 0.94787, f1: 0.96966, f1_macro: 0.98418
# epoch: 10, passed number of graphs: 192, train running loss: 0.00195 (passed time: 8m 56s)
#           acc: 0.99972, fpr: 0.00010, fnr: 0.00377, rec: 0.99623, prc: 0.99801, f1: 0.99712, f1_macro: 0.99848
# epoch: 10, passed number of graphs: 288, train running loss: 0.00203 (passed time: 9m 1s)
#           acc: 0.99670, fpr: 0.00005, fnr: 0.08313, rec: 0.91687, prc: 0.99865, f1: 0.95601, f1_macro: 0.97715
# epoch: 10, passed number of graphs: 384, train running loss: 0.00187 (passed time: 9m 6s)
#           acc: 0.99970, fpr: 0.00013, fnr: 0.00412, rec: 0.99588, prc: 0.99719, f1: 0.99653, f1_macro: 0.99819
# epoch: 10, passed number of graphs: 480, train running loss: 0.00190 (passed time: 9m 12s)
#           acc: 0.99883, fpr: 0.00005, fnr: 0.02381, rec: 0.97619, prc: 0.99892, f1: 0.98742, f1_macro: 0.99341
# epoch: 10, passed number of graphs: 576, train running loss: 0.00194 (passed time: 9m 17s)
#           acc: 0.99975, fpr: 0.00010, fnr: 0.00365, rec: 0.99635, prc: 0.99780, f1: 0.99707, f1_macro: 0.99847
# epoch: 10, passed number of graphs: 672, train running loss: 0.00191 (passed time: 9m 22s)
#           acc: 0.99977, fpr: 0.00006, fnr: 0.00334, rec: 0.99666, prc: 0.99884, f1: 0.99775, f1_macro: 0.99881
# epoch: 10, passed number of graphs: 768, train running loss: 0.00198 (passed time: 9m 27s)
#           acc: 0.99976, fpr: 0.00010, fnr: 0.00347, rec: 0.99653, prc: 0.99777, f1: 0.99715, f1_macro: 0.99851
# Validation --- epoch: 10, loss: 0.01745
#           f1_macro: 0.93568, fnr: 0.01006, prc: 0.78395, f1: 0.87460, fpr: 0.00624, acc: 0.99370, rec: 0.98994
# epoch: 11, passed number of graphs: 96, train running loss: 0.00183 (passed time: 9m 49s)
#           acc: 0.99739, fpr: 0.00241, fnr: 0.00743, rec: 0.99257, prc: 0.94507, f1: 0.96824, f1_macro: 0.98344
# epoch: 11, passed number of graphs: 192, train running loss: 0.00164 (passed time: 9m 54s)
#           acc: 0.99975, fpr: 0.00011, fnr: 0.00313, rec: 0.99687, prc: 0.99794, f1: 0.99740, f1_macro: 0.99864
# epoch: 11, passed number of graphs: 288, train running loss: 0.00175 (passed time: 10m 0s)
#           acc: 0.99814, fpr: 0.00008, fnr: 0.04546, rec: 0.95454, prc: 0.99787, f1: 0.97573, f1_macro: 0.98738
# epoch: 11, passed number of graphs: 384, train running loss: 0.00159 (passed time: 10m 5s)
#           acc: 0.99970, fpr: 0.00014, fnr: 0.00396, rec: 0.99604, prc: 0.99695, f1: 0.99649, f1_macro: 0.99817
# epoch: 11, passed number of graphs: 480, train running loss: 0.00161 (passed time: 10m 10s)
#           acc: 0.99889, fpr: 0.00004, fnr: 0.02283, rec: 0.97717, prc: 0.99923, f1: 0.98808, f1_macro: 0.99375
# epoch: 11, passed number of graphs: 576, train running loss: 0.00166 (passed time: 10m 15s)
#           acc: 0.99979, fpr: 0.00009, fnr: 0.00276, rec: 0.99724, prc: 0.99789, f1: 0.99756, f1_macro: 0.99873
# epoch: 11, passed number of graphs: 672, train running loss: 0.00202 (passed time: 10m 21s)
#           acc: 0.99780, fpr: 0.00003, fnr: 0.04271, rec: 0.95729, prc: 0.99943, f1: 0.97790, f1_macro: 0.98837
# epoch: 11, passed number of graphs: 768, train running loss: 0.00311 (passed time: 10m 26s)
#           acc: 0.99677, fpr: 0.00262, fnr: 0.01701, rec: 0.98299, prc: 0.94260, f1: 0.96237, f1_macro: 0.98034
# Validation --- epoch: 11, loss: 0.00782
#           f1_macro: 0.97819, fnr: 0.03193, prc: 0.94952, f1: 0.95736, fpr: 0.00126, acc: 0.99809, rec: 0.96807
# epoch: 12, passed number of graphs: 96, train running loss: 0.00391 (passed time: 10m 47s)
#           acc: 0.99738, fpr: 0.00230, fnr: 0.01036, rec: 0.98964, prc: 0.94733, f1: 0.96802, f1_macro: 0.98333
# epoch: 12, passed number of graphs: 192, train running loss: 0.00331 (passed time: 10m 52s)
#           acc: 0.99962, fpr: 0.00008, fnr: 0.00618, rec: 0.99382, prc: 0.99836, f1: 0.99608, f1_macro: 0.99794
# epoch: 12, passed number of graphs: 288, train running loss: 0.00322 (passed time: 10m 58s)
#           acc: 0.99805, fpr: 0.00010, fnr: 0.04732, rec: 0.95268, prc: 0.99732, f1: 0.97449, f1_macro: 0.98674
# epoch: 12, passed number of graphs: 384, train running loss: 0.00290 (passed time: 11m 3s)
#           acc: 0.99968, fpr: 0.00010, fnr: 0.00528, rec: 0.99472, prc: 0.99777, f1: 0.99624, f1_macro: 0.99804
# epoch: 12, passed number of graphs: 480, train running loss: 0.00282 (passed time: 11m 8s)
#           acc: 0.99879, fpr: 0.00004, fnr: 0.02494, rec: 0.97506, prc: 0.99907, f1: 0.98692, f1_macro: 0.99314
# epoch: 12, passed number of graphs: 576, train running loss: 0.00277 (passed time: 11m 14s)
#           acc: 0.99971, fpr: 0.00010, fnr: 0.00463, rec: 0.99537, prc: 0.99772, f1: 0.99654, f1_macro: 0.99820
# epoch: 12, passed number of graphs: 672, train running loss: 0.00268 (passed time: 11m 19s)
#           acc: 0.99974, fpr: 0.00005, fnr: 0.00402, rec: 0.99598, prc: 0.99898, f1: 0.99748, f1_macro: 0.99867
# epoch: 12, passed number of graphs: 768, train running loss: 0.00265 (passed time: 11m 24s)
#           acc: 0.99918, fpr: 0.00006, fnr: 0.01808, rec: 0.98192, prc: 0.99857, f1: 0.99017, f1_macro: 0.99487
# Validation --- epoch: 12, loss: 0.00265
#           f1_macro: 0.99368, fnr: 0.02076, prc: 0.99761, f1: 0.98759, fpr: 0.00006, acc: 0.99953, rec: 0.97924
# epoch: 13, passed number of graphs: 96, train running loss: 0.00201 (passed time: 11m 46s)
#           acc: 0.99737, fpr: 0.00239, fnr: 0.00829, rec: 0.99171, prc: 0.94541, f1: 0.96801, f1_macro: 0.98332
# epoch: 13, passed number of graphs: 192, train running loss: 0.00183 (passed time: 11m 51s)
#           acc: 0.99971, fpr: 0.00010, fnr: 0.00391, rec: 0.99609, prc: 0.99801, f1: 0.99705, f1_macro: 0.99845
# epoch: 13, passed number of graphs: 288, train running loss: 0.00192 (passed time: 11m 56s)
#           acc: 0.99813, fpr: 0.00011, fnr: 0.04493, rec: 0.95507, prc: 0.99714, f1: 0.97565, f1_macro: 0.98734
# epoch: 13, passed number of graphs: 384, train running loss: 0.00177 (passed time: 12m 1s)
#           acc: 0.99971, fpr: 0.00013, fnr: 0.00396, rec: 0.99604, prc: 0.99719, f1: 0.99662, f1_macro: 0.99823
# epoch: 13, passed number of graphs: 480, train running loss: 0.00181 (passed time: 12m 7s)
#           acc: 0.99886, fpr: 0.00006, fnr: 0.02306, rec: 0.97694, prc: 0.99877, f1: 0.98773, f1_macro: 0.99357
# epoch: 13, passed number of graphs: 576, train running loss: 0.00186 (passed time: 12m 12s)
#           acc: 0.99974, fpr: 0.00012, fnr: 0.00341, rec: 0.99659, prc: 0.99724, f1: 0.99691, f1_macro: 0.99839
# epoch: 13, passed number of graphs: 672, train running loss: 0.00184 (passed time: 12m 17s)
#           acc: 0.99978, fpr: 0.00006, fnr: 0.00320, rec: 0.99680, prc: 0.99891, f1: 0.99785, f1_macro: 0.99887
# epoch: 13, passed number of graphs: 768, train running loss: 0.00188 (passed time: 12m 22s)
#           acc: 0.99916, fpr: 0.00010, fnr: 0.01784, rec: 0.98216, prc: 0.99774, f1: 0.98989, f1_macro: 0.99472
# Validation --- epoch: 13, loss: 0.00243
#           f1_macro: 0.99394, fnr: 0.01910, prc: 0.99683, f1: 0.98810, fpr: 0.00007, acc: 0.99955, rec: 0.98090
# epoch: 14, passed number of graphs: 96, train running loss: 0.00181 (passed time: 12m 44s)
#           acc: 0.99953, fpr: 0.00018, fnr: 0.00760, rec: 0.99240, prc: 0.99575, f1: 0.99407, f1_macro: 0.99691
# epoch: 14, passed number of graphs: 192, train running loss: 0.00165 (passed time: 12m 49s)
#           acc: 0.99974, fpr: 0.00010, fnr: 0.00327, rec: 0.99673, prc: 0.99801, f1: 0.99737, f1_macro: 0.99862
# epoch: 14, passed number of graphs: 288, train running loss: 0.00172 (passed time: 12m 54s)
#           acc: 0.99813, fpr: 0.00011, fnr: 0.04493, rec: 0.95507, prc: 0.99714, f1: 0.97565, f1_macro: 0.98734
# epoch: 14, passed number of graphs: 384, train running loss: 0.00158 (passed time: 13m 0s)
#           acc: 0.99971, fpr: 0.00020, fnr: 0.00223, rec: 0.99777, prc: 0.99556, f1: 0.99666, f1_macro: 0.99826
# epoch: 14, passed number of graphs: 480, train running loss: 0.00161 (passed time: 13m 5s)
#           acc: 0.99889, fpr: 0.00006, fnr: 0.02253, rec: 0.97747, prc: 0.99877, f1: 0.98800, f1_macro: 0.99371
# epoch: 14, passed number of graphs: 576, train running loss: 0.00166 (passed time: 13m 10s)
#           acc: 0.99975, fpr: 0.00011, fnr: 0.00333, rec: 0.99667, prc: 0.99756, f1: 0.99712, f1_macro: 0.99849
# epoch: 14, passed number of graphs: 672, train running loss: 0.00164 (passed time: 13m 15s)
#           acc: 0.99981, fpr: 0.00006, fnr: 0.00259, rec: 0.99741, prc: 0.99891, f1: 0.99816, f1_macro: 0.99903
# epoch: 14, passed number of graphs: 768, train running loss: 0.00168 (passed time: 13m 21s)
#           acc: 0.99914, fpr: 0.00007, fnr: 0.01899, rec: 0.98101, prc: 0.99840, f1: 0.98963, f1_macro: 0.99459
# Validation --- epoch: 14, loss: 0.00225
#           f1_macro: 0.99403, fnr: 0.01971, prc: 0.99783, f1: 0.98829, fpr: 0.00005, acc: 0.99956, rec: 0.98029
# epoch: 15, passed number of graphs: 96, train running loss: 0.00159 (passed time: 13m 42s)
#           acc: 0.99948, fpr: 0.00026, fnr: 0.00682, rec: 0.99318, prc: 0.99386, f1: 0.99352, f1_macro: 0.99662
# epoch: 15, passed number of graphs: 192, train running loss: 0.00143 (passed time: 13m 47s)
#           acc: 0.99978, fpr: 0.00011, fnr: 0.00249, rec: 0.99751, prc: 0.99794, f1: 0.99772, f1_macro: 0.99880
# epoch: 15, passed number of graphs: 288, train running loss: 0.00152 (passed time: 13m 52s)
#           acc: 0.99814, fpr: 0.00011, fnr: 0.04475, rec: 0.95525, prc: 0.99714, f1: 0.97574, f1_macro: 0.98739
# epoch: 15, passed number of graphs: 384, train running loss: 0.00141 (passed time: 13m 58s)
#           acc: 0.99974, fpr: 0.00010, fnr: 0.00371, rec: 0.99629, prc: 0.99777, f1: 0.99703, f1_macro: 0.99845
# epoch: 15, passed number of graphs: 480, train running loss: 0.00145 (passed time: 14m 3s)
#           acc: 0.99889, fpr: 0.00004, fnr: 0.02283, rec: 0.97717, prc: 0.99915, f1: 0.98804, f1_macro: 0.99373
# epoch: 15, passed number of graphs: 576, train running loss: 0.00150 (passed time: 14m 8s)
#           acc: 0.99979, fpr: 0.00009, fnr: 0.00309, rec: 0.99691, prc: 0.99805, f1: 0.99748, f1_macro: 0.99868
# epoch: 15, passed number of graphs: 672, train running loss: 0.00149 (passed time: 14m 13s)
#           acc: 0.99980, fpr: 0.00005, fnr: 0.00293, rec: 0.99707, prc: 0.99898, f1: 0.99802, f1_macro: 0.99896
# epoch: 15, passed number of graphs: 768, train running loss: 0.00154 (passed time: 14m 19s)
#           acc: 0.99941, fpr: 0.00009, fnr: 0.01189, rec: 0.98811, prc: 0.99792, f1: 0.99299, f1_macro: 0.99634
# Validation --- epoch: 15, loss: 0.00215
#           f1_macro: 0.99405, fnr: 0.01957, prc: 0.99777, f1: 0.98832, fpr: 0.00005, acc: 0.99956, rec: 0.98043
# epoch: 16, passed number of graphs: 96, train running loss: 0.00146 (passed time: 14m 40s)
#           acc: 0.99954, fpr: 0.00021, fnr: 0.00665, rec: 0.99335, prc: 0.99507, f1: 0.99421, f1_macro: 0.99698
# epoch: 16, passed number of graphs: 192, train running loss: 0.00134 (passed time: 14m 45s)
#           acc: 0.99978, fpr: 0.00010, fnr: 0.00256, rec: 0.99744, prc: 0.99801, f1: 0.99772, f1_macro: 0.99880
# epoch: 16, passed number of graphs: 288, train running loss: 0.00144 (passed time: 14m 51s)
#           acc: 0.99815, fpr: 0.00009, fnr: 0.04484, rec: 0.95516, prc: 0.99760, f1: 0.97592, f1_macro: 0.98748
# epoch: 16, passed number of graphs: 384, train running loss: 0.00134 (passed time: 14m 56s)
#           acc: 0.99973, fpr: 0.00017, fnr: 0.00256, rec: 0.99744, prc: 0.99629, f1: 0.99687, f1_macro: 0.99836
# epoch: 16, passed number of graphs: 480, train running loss: 0.00138 (passed time: 15m 1s)
#           acc: 0.99888, fpr: 0.00004, fnr: 0.02306, rec: 0.97694, prc: 0.99923, f1: 0.98796, f1_macro: 0.99369
# epoch: 16, passed number of graphs: 576, train running loss: 0.00143 (passed time: 15m 6s)
#           acc: 0.99977, fpr: 0.00008, fnr: 0.00365, rec: 0.99635, prc: 0.99821, f1: 0.99728, f1_macro: 0.99858
# epoch: 16, passed number of graphs: 672, train running loss: 0.00143 (passed time: 15m 11s)
#           acc: 0.99982, fpr: 0.00006, fnr: 0.00252, rec: 0.99748, prc: 0.99891, f1: 0.99819, f1_macro: 0.99905
# epoch: 16, passed number of graphs: 768, train running loss: 0.00147 (passed time: 15m 17s)
#           acc: 0.99941, fpr: 0.00009, fnr: 0.01189, rec: 0.98811, prc: 0.99783, f1: 0.99295, f1_macro: 0.99632
# Validation --- epoch: 16, loss: 0.00199
#           f1_macro: 0.99427, fnr: 0.01885, prc: 0.99787, f1: 0.98875, fpr: 0.00005, acc: 0.99958, rec: 0.98115
# epoch: 17, passed number of graphs: 96, train running loss: 0.00142 (passed time: 15m 38s)
#           acc: 0.99956, fpr: 0.00017, fnr: 0.00691, rec: 0.99309, prc: 0.99584, f1: 0.99446, f1_macro: 0.99712
# epoch: 17, passed number of graphs: 192, train running loss: 0.00131 (passed time: 15m 43s)
#           acc: 0.99976, fpr: 0.00009, fnr: 0.00320, rec: 0.99680, prc: 0.99822, f1: 0.99751, f1_macro: 0.99869
# epoch: 17, passed number of graphs: 288, train running loss: 0.00141 (passed time: 15m 49s)
#           acc: 0.99815, fpr: 0.00010, fnr: 0.04493, rec: 0.95507, prc: 0.99751, f1: 0.97583, f1_macro: 0.98743
# epoch: 17, passed number of graphs: 384, train running loss: 0.00132 (passed time: 15m 54s)
#           acc: 0.99976, fpr: 0.00008, fnr: 0.00388, rec: 0.99612, prc: 0.99818, f1: 0.99715, f1_macro: 0.99851
# epoch: 17, passed number of graphs: 480, train running loss: 0.00135 (passed time: 15m 59s)
#           acc: 0.99889, fpr: 0.00004, fnr: 0.02283, rec: 0.97717, prc: 0.99915, f1: 0.98804, f1_macro: 0.99373
# epoch: 17, passed number of graphs: 576, train running loss: 0.00139 (passed time: 16m 4s)
#           acc: 0.99978, fpr: 0.00008, fnr: 0.00333, rec: 0.99667, prc: 0.99821, f1: 0.99744, f1_macro: 0.99866
# epoch: 17, passed number of graphs: 672, train running loss: 0.00139 (passed time: 16m 10s)
#           acc: 0.99981, fpr: 0.00006, fnr: 0.00259, rec: 0.99741, prc: 0.99891, f1: 0.99816, f1_macro: 0.99903
# epoch: 17, passed number of graphs: 768, train running loss: 0.00144 (passed time: 16m 15s)
#           acc: 0.99941, fpr: 0.00007, fnr: 0.01247, rec: 0.98753, prc: 0.99850, f1: 0.99298, f1_macro: 0.99634
# Validation --- epoch: 17, loss: 0.00196
#           f1_macro: 0.99499, fnr: 0.01666, prc: 0.99799, f1: 0.99017, fpr: 0.00005, acc: 0.99962, rec: 0.98334
# epoch: 18, passed number of graphs: 96, train running loss: 0.00146 (passed time: 16m 36s)
#           acc: 0.99951, fpr: 0.00019, fnr: 0.00777, rec: 0.99223, prc: 0.99541, f1: 0.99381, f1_macro: 0.99678
# epoch: 18, passed number of graphs: 192, train running loss: 0.00132 (passed time: 16m 41s)
#           acc: 0.99975, fpr: 0.00010, fnr: 0.00320, rec: 0.99680, prc: 0.99815, f1: 0.99747, f1_macro: 0.99867
# epoch: 18, passed number of graphs: 288, train running loss: 0.00140 (passed time: 16m 47s)
#           acc: 0.99816, fpr: 0.00009, fnr: 0.04475, rec: 0.95525, prc: 0.99769, f1: 0.97601, f1_macro: 0.98753
# epoch: 18, passed number of graphs: 384, train running loss: 0.00131 (passed time: 16m 52s)
#           acc: 0.99972, fpr: 0.00019, fnr: 0.00231, rec: 0.99769, prc: 0.99572, f1: 0.99670, f1_macro: 0.99828
# epoch: 18, passed number of graphs: 480, train running loss: 0.00133 (passed time: 16m 58s)
#           acc: 0.99887, fpr: 0.00004, fnr: 0.02343, rec: 0.97657, prc: 0.99923, f1: 0.98777, f1_macro: 0.99359
# epoch: 18, passed number of graphs: 576, train running loss: 0.00143 (passed time: 17m 3s)
#           acc: 0.99978, fpr: 0.00007, fnr: 0.00374, rec: 0.99626, prc: 0.99845, f1: 0.99736, f1_macro: 0.99862
# epoch: 18, passed number of graphs: 672, train running loss: 0.00145 (passed time: 17m 8s)
#           acc: 0.99982, fpr: 0.00005, fnr: 0.00252, rec: 0.99748, prc: 0.99898, f1: 0.99823, f1_macro: 0.99907
# epoch: 18, passed number of graphs: 768, train running loss: 0.00149 (passed time: 17m 14s)
#           acc: 0.99941, fpr: 0.00008, fnr: 0.01239, rec: 0.98761, prc: 0.99825, f1: 0.99290, f1_macro: 0.99630
# Validation --- epoch: 18, loss: 0.00187
#           f1_macro: 0.99585, fnr: 0.01347, prc: 0.99779, f1: 0.99186, fpr: 0.00005, acc: 0.99968, rec: 0.98653
# Better model saved at ./saved_models/GIN_17_0.9918580050458514.pt.
# epoch: 19, passed number of graphs: 96, train running loss: 0.00148 (passed time: 17m 35s)
#           acc: 0.99948, fpr: 0.00018, fnr: 0.00855, rec: 0.99145, prc: 0.99566, f1: 0.99355, f1_macro: 0.99664
# epoch: 19, passed number of graphs: 192, train running loss: 0.00133 (passed time: 17m 40s)
#           acc: 0.99976, fpr: 0.00010, fnr: 0.00291, rec: 0.99709, prc: 0.99808, f1: 0.99758, f1_macro: 0.99873
# epoch: 19, passed number of graphs: 288, train running loss: 0.00139 (passed time: 17m 46s)
#           acc: 0.99814, fpr: 0.00011, fnr: 0.04475, rec: 0.95525, prc: 0.99714, f1: 0.97574, f1_macro: 0.98739
# epoch: 19, passed number of graphs: 384, train running loss: 0.00130 (passed time: 17m 51s)
#           acc: 0.99977, fpr: 0.00007, fnr: 0.00396, rec: 0.99604, prc: 0.99851, f1: 0.99727, f1_macro: 0.99858
# epoch: 19, passed number of graphs: 480, train running loss: 0.00132 (passed time: 17m 56s)
#           acc: 0.99886, fpr: 0.00005, fnr: 0.02336, rec: 0.97664, prc: 0.99900, f1: 0.98769, f1_macro: 0.99355
# epoch: 19, passed number of graphs: 576, train running loss: 0.00134 (passed time: 18m 1s)
#           acc: 0.99978, fpr: 0.00005, fnr: 0.00406, rec: 0.99594, prc: 0.99886, f1: 0.99740, f1_macro: 0.99864
# epoch: 19, passed number of graphs: 672, train running loss: 0.00135 (passed time: 18m 7s)
#           acc: 0.99976, fpr: 0.00005, fnr: 0.00381, rec: 0.99619, prc: 0.99904, f1: 0.99761, f1_macro: 0.99874
# epoch: 19, passed number of graphs: 768, train running loss: 0.00139 (passed time: 18m 12s)
#           acc: 0.99941, fpr: 0.00008, fnr: 0.01239, rec: 0.98761, prc: 0.99825, f1: 0.99290, f1_macro: 0.99630
# Validation --- epoch: 19, loss: 0.00167
#           f1_macro: 0.99601, fnr: 0.01261, prc: 0.99754, f1: 0.99217, fpr: 0.00006, acc: 0.99969, rec: 0.98739
# Better model saved at ./saved_models/GIN_18_0.992167883230834.pt.
# epoch: 20, passed number of graphs: 96, train running loss: 0.00141 (passed time: 18m 34s)
#           acc: 0.99937, fpr: 0.00032, fnr: 0.00803, rec: 0.99197, prc: 0.99222, f1: 0.99210, f1_macro: 0.99588
# epoch: 20, passed number of graphs: 192, train running loss: 0.00129 (passed time: 18m 39s)
#           acc: 0.99973, fpr: 0.00010, fnr: 0.00355, rec: 0.99645, prc: 0.99815, f1: 0.99730, f1_macro: 0.99858
# epoch: 20, passed number of graphs: 288, train running loss: 0.00134 (passed time: 18m 44s)
#           acc: 0.99812, fpr: 0.00013, fnr: 0.04493, rec: 0.95507, prc: 0.99668, f1: 0.97543, f1_macro: 0.98723
# epoch: 20, passed number of graphs: 384, train running loss: 0.00127 (passed time: 18m 50s)
#           acc: 0.99973, fpr: 0.00020, fnr: 0.00190, rec: 0.99810, prc: 0.99556, f1: 0.99683, f1_macro: 0.99834
# epoch: 20, passed number of graphs: 480, train running loss: 0.00128 (passed time: 18m 55s)
#           acc: 0.99886, fpr: 0.00003, fnr: 0.02359, rec: 0.97641, prc: 0.99931, f1: 0.98773, f1_macro: 0.99357
# epoch: 20, passed number of graphs: 576, train running loss: 0.00130 (passed time: 19m 0s)
#           acc: 0.99972, fpr: 0.00009, fnr: 0.00447, rec: 0.99553, prc: 0.99796, f1: 0.99675, f1_macro: 0.99830
# epoch: 20, passed number of graphs: 672, train running loss: 0.00132 (passed time: 19m 5s)
#           acc: 0.99974, fpr: 0.00004, fnr: 0.00422, rec: 0.99578, prc: 0.99918, f1: 0.99748, f1_macro: 0.99867
# epoch: 20, passed number of graphs: 768, train running loss: 0.00135 (passed time: 19m 11s)
#           acc: 0.99939, fpr: 0.00012, fnr: 0.01172, rec: 0.98828, prc: 0.99717, f1: 0.99270, f1_macro: 0.99619
# Validation --- epoch: 20, loss: 0.00153
#           f1_macro: 0.99615, fnr: 0.01150, prc: 0.99690, f1: 0.99244, fpr: 0.00007, acc: 0.99970, rec: 0.98850
# Better model saved at ./saved_models/GIN_19_0.9924423875013572.pt.
# epoch: 21, passed number of graphs: 96, train running loss: 0.00138 (passed time: 19m 32s)
#           acc: 0.99966, fpr: 0.00005, fnr: 0.00734, rec: 0.99266, prc: 0.99878, f1: 0.99571, f1_macro: 0.99777
# epoch: 21, passed number of graphs: 192, train running loss: 0.00134 (passed time: 19m 37s)
#           acc: 0.99976, fpr: 0.00010, fnr: 0.00299, rec: 0.99701, prc: 0.99808, f1: 0.99755, f1_macro: 0.99871
# epoch: 21, passed number of graphs: 288, train running loss: 0.00138 (passed time: 19m 43s)
#           acc: 0.99813, fpr: 0.00013, fnr: 0.04457, rec: 0.95543, prc: 0.99659, f1: 0.97557, f1_macro: 0.98730
# epoch: 21, passed number of graphs: 384, train running loss: 0.00130 (passed time: 19m 48s)
#           acc: 0.99976, fpr: 0.00007, fnr: 0.00404, rec: 0.99596, prc: 0.99835, f1: 0.99715, f1_macro: 0.99851
# epoch: 21, passed number of graphs: 480, train running loss: 0.00130 (passed time: 19m 53s)
#           acc: 0.99886, fpr: 0.00004, fnr: 0.02351, rec: 0.97649, prc: 0.99923, f1: 0.98773, f1_macro: 0.99357
# epoch: 21, passed number of graphs: 576, train running loss: 0.00132 (passed time: 19m 58s)
#           acc: 0.99973, fpr: 0.00004, fnr: 0.00544, rec: 0.99456, prc: 0.99910, f1: 0.99683, f1_macro: 0.99834
# epoch: 21, passed number of graphs: 672, train running loss: 0.00133 (passed time: 20m 4s)
#           acc: 0.99975, fpr: 0.00004, fnr: 0.00422, rec: 0.99578, prc: 0.99932, f1: 0.99754, f1_macro: 0.99871
# epoch: 21, passed number of graphs: 768, train running loss: 0.00137 (passed time: 20m 9s)
#           acc: 0.99940, fpr: 0.00012, fnr: 0.01156, rec: 0.98844, prc: 0.99717, f1: 0.99278, f1_macro: 0.99624
# Validation --- epoch: 21, loss: 0.00154
#           f1_macro: 0.99608, fnr: 0.01128, prc: 0.99642, f1: 0.99231, fpr: 0.00008, acc: 0.99970, rec: 0.98872
# epoch: 22, passed number of graphs: 96, train running loss: 0.00135 (passed time: 20m 30s)
#           acc: 0.99965, fpr: 0.00005, fnr: 0.00751, rec: 0.99249, prc: 0.99870, f1: 0.99558, f1_macro: 0.99770
# epoch: 22, passed number of graphs: 192, train running loss: 0.00129 (passed time: 20m 36s)
#           acc: 0.99973, fpr: 0.00008, fnr: 0.00377, rec: 0.99623, prc: 0.99836, f1: 0.99730, f1_macro: 0.99858
# epoch: 22, passed number of graphs: 288, train running loss: 0.00135 (passed time: 20m 41s)
#           acc: 0.99812, fpr: 0.00013, fnr: 0.04502, rec: 0.95498, prc: 0.99677, f1: 0.97543, f1_macro: 0.98722
# epoch: 22, passed number of graphs: 384, train running loss: 0.00127 (passed time: 20m 46s)
#           acc: 0.99969, fpr: 0.00024, fnr: 0.00198, rec: 0.99802, prc: 0.99474, f1: 0.99638, f1_macro: 0.99811
# epoch: 22, passed number of graphs: 480, train running loss: 0.00128 (passed time: 20m 51s)
#           acc: 0.99884, fpr: 0.00003, fnr: 0.02426, rec: 0.97574, prc: 0.99946, f1: 0.98746, f1_macro: 0.99342
# epoch: 22, passed number of graphs: 576, train running loss: 0.00132 (passed time: 20m 57s)
#           acc: 0.99971, fpr: 0.00012, fnr: 0.00414, rec: 0.99586, prc: 0.99740, f1: 0.99663, f1_macro: 0.99824
# epoch: 22, passed number of graphs: 672, train running loss: 0.00133 (passed time: 21m 2s)
#           acc: 0.99977, fpr: 0.00004, fnr: 0.00388, rec: 0.99612, prc: 0.99932, f1: 0.99771, f1_macro: 0.99880
# epoch: 22, passed number of graphs: 768, train running loss: 0.00137 (passed time: 21m 7s)
#           acc: 0.99935, fpr: 0.00004, fnr: 0.01470, rec: 0.98530, prc: 0.99916, f1: 0.99218, f1_macro: 0.99592
# Validation --- epoch: 22, loss: 0.00166
#           f1_macro: 0.99538, fnr: 0.01548, prc: 0.99801, f1: 0.99095, fpr: 0.00005, acc: 0.99964, rec: 0.98452
# epoch: 23, passed number of graphs: 96, train running loss: 0.00132 (passed time: 21m 29s)
#           acc: 0.99965, fpr: 0.00005, fnr: 0.00751, rec: 0.99249, prc: 0.99878, f1: 0.99562, f1_macro: 0.99772
# epoch: 23, passed number of graphs: 192, train running loss: 0.00122 (passed time: 21m 34s)
#           acc: 0.99975, fpr: 0.00009, fnr: 0.00334, rec: 0.99666, prc: 0.99822, f1: 0.99744, f1_macro: 0.99865
# epoch: 23, passed number of graphs: 288, train running loss: 0.00125 (passed time: 21m 39s)
#           acc: 0.99818, fpr: 0.00006, fnr: 0.04502, rec: 0.95498, prc: 0.99834, f1: 0.97618, f1_macro: 0.98761
# epoch: 23, passed number of graphs: 384, train running loss: 0.00118 (passed time: 21m 45s)
#           acc: 0.99977, fpr: 0.00011, fnr: 0.00305, rec: 0.99695, prc: 0.99761, f1: 0.99728, f1_macro: 0.99858
# epoch: 23, passed number of graphs: 480, train running loss: 0.00119 (passed time: 21m 50s)
#           acc: 0.99886, fpr: 0.00004, fnr: 0.02351, rec: 0.97649, prc: 0.99915, f1: 0.98769, f1_macro: 0.99355
# epoch: 23, passed number of graphs: 576, train running loss: 0.00121 (passed time: 21m 55s)
#           acc: 0.99976, fpr: 0.00005, fnr: 0.00438, rec: 0.99562, prc: 0.99886, f1: 0.99723, f1_macro: 0.99856
# epoch: 23, passed number of graphs: 672, train running loss: 0.00123 (passed time: 22m 0s)
#           acc: 0.99977, fpr: 0.00005, fnr: 0.00354, rec: 0.99646, prc: 0.99904, f1: 0.99775, f1_macro: 0.99881
# epoch: 23, passed number of graphs: 768, train running loss: 0.00127 (passed time: 22m 6s)
#           acc: 0.99941, fpr: 0.00006, fnr: 0.01280, rec: 0.98720, prc: 0.99866, f1: 0.99290, f1_macro: 0.99630
# Validation --- epoch: 23, loss: 0.00157
#           f1_macro: 0.99578, fnr: 0.01370, prc: 0.99777, f1: 0.99174, fpr: 0.00005, acc: 0.99967, rec: 0.98630
# epoch: 24, passed number of graphs: 96, train running loss: 0.00127 (passed time: 22m 27s)
#           acc: 0.99958, fpr: 0.00006, fnr: 0.00890, rec: 0.99110, prc: 0.99852, f1: 0.99480, f1_macro: 0.99729
# epoch: 24, passed number of graphs: 192, train running loss: 0.00118 (passed time: 22m 33s)
#           acc: 0.99973, fpr: 0.00009, fnr: 0.00370, rec: 0.99630, prc: 0.99822, f1: 0.99726, f1_macro: 0.99856
# epoch: 24, passed number of graphs: 288, train running loss: 0.00122 (passed time: 22m 38s)
#           acc: 0.99818, fpr: 0.00007, fnr: 0.04493, rec: 0.95507, prc: 0.99824, f1: 0.97618, f1_macro: 0.98762
# epoch: 24, passed number of graphs: 384, train running loss: 0.00115 (passed time: 22m 43s)
#           acc: 0.99977, fpr: 0.00010, fnr: 0.00313, rec: 0.99687, prc: 0.99785, f1: 0.99736, f1_macro: 0.99862
# epoch: 24, passed number of graphs: 480, train running loss: 0.00116 (passed time: 22m 49s)
#           acc: 0.99887, fpr: 0.00004, fnr: 0.02328, rec: 0.97672, prc: 0.99915, f1: 0.98781, f1_macro: 0.99361
# epoch: 24, passed number of graphs: 576, train running loss: 0.00119 (passed time: 22m 54s)
#           acc: 0.99976, fpr: 0.00005, fnr: 0.00463, rec: 0.99537, prc: 0.99894, f1: 0.99715, f1_macro: 0.99851
# epoch: 24, passed number of graphs: 672, train running loss: 0.00121 (passed time: 22m 59s)
#           acc: 0.99976, fpr: 0.00005, fnr: 0.00388, rec: 0.99612, prc: 0.99911, f1: 0.99761, f1_macro: 0.99874
# epoch: 24, passed number of graphs: 768, train running loss: 0.00125 (passed time: 23m 4s)
#           acc: 0.99940, fpr: 0.00005, fnr: 0.01296, rec: 0.98704, prc: 0.99875, f1: 0.99286, f1_macro: 0.99627
# Validation --- epoch: 24, loss: 0.00159
#           f1_macro: 0.99517, fnr: 0.01589, prc: 0.99782, f1: 0.99054, fpr: 0.00005, acc: 0.99963, rec: 0.98411
# epoch: 25, passed number of graphs: 96, train running loss: 0.00126 (passed time: 23m 26s)
#           acc: 0.99956, fpr: 0.00009, fnr: 0.00881, rec: 0.99119, prc: 0.99774, f1: 0.99445, f1_macro: 0.99711
# epoch: 25, passed number of graphs: 192, train running loss: 0.00116 (passed time: 23m 31s)
#           acc: 0.99975, fpr: 0.00010, fnr: 0.00334, rec: 0.99666, prc: 0.99815, f1: 0.99740, f1_macro: 0.99863
# epoch: 25, passed number of graphs: 288, train running loss: 0.00120 (passed time: 23m 37s)
#           acc: 0.99819, fpr: 0.00005, fnr: 0.04484, rec: 0.95516, prc: 0.99861, f1: 0.97640, f1_macro: 0.98773
# epoch: 25, passed number of graphs: 384, train running loss: 0.00114 (passed time: 23m 42s)
#           acc: 0.99977, fpr: 0.00010, fnr: 0.00313, rec: 0.99687, prc: 0.99777, f1: 0.99732, f1_macro: 0.99860
# ...
# epoch: 42, passed number of graphs: 288, train running loss: 0.00114 (passed time: 40m 9s)
#           acc: 0.99818, fpr: 0.00005, fnr: 0.04519, rec: 0.95481, prc: 0.99870, f1: 0.97626, f1_macro: 0.98766
# epoch: 42, passed number of graphs: 384, train running loss: 0.00109 (passed time: 40m 15s)
#           acc: 0.99978, fpr: 0.00010, fnr: 0.00297, rec: 0.99703, prc: 0.99777, f1: 0.99740, f1_macro: 0.99864
# epoch: 42, passed number of graphs: 480, train running loss: 0.00109 (passed time: 40m 20s)
#           acc: 0.99885, fpr: 0.00003, fnr: 0.02389, rec: 0.97611, prc: 0.99938, f1: 0.98761, f1_macro: 0.99350
# epoch: 42, passed number of graphs: 576, train running loss: 0.00111 (passed time: 40m 25s)
#           acc: 0.99977, fpr: 0.00007, fnr: 0.00374, rec: 0.99626, prc: 0.99837, f1: 0.99732, f1_macro: 0.99860
# epoch: 42, passed number of graphs: 672, train running loss: 0.00113 (passed time: 40m 31s)
#           acc: 0.99979, fpr: 0.00004, fnr: 0.00341, rec: 0.99659, prc: 0.99918, f1: 0.99789, f1_macro: 0.99889
# epoch: 42, passed number of graphs: 768, train running loss: 0.00117 (passed time: 40m 36s)
#           acc: 0.99941, fpr: 0.00009, fnr: 0.01206, rec: 0.98794, prc: 0.99800, f1: 0.99295, f1_macro: 0.99632
# Validation --- epoch: 42, loss: 0.00136
#           f1_macro: 0.99589, fnr: 0.01278, prc: 0.99725, f1: 0.99195, fpr: 0.00007, acc: 0.99968, rec: 0.98722
# epoch: 43, passed number of graphs: 96, train running loss: 0.00121 (passed time: 40m 57s)
#           acc: 0.99951, fpr: 0.00015, fnr: 0.00864, rec: 0.99136, prc: 0.99635, f1: 0.99385, f1_macro: 0.99680
# epoch: 43, passed number of graphs: 192, train running loss: 0.00110 (passed time: 41m 3s)
#           acc: 0.99974, fpr: 0.00009, fnr: 0.00355, rec: 0.99645, prc: 0.99822, f1: 0.99733, f1_macro: 0.99860
# epoch: 43, passed number of graphs: 288, train running loss: 0.00114 (passed time: 41m 8s)
#           acc: 0.99819, fpr: 0.00006, fnr: 0.04484, rec: 0.95516, prc: 0.99852, f1: 0.97636, f1_macro: 0.98771
# epoch: 43, passed number of graphs: 384, train running loss: 0.00109 (passed time: 41m 13s)
#           acc: 0.99978, fpr: 0.00010, fnr: 0.00297, rec: 0.99703, prc: 0.99777, f1: 0.99740, f1_macro: 0.99864
# epoch: 43, passed number of graphs: 480, train running loss: 0.00108 (passed time: 41m 18s)
#           acc: 0.99885, fpr: 0.00003, fnr: 0.02389, rec: 0.97611, prc: 0.99938, f1: 0.98761, f1_macro: 0.99350
# epoch: 43, passed number of graphs: 576, train running loss: 0.00111 (passed time: 41m 24s)
#           acc: 0.99977, fpr: 0.00007, fnr: 0.00374, rec: 0.99626, prc: 0.99837, f1: 0.99732, f1_macro: 0.99860
# epoch: 43, passed number of graphs: 672, train running loss: 0.00113 (passed time: 41m 29s)
#           acc: 0.99979, fpr: 0.00004, fnr: 0.00341, rec: 0.99659, prc: 0.99918, f1: 0.99789, f1_macro: 0.99889
# epoch: 43, passed number of graphs: 768, train running loss: 0.00117 (passed time: 41m 34s)
#           acc: 0.99940, fpr: 0.00008, fnr: 0.01239, rec: 0.98761, prc: 0.99816, f1: 0.99286, f1_macro: 0.99628
# Validation --- epoch: 43, loss: 0.00134
#           f1_macro: 0.99591, fnr: 0.01274, prc: 0.99725, f1: 0.99197, fpr: 0.00007, acc: 0.99968, rec: 0.98726
# epoch: 44, passed number of graphs: 96, train running loss: 0.00120 (passed time: 41m 56s)
#           acc: 0.99957, fpr: 0.00008, fnr: 0.00864, rec: 0.99136, prc: 0.99800, f1: 0.99467, f1_macro: 0.99722
# epoch: 44, passed number of graphs: 192, train running loss: 0.00110 (passed time: 42m 1s)
#           acc: 0.99974, fpr: 0.00009, fnr: 0.00355, rec: 0.99645, prc: 0.99822, f1: 0.99733, f1_macro: 0.99860
# epoch: 44, passed number of graphs: 288, train running loss: 0.00114 (passed time: 42m 6s)
#           acc: 0.99818, fpr: 0.00005, fnr: 0.04519, rec: 0.95481, prc: 0.99870, f1: 0.97626, f1_macro: 0.98766
# epoch: 44, passed number of graphs: 384, train running loss: 0.00108 (passed time: 42m 12s)
#           acc: 0.99978, fpr: 0.00009, fnr: 0.00305, rec: 0.99695, prc: 0.99794, f1: 0.99744, f1_macro: 0.99866
# epoch: 44, passed number of graphs: 480, train running loss: 0.00108 (passed time: 42m 17s)
#           acc: 0.99885, fpr: 0.00003, fnr: 0.02389, rec: 0.97611, prc: 0.99938, f1: 0.98761, f1_macro: 0.99350
# epoch: 44, passed number of graphs: 576, train running loss: 0.00111 (passed time: 42m 22s)
#           acc: 0.99978, fpr: 0.00007, fnr: 0.00365, rec: 0.99635, prc: 0.99837, f1: 0.99736, f1_macro: 0.99862
# epoch: 44, passed number of graphs: 672, train running loss: 0.00112 (passed time: 42m 28s)
#           acc: 0.99979, fpr: 0.00004, fnr: 0.00341, rec: 0.99659, prc: 0.99925, f1: 0.99792, f1_macro: 0.99890
# epoch: 44, passed number of graphs: 768, train running loss: 0.00117 (passed time: 42m 33s)
#           acc: 0.99939, fpr: 0.00009, fnr: 0.01239, rec: 0.98761, prc: 0.99791, f1: 0.99274, f1_macro: 0.99621
# Validation --- epoch: 44, loss: 0.00133
#           f1_macro: 0.99611, fnr: 0.01183, prc: 0.99710, f1: 0.99238, fpr: 0.00007, acc: 0.99970, rec: 0.98817
# epoch: 45, passed number of graphs: 96, train running loss: 0.00120 (passed time: 42m 54s)
#           acc: 0.99958, fpr: 0.00008, fnr: 0.00864, rec: 0.99136, prc: 0.99809, f1: 0.99471, f1_macro: 0.99725
# epoch: 45, passed number of graphs: 192, train running loss: 0.00109 (passed time: 43m 0s)
#           acc: 0.99973, fpr: 0.00009, fnr: 0.00363, rec: 0.99637, prc: 0.99822, f1: 0.99730, f1_macro: 0.99858
# epoch: 45, passed number of graphs: 288, train running loss: 0.00114 (passed time: 43m 5s)
#           acc: 0.99818, fpr: 0.00005, fnr: 0.04519, rec: 0.95481, prc: 0.99870, f1: 0.97626, f1_macro: 0.98766
# epoch: 45, passed number of graphs: 384, train running loss: 0.00108 (passed time: 43m 10s)
#           acc: 0.99978, fpr: 0.00009, fnr: 0.00305, rec: 0.99695, prc: 0.99802, f1: 0.99748, f1_macro: 0.99868
# epoch: 45, passed number of graphs: 480, train running loss: 0.00108 (passed time: 43m 15s)
#           acc: 0.99886, fpr: 0.00003, fnr: 0.02381, rec: 0.97619, prc: 0.99938, f1: 0.98765, f1_macro: 0.99352
# epoch: 45, passed number of graphs: 576, train running loss: 0.00110 (passed time: 43m 21s)
#           acc: 0.99978, fpr: 0.00007, fnr: 0.00374, rec: 0.99626, prc: 0.99845, f1: 0.99736, f1_macro: 0.99862
# epoch: 45, passed number of graphs: 672, train running loss: 0.00112 (passed time: 43m 26s)
#           acc: 0.99979, fpr: 0.00004, fnr: 0.00341, rec: 0.99659, prc: 0.99925, f1: 0.99792, f1_macro: 0.99890
# epoch: 45, passed number of graphs: 768, train running loss: 0.00116 (passed time: 43m 31s)
#           acc: 0.99938, fpr: 0.00010, fnr: 0.01247, rec: 0.98753, prc: 0.99758, f1: 0.99253, f1_macro: 0.99610
# Validation --- epoch: 45, loss: 0.00131
#           f1_macro: 0.99617, fnr: 0.01143, prc: 0.99693, f1: 0.99250, fpr: 0.00007, acc: 0.99970, rec: 0.98857
# Better model saved at ./saved_models/GIN_44_0.9924993794593134.pt.
# epoch: 46, passed number of graphs: 96, train running loss: 0.00119 (passed time: 43m 53s)
#           acc: 0.99948, fpr: 0.00018, fnr: 0.00846, rec: 0.99154, prc: 0.99558, f1: 0.99355, f1_macro: 0.99664
# epoch: 46, passed number of graphs: 192, train running loss: 0.00108 (passed time: 43m 58s)
#           acc: 0.99974, fpr: 0.00009, fnr: 0.00355, rec: 0.99645, prc: 0.99822, f1: 0.99733, f1_macro: 0.99860
# epoch: 46, passed number of graphs: 288, train running loss: 0.00113 (passed time: 44m 4s)
#           acc: 0.99818, fpr: 0.00005, fnr: 0.04519, rec: 0.95481, prc: 0.99861, f1: 0.97622, f1_macro: 0.98764
# epoch: 46, passed number of graphs: 384, train running loss: 0.00108 (passed time: 44m 9s)
#           acc: 0.99979, fpr: 0.00009, fnr: 0.00297, rec: 0.99703, prc: 0.99802, f1: 0.99752, f1_macro: 0.99871
# epoch: 46, passed number of graphs: 480, train running loss: 0.00107 (passed time: 44m 14s)
#           acc: 0.99885, fpr: 0.00003, fnr: 0.02389, rec: 0.97611, prc: 0.99938, f1: 0.98761, f1_macro: 0.99350
# epoch: 46, passed number of graphs: 576, train running loss: 0.00110 (passed time: 44m 19s)
#           acc: 0.99978, fpr: 0.00007, fnr: 0.00374, rec: 0.99626, prc: 0.99845, f1: 0.99736, f1_macro: 0.99862
# epoch: 46, passed number of graphs: 672, train running loss: 0.00111 (passed time: 44m 25s)
#           acc: 0.99979, fpr: 0.00004, fnr: 0.00334, rec: 0.99666, prc: 0.99925, f1: 0.99795, f1_macro: 0.99892
# epoch: 46, passed number of graphs: 768, train running loss: 0.00116 (passed time: 44m 30s)
#           acc: 0.99939, fpr: 0.00010, fnr: 0.01222, rec: 0.98778, prc: 0.99758, f1: 0.99266, f1_macro: 0.99617
# Validation --- epoch: 46, loss: 0.00127
#           f1_macro: 0.99618, fnr: 0.01088, prc: 0.99637, f1: 0.99250, fpr: 0.00009, acc: 0.99970, rec: 0.98912
# Better model saved at ./saved_models/GIN_45_0.9925035737683877.pt.
# epoch: 47, passed number of graphs: 96, train running loss: 0.00118 (passed time: 44m 52s)
#           acc: 0.99958, fpr: 0.00008, fnr: 0.00864, rec: 0.99136, prc: 0.99809, f1: 0.99471, f1_macro: 0.99725
# epoch: 47, passed number of graphs: 192, train running loss: 0.00108 (passed time: 44m 57s)
#           acc: 0.99973, fpr: 0.00009, fnr: 0.00363, rec: 0.99637, prc: 0.99822, f1: 0.99730, f1_macro: 0.99858
# epoch: 47, passed number of graphs: 288, train running loss: 0.00113 (passed time: 45m 2s)
#           acc: 0.99818, fpr: 0.00005, fnr: 0.04537, rec: 0.95463, prc: 0.99870, f1: 0.97617, f1_macro: 0.98761
# epoch: 47, passed number of graphs: 384, train running loss: 0.00107 (passed time: 45m 7s)
#           acc: 0.99978, fpr: 0.00009, fnr: 0.00313, rec: 0.99687, prc: 0.99802, f1: 0.99744, f1_macro: 0.99866
# epoch: 47, passed number of graphs: 480, train running loss: 0.00107 (passed time: 45m 13s)
#           acc: 0.99886, fpr: 0.00003, fnr: 0.02381, rec: 0.97619, prc: 0.99938, f1: 0.98765, f1_macro: 0.99352
# epoch: 47, passed number of graphs: 576, train running loss: 0.00109 (passed time: 45m 18s)
#           acc: 0.99977, fpr: 0.00007, fnr: 0.00382, rec: 0.99618, prc: 0.99845, f1: 0.99732, f1_macro: 0.99860
# epoch: 47, passed number of graphs: 672, train running loss: 0.00111 (passed time: 45m 23s)
#           acc: 0.99979, fpr: 0.00004, fnr: 0.00334, rec: 0.99666, prc: 0.99925, f1: 0.99795, f1_macro: 0.99892
# epoch: 47, passed number of graphs: 768, train running loss: 0.00115 (passed time: 45m 29s)
#           acc: 0.99937, fpr: 0.00011, fnr: 0.01247, rec: 0.98753, prc: 0.99750, f1: 0.99249, f1_macro: 0.99608
# Validation --- epoch: 47, loss: 0.00149
#           f1_macro: 0.99500, fnr: 0.01055, prc: 0.99169, f1: 0.99020, fpr: 0.00020, acc: 0.99960, rec: 0.98945
# epoch: 48, passed number of graphs: 96, train running loss: 0.00118 (passed time: 45m 50s)
#           acc: 0.99952, fpr: 0.00014, fnr: 0.00846, rec: 0.99154, prc: 0.99653, f1: 0.99403, f1_macro: 0.99689
# epoch: 48, passed number of graphs: 192, train running loss: 0.00107 (passed time: 45m 56s)
#           acc: 0.99973, fpr: 0.00009, fnr: 0.00363, rec: 0.99637, prc: 0.99822, f1: 0.99730, f1_macro: 0.99858
# epoch: 48, passed number of graphs: 288, train running loss: 0.00112 (passed time: 46m 1s)
#           acc: 0.99817, fpr: 0.00005, fnr: 0.04546, rec: 0.95454, prc: 0.99870, f1: 0.97612, f1_macro: 0.98759
# epoch: 48, passed number of graphs: 384, train running loss: 0.00107 (passed time: 46m 6s)
#           acc: 0.99978, fpr: 0.00009, fnr: 0.00313, rec: 0.99687, prc: 0.99802, f1: 0.99744, f1_macro: 0.99866
# epoch: 48, passed number of graphs: 480, train running loss: 0.00106 (passed time: 46m 11s)
#           acc: 0.99886, fpr: 0.00003, fnr: 0.02381, rec: 0.97619, prc: 0.99938, f1: 0.98765, f1_macro: 0.99352
# epoch: 48, passed number of graphs: 576, train running loss: 0.00109 (passed time: 46m 17s)
#           acc: 0.99977, fpr: 0.00007, fnr: 0.00382, rec: 0.99618, prc: 0.99845, f1: 0.99732, f1_macro: 0.99860
# epoch: 48, passed number of graphs: 672, train running loss: 0.00111 (passed time: 46m 22s)
#           acc: 0.99979, fpr: 0.00004, fnr: 0.00341, rec: 0.99659, prc: 0.99925, f1: 0.99792, f1_macro: 0.99890
# epoch: 48, passed number of graphs: 768, train running loss: 0.00115 (passed time: 46m 27s)
#           acc: 0.99937, fpr: 0.00011, fnr: 0.01255, rec: 0.98745, prc: 0.99750, f1: 0.99245, f1_macro: 0.99606
# Validation --- epoch: 48, loss: 0.00161
#           f1_macro: 0.99427, fnr: 0.01027, prc: 0.98890, f1: 0.98879, fpr: 0.00027, acc: 0.99953, rec: 0.98973
# epoch: 49, passed number of graphs: 96, train running loss: 0.00118 (passed time: 46m 48s)
#           acc: 0.99960, fpr: 0.00006, fnr: 0.00872, rec: 0.99128, prc: 0.99861, f1: 0.99493, f1_macro: 0.99736
# epoch: 49, passed number of graphs: 192, train running loss: 0.00106 (passed time: 46m 54s)
#           acc: 0.99974, fpr: 0.00009, fnr: 0.00355, rec: 0.99645, prc: 0.99822, f1: 0.99733, f1_macro: 0.99860
# epoch: 49, passed number of graphs: 288, train running loss: 0.00111 (passed time: 46m 59s)
#           acc: 0.99818, fpr: 0.00006, fnr: 0.04502, rec: 0.95498, prc: 0.99852, f1: 0.97627, f1_macro: 0.98766
# epoch: 49, passed number of graphs: 384, train running loss: 0.00106 (passed time: 47m 4s)
#           acc: 0.99977, fpr: 0.00009, fnr: 0.00338, rec: 0.99662, prc: 0.99802, f1: 0.99732, f1_macro: 0.99860
# epoch: 49, passed number of graphs: 480, train running loss: 0.00106 (passed time: 47m 9s)
#           acc: 0.99886, fpr: 0.00003, fnr: 0.02381, rec: 0.97619, prc: 0.99938, f1: 0.98765, f1_macro: 0.99352
# epoch: 49, passed number of graphs: 576, train running loss: 0.00108 (passed time: 47m 15s)
#           acc: 0.99977, fpr: 0.00007, fnr: 0.00374, rec: 0.99626, prc: 0.99837, f1: 0.99732, f1_macro: 0.99860
# epoch: 49, passed number of graphs: 672, train running loss: 0.00110 (passed time: 47m 20s)
#           acc: 0.99980, fpr: 0.00004, fnr: 0.00334, rec: 0.99666, prc: 0.99932, f1: 0.99799, f1_macro: 0.99894
# epoch: 49, passed number of graphs: 768, train running loss: 0.00114 (passed time: 47m 25s)
#           acc: 0.99938, fpr: 0.00010, fnr: 0.01230, rec: 0.98770, prc: 0.99758, f1: 0.99261, f1_macro: 0.99615
# Validation --- epoch: 49, loss: 0.00125
#           f1_macro: 0.99594, fnr: 0.01226, prc: 0.99688, f1: 0.99203, fpr: 0.00007, acc: 0.99968, rec: 0.98774
# epoch: 50, passed number of graphs: 96, train running loss: 0.00116 (passed time: 47m 47s)
#           acc: 0.99960, fpr: 0.00006, fnr: 0.00846, rec: 0.99154, prc: 0.99852, f1: 0.99502, f1_macro: 0.99740
# epoch: 50, passed number of graphs: 192, train running loss: 0.00105 (passed time: 47m 52s)
#           acc: 0.99974, fpr: 0.00009, fnr: 0.00348, rec: 0.99652, prc: 0.99822, f1: 0.99737, f1_macro: 0.99862
# epoch: 50, passed number of graphs: 288, train running loss: 0.00111 (passed time: 47m 57s)
#           acc: 0.99818, fpr: 0.00006, fnr: 0.04502, rec: 0.95498, prc: 0.99852, f1: 0.97627, f1_macro: 0.98766
# epoch: 50, passed number of graphs: 384, train running loss: 0.00106 (passed time: 48m 3s)
#           acc: 0.99977, fpr: 0.00009, fnr: 0.00338, rec: 0.99662, prc: 0.99802, f1: 0.99732, f1_macro: 0.99860
# epoch: 50, passed number of graphs: 480, train running loss: 0.00105 (passed time: 48m 8s)
#           acc: 0.99886, fpr: 0.00003, fnr: 0.02381, rec: 0.97619, prc: 0.99938, f1: 0.98765, f1_macro: 0.99352
# epoch: 50, passed number of graphs: 576, train running loss: 0.00108 (passed time: 48m 13s)
#           acc: 0.99977, fpr: 0.00007, fnr: 0.00374, rec: 0.99626, prc: 0.99837, f1: 0.99732, f1_macro: 0.99860
# epoch: 50, passed number of graphs: 672, train running loss: 0.00109 (passed time: 48m 18s)
#           acc: 0.99980, fpr: 0.00004, fnr: 0.00334, rec: 0.99666, prc: 0.99932, f1: 0.99799, f1_macro: 0.99894
# epoch: 50, passed number of graphs: 768, train running loss: 0.00114 (passed time: 48m 24s)
#           acc: 0.99938, fpr: 0.00011, fnr: 0.01230, rec: 0.98770, prc: 0.99750, f1: 0.99257, f1_macro: 0.99612
# Validation --- epoch: 50, loss: 0.00125
#           f1_macro: 0.99594, fnr: 0.01223, prc: 0.99688, f1: 0.99205, fpr: 0.00007, acc: 0.99968, rec: 0.98777
# ************ best model obtained after epoch 46, saved at ./saved_models/GIN_45_0.9925035737683877.pt ************
# Testing --- loss: 0.00166
#           f1_macro: 0.99627, fnr: 0.01105, prc: 0.99672, f1: 0.99269, fpr: 0.00008, acc: 0.99970, rec: 0.98895

# %%
# !zip -r /content/GIN_053_12_Adam_C2_6k_botnode.zip /content/saved_models

# %%
from google.colab import files
files.download("/content/GIN_053_12_Adam_C2_6k_botnode.zip")
