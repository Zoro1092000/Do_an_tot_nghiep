# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/Do_an_tot_nghiep/blob/main/GNN_1000Layer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5
# !pip install torch-optimizer

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset
import torch_optimizer as optimization
from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout, LayerNorm
from torch_geometric.nn import GINConv, GroupAddRev, GATv2Conv
import torch.nn.functional as F

from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric in /usr/local/lib/python3.7/dist-packages (2.1.0.post1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.21.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (4.64.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.7.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (3.0.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.11.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch-geometric) (2.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2022.9.24)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-optimizer in /usr/local/lib/python3.7/dist-packages (0.3.0)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (0.1.1)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->torch-optimizer) (4.1.1)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
            self.num_graphs = 768
        elif split == 'val':
            self.path = self.processed_paths[1]
            self.num_graphs = 96
        elif split == 'test':
            self.path = self.processed_paths[2]
            self.num_graphs = 96

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %%
from torch_geometric.nn import GroupAddRev, SAGEConv

# %%
class GNNBlock(torch.nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.norm = LayerNorm(in_channels, elementwise_affine=True)
        self.conv = SAGEConv(in_channels, out_channels)

    def reset_parameters(self):
        self.norm.reset_parameters()
        self.conv.reset_parameters()

    def forward(self, x, edge_index, dropout_mask=None):
        x = self.norm(x).relu()
        if self.training and dropout_mask is not None:
            x = x * dropout_mask
        return self.conv(x, edge_index)

# %%
class RevGNN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_layers,
                 dropout, num_groups=2):
        super().__init__()

        self.dropout = dropout

        self.lin1 = Linear(in_channels, hidden_channels)
        self.lin2 = Linear(hidden_channels, out_channels)
        self.norm = LayerNorm(hidden_channels, elementwise_affine=True)

        assert hidden_channels % num_groups == 0
        self.convs = torch.nn.ModuleList()
        for _ in range(num_layers):
            conv = GNNBlock(
                hidden_channels // num_groups,
                hidden_channels // num_groups,
            )
            self.convs.append(GroupAddRev(conv, num_groups=num_groups))

    def reset_parameters(self):
        self.lin1.reset_parameters()
        self.lin2.reset_parameters()
        self.norm.reset_parameters()
        for conv in self.convs:
            conv.reset_parameters()

    def forward(self, x, edge_index):
        x = self.lin1(x)

        # Generate a dropout mask which will be shared across GNN blocks:
        mask = None
        if self.training and self.dropout > 0:
            mask = torch.zeros_like(x).bernoulli_(1 - self.dropout)
            mask = mask.requires_grad_(False)
            mask = mask / (1 - self.dropout)

        for conv in self.convs:
            x = conv(x, edge_index, mask)
        x = self.norm(x).relu()
        x = F.dropout(x, p=self.dropout, training=self.training)
        return self.lin2(x)

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/p2p_6k_feat_norm'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=False, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
torch.cuda.empty_cache()

# %%
batch_size = 2
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
dim_output_feature = 2
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 48
num_classes = 2 

dropout = 0.2
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = RevGNN(in_channels=dim_input_feature,
                   hidden_channels=32,
                   out_channels=num_classes,
                   num_layers=10,  # You can try 1000 layers for fun
                   dropout=0.5,
                   num_groups=2,
    ).to(device)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)
    
    class_weight = torch.Tensor([0.53, 12])
    class_weight = class_weight.cuda(device=0)
    criterion = torch.nn.CrossEntropyLoss(weight=class_weight)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-75e3929a-cddd-4f3c-b510-860d7e0ffcbc.json
# ------------------------------
# ------------------------------
# Sun Nov  6 02:37:47 2022
# ------------------------------
# model ----------
# RevGNN(
#   (lin1): Linear(in_features=1, out_features=32, bias=True)
#   (lin2): Linear(in_features=32, out_features=2, bias=True)
#   (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#   (convs): ModuleList(
#     (0): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (1): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (2): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (3): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (4): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (5): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (6): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (7): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (8): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (9): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (10): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (11): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (12): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (13): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (14): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (15): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (16): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (17): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (18): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (19): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (20): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (21): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (22): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (23): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (24): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (25): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (26): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (27): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (28): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (29): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (30): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (31): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (32): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (33): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (34): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (35): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (36): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (37): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (38): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (39): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (40): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (41): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (42): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (43): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (44): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (45): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (46): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (47): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (48): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (49): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (50): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (51): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (52): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (53): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (54): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (55): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (56): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (57): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (58): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (59): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (60): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (61): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (62): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (63): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (64): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (65): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (66): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (67): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (68): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (69): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (70): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (71): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (72): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (73): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (74): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (75): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (76): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (77): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (78): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (79): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (80): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (81): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (82): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (83): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (84): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (85): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (86): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (87): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (88): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (89): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (90): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (91): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (92): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (93): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (94): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (95): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (96): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (97): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (98): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (99): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (100): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (101): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (102): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (103): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (104): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (105): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (106): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (107): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (108): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (109): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (110): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (111): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (112): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (113): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (114): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (115): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (116): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (117): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (118): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (119): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (120): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (121): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (122): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (123): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (124): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (125): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (126): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (127): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (128): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (129): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (130): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (131): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (132): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (133): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (134): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (135): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (136): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (137): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (138): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (139): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (140): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (141): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (142): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (143): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (144): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (145): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (146): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (147): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (148): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (149): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (150): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (151): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (152): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (153): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (154): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (155): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (156): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (157): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (158): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (159): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (160): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (161): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (162): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (163): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (164): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (165): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (166): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (167): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (168): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (169): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (170): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (171): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (172): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (173): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (174): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (175): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (176): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (177): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (178): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (179): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (180): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (181): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (182): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (183): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (184): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (185): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (186): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (187): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (188): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (189): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (190): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (191): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (192): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (193): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (194): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (195): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (196): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (197): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (198): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (199): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (200): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (201): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (202): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (203): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (204): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (205): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (206): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (207): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (208): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (209): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (210): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (211): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (212): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (213): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (214): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (215): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (216): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (217): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (218): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (219): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (220): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (221): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (222): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (223): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (224): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (225): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (226): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (227): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (228): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (229): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (230): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (231): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (232): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (233): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (234): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (235): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (236): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (237): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (238): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (239): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (240): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (241): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (242): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (243): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (244): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (245): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (246): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (247): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (248): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (249): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (250): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (251): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (252): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (253): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (254): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (255): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (256): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (257): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (258): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (259): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (260): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (261): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (262): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (263): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (264): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (265): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (266): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (267): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (268): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (269): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (270): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (271): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (272): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (273): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (274): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (275): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (276): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (277): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (278): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (279): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (280): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (281): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (282): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (283): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (284): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (285): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (286): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (287): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (288): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (289): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (290): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (291): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
# ...
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (912): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (913): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (914): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (915): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (916): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (917): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (918): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (919): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (920): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (921): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (922): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (923): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (924): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (925): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (926): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (927): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (928): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (929): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (930): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (931): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (932): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (933): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (934): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (935): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (936): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (937): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (938): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (939): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (940): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (941): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (942): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (943): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (944): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (945): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (946): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (947): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (948): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (949): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (950): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (951): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (952): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (953): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (954): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (955): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (956): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (957): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (958): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (959): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (960): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (961): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (962): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (963): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (964): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (965): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (966): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (967): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (968): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (969): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (970): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (971): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (972): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (973): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (974): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (975): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (976): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (977): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (978): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (979): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (980): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (981): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (982): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (983): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (984): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (985): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (986): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (987): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (988): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (989): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (990): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (991): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (992): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (993): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (994): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (995): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (996): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (997): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (998): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#     (999): GroupAddRev(GNNBlock(
#       (norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#       (conv): SAGEConv(16, 16, aggr=mean)
#     ), num_groups=2)
#   )
# )
# Batch size: 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-b8e4c2af7448> in <module>
#     126     # ========== train the model
#     127     print(f"Batch size: {batch_size}")
# --> 128     train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
#
# <ipython-input-14-b8e4c2af7448> in train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler)
#      45             num_train_graph += batch.num_graphs
#      46
# ---> 47             loss.backward()
#      48             optimizer.step()
#      49
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     394                 create_graph=create_graph,
#     395                 inputs=inputs)
# --> 396         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     397
#     398     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     173     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 175         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#     176
#     177 def grad(
#
# KeyboardInterrupt:

# %%
# !zip -r /content/RevGIN_24Layer_64Chan_053_12.zip /content/saved_models

# %%
from google.colab import files
files.download("/content/RevGIN_24Layer_64Chan_053_12.zip")

# %%
# from google.colab import runtime
# runtime.unassign()
