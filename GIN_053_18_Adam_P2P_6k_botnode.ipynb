# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/Do_an_tot_nghiep/blob/main/GIN_053_18_Adam_P2P_6k_botnode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric==1.4.3
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5
# !pip install torch-optimizer

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter_
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset
import torch_optimizer as optimization


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric==1.4.3 in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.7.3)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (6.2.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.0.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.56.3)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.7.4)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.18.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.23.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.12.1+cu113)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->torch-geometric==1.4.3) (1.5.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (4.13.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (3.9.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.4.3) (1.15.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (0.6.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2022.9.24)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (3.2.2)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2021.11.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2.9.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (7.1.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (1.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (0.11.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-optimizer in /usr/local/lib/python3.7/dist-packages (0.3.0)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (0.1.1)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->torch-optimizer) (4.1.1)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
            self.num_graphs = 768
        elif split == 'val':
            self.path = self.processed_paths[1]
            self.num_graphs = 96
        elif split == 'test':
            self.path = self.processed_paths[2]
            self.num_graphs = 96

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GINConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_input_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU())))
          else:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU()))) 

        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                add_xr_at = n
            if n == add_xr_at:
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/p2p_6k_botnode'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=True, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 8
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.0
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    class_weight = torch.Tensor([0.53, 18])
    class_weight = class_weight.cuda(device=0)
    criterion = torch.nn.CrossEntropyLoss(weight=class_weight)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    print(class_weight)
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-c302d597-f28b-47b8-bd87-21e7c4edf261.json
# ------------------------------
# ------------------------------
# Wed Oct 26 11:31:33 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GINConv(nn=Sequential(
#       (0): Linear(in_features=1, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (1): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (2): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (3): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (4): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (5): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (6): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (7): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (8): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (9): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (10): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (11): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 8
# tensor([ 0.5300, 18.0000], device='cuda:0')
# epoch: 1, passed number of graphs: 96, train running loss: 0.08237 (passed time: 16s)
#           acc: 0.43566, fpr: 0.58913, fnr: 0.00659, rec: 0.99341, prc: 0.06971, f1: 0.13028, f1_macro: 0.35630
# epoch: 1, passed number of graphs: 192, train running loss: 0.07644 (passed time: 30s)
#           acc: 0.63929, fpr: 0.37472, fnr: 0.04268, rec: 0.95732, prc: 0.10117, f1: 0.18300, f1_macro: 0.47578
# epoch: 1, passed number of graphs: 288, train running loss: 0.06461 (passed time: 43s)
#           acc: 0.85158, fpr: 0.15488, fnr: 0.00104, rec: 0.99896, prc: 0.22033, f1: 0.36103, f1_macro: 0.63854
# epoch: 1, passed number of graphs: 384, train running loss: 0.05513 (passed time: 57s)
#           acc: 0.91836, fpr: 0.08446, fnr: 0.01786, rec: 0.98214, prc: 0.33964, f1: 0.50474, f1_macro: 0.73012
# epoch: 1, passed number of graphs: 480, train running loss: 0.04637 (passed time: 1m 11s)
#           acc: 0.94272, fpr: 0.05881, fnr: 0.02282, rec: 0.97718, prc: 0.42556, f1: 0.59291, f1_macro: 0.78105
# epoch: 1, passed number of graphs: 576, train running loss: 0.04127 (passed time: 1m 25s)
#           acc: 0.97109, fpr: 0.02919, fnr: 0.02250, rec: 0.97750, prc: 0.59696, f1: 0.74124, f1_macro: 0.86297
# epoch: 1, passed number of graphs: 672, train running loss: 0.03690 (passed time: 1m 39s)
#           acc: 0.98693, fpr: 0.01273, fnr: 0.02081, rec: 0.97919, prc: 0.77416, f1: 0.86469, f1_macro: 0.92891
# epoch: 1, passed number of graphs: 768, train running loss: 0.03307 (passed time: 1m 53s)
#           acc: 0.99117, fpr: 0.00919, fnr: 0.00055, rec: 0.99945, prc: 0.82620, f1: 0.90460, f1_macro: 0.94999
# Validation --- epoch: 1, loss: 0.04429
#           acc: 0.98270, fnr: 0.79751, rec: 0.20249, prc: 0.97634, f1_macro: 0.65853, f1: 0.32583, fpr: 0.00014
# Better model saved at ./saved_models/GIN_0: 0.32583044865002125.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.00385 (passed time: 2m 33s)
#           acc: 0.99657, fpr: 0.00357, fnr: 0.00014, rec: 0.99986, prc: 0.92554, f1: 0.96126, f1_macro: 0.97974
# epoch: 2, passed number of graphs: 192, train running loss: 0.00393 (passed time: 2m 48s)
#           acc: 0.99041, fpr: 0.00897, fnr: 0.02381, rec: 0.97619, prc: 0.82750, f1: 0.89571, f1_macro: 0.94534
# epoch: 2, passed number of graphs: 288, train running loss: 0.00404 (passed time: 3m 2s)
#           acc: 0.99596, fpr: 0.00420, fnr: 0.00046, rec: 0.99954, prc: 0.91248, f1: 0.95403, f1_macro: 0.97596
# epoch: 2, passed number of graphs: 384, train running loss: 0.00380 (passed time: 3m 16s)
#           acc: 0.99736, fpr: 0.00194, fnr: 0.01854, rec: 0.98146, prc: 0.95720, f1: 0.96918, f1_macro: 0.98390
# epoch: 2, passed number of graphs: 480, train running loss: 0.00448 (passed time: 3m 30s)
#           acc: 0.98999, fpr: 0.00932, fnr: 0.02555, rec: 0.97445, prc: 0.82336, f1: 0.89256, f1_macro: 0.94365
# epoch: 2, passed number of graphs: 576, train running loss: 0.00452 (passed time: 3m 44s)
#           acc: 0.99112, fpr: 0.00867, fnr: 0.01364, rec: 0.98636, prc: 0.83423, f1: 0.90394, f1_macro: 0.94964
# epoch: 2, passed number of graphs: 672, train running loss: 0.00468 (passed time: 3m 58s)
#           acc: 0.99469, fpr: 0.00445, fnr: 0.02473, rec: 0.97527, prc: 0.90715, f1: 0.93998, f1_macro: 0.96860
# epoch: 2, passed number of graphs: 768, train running loss: 0.00464 (passed time: 4m 13s)
#           acc: 0.99398, fpr: 0.00628, fnr: 0.00006, rec: 0.99994, prc: 0.87445, f1: 0.93299, f1_macro: 0.96492
# Validation --- epoch: 2, loss: 0.01920
#           acc: 0.99837, fnr: 0.04556, rec: 0.95444, prc: 0.97084, f1_macro: 0.98002, f1: 0.96087, fpr: 0.00066
# Better model saved at ./saved_models/GIN_1: 0.9608694808579251.pt.
# epoch: 3, passed number of graphs: 96, train running loss: 0.00292 (passed time: 4m 47s)
#           acc: 0.99794, fpr: 0.00212, fnr: 0.00059, rec: 0.99941, prc: 0.95444, f1: 0.97641, f1_macro: 0.98767
# epoch: 3, passed number of graphs: 192, train running loss: 0.00317 (passed time: 5m 1s)
#           acc: 0.99377, fpr: 0.00563, fnr: 0.01985, rec: 0.98015, prc: 0.88460, f1: 0.92993, f1_macro: 0.96333
# epoch: 3, passed number of graphs: 288, train running loss: 0.00364 (passed time: 5m 16s)
#           acc: 0.93026, fpr: 0.07257, fnr: 0.00529, rec: 0.99471, prc: 0.37522, f1: 0.54490, f1_macro: 0.75357
# epoch: 3, passed number of graphs: 384, train running loss: 0.00392 (passed time: 5m 30s)
#           acc: 0.99539, fpr: 0.00399, fnr: 0.01858, rec: 0.98142, prc: 0.91586, f1: 0.94750, f1_macro: 0.97255
# epoch: 3, passed number of graphs: 480, train running loss: 0.00434 (passed time: 5m 44s)
#           acc: 0.99675, fpr: 0.00214, fnr: 0.02825, rec: 0.97175, prc: 0.95299, f1: 0.96227, f1_macro: 0.98029
# epoch: 3, passed number of graphs: 576, train running loss: 0.00399 (passed time: 5m 58s)
#           acc: 0.99529, fpr: 0.00488, fnr: 0.00072, rec: 0.99928, prc: 0.90048, f1: 0.94731, f1_macro: 0.97242
# epoch: 3, passed number of graphs: 672, train running loss: 0.00384 (passed time: 6m 12s)
#           acc: 0.99743, fpr: 0.00246, fnr: 0.00506, rec: 0.99494, prc: 0.94751, f1: 0.97065, f1_macro: 0.98465
# epoch: 3, passed number of graphs: 768, train running loss: 0.00369 (passed time: 6m 26s)
#           acc: 0.99604, fpr: 0.00412, fnr: 0.00023, rec: 0.99977, prc: 0.91377, f1: 0.95484, f1_macro: 0.97638
# Validation --- epoch: 3, loss: 24.90317
#           acc: 0.20748, fnr: 0.00000, rec: 1.00000, prc: 0.02649, f1_macro: 0.18474, f1: 0.05160, fpr: 0.80995
# epoch: 4, passed number of graphs: 96, train running loss: 0.00167 (passed time: 7m 1s)
#           acc: 0.99954, fpr: 0.00046, fnr: 0.00043, rec: 0.99957, prc: 0.98975, f1: 0.99464, f1_macro: 0.99720
# epoch: 4, passed number of graphs: 192, train running loss: 0.00162 (passed time: 7m 15s)
#           acc: 0.99397, fpr: 0.00627, fnr: 0.00055, rec: 0.99945, prc: 0.87532, f1: 0.93328, f1_macro: 0.96506
# epoch: 4, passed number of graphs: 288, train running loss: 0.00158 (passed time: 7m 30s)
#           acc: 0.99754, fpr: 0.00254, fnr: 0.00048, rec: 0.99952, prc: 0.94513, f1: 0.97156, f1_macro: 0.98514
# epoch: 4, passed number of graphs: 384, train running loss: 0.00167 (passed time: 7m 44s)
#           acc: 0.99906, fpr: 0.00047, fnr: 0.01160, rec: 0.98840, prc: 0.98931, f1: 0.98885, f1_macro: 0.99418
# epoch: 4, passed number of graphs: 480, train running loss: 0.00176 (passed time: 7m 58s)
#           acc: 0.99787, fpr: 0.00110, fnr: 0.02524, rec: 0.97476, prc: 0.97536, f1: 0.97506, f1_macro: 0.98698
# epoch: 4, passed number of graphs: 576, train running loss: 0.00158 (passed time: 8m 12s)
#           acc: 0.99932, fpr: 0.00069, fnr: 0.00053, rec: 0.99947, prc: 0.98470, f1: 0.99203, f1_macro: 0.99584
# epoch: 4, passed number of graphs: 672, train running loss: 0.00199 (passed time: 8m 26s)
#           acc: 0.99054, fpr: 0.00953, fnr: 0.00790, rec: 0.99210, prc: 0.82260, f1: 0.89944, f1_macro: 0.94724
# epoch: 4, passed number of graphs: 768, train running loss: 0.00244 (passed time: 8m 40s)
#           acc: 0.99442, fpr: 0.00540, fnr: 0.00966, rec: 0.99034, prc: 0.88916, f1: 0.93703, f1_macro: 0.96706
# Validation --- epoch: 4, loss: 10.75542
#           acc: 0.29989, fnr: 0.00000, rec: 1.00000, prc: 0.02983, f1_macro: 0.25038, f1: 0.05793, fpr: 0.71551
# epoch: 5, passed number of graphs: 96, train running loss: 0.00329 (passed time: 9m 15s)
#           acc: 0.99726, fpr: 0.00285, fnr: 0.00039, rec: 0.99961, prc: 0.93975, f1: 0.96875, f1_macro: 0.98366
# epoch: 5, passed number of graphs: 192, train running loss: 0.00275 (passed time: 9m 29s)
#           acc: 0.99648, fpr: 0.00257, fnr: 0.02496, rec: 0.97504, prc: 0.94346, f1: 0.95899, f1_macro: 0.97858
# epoch: 5, passed number of graphs: 288, train running loss: 0.00221 (passed time: 9m 44s)
#           acc: 0.99821, fpr: 0.00184, fnr: 0.00068, rec: 0.99932, prc: 0.95968, f1: 0.97910, f1_macro: 0.98908
# epoch: 5, passed number of graphs: 384, train running loss: 0.00205 (passed time: 9m 58s)
#           acc: 0.99934, fpr: 0.00028, fnr: 0.00926, rec: 0.99074, prc: 0.99364, f1: 0.99219, f1_macro: 0.99592
# epoch: 5, passed number of graphs: 480, train running loss: 0.00215 (passed time: 10m 12s)
#           acc: 0.99851, fpr: 0.00040, fnr: 0.02602, rec: 0.97398, prc: 0.99095, f1: 0.98239, f1_macro: 0.99081
# epoch: 5, passed number of graphs: 576, train running loss: 0.00195 (passed time: 10m 26s)
#           acc: 0.99873, fpr: 0.00133, fnr: 0.00012, rec: 0.99988, prc: 0.97090, f1: 0.98518, f1_macro: 0.99226
# epoch: 5, passed number of graphs: 672, train running loss: 0.00183 (passed time: 10m 40s)
#           acc: 0.99926, fpr: 0.00075, fnr: 0.00051, rec: 0.99949, prc: 0.98350, f1: 0.99143, f1_macro: 0.99552
# epoch: 5, passed number of graphs: 768, train running loss: 0.00178 (passed time: 10m 54s)
#           acc: 0.99890, fpr: 0.00114, fnr: 0.00008, rec: 0.99992, prc: 0.97448, f1: 0.98704, f1_macro: 0.99323
# Validation --- epoch: 5, loss: 0.00752
#           acc: 0.99897, fnr: 0.04777, rec: 0.95223, prc: 0.99959, f1_macro: 0.98618, f1: 0.97289, fpr: 0.00001
# Better model saved at ./saved_models/GIN_4: 0.9728889974796195.pt.
# epoch: 6, passed number of graphs: 96, train running loss: 0.00066 (passed time: 11m 29s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00025, rec: 0.99975, prc: 0.99572, f1: 0.99773, f1_macro: 0.99882
# epoch: 6, passed number of graphs: 192, train running loss: 0.00067 (passed time: 11m 43s)
#           acc: 0.99835, fpr: 0.00168, fnr: 0.00103, rec: 0.99897, prc: 0.96333, f1: 0.98083, f1_macro: 0.98998
# epoch: 6, passed number of graphs: 288, train running loss: 0.00061 (passed time: 11m 57s)
#           acc: 0.99943, fpr: 0.00059, fnr: 0.00017, rec: 0.99983, prc: 0.98669, f1: 0.99322, f1_macro: 0.99646
# epoch: 6, passed number of graphs: 384, train running loss: 0.00062 (passed time: 12m 11s)
#           acc: 0.99944, fpr: 0.00057, fnr: 0.00035, rec: 0.99965, prc: 0.98724, f1: 0.99341, f1_macro: 0.99656
# epoch: 6, passed number of graphs: 480, train running loss: 0.00061 (passed time: 12m 26s)
#           acc: 0.99927, fpr: 0.00071, fnr: 0.00118, rec: 0.99882, prc: 0.98436, f1: 0.99154, f1_macro: 0.99558
# epoch: 6, passed number of graphs: 576, train running loss: 0.00056 (passed time: 12m 40s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00023, rec: 0.99977, prc: 0.99324, f1: 0.99649, f1_macro: 0.99817
# epoch: 6, passed number of graphs: 672, train running loss: 0.00054 (passed time: 12m 54s)
#           acc: 0.99980, fpr: 0.00020, fnr: 0.00033, rec: 0.99967, prc: 0.99555, f1: 0.99761, f1_macro: 0.99875
# epoch: 6, passed number of graphs: 768, train running loss: 0.00060 (passed time: 13m 8s)
#           acc: 0.99126, fpr: 0.00912, fnr: 0.00006, rec: 0.99994, prc: 0.82742, f1: 0.90554, f1_macro: 0.95048
# Validation --- epoch: 6, loss: 0.00329
#           acc: 0.99960, fnr: 0.01730, rec: 0.98270, prc: 0.99877, f1_macro: 0.99475, f1: 0.98969, fpr: 0.00003
# Better model saved at ./saved_models/GIN_5: 0.9896938810217616.pt.
# epoch: 7, passed number of graphs: 96, train running loss: 0.00257 (passed time: 13m 42s)
#           acc: 0.99480, fpr: 0.00540, fnr: 0.00078, rec: 0.99922, prc: 0.89156, f1: 0.94232, f1_macro: 0.96980
# epoch: 7, passed number of graphs: 192, train running loss: 0.00360 (passed time: 13m 57s)
#           acc: 0.99509, fpr: 0.00403, fnr: 0.02490, rec: 0.97510, prc: 0.91425, f1: 0.94369, f1_macro: 0.97056
# epoch: 7, passed number of graphs: 288, train running loss: 0.00320 (passed time: 14m 11s)
#           acc: 0.99546, fpr: 0.00473, fnr: 0.00008, rec: 0.99992, prc: 0.90250, f1: 0.94871, f1_macro: 0.97317
# epoch: 7, passed number of graphs: 384, train running loss: 0.00296 (passed time: 14m 25s)
#           acc: 0.99869, fpr: 0.00056, fnr: 0.01834, rec: 0.98166, prc: 0.98736, f1: 0.98450, f1_macro: 0.99191
# epoch: 7, passed number of graphs: 480, train running loss: 0.00295 (passed time: 14m 39s)
#           acc: 0.99742, fpr: 0.00178, fnr: 0.02064, rec: 0.97936, prc: 0.96088, f1: 0.97003, f1_macro: 0.98434
# epoch: 7, passed number of graphs: 576, train running loss: 0.00265 (passed time: 14m 53s)
#           acc: 0.99901, fpr: 0.00103, fnr: 0.00012, rec: 0.99988, prc: 0.97717, f1: 0.98839, f1_macro: 0.99394
# epoch: 7, passed number of graphs: 672, train running loss: 0.00244 (passed time: 15m 7s)
#           acc: 0.99931, fpr: 0.00068, fnr: 0.00073, rec: 0.99927, prc: 0.98490, f1: 0.99203, f1_macro: 0.99584
# epoch: 7, passed number of graphs: 768, train running loss: 0.00227 (passed time: 15m 22s)
#           acc: 0.99781, fpr: 0.00228, fnr: 0.00014, rec: 0.99986, prc: 0.95051, f1: 0.97456, f1_macro: 0.98671
# Validation --- epoch: 7, loss: 1.82737
#           acc: 0.65826, fnr: 0.00000, rec: 1.00000, prc: 0.06112, f1_macro: 0.45085, f1: 0.11498, fpr: 0.34925
# epoch: 8, passed number of graphs: 96, train running loss: 0.00059 (passed time: 15m 57s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00016, rec: 0.99984, prc: 0.99574, f1: 0.99778, f1_macro: 0.99884
# epoch: 8, passed number of graphs: 192, train running loss: 0.00060 (passed time: 16m 11s)
#           acc: 0.99790, fpr: 0.00215, fnr: 0.00111, rec: 0.99889, prc: 0.95346, f1: 0.97565, f1_macro: 0.98727
# epoch: 8, passed number of graphs: 288, train running loss: 0.00055 (passed time: 16m 25s)
#           acc: 0.99945, fpr: 0.00057, fnr: 0.00010, rec: 0.99990, prc: 0.98709, f1: 0.99345, f1_macro: 0.99658
# epoch: 8, passed number of graphs: 384, train running loss: 0.00067 (passed time: 16m 39s)
#           acc: 0.99944, fpr: 0.00056, fnr: 0.00047, rec: 0.99953, prc: 0.98742, f1: 0.99344, f1_macro: 0.99657
# epoch: 8, passed number of graphs: 480, train running loss: 0.00072 (passed time: 16m 53s)
#           acc: 0.99917, fpr: 0.00065, fnr: 0.00487, rec: 0.99513, prc: 0.98563, f1: 0.99036, f1_macro: 0.99496
# epoch: 8, passed number of graphs: 576, train running loss: 0.00066 (passed time: 17m 7s)
#           acc: 0.99946, fpr: 0.00056, fnr: 0.00012, rec: 0.99988, prc: 0.98758, f1: 0.99369, f1_macro: 0.99671
# epoch: 8, passed number of graphs: 672, train running loss: 0.00065 (passed time: 17m 21s)
#           acc: 0.99961, fpr: 0.00040, fnr: 0.00016, rec: 0.99984, prc: 0.99110, f1: 0.99545, f1_macro: 0.99762
# epoch: 8, passed number of graphs: 768, train running loss: 0.00065 (passed time: 17m 35s)
#           acc: 0.99634, fpr: 0.00382, fnr: 0.00014, rec: 0.99986, prc: 0.91972, f1: 0.95812, f1_macro: 0.97810
# Validation --- epoch: 8, loss: 3.39165
#           acc: 0.61849, fnr: 0.00000, rec: 1.00000, prc: 0.05636, f1_macro: 0.42985, f1: 0.10640, fpr: 0.38990
# epoch: 9, passed number of graphs: 96, train running loss: 0.00037 (passed time: 18m 10s)
#           acc: 0.99980, fpr: 0.00020, fnr: 0.00016, rec: 0.99984, prc: 0.99546, f1: 0.99764, f1_macro: 0.99877
# epoch: 9, passed number of graphs: 192, train running loss: 0.00037 (passed time: 18m 24s)
#           acc: 0.99925, fpr: 0.00076, fnr: 0.00055, rec: 0.99945, prc: 0.98304, f1: 0.99117, f1_macro: 0.99539
# epoch: 9, passed number of graphs: 288, train running loss: 0.00034 (passed time: 18m 38s)
#           acc: 0.99968, fpr: 0.00033, fnr: 0.00012, rec: 0.99988, prc: 0.99244, f1: 0.99614, f1_macro: 0.99799
# epoch: 9, passed number of graphs: 384, train running loss: 0.00047 (passed time: 18m 52s)
#           acc: 0.99946, fpr: 0.00054, fnr: 0.00033, rec: 0.99967, prc: 0.98783, f1: 0.99371, f1_macro: 0.99672
# epoch: 9, passed number of graphs: 480, train running loss: 0.00047 (passed time: 19m 6s)
#           acc: 0.99907, fpr: 0.00097, fnr: 0.00021, rec: 0.99979, prc: 0.97877, f1: 0.98917, f1_macro: 0.99434
# epoch: 9, passed number of graphs: 576, train running loss: 0.00044 (passed time: 19m 20s)
#           acc: 0.99974, fpr: 0.00026, fnr: 0.00021, rec: 0.99979, prc: 0.99421, f1: 0.99699, f1_macro: 0.99843
# epoch: 9, passed number of graphs: 672, train running loss: 0.00043 (passed time: 19m 34s)
#           acc: 0.99977, fpr: 0.00023, fnr: 0.00022, rec: 0.99978, prc: 0.99490, f1: 0.99733, f1_macro: 0.99861
# epoch: 9, passed number of graphs: 768, train running loss: 0.00043 (passed time: 19m 48s)
#           acc: 0.99978, fpr: 0.00023, fnr: 0.00010, rec: 0.99990, prc: 0.99477, f1: 0.99732, f1_macro: 0.99860
# Validation --- epoch: 9, loss: 0.00353
#           acc: 0.99976, fnr: 0.00497, rec: 0.99503, prc: 0.99390, f1_macro: 0.99688, f1: 0.99388, fpr: 0.00014
# Better model saved at ./saved_models/GIN_8: 0.9938837111312823.pt.
# epoch: 10, passed number of graphs: 96, train running loss: 0.00034 (passed time: 20m 22s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00016, rec: 0.99984, prc: 0.99584, f1: 0.99784, f1_macro: 0.99887
# epoch: 10, passed number of graphs: 192, train running loss: 0.00033 (passed time: 20m 36s)
#           acc: 0.99926, fpr: 0.00075, fnr: 0.00053, rec: 0.99947, prc: 0.98326, f1: 0.99130, f1_macro: 0.99545
# epoch: 10, passed number of graphs: 288, train running loss: 0.00031 (passed time: 20m 50s)
#           acc: 0.99967, fpr: 0.00034, fnr: 0.00012, rec: 0.99988, prc: 0.99238, f1: 0.99611, f1_macro: 0.99797
# epoch: 10, passed number of graphs: 384, train running loss: 0.00037 (passed time: 21m 4s)
#           acc: 0.99948, fpr: 0.00052, fnr: 0.00033, rec: 0.99967, prc: 0.98827, f1: 0.99394, f1_macro: 0.99683
# epoch: 10, passed number of graphs: 480, train running loss: 0.00038 (passed time: 21m 18s)
#           acc: 0.99909, fpr: 0.00094, fnr: 0.00021, rec: 0.99979, prc: 0.97928, f1: 0.98943, f1_macro: 0.99448
# epoch: 10, passed number of graphs: 576, train running loss: 0.00036 (passed time: 21m 32s)
#           acc: 0.99974, fpr: 0.00027, fnr: 0.00018, rec: 0.99982, prc: 0.99396, f1: 0.99688, f1_macro: 0.99837
# epoch: 10, passed number of graphs: 672, train running loss: 0.00036 (passed time: 21m 46s)
#           acc: 0.99977, fpr: 0.00023, fnr: 0.00020, rec: 0.99980, prc: 0.99488, f1: 0.99733, f1_macro: 0.99861
# epoch: 10, passed number of graphs: 768, train running loss: 0.00036 (passed time: 22m 0s)
#           acc: 0.99974, fpr: 0.00027, fnr: 0.00010, rec: 0.99990, prc: 0.99387, f1: 0.99687, f1_macro: 0.99837
# Validation --- epoch: 10, loss: 0.00360
#           acc: 0.99973, fnr: 0.00491, rec: 0.99509, prc: 0.99272, f1_macro: 0.99657, f1: 0.99327, fpr: 0.00017
# epoch: 11, passed number of graphs: 96, train running loss: 0.00035 (passed time: 22m 34s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00016, rec: 0.99984, prc: 0.99534, f1: 0.99758, f1_macro: 0.99874
# epoch: 11, passed number of graphs: 192, train running loss: 0.00033 (passed time: 22m 48s)
#           acc: 0.99924, fpr: 0.00078, fnr: 0.00039, rec: 0.99961, prc: 0.98260, f1: 0.99103, f1_macro: 0.99532
# epoch: 11, passed number of graphs: 288, train running loss: 0.00030 (passed time: 23m 2s)
#           acc: 0.99964, fpr: 0.00037, fnr: 0.00015, rec: 0.99985, prc: 0.99172, f1: 0.99577, f1_macro: 0.99779
# epoch: 11, passed number of graphs: 384, train running loss: 0.00033 (passed time: 23m 16s)
#           acc: 0.99950, fpr: 0.00051, fnr: 0.00033, rec: 0.99967, prc: 0.98869, f1: 0.99415, f1_macro: 0.99694
# epoch: 11, passed number of graphs: 480, train running loss: 0.00034 (passed time: 23m 30s)
#           acc: 0.99918, fpr: 0.00085, fnr: 0.00023, rec: 0.99977, prc: 0.98126, f1: 0.99043, f1_macro: 0.99500
# epoch: 11, passed number of graphs: 576, train running loss: 0.00032 (passed time: 23m 44s)
#           acc: 0.99971, fpr: 0.00030, fnr: 0.00016, rec: 0.99984, prc: 0.99326, f1: 0.99654, f1_macro: 0.99819
# epoch: 11, passed number of graphs: 672, train running loss: 0.00032 (passed time: 23m 58s)
#           acc: 0.99977, fpr: 0.00022, fnr: 0.00024, rec: 0.99976, prc: 0.99498, f1: 0.99736, f1_macro: 0.99862
# epoch: 11, passed number of graphs: 768, train running loss: 0.00032 (passed time: 24m 12s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00010, rec: 0.99990, prc: 0.99589, f1: 0.99789, f1_macro: 0.99890
# Validation --- epoch: 11, loss: 0.00247
#           acc: 0.99979, fnr: 0.00515, rec: 0.99485, prc: 0.99547, f1_macro: 0.99724, f1: 0.99459, fpr: 0.00010
# Better model saved at ./saved_models/GIN_10: 0.9945922321424808.pt.
# epoch: 12, passed number of graphs: 96, train running loss: 0.00028 (passed time: 24m 46s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00014, rec: 0.99986, prc: 0.99566, f1: 0.99775, f1_macro: 0.99883
# epoch: 12, passed number of graphs: 192, train running loss: 0.00028 (passed time: 25m 0s)
#           acc: 0.99927, fpr: 0.00075, fnr: 0.00035, rec: 0.99965, prc: 0.98334, f1: 0.99143, f1_macro: 0.99552
# epoch: 12, passed number of graphs: 288, train running loss: 0.00027 (passed time: 25m 14s)
#           acc: 0.99967, fpr: 0.00034, fnr: 0.00015, rec: 0.99985, prc: 0.99240, f1: 0.99611, f1_macro: 0.99797
# epoch: 12, passed number of graphs: 384, train running loss: 0.00030 (passed time: 25m 28s)
#           acc: 0.99951, fpr: 0.00050, fnr: 0.00031, rec: 0.99969, prc: 0.98875, f1: 0.99419, f1_macro: 0.99697
# epoch: 12, passed number of graphs: 480, train running loss: 0.00031 (passed time: 25m 42s)
#           acc: 0.99917, fpr: 0.00086, fnr: 0.00023, rec: 0.99977, prc: 0.98112, f1: 0.99036, f1_macro: 0.99496
# epoch: 12, passed number of graphs: 576, train running loss: 0.00030 (passed time: 25m 56s)
#           acc: 0.99971, fpr: 0.00030, fnr: 0.00016, rec: 0.99984, prc: 0.99328, f1: 0.99655, f1_macro: 0.99820
# epoch: 12, passed number of graphs: 672, train running loss: 0.00030 (passed time: 26m 10s)
#           acc: 0.99978, fpr: 0.00022, fnr: 0.00022, rec: 0.99978, prc: 0.99500, f1: 0.99738, f1_macro: 0.99863
# epoch: 12, passed number of graphs: 768, train running loss: 0.00030 (passed time: 26m 24s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00010, rec: 0.99990, prc: 0.99578, f1: 0.99784, f1_macro: 0.99887
# Validation --- epoch: 12, loss: 0.00241
#           acc: 0.99979, fnr: 0.00515, rec: 0.99485, prc: 0.99553, f1_macro: 0.99726, f1: 0.99463, fpr: 0.00010
# Better model saved at ./saved_models/GIN_11: 0.9946274699306525.pt.
# epoch: 13, passed number of graphs: 96, train running loss: 0.00028 (passed time: 26m 59s)
#           acc: 0.99981, fpr: 0.00020, fnr: 0.00014, rec: 0.99986, prc: 0.99558, f1: 0.99771, f1_macro: 0.99881
# epoch: 13, passed number of graphs: 192, train running loss: 0.00027 (passed time: 27m 12s)
#           acc: 0.99927, fpr: 0.00074, fnr: 0.00035, rec: 0.99965, prc: 0.98340, f1: 0.99146, f1_macro: 0.99554
# epoch: 13, passed number of graphs: 288, train running loss: 0.00026 (passed time: 27m 26s)
#           acc: 0.99967, fpr: 0.00033, fnr: 0.00015, rec: 0.99985, prc: 0.99242, f1: 0.99612, f1_macro: 0.99798
# epoch: 13, passed number of graphs: 384, train running loss: 0.00029 (passed time: 27m 40s)
#           acc: 0.99951, fpr: 0.00050, fnr: 0.00031, rec: 0.99969, prc: 0.98883, f1: 0.99423, f1_macro: 0.99699
# epoch: 13, passed number of graphs: 480, train running loss: 0.00030 (passed time: 27m 54s)
#           acc: 0.99917, fpr: 0.00086, fnr: 0.00023, rec: 0.99977, prc: 0.98114, f1: 0.99037, f1_macro: 0.99497
# epoch: 13, passed number of graphs: 576, train running loss: 0.00029 (passed time: 28m 8s)
#           acc: 0.99971, fpr: 0.00030, fnr: 0.00016, rec: 0.99984, prc: 0.99332, f1: 0.99657, f1_macro: 0.99821
# epoch: 13, passed number of graphs: 672, train running loss: 0.00029 (passed time: 28m 22s)
#           acc: 0.99978, fpr: 0.00022, fnr: 0.00022, rec: 0.99978, prc: 0.99509, f1: 0.99742, f1_macro: 0.99865
# epoch: 13, passed number of graphs: 768, train running loss: 0.00029 (passed time: 28m 36s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00010, rec: 0.99990, prc: 0.99584, f1: 0.99787, f1_macro: 0.99889
# Validation --- epoch: 13, loss: 0.00235
#           acc: 0.99979, fnr: 0.00518, rec: 0.99482, prc: 0.99567, f1_macro: 0.99729, f1: 0.99469, fpr: 0.00010
# Better model saved at ./saved_models/GIN_12: 0.9946857004760895.pt.
# epoch: 14, passed number of graphs: 96, train running loss: 0.00027 (passed time: 29m 10s)
#           acc: 0.99981, fpr: 0.00020, fnr: 0.00014, rec: 0.99986, prc: 0.99558, f1: 0.99771, f1_macro: 0.99881
# epoch: 14, passed number of graphs: 192, train running loss: 0.00027 (passed time: 29m 24s)
#           acc: 0.99928, fpr: 0.00074, fnr: 0.00035, rec: 0.99965, prc: 0.98352, f1: 0.99152, f1_macro: 0.99557
# epoch: 14, passed number of graphs: 288, train running loss: 0.00026 (passed time: 29m 38s)
#           acc: 0.99967, fpr: 0.00034, fnr: 0.00015, rec: 0.99985, prc: 0.99240, f1: 0.99611, f1_macro: 0.99797
# epoch: 14, passed number of graphs: 384, train running loss: 0.00028 (passed time: 29m 52s)
#           acc: 0.99950, fpr: 0.00050, fnr: 0.00035, rec: 0.99965, prc: 0.98877, f1: 0.99418, f1_macro: 0.99696
# epoch: 14, passed number of graphs: 480, train running loss: 0.00029 (passed time: 30m 6s)
#           acc: 0.99916, fpr: 0.00087, fnr: 0.00021, rec: 0.99979, prc: 0.98083, f1: 0.99022, f1_macro: 0.99489
# epoch: 14, passed number of graphs: 576, train running loss: 0.00028 (passed time: 30m 20s)
#           acc: 0.99971, fpr: 0.00030, fnr: 0.00016, rec: 0.99984, prc: 0.99336, f1: 0.99659, f1_macro: 0.99822
# epoch: 14, passed number of graphs: 672, train running loss: 0.00028 (passed time: 30m 34s)
#           acc: 0.99978, fpr: 0.00022, fnr: 0.00024, rec: 0.99976, prc: 0.99506, f1: 0.99740, f1_macro: 0.99864
# epoch: 14, passed number of graphs: 768, train running loss: 0.00028 (passed time: 30m 48s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00010, rec: 0.99990, prc: 0.99578, f1: 0.99784, f1_macro: 0.99887
# Validation --- epoch: 14, loss: 0.00229
#           acc: 0.99979, fnr: 0.00524, rec: 0.99476, prc: 0.99576, f1_macro: 0.99730, f1: 0.99470, fpr: 0.00009
# Better model saved at ./saved_models/GIN_13: 0.9946985859342194.pt.
# epoch: 15, passed number of graphs: 96, train running loss: 0.00027 (passed time: 31m 22s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00014, rec: 0.99986, prc: 0.99566, f1: 0.99775, f1_macro: 0.99883
# epoch: 15, passed number of graphs: 192, train running loss: 0.00026 (passed time: 31m 36s)
#           acc: 0.99928, fpr: 0.00073, fnr: 0.00035, rec: 0.99965, prc: 0.98364, f1: 0.99158, f1_macro: 0.99560
# epoch: 15, passed number of graphs: 288, train running loss: 0.00025 (passed time: 31m 50s)
#           acc: 0.99968, fpr: 0.00033, fnr: 0.00015, rec: 0.99985, prc: 0.99246, f1: 0.99614, f1_macro: 0.99799
# epoch: 15, passed number of graphs: 384, train running loss: 0.00027 (passed time: 32m 4s)
#           acc: 0.99951, fpr: 0.00050, fnr: 0.00031, rec: 0.99969, prc: 0.98883, f1: 0.99423, f1_macro: 0.99699
# epoch: 15, passed number of graphs: 480, train running loss: 0.00028 (passed time: 32m 18s)
#           acc: 0.99915, fpr: 0.00087, fnr: 0.00021, rec: 0.99979, prc: 0.98077, f1: 0.99019, f1_macro: 0.99487
# epoch: 15, passed number of graphs: 576, train running loss: 0.00027 (passed time: 32m 32s)
#           acc: 0.99972, fpr: 0.00029, fnr: 0.00016, rec: 0.99984, prc: 0.99350, f1: 0.99666, f1_macro: 0.99825
# epoch: 15, passed number of graphs: 672, train running loss: 0.00027 (passed time: 32m 46s)
#           acc: 0.99978, fpr: 0.00022, fnr: 0.00027, rec: 0.99973, prc: 0.99506, f1: 0.99739, f1_macro: 0.99864
# epoch: 15, passed number of graphs: 768, train running loss: 0.00028 (passed time: 33m 0s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00010, rec: 0.99990, prc: 0.99576, f1: 0.99783, f1_macro: 0.99887
# Validation --- epoch: 15, loss: 0.00225
#           acc: 0.99979, fnr: 0.00526, rec: 0.99474, prc: 0.99584, f1_macro: 0.99731, f1: 0.99473, fpr: 0.00009
# Better model saved at ./saved_models/GIN_14: 0.9947302868510487.pt.
# epoch: 16, passed number of graphs: 96, train running loss: 0.00026 (passed time: 33m 35s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00014, rec: 0.99986, prc: 0.99572, f1: 0.99778, f1_macro: 0.99884
# epoch: 16, passed number of graphs: 192, train running loss: 0.00026 (passed time: 33m 49s)
#           acc: 0.99928, fpr: 0.00073, fnr: 0.00037, rec: 0.99963, prc: 0.98364, f1: 0.99157, f1_macro: 0.99560
# epoch: 16, passed number of graphs: 288, train running loss: 0.00025 (passed time: 34m 2s)
#           acc: 0.99968, fpr: 0.00033, fnr: 0.00015, rec: 0.99985, prc: 0.99250, f1: 0.99616, f1_macro: 0.99800
# epoch: 16, passed number of graphs: 384, train running loss: 0.00027 (passed time: 34m 16s)
#           acc: 0.99951, fpr: 0.00050, fnr: 0.00033, rec: 0.99967, prc: 0.98881, f1: 0.99421, f1_macro: 0.99698
# epoch: 16, passed number of graphs: 480, train running loss: 0.00028 (passed time: 34m 30s)
#           acc: 0.99914, fpr: 0.00089, fnr: 0.00021, rec: 0.99979, prc: 0.98037, f1: 0.98999, f1_macro: 0.99477
# epoch: 16, passed number of graphs: 576, train running loss: 0.00027 (passed time: 34m 44s)
#           acc: 0.99972, fpr: 0.00029, fnr: 0.00016, rec: 0.99984, prc: 0.99354, f1: 0.99668, f1_macro: 0.99827
# epoch: 16, passed number of graphs: 672, train running loss: 0.00027 (passed time: 34m 58s)
#           acc: 0.99978, fpr: 0.00022, fnr: 0.00027, rec: 0.99973, prc: 0.99508, f1: 0.99740, f1_macro: 0.99864
# epoch: 16, passed number of graphs: 768, train running loss: 0.00027 (passed time: 35m 12s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00010, rec: 0.99990, prc: 0.99574, f1: 0.99782, f1_macro: 0.99886
# Validation --- epoch: 16, loss: 0.00222
#           acc: 0.99979, fnr: 0.00537, rec: 0.99463, prc: 0.99592, f1_macro: 0.99731, f1: 0.99472, fpr: 0.00009
# epoch: 17, passed number of graphs: 96, train running loss: 0.00026 (passed time: 35m 47s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00014, rec: 0.99986, prc: 0.99564, f1: 0.99774, f1_macro: 0.99882
# epoch: 17, passed number of graphs: 192, train running loss: 0.00025 (passed time: 36m 2s)
#           acc: 0.99929, fpr: 0.00073, fnr: 0.00035, rec: 0.99965, prc: 0.98380, f1: 0.99166, f1_macro: 0.99564
# epoch: 17, passed number of graphs: 288, train running loss: 0.00024 (passed time: 36m 16s)
#           acc: 0.99968, fpr: 0.00033, fnr: 0.00015, rec: 0.99985, prc: 0.99256, f1: 0.99620, f1_macro: 0.99801
# epoch: 17, passed number of graphs: 384, train running loss: 0.00026 (passed time: 36m 30s)
#           acc: 0.99951, fpr: 0.00050, fnr: 0.00033, rec: 0.99967, prc: 0.98889, f1: 0.99425, f1_macro: 0.99700
# epoch: 17, passed number of graphs: 480, train running loss: 0.00027 (passed time: 36m 44s)
#           acc: 0.99914, fpr: 0.00089, fnr: 0.00021, rec: 0.99979, prc: 0.98043, f1: 0.99002, f1_macro: 0.99478
# epoch: 17, passed number of graphs: 576, train running loss: 0.00026 (passed time: 36m 58s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00016, rec: 0.99984, prc: 0.99360, f1: 0.99671, f1_macro: 0.99828
# epoch: 17, passed number of graphs: 672, train running loss: 0.00026 (passed time: 37m 12s)
#           acc: 0.99978, fpr: 0.00022, fnr: 0.00027, rec: 0.99973, prc: 0.99504, f1: 0.99738, f1_macro: 0.99863
# epoch: 17, passed number of graphs: 768, train running loss: 0.00027 (passed time: 37m 26s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00010, rec: 0.99990, prc: 0.99574, f1: 0.99782, f1_macro: 0.99886
# Validation --- epoch: 17, loss: 0.00220
#           acc: 0.99979, fnr: 0.00518, rec: 0.99482, prc: 0.99563, f1_macro: 0.99728, f1: 0.99466, fpr: 0.00010
# epoch: 18, passed number of graphs: 96, train running loss: 0.00025 (passed time: 38m 1s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00014, rec: 0.99986, prc: 0.99586, f1: 0.99786, f1_macro: 0.99888
# epoch: 18, passed number of graphs: 192, train running loss: 0.00025 (passed time: 38m 15s)
#           acc: 0.99928, fpr: 0.00073, fnr: 0.00031, rec: 0.99969, prc: 0.98360, f1: 0.99158, f1_macro: 0.99560
# epoch: 18, passed number of graphs: 288, train running loss: 0.00024 (passed time: 38m 30s)
#           acc: 0.99968, fpr: 0.00033, fnr: 0.00012, rec: 0.99988, prc: 0.99246, f1: 0.99615, f1_macro: 0.99799
# epoch: 18, passed number of graphs: 384, train running loss: 0.00026 (passed time: 38m 44s)
#           acc: 0.99951, fpr: 0.00050, fnr: 0.00035, rec: 0.99965, prc: 0.98893, f1: 0.99426, f1_macro: 0.99700
# epoch: 18, passed number of graphs: 480, train running loss: 0.00027 (passed time: 38m 58s)
#           acc: 0.99913, fpr: 0.00090, fnr: 0.00019, rec: 0.99981, prc: 0.98025, f1: 0.98994, f1_macro: 0.99474
# epoch: 18, passed number of graphs: 576, train running loss: 0.00026 (passed time: 39m 12s)
#           acc: 0.99972, fpr: 0.00029, fnr: 0.00016, rec: 0.99984, prc: 0.99358, f1: 0.99670, f1_macro: 0.99828
# epoch: 18, passed number of graphs: 672, train running loss: 0.00026 (passed time: 39m 26s)
#           acc: 0.99978, fpr: 0.00022, fnr: 0.00027, rec: 0.99973, prc: 0.99508, f1: 0.99740, f1_macro: 0.99864
# epoch: 18, passed number of graphs: 768, train running loss: 0.00026 (passed time: 39m 40s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00008, rec: 0.99992, prc: 0.99568, f1: 0.99780, f1_macro: 0.99885
# Validation --- epoch: 18, loss: 0.00217
#           acc: 0.99979, fnr: 0.00524, rec: 0.99476, prc: 0.99573, f1_macro: 0.99729, f1: 0.99468, fpr: 0.00010
# epoch: 19, passed number of graphs: 96, train running loss: 0.00025 (passed time: 40m 15s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00014, rec: 0.99986, prc: 0.99582, f1: 0.99784, f1_macro: 0.99887
# epoch: 19, passed number of graphs: 192, train running loss: 0.00025 (passed time: 40m 30s)
#           acc: 0.99929, fpr: 0.00073, fnr: 0.00033, rec: 0.99967, prc: 0.98368, f1: 0.99161, f1_macro: 0.99562
# epoch: 19, passed number of graphs: 288, train running loss: 0.00023 (passed time: 40m 44s)
#           acc: 0.99968, fpr: 0.00033, fnr: 0.00012, rec: 0.99988, prc: 0.99248, f1: 0.99616, f1_macro: 0.99800
# epoch: 19, passed number of graphs: 384, train running loss: 0.00025 (passed time: 40m 58s)
#           acc: 0.99951, fpr: 0.00049, fnr: 0.00033, rec: 0.99967, prc: 0.98895, f1: 0.99428, f1_macro: 0.99701
# epoch: 19, passed number of graphs: 480, train running loss: 0.00026 (passed time: 41m 12s)
#           acc: 0.99913, fpr: 0.00090, fnr: 0.00017, rec: 0.99983, prc: 0.98021, f1: 0.98993, f1_macro: 0.99474
# epoch: 19, passed number of graphs: 576, train running loss: 0.00025 (passed time: 41m 27s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00016, rec: 0.99984, prc: 0.99360, f1: 0.99671, f1_macro: 0.99828
# epoch: 19, passed number of graphs: 672, train running loss: 0.00025 (passed time: 41m 41s)
#           acc: 0.99978, fpr: 0.00022, fnr: 0.00027, rec: 0.99973, prc: 0.99508, f1: 0.99740, f1_macro: 0.99864
# epoch: 19, passed number of graphs: 768, train running loss: 0.00026 (passed time: 41m 55s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00008, rec: 0.99992, prc: 0.99566, f1: 0.99778, f1_macro: 0.99884
# Validation --- epoch: 19, loss: 0.00215
#           acc: 0.99979, fnr: 0.00518, rec: 0.99482, prc: 0.99566, f1_macro: 0.99728, f1: 0.99467, fpr: 0.00010
# epoch: 20, passed number of graphs: 96, train running loss: 0.00025 (passed time: 42m 30s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00014, rec: 0.99986, prc: 0.99588, f1: 0.99787, f1_macro: 0.99889
# epoch: 20, passed number of graphs: 192, train running loss: 0.00024 (passed time: 42m 44s)
#           acc: 0.99929, fpr: 0.00073, fnr: 0.00033, rec: 0.99967, prc: 0.98372, f1: 0.99163, f1_macro: 0.99563
# epoch: 20, passed number of graphs: 288, train running loss: 0.00023 (passed time: 42m 58s)
#           acc: 0.99968, fpr: 0.00033, fnr: 0.00010, rec: 0.99990, prc: 0.99254, f1: 0.99621, f1_macro: 0.99802
# epoch: 20, passed number of graphs: 384, train running loss: 0.00025 (passed time: 43m 13s)
#           acc: 0.99951, fpr: 0.00050, fnr: 0.00033, rec: 0.99967, prc: 0.98887, f1: 0.99424, f1_macro: 0.99699
# epoch: 20, passed number of graphs: 480, train running loss: 0.00026 (passed time: 43m 27s)
#           acc: 0.99910, fpr: 0.00093, fnr: 0.00017, rec: 0.99983, prc: 0.97958, f1: 0.98960, f1_macro: 0.99457
# epoch: 20, passed number of graphs: 576, train running loss: 0.00025 (passed time: 43m 41s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00016, rec: 0.99984, prc: 0.99366, f1: 0.99674, f1_macro: 0.99830
# epoch: 20, passed number of graphs: 672, train running loss: 0.00025 (passed time: 43m 55s)
#           acc: 0.99978, fpr: 0.00022, fnr: 0.00027, rec: 0.99973, prc: 0.99511, f1: 0.99741, f1_macro: 0.99865
# epoch: 20, passed number of graphs: 768, train running loss: 0.00025 (passed time: 44m 9s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00008, rec: 0.99992, prc: 0.99570, f1: 0.99781, f1_macro: 0.99885
# Validation --- epoch: 20, loss: 0.00214
#           acc: 0.99979, fnr: 0.00526, rec: 0.99474, prc: 0.99574, f1_macro: 0.99729, f1: 0.99468, fpr: 0.00010
# epoch: 21, passed number of graphs: 96, train running loss: 0.00025 (passed time: 44m 44s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00014, rec: 0.99986, prc: 0.99590, f1: 0.99788, f1_macro: 0.99889
# epoch: 21, passed number of graphs: 192, train running loss: 0.00024 (passed time: 44m 58s)
#           acc: 0.99929, fpr: 0.00073, fnr: 0.00033, rec: 0.99967, prc: 0.98376, f1: 0.99165, f1_macro: 0.99564
# epoch: 21, passed number of graphs: 288, train running loss: 0.00023 (passed time: 45m 13s)
#           acc: 0.99968, fpr: 0.00033, fnr: 0.00010, rec: 0.99990, prc: 0.99258, f1: 0.99623, f1_macro: 0.99803
# epoch: 21, passed number of graphs: 384, train running loss: 0.00025 (passed time: 45m 27s)
#           acc: 0.99951, fpr: 0.00050, fnr: 0.00033, rec: 0.99967, prc: 0.98881, f1: 0.99421, f1_macro: 0.99698
# epoch: 21, passed number of graphs: 480, train running loss: 0.00026 (passed time: 45m 41s)
#           acc: 0.99909, fpr: 0.00094, fnr: 0.00014, rec: 0.99986, prc: 0.97936, f1: 0.98950, f1_macro: 0.99451
# epoch: 21, passed number of graphs: 576, train running loss: 0.00025 (passed time: 45m 55s)
#           acc: 0.99973, fpr: 0.00028, fnr: 0.00016, rec: 0.99984, prc: 0.99374, f1: 0.99678, f1_macro: 0.99832
# epoch: 21, passed number of graphs: 672, train running loss: 0.00025 (passed time: 46m 9s)
#           acc: 0.99978, fpr: 0.00022, fnr: 0.00024, rec: 0.99976, prc: 0.99508, f1: 0.99741, f1_macro: 0.99865
# epoch: 21, passed number of graphs: 768, train running loss: 0.00025 (passed time: 46m 23s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00008, rec: 0.99992, prc: 0.99572, f1: 0.99782, f1_macro: 0.99886
# Validation --- epoch: 21, loss: 0.00214
#           acc: 0.99979, fnr: 0.00529, rec: 0.99471, prc: 0.99577, f1_macro: 0.99729, f1: 0.99468, fpr: 0.00009
# epoch: 22, passed number of graphs: 96, train running loss: 0.00024 (passed time: 46m 58s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00014, rec: 0.99986, prc: 0.99592, f1: 0.99789, f1_macro: 0.99890
# epoch: 22, passed number of graphs: 192, train running loss: 0.00024 (passed time: 47m 12s)
#           acc: 0.99929, fpr: 0.00072, fnr: 0.00033, rec: 0.99967, prc: 0.98382, f1: 0.99168, f1_macro: 0.99566
# epoch: 22, passed number of graphs: 288, train running loss: 0.00022 (passed time: 47m 26s)
#           acc: 0.99968, fpr: 0.00032, fnr: 0.00010, rec: 0.99990, prc: 0.99264, f1: 0.99626, f1_macro: 0.99805
# epoch: 22, passed number of graphs: 384, train running loss: 0.00024 (passed time: 47m 41s)
#           acc: 0.99950, fpr: 0.00051, fnr: 0.00031, rec: 0.99969, prc: 0.98869, f1: 0.99416, f1_macro: 0.99695
# epoch: 22, passed number of graphs: 480, train running loss: 0.00025 (passed time: 47m 55s)
#           acc: 0.99908, fpr: 0.00096, fnr: 0.00014, rec: 0.99986, prc: 0.97901, f1: 0.98932, f1_macro: 0.99442
# epoch: 22, passed number of graphs: 576, train running loss: 0.00024 (passed time: 48m 9s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00016, rec: 0.99984, prc: 0.99382, f1: 0.99682, f1_macro: 0.99834
# epoch: 22, passed number of graphs: 672, train running loss: 0.00024 (passed time: 48m 23s)
#           acc: 0.99978, fpr: 0.00022, fnr: 0.00024, rec: 0.99976, prc: 0.99506, f1: 0.99740, f1_macro: 0.99864
# epoch: 22, passed number of graphs: 768, train running loss: 0.00025 (passed time: 48m 37s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00008, rec: 0.99992, prc: 0.99572, f1: 0.99782, f1_macro: 0.99886
# Validation --- epoch: 22, loss: 0.00213
#           acc: 0.99979, fnr: 0.00521, rec: 0.99479, prc: 0.99558, f1_macro: 0.99725, f1: 0.99461, fpr: 0.00010
# epoch: 23, passed number of graphs: 96, train running loss: 0.00024 (passed time: 49m 12s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00014, rec: 0.99986, prc: 0.99594, f1: 0.99790, f1_macro: 0.99890
# epoch: 23, passed number of graphs: 192, train running loss: 0.00023 (passed time: 49m 26s)
#           acc: 0.99929, fpr: 0.00072, fnr: 0.00033, rec: 0.99967, prc: 0.98386, f1: 0.99170, f1_macro: 0.99567
# epoch: 23, passed number of graphs: 288, train running loss: 0.00022 (passed time: 49m 40s)
#           acc: 0.99968, fpr: 0.00033, fnr: 0.00010, rec: 0.99990, prc: 0.99258, f1: 0.99623, f1_macro: 0.99803
# epoch: 23, passed number of graphs: 384, train running loss: 0.00024 (passed time: 49m 54s)
#           acc: 0.99950, fpr: 0.00051, fnr: 0.00031, rec: 0.99969, prc: 0.98869, f1: 0.99416, f1_macro: 0.99695
# epoch: 23, passed number of graphs: 480, train running loss: 0.00025 (passed time: 50m 9s)
#           acc: 0.99908, fpr: 0.00096, fnr: 0.00014, rec: 0.99986, prc: 0.97895, f1: 0.98929, f1_macro: 0.99440
# epoch: 23, passed number of graphs: 576, train running loss: 0.00024 (passed time: 50m 23s)
#           acc: 0.99974, fpr: 0.00027, fnr: 0.00016, rec: 0.99984, prc: 0.99396, f1: 0.99689, f1_macro: 0.99838
# epoch: 23, passed number of graphs: 672, train running loss: 0.00024 (passed time: 50m 37s)
#           acc: 0.99978, fpr: 0.00022, fnr: 0.00022, rec: 0.99978, prc: 0.99500, f1: 0.99738, f1_macro: 0.99863
# epoch: 23, passed number of graphs: 768, train running loss: 0.00024 (passed time: 50m 51s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00008, rec: 0.99992, prc: 0.99574, f1: 0.99783, f1_macro: 0.99887
# Validation --- epoch: 23, loss: 0.00211
#           acc: 0.99979, fnr: 0.00511, rec: 0.99489, prc: 0.99536, f1_macro: 0.99722, f1: 0.99454, fpr: 0.00011
# epoch: 24, passed number of graphs: 96, train running loss: 0.00024 (passed time: 51m 26s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00014, rec: 0.99986, prc: 0.99594, f1: 0.99790, f1_macro: 0.99890
# epoch: 24, passed number of graphs: 192, train running loss: 0.00023 (passed time: 51m 40s)
#           acc: 0.99930, fpr: 0.00071, fnr: 0.00033, rec: 0.99967, prc: 0.98409, f1: 0.99182, f1_macro: 0.99573
# epoch: 24, passed number of graphs: 288, train running loss: 0.00022 (passed time: 51m 54s)
#           acc: 0.99968, fpr: 0.00033, fnr: 0.00010, rec: 0.99990, prc: 0.99256, f1: 0.99622, f1_macro: 0.99802
# epoch: 24, passed number of graphs: 384, train running loss: 0.00024 (passed time: 52m 8s)
#           acc: 0.99950, fpr: 0.00051, fnr: 0.00031, rec: 0.99969, prc: 0.98863, f1: 0.99413, f1_macro: 0.99693
# epoch: 24, passed number of graphs: 480, train running loss: 0.00025 (passed time: 52m 22s)
#           acc: 0.99905, fpr: 0.00099, fnr: 0.00014, rec: 0.99986, prc: 0.97825, f1: 0.98894, f1_macro: 0.99422
# epoch: 24, passed number of graphs: 576, train running loss: 0.00024 (passed time: 52m 37s)
#           acc: 0.99974, fpr: 0.00026, fnr: 0.00018, rec: 0.99982, prc: 0.99405, f1: 0.99692, f1_macro: 0.99839
# epoch: 24, passed number of graphs: 672, train running loss: 0.00024 (passed time: 52m 51s)
#           acc: 0.99977, fpr: 0.00023, fnr: 0.00020, rec: 0.99980, prc: 0.99490, f1: 0.99734, f1_macro: 0.99861
# epoch: 24, passed number of graphs: 768, train running loss: 0.00024 (passed time: 53m 5s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00008, rec: 0.99992, prc: 0.99578, f1: 0.99785, f1_macro: 0.99888
# Validation --- epoch: 24, loss: 0.00214
#           acc: 0.99978, fnr: 0.00509, rec: 0.99491, prc: 0.99508, f1_macro: 0.99715, f1: 0.99441, fpr: 0.00011
# epoch: 25, passed number of graphs: 96, train running loss: 0.00024 (passed time: 53m 40s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00014, rec: 0.99986, prc: 0.99592, f1: 0.99789, f1_macro: 0.99890
# epoch: 25, passed number of graphs: 192, train running loss: 0.00023 (passed time: 53m 54s)
#           acc: 0.99931, fpr: 0.00071, fnr: 0.00033, rec: 0.99967, prc: 0.98413, f1: 0.99184, f1_macro: 0.99574
# epoch: 25, passed number of graphs: 288, train running loss: 0.00021 (passed time: 54m 8s)
# ...
#           acc: 0.99969, fpr: 0.00032, fnr: 0.00010, rec: 0.99990, prc: 0.99281, f1: 0.99634, f1_macro: 0.99809
# epoch: 42, passed number of graphs: 384, train running loss: 0.00020 (passed time: 1h 31m 59s)
#           acc: 0.99949, fpr: 0.00052, fnr: 0.00021, rec: 0.99979, prc: 0.98835, f1: 0.99404, f1_macro: 0.99689
# epoch: 42, passed number of graphs: 480, train running loss: 0.00021 (passed time: 1h 32m 13s)
#           acc: 0.99916, fpr: 0.00087, fnr: 0.00008, rec: 0.99992, prc: 0.98085, f1: 0.99029, f1_macro: 0.99493
# epoch: 42, passed number of graphs: 576, train running loss: 0.00020 (passed time: 1h 32m 27s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00016, rec: 0.99984, prc: 0.99366, f1: 0.99674, f1_macro: 0.99830
# epoch: 42, passed number of graphs: 672, train running loss: 0.00020 (passed time: 1h 32m 41s)
#           acc: 0.99978, fpr: 0.00023, fnr: 0.00012, rec: 0.99988, prc: 0.99490, f1: 0.99738, f1_macro: 0.99863
# epoch: 42, passed number of graphs: 768, train running loss: 0.00021 (passed time: 1h 32m 56s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00006, rec: 0.99994, prc: 0.99625, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 42, loss: 0.00185
#           acc: 0.99980, fnr: 0.00504, rec: 0.99496, prc: 0.99577, f1_macro: 0.99734, f1: 0.99479, fpr: 0.00010
# epoch: 43, passed number of graphs: 96, train running loss: 0.00021 (passed time: 1h 33m 31s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00012, rec: 0.99988, prc: 0.99599, f1: 0.99793, f1_macro: 0.99892
# epoch: 43, passed number of graphs: 192, train running loss: 0.00020 (passed time: 1h 33m 45s)
#           acc: 0.99928, fpr: 0.00075, fnr: 0.00023, rec: 0.99977, prc: 0.98336, f1: 0.99150, f1_macro: 0.99556
# epoch: 43, passed number of graphs: 288, train running loss: 0.00019 (passed time: 1h 33m 59s)
#           acc: 0.99969, fpr: 0.00032, fnr: 0.00010, rec: 0.99990, prc: 0.99281, f1: 0.99634, f1_macro: 0.99809
# epoch: 43, passed number of graphs: 384, train running loss: 0.00020 (passed time: 1h 34m 14s)
#           acc: 0.99949, fpr: 0.00052, fnr: 0.00021, rec: 0.99979, prc: 0.98835, f1: 0.99404, f1_macro: 0.99689
# epoch: 43, passed number of graphs: 480, train running loss: 0.00021 (passed time: 1h 34m 28s)
#           acc: 0.99916, fpr: 0.00087, fnr: 0.00008, rec: 0.99992, prc: 0.98083, f1: 0.99028, f1_macro: 0.99492
# epoch: 43, passed number of graphs: 576, train running loss: 0.00020 (passed time: 1h 34m 42s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00016, rec: 0.99984, prc: 0.99364, f1: 0.99673, f1_macro: 0.99829
# epoch: 43, passed number of graphs: 672, train running loss: 0.00020 (passed time: 1h 34m 56s)
#           acc: 0.99978, fpr: 0.00023, fnr: 0.00012, rec: 0.99988, prc: 0.99490, f1: 0.99738, f1_macro: 0.99863
# epoch: 43, passed number of graphs: 768, train running loss: 0.00021 (passed time: 1h 35m 10s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00006, rec: 0.99994, prc: 0.99625, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 43, loss: 0.00185
#           acc: 0.99980, fnr: 0.00504, rec: 0.99496, prc: 0.99576, f1_macro: 0.99734, f1: 0.99478, fpr: 0.00010
# epoch: 44, passed number of graphs: 96, train running loss: 0.00021 (passed time: 1h 35m 45s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00012, rec: 0.99988, prc: 0.99601, f1: 0.99794, f1_macro: 0.99892
# epoch: 44, passed number of graphs: 192, train running loss: 0.00020 (passed time: 1h 35m 59s)
#           acc: 0.99927, fpr: 0.00075, fnr: 0.00023, rec: 0.99977, prc: 0.98332, f1: 0.99148, f1_macro: 0.99555
# epoch: 44, passed number of graphs: 288, train running loss: 0.00019 (passed time: 1h 36m 14s)
#           acc: 0.99969, fpr: 0.00032, fnr: 0.00010, rec: 0.99990, prc: 0.99281, f1: 0.99634, f1_macro: 0.99809
# epoch: 44, passed number of graphs: 384, train running loss: 0.00020 (passed time: 1h 36m 28s)
#           acc: 0.99949, fpr: 0.00052, fnr: 0.00021, rec: 0.99979, prc: 0.98835, f1: 0.99404, f1_macro: 0.99689
# epoch: 44, passed number of graphs: 480, train running loss: 0.00021 (passed time: 1h 36m 42s)
#           acc: 0.99916, fpr: 0.00087, fnr: 0.00008, rec: 0.99992, prc: 0.98079, f1: 0.99026, f1_macro: 0.99491
# epoch: 44, passed number of graphs: 576, train running loss: 0.00020 (passed time: 1h 36m 56s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00016, rec: 0.99984, prc: 0.99364, f1: 0.99673, f1_macro: 0.99829
# epoch: 44, passed number of graphs: 672, train running loss: 0.00020 (passed time: 1h 37m 10s)
#           acc: 0.99978, fpr: 0.00023, fnr: 0.00012, rec: 0.99988, prc: 0.99488, f1: 0.99737, f1_macro: 0.99863
# epoch: 44, passed number of graphs: 768, train running loss: 0.00021 (passed time: 1h 37m 24s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00006, rec: 0.99994, prc: 0.99625, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 44, loss: 0.00185
#           acc: 0.99980, fnr: 0.00504, rec: 0.99496, prc: 0.99575, f1_macro: 0.99734, f1: 0.99478, fpr: 0.00010
# epoch: 45, passed number of graphs: 96, train running loss: 0.00021 (passed time: 1h 37m 59s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00012, rec: 0.99988, prc: 0.99599, f1: 0.99793, f1_macro: 0.99892
# epoch: 45, passed number of graphs: 192, train running loss: 0.00020 (passed time: 1h 38m 14s)
#           acc: 0.99927, fpr: 0.00075, fnr: 0.00023, rec: 0.99977, prc: 0.98324, f1: 0.99144, f1_macro: 0.99553
# epoch: 45, passed number of graphs: 288, train running loss: 0.00019 (passed time: 1h 38m 28s)
#           acc: 0.99969, fpr: 0.00032, fnr: 0.00010, rec: 0.99990, prc: 0.99283, f1: 0.99635, f1_macro: 0.99809
# epoch: 45, passed number of graphs: 384, train running loss: 0.00020 (passed time: 1h 38m 42s)
#           acc: 0.99949, fpr: 0.00052, fnr: 0.00021, rec: 0.99979, prc: 0.98835, f1: 0.99404, f1_macro: 0.99689
# epoch: 45, passed number of graphs: 480, train running loss: 0.00021 (passed time: 1h 38m 56s)
#           acc: 0.99916, fpr: 0.00087, fnr: 0.00008, rec: 0.99992, prc: 0.98079, f1: 0.99026, f1_macro: 0.99491
# epoch: 45, passed number of graphs: 576, train running loss: 0.00020 (passed time: 1h 39m 10s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00016, rec: 0.99984, prc: 0.99362, f1: 0.99672, f1_macro: 0.99829
# epoch: 45, passed number of graphs: 672, train running loss: 0.00020 (passed time: 1h 39m 24s)
#           acc: 0.99978, fpr: 0.00023, fnr: 0.00012, rec: 0.99988, prc: 0.99490, f1: 0.99738, f1_macro: 0.99863
# epoch: 45, passed number of graphs: 768, train running loss: 0.00021 (passed time: 1h 39m 39s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00006, rec: 0.99994, prc: 0.99625, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 45, loss: 0.00185
#           acc: 0.99980, fnr: 0.00504, rec: 0.99496, prc: 0.99574, f1_macro: 0.99734, f1: 0.99478, fpr: 0.00010
# epoch: 46, passed number of graphs: 96, train running loss: 0.00020 (passed time: 1h 40m 14s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00012, rec: 0.99988, prc: 0.99599, f1: 0.99793, f1_macro: 0.99892
# epoch: 46, passed number of graphs: 192, train running loss: 0.00020 (passed time: 1h 40m 28s)
#           acc: 0.99927, fpr: 0.00075, fnr: 0.00023, rec: 0.99977, prc: 0.98324, f1: 0.99144, f1_macro: 0.99553
# epoch: 46, passed number of graphs: 288, train running loss: 0.00019 (passed time: 1h 40m 42s)
#           acc: 0.99969, fpr: 0.00032, fnr: 0.00010, rec: 0.99990, prc: 0.99283, f1: 0.99635, f1_macro: 0.99809
# epoch: 46, passed number of graphs: 384, train running loss: 0.00020 (passed time: 1h 40m 56s)
#           acc: 0.99949, fpr: 0.00052, fnr: 0.00021, rec: 0.99979, prc: 0.98835, f1: 0.99404, f1_macro: 0.99689
# epoch: 46, passed number of graphs: 480, train running loss: 0.00021 (passed time: 1h 41m 11s)
#           acc: 0.99916, fpr: 0.00087, fnr: 0.00008, rec: 0.99992, prc: 0.98079, f1: 0.99026, f1_macro: 0.99491
# epoch: 46, passed number of graphs: 576, train running loss: 0.00020 (passed time: 1h 41m 25s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00016, rec: 0.99984, prc: 0.99362, f1: 0.99672, f1_macro: 0.99829
# epoch: 46, passed number of graphs: 672, train running loss: 0.00020 (passed time: 1h 41m 39s)
#           acc: 0.99978, fpr: 0.00023, fnr: 0.00012, rec: 0.99988, prc: 0.99492, f1: 0.99739, f1_macro: 0.99864
# epoch: 46, passed number of graphs: 768, train running loss: 0.00021 (passed time: 1h 41m 53s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00006, rec: 0.99994, prc: 0.99625, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 46, loss: 0.00184
#           acc: 0.99980, fnr: 0.00504, rec: 0.99496, prc: 0.99574, f1_macro: 0.99733, f1: 0.99477, fpr: 0.00010
# epoch: 47, passed number of graphs: 96, train running loss: 0.00020 (passed time: 1h 42m 28s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00012, rec: 0.99988, prc: 0.99601, f1: 0.99794, f1_macro: 0.99892
# epoch: 47, passed number of graphs: 192, train running loss: 0.00020 (passed time: 1h 42m 43s)
#           acc: 0.99927, fpr: 0.00075, fnr: 0.00023, rec: 0.99977, prc: 0.98322, f1: 0.99143, f1_macro: 0.99552
# epoch: 47, passed number of graphs: 288, train running loss: 0.00019 (passed time: 1h 42m 57s)
#           acc: 0.99969, fpr: 0.00032, fnr: 0.00010, rec: 0.99990, prc: 0.99283, f1: 0.99635, f1_macro: 0.99809
# epoch: 47, passed number of graphs: 384, train running loss: 0.00020 (passed time: 1h 43m 11s)
#           acc: 0.99949, fpr: 0.00052, fnr: 0.00021, rec: 0.99979, prc: 0.98833, f1: 0.99403, f1_macro: 0.99688
# epoch: 47, passed number of graphs: 480, train running loss: 0.00021 (passed time: 1h 43m 25s)
#           acc: 0.99916, fpr: 0.00087, fnr: 0.00008, rec: 0.99992, prc: 0.98077, f1: 0.99025, f1_macro: 0.99491
# epoch: 47, passed number of graphs: 576, train running loss: 0.00020 (passed time: 1h 43m 39s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00016, rec: 0.99984, prc: 0.99366, f1: 0.99674, f1_macro: 0.99830
# epoch: 47, passed number of graphs: 672, train running loss: 0.00020 (passed time: 1h 43m 54s)
#           acc: 0.99978, fpr: 0.00023, fnr: 0.00012, rec: 0.99988, prc: 0.99490, f1: 0.99738, f1_macro: 0.99863
# epoch: 47, passed number of graphs: 768, train running loss: 0.00021 (passed time: 1h 44m 8s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00006, rec: 0.99994, prc: 0.99625, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 47, loss: 0.00184
#           acc: 0.99980, fnr: 0.00504, rec: 0.99496, prc: 0.99574, f1_macro: 0.99733, f1: 0.99477, fpr: 0.00010
# epoch: 48, passed number of graphs: 96, train running loss: 0.00020 (passed time: 1h 44m 43s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00012, rec: 0.99988, prc: 0.99597, f1: 0.99792, f1_macro: 0.99891
# epoch: 48, passed number of graphs: 192, train running loss: 0.00020 (passed time: 1h 44m 58s)
#           acc: 0.99927, fpr: 0.00075, fnr: 0.00023, rec: 0.99977, prc: 0.98324, f1: 0.99144, f1_macro: 0.99553
# epoch: 48, passed number of graphs: 288, train running loss: 0.00019 (passed time: 1h 45m 12s)
#           acc: 0.99969, fpr: 0.00032, fnr: 0.00010, rec: 0.99990, prc: 0.99281, f1: 0.99634, f1_macro: 0.99809
# epoch: 48, passed number of graphs: 384, train running loss: 0.00020 (passed time: 1h 45m 26s)
#           acc: 0.99949, fpr: 0.00052, fnr: 0.00021, rec: 0.99979, prc: 0.98833, f1: 0.99403, f1_macro: 0.99688
# epoch: 48, passed number of graphs: 480, train running loss: 0.00021 (passed time: 1h 45m 40s)
#           acc: 0.99916, fpr: 0.00088, fnr: 0.00008, rec: 0.99992, prc: 0.98075, f1: 0.99024, f1_macro: 0.99490
# epoch: 48, passed number of graphs: 576, train running loss: 0.00020 (passed time: 1h 45m 54s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00016, rec: 0.99984, prc: 0.99364, f1: 0.99673, f1_macro: 0.99829
# epoch: 48, passed number of graphs: 672, train running loss: 0.00020 (passed time: 1h 46m 8s)
#           acc: 0.99978, fpr: 0.00023, fnr: 0.00012, rec: 0.99988, prc: 0.99490, f1: 0.99738, f1_macro: 0.99863
# epoch: 48, passed number of graphs: 768, train running loss: 0.00021 (passed time: 1h 46m 23s)
#           acc: 0.99984, fpr: 0.00017, fnr: 0.00006, rec: 0.99994, prc: 0.99623, f1: 0.99808, f1_macro: 0.99900
# Validation --- epoch: 48, loss: 0.00184
#           acc: 0.99980, fnr: 0.00504, rec: 0.99496, prc: 0.99574, f1_macro: 0.99733, f1: 0.99477, fpr: 0.00010
# epoch: 49, passed number of graphs: 96, train running loss: 0.00020 (passed time: 1h 46m 58s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00012, rec: 0.99988, prc: 0.99597, f1: 0.99792, f1_macro: 0.99891
# epoch: 49, passed number of graphs: 192, train running loss: 0.00020 (passed time: 1h 47m 12s)
#           acc: 0.99927, fpr: 0.00075, fnr: 0.00023, rec: 0.99977, prc: 0.98326, f1: 0.99145, f1_macro: 0.99553
# epoch: 49, passed number of graphs: 288, train running loss: 0.00019 (passed time: 1h 47m 26s)
#           acc: 0.99969, fpr: 0.00032, fnr: 0.00010, rec: 0.99990, prc: 0.99281, f1: 0.99634, f1_macro: 0.99809
# epoch: 49, passed number of graphs: 384, train running loss: 0.00020 (passed time: 1h 47m 41s)
#           acc: 0.99949, fpr: 0.00052, fnr: 0.00021, rec: 0.99979, prc: 0.98833, f1: 0.99403, f1_macro: 0.99688
# epoch: 49, passed number of graphs: 480, train running loss: 0.00021 (passed time: 1h 47m 55s)
#           acc: 0.99916, fpr: 0.00087, fnr: 0.00008, rec: 0.99992, prc: 0.98077, f1: 0.99025, f1_macro: 0.99491
# epoch: 49, passed number of graphs: 576, train running loss: 0.00020 (passed time: 1h 48m 9s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00016, rec: 0.99984, prc: 0.99364, f1: 0.99673, f1_macro: 0.99829
# epoch: 49, passed number of graphs: 672, train running loss: 0.00020 (passed time: 1h 48m 23s)
#           acc: 0.99978, fpr: 0.00023, fnr: 0.00012, rec: 0.99988, prc: 0.99494, f1: 0.99740, f1_macro: 0.99864
# epoch: 49, passed number of graphs: 768, train running loss: 0.00021 (passed time: 1h 48m 37s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00006, rec: 0.99994, prc: 0.99625, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 49, loss: 0.00184
#           acc: 0.99980, fnr: 0.00504, rec: 0.99496, prc: 0.99573, f1_macro: 0.99733, f1: 0.99477, fpr: 0.00010
# epoch: 50, passed number of graphs: 96, train running loss: 0.00020 (passed time: 1h 49m 13s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00012, rec: 0.99988, prc: 0.99599, f1: 0.99793, f1_macro: 0.99892
# epoch: 50, passed number of graphs: 192, train running loss: 0.00020 (passed time: 1h 49m 27s)
#           acc: 0.99927, fpr: 0.00075, fnr: 0.00023, rec: 0.99977, prc: 0.98322, f1: 0.99143, f1_macro: 0.99552
# epoch: 50, passed number of graphs: 288, train running loss: 0.00019 (passed time: 1h 49m 41s)
#           acc: 0.99969, fpr: 0.00032, fnr: 0.00010, rec: 0.99990, prc: 0.99281, f1: 0.99634, f1_macro: 0.99809
# epoch: 50, passed number of graphs: 384, train running loss: 0.00020 (passed time: 1h 49m 55s)
#           acc: 0.99949, fpr: 0.00052, fnr: 0.00021, rec: 0.99979, prc: 0.98831, f1: 0.99402, f1_macro: 0.99688
# epoch: 50, passed number of graphs: 480, train running loss: 0.00021 (passed time: 1h 50m 9s)
#           acc: 0.99915, fpr: 0.00088, fnr: 0.00008, rec: 0.99992, prc: 0.98065, f1: 0.99019, f1_macro: 0.99487
# epoch: 50, passed number of graphs: 576, train running loss: 0.00020 (passed time: 1h 50m 24s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00016, rec: 0.99984, prc: 0.99364, f1: 0.99673, f1_macro: 0.99829
# epoch: 50, passed number of graphs: 672, train running loss: 0.00020 (passed time: 1h 50m 38s)
#           acc: 0.99978, fpr: 0.00023, fnr: 0.00012, rec: 0.99988, prc: 0.99488, f1: 0.99737, f1_macro: 0.99863
# epoch: 50, passed number of graphs: 768, train running loss: 0.00021 (passed time: 1h 50m 52s)
#           acc: 0.99984, fpr: 0.00017, fnr: 0.00006, rec: 0.99994, prc: 0.99621, f1: 0.99807, f1_macro: 0.99899
# Validation --- epoch: 50, loss: 0.00184
#           acc: 0.99980, fnr: 0.00505, rec: 0.99495, prc: 0.99575, f1_macro: 0.99734, f1: 0.99478, fpr: 0.00010
# ************ best model obtained after epoch 34, saved at ./saved_models/GIN_33: 0.9947998181870554.pt ************
# Testing --- loss: 0.00167
#           acc: 0.99976, fnr: 0.00090, rec: 0.99910, prc: 0.99123, f1_macro: 0.99734, f1: 0.99481, fpr: 0.00023

# %%
# !zip -r /content/GIN_053_18_Adam_P2P_6k_botnode.zip /content/saved_models
# Out:
#   adding: content/saved_models/ (stored 0%)
#   adding: content/saved_models/GIN_4: 0.9728889974796195.pt (deflated 30%)
#   adding: content/saved_models/GIN_13: 0.9946985859342194.pt (deflated 30%)
#   adding: content/saved_models/GIN_33: 0.9947998181870554.pt (deflated 30%)
#   adding: content/saved_models/GIN_8: 0.9938837111312823.pt (deflated 30%)
#   adding: content/saved_models/GIN_10: 0.9945922321424808.pt (deflated 30%)
#   adding: content/saved_models/GIN_12: 0.9946857004760895.pt (deflated 30%)
#   adding: content/saved_models/GIN_14: 0.9947302868510487.pt (deflated 30%)
#   adding: content/saved_models/GIN_32: 0.994788168005274.pt (deflated 30%)
#   adding: content/saved_models/GIN_5: 0.9896938810217616.pt (deflated 30%)
#   adding: content/saved_models/GIN_1: 0.9608694808579251.pt (deflated 31%)
#   adding: content/saved_models/GIN_31: 0.9947718507771564.pt (deflated 30%)
#   adding: content/saved_models/GIN_11: 0.9946274699306525.pt (deflated 30%)
#   adding: content/saved_models/GIN_0: 0.32583044865002125.pt (deflated 31%)

# %%
from google.colab import files
files.download("/content/GIN_053_18_Adam_P2P_6k_botnode.zip")
