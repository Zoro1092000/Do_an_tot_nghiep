# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/Do_an_tot_nghiep/blob/main/GIN_Adam_Chord.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Oct 25 14:05:33 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   29C    P0    47W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric==1.4.3
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5
# !pip install torch-optimizer

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter_
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset
import torch_optimizer as optimization


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric==1.4.3 in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.21.6)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (6.2.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.6.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.7.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.23.0)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.7.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.3.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.0.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.12.1+cu113)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.56.3)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.4)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.18.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->torch-geometric==1.4.3) (1.5.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (4.13.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (57.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (3.9.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2022.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.4.3) (1.15.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (0.6.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2022.9.24)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (3.2.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (1.3.0)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2.9.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (7.1.2)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2021.11.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (0.11.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-optimizer in /usr/local/lib/python3.7/dist-packages (0.3.0)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (0.1.1)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->torch-optimizer) (4.1.1)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
            self.num_graphs = 768
        elif split == 'val':
            self.path = self.processed_paths[1]
            self.num_graphs = 96
        elif split == 'test':
            self.path = self.processed_paths[2]
            self.num_graphs = 96

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GINConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_input_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU())))
          else:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU()))) 

        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                add_xr_at = n
            if n == add_xr_at:
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/Chord'
data_name = 'chord' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=True, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=True, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=True, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 2
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# !rm -rf /content/saved_models

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.0
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}_{result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    # class_weight = torch.Tensor([0.54, 7.15])
    # class_weight = class_weight.cuda(device=0)
    # criterion = torch.nn.CrossEntropyLoss(weight=class_weight)
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    # print(class_weight)
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-4c192f4d-3352-4e81-99af-fae39d108776.json
# ------------------------------
# ------------------------------
# Tue Oct 25 14:08:38 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GINConv(nn=Sequential(
#       (0): Linear(in_features=1, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (1): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (2): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (3): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (4): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (5): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (6): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (7): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (8): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (9): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (10): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (11): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 2
# epoch: 1, passed number of graphs: 96, train running loss: 0.14247 (passed time: 7s)
#           acc: 0.93079, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: 0.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 192, train running loss: 0.13050 (passed time: 12s)
#           acc: 0.93020, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 288, train running loss: 0.12051 (passed time: 16s)
#           acc: 0.93382, fpr: 0.00030, fnr: 0.95155, rec: 0.04845, prc: 0.92286, f1: 0.09207, f1_macro: 0.52886
# epoch: 1, passed number of graphs: 384, train running loss: 0.10630 (passed time: 21s)
#           acc: 0.97160, fpr: 0.00290, fnr: 0.36235, rec: 0.63765, prc: 0.94376, f1: 0.76108, f1_macro: 0.87299
# epoch: 1, passed number of graphs: 480, train running loss: 0.09132 (passed time: 25s)
#           acc: 0.99019, fpr: 0.00324, fnr: 0.09610, rec: 0.90390, prc: 0.95494, f1: 0.92872, f1_macro: 0.96173
# epoch: 1, passed number of graphs: 576, train running loss: 0.07878 (passed time: 29s)
#           acc: 0.99149, fpr: 0.00185, fnr: 0.09815, rec: 0.90185, prc: 0.97313, f1: 0.93614, f1_macro: 0.96579
# epoch: 1, passed number of graphs: 672, train running loss: 0.06968 (passed time: 34s)
#           acc: 0.99079, fpr: 0.00096, fnr: 0.12015, rec: 0.87985, prc: 0.98550, f1: 0.92968, f1_macro: 0.96238
# epoch: 1, passed number of graphs: 768, train running loss: 0.06309 (passed time: 38s)
#           acc: 0.99110, fpr: 0.00553, fnr: 0.05410, rec: 0.94590, prc: 0.92717, f1: 0.93644, f1_macro: 0.96583
# Validation --- epoch: 1, loss: 0.04251
#           prc: 0.97372, f1: 0.90214, acc: 0.98732, rec: 0.84042, fnr: 0.15958, f1_macro: 0.94768, fpr: 0.00170
# Better model saved at ./saved_models/GIN_0_0.9021373960268554.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.01525 (passed time: 46s)
#           acc: 0.99258, fpr: 0.00303, fnr: 0.06645, rec: 0.93355, prc: 0.95822, f1: 0.94573, f1_macro: 0.97087
# epoch: 2, passed number of graphs: 192, train running loss: 0.01272 (passed time: 51s)
#           acc: 0.99441, fpr: 0.00160, fnr: 0.05870, rec: 0.94130, prc: 0.97782, f1: 0.95921, f1_macro: 0.97811
# epoch: 2, passed number of graphs: 288, train running loss: 0.01073 (passed time: 55s)
#           acc: 0.99726, fpr: 0.00131, fnr: 0.02195, rec: 0.97805, prc: 0.98227, f1: 0.98016, f1_macro: 0.98934
# epoch: 2, passed number of graphs: 384, train running loss: 0.01246 (passed time: 59s)
#           acc: 0.94833, fpr: 0.00369, fnr: 0.67995, rec: 0.32005, prc: 0.86876, f1: 0.46777, f1_macro: 0.72031
# epoch: 2, passed number of graphs: 480, train running loss: 0.01209 (passed time: 1m 4s)
#           acc: 0.99712, fpr: 0.00122, fnr: 0.02465, rec: 0.97535, prc: 0.98381, f1: 0.97956, f1_macro: 0.98901
# epoch: 2, passed number of graphs: 576, train running loss: 0.01088 (passed time: 1m 8s)
#           acc: 0.99786, fpr: 0.00108, fnr: 0.01635, rec: 0.98365, prc: 0.98537, f1: 0.98451, f1_macro: 0.99168
# epoch: 2, passed number of graphs: 672, train running loss: 0.01174 (passed time: 1m 13s)
#           acc: 0.99373, fpr: 0.00234, fnr: 0.05915, rec: 0.94085, prc: 0.96760, f1: 0.95404, f1_macro: 0.97534
# epoch: 2, passed number of graphs: 768, train running loss: 0.01114 (passed time: 1m 17s)
#           acc: 0.99740, fpr: 0.00134, fnr: 0.01960, rec: 0.98040, prc: 0.98202, f1: 0.98121, f1_macro: 0.98991
# Validation --- epoch: 2, loss: 0.01206
#           prc: 0.98126, f1: 0.97207, acc: 0.99615, rec: 0.96309, fnr: 0.03691, f1_macro: 0.98500, fpr: 0.00138
# Better model saved at ./saved_models/GIN_1_0.9720732230849038.pt.
# epoch: 3, passed number of graphs: 96, train running loss: 0.00968 (passed time: 1m 25s)
#           acc: 0.98900, fpr: 0.00200, fnr: 0.13195, rec: 0.86805, prc: 0.96989, f1: 0.91615, f1_macro: 0.95513
# epoch: 3, passed number of graphs: 192, train running loss: 0.03684 (passed time: 1m 29s)
#           acc: 0.97815, fpr: 0.00328, fnr: 0.26940, rec: 0.73060, prc: 0.94356, f1: 0.82354, f1_macro: 0.90594
# epoch: 3, passed number of graphs: 288, train running loss: 0.03124 (passed time: 1m 34s)
#           acc: 0.99151, fpr: 0.00423, fnr: 0.06575, rec: 0.93425, prc: 0.94259, f1: 0.93840, f1_macro: 0.96692
# epoch: 3, passed number of graphs: 384, train running loss: 0.02649 (passed time: 1m 38s)
#           acc: 0.99253, fpr: 0.00557, fnr: 0.03230, rec: 0.96770, prc: 0.92985, f1: 0.94840, f1_macro: 0.97219
# epoch: 3, passed number of graphs: 480, train running loss: 0.02332 (passed time: 1m 43s)
#           acc: 0.99368, fpr: 0.00376, fnr: 0.03995, rec: 0.96005, prc: 0.95097, f1: 0.95549, f1_macro: 0.97604
# epoch: 3, passed number of graphs: 576, train running loss: 0.02249 (passed time: 1m 47s)
#           acc: 0.99036, fpr: 0.00486, fnr: 0.07390, rec: 0.92610, prc: 0.93395, f1: 0.93001, f1_macro: 0.96242
# epoch: 3, passed number of graphs: 672, train running loss: 0.02074 (passed time: 1m 51s)
#           acc: 0.99456, fpr: 0.00323, fnr: 0.03525, rec: 0.96475, prc: 0.95695, f1: 0.96083, f1_macro: 0.97896
# epoch: 3, passed number of graphs: 768, train running loss: 0.01908 (passed time: 1m 56s)
#           acc: 0.99545, fpr: 0.00271, fnr: 0.02925, rec: 0.97075, prc: 0.96386, f1: 0.96729, f1_macro: 0.98242
# Validation --- epoch: 3, loss: 0.01754
#           prc: 0.98027, f1: 0.95744, acc: 0.99421, rec: 0.93567, fnr: 0.06433, f1_macro: 0.97717, fpr: 0.00141
# epoch: 4, passed number of graphs: 96, train running loss: 0.00792 (passed time: 2m 4s)
#           acc: 0.99576, fpr: 0.00215, fnr: 0.03235, rec: 0.96765, prc: 0.97100, f1: 0.96932, f1_macro: 0.98352
# epoch: 4, passed number of graphs: 192, train running loss: 0.00911 (passed time: 2m 8s)
#           acc: 0.99297, fpr: 0.00107, fnr: 0.08655, rec: 0.91345, prc: 0.98469, f1: 0.94773, f1_macro: 0.97198
# epoch: 4, passed number of graphs: 288, train running loss: 0.00903 (passed time: 2m 12s)
#           acc: 0.99590, fpr: 0.00157, fnr: 0.03810, rec: 0.96190, prc: 0.97854, f1: 0.97015, f1_macro: 0.98397
# epoch: 4, passed number of graphs: 384, train running loss: 0.01260 (passed time: 2m 17s)
#           acc: 0.98996, fpr: 0.00573, fnr: 0.06655, rec: 0.93345, prc: 0.92563, f1: 0.92952, f1_macro: 0.96206
# epoch: 4, passed number of graphs: 480, train running loss: 0.01206 (passed time: 2m 21s)
#           acc: 0.99525, fpr: 0.00297, fnr: 0.02820, rec: 0.97180, prc: 0.96142, f1: 0.96658, f1_macro: 0.98201
# epoch: 4, passed number of graphs: 576, train running loss: 0.01260 (passed time: 2m 26s)
#           acc: 0.99386, fpr: 0.00283, fnr: 0.05070, rec: 0.94930, prc: 0.96141, f1: 0.95532, f1_macro: 0.97601
# epoch: 4, passed number of graphs: 672, train running loss: 0.01199 (passed time: 2m 30s)
#           acc: 0.99578, fpr: 0.00235, fnr: 0.02930, rec: 0.97070, prc: 0.96842, f1: 0.96956, f1_macro: 0.98365
# epoch: 4, passed number of graphs: 768, train running loss: 0.01136 (passed time: 2m 35s)
#           acc: 0.99667, fpr: 0.00109, fnr: 0.03330, rec: 0.96670, prc: 0.98502, f1: 0.97577, f1_macro: 0.98699
# Validation --- epoch: 4, loss: 0.01250
#           prc: 0.98546, f1: 0.97353, acc: 0.99636, rec: 0.96189, fnr: 0.03811, f1_macro: 0.98579, fpr: 0.00106
# Better model saved at ./saved_models/GIN_3_0.9735259244880883.pt.
# epoch: 5, passed number of graphs: 96, train running loss: 0.00567 (passed time: 2m 42s)
#           acc: 0.99678, fpr: 0.00091, fnr: 0.03425, rec: 0.96575, prc: 0.98747, f1: 0.97649, f1_macro: 0.98738
# epoch: 5, passed number of graphs: 192, train running loss: 0.00540 (passed time: 2m 47s)
#           acc: 0.99750, fpr: 0.00081, fnr: 0.02510, rec: 0.97490, prc: 0.98909, f1: 0.98195, f1_macro: 0.99030
# epoch: 5, passed number of graphs: 288, train running loss: 0.00509 (passed time: 2m 51s)
#           acc: 0.99786, fpr: 0.00092, fnr: 0.01855, rec: 0.98145, prc: 0.98752, f1: 0.98448, f1_macro: 0.99166
# epoch: 5, passed number of graphs: 384, train running loss: 0.00483 (passed time: 2m 56s)
#           acc: 0.99762, fpr: 0.00100, fnr: 0.02045, rec: 0.97955, prc: 0.98675, f1: 0.98314, f1_macro: 0.99093
# epoch: 5, passed number of graphs: 480, train running loss: 0.00460 (passed time: 3m 0s)
#           acc: 0.99818, fpr: 0.00054, fnr: 0.01865, rec: 0.98135, prc: 0.99277, f1: 0.98703, f1_macro: 0.99302
# epoch: 5, passed number of graphs: 576, train running loss: 0.00458 (passed time: 3m 5s)
#           acc: 0.99768, fpr: 0.00124, fnr: 0.01685, rec: 0.98315, prc: 0.98330, f1: 0.98322, f1_macro: 0.99099
# epoch: 5, passed number of graphs: 672, train running loss: 0.00453 (passed time: 3m 9s)
#           acc: 0.99791, fpr: 0.00095, fnr: 0.01750, rec: 0.98250, prc: 0.98719, f1: 0.98484, f1_macro: 0.99186
# epoch: 5, passed number of graphs: 768, train running loss: 0.00441 (passed time: 3m 13s)
#           acc: 0.99805, fpr: 0.00104, fnr: 0.01430, rec: 0.98570, prc: 0.98609, f1: 0.98590, f1_macro: 0.99242
# Validation --- epoch: 5, loss: 0.00683
#           prc: 0.98915, f1: 0.98628, acc: 0.99810, rec: 0.98345, fnr: 0.01655, f1_macro: 0.99263, fpr: 0.00081
# Better model saved at ./saved_models/GIN_4_0.9862823908498309.pt.
# epoch: 6, passed number of graphs: 96, train running loss: 0.00383 (passed time: 3m 21s)
#           acc: 0.99624, fpr: 0.00154, fnr: 0.03375, rec: 0.96625, prc: 0.97908, f1: 0.97262, f1_macro: 0.98530
# epoch: 6, passed number of graphs: 192, train running loss: 0.00947 (passed time: 3m 26s)
#           acc: 0.99509, fpr: 0.00186, fnr: 0.04550, rec: 0.95450, prc: 0.97463, f1: 0.96446, f1_macro: 0.98091
# epoch: 6, passed number of graphs: 288, train running loss: 0.00891 (passed time: 3m 30s)
#           acc: 0.99704, fpr: 0.00142, fnr: 0.02365, rec: 0.97635, prc: 0.98076, f1: 0.97855, f1_macro: 0.98848
# epoch: 6, passed number of graphs: 384, train running loss: 0.00799 (passed time: 3m 34s)
#           acc: 0.99693, fpr: 0.00174, fnr: 0.02050, rec: 0.97950, prc: 0.97730, f1: 0.97840, f1_macro: 0.98837
# epoch: 6, passed number of graphs: 480, train running loss: 0.00724 (passed time: 3m 39s)
#           acc: 0.99787, fpr: 0.00097, fnr: 0.01750, rec: 0.98250, prc: 0.98724, f1: 0.98486, f1_macro: 0.99186
# epoch: 6, passed number of graphs: 576, train running loss: 0.00671 (passed time: 3m 43s)
#           acc: 0.99788, fpr: 0.00111, fnr: 0.01570, rec: 0.98430, prc: 0.98499, f1: 0.98464, f1_macro: 0.99175
# epoch: 6, passed number of graphs: 672, train running loss: 0.00629 (passed time: 3m 48s)
#           acc: 0.99810, fpr: 0.00074, fnr: 0.01755, rec: 0.98245, prc: 0.98997, f1: 0.98620, f1_macro: 0.99259
# epoch: 6, passed number of graphs: 768, train running loss: 0.00594 (passed time: 3m 52s)
#           acc: 0.99823, fpr: 0.00080, fnr: 0.01475, rec: 0.98525, prc: 0.98921, f1: 0.98722, f1_macro: 0.99314
# Validation --- epoch: 6, loss: 0.00807
#           prc: 0.98296, f1: 0.98400, acc: 0.99775, rec: 0.98524, fnr: 0.01476, f1_macro: 0.99140, fpr: 0.00131
# epoch: 7, passed number of graphs: 96, train running loss: 0.00341 (passed time: 4m 0s)
#           acc: 0.99822, fpr: 0.00055, fnr: 0.01825, rec: 0.98175, prc: 0.99247, f1: 0.98708, f1_macro: 0.99306
# epoch: 7, passed number of graphs: 192, train running loss: 0.00390 (passed time: 4m 4s)
#           acc: 0.99792, fpr: 0.00062, fnr: 0.02145, rec: 0.97855, prc: 0.99159, f1: 0.98503, f1_macro: 0.99196
# epoch: 7, passed number of graphs: 288, train running loss: 0.00378 (passed time: 4m 9s)
#           acc: 0.99831, fpr: 0.00056, fnr: 0.01680, rec: 0.98320, prc: 0.99238, f1: 0.98777, f1_macro: 0.99343
# epoch: 7, passed number of graphs: 384, train running loss: 0.00376 (passed time: 4m 13s)
#           acc: 0.99665, fpr: 0.00039, fnr: 0.04210, rec: 0.95790, prc: 0.99470, f1: 0.97596, f1_macro: 0.98708
# epoch: 7, passed number of graphs: 480, train running loss: 0.00374 (passed time: 4m 18s)
#           acc: 0.99846, fpr: 0.00039, fnr: 0.01675, rec: 0.98325, prc: 0.99484, f1: 0.98901, f1_macro: 0.99409
# epoch: 7, passed number of graphs: 576, train running loss: 0.00365 (passed time: 4m 22s)
#           acc: 0.99860, fpr: 0.00054, fnr: 0.01295, rec: 0.98705, prc: 0.99271, f1: 0.98987, f1_macro: 0.99456
# epoch: 7, passed number of graphs: 672, train running loss: 0.00358 (passed time: 4m 27s)
#           acc: 0.99812, fpr: 0.00088, fnr: 0.01520, rec: 0.98480, prc: 0.98806, f1: 0.98643, f1_macro: 0.99271
# epoch: 7, passed number of graphs: 768, train running loss: 0.00387 (passed time: 4m 31s)
#           acc: 0.99787, fpr: 0.00086, fnr: 0.01915, rec: 0.98085, prc: 0.98831, f1: 0.98457, f1_macro: 0.99171
# Validation --- epoch: 7, loss: 0.00901
#           prc: 0.99257, f1: 0.98425, acc: 0.99783, rec: 0.97607, fnr: 0.02393, f1_macro: 0.99154, fpr: 0.00055
# epoch: 8, passed number of graphs: 96, train running loss: 0.00410 (passed time: 4m 39s)
#           acc: 0.99808, fpr: 0.00097, fnr: 0.01470, rec: 0.98530, prc: 0.98688, f1: 0.98609, f1_macro: 0.99253
# epoch: 8, passed number of graphs: 192, train running loss: 0.00390 (passed time: 4m 43s)
#           acc: 0.99813, fpr: 0.00075, fnr: 0.01675, rec: 0.98325, prc: 0.98993, f1: 0.98658, f1_macro: 0.99279
# epoch: 8, passed number of graphs: 288, train running loss: 0.00378 (passed time: 4m 48s)
#           acc: 0.99823, fpr: 0.00077, fnr: 0.01520, rec: 0.98480, prc: 0.98960, f1: 0.98719, f1_macro: 0.99312
# epoch: 8, passed number of graphs: 384, train running loss: 0.00369 (passed time: 4m 52s)
#           acc: 0.99783, fpr: 0.00106, fnr: 0.01670, rec: 0.98330, prc: 0.98611, f1: 0.98470, f1_macro: 0.99177
# epoch: 8, passed number of graphs: 480, train running loss: 0.00361 (passed time: 4m 56s)
#           acc: 0.99845, fpr: 0.00054, fnr: 0.01485, rec: 0.98515, prc: 0.99279, f1: 0.98896, f1_macro: 0.99406
# epoch: 8, passed number of graphs: 576, train running loss: 0.00356 (passed time: 5m 1s)
#           acc: 0.99855, fpr: 0.00054, fnr: 0.01370, rec: 0.98630, prc: 0.99265, f1: 0.98947, f1_macro: 0.99434
# epoch: 8, passed number of graphs: 672, train running loss: 0.00351 (passed time: 5m 5s)
#           acc: 0.99825, fpr: 0.00082, fnr: 0.01430, rec: 0.98570, prc: 0.98896, f1: 0.98733, f1_macro: 0.99319
# epoch: 8, passed number of graphs: 768, train running loss: 0.00346 (passed time: 5m 10s)
#           acc: 0.99834, fpr: 0.00072, fnr: 0.01425, rec: 0.98575, prc: 0.99026, f1: 0.98800, f1_macro: 0.99355
# Validation --- epoch: 8, loss: 0.00622
#           prc: 0.99314, f1: 0.98864, acc: 0.99843, rec: 0.98418, fnr: 0.01583, f1_macro: 0.99390, fpr: 0.00051
# Better model saved at ./saved_models/GIN_7_0.9886357809564109.pt.
# epoch: 9, passed number of graphs: 96, train running loss: 0.00308 (passed time: 5m 18s)
#           acc: 0.99836, fpr: 0.00061, fnr: 0.01555, rec: 0.98445, prc: 0.99174, f1: 0.98808, f1_macro: 0.99360
# epoch: 9, passed number of graphs: 192, train running loss: 0.00315 (passed time: 5m 22s)
#           acc: 0.99808, fpr: 0.00089, fnr: 0.01575, rec: 0.98425, prc: 0.98815, f1: 0.98620, f1_macro: 0.99258
# epoch: 9, passed number of graphs: 288, train running loss: 0.00312 (passed time: 5m 26s)
#           acc: 0.99846, fpr: 0.00056, fnr: 0.01480, rec: 0.98520, prc: 0.99244, f1: 0.98881, f1_macro: 0.99399
# epoch: 9, passed number of graphs: 384, train running loss: 0.00310 (passed time: 5m 31s)
#           acc: 0.99811, fpr: 0.00090, fnr: 0.01480, rec: 0.98520, prc: 0.98816, f1: 0.98668, f1_macro: 0.99283
# epoch: 9, passed number of graphs: 480, train running loss: 0.00307 (passed time: 5m 35s)
#           acc: 0.99869, fpr: 0.00039, fnr: 0.01340, rec: 0.98660, prc: 0.99486, f1: 0.99071, f1_macro: 0.99500
# epoch: 9, passed number of graphs: 576, train running loss: 0.00307 (passed time: 5m 40s)
#           acc: 0.99874, fpr: 0.00036, fnr: 0.01350, rec: 0.98650, prc: 0.99516, f1: 0.99081, f1_macro: 0.99507
# epoch: 9, passed number of graphs: 672, train running loss: 0.00308 (passed time: 5m 44s)
#           acc: 0.99846, fpr: 0.00053, fnr: 0.01520, rec: 0.98480, prc: 0.99284, f1: 0.98880, f1_macro: 0.99399
# epoch: 9, passed number of graphs: 768, train running loss: 0.00306 (passed time: 5m 49s)
#           acc: 0.99848, fpr: 0.00063, fnr: 0.01360, rec: 0.98640, prc: 0.99156, f1: 0.98897, f1_macro: 0.99408
# Validation --- epoch: 9, loss: 0.00581
#           prc: 0.99279, f1: 0.98912, acc: 0.99849, rec: 0.98548, fnr: 0.01452, f1_macro: 0.99415, fpr: 0.00054
# Better model saved at ./saved_models/GIN_8_0.9891156608819275.pt.
# epoch: 10, passed number of graphs: 96, train running loss: 0.00302 (passed time: 5m 56s)
#           acc: 0.99820, fpr: 0.00096, fnr: 0.01305, rec: 0.98695, prc: 0.98710, f1: 0.98702, f1_macro: 0.99303
# epoch: 10, passed number of graphs: 192, train running loss: 0.00300 (passed time: 6m 1s)
#           acc: 0.99843, fpr: 0.00060, fnr: 0.01450, rec: 0.98550, prc: 0.99190, f1: 0.98869, f1_macro: 0.99392
# epoch: 10, passed number of graphs: 288, train running loss: 0.00295 (passed time: 6m 5s)
#           acc: 0.99855, fpr: 0.00047, fnr: 0.01470, rec: 0.98530, prc: 0.99365, f1: 0.98946, f1_macro: 0.99434
# epoch: 10, passed number of graphs: 384, train running loss: 0.00293 (passed time: 6m 10s)
#           acc: 0.99819, fpr: 0.00079, fnr: 0.01505, rec: 0.98495, prc: 0.98955, f1: 0.98725, f1_macro: 0.99314
# epoch: 10, passed number of graphs: 480, train running loss: 0.00291 (passed time: 6m 14s)
#           acc: 0.99863, fpr: 0.00041, fnr: 0.01400, rec: 0.98600, prc: 0.99460, f1: 0.99028, f1_macro: 0.99477
# epoch: 10, passed number of graphs: 576, train running loss: 0.00298 (passed time: 6m 18s)
#           acc: 0.99880, fpr: 0.00038, fnr: 0.01215, rec: 0.98785, prc: 0.99481, f1: 0.99132, f1_macro: 0.99534
# epoch: 10, passed number of graphs: 672, train running loss: 0.00298 (passed time: 6m 23s)
#           acc: 0.99850, fpr: 0.00055, fnr: 0.01420, rec: 0.98580, prc: 0.99250, f1: 0.98914, f1_macro: 0.99417
# epoch: 10, passed number of graphs: 768, train running loss: 0.00295 (passed time: 6m 27s)
#           acc: 0.99855, fpr: 0.00055, fnr: 0.01350, rec: 0.98650, prc: 0.99260, f1: 0.98954, f1_macro: 0.99438
# Validation --- epoch: 10, loss: 0.00550
#           prc: 0.99348, f1: 0.98972, acc: 0.99857, rec: 0.98599, fnr: 0.01401, f1_macro: 0.99447, fpr: 0.00049
# Better model saved at ./saved_models/GIN_9_0.9897156681718408.pt.
# epoch: 11, passed number of graphs: 96, train running loss: 0.00278 (passed time: 6m 35s)
#           acc: 0.99849, fpr: 0.00064, fnr: 0.01320, rec: 0.98680, prc: 0.99131, f1: 0.98905, f1_macro: 0.99412
# epoch: 11, passed number of graphs: 192, train running loss: 0.00283 (passed time: 6m 40s)
#           acc: 0.99855, fpr: 0.00037, fnr: 0.01580, rec: 0.98420, prc: 0.99500, f1: 0.98957, f1_macro: 0.99440
# epoch: 11, passed number of graphs: 288, train running loss: 0.00299 (passed time: 6m 44s)
#           acc: 0.99820, fpr: 0.00078, fnr: 0.01550, rec: 0.98450, prc: 0.98945, f1: 0.98697, f1_macro: 0.99300
# epoch: 11, passed number of graphs: 384, train running loss: 0.00295 (passed time: 6m 48s)
#           acc: 0.99817, fpr: 0.00090, fnr: 0.01400, rec: 0.98600, prc: 0.98812, f1: 0.98706, f1_macro: 0.99304
# epoch: 11, passed number of graphs: 480, train running loss: 0.00292 (passed time: 6m 53s)
#           acc: 0.99867, fpr: 0.00040, fnr: 0.01360, rec: 0.98640, prc: 0.99471, f1: 0.99054, f1_macro: 0.99491
# epoch: 11, passed number of graphs: 576, train running loss: 0.00301 (passed time: 6m 57s)
#           acc: 0.99862, fpr: 0.00045, fnr: 0.01400, rec: 0.98600, prc: 0.99395, f1: 0.98996, f1_macro: 0.99461
# epoch: 11, passed number of graphs: 672, train running loss: 0.00309 (passed time: 7m 2s)
#           acc: 0.99796, fpr: 0.00123, fnr: 0.01290, rec: 0.98710, prc: 0.98346, f1: 0.98528, f1_macro: 0.99209
# epoch: 11, passed number of graphs: 768, train running loss: 0.00311 (passed time: 7m 6s)
#           acc: 0.99836, fpr: 0.00078, fnr: 0.01315, rec: 0.98685, prc: 0.98947, f1: 0.98816, f1_macro: 0.99364
# Validation --- epoch: 11, loss: 0.00613
#           prc: 0.99058, f1: 0.98840, acc: 0.99839, rec: 0.98624, fnr: 0.01376, f1_macro: 0.99377, fpr: 0.00070
# epoch: 12, passed number of graphs: 96, train running loss: 0.00296 (passed time: 7m 14s)
#           acc: 0.99848, fpr: 0.00045, fnr: 0.01600, rec: 0.98400, prc: 0.99394, f1: 0.98894, f1_macro: 0.99406
# epoch: 12, passed number of graphs: 192, train running loss: 0.00292 (passed time: 7m 18s)
#           acc: 0.99853, fpr: 0.00032, fnr: 0.01685, rec: 0.98315, prc: 0.99570, f1: 0.98938, f1_macro: 0.99430
# epoch: 12, passed number of graphs: 288, train running loss: 0.00290 (passed time: 7m 23s)
#           acc: 0.99863, fpr: 0.00047, fnr: 0.01345, rec: 0.98655, prc: 0.99360, f1: 0.99006, f1_macro: 0.99466
# epoch: 12, passed number of graphs: 384, train running loss: 0.00285 (passed time: 7m 27s)
#           acc: 0.99834, fpr: 0.00056, fnr: 0.01600, rec: 0.98400, prc: 0.99259, f1: 0.98827, f1_macro: 0.99369
# epoch: 12, passed number of graphs: 480, train running loss: 0.00284 (passed time: 7m 32s)
#           acc: 0.99865, fpr: 0.00029, fnr: 0.01525, rec: 0.98475, prc: 0.99611, f1: 0.99040, f1_macro: 0.99483
# epoch: 12, passed number of graphs: 576, train running loss: 0.00285 (passed time: 7m 36s)
#           acc: 0.99880, fpr: 0.00024, fnr: 0.01405, rec: 0.98595, prc: 0.99671, f1: 0.99130, f1_macro: 0.99533
# epoch: 12, passed number of graphs: 672, train running loss: 0.00300 (passed time: 7m 40s)
#           acc: 0.99809, fpr: 0.00039, fnr: 0.02230, rec: 0.97770, prc: 0.99466, f1: 0.98611, f1_macro: 0.99254
# epoch: 12, passed number of graphs: 768, train running loss: 0.00304 (passed time: 7m 45s)
#           acc: 0.99830, fpr: 0.00079, fnr: 0.01390, rec: 0.98610, prc: 0.98936, f1: 0.98773, f1_macro: 0.99341
# Validation --- epoch: 12, loss: 0.00639
#           prc: 0.99440, f1: 0.98816, acc: 0.99836, rec: 0.98200, fnr: 0.01800, f1_macro: 0.99364, fpr: 0.00041
# epoch: 13, passed number of graphs: 96, train running loss: 0.00315 (passed time: 7m 53s)
#           acc: 0.99841, fpr: 0.00075, fnr: 0.01285, rec: 0.98715, prc: 0.98982, f1: 0.98848, f1_macro: 0.99381
# epoch: 13, passed number of graphs: 192, train running loss: 0.00309 (passed time: 7m 57s)
#           acc: 0.99833, fpr: 0.00051, fnr: 0.01705, rec: 0.98295, prc: 0.99308, f1: 0.98799, f1_macro: 0.99355
# epoch: 13, passed number of graphs: 288, train running loss: 0.00305 (passed time: 8m 1s)
#           acc: 0.99849, fpr: 0.00063, fnr: 0.01340, rec: 0.98660, prc: 0.99156, f1: 0.98907, f1_macro: 0.99413
# epoch: 13, passed number of graphs: 384, train running loss: 0.00302 (passed time: 8m 6s)
#           acc: 0.99819, fpr: 0.00066, fnr: 0.01680, rec: 0.98320, prc: 0.99123, f1: 0.98720, f1_macro: 0.99311
# epoch: 13, passed number of graphs: 480, train running loss: 0.00303 (passed time: 8m 10s)
#           acc: 0.99858, fpr: 0.00041, fnr: 0.01470, rec: 0.98530, prc: 0.99455, f1: 0.98990, f1_macro: 0.99457
# epoch: 13, passed number of graphs: 576, train running loss: 0.00304 (passed time: 8m 15s)
#           acc: 0.99879, fpr: 0.00042, fnr: 0.01180, rec: 0.98820, prc: 0.99427, f1: 0.99122, f1_macro: 0.99529
# epoch: 13, passed number of graphs: 672, train running loss: 0.00304 (passed time: 8m 19s)
#           acc: 0.99849, fpr: 0.00048, fnr: 0.01535, rec: 0.98465, prc: 0.99344, f1: 0.98903, f1_macro: 0.99411
# epoch: 13, passed number of graphs: 768, train running loss: 0.00302 (passed time: 8m 24s)
#           acc: 0.99853, fpr: 0.00056, fnr: 0.01365, rec: 0.98635, prc: 0.99245, f1: 0.98939, f1_macro: 0.99430
# Validation --- epoch: 13, loss: 0.00558
#           prc: 0.99474, f1: 0.98962, acc: 0.99856, rec: 0.98456, fnr: 0.01544, f1_macro: 0.99442, fpr: 0.00039
# epoch: 14, passed number of graphs: 96, train running loss: 0.00292 (passed time: 8m 31s)
#           acc: 0.99857, fpr: 0.00068, fnr: 0.01150, rec: 0.98850, prc: 0.99083, f1: 0.98966, f1_macro: 0.99445
# epoch: 14, passed number of graphs: 192, train running loss: 0.00297 (passed time: 8m 36s)
#           acc: 0.99842, fpr: 0.00039, fnr: 0.01745, rec: 0.98255, prc: 0.99479, f1: 0.98863, f1_macro: 0.99389
# epoch: 14, passed number of graphs: 288, train running loss: 0.00291 (passed time: 8m 40s)
#           acc: 0.99859, fpr: 0.00051, fnr: 0.01345, rec: 0.98655, prc: 0.99310, f1: 0.98982, f1_macro: 0.99453
# epoch: 14, passed number of graphs: 384, train running loss: 0.00285 (passed time: 8m 45s)
#           acc: 0.99834, fpr: 0.00068, fnr: 0.01455, rec: 0.98545, prc: 0.99110, f1: 0.98827, f1_macro: 0.99369
# epoch: 14, passed number of graphs: 480, train running loss: 0.00281 (passed time: 8m 49s)
#           acc: 0.99876, fpr: 0.00030, fnr: 0.01355, rec: 0.98645, prc: 0.99596, f1: 0.99118, f1_macro: 0.99526
# epoch: 14, passed number of graphs: 576, train running loss: 0.00279 (passed time: 8m 53s)
#           acc: 0.99892, fpr: 0.00025, fnr: 0.01220, rec: 0.98780, prc: 0.99657, f1: 0.99217, f1_macro: 0.99579
# epoch: 14, passed number of graphs: 672, train running loss: 0.00277 (passed time: 8m 58s)
#           acc: 0.99853, fpr: 0.00057, fnr: 0.01360, rec: 0.98640, prc: 0.99230, f1: 0.98934, f1_macro: 0.99428
# epoch: 14, passed number of graphs: 768, train running loss: 0.00275 (passed time: 9m 2s)
#           acc: 0.99867, fpr: 0.00043, fnr: 0.01335, rec: 0.98665, prc: 0.99416, f1: 0.99039, f1_macro: 0.99484
# Validation --- epoch: 14, loss: 0.00519
#           prc: 0.99459, f1: 0.99039, acc: 0.99867, rec: 0.98622, fnr: 0.01378, f1_macro: 0.99484, fpr: 0.00040
# Better model saved at ./saved_models/GIN_13_0.9903894324405815.pt.
# epoch: 15, passed number of graphs: 96, train running loss: 0.00261 (passed time: 9m 10s)
#           acc: 0.99871, fpr: 0.00043, fnr: 0.01285, rec: 0.98715, prc: 0.99421, f1: 0.99067, f1_macro: 0.99499
# epoch: 15, passed number of graphs: 192, train running loss: 0.00264 (passed time: 9m 15s)
#           acc: 0.99863, fpr: 0.00037, fnr: 0.01480, rec: 0.98520, prc: 0.99505, f1: 0.99010, f1_macro: 0.99468
# epoch: 15, passed number of graphs: 288, train running loss: 0.00263 (passed time: 9m 19s)
#           acc: 0.99865, fpr: 0.00044, fnr: 0.01360, rec: 0.98640, prc: 0.99405, f1: 0.99021, f1_macro: 0.99474
# epoch: 15, passed number of graphs: 384, train running loss: 0.00262 (passed time: 9m 23s)
#           acc: 0.99845, fpr: 0.00053, fnr: 0.01495, rec: 0.98505, prc: 0.99299, f1: 0.98901, f1_macro: 0.99409
# epoch: 15, passed number of graphs: 480, train running loss: 0.00262 (passed time: 9m 28s)
#           acc: 0.99871, fpr: 0.00037, fnr: 0.01330, rec: 0.98670, prc: 0.99506, f1: 0.99086, f1_macro: 0.99508
# epoch: 15, passed number of graphs: 576, train running loss: 0.00263 (passed time: 9m 32s)
#           acc: 0.99893, fpr: 0.00025, fnr: 0.01220, rec: 0.98780, prc: 0.99667, f1: 0.99222, f1_macro: 0.99582
# epoch: 15, passed number of graphs: 672, train running loss: 0.00262 (passed time: 9m 37s)
#           acc: 0.99858, fpr: 0.00049, fnr: 0.01390, rec: 0.98610, prc: 0.99330, f1: 0.98969, f1_macro: 0.99446
# epoch: 15, passed number of graphs: 768, train running loss: 0.00262 (passed time: 9m 41s)
#           acc: 0.99866, fpr: 0.00048, fnr: 0.01285, rec: 0.98715, prc: 0.99351, f1: 0.99032, f1_macro: 0.99480
# Validation --- epoch: 15, loss: 0.00514
#           prc: 0.99356, f1: 0.99021, acc: 0.99864, rec: 0.98689, fnr: 0.01311, f1_macro: 0.99474, fpr: 0.00048
# epoch: 16, passed number of graphs: 96, train running loss: 0.00259 (passed time: 9m 49s)
#           acc: 0.99870, fpr: 0.00037, fnr: 0.01390, rec: 0.98610, prc: 0.99501, f1: 0.99053, f1_macro: 0.99492
# epoch: 16, passed number of graphs: 192, train running loss: 0.00261 (passed time: 9m 53s)
#           acc: 0.99865, fpr: 0.00024, fnr: 0.01615, rec: 0.98385, prc: 0.99671, f1: 0.99024, f1_macro: 0.99475
# epoch: 16, passed number of graphs: 288, train running loss: 0.00260 (passed time: 9m 58s)
#           acc: 0.99863, fpr: 0.00046, fnr: 0.01360, rec: 0.98640, prc: 0.99380, f1: 0.99009, f1_macro: 0.99468
# epoch: 16, passed number of graphs: 384, train running loss: 0.00259 (passed time: 10m 2s)
#           acc: 0.99847, fpr: 0.00049, fnr: 0.01505, rec: 0.98495, prc: 0.99349, f1: 0.98920, f1_macro: 0.99419
# epoch: 16, passed number of graphs: 480, train running loss: 0.00258 (passed time: 10m 7s)
#           acc: 0.99877, fpr: 0.00033, fnr: 0.01300, rec: 0.98700, prc: 0.99556, f1: 0.99126, f1_macro: 0.99530
# epoch: 16, passed number of graphs: 576, train running loss: 0.00259 (passed time: 10m 11s)
#           acc: 0.99894, fpr: 0.00026, fnr: 0.01185, rec: 0.98815, prc: 0.99642, f1: 0.99227, f1_macro: 0.99585
# epoch: 16, passed number of graphs: 672, train running loss: 0.00259 (passed time: 10m 15s)
#           acc: 0.99860, fpr: 0.00043, fnr: 0.01440, rec: 0.98560, prc: 0.99415, f1: 0.98986, f1_macro: 0.99455
# epoch: 16, passed number of graphs: 768, train running loss: 0.00258 (passed time: 10m 20s)
#           acc: 0.99871, fpr: 0.00042, fnr: 0.01295, rec: 0.98705, prc: 0.99436, f1: 0.99069, f1_macro: 0.99500
# Validation --- epoch: 16, loss: 0.00504
#           prc: 0.99455, f1: 0.99061, acc: 0.99870, rec: 0.98670, fnr: 0.01330, f1_macro: 0.99496, fpr: 0.00040
# Better model saved at ./saved_models/GIN_15_0.9906092022031939.pt.
# epoch: 17, passed number of graphs: 96, train running loss: 0.00258 (passed time: 10m 28s)
#           acc: 0.99872, fpr: 0.00037, fnr: 0.01360, rec: 0.98640, prc: 0.99501, f1: 0.99068, f1_macro: 0.99500
# epoch: 17, passed number of graphs: 192, train running loss: 0.00266 (passed time: 10m 32s)
#           acc: 0.99857, fpr: 0.00025, fnr: 0.01720, rec: 0.98280, prc: 0.99665, f1: 0.98968, f1_macro: 0.99445
# epoch: 17, passed number of graphs: 288, train running loss: 0.00264 (passed time: 10m 37s)
#           acc: 0.99867, fpr: 0.00042, fnr: 0.01345, rec: 0.98655, prc: 0.99426, f1: 0.99039, f1_macro: 0.99484
# epoch: 17, passed number of graphs: 384, train running loss: 0.00262 (passed time: 10m 41s)
#           acc: 0.99848, fpr: 0.00049, fnr: 0.01500, rec: 0.98500, prc: 0.99349, f1: 0.98923, f1_macro: 0.99421
# epoch: 17, passed number of graphs: 480, train running loss: 0.00260 (passed time: 10m 45s)
#           acc: 0.99878, fpr: 0.00029, fnr: 0.01340, rec: 0.98660, prc: 0.99611, f1: 0.99133, f1_macro: 0.99534
# epoch: 17, passed number of graphs: 576, train running loss: 0.00261 (passed time: 10m 50s)
#           acc: 0.99894, fpr: 0.00025, fnr: 0.01200, rec: 0.98800, prc: 0.99662, f1: 0.99229, f1_macro: 0.99586
# epoch: 17, passed number of graphs: 672, train running loss: 0.00271 (passed time: 10m 54s)
#           acc: 0.99851, fpr: 0.00051, fnr: 0.01470, rec: 0.98530, prc: 0.99305, f1: 0.98916, f1_macro: 0.99418
# epoch: 17, passed number of graphs: 768, train running loss: 0.00276 (passed time: 10m 59s)
#           acc: 0.99866, fpr: 0.00042, fnr: 0.01380, rec: 0.98620, prc: 0.99435, f1: 0.99026, f1_macro: 0.99477
# Validation --- epoch: 17, loss: 0.00551
#           prc: 0.99470, f1: 0.99006, acc: 0.99862, rec: 0.98547, fnr: 0.01453, f1_macro: 0.99466, fpr: 0.00039
# epoch: 18, passed number of graphs: 96, train running loss: 0.00270 (passed time: 11m 6s)
#           acc: 0.99867, fpr: 0.00050, fnr: 0.01240, rec: 0.98760, prc: 0.99321, f1: 0.99040, f1_macro: 0.99484
# epoch: 18, passed number of graphs: 192, train running loss: 0.00265 (passed time: 11m 11s)
#           acc: 0.99866, fpr: 0.00035, fnr: 0.01445, rec: 0.98555, prc: 0.99525, f1: 0.99038, f1_macro: 0.99483
# epoch: 18, passed number of graphs: 288, train running loss: 0.00262 (passed time: 11m 15s)
#           acc: 0.99866, fpr: 0.00044, fnr: 0.01345, rec: 0.98655, prc: 0.99411, f1: 0.99031, f1_macro: 0.99480
# epoch: 18, passed number of graphs: 384, train running loss: 0.00260 (passed time: 11m 20s)
#           acc: 0.99848, fpr: 0.00057, fnr: 0.01390, rec: 0.98610, prc: 0.99245, f1: 0.98927, f1_macro: 0.99422
# epoch: 18, passed number of graphs: 480, train running loss: 0.00258 (passed time: 11m 24s)
#           acc: 0.99880, fpr: 0.00029, fnr: 0.01320, rec: 0.98680, prc: 0.99611, f1: 0.99143, f1_macro: 0.99539
# epoch: 18, passed number of graphs: 576, train running loss: 0.00259 (passed time: 11m 29s)
#           acc: 0.99893, fpr: 0.00024, fnr: 0.01225, rec: 0.98775, prc: 0.99672, f1: 0.99221, f1_macro: 0.99582
# epoch: 18, passed number of graphs: 672, train running loss: 0.00258 (passed time: 11m 33s)
#           acc: 0.99864, fpr: 0.00045, fnr: 0.01360, rec: 0.98640, prc: 0.99385, f1: 0.99011, f1_macro: 0.99469
# epoch: 18, passed number of graphs: 768, train running loss: 0.00257 (passed time: 11m 37s)
#           acc: 0.99872, fpr: 0.00041, fnr: 0.01290, rec: 0.98710, prc: 0.99441, f1: 0.99074, f1_macro: 0.99503
# Validation --- epoch: 18, loss: 0.00499
#           prc: 0.99465, f1: 0.99062, acc: 0.99870, rec: 0.98663, fnr: 0.01337, f1_macro: 0.99496, fpr: 0.00040
# Better model saved at ./saved_models/GIN_17_0.9906188252013206.pt.
# epoch: 19, passed number of graphs: 96, train running loss: 0.00252 (passed time: 11m 45s)
#           acc: 0.99871, fpr: 0.00035, fnr: 0.01385, rec: 0.98615, prc: 0.99521, f1: 0.99066, f1_macro: 0.99498
# epoch: 19, passed number of graphs: 192, train running loss: 0.00257 (passed time: 11m 50s)
#           acc: 0.99867, fpr: 0.00026, fnr: 0.01560, rec: 0.98440, prc: 0.99656, f1: 0.99044, f1_macro: 0.99486
# epoch: 19, passed number of graphs: 288, train running loss: 0.00256 (passed time: 11m 54s)
#           acc: 0.99868, fpr: 0.00041, fnr: 0.01355, rec: 0.98645, prc: 0.99451, f1: 0.99046, f1_macro: 0.99488
# epoch: 19, passed number of graphs: 384, train running loss: 0.00254 (passed time: 11m 59s)
#           acc: 0.99851, fpr: 0.00047, fnr: 0.01490, rec: 0.98510, prc: 0.99385, f1: 0.98945, f1_macro: 0.99433
# epoch: 19, passed number of graphs: 480, train running loss: 0.00254 (passed time: 12m 3s)
#           acc: 0.99879, fpr: 0.00029, fnr: 0.01325, rec: 0.98675, prc: 0.99611, f1: 0.99141, f1_macro: 0.99538
# epoch: 19, passed number of graphs: 576, train running loss: 0.00255 (passed time: 12m 7s)
#           acc: 0.99893, fpr: 0.00022, fnr: 0.01250, rec: 0.98750, prc: 0.99697, f1: 0.99221, f1_macro: 0.99582
# epoch: 19, passed number of graphs: 672, train running loss: 0.00256 (passed time: 12m 12s)
#           acc: 0.99859, fpr: 0.00053, fnr: 0.01330, rec: 0.98670, prc: 0.99281, f1: 0.98974, f1_macro: 0.99449
# epoch: 19, passed number of graphs: 768, train running loss: 0.00256 (passed time: 12m 16s)
#           acc: 0.99873, fpr: 0.00041, fnr: 0.01285, rec: 0.98715, prc: 0.99451, f1: 0.99082, f1_macro: 0.99507
# Validation --- epoch: 19, loss: 0.00498
#           prc: 0.99487, f1: 0.99074, acc: 0.99872, rec: 0.98666, fnr: 0.01334, f1_macro: 0.99503, fpr: 0.00038
# Better model saved at ./saved_models/GIN_18_0.9907448411551045.pt.
# epoch: 20, passed number of graphs: 96, train running loss: 0.00252 (passed time: 12m 24s)
#           acc: 0.99869, fpr: 0.00032, fnr: 0.01470, rec: 0.98530, prc: 0.99565, f1: 0.99045, f1_macro: 0.99487
# epoch: 20, passed number of graphs: 192, train running loss: 0.00254 (passed time: 12m 28s)
#           acc: 0.99870, fpr: 0.00025, fnr: 0.01535, rec: 0.98465, prc: 0.99666, f1: 0.99062, f1_macro: 0.99496
# epoch: 20, passed number of graphs: 288, train running loss: 0.00253 (passed time: 12m 33s)
#           acc: 0.99871, fpr: 0.00038, fnr: 0.01350, rec: 0.98650, prc: 0.99481, f1: 0.99064, f1_macro: 0.99497
# epoch: 20, passed number of graphs: 384, train running loss: 0.00252 (passed time: 12m 37s)
#           acc: 0.99852, fpr: 0.00049, fnr: 0.01440, rec: 0.98560, prc: 0.99350, f1: 0.98953, f1_macro: 0.99437
# epoch: 20, passed number of graphs: 480, train running loss: 0.00252 (passed time: 12m 42s)
#           acc: 0.99879, fpr: 0.00026, fnr: 0.01370, rec: 0.98630, prc: 0.99651, f1: 0.99138, f1_macro: 0.99536
# epoch: 20, passed number of graphs: 576, train running loss: 0.00254 (passed time: 12m 46s)
#           acc: 0.99893, fpr: 0.00029, fnr: 0.01165, rec: 0.98835, prc: 0.99612, f1: 0.99222, f1_macro: 0.99582
# epoch: 20, passed number of graphs: 672, train running loss: 0.00269 (passed time: 12m 51s)
#           acc: 0.99847, fpr: 0.00060, fnr: 0.01400, rec: 0.98600, prc: 0.99190, f1: 0.98894, f1_macro: 0.99406
# epoch: 20, passed number of graphs: 768, train running loss: 0.00269 (passed time: 12m 55s)
#           acc: 0.99863, fpr: 0.00045, fnr: 0.01380, rec: 0.98620, prc: 0.99395, f1: 0.99006, f1_macro: 0.99466
# Validation --- epoch: 20, loss: 0.00526
#           prc: 0.99488, f1: 0.99027, acc: 0.99865, rec: 0.98569, fnr: 0.01431, f1_macro: 0.99477, fpr: 0.00038
# epoch: 21, passed number of graphs: 96, train running loss: 0.00260 (passed time: 13m 3s)
#           acc: 0.99867, fpr: 0.00036, fnr: 0.01430, rec: 0.98570, prc: 0.99505, f1: 0.99035, f1_macro: 0.99482
# epoch: 21, passed number of graphs: 192, train running loss: 0.00260 (passed time: 13m 7s)
#           acc: 0.99869, fpr: 0.00030, fnr: 0.01470, rec: 0.98530, prc: 0.99591, f1: 0.99057, f1_macro: 0.99494
# epoch: 21, passed number of graphs: 288, train running loss: 0.00258 (passed time: 13m 12s)
#           acc: 0.99869, fpr: 0.00042, fnr: 0.01330, rec: 0.98670, prc: 0.99436, f1: 0.99051, f1_macro: 0.99491
# epoch: 21, passed number of graphs: 384, train running loss: 0.00256 (passed time: 13m 16s)
#           acc: 0.99850, fpr: 0.00054, fnr: 0.01410, rec: 0.98590, prc: 0.99290, f1: 0.98939, f1_macro: 0.99429
# epoch: 21, passed number of graphs: 480, train running loss: 0.00255 (passed time: 13m 21s)
#           acc: 0.99883, fpr: 0.00027, fnr: 0.01300, rec: 0.98700, prc: 0.99637, f1: 0.99166, f1_macro: 0.99551
# epoch: 21, passed number of graphs: 576, train running loss: 0.00256 (passed time: 13m 25s)
#           acc: 0.99893, fpr: 0.00021, fnr: 0.01270, rec: 0.98730, prc: 0.99712, f1: 0.99219, f1_macro: 0.99580
# epoch: 21, passed number of graphs: 672, train running loss: 0.00255 (passed time: 13m 29s)
#           acc: 0.99868, fpr: 0.00045, fnr: 0.01310, rec: 0.98690, prc: 0.99396, f1: 0.99042, f1_macro: 0.99485
# epoch: 21, passed number of graphs: 768, train running loss: 0.00254 (passed time: 13m 34s)
#           acc: 0.99876, fpr: 0.00038, fnr: 0.01285, rec: 0.98715, prc: 0.99491, f1: 0.99101, f1_macro: 0.99517
# Validation --- epoch: 21, loss: 0.00493
#           prc: 0.99500, f1: 0.99087, acc: 0.99873, rec: 0.98677, fnr: 0.01323, f1_macro: 0.99509, fpr: 0.00037
# Better model saved at ./saved_models/GIN_20_0.9908682238029817.pt.
# epoch: 22, passed number of graphs: 96, train running loss: 0.00250 (passed time: 13m 42s)
#           acc: 0.99872, fpr: 0.00032, fnr: 0.01420, rec: 0.98580, prc: 0.99561, f1: 0.99068, f1_macro: 0.99499
# epoch: 22, passed number of graphs: 192, train running loss: 0.00251 (passed time: 13m 46s)
#           acc: 0.99869, fpr: 0.00030, fnr: 0.01470, rec: 0.98530, prc: 0.99596, f1: 0.99060, f1_macro: 0.99495
# epoch: 22, passed number of graphs: 288, train running loss: 0.00251 (passed time: 13m 50s)
#           acc: 0.99872, fpr: 0.00038, fnr: 0.01340, rec: 0.98660, prc: 0.99481, f1: 0.99069, f1_macro: 0.99500
# epoch: 22, passed number of graphs: 384, train running loss: 0.00249 (passed time: 13m 55s)
#           acc: 0.99855, fpr: 0.00044, fnr: 0.01475, rec: 0.98525, prc: 0.99425, f1: 0.98973, f1_macro: 0.99447
# epoch: 22, passed number of graphs: 480, train running loss: 0.00249 (passed time: 13m 59s)
#           acc: 0.99884, fpr: 0.00026, fnr: 0.01300, rec: 0.98700, prc: 0.99657, f1: 0.99176, f1_macro: 0.99557
# epoch: 22, passed number of graphs: 576, train running loss: 0.00250 (passed time: 14m 4s)
#           acc: 0.99896, fpr: 0.00025, fnr: 0.01170, rec: 0.98830, prc: 0.99667, f1: 0.99247, f1_macro: 0.99596
# epoch: 22, passed number of graphs: 672, train running loss: 0.00250 (passed time: 14m 8s)
#           acc: 0.99870, fpr: 0.00038, fnr: 0.01365, rec: 0.98635, prc: 0.99481, f1: 0.99056, f1_macro: 0.99493
# epoch: 22, passed number of graphs: 768, train running loss: 0.00249 (passed time: 14m 13s)
#           acc: 0.99875, fpr: 0.00039, fnr: 0.01270, rec: 0.98730, prc: 0.99466, f1: 0.99097, f1_macro: 0.99515
# Validation --- epoch: 22, loss: 0.00490
#           prc: 0.99484, f1: 0.99090, acc: 0.99874, rec: 0.98699, fnr: 0.01301, f1_macro: 0.99511, fpr: 0.00038
# Better model saved at ./saved_models/GIN_21_0.990898222759966.pt.
# epoch: 23, passed number of graphs: 96, train running loss: 0.00253 (passed time: 14m 20s)
#           acc: 0.99862, fpr: 0.00029, fnr: 0.01605, rec: 0.98395, prc: 0.99600, f1: 0.98994, f1_macro: 0.99460
# epoch: 23, passed number of graphs: 192, train running loss: 0.00259 (passed time: 14m 25s)
#           acc: 0.99869, fpr: 0.00023, fnr: 0.01570, rec: 0.98430, prc: 0.99696, f1: 0.99059, f1_macro: 0.99494
# epoch: 23, passed number of graphs: 288, train running loss: 0.00256 (passed time: 14m 29s)
#           acc: 0.99872, fpr: 0.00038, fnr: 0.01340, rec: 0.98660, prc: 0.99491, f1: 0.99074, f1_macro: 0.99503
# epoch: 23, passed number of graphs: 384, train running loss: 0.00253 (passed time: 14m 34s)
#           acc: 0.99856, fpr: 0.00045, fnr: 0.01445, rec: 0.98555, prc: 0.99410, f1: 0.98981, f1_macro: 0.99452
# epoch: 23, passed number of graphs: 480, train running loss: 0.00252 (passed time: 14m 38s)
#           acc: 0.99883, fpr: 0.00024, fnr: 0.01330, rec: 0.98670, prc: 0.99677, f1: 0.99171, f1_macro: 0.99554
# epoch: 23, passed number of graphs: 576, train running loss: 0.00257 (passed time: 14m 43s)
#           acc: 0.99896, fpr: 0.00024, fnr: 0.01185, rec: 0.98815, prc: 0.99672, f1: 0.99242, f1_macro: 0.99593
# epoch: 23, passed number of graphs: 672, train running loss: 0.00256 (passed time: 14m 47s)
#           acc: 0.99870, fpr: 0.00042, fnr: 0.01305, rec: 0.98695, prc: 0.99426, f1: 0.99059, f1_macro: 0.99495
# epoch: 23, passed number of graphs: 768, train running loss: 0.00254 (passed time: 14m 51s)
#           acc: 0.99877, fpr: 0.00035, fnr: 0.01305, rec: 0.98695, prc: 0.99521, f1: 0.99106, f1_macro: 0.99520
# Validation --- epoch: 23, loss: 0.00485
#           prc: 0.99590, f1: 0.99109, acc: 0.99877, rec: 0.98633, fnr: 0.01367, f1_macro: 0.99521, fpr: 0.00030
# Better model saved at ./saved_models/GIN_22_0.9910884145359463.pt.
# epoch: 24, passed number of graphs: 96, train running loss: 0.00252 (passed time: 14m 59s)
#           acc: 0.99871, fpr: 0.00034, fnr: 0.01410, rec: 0.98590, prc: 0.99541, f1: 0.99063, f1_macro: 0.99497
# epoch: 24, passed number of graphs: 192, train running loss: 0.00251 (passed time: 15m 4s)
#           acc: 0.99874, fpr: 0.00021, fnr: 0.01535, rec: 0.98465, prc: 0.99721, f1: 0.99089, f1_macro: 0.99511
# epoch: 24, passed number of graphs: 288, train running loss: 0.00249 (passed time: 15m 8s)
#           acc: 0.99874, fpr: 0.00037, fnr: 0.01330, rec: 0.98670, prc: 0.99501, f1: 0.99084, f1_macro: 0.99508
# epoch: 24, passed number of graphs: 384, train running loss: 0.00248 (passed time: 15m 12s)
#           acc: 0.99858, fpr: 0.00040, fnr: 0.01480, rec: 0.98520, prc: 0.99470, f1: 0.98993, f1_macro: 0.99458
# epoch: 24, passed number of graphs: 480, train running loss: 0.00248 (passed time: 15m 17s)
#           acc: 0.99887, fpr: 0.00025, fnr: 0.01265, rec: 0.98735, prc: 0.99662, f1: 0.99196, f1_macro: 0.99568
# epoch: 24, passed number of graphs: 576, train running loss: 0.00249 (passed time: 15m 21s)
#           acc: 0.99896, fpr: 0.00025, fnr: 0.01170, rec: 0.98830, prc: 0.99662, f1: 0.99244, f1_macro: 0.99594
# epoch: 24, passed number of graphs: 672, train running loss: 0.00249 (passed time: 15m 26s)
#           acc: 0.99869, fpr: 0.00039, fnr: 0.01370, rec: 0.98630, prc: 0.99471, f1: 0.99048, f1_macro: 0.99489
# epoch: 24, passed number of graphs: 768, train running loss: 0.00248 (passed time: 15m 30s)
#           acc: 0.99880, fpr: 0.00036, fnr: 0.01250, rec: 0.98750, prc: 0.99516, f1: 0.99132, f1_macro: 0.99534
# Validation --- epoch: 24, loss: 0.00479
#           prc: 0.99557, f1: 0.99123, acc: 0.99879, rec: 0.98694, fnr: 0.01306, f1_macro: 0.99529, fpr: 0.00033
# Better model saved at ./saved_models/GIN_23_0.9912329294052004.pt.
# epoch: 25, passed number of graphs: 96, train running loss: 0.00253 (passed time: 15m 38s)
#           acc: 0.99846, fpr: 0.00026, fnr: 0.01885, rec: 0.98115, prc: 0.99650, f1: 0.98876, f1_macro: 0.99397
# epoch: 25, passed number of graphs: 192, train running loss: 0.00291 (passed time: 15m 42s)
#           acc: 0.99853, fpr: 0.00024, fnr: 0.01785, rec: 0.98215, prc: 0.99680, f1: 0.98942, f1_macro: 0.99432
# ...
#           acc: 0.99878, fpr: 0.00036, fnr: 0.01275, rec: 0.98725, prc: 0.99511, f1: 0.99117, f1_macro: 0.99526
# epoch: 42, passed number of graphs: 384, train running loss: 0.00234 (passed time: 26m 50s)
#           acc: 0.99864, fpr: 0.00044, fnr: 0.01345, rec: 0.98655, prc: 0.99421, f1: 0.99036, f1_macro: 0.99482
# epoch: 42, passed number of graphs: 480, train running loss: 0.00234 (passed time: 26m 54s)
#           acc: 0.99892, fpr: 0.00020, fnr: 0.01260, rec: 0.98740, prc: 0.99732, f1: 0.99234, f1_macro: 0.99588
# epoch: 42, passed number of graphs: 576, train running loss: 0.00235 (passed time: 26m 59s)
#           acc: 0.99897, fpr: 0.00024, fnr: 0.01165, rec: 0.98835, prc: 0.99672, f1: 0.99252, f1_macro: 0.99598
# epoch: 42, passed number of graphs: 672, train running loss: 0.00234 (passed time: 27m 3s)
#           acc: 0.99881, fpr: 0.00030, fnr: 0.01310, rec: 0.98690, prc: 0.99586, f1: 0.99136, f1_macro: 0.99536
# epoch: 42, passed number of graphs: 768, train running loss: 0.00234 (passed time: 27m 8s)
#           acc: 0.99885, fpr: 0.00029, fnr: 0.01275, rec: 0.98725, prc: 0.99612, f1: 0.99166, f1_macro: 0.99552
# Validation --- epoch: 42, loss: 0.00461
#           prc: 0.99617, f1: 0.99159, acc: 0.99884, rec: 0.98706, fnr: 0.01294, f1_macro: 0.99548, fpr: 0.00028
# epoch: 43, passed number of graphs: 96, train running loss: 0.00235 (passed time: 27m 15s)
#           acc: 0.99881, fpr: 0.00033, fnr: 0.01270, rec: 0.98730, prc: 0.99551, f1: 0.99139, f1_macro: 0.99538
# epoch: 43, passed number of graphs: 192, train running loss: 0.00235 (passed time: 27m 20s)
#           acc: 0.99881, fpr: 0.00023, fnr: 0.01400, rec: 0.98600, prc: 0.99697, f1: 0.99145, f1_macro: 0.99541
# epoch: 43, passed number of graphs: 288, train running loss: 0.00235 (passed time: 27m 24s)
#           acc: 0.99878, fpr: 0.00036, fnr: 0.01275, rec: 0.98725, prc: 0.99511, f1: 0.99117, f1_macro: 0.99526
# epoch: 43, passed number of graphs: 384, train running loss: 0.00234 (passed time: 27m 29s)
#           acc: 0.99864, fpr: 0.00044, fnr: 0.01345, rec: 0.98655, prc: 0.99421, f1: 0.99036, f1_macro: 0.99482
# epoch: 43, passed number of graphs: 480, train running loss: 0.00234 (passed time: 27m 33s)
#           acc: 0.99892, fpr: 0.00020, fnr: 0.01260, rec: 0.98740, prc: 0.99732, f1: 0.99234, f1_macro: 0.99588
# epoch: 43, passed number of graphs: 576, train running loss: 0.00235 (passed time: 27m 38s)
#           acc: 0.99897, fpr: 0.00024, fnr: 0.01165, rec: 0.98835, prc: 0.99672, f1: 0.99252, f1_macro: 0.99598
# epoch: 43, passed number of graphs: 672, train running loss: 0.00234 (passed time: 27m 42s)
#           acc: 0.99881, fpr: 0.00030, fnr: 0.01310, rec: 0.98690, prc: 0.99586, f1: 0.99136, f1_macro: 0.99536
# epoch: 43, passed number of graphs: 768, train running loss: 0.00234 (passed time: 27m 46s)
#           acc: 0.99885, fpr: 0.00029, fnr: 0.01275, rec: 0.98725, prc: 0.99612, f1: 0.99166, f1_macro: 0.99552
# Validation --- epoch: 43, loss: 0.00461
#           prc: 0.99617, f1: 0.99159, acc: 0.99884, rec: 0.98706, fnr: 0.01294, f1_macro: 0.99548, fpr: 0.00028
# epoch: 44, passed number of graphs: 96, train running loss: 0.00235 (passed time: 27m 54s)
#           acc: 0.99881, fpr: 0.00033, fnr: 0.01275, rec: 0.98725, prc: 0.99551, f1: 0.99136, f1_macro: 0.99536
# epoch: 44, passed number of graphs: 192, train running loss: 0.00235 (passed time: 27m 59s)
#           acc: 0.99881, fpr: 0.00023, fnr: 0.01400, rec: 0.98600, prc: 0.99697, f1: 0.99145, f1_macro: 0.99541
# epoch: 44, passed number of graphs: 288, train running loss: 0.00235 (passed time: 28m 3s)
#           acc: 0.99878, fpr: 0.00036, fnr: 0.01270, rec: 0.98730, prc: 0.99511, f1: 0.99119, f1_macro: 0.99527
# epoch: 44, passed number of graphs: 384, train running loss: 0.00234 (passed time: 28m 7s)
#           acc: 0.99864, fpr: 0.00044, fnr: 0.01345, rec: 0.98655, prc: 0.99421, f1: 0.99036, f1_macro: 0.99482
# epoch: 44, passed number of graphs: 480, train running loss: 0.00234 (passed time: 28m 12s)
#           acc: 0.99893, fpr: 0.00020, fnr: 0.01255, rec: 0.98745, prc: 0.99732, f1: 0.99236, f1_macro: 0.99589
# epoch: 44, passed number of graphs: 576, train running loss: 0.00235 (passed time: 28m 16s)
#           acc: 0.99897, fpr: 0.00025, fnr: 0.01165, rec: 0.98835, prc: 0.99667, f1: 0.99249, f1_macro: 0.99597
# epoch: 44, passed number of graphs: 672, train running loss: 0.00234 (passed time: 28m 21s)
#           acc: 0.99881, fpr: 0.00030, fnr: 0.01310, rec: 0.98690, prc: 0.99586, f1: 0.99136, f1_macro: 0.99536
# epoch: 44, passed number of graphs: 768, train running loss: 0.00234 (passed time: 28m 25s)
#           acc: 0.99885, fpr: 0.00029, fnr: 0.01275, rec: 0.98725, prc: 0.99612, f1: 0.99166, f1_macro: 0.99552
# Validation --- epoch: 44, loss: 0.00461
#           prc: 0.99617, f1: 0.99159, acc: 0.99884, rec: 0.98706, fnr: 0.01294, f1_macro: 0.99548, fpr: 0.00028
# epoch: 45, passed number of graphs: 96, train running loss: 0.00235 (passed time: 28m 33s)
#           acc: 0.99881, fpr: 0.00033, fnr: 0.01270, rec: 0.98730, prc: 0.99546, f1: 0.99136, f1_macro: 0.99536
# epoch: 45, passed number of graphs: 192, train running loss: 0.00235 (passed time: 28m 37s)
#           acc: 0.99881, fpr: 0.00023, fnr: 0.01400, rec: 0.98600, prc: 0.99697, f1: 0.99145, f1_macro: 0.99541
# epoch: 45, passed number of graphs: 288, train running loss: 0.00235 (passed time: 28m 42s)
#           acc: 0.99878, fpr: 0.00036, fnr: 0.01270, rec: 0.98730, prc: 0.99511, f1: 0.99119, f1_macro: 0.99527
# epoch: 45, passed number of graphs: 384, train running loss: 0.00234 (passed time: 28m 46s)
#           acc: 0.99864, fpr: 0.00044, fnr: 0.01345, rec: 0.98655, prc: 0.99421, f1: 0.99036, f1_macro: 0.99482
# epoch: 45, passed number of graphs: 480, train running loss: 0.00234 (passed time: 28m 51s)
#           acc: 0.99893, fpr: 0.00020, fnr: 0.01255, rec: 0.98745, prc: 0.99732, f1: 0.99236, f1_macro: 0.99589
# epoch: 45, passed number of graphs: 576, train running loss: 0.00235 (passed time: 28m 55s)
#           acc: 0.99897, fpr: 0.00025, fnr: 0.01165, rec: 0.98835, prc: 0.99667, f1: 0.99249, f1_macro: 0.99597
# epoch: 45, passed number of graphs: 672, train running loss: 0.00234 (passed time: 29m 0s)
#           acc: 0.99881, fpr: 0.00030, fnr: 0.01305, rec: 0.98695, prc: 0.99586, f1: 0.99139, f1_macro: 0.99537
# epoch: 45, passed number of graphs: 768, train running loss: 0.00234 (passed time: 29m 4s)
#           acc: 0.99885, fpr: 0.00028, fnr: 0.01275, rec: 0.98725, prc: 0.99617, f1: 0.99169, f1_macro: 0.99554
# Validation --- epoch: 45, loss: 0.00461
#           prc: 0.99617, f1: 0.99159, acc: 0.99884, rec: 0.98706, fnr: 0.01294, f1_macro: 0.99548, fpr: 0.00028
# epoch: 46, passed number of graphs: 96, train running loss: 0.00235 (passed time: 29m 12s)
#           acc: 0.99881, fpr: 0.00034, fnr: 0.01270, rec: 0.98730, prc: 0.99541, f1: 0.99134, f1_macro: 0.99535
# epoch: 46, passed number of graphs: 192, train running loss: 0.00235 (passed time: 29m 16s)
#           acc: 0.99881, fpr: 0.00023, fnr: 0.01400, rec: 0.98600, prc: 0.99697, f1: 0.99145, f1_macro: 0.99541
# epoch: 46, passed number of graphs: 288, train running loss: 0.00235 (passed time: 29m 21s)
#           acc: 0.99878, fpr: 0.00036, fnr: 0.01270, rec: 0.98730, prc: 0.99511, f1: 0.99119, f1_macro: 0.99527
# epoch: 46, passed number of graphs: 384, train running loss: 0.00234 (passed time: 29m 25s)
#           acc: 0.99864, fpr: 0.00044, fnr: 0.01345, rec: 0.98655, prc: 0.99421, f1: 0.99036, f1_macro: 0.99482
# epoch: 46, passed number of graphs: 480, train running loss: 0.00234 (passed time: 29m 30s)
#           acc: 0.99893, fpr: 0.00020, fnr: 0.01255, rec: 0.98745, prc: 0.99732, f1: 0.99236, f1_macro: 0.99589
# epoch: 46, passed number of graphs: 576, train running loss: 0.00235 (passed time: 29m 34s)
#           acc: 0.99897, fpr: 0.00025, fnr: 0.01165, rec: 0.98835, prc: 0.99667, f1: 0.99249, f1_macro: 0.99597
# epoch: 46, passed number of graphs: 672, train running loss: 0.00234 (passed time: 29m 38s)
#           acc: 0.99882, fpr: 0.00030, fnr: 0.01305, rec: 0.98695, prc: 0.99591, f1: 0.99141, f1_macro: 0.99539
# epoch: 46, passed number of graphs: 768, train running loss: 0.00234 (passed time: 29m 43s)
#           acc: 0.99885, fpr: 0.00028, fnr: 0.01275, rec: 0.98725, prc: 0.99617, f1: 0.99169, f1_macro: 0.99554
# Validation --- epoch: 46, loss: 0.00461
#           prc: 0.99617, f1: 0.99159, acc: 0.99884, rec: 0.98706, fnr: 0.01294, f1_macro: 0.99548, fpr: 0.00028
# Better model saved at ./saved_models/GIN_45_0.9915948470798687.pt.
# epoch: 47, passed number of graphs: 96, train running loss: 0.00235 (passed time: 29m 51s)
#           acc: 0.99881, fpr: 0.00033, fnr: 0.01275, rec: 0.98725, prc: 0.99546, f1: 0.99134, f1_macro: 0.99535
# epoch: 47, passed number of graphs: 192, train running loss: 0.00235 (passed time: 29m 55s)
#           acc: 0.99881, fpr: 0.00023, fnr: 0.01400, rec: 0.98600, prc: 0.99697, f1: 0.99145, f1_macro: 0.99541
# epoch: 47, passed number of graphs: 288, train running loss: 0.00235 (passed time: 30m 0s)
#           acc: 0.99878, fpr: 0.00036, fnr: 0.01270, rec: 0.98730, prc: 0.99511, f1: 0.99119, f1_macro: 0.99527
# epoch: 47, passed number of graphs: 384, train running loss: 0.00234 (passed time: 30m 4s)
#           acc: 0.99864, fpr: 0.00044, fnr: 0.01345, rec: 0.98655, prc: 0.99421, f1: 0.99036, f1_macro: 0.99482
# epoch: 47, passed number of graphs: 480, train running loss: 0.00234 (passed time: 30m 8s)
#           acc: 0.99893, fpr: 0.00020, fnr: 0.01255, rec: 0.98745, prc: 0.99732, f1: 0.99236, f1_macro: 0.99589
# epoch: 47, passed number of graphs: 576, train running loss: 0.00235 (passed time: 30m 13s)
#           acc: 0.99897, fpr: 0.00025, fnr: 0.01165, rec: 0.98835, prc: 0.99667, f1: 0.99249, f1_macro: 0.99597
# epoch: 47, passed number of graphs: 672, train running loss: 0.00234 (passed time: 30m 17s)
#           acc: 0.99882, fpr: 0.00030, fnr: 0.01305, rec: 0.98695, prc: 0.99591, f1: 0.99141, f1_macro: 0.99539
# epoch: 47, passed number of graphs: 768, train running loss: 0.00234 (passed time: 30m 22s)
#           acc: 0.99885, fpr: 0.00028, fnr: 0.01275, rec: 0.98725, prc: 0.99617, f1: 0.99169, f1_macro: 0.99554
# Validation --- epoch: 47, loss: 0.00461
#           prc: 0.99618, f1: 0.99160, acc: 0.99884, rec: 0.98706, fnr: 0.01294, f1_macro: 0.99549, fpr: 0.00028
# Better model saved at ./saved_models/GIN_46_0.9915969085911823.pt.
# epoch: 48, passed number of graphs: 96, train running loss: 0.00235 (passed time: 30m 29s)
#           acc: 0.99881, fpr: 0.00033, fnr: 0.01275, rec: 0.98725, prc: 0.99546, f1: 0.99134, f1_macro: 0.99535
# epoch: 48, passed number of graphs: 192, train running loss: 0.00235 (passed time: 30m 34s)
#           acc: 0.99881, fpr: 0.00023, fnr: 0.01400, rec: 0.98600, prc: 0.99697, f1: 0.99145, f1_macro: 0.99541
# epoch: 48, passed number of graphs: 288, train running loss: 0.00235 (passed time: 30m 38s)
#           acc: 0.99878, fpr: 0.00036, fnr: 0.01270, rec: 0.98730, prc: 0.99511, f1: 0.99119, f1_macro: 0.99527
# epoch: 48, passed number of graphs: 384, train running loss: 0.00234 (passed time: 30m 43s)
#           acc: 0.99864, fpr: 0.00044, fnr: 0.01345, rec: 0.98655, prc: 0.99421, f1: 0.99036, f1_macro: 0.99482
# epoch: 48, passed number of graphs: 480, train running loss: 0.00234 (passed time: 30m 47s)
#           acc: 0.99893, fpr: 0.00020, fnr: 0.01255, rec: 0.98745, prc: 0.99732, f1: 0.99236, f1_macro: 0.99589
# epoch: 48, passed number of graphs: 576, train running loss: 0.00235 (passed time: 30m 52s)
#           acc: 0.99897, fpr: 0.00025, fnr: 0.01165, rec: 0.98835, prc: 0.99667, f1: 0.99249, f1_macro: 0.99597
# epoch: 48, passed number of graphs: 672, train running loss: 0.00234 (passed time: 30m 56s)
#           acc: 0.99882, fpr: 0.00030, fnr: 0.01305, rec: 0.98695, prc: 0.99591, f1: 0.99141, f1_macro: 0.99539
# epoch: 48, passed number of graphs: 768, train running loss: 0.00234 (passed time: 31m 0s)
#           acc: 0.99885, fpr: 0.00028, fnr: 0.01280, rec: 0.98720, prc: 0.99617, f1: 0.99166, f1_macro: 0.99552
# Validation --- epoch: 48, loss: 0.00461
#           prc: 0.99618, f1: 0.99160, acc: 0.99884, rec: 0.98706, fnr: 0.01294, f1_macro: 0.99549, fpr: 0.00028
# Better model saved at ./saved_models/GIN_47_0.9915989850864242.pt.
# epoch: 49, passed number of graphs: 96, train running loss: 0.00235 (passed time: 31m 8s)
#           acc: 0.99881, fpr: 0.00033, fnr: 0.01275, rec: 0.98725, prc: 0.99546, f1: 0.99134, f1_macro: 0.99535
# epoch: 49, passed number of graphs: 192, train running loss: 0.00235 (passed time: 31m 13s)
#           acc: 0.99881, fpr: 0.00023, fnr: 0.01400, rec: 0.98600, prc: 0.99697, f1: 0.99145, f1_macro: 0.99541
# epoch: 49, passed number of graphs: 288, train running loss: 0.00235 (passed time: 31m 17s)
#           acc: 0.99878, fpr: 0.00036, fnr: 0.01270, rec: 0.98730, prc: 0.99511, f1: 0.99119, f1_macro: 0.99527
# epoch: 49, passed number of graphs: 384, train running loss: 0.00234 (passed time: 31m 22s)
#           acc: 0.99864, fpr: 0.00044, fnr: 0.01345, rec: 0.98655, prc: 0.99421, f1: 0.99036, f1_macro: 0.99482
# epoch: 49, passed number of graphs: 480, train running loss: 0.00234 (passed time: 31m 26s)
#           acc: 0.99893, fpr: 0.00020, fnr: 0.01255, rec: 0.98745, prc: 0.99732, f1: 0.99236, f1_macro: 0.99589
# epoch: 49, passed number of graphs: 576, train running loss: 0.00234 (passed time: 31m 30s)
#           acc: 0.99897, fpr: 0.00025, fnr: 0.01165, rec: 0.98835, prc: 0.99667, f1: 0.99249, f1_macro: 0.99597
# epoch: 49, passed number of graphs: 672, train running loss: 0.00234 (passed time: 31m 35s)
#           acc: 0.99882, fpr: 0.00030, fnr: 0.01305, rec: 0.98695, prc: 0.99591, f1: 0.99141, f1_macro: 0.99539
# epoch: 49, passed number of graphs: 768, train running loss: 0.00234 (passed time: 31m 39s)
#           acc: 0.99885, fpr: 0.00028, fnr: 0.01280, rec: 0.98720, prc: 0.99617, f1: 0.99166, f1_macro: 0.99552
# Validation --- epoch: 49, loss: 0.00461
#           prc: 0.99618, f1: 0.99160, acc: 0.99884, rec: 0.98706, fnr: 0.01294, f1_macro: 0.99549, fpr: 0.00028
# epoch: 50, passed number of graphs: 96, train running loss: 0.00235 (passed time: 31m 47s)
#           acc: 0.99881, fpr: 0.00033, fnr: 0.01275, rec: 0.98725, prc: 0.99546, f1: 0.99134, f1_macro: 0.99535
# epoch: 50, passed number of graphs: 192, train running loss: 0.00235 (passed time: 31m 51s)
#           acc: 0.99881, fpr: 0.00023, fnr: 0.01400, rec: 0.98600, prc: 0.99697, f1: 0.99145, f1_macro: 0.99541
# epoch: 50, passed number of graphs: 288, train running loss: 0.00235 (passed time: 31m 56s)
#           acc: 0.99878, fpr: 0.00036, fnr: 0.01270, rec: 0.98730, prc: 0.99511, f1: 0.99119, f1_macro: 0.99527
# epoch: 50, passed number of graphs: 384, train running loss: 0.00234 (passed time: 32m 0s)
#           acc: 0.99864, fpr: 0.00044, fnr: 0.01345, rec: 0.98655, prc: 0.99426, f1: 0.99039, f1_macro: 0.99483
# epoch: 50, passed number of graphs: 480, train running loss: 0.00233 (passed time: 32m 5s)
#           acc: 0.99893, fpr: 0.00020, fnr: 0.01255, rec: 0.98745, prc: 0.99732, f1: 0.99236, f1_macro: 0.99589
# epoch: 50, passed number of graphs: 576, train running loss: 0.00234 (passed time: 32m 9s)
#           acc: 0.99897, fpr: 0.00025, fnr: 0.01165, rec: 0.98835, prc: 0.99667, f1: 0.99249, f1_macro: 0.99597
# epoch: 50, passed number of graphs: 672, train running loss: 0.00234 (passed time: 32m 14s)
#           acc: 0.99882, fpr: 0.00030, fnr: 0.01305, rec: 0.98695, prc: 0.99591, f1: 0.99141, f1_macro: 0.99539
# epoch: 50, passed number of graphs: 768, train running loss: 0.00234 (passed time: 32m 18s)
#           acc: 0.99885, fpr: 0.00028, fnr: 0.01280, rec: 0.98720, prc: 0.99617, f1: 0.99166, f1_macro: 0.99552
# Validation --- epoch: 50, loss: 0.00461
#           prc: 0.99618, f1: 0.99160, acc: 0.99884, rec: 0.98707, fnr: 0.01293, f1_macro: 0.99549, fpr: 0.00028
# Better model saved at ./saved_models/GIN_49_0.9916000601477558.pt.
# ************ best model obtained after epoch 50, saved at ./saved_models/GIN_49_0.9916000601477558.pt ************
# Testing --- loss: 0.00463
#           prc: 0.99619, f1: 0.99150, acc: 0.99883, rec: 0.98685, fnr: 0.01315, f1_macro: 0.99543, fpr: 0.00028

# %%
# !zip -r /content/GIN_Adam_Chord.zip /content/saved_models
# Out:
#   adding: content/saved_models/ (stored 0%)
#   adding: content/saved_models/GIN_0_0.9021373960268554.pt (deflated 30%)
#   adding: content/saved_models/GIN_4_0.9862823908498309.pt (deflated 29%)
#   adding: content/saved_models/GIN_47_0.9915989850864242.pt (deflated 30%)
#   adding: content/saved_models/GIN_17_0.9906188252013206.pt (deflated 29%)
#   adding: content/saved_models/GIN_20_0.9908682238029817.pt (deflated 29%)
#   adding: content/saved_models/GIN_15_0.9906092022031939.pt (deflated 29%)
#   adding: content/saved_models/GIN_3_0.9735259244880883.pt (deflated 29%)
#   adding: content/saved_models/GIN_22_0.9910884145359463.pt (deflated 29%)
#   adding: content/saved_models/GIN_33_0.9915776813873518.pt (deflated 30%)
#   adding: content/saved_models/GIN_18_0.9907448411551045.pt (deflated 29%)
#   adding: content/saved_models/GIN_7_0.9886357809564109.pt (deflated 29%)
#   adding: content/saved_models/GIN_21_0.990898222759966.pt (deflated 29%)
#   adding: content/saved_models/GIN_13_0.9903894324405815.pt (deflated 29%)
#   adding: content/saved_models/GIN_49_0.9916000601477558.pt (deflated 31%)
#   adding: content/saved_models/GIN_8_0.9891156608819275.pt (deflated 29%)
#   adding: content/saved_models/GIN_26_0.991388966310454.pt (deflated 30%)
#   adding: content/saved_models/GIN_45_0.9915948470798687.pt (deflated 30%)
#   adding: content/saved_models/GIN_34_0.9915891864415439.pt (deflated 30%)
#   adding: content/saved_models/GIN_9_0.9897156681718408.pt (deflated 29%)
#   adding: content/saved_models/GIN_27_0.9914033640369452.pt (deflated 30%)
#   adding: content/saved_models/GIN_35_0.991594822519723.pt (deflated 30%)
#   adding: content/saved_models/GIN_30_0.9915268861604609.pt (deflated 30%)
#   adding: content/saved_models/GIN_46_0.9915969085911823.pt (deflated 30%)
#   adding: content/saved_models/GIN_23_0.9912329294052004.pt (deflated 29%)
#   adding: content/saved_models/GIN_1_0.9720732230849038.pt (deflated 30%)

# %%
from google.colab import files
files.download("/content/GIN_Adam_Chord.zip")
